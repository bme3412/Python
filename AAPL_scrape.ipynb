# %%
import pandas as pd
url = 'https://nvidianews.nvidia.com/news/nvidia-announces-financial-results-for-third-quarter-fiscal-2022'

# %%
list_of_dfs = pd.read_html(url)

# %%
df = list_of_dfs[1]
df.head()
# Out:
#                                             0         1         2         3  \
# 0                                    Non-GAAP  Non-GAAP  Non-GAAP  Non-GAAP
# 1  ($ in millions, except earnings per share)   Q3 FY22   Q3 FY22   Q2 FY22
# 2                                     Revenue    $7,103    $7,103    $6,507
# 3                                Gross margin     67.0%     67.0%     66.7%
# 4                          Operating expenses    $1,375    $1,375    $1,266
#
#           4         5         6          7           8
# 0  Non-GAAP  Non-GAAP  Non-GAAP   Non-GAAP    Non-GAAP
# 1   Q2 FY22   Q3 FY21   Q3 FY21        Q/Q         Y/Y
# 2    $6,507    $4,726    $4,726      Up 9%      Up 50%
# 3     66.7%     65.5%     65.5%  Up 30 bps  Up 150 bps
# 4    $1,266    $1,101    $1,101      Up 9%      Up 25%

# %%
df.shape
# Out:
# (8, 9)

# %%
df
# Out:
#                                             0         1         2         3  \
# 0                                    Non-GAAP  Non-GAAP  Non-GAAP  Non-GAAP
# 1  ($ in millions, except earnings per share)   Q3 FY22   Q3 FY22   Q2 FY22
# 2                                     Revenue    $7,103    $7,103    $6,507
# 3                                Gross margin     67.0%     67.0%     66.7%
# 4                          Operating expenses    $1,375    $1,375    $1,266
# 5                            Operating income    $3,386    $3,386    $3,071
# 6                                  Net income    $2,973    $2,973    $2,623
# 7                 Diluted earnings per share*     $1.17     $1.17     $1.04
#
#           4         5         6          7           8
# 0  Non-GAAP  Non-GAAP  Non-GAAP   Non-GAAP    Non-GAAP
# 1   Q2 FY22   Q3 FY21   Q3 FY21        Q/Q         Y/Y
# 2    $6,507    $4,726    $4,726      Up 9%      Up 50%
# 3     66.7%     65.5%     65.5%  Up 30 bps  Up 150 bps
# ...
