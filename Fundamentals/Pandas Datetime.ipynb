# %%
import pandas as pd

df = pd.read_csv("https://calmcode.io/datasets/birthdays.csv")

# %%
# convert data from object to datetime64
df.assign(date = lambda d: pd.to_datetime(d['date'])).dtypes
# Out:
# state             object
# year               int64
# month              int64
# day                int64
# date      datetime64[ns]
# wday              object
# births             int64
# dtype: object

# %%
df.assign(date = lambda d: pd.to_datetime(d['date'],format='%Y-%m-%d')).dtypes
# Out:
# state             object
# year               int64
# month              int64
# day                int64
# date      datetime64[ns]
# wday              object
# births             int64
# dtype: object

# %%
# if have a column of type datetime, can unpack datetime data
(df.assign(date = lambda d: pd.to_datetime(d['date']),
          day_of_week = lambda d: d['date'].dt.day_name(),
          minute = lambda d: d['date'].dt.minute,
          nanosecond = lambda d: d['date'].dt.nanosecond,
          day_of_year = lambda d: d['date'].dt.day_of_year,
          month_manual = lambda d: d['date'].dt.month,
          week = lambda d: d['date'].dt.isocalendar().week))
# Out:
#        state  year  month  day       date wday  births day_of_week  minute  \
# 0         AK  1969      1    1 1969-01-01  Wed      14   Wednesday       0
# 1         AL  1969      1    1 1969-01-01  Wed     174   Wednesday       0
# 2         AR  1969      1    1 1969-01-01  Wed      78   Wednesday       0
# 3         AZ  1969      1    1 1969-01-01  Wed      84   Wednesday       0
# 4         CA  1969      1    1 1969-01-01  Wed     824   Wednesday       0
# ...      ...   ...    ...  ...        ...  ...     ...         ...     ...
# 372550    VT  1988     12   31 1988-12-31  Sat      21    Saturday       0
# 372551    WA  1988     12   31 1988-12-31  Sat     157    Saturday       0
# 372552    WI  1988     12   31 1988-12-31  Sat     167    Saturday       0
# 372553    WV  1988     12   31 1988-12-31  Sat      45    Saturday       0
# 372554    WY  1988     12   31 1988-12-31  Sat      18    Saturday       0
#
#         nanosecond  day_of_year  month_manual  week
# 0                0            1             1     1
# 1                0            1             1     1
# 2                0            1             1     1
# 3                0            1             1     1
# 4                0            1             1     1
# ...            ...          ...           ...   ...
# 372550           0          366            12    52
# 372551           0          366            12    52
# 372552           0          366            12    52
# 372553           0          366            12    52
# 372554           0          366            12    52
#
# [372555 rows x 13 columns]

# %%
subset_df = (df
            .assign(date=lambda d: pd.to_datetime(d['date'], format="%Y-%m-%d"))
            [['state', 'date', 'births']]
            .assign(year = lambda d: d['date'].dt.year))
subset_df
# Out:
#        state       date  births  year
# 0         AK 1969-01-01      14  1969
# 1         AL 1969-01-01     174  1969
# 2         AR 1969-01-01      78  1969
# 3         AZ 1969-01-01      84  1969
# 4         CA 1969-01-01     824  1969
# ...      ...        ...     ...   ...
# 372550    VT 1988-12-31      21  1988
# 372551    WA 1988-12-31     157  1988
# 372552    WI 1988-12-31     167  1988
# 372553    WV 1988-12-31      45  1988
# 372554    WY 1988-12-31      18  1988
#
# [372555 rows x 4 columns]

# %%
subset_df = (df
            .assign(date=lambda d: pd.to_datetime(d['date'], format="%Y-%m-%d"))
            [['state', 'date', 'births']]
            .loc[lambda d: d['state']=='CA'])

 # resample by 2 weeks and sum
subset_df.set_index('date').resample('2W').sum().head()
# Out:
#             births
# date
# 1969-01-05    4290
# 1969-01-19   12942
# 1969-02-02   12784
# 1969-02-16   12932
# 1969-03-02   13198

# %%
 # resample by 1 month and sum
subset_df.set_index('date').resample('M').sum().head()
# Out:
#             births
# date
# 1969-01-31   28386
# 1969-02-28   26052
# 1969-03-31   29488
# 1969-04-30   28668
# 1969-05-31   29806

# %%
subset_df = (df
            .assign(date=lambda d: pd.to_datetime(d['date'], format="%Y-%m-%d"))
            [['state', 'date', 'births']])


 # resample by 1 year and sum
subset_df.set_index('date').resample('Y').sum().head()
# Out:
#              births
# date
# 1969-12-31  3599036
# 1970-12-31  3734914
# 1971-12-31  3563126
# 1972-12-31  3265895
# 1973-12-31  3145703

# %%
 # resample by 1 year, groubpy and sum
subset_df.set_index('date').groupby('state').resample('Y').sum().head()
# Out:
#                   births
# state date
# AK    1969-12-31    6824
#       1970-12-31    7464
#       1971-12-31    7244
#       1972-12-31    6892
#       1973-12-31    6566

# %% [markdown]
# ## Visualize

# %%
subset_df = (df
            .assign(date=lambda d: pd.to_datetime(d['date'], format="%Y-%m-%d"))
            [['state', 'date', 'births']]
            .loc[lambda d: d['state']=='CA']
            .tail(365*2))

# %%
subset_df.assign(rolling_births = lambda d: d.rolling(10, min_periods=1).mean()).head(15)
# Out:
#        state       date  births  rolling_births
# 335329    CA 1987-01-02    1230     1230.000000
# 335380    CA 1987-01-03    1178     1204.000000
# 335431    CA 1987-01-04    1087     1165.000000
# 335482    CA 1987-01-05    1300     1198.750000
# 335533    CA 1987-01-06    1415     1242.000000
# 335584    CA 1987-01-07    1318     1254.666667
# 335635    CA 1987-01-08    1310     1262.571429
# 335686    CA 1987-01-09    1430     1283.500000
# 335737    CA 1987-01-10    1131     1266.555556
# 335788    CA 1987-01-11    1123     1252.200000
# 335839    CA 1987-01-12    1371     1266.300000
# 335890    CA 1987-01-13    1401     1288.600000
# 335941    CA 1987-01-14    1393     1319.200000
# 335992    CA 1987-01-15    1314     1320.600000
# 336043    CA 1987-01-16    1396     1318.700000

# %%
import altair as alt

(alt.Chart(subset_df)
    .mark_line()
    .encode(x='date', y='births')
    .properties(width=600, height=250)
    .interactive())
# Out:
# alt.Chart(...)

# %%
plot_df = (subset_df
           .set_index('date')
           .assign(rolling_births = lambda d: d['births'].rolling('20D', min_periods=1).mean())
           .reset_index())

# %%
p1 = (alt.Chart(plot_df)
     .mark_line()
     .encode(x='date', y='births')
     .properties(width=600, height=250)
     .interactive())

p2 = (alt.Chart(plot_df)
     .mark_line(color='red')
     .encode(x='date', y='rolling_births')
     .properties(width=600, height=250)
     .interactive())

p1 + p2
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Rolling groupby for every state

# %%
subset_df = (df
            .assign(date=lambda d: pd.to_datetime(d['date'], format="%Y-%m-%d"))
            [['state', 'date', 'births']])

# %%
def calc_rolling_mean(dataf, column=None, setting='30D'):
    return (dataf
           .groupby('state')[column]
           .transform(lambda d: d.rolling(setting, min_periods=1).mean()))

(subset_df
     .set_index('date')
     .assign(rolling_births = lambda d: calc_rolling_mean(d, column='births'))
     .reset_index()
     .sort_values(['state', 'date']))
# Out:
#              date state  births  rolling_births
# 0      1969-01-01    AK      14       14.000000
# 51     1969-01-02    AK      20       17.000000
# 102    1969-01-03    AK      20       18.000000
# 153    1969-01-04    AK      16       17.500000
# 204    1969-01-05    AK      18       17.600000
# ...           ...   ...     ...             ...
# 372350 1988-12-27    WY      16       18.066667
# 372401 1988-12-28    WY      27       18.466667
# 372452 1988-12-29    WY      15       18.200000
# 372503 1988-12-30    WY      21       18.266667
# 372554 1988-12-31    WY      18       18.000000
#
# [372555 rows x 4 columns]

# %%
(subset_df
     .set_index('date')
     .assign(rolling_births = lambda d: calc_rolling_mean(d, column='births'))
     .reset_index()
     .sort_values(['state', 'date'])
     .loc[lambda d: d['state']=='CA'])
# Out:
#              date state  births  rolling_births
# 4      1969-01-01    CA     824      824.000000
# 55     1969-01-02    CA     816      820.000000
# 106    1969-01-03    CA     940      860.000000
# 157    1969-01-04    CA     906      871.500000
# 208    1969-01-05    CA     804      858.000000
# ...           ...   ...     ...             ...
# 372304 1988-12-27    CA    1586     1434.266667
# 372355 1988-12-28    CA    1551     1434.433333
# 372406 1988-12-29    CA    1638     1435.266667
# 372457 1988-12-30    CA    1562     1435.633333
# 372508 1988-12-31    CA    1283     1427.766667
#
# [7305 rows x 4 columns]
