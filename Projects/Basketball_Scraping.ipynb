# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# write function

def get_NBA_stats():
    year = input("Which NBA season?: ")
    player = input("Which player?: ")
    
    url = 'http://www.basketball-reference.com/leagues/NBA_{}_per_game.html'.format(year)
    r=requests.get(url)
    r_html = r.text
    soup = BeautifulSoup(r_html, 'html.parser')
    
    
    table = soup.find_all(class_='full_table')
    
    """Extrating List of column names"""
    head = soup.find(class_="thead")
    column_names_raw = [head.text for item in head][0]
    
    column_names_polished = column_names_raw.replace("\n",",").split(",")[2:-1]
    
    print(column_names_polished)
    
    """Extracting full list of player_data"""
    players=[]
    for i in range(len(table)):
        player_ =[]
        for td in table[i].find_all('td'):
            player_.append(td.text)
            
            players.append(player_)
    df = pd.DataFrame(players, columns=column_names_polished).set_index("Player")
    
    # clean the player's name
    df.index=df.index.str.replace('*','')
    
    print(df.loc[player])
    
if __name__ == '__main__':
    get_NBA_stats()
# Out:
# Which NBA season?: 2008
# Which player?: Kobe Bryant
# ['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
#             Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  ...   FT%  ORB  \
# Player                                                        ...
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
# Kobe Bryant  SG  29  LAL  82  82  38.9  9.5  20.6  .459  1.8  ...  .840  1.1
#
#              DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# Player
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
# Kobe Bryant  5.2  6.3  5.4  1.8  0.5  3.1  2.8  28.3
#
# [29 rows x 28 columns]
# <ipython-input-11-6f0c8a838618>:34: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.index=df.index.str.replace('*','')
