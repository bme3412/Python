# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_ATL = []

# ATL
while season <= 2021:
    df_ATL = get_roster('ATL', season)
    df_ATL['Season'] = season
    df_ATL['Team'] = 'ATL'
    appended_data_ATL.append(df_ATL)
    season = season + 1
appended_data_ATL = pd.concat(appended_data_ATL)

# %%
ATL_df_all = appended_data_ATL.copy()
ATL_df_all_csv = ATL_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_players_all.csv', index=False)
ATL_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_players_all.csv')
ATL_df_all_csv_io.head()
# Out:
#    NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      10      Drew Barry  PG    6-5     191  1973-02-17          US
# 1       3     Cal Bowdler  SF   6-10     245  1977-03-31          US
# 2      12     Bimbo Coles  PG    6-1     180  1968-04-22          US
# 3       4  Chris Crawford  PF    6-9     235  1975-05-13          US
# 4      20  LaPhonso Ellis  PF    6-8     240  1970-05-05          US
#
#   EXPERIENCE        COLLEGE  Season Team
# 0          2   Georgia Tech    2000  ATL
# 1          R   Old Dominion    2000  ATL
# 2          9  Virginia Tech    2000  ATL
# 3          2      Marquette    2000  ATL
# 4          7     Notre Dame    2000  ATL

# %%
ATL_df_2000 = ATL_df_all[ATL_df_all['Season'] == 2000]
ATL_df_2001 = ATL_df_all[ATL_df_all['Season'] == 2001]
ATL_df_2002 = ATL_df_all[ATL_df_all['Season'] == 2002]
ATL_df_2003 = ATL_df_all[ATL_df_all['Season'] == 2003]
ATL_df_2004 = ATL_df_all[ATL_df_all['Season'] == 2004]
ATL_df_2005 = ATL_df_all[ATL_df_all['Season'] == 2005]
ATL_df_2006 = ATL_df_all[ATL_df_all['Season'] == 2006]
ATL_df_2007 = ATL_df_all[ATL_df_all['Season'] == 2007]
ATL_df_2008 = ATL_df_all[ATL_df_all['Season'] == 2008]
ATL_df_2009 = ATL_df_all[ATL_df_all['Season'] == 2009]
ATL_df_2010 = ATL_df_all[ATL_df_all['Season'] == 2010]
ATL_df_2011 = ATL_df_all[ATL_df_all['Season'] == 2011]
ATL_df_2012 = ATL_df_all[ATL_df_all['Season'] == 2012]
ATL_df_2013 = ATL_df_all[ATL_df_all['Season'] == 2013]
ATL_df_2014 = ATL_df_all[ATL_df_all['Season'] == 2014]
ATL_df_2015 = ATL_df_all[ATL_df_all['Season'] == 2015]
ATL_df_2016 = ATL_df_all[ATL_df_all['Season'] == 2016]
ATL_df_2017 = ATL_df_all[ATL_df_all['Season'] == 2017]
ATL_df_2018 = ATL_df_all[ATL_df_all['Season'] == 2018]
ATL_df_2019 = ATL_df_all[ATL_df_all['Season'] == 2019]
ATL_df_2020 = ATL_df_all[ATL_df_all['Season'] == 2020]
ATL_df_2021 = ATL_df_all[ATL_df_all['Season'] == 2021]

# %%
ATL_df_2000_players = ATL_df_2000['PLAYER'].to_list()
ATL_df_2001_players = ATL_df_2001['PLAYER'].to_list()
ATL_df_2002_players = ATL_df_2002['PLAYER'].to_list()
ATL_df_2003_players = ATL_df_2003['PLAYER'].to_list()
ATL_df_2004_players = ATL_df_2004['PLAYER'].to_list()
ATL_df_2005_players = ATL_df_2005['PLAYER'].to_list()

ATL_df_2006_players = ATL_df_2006['PLAYER'].to_list()
ATL_df_2007_players = ATL_df_2007['PLAYER'].to_list()
ATL_df_2008_players = ATL_df_2008['PLAYER'].to_list()
ATL_df_2009_players = ATL_df_2009['PLAYER'].to_list()
ATL_df_2010_players = ATL_df_2010['PLAYER'].to_list()
ATL_df_2011_players = ATL_df_2011['PLAYER'].to_list()

ATL_df_2012_players = ATL_df_2012['PLAYER'].to_list()
ATL_df_2013_players = ATL_df_2013['PLAYER'].to_list()
ATL_df_2014_players = ATL_df_2014['PLAYER'].to_list()
ATL_df_2015_players = ATL_df_2015['PLAYER'].to_list()
ATL_df_2016_players = ATL_df_2016['PLAYER'].to_list()
ATL_df_2017_players = ATL_df_2017['PLAYER'].to_list()

ATL_df_2018_players = ATL_df_2018['PLAYER'].to_list()
ATL_df_2019_players = ATL_df_2019['PLAYER'].to_list()
ATL_df_2020_players = ATL_df_2020['PLAYER'].to_list()
ATL_df_2021_players = ATL_df_2021['PLAYER'].to_list()

# %%
## palyers to drop
#ATL_df_2004_players.remove("Mamadou N'Diaye")
#ATL_df_2016_players.remove("Tim Hardaway")
#ATL_df_2016_players.remove("Edy Tavares")
ATL_df_2017_players.remove("Edy Tavares")
#ATL_df_2017_players.remove("Mike Dunleavy")
#ATL_df_2021_players.remove("Clint Capela")

# %%
ATL_2000_gamelog = []



for p in ATL_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2000_gamelog.append(player_log)
ATL_2000_gamelog = pd.concat(ATL_2000_gamelog)    
ATL_2000_gamelogs = ATL_2000_gamelog.copy()
ATL_2000_gamelogs['GAME_SCORE'] = ATL_2000_gamelogs['GAME_SCORE'].astype(float)
ATL_2000_games = ATL_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2000_games_csv = ATL_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2000_games.csv', index=False)
ATL_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2000_games.csv')
ATL_2000_games_proc.head()
# Out:
# You searched for "Drew Barry"
# 5 results found.
# 0: Drew Barry
# 1: Brent Barry
# 2: Moe Barr
# 3: Jon Barry
# 4: Rick Barry
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-11f16e7c4683> in <module>
#       4
#       5 for p in ATL_df_2000_players:
# ----> 6     player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
#       7     player_log['Player'] = p
#       8
#
# ~/opt/anaconda3/lib/python3.8/site-packages/basketball_reference_scraper/players.py in get_game_logs(_name, start_date, end_date, playoffs, ask_matches)
#      40
#      41 def get_game_logs(_name, start_date, end_date, playoffs=False, ask_matches=True):
# ---> 42     name = lookup(_name, ask_matches)
#      43     suffix = get_player_suffix(name).replace('/', '%2F').replace('.html', '')
#      44     start_date_str = start_date
#
# ...

# %%
ATL_2001_gamelog = []



for p in ATL_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2001_gamelog.append(player_log)
ATL_2001_gamelog = pd.concat(ATL_2001_gamelog)    
ATL_2001_gamelogs = ATL_2001_gamelog.copy()
ATL_2001_gamelogs['GAME_SCORE'] = ATL_2001_gamelogs['GAME_SCORE'].astype(float)
ATL_2001_games = ATL_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2001_games_csv = ATL_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2001_games.csv', index=False)
ATL_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2001_games.csv')
ATL_2001_games_proc.head()
# Out:
# You searched for "Cal Bowdler"
# 2 results found.
# 0: Cal Bowdler
# 1: Al Butler
# Pick one: 0
# Results for Cal Bowdler:
#
# You searched for "Ira Bowman"
# 3 results found.
# 0: Ira Bowman
# 1: Ky Bowman
# 2: Nate Bowman
# Pick one: 0
# Results for Ira Bowman:
#
# You searched for "Sean Colson"
# 3 results found.
# 0: Sean Colson
# 1: Dean Tolson
# 2: Sean Rooks
# Pick one: 0
# Results for Sean Colson:
#
# You searched for "Chris Crawford"
# 2 results found.
# 0: Chris Crawford
# 1: Chris Ford
# Pick one: 0
# Results for Chris Crawford:
#
# You searched for "Dion Glover"
# 3 results found.
# 0: Dion Glover
# 1: Don Boven
# 2: Dean Oliver
# Pick one: 0
# Results for Dion Glover:
#
# You searched for "Alan Henderson"
# 9 results found.
# 0: Alan Henderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ryan Anderson
# 5: Dave Henderson
# 6: J.R. Henderson
# 7: Kevin Henderson
# 8: Tom Henderson
# Pick one: 0
# Results for Alan Henderson:
#
# ...

# %%
ATL_2002_gamelog = []



for p in ATL_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2002_gamelog.append(player_log)
ATL_2002_gamelog = pd.concat(ATL_2002_gamelog)    
ATL_2002_gamelogs = ATL_2002_gamelog.copy()
ATL_2002_gamelogs['GAME_SCORE'] = ATL_2002_gamelogs['GAME_SCORE'].astype(float)
ATL_2002_games = ATL_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2002_games_csv = ATL_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2002_games.csv', index=False)
ATL_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2002_games.csv')
ATL_2002_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Cal Bowdler"
# 2 results found.
# 0: Cal Bowdler
# 1: Al Butler
# Pick one: 0
# Results for Cal Bowdler:
#
# You searched for "Chris Crawford"
# 2 results found.
# 0: Chris Crawford
# 1: Chris Ford
# Pick one: 0
# Results for Chris Crawford:
#
# You searched for "Emanual Davis"
# 2 results found.
# 0: Emanual Davis
# 1: Paul Davis
# Pick one: 0
# Results for Emanual Davis:
#
# You searched for "Dion Glover"
# 3 results found.
# 0: Dion Glover
# 1: Don Boven
# 2: Dean Oliver
# Pick one: 0
# Results for Dion Glover:
#
# You searched for "Alan Henderson"
# 9 results found.
# 0: Alan Henderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ryan Anderson
# 5: Dave Henderson
# 6: J.R. Henderson
# 7: Kevin Henderson
# 8: Tom Henderson
# Pick one: 0
# Results for Alan Henderson:
#
# You searched for "DerMarr Johnson"
# 4 results found.
# ...

# %%
ATL_2003_gamelog = []



for p in ATL_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2003_gamelog.append(player_log)
ATL_2003_gamelog = pd.concat(ATL_2003_gamelog)    
ATL_2003_gamelogs = ATL_2003_gamelog.copy()
ATL_2003_gamelogs['GAME_SCORE'] = ATL_2003_gamelogs['GAME_SCORE'].astype(float)
ATL_2003_games = ATL_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2003_games_csv = ATL_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2003_games.csv', index=False)
ATL_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2003_games.csv')
ATL_2003_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Corey Benjamin"
# 1 result found.
# Corey Benjamin
# Results for Corey Benjamin:
#
# You searched for "Chris Crawford"
# 2 results found.
# 0: Chris Crawford
# 1: Chris Ford
# Pick one: 0
# Results for Chris Crawford:
#
# You searched for "Emanual Davis"
# 2 results found.
# 0: Emanual Davis
# 1: Paul Davis
# Pick one: 0
# Results for Emanual Davis:
#
# You searched for "Dan Dickau"
# 3 results found.
# 0: Dan Dickau
# 1: Dan Tieman
# 2: Dan Kraus
# Pick one: 0
# Results for Dan Dickau:
#
# You searched for "Dion Glover"
# 3 results found.
# 0: Dion Glover
# 1: Don Boven
# 2: Dean Oliver
# Pick one: 0
# Results for Dion Glover:
#
# You searched for "Darvin Ham"
# 1 result found.
# Darvin Ham
# Results for Darvin Ham:
#
# You searched for "Antonio Harvey"
# 2 results found.
# 0: Antonio Harvey
# 1: Antonio Davis
# Pick one: 0
# ...

# %%
# removed Mamadou N'Diaye

ATL_2004_gamelog = []



for p in ATL_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    player_log_ = player_log.drop(player_log[player_log['Player'] == "Mamadou N'Diaye"].index)
    ATL_2004_gamelog.append(player_log_)
ATL_2004_gamelog = pd.concat(ATL_2004_gamelog)    
ATL_2004_gamelogs = ATL_2004_gamelog.copy()
ATL_2004_gamelog
ATL_2004_gamelogs['GAME_SCORE'] = ATL_2004_gamelogs['GAME_SCORE'].astype(float)
ATL_2004_games = ATL_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2004_games_csv = ATL_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2004_games.csv', index=False)
ATL_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2004_games.csv')
ATL_2004_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Jason Collier"
# 3 results found.
# 0: Jason Collier
# 1: Jason Collins
# 2: Jarron Collins
# Pick one: 0
# Results for Jason Collier:
#
# You searched for "Chris Crawford"
# 2 results found.
# 0: Chris Crawford
# 1: Chris Ford
# Pick one: 0
# Results for Chris Crawford:
#
# You searched for "Josh Davis"
# 27 results found.
# 0: Josh Davis
# 1: Bob Davis
# 2: Jim Davis
# 3: Ron Davis
# 4: Josh Reaves
# 5: Josh Hall
# 6: Bob Davies
# 7: Ben Davis
# 8: Bill Davis
# 9: Brad Davis
# 10: Dale Davis
# 11: Ed Davis
# 12: Glen Davis
# 13: Johnny Davis
# 14: Lee Davis
# 15: Mark Davis
# 16: Mark Davis
# 17: Mel Davis
# ...

# %%
ATL_2005_gamelog = []

for p in ATL_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2005_gamelog.append(player_log)
ATL_2005_gamelog = pd.concat(ATL_2005_gamelog)    
ATL_2005_gamelogs = ATL_2005_gamelog.copy()
ATL_2005_gamelogs['GAME_SCORE'] = ATL_2005_gamelogs['GAME_SCORE'].astype(float)
ATL_2005_games = ATL_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2005_games_csv = ATL_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2005_games.csv', index=False)
ATL_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2005_games.csv')
ATL_2005_games_proc.head()
# Out:
# You searched for "Kenny Anderson"
# 10 results found.
# 0: Kenny Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Eric Anderson
# 6: Kim Anderson
# 7: Kyle Anderson
# 8: Ron Anderson
# 9: Ryan Anderson
# Pick one: 0
# Results for Kenny Anderson:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# ...

# %%
ATL_2006_gamelog = []

for p in ATL_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2006_gamelog.append(player_log)
ATL_2006_gamelog = pd.concat(ATL_2006_gamelog)    
ATL_2006_gamelogs = ATL_2006_gamelog.copy()
ATL_2006_gamelogs['GAME_SCORE'] = ATL_2006_gamelogs['GAME_SCORE'].astype(float)
ATL_2006_games = ATL_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2006_games_csv = ATL_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2006_games.csv', index=False)
ATL_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2006_games.csv')
ATL_2006_games_proc.head()
# Out:
# You searched for "Esteban Batista"
# 1 result found.
# Esteban Batista
# Results for Esteban Batista:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Tony Delk"
# 12 results found.
# 0: Tony Delk
# 1: Tony Snell
# 2: Tony Zeno
# 3: Tony Allen
# 4: Troy Bell
# 5: Don Dee
# 6: Tony Dumas
# 7: Tony Koski
# 8: Deng Adel
# 9: Sonny Dove
# 10: Tony Price
# 11: Tony White
# Pick one: 0
# Results for Tony Delk:
#
# You searched for "John Edwards"
# 10 results found.
# 0: John Edwards
# 1: Doug Edwards
# 2: Jay Edwards
# 3: Bill Edwards
# 4: Blue Edwards
# 5: James Edwards
# 6: Kevin Edwards
# 7: Shane Edwards
# 8: John Starks
# 9: John Warren
# Pick one: 0
# Results for John Edwards:
#
# You searched for "Anthony Grundy"
# 1 result found.
# Anthony Grundy
# Results for Anthony Grundy:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# 2: Bob Carrington
# 3: Al Hairston
# ...

# %%
ATL_2007_gamelog = []

for p in ATL_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2007_gamelog.append(player_log)
ATL_2007_gamelog = pd.concat(ATL_2007_gamelog)    
ATL_2007_gamelogs = ATL_2007_gamelog.copy()
ATL_2007_gamelogs['GAME_SCORE'] = ATL_2007_gamelogs['GAME_SCORE'].astype(float)
ATL_2007_games = ATL_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2007_games_csv = ATL_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2007_games.csv', index=False)
ATL_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2007_games.csv')
ATL_2007_games_proc.head()
# Out:
# You searched for "Esteban Batista"
# 1 result found.
# Esteban Batista
# Results for Esteban Batista:
#
# You searched for "Cedric Bozeman"
# 1 result found.
# Cedric Bozeman
# Results for Cedric Bozeman:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Matt Freije"
# 4 results found.
# 0: Matt Freije
# 1: Matt Fish
# 2: Matt Geiger
# 3: Matt Barnes
# Pick one: 0
# Results for Matt Freije:
#
# You searched for "Royal Ivey"
# 1 result found.
# Royal Ivey
# Results for Royal Ivey:
#
# You searched for "Anthony Johnson"
# 8 results found.
# 0: Anthony Johnson
# 1: Andy Johnson
# 2: Armon Johnson
# 3: Linton Johnson
# 4: Anthony Jones
# 5: Anthony Mason
# 6: Anthony Roberson
# 7: Anthony Bonner
# Pick one: 0
# Results for Anthony Johnson:
#
# You searched for "Joe Johnson"
# 40 results found.
# 0: Joe Johnson
# ...

# %%
ATL_2008_gamelog = []

for p in ATL_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2008_gamelog.append(player_log)
ATL_2008_gamelog = pd.concat(ATL_2008_gamelog)    
ATL_2008_gamelogs = ATL_2008_gamelog.copy()
ATL_2008_gamelogs['GAME_SCORE'] = ATL_2008_gamelogs['GAME_SCORE'].astype(float)
ATL_2008_games = ATL_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2008_games_csv = ATL_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2008_games.csv', index=False)
ATL_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2008_games.csv')
ATL_2008_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "Anthony Johnson"
# 8 results found.
# 0: Anthony Johnson
# 1: Andy Johnson
# 2: Armon Johnson
# 3: Linton Johnson
# 4: Anthony Jones
# 5: Anthony Mason
# 6: Anthony Roberson
# 7: Anthony Bonner
# Pick one: 0
# Results for Anthony Johnson:
#
# You searched for "Joe Johnson"
# 40 results found.
# 0: Joe Johnson
# 1: John Johnson
# ...

# %%
ATL_2009_gamelog = []

for p in ATL_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2009_gamelog.append(player_log)
ATL_2009_gamelog = pd.concat(ATL_2009_gamelog)    
ATL_2009_gamelogs = ATL_2009_gamelog.copy()
ATL_2009_gamelogs['GAME_SCORE'] = ATL_2009_gamelogs['GAME_SCORE'].astype(float)
ATL_2009_games = ATL_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2009_games_csv = ATL_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2009_games.csv', index=False)
ATL_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2009_games.csv')
ATL_2009_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# 4: Maurice Ager
# 5: Maurice Baker
# Pick one: 0
# Results for Maurice Evans:
#
# You searched for "Thomas Gardner"
# 1 result found.
# Thomas Gardner
# Results for Thomas Gardner:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "Othello Hunter"
# ...

# %%
ATL_2010_gamelog = []

for p in ATL_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2010_gamelog.append(player_log)
ATL_2010_gamelog = pd.concat(ATL_2010_gamelog)    
ATL_2010_gamelogs = ATL_2010_gamelog.copy()
ATL_2010_gamelogs['GAME_SCORE'] = ATL_2010_gamelogs['GAME_SCORE'].astype(float)
ATL_2010_games = ATL_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2010_games_csv = ATL_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2010_games.csv', index=False)
ATL_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2010_games.csv')
ATL_2010_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# Pick one: 0
# Results for Jason Collins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# 4: Maurice Ager
# ...

# %%
ATL_2011_gamelog = []

for p in ATL_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2011_gamelog.append(player_log)
ATL_2011_gamelog = pd.concat(ATL_2011_gamelog)    
ATL_2011_gamelogs = ATL_2011_gamelog.copy()
ATL_2011_gamelogs['GAME_SCORE'] = ATL_2011_gamelogs['GAME_SCORE'].astype(float)
ATL_2011_games = ATL_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2011_games_csv = ATL_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2011_games.csv', index=False)
ATL_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2011_games.csv')
ATL_2011_games_proc.head()
# Out:
# You searched for "Hilton Armstrong"
# 1 result found.
# Hilton Armstrong
# Results for Hilton Armstrong:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# Pick one: 0
# Results for Jason Collins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Jordan Crawford"
# ...

# %%
ATL_2012_gamelog = []

for p in ATL_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2012_gamelog.append(player_log)
ATL_2012_gamelog = pd.concat(ATL_2012_gamelog)    
ATL_2012_gamelogs = ATL_2012_gamelog.copy()
ATL_2012_gamelogs['GAME_SCORE'] = ATL_2012_gamelogs['GAME_SCORE'].astype(float)
ATL_2012_games = ATL_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2012_games_csv = ATL_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2012_games.csv', index=False)
ATL_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2012_games.csv')
ATL_2012_games_proc.head()
# Out:
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# Pick one: 0
# Results for Jason Collins:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# 9: Willie Porter
# 10: Willie Wise
# 11: Willie Long
# 12: Willie Rogers
# 13: Willie White
# Pick one: 0
# Results for Willie Green:
#
# You searched for "Kirk Hinrich"
# 1 result found.
# Kirk Hinrich
# Results for Kirk Hinrich:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# ...

# %%
ATL_2013_gamelog = []

for p in ATL_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2013_gamelog.append(player_log)
ATL_2013_gamelog = pd.concat(ATL_2013_gamelog)    
ATL_2013_gamelogs = ATL_2013_gamelog.copy()
ATL_2013_gamelogs['GAME_SCORE'] = ATL_2013_gamelogs['GAME_SCORE'].astype(float)
ATL_2013_games = ATL_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2013_games_csv = ATL_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2013_games.csv', index=False)
ATL_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2013_games.csv')
ATL_2013_games_proc.head()
# Out:
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# 6: David Harrison
# 7: Kevin Martin
# Pick one: 0
# Results for Devin Harris:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "John Jenkins"
# 5 results found.
# 0: John Jenkins
# 1: John Collins
# 2: John Henson
# 3: John Johnson
# 4: John Mahnken
# Pick one: 0
# Results for John Jenkins:
#
# You searched for "Ivan Johnson"
# 29 results found.
# 0: Ivan Johnson
# 1: Clay Johnson
# 2: Ervin Johnson
# 3: Frank Johnson
# 4: John Johnson
# 5: Ken Johnson
# 6: Ken Johnson
# 7: Kevin Johnson
# 8: Ron Johnson
# 9: Amir Johnson
# 10: Andy Johnson
# 11: Armon Johnson
# 12: Avery Johnson
# 13: B.J. Johnson
# 14: Buck Johnson
# 15: Dave Johnson
# 16: Ed Johnson
# 17: Eric Johnson
# ...

# %%
ATL_2014_gamelog = []

for p in ATL_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2014_gamelog.append(player_log)
ATL_2014_gamelog = pd.concat(ATL_2014_gamelog)    
ATL_2014_gamelogs = ATL_2014_gamelog.copy()
ATL_2014_gamelogs['GAME_SCORE'] = ATL_2014_gamelogs['GAME_SCORE'].astype(float)
ATL_2014_games = ATL_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2014_games_csv = ATL_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2014_games.csv', index=False)
ATL_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2014_games.csv')
ATL_2014_games_proc.head()
# Out:
# You searched for "Pero Antić"
# 1 result found.
# Pero Antic
# Results for Pero Antic:
#
# You searched for "Gustavo Ayón"
# 1 result found.
# Gustavo Ayon
# Results for Gustavo Ayon:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Jared Cunningham"
# 2 results found.
# 0: Jared Cunningham
# 1: Dante Cunningham
# Pick one: 0
# Results for Jared Cunningham:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "John Jenkins"
# 5 results found.
# 0: John Jenkins
# 1: John Collins
# 2: John Henson
# 3: John Johnson
# 4: John Mahnken
# Pick one: 0
# Results for John Jenkins:
#
# You searched for "Kyle Korver"
# 3 results found.
# 0: Kyle Korver
# 1: Kyle Weaver
# 2: Kyle Lowry
# ...

# %%
ATL_2015_gamelog = []

for p in ATL_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2015_gamelog.append(player_log)
ATL_2015_gamelog = pd.concat(ATL_2015_gamelog)    
ATL_2015_gamelogs = ATL_2015_gamelog.copy()
ATL_2015_gamelogs['GAME_SCORE'] = ATL_2015_gamelogs['GAME_SCORE'].astype(float)
ATL_2015_games = ATL_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2015_games_csv = ATL_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2015_games.csv', index=False)
ATL_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2015_games.csv')
ATL_2015_games_proc.head()
# Out:
# You searched for "Pero Antić"
# 1 result found.
# Pero Antic
# Results for Pero Antic:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "John Jenkins"
# 5 results found.
# 0: John Jenkins
# 1: John Collins
# 2: John Henson
# 3: John Johnson
# 4: John Mahnken
# Pick one: 0
# Results for John Jenkins:
#
# You searched for "Kyle Korver"
# 3 results found.
# 0: Kyle Korver
# 1: Kyle Weaver
# ...

# %%
# removed tim hardwaya
# removed edy tavares

ATL_2016_gamelog = []

for p in ATL_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2016_gamelog.append(player_log)
ATL_2016_gamelog = pd.concat(ATL_2016_gamelog)    
ATL_2016_gamelogs = ATL_2016_gamelog.copy()
ATL_2016_gamelogs['GAME_SCORE'] = ATL_2016_gamelogs['GAME_SCORE'].astype(float)
ATL_2016_games = ATL_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2016_games_csv = ATL_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2016_games.csv', index=False)
ATL_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2016_games.csv')
ATL_2016_games_proc.head()
# Out:
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Kirk Hinrich"
# 1 result found.
# Kirk Hinrich
# Results for Kirk Hinrich:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Al Horford"
# 5 results found.
# 0: Al Horford
# 1: Alton Ford
# 2: Tito Horford
# 3: Al Wood
# 4: Al Thornton
# Pick one: 0
# Results for Al Horford:
#
# You searched for "Kris Humphries"
# 2 results found.
# 0: Kris Humphries
# 1: Jay Humphries
# Pick one: 0
# Results for Kris Humphries:
#
# You searched for "Kyle Korver"
# 3 results found.
# 0: Kyle Korver
# 1: Kyle Weaver
# 2: Kyle Lowry
# Pick one: 0
# Results for Kyle Korver:
#
# You searched for "Shelvin Mack"
# 2 results found.
# 0: Shelvin Mack
# 1: Sheldon Mac
# Pick one: 0
# Results for Shelvin Mack:
#
# You searched for "Paul Millsap"
# 2 results found.
# 0: Paul Millsap
# 1: Paul Silas
# Pick one: 0
# ...

# %%
# removed mike dunleavy
# removed edy tavares
# selected Tim Hardaway, Jr = #1

ATL_2017_gamelog = []

for p in ATL_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2017_gamelog.append(player_log)
ATL_2017_gamelog = pd.concat(ATL_2017_gamelog)    
ATL_2017_gamelogs = ATL_2017_gamelog.copy()
ATL_2017_gamelogs['GAME_SCORE'] = ATL_2017_gamelogs['GAME_SCORE'].astype(float)
ATL_2017_games = ATL_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2017_games_csv = ATL_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2017_games.csv', index=False)
ATL_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2017_games.csv')
ATL_2017_games_proc.head()
# Out:
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Malcolm Delaney"
# 1 result found.
# Malcolm Delaney
# Results for Malcolm Delaney:
#
# You searched for "Tim Hardaway"
# 2 results found.
# 0: Tim Hardaway
# 1: Tim Hardaway Jr.
# Pick one: 1
# Results for Tim Hardaway Jr.:
#
# You searched for "Dwight Howard"
# 2 results found.
# 0: Dwight Howard
# 1: Dwight Powell
# Pick one: 0
# Results for Dwight Howard:
#
# You searched for "Kris Humphries"
# 2 results found.
# 0: Kris Humphries
# 1: Jay Humphries
# Pick one: 0
# Results for Kris Humphries:
#
# You searched for "Ersan İlyasova"
# 1 result found.
# Ersan Ilyasova
# Results for Ersan Ilyasova:
#
# You searched for "Ryan Kelly"
# 8 results found.
# 0: Ryan Kelly
# ...

# %%
ATL_2018_gamelog = []

for p in ATL_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2018_gamelog.append(player_log)
ATL_2018_gamelog = pd.concat(ATL_2018_gamelog)    
ATL_2018_gamelogs = ATL_2018_gamelog.copy()
ATL_2018_gamelogs['GAME_SCORE'] = ATL_2018_gamelogs['GAME_SCORE'].astype(float)
ATL_2018_games = ATL_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2018_games_csv = ATL_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2018_games.csv', index=False)
ATL_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2018_games.csv')
ATL_2018_games_proc.head()
# Out:
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "Nicolás Brussino"
# 1 result found.
# Nicolas Brussino
# Results for Nicolas Brussino:
#
# You searched for "Tyler Cavanaugh"
# 1 result found.
# Tyler Cavanaugh
# Results for Tyler Cavanaugh:
#
# You searched for "Antonius Cleveland"
# 1 result found.
# Antonius Cleveland
# Results for Antonius Cleveland:
#
# You searched for "John Collins"
# 17 results found.
# 0: John Collins
# 1: Don Collins
# 2: Doug Collins
# 3: Jason Collins
# 4: John Holland
# 5: Art Collins
# 6: James Collins
# 7: Jarron Collins
# 8: Jimmy Collins
# ...

# %%
ATL_2019_gamelog = []

for p in ATL_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2019_gamelog.append(player_log)
ATL_2019_gamelog = pd.concat(ATL_2019_gamelog)    
ATL_2019_gamelogs = ATL_2019_gamelog.copy()
ATL_2019_gamelogs['GAME_SCORE'] = ATL_2019_gamelogs['GAME_SCORE'].astype(float)
ATL_2019_games = ATL_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2019_games_csv = ATL_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2019_games.csv', index=False)
ATL_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2019_games.csv')
ATL_2019_games_proc.head()
# Out:
# You searched for "Jaylen Adams"
# 6 results found.
# 0: Jaylen Adams
# 1: Alvan Adams
# 2: Hassan Adams
# 3: Jordan Adams
# 4: Steven Adams
# 5: Jaylen Hoard
# Pick one: 0
# Results for Jaylen Adams:
#
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "John Collins"
# 17 results found.
# 0: John Collins
# 1: Don Collins
# 2: Doug Collins
# 3: Jason Collins
# 4: John Holland
# 5: Art Collins
# 6: James Collins
# 7: Jarron Collins
# 8: Jimmy Collins
# 9: Zach Collins
# 10: Ryan Hollins
# 11: John Jenkins
# ...

# %%
ATL_2020_gamelog = []

for p in ATL_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2020_gamelog.append(player_log)
ATL_2020_gamelog = pd.concat(ATL_2020_gamelog)    
ATL_2020_gamelogs = ATL_2020_gamelog.copy()
ATL_2020_gamelogs['GAME_SCORE'] = ATL_2020_gamelogs['GAME_SCORE'].astype(float)
ATL_2020_games = ATL_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2020_games_csv = ATL_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2020_games.csv', index=False)
ATL_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2020_games.csv')
ATL_2020_games_proc.head()
# Out:
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "Charlie Brown"
# 7 results found.
# 0: Charlie Brown
# 1: Charlie Bell
# 2: Charlie Black
# 3: Harold Brown
# 4: Charlie Criss
# 5: Charlie Scott
# 6: Charlie Ward
# Pick one: 0
# Results for Charlie Brown:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "John Collins"
# 17 results found.
# 0: John Collins
# 1: Don Collins
# 2: Doug Collins
# 3: Jason Collins
# 4: John Holland
# 5: Art Collins
# 6: James Collins
# 7: Jarron Collins
# 8: Jimmy Collins
# 9: Zach Collins
# 10: Ryan Hollins
# 11: John Jenkins
# 12: John Mills
# 13: John Olive
# 14: John Salmons
# 15: John Williams
# 16: John Tschogl
# Pick one: 0
# Results for John Collins:
#
# You searched for "Allen Crabbe"
# 1 result found.
# ...

# %%
# removed clint capela
ATL_2021_gamelog = []

for p in ATL_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    ATL_2021_gamelog.append(player_log)
ATL_2021_gamelog = pd.concat(ATL_2021_gamelog)    
ATL_2021_gamelogs = ATL_2021_gamelog.copy()
ATL_2021_gamelogs['GAME_SCORE'] = ATL_2021_gamelogs['GAME_SCORE'].astype(float)
ATL_2021_games = ATL_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_2021_games_csv = ATL_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2021_games.csv', index=False)
ATL_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2021_games.csv')
ATL_2021_games_proc.head()
# Out:
# You searched for "Bogdan Bogdanović"
# 2 results found.
# 0: Bogdan Bogdanovic
# 1: Bojan Bogdanovic
# Pick one: 0
# Results for Bogdan Bogdanovic:
#
# You searched for "John Collins"
# 17 results found.
# 0: John Collins
# 1: Don Collins
# 2: Doug Collins
# 3: Jason Collins
# 4: John Holland
# 5: Art Collins
# 6: James Collins
# 7: Jarron Collins
# 8: Jimmy Collins
# 9: Zach Collins
# 10: Ryan Hollins
# 11: John Jenkins
# 12: John Mills
# 13: John Olive
# 14: John Salmons
# 15: John Williams
# 16: John Tschogl
# Pick one: 0
# Results for John Collins:
#
# You searched for "Kris Dunn"
# 6 results found.
# 0: Kris Dunn
# 1: Chris Duhon
# 2: Pat Dunn
# 3: T.R. Dunn
# 4: Chris Munk
# 5: Chris Quinn
# Pick one: 0
# Results for Kris Dunn:
#
# You searched for "Bruno Fernando"
# 1 result found.
# Bruno Fernando
# Results for Bruno Fernando:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Brandon Goodwin"
# ...

# %% [markdown]
# ## combine all seasons

# %%
ATL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2000_games.csv')
ATL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2001_games.csv')
ATL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2002_games.csv')
ATL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2003_games.csv')
ATL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2004_games.csv')
ATL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2005_games.csv')
ATL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2006_games.csv')
ATL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2007_games.csv')
ATL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2008_games.csv')
ATL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2009_games.csv')
ATL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2010_games.csv')
ATL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2011_games.csv')
ATL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2012_games.csv')
ATL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2013_games.csv')
ATL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2014_games.csv')
ATL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2015_games.csv')
ATL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2016_games.csv')
ATL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2017_games.csv')
ATL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2018_games.csv')
ATL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2019_games.csv')
ATL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2020_games.csv')
ATL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2021_games.csv')

# %%
ATL_season_dfs = [ATL_2000_games_io, ATL_2001_games_io, ATL_2002_games_io, ATL_2003_games_io, ATL_2004_games_io, ATL_2005_games_io,
                 ATL_2006_games_io, ATL_2007_games_io, ATL_2008_games_io, ATL_2009_games_io, ATL_2010_games_io, ATL_2011_games_io,
                 ATL_2012_games_io, ATL_2013_games_io, ATL_2014_games_io, ATL_2015_games_io, ATL_2016_games_io, ATL_2017_games_io,
                 ATL_2018_games_io, ATL_2019_games_io, ATL_2020_games_io, ATL_2021_games_io]

# %%
ATL_all = pd.concat(ATL_season_dfs)
ATL_all_sorted = ATL_all.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2001-11-23  24-347  ATL      HOME      DET   W (+7)   1  45:12  21   30
# 0  2020-01-26  21-129  ATL      HOME      WAS  W (+19)   1  38:59  13   24
# 0  2019-03-01  20-163  ATL      HOME      CHI   L (-7)   1  55:50  17   33
# 0  2006-03-19  24-263  ATL      HOME      ORL   W (+1)   1  47:33  17   24
# 0  2004-03-12  25-342  ATL      HOME      WAS  W (+14)   1  45:26  14   24
# 1  2020-02-20  21-154  ATL      HOME      MIA   W (+5)   1  39:32  12   25
# 2  2020-01-20  21-123  ATL      HOME      TOR   L (-5)   1  39:01  11   20
# 0  1999-12-14  33-172  ATL      HOME      MIN  W (+11)   1  41:04  11   11
# 1  2006-02-24  24-240  ATL      AWAY      IND   W (+5)   1  47:21  16   24
# 3  2020-02-09  21-143  ATL      HOME      NYK   W (+5)   1  47:40  13   30
# 4  2020-02-22  22-152  ATL      HOME      DAL   W (+4)   1  37:04  13   18
# ...
