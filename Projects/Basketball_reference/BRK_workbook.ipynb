# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2013
appended_data_BRK = []

# BRK
while season <= 2021:
    df_BRK = get_roster('BRK', season)
    df_BRK['Season'] = season
    df_BRK['Team'] = 'BRK'
    appended_data_BRK.append(df_BRK)
    season = season + 1
appended_data_BRK = pd.concat(appended_data_BRK)

# %%
BRK_df_all = appended_data_BRK.copy()
BRK_df_all_csv = BRK_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_players_all.csv', index=False)
BRK_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_players_all.csv')
BRK_df_all_csv_io.head()
# Out:
#   NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      0  Andray Blatche   C   6-11     235  1986-08-22          US
# 1     10    Keith Bogans  SG    6-5     215  1980-05-12          US
# 2      9  MarShon Brooks  SG    6-5     200  1989-01-26          US
# 3      2  Josh Childress  SF    6-8     210  1983-06-20          US
# 4     30    Reggie Evans  PF    6-8     245  1980-05-18          US
#
#   EXPERIENCE     COLLEGE  Season Team
# 0          7         NaN    2013  BRK
# 1          9    Kentucky    2013  BRK
# 2          1  Providence    2013  BRK
# 3          6    Stanford    2013  BRK
# 4         10        Iowa    2013  BRK

# %%
BRK_df_2000 = BRK_df_all[BRK_df_all['Season'] == 2000]
BRK_df_2001 = BRK_df_all[BRK_df_all['Season'] == 2001]
BRK_df_2002 = BRK_df_all[BRK_df_all['Season'] == 2002]
BRK_df_2003 = BRK_df_all[BRK_df_all['Season'] == 2003]
BRK_df_2004 = BRK_df_all[BRK_df_all['Season'] == 2004]
BRK_df_2005 = BRK_df_all[BRK_df_all['Season'] == 2005]
BRK_df_2006 = BRK_df_all[BRK_df_all['Season'] == 2006]
BRK_df_2007 = BRK_df_all[BRK_df_all['Season'] == 2007]
BRK_df_2008 = BRK_df_all[BRK_df_all['Season'] == 2008]
BRK_df_2009 = BRK_df_all[BRK_df_all['Season'] == 2009]
BRK_df_2010 = BRK_df_all[BRK_df_all['Season'] == 2010]
BRK_df_2011 = BRK_df_all[BRK_df_all['Season'] == 2011]
BRK_df_2012 = BRK_df_all[BRK_df_all['Season'] == 2012]
BRK_df_2013 = BRK_df_all[BRK_df_all['Season'] == 2013]
BRK_df_2014 = BRK_df_all[BRK_df_all['Season'] == 2014]
BRK_df_2015 = BRK_df_all[BRK_df_all['Season'] == 2015]
BRK_df_2016 = BRK_df_all[BRK_df_all['Season'] == 2016]
BRK_df_2017 = BRK_df_all[BRK_df_all['Season'] == 2017]
BRK_df_2018 = BRK_df_all[BRK_df_all['Season'] == 2018]
BRK_df_2019 = BRK_df_all[BRK_df_all['Season'] == 2019]
BRK_df_2020 = BRK_df_all[BRK_df_all['Season'] == 2020]
BRK_df_2021 = BRK_df_all[BRK_df_all['Season'] == 2021]

# %%
BRK_df_2000_players = BRK_df_2000['PLAYER'].to_list()
BRK_df_2001_players = BRK_df_2001['PLAYER'].to_list()
BRK_df_2002_players = BRK_df_2002['PLAYER'].to_list()
BRK_df_2003_players = BRK_df_2003['PLAYER'].to_list()
BRK_df_2004_players = BRK_df_2004['PLAYER'].to_list()
BRK_df_2005_players = BRK_df_2005['PLAYER'].to_list()

BRK_df_2006_players = BRK_df_2006['PLAYER'].to_list()
BRK_df_2007_players = BRK_df_2007['PLAYER'].to_list()
BRK_df_2008_players = BRK_df_2008['PLAYER'].to_list()
BRK_df_2009_players = BRK_df_2009['PLAYER'].to_list()
BRK_df_2010_players = BRK_df_2010['PLAYER'].to_list()
BRK_df_2011_players = BRK_df_2011['PLAYER'].to_list()

BRK_df_2012_players = BRK_df_2012['PLAYER'].to_list()
BRK_df_2013_players = BRK_df_2013['PLAYER'].to_list()
BRK_df_2014_players = BRK_df_2014['PLAYER'].to_list()
BRK_df_2015_players = BRK_df_2015['PLAYER'].to_list()
BRK_df_2016_players = BRK_df_2016['PLAYER'].to_list()
BRK_df_2017_players = BRK_df_2017['PLAYER'].to_list()

BRK_df_2018_players = BRK_df_2018['PLAYER'].to_list()
BRK_df_2019_players = BRK_df_2019['PLAYER'].to_list()
BRK_df_2020_players = BRK_df_2020['PLAYER'].to_list()
BRK_df_2021_players = BRK_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## Players to drop

# %%
# 2018, 2019, 2021
# 2018 - D'Angelo Russell
#2019- D'Angelo Russell
# 2021 - Troy BRown

#BRK_df_2018_players.remove("D'Angelo Russell")
#BRK_df_2019_players.remove("D'Angelo Russell")
#BRK_df_2021_players.remove("Mike James")
BRK_df_2018_players.remove("James Webb")

# %%
# start with 2013 for BRK
BRK_2013_gamelog = []



for p in BRK_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2013_gamelog.append(player_log)
BRK_2013_gamelog = pd.concat(BRK_2013_gamelog)    
BRK_2013_gamelogs = BRK_2013_gamelog.copy()
BRK_2013_gamelogs['GAME_SCORE'] = BRK_2013_gamelogs['GAME_SCORE'].astype(float)
BRK_2013_games = BRK_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2013_games_csv = BRK_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv', index=False)
BRK_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv')
BRK_2013_games_proc.head()
# Out:
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "MarShon Brooks"
# 2 results found.
# 0: MarShon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for MarShon Brooks:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Kris Humphries"
# 2 results found.
# 0: Kris Humphries
# 1: Jay Humphries
# Pick one: 0
# Results for Kris Humphries:
#
# You searched for "Damion James"
# ...

# %%
BRK_2014_gamelog = []



for p in BRK_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2014_gamelog.append(player_log)
BRK_2014_gamelog = pd.concat(BRK_2014_gamelog)    
BRK_2014_gamelogs = BRK_2014_gamelog.copy()
BRK_2014_gamelogs['GAME_SCORE'] = BRK_2014_gamelogs['GAME_SCORE'].astype(float)
BRK_2014_games = BRK_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2014_games_csv = BRK_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv', index=False)
BRK_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv')
BRK_2014_games_proc.head()
# Out:
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# Pick one: 0
# Results for Jason Collins:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# ...

# %%
BRK_2015_gamelog = []



for p in BRK_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2015_gamelog.append(player_log)
BRK_2015_gamelog = pd.concat(BRK_2015_gamelog)    
BRK_2015_gamelogs = BRK_2015_gamelog.copy()
BRK_2015_gamelogs['GAME_SCORE'] = BRK_2015_gamelogs['GAME_SCORE'].astype(float)
BRK_2015_games = BRK_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2015_games_csv = BRK_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv', index=False)
BRK_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv')
BRK_2015_games_proc.head()
# Out:
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Markel Brown"
# 14 results found.
# 0: Markel Brown
# 1: Darrell Brown
# 2: Marcus Brown
# 3: Mike Brown
# 4: Fred Brown
# 5: Harold Brown
# 6: Jaylen Brown
# 7: Larry Brown
# 8: Moses Brown
# 9: Myron Brown
# 10: Rickey Brown
# 11: Mark Crow
# 12: Mark Blount
# 13: Mark Bryant
# Pick one: 0
# Results for Markel Brown:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# ...

# %%
BRK_2016_gamelog = []



for p in BRK_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2016_gamelog.append(player_log)
BRK_2016_gamelog = pd.concat(BRK_2016_gamelog)    
BRK_2016_gamelogs = BRK_2016_gamelog.copy()
BRK_2016_gamelogs['GAME_SCORE'] = BRK_2016_gamelogs['GAME_SCORE'].astype(float)
BRK_2016_games = BRK_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2016_games_csv = BRK_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv', index=False)
BRK_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv')
BRK_2016_games_proc.head()
# Out:
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Markel Brown"
# 14 results found.
# 0: Markel Brown
# 1: Darrell Brown
# 2: Marcus Brown
# 3: Mike Brown
# 4: Fred Brown
# 5: Harold Brown
# 6: Jaylen Brown
# 7: Larry Brown
# 8: Moses Brown
# 9: Myron Brown
# 10: Rickey Brown
# 11: Mark Crow
# 12: Mark Blount
# 13: Mark Bryant
# Pick one: 0
# Results for Markel Brown:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Rondae Hollis-Jefferson"
# 1 result found.
# Rondae Hollis-Jefferson
# Results for Rondae Hollis-Jefferson:
#
# You searched for "Jarrett Jack"
# 1 result found.
# Jarrett Jack
# Results for Jarrett Jack:
#
# You searched for "Joe Johnson"
# 40 results found.
# ...

# %%
BRK_2017_gamelog = []



for p in BRK_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2017_gamelog.append(player_log)
BRK_2017_gamelog = pd.concat(BRK_2017_gamelog)    
BRK_2017_gamelogs = BRK_2017_gamelog.copy()
BRK_2017_gamelogs['GAME_SCORE'] = BRK_2017_gamelogs['GAME_SCORE'].astype(float)
BRK_2017_games = BRK_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2017_games_csv = BRK_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv', index=False)
BRK_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv')
BRK_2017_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Anthony Bennett"
# 3 results found.
# 0: Anthony Bennett
# 1: Tony Bennett
# 2: Anthony Bonner
# Pick one: 0
# Results for Anthony Bennett:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Yogi Ferrell"
# 1 result found.
# Yogi Ferrell
# Results for Yogi Ferrell:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# ...

# %%
# "D'Angelo Russell"
BRK_2018_gamelog = []

for p in BRK_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2018_gamelog.append(player_log)
BRK_2018_gamelog = pd.concat(BRK_2018_gamelog)    
BRK_2018_gamelogs = BRK_2018_gamelog.copy()
BRK_2018_gamelogs['GAME_SCORE'] = BRK_2018_gamelogs['GAME_SCORE'].astype(float)
BRK_2018_games = BRK_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2018_games_csv = BRK_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv', index=False)
BRK_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv')
BRK_2018_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Milton Doyle"
# 1 result found.
# Milton Doyle
# Results for Milton Doyle:
# ...

# %%
# "D'Angelo Russell"
BRK_2019_gamelog = []

for p in BRK_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2019_gamelog.append(player_log)
BRK_2019_gamelog = pd.concat(BRK_2019_gamelog)    
BRK_2019_gamelogs = BRK_2019_gamelog.copy()
BRK_2019_gamelogs['GAME_SCORE'] = BRK_2019_gamelogs['GAME_SCORE'].astype(float)
BRK_2019_games = BRK_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2019_games_csv = BRK_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv', index=False)
BRK_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv')
BRK_2019_games_proc.head()
# Out:
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Mitch Creek"
# 3 results found.
# 0: Mitch Creek
# 1: Rich Peek
# 2: Mitch McGary
# Pick one: 0
# Results for Mitch Creek:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# 23: Tyler Davis
# 24: Walt Davis
# 25: Ed Earle
# 26: Ed Gayda
# 27: Ed Melvin
# 28: Ed Beach
# ...

# %%
BRK_2020_gamelog = []

for p in BRK_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2020_gamelog.append(player_log)
BRK_2020_gamelog = pd.concat(BRK_2020_gamelog)    
BRK_2020_gamelogs = BRK_2020_gamelog.copy()
BRK_2020_gamelogs['GAME_SCORE'] = BRK_2020_gamelogs['GAME_SCORE'].astype(float)
BRK_2020_games = BRK_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2020_games_csv = BRK_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv', index=False)
BRK_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv')
BRK_2020_games_proc.head()
# Out:
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Chris Chiozza"
# 2 results found.
# 0: Chris Chiozza
# 1: Chris Childs
# Pick one: 0
# Results for Chris Chiozza:
#
# You searched for "Nicolas Claxton"
# 1 result found.
# Nicolas Claxton
# Results for Nicolas Claxton:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# ...

# %%
# Mike James
BRK_2021_gamelog = []

for p in BRK_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2021_gamelog.append(player_log)
BRK_2021_gamelog = pd.concat(BRK_2021_gamelog)    
BRK_2021_gamelogs = BRK_2021_gamelog.copy()
BRK_2021_gamelogs['GAME_SCORE'] = BRK_2021_gamelogs['GAME_SCORE'].astype(float)
BRK_2021_games = BRK_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2021_games_csv = BRK_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv', index=False)
BRK_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv')
BRK_2021_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "Bruce Brown"
# 16 results found.
# 0: Bruce Brown
# 1: Bruce Bowen
# 2: Andre Brown
# 3: Bob Brown
# 4: Bobby Brown
# 5: Chucky Brown
# 6: Dee Brown
# 7: Dee Brown
# 8: Fred Brown
# 9: Kwame Brown
# 10: Mike Brown
# 11: Rickey Brown
# 12: Roger Brown
# 13: Roger Brown
# 14: Troy Brown
# 15: Bryce Drew
# Pick one: 0
# Results for Bruce Brown:
#
# You searched for "Chris Chiozza"
# 2 results found.
# 0: Chris Chiozza
# 1: Chris Childs
# Pick one: 0
# Results for Chris Chiozza:
#
# You searched for "Nicolas Claxton"
# 1 result found.
# Nicolas Claxton
# Results for Nicolas Claxton:
#
# You searched for "Tyler Cook"
# 8 results found.
# 0: Tyler Cook
# 1: Tyler Bey
# 2: Bert Cook
# 3: Omar Cook
# 4: Tyler Lydon
# ...

# %% [markdown]
# ## convrt to New Jersey NEts

# %%
BRK_2009_gamelog = []

for p in BRK_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2009_gamelog.append(player_log)
BRK_2009_gamelog = pd.concat(BRK_2009_gamelog)    
BRK_2009_gamelogs = BRK_2009_gamelog.copy()
BRK_2009_gamelogs['GAME_SCORE'] = BRK_2009_gamelogs['GAME_SCORE'].astype(float)
BRK_2009_games = BRK_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2009_games_csv = BRK_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2009_games.csv', index=False)
BRK_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2009_games.csv')
BRK_2009_games_proc.head()

# %%
BRK_2010_gamelog = []

for p in BRK_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2010_gamelog.append(player_log)
BRK_2010_gamelog = pd.concat(BRK_2010_gamelog)    
BRK_2010_gamelogs = BRK_2010_gamelog.copy()
BRK_2010_gamelogs['GAME_SCORE'] = BRK_2010_gamelogs['GAME_SCORE'].astype(float)
BRK_2010_games = BRK_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2010_games_csv = BRK_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2010_games.csv', index=False)
BRK_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2010_games.csv')
BRK_2010_games_proc.head()

# %%
BRK_2011_gamelog = []

for p in BRK_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2011_gamelog.append(player_log)
BRK_2011_gamelog = pd.concat(BRK_2011_gamelog)    
BRK_2011_gamelogs = BRK_2011_gamelog.copy()
BRK_2011_gamelogs['GAME_SCORE'] = BRK_2011_gamelogs['GAME_SCORE'].astype(float)
BRK_2011_games = BRK_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2011_games_csv = BRK_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2011_games.csv', index=False)
BRK_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2011_games.csv')
BRK_2011_games_proc.head()

# %%
BRK_2012_gamelog = []

for p in BRK_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2012_gamelog.append(player_log)
BRK_2012_gamelog = pd.concat(BRK_2012_gamelog)    
BRK_2012_gamelogs = BRK_2012_gamelog.copy()
BRK_2012_gamelogs['GAME_SCORE'] = BRK_2012_gamelogs['GAME_SCORE'].astype(float)
BRK_2012_games = BRK_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2012_games_csv = BRK_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2012_games.csv', index=False)
BRK_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2012_games.csv')
BRK_2012_games_proc.head()

# %%
BRK_2013_gamelog = []

for p in BRK_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2013_gamelog.append(player_log)
BRK_2013_gamelog = pd.concat(BRK_2013_gamelog)    
BRK_2013_gamelogs = BRK_2013_gamelog.copy()
BRK_2013_gamelogs['GAME_SCORE'] = BRK_2013_gamelogs['GAME_SCORE'].astype(float)
BRK_2013_games = BRK_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2013_games_csv = BRK_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv', index=False)
BRK_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv')
BRK_2013_games_proc.head()

# %%
BRK_2014_gamelog = []

for p in BRK_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2014_gamelog.append(player_log)
BRK_2014_gamelog = pd.concat(BRK_2014_gamelog)    
BRK_2014_gamelogs = BRK_2014_gamelog.copy()
BRK_2014_gamelogs['GAME_SCORE'] = BRK_2014_gamelogs['GAME_SCORE'].astype(float)
BRK_2014_games = BRK_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2014_games_csv = BRK_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv', index=False)
BRK_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv')
BRK_2014_games_proc.head()

# %%
BRK_2015_gamelog = []

for p in BRK_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2015_gamelog.append(player_log)
BRK_2015_gamelog = pd.concat(BRK_2015_gamelog)    
BRK_2015_gamelogs = BRK_2015_gamelog.copy()
BRK_2015_gamelogs['GAME_SCORE'] = BRK_2015_gamelogs['GAME_SCORE'].astype(float)
BRK_2015_games = BRK_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2015_games_csv = BRK_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv', index=False)
BRK_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv')
BRK_2015_games_proc.head()

# %%
BRK_2016_gamelog = []

for p in BRK_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2016_gamelog.append(player_log)
BRK_2016_gamelog = pd.concat(BRK_2016_gamelog)    
BRK_2016_gamelogs = BRK_2016_gamelog.copy()
BRK_2016_gamelogs['GAME_SCORE'] = BRK_2016_gamelogs['GAME_SCORE'].astype(float)
BRK_2016_games = BRK_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2016_games_csv = BRK_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv', index=False)
BRK_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv')
BRK_2016_games_proc.head()

# %%
BRK_2017_gamelog = []

for p in BRK_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2017_gamelog.append(player_log)
BRK_2017_gamelog = pd.concat(BRK_2017_gamelog)    
BRK_2017_gamelogs = BRK_2017_gamelog.copy()
BRK_2017_gamelogs['GAME_SCORE'] = BRK_2017_gamelogs['GAME_SCORE'].astype(float)
BRK_2017_games = BRK_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2017_games_csv = BRK_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv', index=False)
BRK_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv')
BRK_2017_games_proc.head()

# %%
# removed d'angelo russell
# removed james webb
BRK_2018_gamelog = []

for p in BRK_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2018_gamelog.append(player_log)
BRK_2018_gamelog = pd.concat(BRK_2018_gamelog)    
BRK_2018_gamelogs = BRK_2018_gamelog.copy()
BRK_2018_gamelogs['GAME_SCORE'] = BRK_2018_gamelogs['GAME_SCORE'].astype(float)
BRK_2018_games = BRK_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2018_games_csv = BRK_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv', index=False)
BRK_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv')
BRK_2018_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Milton Doyle"
# 1 result found.
# Milton Doyle
# Results for Milton Doyle:
# ...

# %%
BRK_2019_gamelog = []

for p in BRK_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2019_gamelog.append(player_log)
BRK_2019_gamelog = pd.concat(BRK_2019_gamelog)    
BRK_2019_gamelogs = BRK_2019_gamelog.copy()
BRK_2019_gamelogs['GAME_SCORE'] = BRK_2019_gamelogs['GAME_SCORE'].astype(float)
BRK_2019_games = BRK_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2019_games_csv = BRK_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv', index=False)
BRK_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv')
BRK_2019_games_proc.head()
# Out:
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Mitch Creek"
# 3 results found.
# 0: Mitch Creek
# 1: Rich Peek
# 2: Mitch McGary
# Pick one: 0
# Results for Mitch Creek:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# 23: Tyler Davis
# 24: Walt Davis
# 25: Ed Earle
# 26: Ed Gayda
# 27: Ed Melvin
# 28: Ed Beach
# ...

# %%
BRK_2020_gamelog = []

for p in BRK_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2020_gamelog.append(player_log)
BRK_2020_gamelog = pd.concat(BRK_2020_gamelog)    
BRK_2020_gamelogs = BRK_2020_gamelog.copy()
BRK_2020_gamelogs['GAME_SCORE'] = BRK_2020_gamelogs['GAME_SCORE'].astype(float)
BRK_2020_games = BRK_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2020_games_csv = BRK_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv', index=False)
BRK_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv')
BRK_2020_games_proc.head()

# %%
# removed Mike James
BRK_2021_gamelog = []

for p in BRK_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    BRK_2021_gamelog.append(player_log)
BRK_2021_gamelog = pd.concat(BRK_2021_gamelog)    
BRK_2021_gamelogs = BRK_2021_gamelog.copy()
BRK_2021_gamelogs['GAME_SCORE'] = BRK_2021_gamelogs['GAME_SCORE'].astype(float)
BRK_2021_games = BRK_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_2021_games_csv = BRK_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv', index=False)
BRK_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv')
BRK_2021_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Jarrett Allen"
# 2 results found.
# 0: Jarrett Allen
# 1: Jarrett Culver
# Pick one: 0
# Results for Jarrett Allen:
#
# You searched for "Bruce Brown"
# 16 results found.
# 0: Bruce Brown
# 1: Bruce Bowen
# 2: Andre Brown
# 3: Bob Brown
# 4: Bobby Brown
# 5: Chucky Brown
# 6: Dee Brown
# 7: Dee Brown
# 8: Fred Brown
# 9: Kwame Brown
# 10: Mike Brown
# 11: Rickey Brown
# 12: Roger Brown
# 13: Roger Brown
# 14: Troy Brown
# 15: Bryce Drew
# Pick one: 0
# Results for Bruce Brown:
#
# You searched for "Chris Chiozza"
# 2 results found.
# 0: Chris Chiozza
# 1: Chris Childs
# Pick one: 0
# Results for Chris Chiozza:
#
# You searched for "Nicolas Claxton"
# 1 result found.
# Nicolas Claxton
# Results for Nicolas Claxton:
#
# You searched for "Tyler Cook"
# 8 results found.
# 0: Tyler Cook
# 1: Tyler Bey
# 2: Bert Cook
# 3: Omar Cook
# 4: Tyler Lydon
# ...

# %% [markdown]
# ## combine all seasons

# %%
BRK_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv')
BRK_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv')
BRK_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv')
BRK_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv')
BRK_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv')
BRK_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv')
BRK_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv')
BRK_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv')
BRK_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv')

# %%
BRK_season_dfs = [BRK_2013_games_io, BRK_2014_games_io, BRK_2015_games_io, BRK_2016_games_io, BRK_2017_games_io,
                 BRK_2018_games_io, BRK_2019_games_io, BRK_2020_games_io, BRK_2021_games_io]

# %%
BRK_all = pd.concat(BRK_season_dfs)
BRK_all_sorted = BRK_all.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_all_sorted.head(25)
# Out:
#           DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0   2020-01-31  27-314  BRK      HOME      CHI  W (+15)   1  31:53  19   23
# 0   2020-12-26  31-122  HOU      AWAY      POR   L (-2)   1  43:16  12   21
# 1   2020-03-03  25-191  BRK      AWAY      BOS   W (+9)   1  35:49  17   26
# 2   2019-10-23  27-214  BRK      HOME      MIN   L (-1)   1  38:10  17   33
# 0   2018-04-09  26-000  BRK      HOME      CHI   W (+9)   1  33:42  12   15
# 1   2021-03-17  31-203  BRK      AWAY      IND   W (+9)   1  42:07  13   27
# 2   2021-04-29  32-212  BRK      AWAY      IND  W (+17)   1  36:21  16   24
# 3   2021-05-06  29-044  BRK      AWAY      DAL   L (-4)   1  38:51  17   31
# 4   2021-02-16  31-174  BRK      AWAY      PHO   W (+4)   1  36:49  14   22
# 5   2021-03-01  31-187  BRK      AWAY      SAS  W (+11)   1  44:02  12   23
# 6   2021-01-20  32-113  BRK      AWAY      CLE  L (-12)   1  50:09  12   25
# ...
