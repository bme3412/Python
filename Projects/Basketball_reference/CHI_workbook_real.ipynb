# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_CHI = []

# CHI
while season <= 2021:
    df_CHI = get_roster('CHI', season)
    df_CHI['Season'] = season
    df_CHI['Team'] = 'CHI'
    appended_data_CHI.append(df_CHI)
    season = season + 1
appended_data_CHI = pd.concat(appended_data_CHI)

# %%
CHI_df_all = appended_data_CHI.copy()
CHI_df_all_csv = CHI_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_players_all.csv', index=False)
CHI_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_players_all.csv')
CHI_df_all_csv_io.head()
# Out:
#   NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     22    Chris Anstey   C    7-0     249  1975-01-01          AU
# 1     11  B.J. Armstrong  PG    6-2     175  1967-09-09          US
# 2     25  Corey Benjamin  SG    6-6     200  1978-02-24          US
# 3     42     Elton Brand  PF    6-8     275  1979-03-11          US
# 4      1     Randy Brown  PG    6-2     190  1968-05-22          US
#
#   EXPERIENCE                    COLLEGE  Season Team
# 0          2                        NaN    2000  CHI
# 1         10                       Iowa    2000  CHI
# 2          1               Oregon State    2000  CHI
# 3          R                       Duke    2000  CHI
# 4          8  Houston, New Mexico State    2000  CHI

# %%
CHI_df_2000 = CHI_df_all[CHI_df_all['Season'] == 2000]
CHI_df_2001 = CHI_df_all[CHI_df_all['Season'] == 2001]
CHI_df_2002 = CHI_df_all[CHI_df_all['Season'] == 2002]
CHI_df_2003 = CHI_df_all[CHI_df_all['Season'] == 2003]
CHI_df_2004 = CHI_df_all[CHI_df_all['Season'] == 2004]
CHI_df_2005 = CHI_df_all[CHI_df_all['Season'] == 2005]
CHI_df_2006 = CHI_df_all[CHI_df_all['Season'] == 2006]
CHI_df_2007 = CHI_df_all[CHI_df_all['Season'] == 2007]
CHI_df_2008 = CHI_df_all[CHI_df_all['Season'] == 2008]
CHI_df_2009 = CHI_df_all[CHI_df_all['Season'] == 2009]
CHI_df_2010 = CHI_df_all[CHI_df_all['Season'] == 2010]
CHI_df_2011 = CHI_df_all[CHI_df_all['Season'] == 2011]
CHI_df_2012 = CHI_df_all[CHI_df_all['Season'] == 2012]
CHI_df_2013 = CHI_df_all[CHI_df_all['Season'] == 2013]
CHI_df_2014 = CHI_df_all[CHI_df_all['Season'] == 2014]
CHI_df_2015 = CHI_df_all[CHI_df_all['Season'] == 2015]
CHI_df_2016 = CHI_df_all[CHI_df_all['Season'] == 2016]
CHI_df_2017 = CHI_df_all[CHI_df_all['Season'] == 2017]
CHI_df_2018 = CHI_df_all[CHI_df_all['Season'] == 2018]
CHI_df_2019 = CHI_df_all[CHI_df_all['Season'] == 2019]
CHI_df_2020 = CHI_df_all[CHI_df_all['Season'] == 2020]
CHI_df_2021 = CHI_df_all[CHI_df_all['Season'] == 2021]

# %%
CHI_df_2000_players = CHI_df_2000['PLAYER'].to_list()
CHI_df_2001_players = CHI_df_2001['PLAYER'].to_list()
CHI_df_2002_players = CHI_df_2002['PLAYER'].to_list()
CHI_df_2003_players = CHI_df_2003['PLAYER'].to_list()
CHI_df_2004_players = CHI_df_2004['PLAYER'].to_list()
CHI_df_2005_players = CHI_df_2005['PLAYER'].to_list()

CHI_df_2006_players = CHI_df_2006['PLAYER'].to_list()
CHI_df_2007_players = CHI_df_2007['PLAYER'].to_list()
CHI_df_2008_players = CHI_df_2008['PLAYER'].to_list()
CHI_df_2009_players = CHI_df_2009['PLAYER'].to_list()
CHI_df_2010_players = CHI_df_2010['PLAYER'].to_list()
CHI_df_2011_players = CHI_df_2011['PLAYER'].to_list()

CHI_df_2012_players = CHI_df_2012['PLAYER'].to_list()
CHI_df_2013_players = CHI_df_2013['PLAYER'].to_list()
CHI_df_2014_players = CHI_df_2014['PLAYER'].to_list()
CHI_df_2015_players = CHI_df_2015['PLAYER'].to_list()
CHI_df_2016_players = CHI_df_2016['PLAYER'].to_list()
CHI_df_2017_players = CHI_df_2017['PLAYER'].to_list()

CHI_df_2018_players = CHI_df_2018['PLAYER'].to_list()
CHI_df_2019_players = CHI_df_2019['PLAYER'].to_list()
CHI_df_2020_players = CHI_df_2020['PLAYER'].to_list()
CHI_df_2021_players = CHI_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## Players to drop

# %%
# 2000 Metta World Peace
# 20021 - Khalid El-Amin
#2002 - Metta World Peace
# 2014, 2015, 2016 - Mike Dunleavy
# 2019 Wendell Carter
# 2020 Wendell Carter
# 2021 Troy BRown

#CHI_df_2000_players.remove("Metta World Peace")
#CHI_df_2001_players.remove("Khalid El-Amin")
#CHI_df_2001_players.remove("Metta World Peace")
#CHI_df_2002_players.remove("Metta World Peace")
#CHI_df_2014_players.remove("Mike Dunleavy")
#CHI_df_2015_players.remove("Mike Dunleavy")
#CHI_df_2016_players.remove("Mike Dunleavy")
#CHI_df_2019_players.remove("Wendell Carter")
#CHI_df_2020_players.remove("Wendell Carter")
#CHI_df_2021_players.remove("Troy Brown")
#CHI_df_2015_players.remove("E'Twaun Moore")
#CHI_df_2016_players.remove("E'Twaun Moore")
#CHI_df_2019_players.remove("Walt Lemon")
CHI_df_2021_players.remove("Wendell Carter")

# %%
# removed MEtta World Peace

CHI_2000_gamelog = []



for p in CHI_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2000_gamelog.append(player_log)
CHI_2000_gamelog = pd.concat(CHI_2000_gamelog)    
CHI_2000_gamelogs = CHI_2000_gamelog.copy()
CHI_2000_gamelogs['GAME_SCORE'] = CHI_2000_gamelogs['GAME_SCORE'].astype(float)
CHI_2000_games = CHI_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2000_games_csv = CHI_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2000_games.csv', index=False)
CHI_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2000_games.csv')
CHI_2000_games_proc.head()
# Out:
# You searched for "Chris Anstey"
# 8 results found.
# 0: Chris Anstey
# 1: Chris Dudley
# 2: Chris Engler
# 3: Chris Hunter
# 4: Chris Porter
# 5: Chris Whitney
# 6: Chris Garner
# 7: Chris Harris
# Pick one: 0
# Results for Chris Anstey:
#
# You searched for "B.J. Armstrong"
# 3 results found.
# 0: B.J. Armstrong
# 1: Bob Armstrong
# 2: Tate Armstrong
# Pick one: 0
# Results for B.J. Armstrong:
#
# You searched for "Corey Benjamin"
# 1 result found.
# Corey Benjamin
# Results for Corey Benjamin:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Randy Brown"
# 18 results found.
# 0: Randy Brown
# 1: Andre Brown
# 2: Larry Brown
# 3: Tony Brown
# 4: Randy Allen
# 5: Randy Breuer
# 6: Bobby Brown
# 7: Fred Brown
# 8: Gerald Brown
# 9: Raymond Brown
# 10: Rickey Brown
# 11: Roger Brown
# 12: Roger Brown
# 13: Stan Brown
# 14: Troy Brown
# 15: Randy Foye
# 16: Randy Stoll
# 17: Randy Woods
# Pick one: 0
# ...

# %%
# removed Khalid el amin
# removed metta world pead

CHI_2001_gamelog = []



for p in CHI_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2001_gamelog.append(player_log)
CHI_2001_gamelog = pd.concat(CHI_2001_gamelog)    
CHI_2001_gamelogs = CHI_2001_gamelog.copy()
CHI_2001_gamelogs['GAME_SCORE'] = CHI_2001_gamelogs['GAME_SCORE'].astype(float)
CHI_2001_games = CHI_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2001_games_csv = CHI_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2001_games.csv', index=False)
CHI_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2001_games.csv')
CHI_2001_games_proc.head()
# Out:
# You searched for "Dalibor Bagarić"
# 1 result found.
# Dalibor Bagaric
# Results for Dalibor Bagaric:
#
# You searched for "Corey Benjamin"
# 1 result found.
# Corey Benjamin
# Results for Corey Benjamin:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Bryce Drew"
# 3 results found.
# 0: Bryce Drew
# 1: Bruce Brown
# 2: Bruce Hale
# Pick one: 0
# Results for Bryce Drew:
#
# You searched for "Marcus Fizer"
# 4 results found.
# 0: Marcus Fizer
# 1: Marcus Liberty
# 2: Marcus Paige
# 3: Marcus Webb
# Pick one: 0
# Results for Marcus Fizer:
#
# You searched for "Steve Goodrich"
# 1 result found.
# Steve Goodrich
# Results for Steve Goodrich:
#
# You searched for "A.J. Guyton"
# 1 result found.
# A.J. Guyton
# Results for A.J. Guyton:
#
# ...

# %%
# removed Metta World Peace
CHI_2002_gamelog = []



for p in CHI_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2002_gamelog.append(player_log)
CHI_2002_gamelog = pd.concat(CHI_2002_gamelog)    
CHI_2002_gamelogs = CHI_2002_gamelog.copy()
CHI_2002_gamelogs['GAME_SCORE'] = CHI_2002_gamelogs['GAME_SCORE'].astype(float)
CHI_2002_games = CHI_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2002_games_csv = CHI_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2002_games.csv', index=False)
CHI_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2002_games.csv')
CHI_2002_games_proc.head()
# Out:
# You searched for "Greg Anthony"
# 6 results found.
# 0: Greg Anthony
# 1: Joel Anthony
# 2: Cole Anthony
# 3: Greg Sutton
# 4: Greg Anderson
# 5: Greg Jackson
# Pick one: 0
# Results for Greg Anthony:
#
# You searched for "Dalibor Bagarić"
# 1 result found.
# Dalibor Bagaric
# Results for Dalibor Bagaric:
#
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# ...

# %%
CHI_2003_gamelog = []



for p in CHI_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2003_gamelog.append(player_log)
CHI_2003_gamelog = pd.concat(CHI_2003_gamelog)    
CHI_2003_gamelogs = CHI_2003_gamelog.copy()
CHI_2003_gamelogs['GAME_SCORE'] = CHI_2003_gamelogs['GAME_SCORE'].astype(float)
CHI_2003_games = CHI_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2003_games_csv = CHI_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2003_games.csv', index=False)
CHI_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2003_games.csv')
CHI_2003_games_proc.head()
# Out:
# You searched for "Dalibor Bagarić"
# 1 result found.
# Dalibor Bagaric
# Results for Dalibor Bagaric:
#
# You searched for "Lonny Baxter"
# 3 results found.
# 0: Lonny Baxter
# 1: Sonny Parker
# 2: Kenny Battle
# Pick one: 0
# Results for Lonny Baxter:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# ...

# %%
CHI_2004_gamelog = []



for p in CHI_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2004_gamelog.append(player_log)
CHI_2004_gamelog = pd.concat(CHI_2004_gamelog)    
CHI_2004_gamelogs = CHI_2004_gamelog.copy()
CHI_2004_gamelogs['GAME_SCORE'] = CHI_2004_gamelogs['GAME_SCORE'].astype(float)
CHI_2004_games = CHI_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2004_games_csv = CHI_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2004_games.csv', index=False)
CHI_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2004_games.csv')
CHI_2004_games_proc.head()
# Out:
# You searched for "Lonny Baxter"
# 3 results found.
# 0: Lonny Baxter
# 1: Sonny Parker
# 2: Kenny Battle
# Pick one: 0
# Results for Lonny Baxter:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# ...

# %%
CHI_2005_gamelog = []

for p in CHI_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2005_gamelog.append(player_log)
CHI_2005_gamelog = pd.concat(CHI_2005_gamelog)    
CHI_2005_gamelogs = CHI_2005_gamelog.copy()
CHI_2005_gamelogs['GAME_SCORE'] = CHI_2005_gamelogs['GAME_SCORE'].astype(float)
CHI_2005_games = CHI_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2005_games_csv = CHI_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2005_games.csv', index=False)
CHI_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2005_games.csv')
CHI_2005_games_proc.head()
# Out:
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Antonio Davis"
# 6 results found.
# 0: Antonio Davis
# 1: Antonio Daniels
# 2: Anthony Davis
# 3: Antonio Burks
# 4: Antonio Harvey
# 5: Antonio Lang
# Pick one: 0
# Results for Antonio Davis:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# 3: Kris Dunn
# 4: Chris Johnson
# 5: Chris Johnson
# 6: Chris Kaman
# 7: Chris Mihm
# 8: Chris Mullin
# 9: Chris Munk
# 10: Chris Bosh
# 11: Chris Ford
# 12: Chris Jent
# 13: Chris King
# 14: Chris Smith
# 15: Chris Smith
# Pick one: 0
# Results for Chris Duhon:
#
# ...

# %%
CHI_2006_gamelog = []

for p in CHI_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2006_gamelog.append(player_log)
CHI_2006_gamelog = pd.concat(CHI_2006_gamelog)    
CHI_2006_gamelogs = CHI_2006_gamelog.copy()
CHI_2006_gamelogs['GAME_SCORE'] = CHI_2006_gamelogs['GAME_SCORE'].astype(float)
CHI_2006_games = CHI_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2006_games_csv = CHI_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2006_games.csv', index=False)
CHI_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2006_games.csv')
CHI_2006_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Eddie Basden"
# 5 results found.
# 0: Eddie Basden
# 1: Eddie Jordan
# 2: Eddie Mast
# 3: Eddie Owens
# 4: Freddie Boyd
# Pick one: 0
# Results for Eddie Basden:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# 3: Kris Dunn
# 4: Chris Johnson
# 5: Chris Johnson
# 6: Chris Kaman
# 7: Chris Mihm
# 8: Chris Mullin
# 9: Chris Munk
# 10: Chris Bosh
# 11: Chris Ford
# 12: Chris Jent
# 13: Chris King
# ...

# %%
CHI_2007_gamelog = []

for p in CHI_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2007_gamelog.append(player_log)
CHI_2007_gamelog = pd.concat(CHI_2007_gamelog)    
CHI_2007_gamelogs = CHI_2007_gamelog.copy()
CHI_2007_gamelogs['GAME_SCORE'] = CHI_2007_gamelogs['GAME_SCORE'].astype(float)
CHI_2007_games = CHI_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2007_games_csv = CHI_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2007_games.csv', index=False)
CHI_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2007_games.csv')
CHI_2007_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "P.J. Brown"
# 12 results found.
# 0: P.J. Brown
# 1: Bob Brown
# 2: Dee Brown
# 3: Dee Brown
# 4: Fred Brown
# 5: John Brown
# 6: Leon Brown
# 7: Mike Brown
# 8: Stan Brown
# 9: Tony Brown
# 10: Troy Brown
# 11: J.J. Barea
# Pick one: 0
# Results for P.J. Brown:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# 3: Kris Dunn
# 4: Chris Johnson
# 5: Chris Johnson
# ...

# %%
CHI_2008_gamelog = []

for p in CHI_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2008_gamelog.append(player_log)
CHI_2008_gamelog = pd.concat(CHI_2008_gamelog)    
CHI_2008_gamelogs = CHI_2008_gamelog.copy()
CHI_2008_gamelogs['GAME_SCORE'] = CHI_2008_gamelogs['GAME_SCORE'].astype(float)
CHI_2008_games = CHI_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2008_games_csv = CHI_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2008_games.csv', index=False)
CHI_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2008_games.csv')
CHI_2008_games_proc.head()
# Out:
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# 3: Kris Dunn
# 4: Chris Johnson
# 5: Chris Johnson
# 6: Chris Kaman
# 7: Chris Mihm
# 8: Chris Mullin
# 9: Chris Munk
# 10: Chris Bosh
# 11: Chris Ford
# 12: Chris Jent
# 13: Chris King
# 14: Chris Smith
# 15: Chris Smith
# Pick one: 0
# Results for Chris Duhon:
#
# You searched for "Thomas Gardner"
# 1 result found.
# Thomas Gardner
# Results for Thomas Gardner:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# ...

# %%
CHI_2009_gamelog = []

for p in CHI_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2009_gamelog.append(player_log)
CHI_2009_gamelog = pd.concat(CHI_2009_gamelog)    
CHI_2009_gamelogs = CHI_2009_gamelog.copy()
CHI_2009_gamelogs['GAME_SCORE'] = CHI_2009_gamelogs['GAME_SCORE'].astype(float)
CHI_2009_games = CHI_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2009_games_csv = CHI_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2009_games.csv', index=False)
CHI_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2009_games.csv')
CHI_2009_games_proc.head()
# Out:
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# 6: Ed Horton
# 7: Ken Norman
# 8: Ben Moore
# Pick one: 0
# Results for Ben Gordon:
#
# You searched for "Aaron Gray"
# 8 results found.
# 0: Aaron Gray
# 1: Gary Gray
# 2: Aaron Gordon
# 3: Devin Gray
# 4: Evric Gray
# 5: Allan Ray
# 6: Don Ray
# 7: Don Grate
# Pick one: 0
# Results for Aaron Gray:
#
# You searched for "Kirk Hinrich"
# 1 result found.
# Kirk Hinrich
# Results for Kirk Hinrich:
#
# You searched for "Larry Hughes"
# 6 results found.
# 0: Larry Hughes
# 1: Larry Bunce
# 2: Larry Fogle
# 3: Larry Jones
# 4: Larry Sykes
# 5: Larry Wright
# Pick one: 0
# Results for Larry Hughes:
#
# ...

# %%
CHI_2010_gamelog = []

for p in CHI_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2010_gamelog.append(player_log)
CHI_2010_gamelog = pd.concat(CHI_2010_gamelog)    
CHI_2010_gamelogs = CHI_2010_gamelog.copy()
CHI_2010_gamelogs['GAME_SCORE'] = CHI_2010_gamelogs['GAME_SCORE'].astype(float)
CHI_2010_games = CHI_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2010_games_csv = CHI_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2010_games.csv', index=False)
CHI_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2010_games.csv')
CHI_2010_games_proc.head()
# Out:
# You searched for "Joe Alexander"
# 4 results found.
# 0: Joe Alexander
# 1: Cory Alexander
# 2: Kyle Alexander
# 3: Gary Alexander
# Pick one: 0
# Results for Joe Alexander:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# 14: Jim Browne
# Pick one: 0
# Results for Devin Brown:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Aaron Gray"
# 8 results found.
# 0: Aaron Gray
# 1: Gary Gray
# 2: Aaron Gordon
# 3: Devin Gray
# 4: Evric Gray
# 5: Allan Ray
# 6: Don Ray
# 7: Don Grate
# Pick one: 0
# ...

# %%
CHI_2011_gamelog = []

for p in CHI_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2011_gamelog.append(player_log)
CHI_2011_gamelog = pd.concat(CHI_2011_gamelog)    
CHI_2011_gamelogs = CHI_2011_gamelog.copy()
CHI_2011_gamelogs['GAME_SCORE'] = CHI_2011_gamelogs['GAME_SCORE'].astype(float)
CHI_2011_games = CHI_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2011_games_csv = CHI_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2011_games.csv', index=False)
CHI_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2011_games.csv')
CHI_2011_games_proc.head()
# Out:
# You searched for "Ömer Aşık"
# 2 results found.
# 0: Omer Asik
# 1: Omar Cook
# Pick one: 0
# Results for Omer Asik:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# ...

# %%
CHI_2012_gamelog = []

for p in CHI_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2012_gamelog.append(player_log)
CHI_2012_gamelog = pd.concat(CHI_2012_gamelog)    
CHI_2012_gamelogs = CHI_2012_gamelog.copy()
CHI_2012_gamelogs['GAME_SCORE'] = CHI_2012_gamelogs['GAME_SCORE'].astype(float)
CHI_2012_games = CHI_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2012_games_csv = CHI_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2012_games.csv', index=False)
CHI_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2012_games.csv')
CHI_2012_games_proc.head()
# Out:
# You searched for "Ömer Aşık"
# 2 results found.
# 0: Omer Asik
# 1: Omar Cook
# Pick one: 0
# Results for Omer Asik:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Richard Hamilton"
# ...

# %%
CHI_2013_gamelog = []

for p in CHI_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2013_gamelog.append(player_log)
CHI_2013_gamelog = pd.concat(CHI_2013_gamelog)    
CHI_2013_gamelogs = CHI_2013_gamelog.copy()
CHI_2013_gamelogs['GAME_SCORE'] = CHI_2013_gamelogs['GAME_SCORE'].astype(float)
CHI_2013_games = CHI_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2013_games_csv = CHI_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2013_games.csv', index=False)
CHI_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2013_games.csv')
CHI_2013_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Daequan Cook"
# 2 results found.
# 0: Daequan Cook
# 1: Darwin Cook
# Pick one: 0
# Results for Daequan Cook:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# ...

# %%
# removed Mike Dunleavy
CHI_2014_gamelog = []

for p in CHI_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2014_gamelog.append(player_log)
CHI_2014_gamelog = pd.concat(CHI_2014_gamelog)    
CHI_2014_gamelogs = CHI_2014_gamelog.copy()
CHI_2014_gamelogs['GAME_SCORE'] = CHI_2014_gamelogs['GAME_SCORE'].astype(float)
CHI_2014_games = CHI_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2014_games_csv = CHI_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2014_games.csv', index=False)
CHI_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2014_games.csv')
CHI_2014_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Jimmer Fredette"
# 1 result found.
# Jimmer Fredette
# Results for Jimmer Fredette:
#
# ...

# %%
# removed Mike Dunleavy
# removed E'Twaun Moore
CHI_2015_gamelog = []

for p in CHI_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2015_gamelog.append(player_log)
CHI_2015_gamelog = pd.concat(CHI_2015_gamelog)    
CHI_2015_gamelogs = CHI_2015_gamelog.copy()
CHI_2015_gamelogs['GAME_SCORE'] = CHI_2015_gamelogs['GAME_SCORE'].astype(float)
CHI_2015_games = CHI_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2015_games_csv = CHI_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2015_games.csv', index=False)
CHI_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2015_games.csv')
CHI_2015_games_proc.head()
# Out:
# You searched for "Cameron Bairstow"
# 1 result found.
# Cameron Bairstow
# Results for Cameron Bairstow:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Kirk Hinrich"
# 1 result found.
# Kirk Hinrich
# Results for Kirk Hinrich:
#
# ...

# %%
# removed Mike dunleavy
# removed E'Twaun Moore
CHI_2016_gamelog = []

for p in CHI_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2016_gamelog.append(player_log)
CHI_2016_gamelog = pd.concat(CHI_2016_gamelog)    
CHI_2016_gamelogs = CHI_2016_gamelog.copy()
CHI_2016_gamelogs['GAME_SCORE'] = CHI_2016_gamelogs['GAME_SCORE'].astype(float)
CHI_2016_games = CHI_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2016_games_csv = CHI_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2016_games.csv', index=False)
CHI_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2016_games.csv')
CHI_2016_games_proc.head()
# Out:
# You searched for "Cameron Bairstow"
# 1 result found.
# Cameron Bairstow
# Results for Cameron Bairstow:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# ...

# %%
CHI_2017_gamelog = []

for p in CHI_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2017_gamelog.append(player_log)
CHI_2017_gamelog = pd.concat(CHI_2017_gamelog)    
CHI_2017_gamelogs = CHI_2017_gamelog.copy()
CHI_2017_gamelogs['GAME_SCORE'] = CHI_2017_gamelogs['GAME_SCORE'].astype(float)
CHI_2017_games = CHI_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2017_games_csv = CHI_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2017_games.csv', index=False)
CHI_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2017_games.csv')
CHI_2017_games_proc.head()
# Out:
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Jerian Grant"
# 3 results found.
# 0: Jerian Grant
# 1: Brian Grant
# 2: Jerami Grant
# Pick one: 0
# Results for Jerian Grant:
#
# You searched for "R.J. Hunter"
# 4 results found.
# 0: R.J. Hunter
# 1: Les Hunter
# 2: P.J. Tucker
# 3: A.J. Wynder
# ...

# %%
CHI_2018_gamelog = []

for p in CHI_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2018_gamelog.append(player_log)
CHI_2018_gamelog = pd.concat(CHI_2018_gamelog)    
CHI_2018_gamelogs = CHI_2018_gamelog.copy()
CHI_2018_gamelogs['GAME_SCORE'] = CHI_2018_gamelogs['GAME_SCORE'].astype(float)
CHI_2018_games = CHI_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2018_games_csv = CHI_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2018_games.csv', index=False)
CHI_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2018_games.csv')
CHI_2018_games_proc.head()
# Out:
# You searched for "Ryan Arcidiacono"
# 1 result found.
# Ryan Arcidiacono
# Results for Ryan Arcidiacono:
#
# You searched for "Ömer Aşık"
# 2 results found.
# 0: Omer Asik
# 1: Omar Cook
# Pick one: 0
# Results for Omer Asik:
#
# You searched for "Antonio Blakeney"
# 1 result found.
# Antonio Blakeney
# Results for Antonio Blakeney:
#
# You searched for "Kris Dunn"
# 6 results found.
# 0: Kris Dunn
# 1: Chris Duhon
# 2: Pat Dunn
# 3: T.R. Dunn
# 4: Chris Munk
# 5: Chris Quinn
# Pick one: 0
# Results for Kris Dunn:
#
# You searched for "Jarell Eddie"
# 1 result found.
# Jarell Eddie
# Results for Jarell Eddie:
#
# You searched for "Kay Felder"
# 6 results found.
# 0: Kay Felder
# 1: Ray Felix
# 2: Gary Keller
# 3: Ken Keller
# 4: Jay Miller
# 5: Gary Zeller
# Pick one: 0
# Results for Kay Felder:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Jerian Grant"
# 3 results found.
# 0: Jerian Grant
# ...

# %%
# removed wendell carter
# remed walt lemon
CHI_2019_gamelog = []

for p in CHI_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2019_gamelog.append(player_log)
CHI_2019_gamelog = pd.concat(CHI_2019_gamelog)    
CHI_2019_gamelogs = CHI_2019_gamelog.copy()
CHI_2019_gamelogs['GAME_SCORE'] = CHI_2019_gamelogs['GAME_SCORE'].astype(float)
CHI_2019_games = CHI_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2019_games_csv = CHI_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2019_games.csv', index=False)
CHI_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2019_games.csv')
CHI_2019_games_proc.head()
# Out:
# You searched for "Rawle Alkins"
# 1 result found.
# Rawle Alkins
# Results for Rawle Alkins:
#
# You searched for "Ryan Arcidiacono"
# 1 result found.
# Ryan Arcidiacono
# Results for Ryan Arcidiacono:
#
# You searched for "Antonio Blakeney"
# 1 result found.
# Antonio Blakeney
# Results for Antonio Blakeney:
#
# You searched for "Kris Dunn"
# 6 results found.
# 0: Kris Dunn
# 1: Chris Duhon
# 2: Pat Dunn
# 3: T.R. Dunn
# 4: Chris Munk
# 5: Chris Quinn
# Pick one: 0
# Results for Kris Dunn:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Shaquille Harrison"
# 1 result found.
# Shaquille Harrison
# Results for Shaquille Harrison:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Chandler Hutchison"
# 1 result found.
# Chandler Hutchison
# Results for Chandler Hutchison:
#
# You searched for "Zach LaVine"
# 3 results found.
# ...

# %%
# removed wendell carter
CHI_2020_gamelog = []

for p in CHI_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2020_gamelog.append(player_log)
CHI_2020_gamelog = pd.concat(CHI_2020_gamelog)    
CHI_2020_gamelogs = CHI_2020_gamelog.copy()
CHI_2020_gamelogs['GAME_SCORE'] = CHI_2020_gamelogs['GAME_SCORE'].astype(float)
CHI_2020_games = CHI_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2020_games_csv = CHI_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2020_games.csv', index=False)
CHI_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2020_games.csv')
CHI_2020_games_proc.head()
# Out:
# You searched for "Ryan Arcidiacono"
# 1 result found.
# Ryan Arcidiacono
# Results for Ryan Arcidiacono:
#
# You searched for "Kris Dunn"
# 6 results found.
# 0: Kris Dunn
# 1: Chris Duhon
# 2: Pat Dunn
# 3: T.R. Dunn
# 4: Chris Munk
# 5: Chris Quinn
# Pick one: 0
# Results for Kris Dunn:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Shaquille Harrison"
# 1 result found.
# Shaquille Harrison
# Results for Shaquille Harrison:
#
# You searched for "Chandler Hutchison"
# 1 result found.
# Chandler Hutchison
# Results for Chandler Hutchison:
#
# You searched for "Luke Kornet"
# 1 result found.
# Luke Kornet
# Results for Luke Kornet:
#
# You searched for "Zach LaVine"
# 3 results found.
# 0: Zach LaVine
# 1: Mack Calvin
# 2: Zach Lofton
# Pick one: 0
# Results for Zach LaVine:
#
# ...

# %%
# removed troy brown
# remvoed wendell carter
CHI_2021_gamelog = []

for p in CHI_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    CHI_2021_gamelog.append(player_log)
CHI_2021_gamelog = pd.concat(CHI_2021_gamelog)    
CHI_2021_gamelogs = CHI_2021_gamelog.copy()
CHI_2021_gamelogs['GAME_SCORE'] = CHI_2021_gamelogs['GAME_SCORE'].astype(float)
CHI_2021_games = CHI_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_2021_games_csv = CHI_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2021_games.csv', index=False)
CHI_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2021_games.csv')
CHI_2021_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Ryan Arcidiacono"
# 1 result found.
# Ryan Arcidiacono
# Results for Ryan Arcidiacono:
#
# You searched for "Devon Dotson"
# 2 results found.
# 0: Devon Dotson
# 1: Dean Tolson
# Pick one: 0
# Results for Devon Dotson:
#
# You searched for "Cristiano Felício"
# 1 result found.
# Cristiano Felicio
# Results for Cristiano Felicio:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Javonte Green"
# 2 results found.
# 0: Javonte Green
# 1: Donte Greene
# Pick one: 0
# Results for Javonte Green:
#
# You searched for "Chandler Hutchison"
# 1 result found.
# Chandler Hutchison
# Results for Chandler Hutchison:
#
# You searched for "Luke Kornet"
# 1 result found.
# Luke Kornet
# Results for Luke Kornet:
#
# You searched for "Zach LaVine"
# 3 results found.
# 0: Zach LaVine
# 1: Mack Calvin
# ...

# %% [markdown]
# ## combine all seasons

# %%
CHI_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2000_games.csv')
CHI_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2001_games.csv')
CHI_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2002_games.csv')
CHI_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2003_games.csv')
CHI_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2004_games.csv')
CHI_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2005_games.csv')
CHI_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2006_games.csv')
CHI_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2007_games.csv')
CHI_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2008_games.csv')
CHI_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2009_games.csv')
CHI_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2010_games.csv')
CHI_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2011_games.csv')
CHI_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2012_games.csv')
CHI_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2013_games.csv')
CHI_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2014_games.csv')
CHI_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2015_games.csv')
CHI_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2016_games.csv')
CHI_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2017_games.csv')
CHI_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2018_games.csv')
CHI_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2019_games.csv')
CHI_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2020_games.csv')
CHI_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2021_games.csv')

# %%
CHI_season_dfs = [CHI_2000_games_io, CHI_2001_games_io, CHI_2002_games_io, CHI_2003_games_io, CHI_2004_games_io, CHI_2005_games_io,
                 CHI_2006_games_io, CHI_2007_games_io, CHI_2008_games_io, CHI_2009_games_io, CHI_2010_games_io, CHI_2011_games_io,
                 CHI_2012_games_io, CHI_2013_games_io, CHI_2014_games_io, CHI_2015_games_io, CHI_2016_games_io, CHI_2017_games_io,
                 CHI_2018_games_io, CHI_2019_games_io, CHI_2020_games_io, CHI_2021_games_io]

# %%
CHI_all = pd.concat(CHI_season_dfs)
CHI_all_sorted = CHI_all.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 35 2017-01-02  27-110  CHI      HOME      CHO   W (+7)  1  38:19  15  24  ...
# 29 2003-12-27  23-282  CHI      HOME      WAS  W (+14)  1  42:01  16  27  ...
# 17 2012-12-07  27-286  CHI      AWAY      DET   W (+4)  1  43:26  12  19  ...
# 55 2011-02-17  22-136  CHI      HOME      SAS  W (+10)  1  38:30  18  28  ...
# 13 2016-11-20  27-067  CHI      AWAY      LAL   W (+8)  1  39:59  14  23  ...
# 48 2017-01-25  27-133  CHI      HOME      ATL   L (-5)  1  40:08  13  22  ...
# 73 2017-03-21  27-188  CHI      AWAY      TOR   L (-2)  1  43:37  11  21  ...
# 84 2010-04-13  21-191  CHI      HOME      BOS   W (+8)  1  45:35  15  22  ...
# 9  2016-11-12  27-059  CHI      HOME      WAS  W (+11)  1  38:19  11  23  ...
# 75 2017-03-24  27-191  CHI      HOME      PHI  L (-10)  1  42:08  10  24  ...
# 42 2008-01-23  27-021  CHI      HOME      IND  W (+13)  1  40:54  14  21  ...
# ...
