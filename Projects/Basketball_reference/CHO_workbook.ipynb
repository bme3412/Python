# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2016
appended_data_CHO = []

# CHO
while season <= 2021:
    df_CHO = get_roster('CHO', season)
    df_CHO['Season'] = season
    df_CHO['Team'] = 'CHO'
    appended_data_CHO.append(df_CHO)
    season = season + 1
appended_data_CHO = pd.concat(appended_data_CHO)

# %%
CHO_df_all = appended_data_CHO.copy()
CHO_df_all_csv = CHO_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_players_all.csv', index=False)
CHO_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_players_all.csv')
CHO_df_all_csv_io.head()
# Out:
#    NUMBER            PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0       5     Nicolas Batum  SF    6-8     230  1988-12-14          FR
# 1      30      Troy Daniels  SG    6-4     200  1991-07-15          US
# 2      12   Jorge Gutiérrez  PG    6-3     191  1988-12-27          MX
# 3      19     P.J. Hairston  SF    6-6     230  1992-12-24          US
# 4      50  Tyler Hansbrough  PF    6-9     250  1985-11-03          US
#
#   EXPERIENCE     COLLEGE  Season Team
# 0          7         NaN    2016  CHO
# 1          2         VCU    2016  CHO
# 2          2  California    2016  CHO
# 3          1         UNC    2016  CHO
# 4          6         UNC    2016  CHO

# %%
CHO_df_2000 = CHO_df_all[CHO_df_all['Season'] == 2000]
CHO_df_2001 = CHO_df_all[CHO_df_all['Season'] == 2001]
CHO_df_2002 = CHO_df_all[CHO_df_all['Season'] == 2002]
CHO_df_2003 = CHO_df_all[CHO_df_all['Season'] == 2003]
CHO_df_2004 = CHO_df_all[CHO_df_all['Season'] == 2004]
CHO_df_2005 = CHO_df_all[CHO_df_all['Season'] == 2005]
CHO_df_2006 = CHO_df_all[CHO_df_all['Season'] == 2006]
CHO_df_2007 = CHO_df_all[CHO_df_all['Season'] == 2007]
CHO_df_2008 = CHO_df_all[CHO_df_all['Season'] == 2008]
CHO_df_2009 = CHO_df_all[CHO_df_all['Season'] == 2009]
CHO_df_2010 = CHO_df_all[CHO_df_all['Season'] == 2010]
CHO_df_2011 = CHO_df_all[CHO_df_all['Season'] == 2011]
CHO_df_2012 = CHO_df_all[CHO_df_all['Season'] == 2012]
CHO_df_2013 = CHO_df_all[CHO_df_all['Season'] == 2013]
CHO_df_2014 = CHO_df_all[CHO_df_all['Season'] == 2014]
CHO_df_2015 = CHO_df_all[CHO_df_all['Season'] == 2015]
CHO_df_2016 = CHO_df_all[CHO_df_all['Season'] == 2016]
CHO_df_2017 = CHO_df_all[CHO_df_all['Season'] == 2017]
CHO_df_2018 = CHO_df_all[CHO_df_all['Season'] == 2018]
CHO_df_2019 = CHO_df_all[CHO_df_all['Season'] == 2019]
CHO_df_2020 = CHO_df_all[CHO_df_all['Season'] == 2020]
CHO_df_2021 = CHO_df_all[CHO_df_all['Season'] == 2021]

# %%
CHO_df_2000_players = CHO_df_2000['PLAYER'].to_list()
CHO_df_2001_players = CHO_df_2001['PLAYER'].to_list()
CHO_df_2002_players = CHO_df_2002['PLAYER'].to_list()
CHO_df_2003_players = CHO_df_2003['PLAYER'].to_list()
CHO_df_2004_players = CHO_df_2004['PLAYER'].to_list()
CHO_df_2005_players = CHO_df_2005['PLAYER'].to_list()

CHO_df_2006_players = CHO_df_2006['PLAYER'].to_list()
CHO_df_2007_players = CHO_df_2007['PLAYER'].to_list()
CHO_df_2008_players = CHO_df_2008['PLAYER'].to_list()
CHO_df_2009_players = CHO_df_2009['PLAYER'].to_list()
CHO_df_2010_players = CHO_df_2010['PLAYER'].to_list()
CHO_df_2011_players = CHO_df_2011['PLAYER'].to_list()

CHO_df_2012_players = CHO_df_2012['PLAYER'].to_list()
CHO_df_2013_players = CHO_df_2013['PLAYER'].to_list()
CHO_df_2014_players = CHO_df_2014['PLAYER'].to_list()
CHO_df_2015_players = CHO_df_2015['PLAYER'].to_list()
CHO_df_2016_players = CHO_df_2016['PLAYER'].to_list()
CHO_df_2017_players = CHO_df_2017['PLAYER'].to_list()

CHO_df_2018_players = CHO_df_2018['PLAYER'].to_list()
CHO_df_2019_players = CHO_df_2019['PLAYER'].to_list()
CHO_df_2020_players = CHO_df_2020['PLAYER'].to_list()
CHO_df_2021_players = CHO_df_2021['PLAYER'].to_list()

# %%
# PJ Hairston
CHO_2016_gamelog = []

for p in CHO_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2016_gamelog.append(player_log)
CHO_2016_gamelog = pd.concat(CHO_2016_gamelog)    
CHO_2016_gamelogs = CHO_2016_gamelog.copy()
CHO_2016_gamelogs['GAME_SCORE'] = CHO_2016_gamelogs['GAME_SCORE'].astype(float)
CHO_2016_games = CHO_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2016_games_csv = CHO_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2016_games.csv', index=False)
CHO_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2016_games.csv')
CHO_2016_games_proc.head()
# Out:
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# 2: Lloyd Daniels
# 3: Mel Daniels
# Pick one: 0
# Results for Troy Daniels:
#
# You searched for "Jorge Gutiérrez"
# 1 result found.
# Jorge Gutierrez
# Results for Jorge Gutierrez:
#
# You searched for "P.J. Hairston"
# 3 results found.
# 0: P.J. Hairston
# 1: R.J. Hampton
# 2: Al Hairston
# Pick one: 0
# Results for P.J. Hairston:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-53a94a18a441> in <module>
#       4
#       5 for p in CHO_df_2016_players:
# ----> 6     player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
#       7     player_log['Player'] = p
#       8
#
# ...

# %%
#Michael Kidd Gilchrist
CHO_2017_gamelog = []


for p in CHO_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2017_gamelog.append(player_log)
CHO_2017_gamelog = pd.concat(CHO_2017_gamelog)    
CHO_2017_gamelogs = CHO_2017_gamelog.copy()
CHO_2017_gamelogs['GAME_SCORE'] = CHO_2017_gamelogs['GAME_SCORE'].astype(float)
CHO_2017_games = CHO_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2017_games_csv = CHO_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2017_games.csv', index=False)
CHO_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2017_games.csv')
CHO_2017_games_proc.head()
# Out:
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Treveon Graham"
# 1 result found.
# Treveon Graham
# Results for Treveon Graham:
#
# You searched for "Aaron Harrison"
# 5 results found.
# 0: Aaron Harrison
# 1: Andrew Harrison
# 2: Bob Harrison
# 3: David Harrison
# 4: Aaron Jackson
# Pick one: 0
# Results for Aaron Harrison:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# 1: Steve Hawes
# 2: Spencer Haywood
# Pick one: 0
# Results for Spencer Hawes:
#
# You searched for "Roy Hibbert"
# 2 results found.
# 0: Roy Hibbert
# 1: Ray Tolbert
# Pick one: 0
# Results for Roy Hibbert:
#
# You searched for "Frank Kaminsky"
# 2 results found.
# 0: Frank Kaminsky
# 1: Frank Ramsey
# Pick one: 0
# Results for Frank Kaminsky:
#
# You searched for "Michael Kidd-Gilchrist"
# 1 result found.
# ...

# %%
# michael kidd gilchrist
CHO_2018_gamelog = []

for p in CHO_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2018_gamelog.append(player_log)
CHO_2018_gamelog = pd.concat(CHO_2018_gamelog)    
CHO_2018_gamelogs = CHO_2018_gamelog.copy()
CHO_2018_gamelogs['GAME_SCORE'] = CHO_2018_gamelogs['GAME_SCORE'].astype(float)
CHO_2018_games = CHO_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2018_games_csv = CHO_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2018_games.csv', index=False)
CHO_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2018_games.csv')
CHO_2018_games_proc.head()
# Out:
# You searched for "Dwayne Bacon"
# 4 results found.
# 0: Dwayne Bacon
# 1: Dwayne Sutton
# 2: Dwayne Morton
# 3: Wayne Pack
# Pick one: 0
# Results for Dwayne Bacon:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Treveon Graham"
# 1 result found.
# Treveon Graham
# Results for Treveon Graham:
#
# You searched for "Willy Hernangómez"
# 1 result found.
# Willy Hernangomez
# Results for Willy Hernangomez:
#
# You searched for "Dwight Howard"
# 2 results found.
# 0: Dwight Howard
# 1: Dwight Powell
# Pick one: 0
# Results for Dwight Howard:
#
# You searched for "Frank Kaminsky"
# 2 results found.
# 0: Frank Kaminsky
# 1: Frank Ramsey
# Pick one: 0
# Results for Frank Kaminsky:
#
# You searched for "Michael Kidd-Gilchrist"
# 1 result found.
# Michael Kidd-Gilchrist
# ...

# %%
# michael kidd-gilcrhsit

CHO_2019_gamelog = []



for p in CHO_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2019_gamelog.append(player_log)
CHO_2019_gamelog = pd.concat(CHO_2019_gamelog)    
CHO_2019_gamelogs = CHO_2019_gamelog.copy()
CHO_2019_gamelogs['GAME_SCORE'] = CHO_2019_gamelogs['GAME_SCORE'].astype(float)
CHO_2019_games = CHO_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2019_games_csv = CHO_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2019_games.csv', index=False)
CHO_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2019_games.csv')
CHO_2019_games_proc.head()
# Out:
# You searched for "Dwayne Bacon"
# 4 results found.
# 0: Dwayne Bacon
# 1: Dwayne Sutton
# 2: Dwayne Morton
# 3: Wayne Pack
# Pick one: 0
# Results for Dwayne Bacon:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Miles Bridges"
# 3 results found.
# 0: Miles Bridges
# 1: Bill Bridges
# 2: Mikal Bridges
# Pick one: 0
# Results for Miles Bridges:
#
# You searched for "Joe Chealey"
# 5 results found.
# 0: Joe Chealey
# 1: Joe Bradley
# 2: Don Chaney
# 3: John Chaney
# 4: Joe Reaves
# Pick one: 0
# Results for Joe Chealey:
#
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "Willy Hernangómez"
# 1 result found.
# Willy Hernangomez
# Results for Willy Hernangomez:
#
# You searched for "Frank Kaminsky"
# 2 results found.
# ...

# %%
# Michael kidd gilchrist

CHO_2020_gamelog = []



for p in CHO_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2020_gamelog.append(player_log)
CHO_2020_gamelog = pd.concat(CHO_2020_gamelog)    
CHO_2020_gamelogs = CHO_2020_gamelog.copy()
CHO_2020_gamelogs['GAME_SCORE'] = CHO_2020_gamelogs['GAME_SCORE'].astype(float)
CHO_2020_games = CHO_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2020_games_csv = CHO_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2020_games.csv', index=False)
CHO_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2020_games.csv')
CHO_2020_games_proc.head()
# Out:
# You searched for "Dwayne Bacon"
# 4 results found.
# 0: Dwayne Bacon
# 1: Dwayne Sutton
# 2: Dwayne Morton
# 3: Wayne Pack
# Pick one: 0
# Results for Dwayne Bacon:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Miles Bridges"
# 3 results found.
# 0: Miles Bridges
# 1: Bill Bridges
# 2: Mikal Bridges
# Pick one: 0
# Results for Miles Bridges:
#
# You searched for "Joe Chealey"
# 5 results found.
# 0: Joe Chealey
# 1: Joe Bradley
# 2: Don Chaney
# 3: John Chaney
# 4: Joe Reaves
# Pick one: 0
# Results for Joe Chealey:
#
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "Willy Hernangómez"
# 1 result found.
# Willy Hernangomez
# Results for Willy Hernangomez:
#
# You searched for "Michael Kidd-Gilchrist"
# 1 result found.
# ...

# %%
CHO_2021_gamelog = []

for p in CHO_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2021_gamelog.append(player_log)
CHO_2021_gamelog = pd.concat(CHO_2021_gamelog)    
CHO_2021_gamelogs = CHO_2021_gamelog.copy()
CHO_2021_gamelogs['GAME_SCORE'] = CHO_2021_gamelogs['GAME_SCORE'].astype(float)
CHO_2021_games = CHO_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2021_games_csv = CHO_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2021_games.csv', index=False)
CHO_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2021_games.csv')
CHO_2021_games_proc.head()
# Out:
# You searched for "LaMelo Ball"
# 3 results found.
# 0: LaMelo Ball
# 1: LiAngelo Ball
# 2: Lonzo Ball
# Pick one: 0
# Results for LaMelo Ball:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Miles Bridges"
# 3 results found.
# 0: Miles Bridges
# 1: Bill Bridges
# 2: Mikal Bridges
# Pick one: 0
# Results for Miles Bridges:
#
# You searched for "Vernon Carey"
# 1 result found.
# Vernon Carey Jr.
# Results for Vernon Carey Jr.:
#
# You searched for "Nate Darling"
# 2 results found.
# 0: Nate Darling
# 1: Nate DeLong
# Pick one: 0
# Results for Nate Darling:
#
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "Gordon Hayward"
# 1 result found.
# Gordon Hayward
# Results for Gordon Hayward:
#
# You searched for "Caleb Martin"
# 9 results found.
# 0: Caleb Martin
# 1: Bill Martin
# 2: Bob Martin
# 3: Cartier Martin
# 4: Cody Martin
# ...

# %%
CHO_2006_gamelog = []

for p in CHO_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2006_gamelog.append(player_log)
CHO_2006_gamelog = pd.concat(CHO_2006_gamelog)    
CHO_2006_gamelogs = CHO_2006_gamelog.copy()
CHO_2006_gamelogs['GAME_SCORE'] = CHO_2006_gamelogs['GAME_SCORE'].astype(float)
CHO_2006_games = CHO_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2006_games_csv = CHO_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2006_games.csv', index=False)
CHO_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2006_games.csv')
CHO_2006_games_proc.head()

# %%
CHO_2007_gamelog = []

for p in CHO_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2007_gamelog.append(player_log)
CHO_2007_gamelog = pd.concat(CHO_2007_gamelog)    
CHO_2007_gamelogs = CHO_2007_gamelog.copy()
CHO_2007_gamelogs['GAME_SCORE'] = CHO_2007_gamelogs['GAME_SCORE'].astype(float)
CHO_2007_games = CHO_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2007_games_csv = CHO_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2007_games.csv', index=False)
CHO_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2007_games.csv')
CHO_2007_games_proc.head()

# %%
CHO_2008_gamelog = []

for p in CHO_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2008_gamelog.append(player_log)
CHO_2008_gamelog = pd.concat(CHO_2008_gamelog)    
CHO_2008_gamelogs = CHO_2008_gamelog.copy()
CHO_2008_gamelogs['GAME_SCORE'] = CHO_2008_gamelogs['GAME_SCORE'].astype(float)
CHO_2008_games = CHO_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2008_games_csv = CHO_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2008_games.csv', index=False)
CHO_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2008_games.csv')
CHO_2008_games_proc.head()

# %%
CHO_2009_gamelog = []

for p in CHO_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2009_gamelog.append(player_log)
CHO_2009_gamelog = pd.concat(CHO_2009_gamelog)    
CHO_2009_gamelogs = CHO_2009_gamelog.copy()
CHO_2009_gamelogs['GAME_SCORE'] = CHO_2009_gamelogs['GAME_SCORE'].astype(float)
CHO_2009_games = CHO_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2009_games_csv = CHO_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2009_games.csv', index=False)
CHO_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2009_games.csv')
CHO_2009_games_proc.head()

# %%
CHO_2010_gamelog = []

for p in CHO_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2010_gamelog.append(player_log)
CHO_2010_gamelog = pd.concat(CHO_2010_gamelog)    
CHO_2010_gamelogs = CHO_2010_gamelog.copy()
CHO_2010_gamelogs['GAME_SCORE'] = CHO_2010_gamelogs['GAME_SCORE'].astype(float)
CHO_2010_games = CHO_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2010_games_csv = CHO_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2010_games.csv', index=False)
CHO_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2010_games.csv')
CHO_2010_games_proc.head()

# %%
CHO_2011_gamelog = []

for p in CHO_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2011_gamelog.append(player_log)
CHO_2011_gamelog = pd.concat(CHO_2011_gamelog)    
CHO_2011_gamelogs = CHO_2011_gamelog.copy()
CHO_2011_gamelogs['GAME_SCORE'] = CHO_2011_gamelogs['GAME_SCORE'].astype(float)
CHO_2011_games = CHO_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2011_games_csv = CHO_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2011_games.csv', index=False)
CHO_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2011_games.csv')
CHO_2011_games_proc.head()

# %%
CHO_2012_gamelog = []

for p in CHO_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2012_gamelog.append(player_log)
CHO_2012_gamelog = pd.concat(CHO_2012_gamelog)    
CHO_2012_gamelogs = CHO_2012_gamelog.copy()
CHO_2012_gamelogs['GAME_SCORE'] = CHO_2012_gamelogs['GAME_SCORE'].astype(float)
CHO_2012_games = CHO_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2012_games_csv = CHO_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2012_games.csv', index=False)
CHO_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2012_games.csv')
CHO_2012_games_proc.head()

# %%
CHO_2013_gamelog = []

for p in CHO_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2013_gamelog.append(player_log)
CHO_2013_gamelog = pd.concat(CHO_2013_gamelog)    
CHO_2013_gamelogs = CHO_2013_gamelog.copy()
CHO_2013_gamelogs['GAME_SCORE'] = CHO_2013_gamelogs['GAME_SCORE'].astype(float)
CHO_2013_games = CHO_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2013_games_csv = CHO_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2013_games.csv', index=False)
CHO_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2013_games.csv')
CHO_2013_games_proc.head()

# %%
CHO_2014_gamelog = []

for p in CHO_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2014_gamelog.append(player_log)
CHO_2014_gamelog = pd.concat(CHO_2014_gamelog)    
CHO_2014_gamelogs = CHO_2014_gamelog.copy()
CHO_2014_gamelogs['GAME_SCORE'] = CHO_2014_gamelogs['GAME_SCORE'].astype(float)
CHO_2014_games = CHO_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2014_games_csv = CHO_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2014_games.csv', index=False)
CHO_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2014_games.csv')
CHO_2014_games_proc.head()

# %%
CHO_2015_gamelog = []

for p in CHO_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2015_gamelog.append(player_log)
CHO_2015_gamelog = pd.concat(CHO_2015_gamelog)    
CHO_2015_gamelogs = CHO_2015_gamelog.copy()
CHO_2015_gamelogs['GAME_SCORE'] = CHO_2015_gamelogs['GAME_SCORE'].astype(float)
CHO_2015_games = CHO_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2015_games_csv = CHO_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2015_games.csv', index=False)
CHO_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2015_games.csv')
CHO_2015_games_proc.head()

# %%
# tim hardwaya

CHO_2016_gamelog = []

for p in CHO_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2016_gamelog.append(player_log)
CHO_2016_gamelog = pd.concat(CHO_2016_gamelog)    
CHO_2016_gamelogs = CHO_2016_gamelog.copy()
CHO_2016_gamelogs['GAME_SCORE'] = CHO_2016_gamelogs['GAME_SCORE'].astype(float)
CHO_2016_games = CHO_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2016_games_csv = CHO_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2016_games.csv', index=False)
CHO_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2016_games.csv')
CHO_2016_games_proc.head()

# %%
# mike dunleavy
CHO_2017_gamelog = []

for p in CHO_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2017_gamelog.append(player_log)
CHO_2017_gamelog = pd.concat(CHO_2017_gamelog)    
CHO_2017_gamelogs = CHO_2017_gamelog.copy()
CHO_2017_gamelogs['GAME_SCORE'] = CHO_2017_gamelogs['GAME_SCORE'].astype(float)
CHO_2017_games = CHO_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2017_games_csv = CHO_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2017_games.csv', index=False)
CHO_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2017_games.csv')
CHO_2017_games_proc.head()

# %%
# mike dunleavy
CHO_2018_gamelog = []

for p in CHO_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2018_gamelog.append(player_log)
CHO_2018_gamelog = pd.concat(CHO_2018_gamelog)    
CHO_2018_gamelogs = CHO_2018_gamelog.copy()
CHO_2018_gamelogs['GAME_SCORE'] = CHO_2018_gamelogs['GAME_SCORE'].astype(float)
CHO_2018_games = CHO_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2018_games_csv = CHO_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2018_games.csv', index=False)
CHO_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2018_games.csv')
CHO_2018_games_proc.head()

# %%
CHO_2019_gamelog = []

for p in CHO_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2019_gamelog.append(player_log)
CHO_2019_gamelog = pd.concat(CHO_2019_gamelog)    
CHO_2019_gamelogs = CHO_2019_gamelog.copy()
CHO_2019_gamelogs['GAME_SCORE'] = CHO_2019_gamelogs['GAME_SCORE'].astype(float)
CHO_2019_games = CHO_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2019_games_csv = CHO_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2019_games.csv', index=False)
CHO_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2019_games.csv')
CHO_2019_games_proc.head()

# %%
CHO_2020_gamelog = []

for p in CHO_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2020_gamelog.append(player_log)
CHO_2020_gamelog = pd.concat(CHO_2020_gamelog)    
CHO_2020_gamelogs = CHO_2020_gamelog.copy()
CHO_2020_gamelogs['GAME_SCORE'] = CHO_2020_gamelogs['GAME_SCORE'].astype(float)
CHO_2020_games = CHO_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2020_games_csv = CHO_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2020_games.csv', index=False)
CHO_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2020_games.csv')
CHO_2020_games_proc.head()

# %%
# clint capela
CHO_2021_gamelog = []

for p in CHO_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    CHO_2021_gamelog.append(player_log)
CHO_2021_gamelog = pd.concat(CHO_2021_gamelog)    
CHO_2021_gamelogs = CHO_2021_gamelog.copy()
CHO_2021_gamelogs['GAME_SCORE'] = CHO_2021_gamelogs['GAME_SCORE'].astype(float)
CHO_2021_games = CHO_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_2021_games_csv = CHO_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2021_games.csv', index=False)
CHO_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHO/CHO_2021_games.csv')
CHO_2021_games_proc.head()

# %% [markdown]
# ## combine all seasons

# %%
CHO_season_dfs = [CHO_2000_games, CHO_2001_games, CHO_2002_games, CHO_2003_games, CHO_2005_games,
                 CHO_2006_games, CHO_2007_games, CHO_2008_games, CHO_2009_games, CHO_2010_games, CHO_2011_games,
                  CHO_2012_games, CHO_2013_games, CHO_2014_games, CHO_2015_games,
                 CHO_2018_games, CHO_2019_games, CHO_2020_games]

# %%
CHO_all = pd.concat(CHO_season_dfs)
CHO_all_sorted = CHO_all.sort_values(by=['GAME_SCORE'], ascending=False)
CHO_all_sorted.head(25)
