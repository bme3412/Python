# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc


from matplotlib import rcParams

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
df_bos_2000 = get_roster('BOS', 2000)
df_bos_2001 = get_roster('BOS', 2001)
df_bos_2002 = get_roster('BOS', 2002)
df_bos_2003 = get_roster('BOS', 2003)
df_bos_2004 = get_roster('BOS', 2004)
df_bos_2005 = get_roster('BOS', 2005)
df_bos_2006 = get_roster('BOS', 2006)
df_bos_2007 = get_roster('BOS', 2007)
df_bos_2008 = get_roster('BOS', 2008)
df_bos_2009 = get_roster('BOS', 2009)
df_bos_2010 = get_roster('BOS', 2010)
df_bos_2011 = get_roster('BOS', 2011)
df_bos_2012 = get_roster('BOS', 2012)
df_bos_2013 = get_roster('BOS', 2013)
df_bos_2014 = get_roster('BOS', 2014)
df_bos_2015 = get_roster('BOS', 2015)
df_bos_2016 = get_roster('BOS', 2016)
df_bos_2017 = get_roster('BOS', 2017)
df_bos_2018 = get_roster('BOS', 2018)
df_bos_2019 = get_roster('BOS', 2019)
df_bos_2020 = get_roster('BOS', 2020)
df_bos_2021 = get_roster('BOS', 2021)

# %%
df_celtics_master = pd.concat([df_bos_2000, df_bos_2001, df_bos_2002, df_bos_2003, df_bos_2004, df_bos_2005,
                               df_bos_2006, df_bos_2007, df_bos_2008, df_bos_2009, df_bos_2010, df_bos_2011, df_bos_2012,
                               df_bos_2013, df_bos_2014, df_bos_2015, df_bos_2016, df_bos_2017, df_bos_2018, df_bos_2019,
                               df_bos_2020, df_bos_2021], axis=0)
df_celtics_master.head(60)
# Out:
#    NUMBER            PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       7    Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1      11       Dana Barros  PG   5-11     163 1967-04-13          US
# 2       4       Tony Battie   C   6-11     230 1976-02-11          US
# 3      40   Calbert Cheaney  SG    6-7     209 1971-07-17          US
# 4      29    Pervis Ellison   C    6-9     210 1967-04-03          US
# 5      27     Danny Fortson  PF    6-7     260 1976-03-27          US
# 6      44    Adrian Griffin  SG    6-5     217 1974-07-04          US
# 7       0    Walter McCarty  PF   6-10     230 1974-02-01          US
# 8      20      Doug Overton  PG    6-3     190 1969-08-03          US
# 9      34       Paul Pierce  SF    6-7     235 1977-10-13          US
# 10     52  Vitaly Potapenko   C   6-10     280 1975-03-21          UA
# 11      5      Jamel Thomas  SF    6-6     215 1973-03-25          US
# 12      5      Wayne Turner  PG    6-2     190 1976-03-22          US
# 13      8    Antoine Walker  PF    6-8     224 1976-08-12          US
# 14     55     Eric Williams  SF    6-8     220 1972-07-17          US
# 0       7    Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1       4       Tony Battie   C   6-11     230 1976-02-11          US
# 2      30       Mark Blount   C    7-0     230 1975-11-30          US
# 3      11       Randy Brown  PG    6-2     190 1968-05-22          US
# 4      40      Rick Brunson  PG    6-4     190 1972-06-14          US
# 5      43        Chris Carr  SG    6-5     207 1974-03-12          US
# 6      44    Adrian Griffin  SF    6-5     217 1974-07-04          US
# 7      12      Chris Herren  PG    6-2     197 1975-09-27          US
# 8       0    Walter McCarty  PF   6-10     230 1974-02-01          US
# 9       5      Jérôme Moïso   C   6-10     235 1978-06-15          FR
# 10      9      Doug Overton  PG    6-3     190 1969-08-03          US
# 11      9      Milt Palacio  PG    6-3     195 1978-02-07          US
# 12     34       Paul Pierce  SF    6-7     235 1977-10-13          US
# 13     52  Vitaly Potapenko   C   6-10     280 1975-03-21          UA
# 14     20      Bryant Stith  SG    6-5     208 1970-12-10          US
# 15      8    Antoine Walker  PF    6-8     224 1976-08-12          US
# 16     55     Eric Williams  SF    6-8     220 1972-07-17          US
# 0       7    Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1       4       Tony Battie   C   6-11     230 1976-02-11          US
# 2      30       Mark Blount   C    7-0     230 1975-11-30          US
# 3      42     Kedrick Brown  SF    6-7     222 1981-03-18          US
# 4      11       Randy Brown  PG    6-2     190 1968-05-22          US
# 5      28         Tony Delk  SG    6-1     189 1974-01-28          US
# 6      40      Joseph Forte  SG    6-4     194 1981-03-23          US
# 7      31       Joe Johnson  SG    6-7     240 1981-06-29          US
# 8       0    Walter McCarty  PF   6-10     230 1974-02-01          US
# 9       9      Milt Palacio  PG    6-3     195 1978-02-07          US
# 10     34       Paul Pierce  SG    6-7     235 1977-10-13          US
# 11     52  Vitaly Potapenko   C   6-10     280 1975-03-21          UA
# 12     54     Rodney Rogers  SF    6-7     235 1971-06-20          US
# 13     20  Erick Strickland  PG    6-3     210 1973-11-25          US
# 14      8    Antoine Walker  PF    6-8     224 1976-08-12          US
# 15     55     Eric Williams  SF    6-8     220 1972-07-17          US
# 0      42         Vin Baker   C   6-11     232 1971-11-23          US
# 1       4       Tony Battie   C   6-11     230 1976-02-11          US
# 2      30       Mark Blount   C    7-0     230 1975-11-30          US
# 3       9       J.R. Bremer  PG    6-2     185 1980-09-19          US
# 4       5     Kedrick Brown  SF    6-7     222 1981-03-18          US
# 5      11       Mark Bryant  PF    6-9     245 1965-04-25          US
# 6      12       Bimbo Coles  PG    6-1     180 1968-04-22          US
# 7       7         Tony Delk  PG    6-1     189 1974-01-28          US
# 8      43        Grant Long  PF    6-8     225 1966-03-12          US
# 9       0    Walter McCarty  SF   6-10     230 1974-02-01          US
# 10     31       Mikki Moore   C   6-11     225 1975-11-04          US
# 11     34       Paul Pierce  SG    6-7     235 1977-10-13          US
#
#    EXPERIENCE                            COLLEGE
# 0           8                       Georgia Tech
# 1          10                     Boston College
# 2           2                         Texas Tech
# 3           6                            Indiana
# 4           9                         Louisville
# 5           2                         Cincinnati
# 6           R                         Seton Hall
# 7           3                           Kentucky
# 8           7                           La Salle
# 9           1                             Kansas
# 10          3            Wright State University
# 11          R                         Providence
# 12          R                           Kentucky
# 13          3                           Kentucky
# 14          4   Vincennes University, Providence
# 0           9                       Georgia Tech
# 1           3                         Texas Tech
# 2           R                               Pitt
# 3           9          Houston, New Mexico State
# 4           3                             Temple
# 5           5                  Southern Illinois
# 6           1                         Seton Hall
# 7           1       Boston College, Fresno State
# 8           4                           Kentucky
# 9           R                               UCLA
# 10          8                           La Salle
# 11          1    Midland College, Colorado State
# 12          2                             Kansas
# 13          4            Wright State University
# 14          8                           Virginia
# 15          4                           Kentucky
# 16          5   Vincennes University, Providence
# 0          10                       Georgia Tech
# 1           4                         Texas Tech
# 2           1                               Pitt
# 3           R  Okaloosa-Walton Community College
# 4          10          Houston, New Mexico State
# 5           5                           Kentucky
# 6           R                                UNC
# 7           R                           Arkansas
# 8           5                           Kentucky
# 9           2    Midland College, Colorado State
# 10          3                             Kansas
# 11          5            Wright State University
# 12          8                        Wake Forest
# 13          5                           Nebraska
# 14          5                           Kentucky
# 15          6   Vincennes University, Providence
# 0           9             University of Hartford
# 1           5                         Texas Tech
# 2           2                               Pitt
# 3           R                    St. Bonaventure
# 4           1  Okaloosa-Walton Community College
# 5          14                         Seton Hall
# 6          12                      Virginia Tech
# 7           6                           Kentucky
# 8          14                   Eastern Michigan
# 9           6                           Kentucky
# 10          4                           Nebraska
# 11          4                             Kansas

# %%
df_celtics_master['PLAYER'].value_counts()
# Out:
# Paul Pierce         14
# Rajon Rondo          9
# Kendrick Perkins     8
# Marcus Smart         7
# Avery Bradley        7
#                     ..
# James Posey          1
# Scot Pollard         1
# Sam Cassell          1
# P.J. Brown           1
# Moritz Wagner        1
# Name: PLAYER, Length: 194, dtype: int64

# %%
celtics_all = df_celtics_master['PLAYER'].unique()
celtics_all
# Out:
# array(['Kenny Anderson', 'Dana Barros', 'Tony Battie', 'Calbert Cheaney',
#        'Pervis Ellison', 'Danny Fortson', 'Adrian Griffin',
#        'Walter McCarty', 'Doug Overton', 'Paul Pierce',
#        'Vitaly Potapenko', 'Jamel Thomas', 'Wayne Turner',
#        'Antoine Walker', 'Eric Williams', 'Mark Blount', 'Randy Brown',
#        'Rick Brunson', 'Chris Carr', 'Chris Herren', 'Jérôme Moïso',
#        'Milt Palacio', 'Bryant Stith', 'Kedrick Brown', 'Tony Delk',
#        'Joseph Forte', 'Joe Johnson', 'Rodney Rogers', 'Erick Strickland',
#        'Vin Baker', 'J.R. Bremer', 'Mark Bryant', 'Bimbo Coles',
#        'Grant Long', 'Mikki Moore', 'Bruno Šundov', 'Shammond Williams',
#        'Rubén Wolkowyski', 'Chucky Atkins', 'Marcus Banks', 'Ricky Davis',
#        'Brandon Hunter', 'Mike James', 'Jumaine Jones', 'Raef LaFrentz',
#        'Chris Mihm', 'Kendrick Perkins', 'Michael Stewart', 'Jiří Welsch',
#        'Tony Allen', 'Tom Gugliotta', 'Al Jefferson', 'Gary Payton',
#        'Justin Reed', 'Delonte West', 'Dan Dickau', 'Ryan Gomes',
#        'Gerald Green', 'Orien Greene', 'Dwayne Jones',
#        'Michael Olowokandi', 'Brian Scalabrine', 'Wally Szczerbiak',
#        'Kevinn Pinkney', 'Leon Powe', 'Theo Ratliff', 'Allan Ray',
#        'Rajon Rondo', 'Sebastian Telfair', 'Ray Allen', 'P.J. Brown',
#        'Sam Cassell', 'Glen Davis', 'Kevin Garnett', 'Eddie House',
#        'Scot Pollard', 'James Posey', 'Gabe Pruitt', 'J.R. Giddens',
#        'Stephon Marbury', "Patrick O'Bryant", 'Henry Walker',
#        'Marquis Daniels', 'Michael Finley', 'Lester Hudson',
#        'Oliver Lafayette', 'Marcus Landry', 'Nate Robinson',
#        'Rasheed Wallace', 'Shelden Williams', 'Carlos Arroyo',
#        'Avery Bradley', 'Semih Erden', 'Jeff Green', 'Luke Harangody',
#        'Chris Johnson', 'Nenad Krstić', 'Troy Murphy', "Jermaine O'Neal",
#        "Shaquille O'Neal", 'Sasha Pavlović', 'Von Wafer', 'Brandon Bass',
#        'Keyon Dooling', 'Ryan Hollins', 'JaJuan Johnson', "E'Twaun Moore",
#        'Mickaël Piétrus', 'Greg Stiemsma', 'Chris Wilcox',
#        'Sean Williams', 'Leandro Barbosa', 'Jason Collins',
#        'Jordan Crawford', 'Kris Joseph', 'Courtney Lee', 'Fab Melo',
#        'Darko Miličić', 'Shavlik Randolph', 'Jared Sullinger',
#        'Jason Terry', 'Jarvis Varnado', 'D.J. White', 'Terrence Williams',
#        'Joel Anthony', 'Chris Babb', 'Jerryd Bayless', 'Vander Blue',
#        'Keith Bogans', 'MarShon Brooks', 'Vítor Faverani',
#        'Kris Humphries', 'Kelly Olynyk', 'Phil Pressey', 'Gerald Wallace',
#        'Jae Crowder', 'Luigi Datome', 'Jonas Jerebko', 'Jameer Nelson',
#        'Dwight Powell', 'Tayshaun Prince', 'Marcus Smart',
#        'Isaiah Thomas', 'Marcus Thornton', 'Evan Turner',
#        'Brandan Wright', 'James Young', 'Tyler Zeller', 'Coty Clarke',
#        'John Holland', 'R.J. Hunter', 'Amir Johnson', 'David Lee',
#        'Jordan Mickey', 'Terry Rozier', 'Jaylen Brown', 'Al Horford',
#        'Demetrius Jackson', 'Kadeem Allen', 'Aron Baynes', 'Jabari Bird',
#        'Jarell Eddie', 'Jonathan Gibson', 'Gordon Hayward',
#        'Kyrie Irving', 'Shane Larkin', 'Greg Monroe', 'Marcus Morris',
#        'Abdel Nader', 'Semi Ojeleye', 'Xavier Silas', 'Jayson Tatum',
#        'Daniel Theis', 'Guerschon Yabusele', 'PJ Dozier',
#        'Brad Wanamaker', 'Robert Williams', 'Carsen Edwards',
#        'Tacko Fall', 'Javonte Green', 'Enes Kanter', 'Romeo Langford',
#        'Vincent Poirier', 'Kemba Walker', 'Tremont Waters',
#        'Grant Williams', 'Evan Fournier', 'Luke Kornet', 'Aaron Nesmith',
#        'Jabari Parker', 'Payton Pritchard', 'Jeff Teague',
#        'Tristan Thompson', 'Moritz Wagner'], dtype=object)

# %%
for player in celtics_all:
    s= get_stats(player, stat_type='PER_GAME', playoffs=False, career=False)
    print(s)
