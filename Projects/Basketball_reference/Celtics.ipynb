# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc


from matplotlib import rcParams

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
BOS_2000 = get_roster('BOS', 2000)
BOS_2000['Season'] = '2000'

BOS_2001 = get_roster('BOS', 2001)
BOS_2001['Season'] = '2001'

BOS_2002 = get_roster('BOS', 2002)
BOS_2002['Season'] = '2002'

BOS_2003 = get_roster('BOS', 2003)
BOS_2003['Season'] = '2003'

BOS_2004 = get_roster('BOS', 2004)
BOS_2004['Season'] = '2004'

BOS_2005 = get_roster('BOS', 2005)
BOS_2005['Season'] = '2005'

BOS_2006 = get_roster('BOS', 2006)
BOS_2006['Season'] = '2006'

BOS_2007 = get_roster('BOS', 2007)
BOS_2007['Season'] = '2007'

BOS_2008 = get_roster('BOS', 2008)
BOS_2008['Season'] = '2008'

BOS_2009 = get_roster('BOS', 2009)
BOS_2009['Season'] = '2009'

BOS_2010 = get_roster('BOS', 2010)
BOS_2010['Season'] = '2010'

BOS_2011 = get_roster('BOS', 2011)
BOS_2011['Season'] = '2011'

BOS_2012 = get_roster('BOS', 2012)
BOS_2012['Season'] = '2012'

BOS_2013 = get_roster('BOS', 2013)
BOS_2013['Season'] = '2013'

BOS_2014 = get_roster('BOS', 2014)
BOS_2014['Season'] = '2014'

BOS_2015 = get_roster('BOS', 2015)
BOS_2015['Season'] = '2015'

BOS_2016 = get_roster('BOS', 2016)
BOS_2016['Season'] = '2016'

BOS_2017 = get_roster('BOS', 2017)
BOS_2017['Season'] = '2017'

BOS_2018 = get_roster('BOS', 2018)
BOS_2018['Season'] = '2018'

BOS_2019 = get_roster('BOS', 2019)
BOS_2019['Season'] = '2019'

BOS_2020 = get_roster('BOS', 2020)
BOS_2020['Season'] = '2020'

BOS_2021 = get_roster('BOS', 2021)
BOS_2021['Season'] = '2021'

# %%
BOS_df = [BOS_2000, BOS_2001, BOS_2002, BOS_2003, BOS_2004, BOS_2005, BOS_2006, BOS_2007, BOS_2008,
         BOS_2009, BOS_2010, BOS_2011, BOS_2012, BOS_2013, BOS_2014, BOS_2015, BOS_2016,
         BOS_2017, BOS_2018, BOS_2019, BOS_2020, BOS_2021]
type(BOS_df)
# Out:
# list

# %%
BOS_2000.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       7   Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1      11      Dana Barros  PG   5-11     163 1967-04-13          US
# 2       4      Tony Battie   C   6-11     230 1976-02-11          US
# 3      40  Calbert Cheaney  SG    6-7     209 1971-07-17          US
# 4      29   Pervis Ellison   C    6-9     210 1967-04-03          US
#
#   EXPERIENCE         COLLEGE Season
# 0          8    Georgia Tech   2000
# 1         10  Boston College   2000
# 2          2      Texas Tech   2000
# 3          6         Indiana   2000
# 4          9      Louisville   2000

# %%
BOS_2000.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       7   Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1      11      Dana Barros  PG   5-11     163 1967-04-13          US
# 2       4      Tony Battie   C   6-11     230 1976-02-11          US
# 3      40  Calbert Cheaney  SG    6-7     209 1971-07-17          US
# 4      29   Pervis Ellison   C    6-9     210 1967-04-03          US
#
#   EXPERIENCE         COLLEGE Season
# 0          8    Georgia Tech   2000
# 1         10  Boston College   2000
# 2          2      Texas Tech   2000
# 3          6         Indiana   2000
# 4          9      Louisville   2000

# %%
BOS_2021
# Out:
#     NUMBER            PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0        7      Jaylen Brown  SG    6-6     223 1996-10-24          US
# 1        4    Carsen Edwards  SG   5-11     200 1998-03-12          US
# 2       99        Tacko Fall   C    7-5     311 1995-12-10          SN
# 3       94     Evan Fournier  SG    6-7     205 1992-10-29          FR
# 4       43     Javonte Green  SG    6-4     205 1993-07-23          US
# 5       40       Luke Kornet   C    7-2     250 1995-07-15          US
# 6       45    Romeo Langford  SG    6-4     216 1999-10-25          US
# 7       26     Aaron Nesmith  SF    6-5     215 1999-10-16          US
# 8       37      Semi Ojeleye  PF    6-6     240 1994-12-05          US
# 9       20     Jabari Parker  PF    6-8     245 1995-03-15          US
# 10      11  Payton Pritchard  SG    6-1     195 1998-01-28          US
# 11      36      Marcus Smart  PG    6-3     220 1994-03-06          US
# ...

# %%
df_celtics_master = pd.concat([BOS_2000, BOS_2001, BOS_2002, BOS_2003, BOS_2004, BOS_2005, BOS_2006, BOS_2007, BOS_2008,
         BOS_2009, BOS_2010, BOS_2011, BOS_2012, BOS_2013, BOS_2014, BOS_2015, BOS_2016,
         BOS_2017, BOS_2018, BOS_2019, BOS_2020, BOS_2021], axis=0)
df_celtics_master.head(60)
# Out:
#    NUMBER            PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       7    Kenny Anderson  PG    6-0     168 1970-10-09          US
# 1      11       Dana Barros  PG   5-11     163 1967-04-13          US
# 2       4       Tony Battie   C   6-11     230 1976-02-11          US
# 3      40   Calbert Cheaney  SG    6-7     209 1971-07-17          US
# 4      29    Pervis Ellison   C    6-9     210 1967-04-03          US
# 5      27     Danny Fortson  PF    6-7     260 1976-03-27          US
# 6      44    Adrian Griffin  SG    6-5     217 1974-07-04          US
# 7       0    Walter McCarty  PF   6-10     230 1974-02-01          US
# 8      20      Doug Overton  PG    6-3     190 1969-08-03          US
# 9      34       Paul Pierce  SF    6-7     235 1977-10-13          US
# 10     52  Vitaly Potapenko   C   6-10     280 1975-03-21          UA
# 11      5      Jamel Thomas  SF    6-6     215 1973-03-25          US
# ...

# %%
df_celtics_master['PLAYER'].value_counts()
# Out:
# Paul Pierce         14
# Rajon Rondo          9
# Kendrick Perkins     8
# Marcus Smart         7
# Avery Bradley        7
#                     ..
# James Posey          1
# Scot Pollard         1
# Sam Cassell          1
# P.J. Brown           1
# Moritz Wagner        1
# Name: PLAYER, Length: 194, dtype: int64

# %%
celtics_all = df_celtics_master['PLAYER'].unique()
celtics_all
# Out:
# array(['Kenny Anderson', 'Dana Barros', 'Tony Battie', 'Calbert Cheaney',
#        'Pervis Ellison', 'Danny Fortson', 'Adrian Griffin',
#        'Walter McCarty', 'Doug Overton', 'Paul Pierce',
#        'Vitaly Potapenko', 'Jamel Thomas', 'Wayne Turner',
#        'Antoine Walker', 'Eric Williams', 'Mark Blount', 'Randy Brown',
#        'Rick Brunson', 'Chris Carr', 'Chris Herren', 'Jérôme Moïso',
#        'Milt Palacio', 'Bryant Stith', 'Kedrick Brown', 'Tony Delk',
#        'Joseph Forte', 'Joe Johnson', 'Rodney Rogers', 'Erick Strickland',
#        'Vin Baker', 'J.R. Bremer', 'Mark Bryant', 'Bimbo Coles',
#        'Grant Long', 'Mikki Moore', 'Bruno Šundov', 'Shammond Williams',
#        'Rubén Wolkowyski', 'Chucky Atkins', 'Marcus Banks', 'Ricky Davis',
#        'Brandon Hunter', 'Mike James', 'Jumaine Jones', 'Raef LaFrentz',
#        'Chris Mihm', 'Kendrick Perkins', 'Michael Stewart', 'Jiří Welsch',
#        'Tony Allen', 'Tom Gugliotta', 'Al Jefferson', 'Gary Payton',
# ...

# %%
BOS_2008.head()
# Out:
#    NUMBER       PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0      20    Ray Allen  SG    6-5     205 1975-07-20          US         11
# 1      42   Tony Allen  SG    6-4     213 1982-01-11          US          3
# 2      93   P.J. Brown  PF   6-11     225 1969-10-14          US         14
# 3      28  Sam Cassell  PG    6-3     185 1969-11-18          US         14
# 4      11   Glen Davis   C    6-9     289 1986-01-01          US          R
#
#                                            COLLEGE Season
# 0                                            UConn   2008
# 1  Butler County Community College, Oklahoma State   2008
# 2                                   Louisiana Tech   2008
# 3                                    Florida State   2008
# 4                                              LSU   2008

# %%
players_2008 = BOS_2008['PLAYER'].to_list()
players2008 = []

for p in players_2008:
    x = p.split()[0]+p.split()[1]
    players2008.append((x+'2008'))

# %%
#players2008

# %%
ray_allen_2008 = get_game_logs('Ray Allen', SEASON_2008_START, SEASON_2008_END, playoffs=False)
tony_allen_2008 = get_game_logs('Tony Allen', SEASON_2008_START, SEASON_2008_END, playoffs=False)
paul_pierce_2008 = get_game_logs('Paul Pierce', SEASON_2008_START, SEASON_2008_END, playoffs=False)
kevin_garnett_2008 = get_game_logs('Kevin Garnett', SEASON_2008_START, SEASON_2008_END, playoffs=False)
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# ...

# %%
paul_pierce_2008['GAME_SCORE'] = paul_pierce_2008['GAME_SCORE'].astype(float)
paul_pierce_2008['Player'] = 'Paul Pierce'
paul_pierce_2008.head()
# Out:
#         DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 0 2007-11-02  30-020  BOS      HOME      WAS  W (+20)  1  39:22  10  19  ...
# 1 2007-11-04  30-022  BOS      AWAY      TOR   W (+3)  1  45:34   4  17  ...
# 2 2007-11-07  30-025  BOS      HOME      DEN  W (+26)  1  29:42  10  15  ...
# 3 2007-11-09  30-027  BOS      HOME      ATL  W (+23)  1  37:06   8  15  ...
# 4 2007-11-10  30-028  BOS      AWAY      NJN  W (+11)  1  40:08   9  19  ...
#
#   TRB AST STL BLK TOV PF PTS GAME_SCORE  +/-       Player
# 0   5   4   0   1   3  3  28       18.7  +19  Paul Pierce
# 1   5   6   2   0   3  4  13        5.4   +1  Paul Pierce
# 2   5   5   5   0   2  2  26       26.3  +26  Paul Pierce
# 3   3   4   1   0   5  1  23       14.6  +13  Paul Pierce
# 4   3   4   2   0   2  2  28       20.4  +16  Paul Pierce
#
# [5 rows x 29 columns]

# %%
kevin_garnett_2008['GAME_SCORE'] = kevin_garnett_2008['GAME_SCORE'].astype(float)
kevin_garnett_2008['Player'] = 'Kevin Garnett'

kevin_garnett_2008.head()
# Out:
#         DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 0 2007-11-02  31-167  BOS      HOME      WAS  W (+20)  1  38:08   9  17  ...
# 1 2007-11-04  31-169  BOS      AWAY      TOR   W (+3)  1  43:38   9  18  ...
# 2 2007-11-07  31-172  BOS      HOME      DEN  W (+26)  1  36:24  10  14  ...
# 3 2007-11-09  31-174  BOS      HOME      ATL  W (+23)  1  38:24  12  16  ...
# 4 2007-11-10  31-175  BOS      AWAY      NJN  W (+11)  1  42:50   5  14  ...
#
#   TRB AST STL BLK TOV PF PTS GAME_SCORE  +/-         Player
# 0  20   5   3   3   3  2  22       25.3  +16  Kevin Garnett
# 1  13   6   3   0   3  5  23       20.5   +7  Kevin Garnett
# 2  13   7   4   1   5  3  23       24.5  +33  Kevin Garnett
# 3  19   6   1   2   6  3  27       26.5  +19  Kevin Garnett
# 4  14   6   3   1   2  3  18       19.9  +10  Kevin Garnett
#
# [5 rows x 29 columns]

# %%
ray_allen_2008['GAME_SCORE'] = ray_allen_2008['GAME_SCORE'].astype(float)
ray_allen_2008['Player'] = 'Ray Allen'
ray_allen_2008.head()
# Out:
#         DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 0 2007-11-02  32-105  BOS      HOME      WAS  W (+20)  1  38:08   5  10  ...
# 1 2007-11-04  32-107  BOS      AWAY      TOR   W (+3)  1  49:10  11  16  ...
# 2 2007-11-07  32-110  BOS      HOME      DEN  W (+26)  1  32:48   8  12  ...
# 3 2007-11-09  32-112  BOS      HOME      ATL  W (+23)  1  35:14   6   9  ...
# 4 2007-11-10  32-113  BOS      AWAY      NJN  W (+11)  1  48:00   7  17  ...
#
#   TRB AST STL BLK TOV PF PTS GAME_SCORE  +/-     Player
# 0   4   2   0   0   0  2  17       14.6  +16  Ray Allen
# 1   4   0   0   0   2  1  33       25.0   -1  Ray Allen
# 2   3   6   2   0   2  1  22       22.3  +25  Ray Allen
# 3   2   3   1   0   1  3  14       11.6  +14  Ray Allen
# 4  10   5   0   0   3  1  27       21.4  +11  Ray Allen
#
# [5 rows x 29 columns]

# %%
big_three_2008 = pd.concat([paul_pierce_2008, kevin_garnett_2008, ray_allen_2008], axis=0)
big_three_2008.head()
# Out:
#         DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 0 2007-11-02  30-020  BOS      HOME      WAS  W (+20)  1  39:22  10  19  ...
# 1 2007-11-04  30-022  BOS      AWAY      TOR   W (+3)  1  45:34   4  17  ...
# 2 2007-11-07  30-025  BOS      HOME      DEN  W (+26)  1  29:42  10  15  ...
# 3 2007-11-09  30-027  BOS      HOME      ATL  W (+23)  1  37:06   8  15  ...
# 4 2007-11-10  30-028  BOS      AWAY      NJN  W (+11)  1  40:08   9  19  ...
#
#   TRB AST STL BLK TOV PF PTS GAME_SCORE  +/-       Player
# 0   5   4   0   1   3  3  28       18.7  +19  Paul Pierce
# 1   5   6   2   0   3  4  13        5.4   +1  Paul Pierce
# 2   5   5   5   0   2  2  26       26.3  +26  Paul Pierce
# 3   3   4   1   0   5  1  23       14.6  +13  Paul Pierce
# 4   3   4   2   0   2  2  28       20.4  +16  Paul Pierce
#
# [5 rows x 29 columns]

# %%
big_three_2008['GAME_SCORE'] = big_three_2008['GAME_SCORE'].astype(float)
big_three_2008.sort_values(by='GAME_SCORE', ascending=False)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 5  2007-11-13  30-031  BOS      AWAY      IND  W (+15)  1  41:20   8  17  ...
# 53 2008-02-20  32-215  BOS      AWAY      GSW   L (-2)  1  38:42  11  17  ...
# 73 2008-03-26  31-312  BOS      HOME      PHO  W (+20)  1  33:56  12  19  ...
# 74 2008-03-28  30-167  BOS      HOME      NOH  W (+20)  1  36:16   7  11  ...
# 37 2008-01-16  32-180  BOS      HOME      POR  W (+10)  1  42:24  12  20  ...
# ..        ...     ...  ...       ...      ...      ... ..    ...  ..  ..  ...
# 57 2008-02-27  30-137  BOS      HOME      CLE   W (+5)  1  38:59   4  14  ...
# 85 2008-04-16  32-271  BOS      HOME      NJN  W (+11)  1  17:28   1   4  ...
# 35 2008-01-12  32-176  BOS      AWAY      WAS   L (-7)  1  40:33   3  13  ...
# 42 2008-01-25  32-189  BOS      HOME      MIN   W (+1)  1  40:25   4  18  ...
# 31 2008-01-04  32-168  BOS      HOME      MEM   W (+4)  1  35:18   0   9  ...
#
# ...

# %%
plt.plot(big_three_2008['DATE'],big_three_2008['GAME_SCORE'])
plt.show()

# %%
df_bos_2021_stats = get_roster_stats('BOS', 2021)
df_bos_2021_stats
# Out:
#               PLAYER POS AGE TEAM   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0       Jaylen Brown  SG  24  BOS  58  58  34.5  9.3  19.2  .484  ...  1.2
# 1     Carsen Edwards  SG  22  BOS  31   1   8.9  1.5   3.6  .423  ...  0.1
# 2         Tacko Fall   C  25  BOS  19   0   7.2  1.1   1.5  .724  ...  0.8
# 3      Evan Fournier  SG  28  BOS  16  10  29.5  4.8  10.8  .448  ...  0.3
# 4      Javonte Green  SG  27  BOS  25   2  13.8  1.6   2.8  .549  ...  0.8
# 5        Luke Kornet   C  25  BOS  18   2  14.1  1.9   4.1  .473  ...  0.7
# 6     Romeo Langford  SG  21  BOS  18   4  15.7  1.2   3.3  .356  ...  0.7
# 7      Aaron Nesmith  SF  21  BOS  46   1  14.5  1.7   3.9  .438  ...  0.6
# 8       Semi Ojeleye  PF  26  BOS  56  15  17.0  1.6   3.9  .403  ...  0.6
# 9      Jabari Parker  PF  25  BOS  10   0  13.8  2.6   4.8  .542  ...  0.9
# 10  Payton Pritchard  SG  23  BOS  66   4  19.2  2.8   6.3  .440  ...  0.5
# ...
