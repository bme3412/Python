# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_DAL = []

# DAL
while season <= 2021:
    df_DAL = get_roster('DAL', season)
    df_DAL['Season'] = season
    df_DAL['Team'] = 'DAL'
    appended_data_DAL.append(df_DAL)
    season = season + 1
appended_data_DAL = pd.concat(appended_data_DAL)

# %%
DAL_df_all = appended_data_DAL.copy()
DAL_df_all_csv = DAL_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_players_all.csv', index=False)
DAL_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_players_all.csv')
DAL_df_all_csv_io.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      44    Shawn Bradley   C    7-6     235  1972-03-22          DE
# 1      21     Greg Buckner  SG    6-4     210  1976-09-16          US
# 2      23  Cedric Ceballos  SF    6-6     190  1969-08-02          US
# 3      24     Hubert Davis  PG    6-5     183  1970-05-17          US
# 4       4   Michael Finley  SF    6-7     215  1973-03-06          US
#
#   EXPERIENCE              COLLEGE  Season Team
# 0          6                  BYU    2000  DAL
# 1          R              Clemson    2000  DAL
# 2          9  Cal State Fullerton    2000  DAL
# 3          7                  UNC    2000  DAL
# 4          4            Wisconsin    2000  DAL

# %%
DAL_df_2000 = DAL_df_all[DAL_df_all['Season'] == 2000]
DAL_df_2001 = DAL_df_all[DAL_df_all['Season'] == 2001]
DAL_df_2002 = DAL_df_all[DAL_df_all['Season'] == 2002]
DAL_df_2003 = DAL_df_all[DAL_df_all['Season'] == 2003]
DAL_df_2004 = DAL_df_all[DAL_df_all['Season'] == 2004]
DAL_df_2005 = DAL_df_all[DAL_df_all['Season'] == 2005]
DAL_df_2006 = DAL_df_all[DAL_df_all['Season'] == 2006]
DAL_df_2007 = DAL_df_all[DAL_df_all['Season'] == 2007]
DAL_df_2008 = DAL_df_all[DAL_df_all['Season'] == 2008]
DAL_df_2009 = DAL_df_all[DAL_df_all['Season'] == 2009]
DAL_df_2010 = DAL_df_all[DAL_df_all['Season'] == 2010]
DAL_df_2011 = DAL_df_all[DAL_df_all['Season'] == 2011]
DAL_df_2012 = DAL_df_all[DAL_df_all['Season'] == 2012]
DAL_df_2013 = DAL_df_all[DAL_df_all['Season'] == 2013]
DAL_df_2014 = DAL_df_all[DAL_df_all['Season'] == 2014]
DAL_df_2015 = DAL_df_all[DAL_df_all['Season'] == 2015]
DAL_df_2016 = DAL_df_all[DAL_df_all['Season'] == 2016]
DAL_df_2017 = DAL_df_all[DAL_df_all['Season'] == 2017]
DAL_df_2018 = DAL_df_all[DAL_df_all['Season'] == 2018]
DAL_df_2019 = DAL_df_all[DAL_df_all['Season'] == 2019]
DAL_df_2020 = DAL_df_all[DAL_df_all['Season'] == 2020]
DAL_df_2021 = DAL_df_all[DAL_df_all['Season'] == 2021]

# %%
# changing names
#DAL_df_2002.loc[DAL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#DAL_df_2004.loc[DAL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
DAL_df_2000_players = DAL_df_2000['PLAYER'].to_list()
DAL_df_2001_players = DAL_df_2001['PLAYER'].to_list()
DAL_df_2002_players = DAL_df_2002['PLAYER'].to_list()
DAL_df_2003_players = DAL_df_2003['PLAYER'].to_list()
DAL_df_2004_players = DAL_df_2004['PLAYER'].to_list()
DAL_df_2005_players = DAL_df_2005['PLAYER'].to_list()

DAL_df_2006_players = DAL_df_2006['PLAYER'].to_list()
DAL_df_2007_players = DAL_df_2007['PLAYER'].to_list()
DAL_df_2008_players = DAL_df_2008['PLAYER'].to_list()
DAL_df_2009_players = DAL_df_2009['PLAYER'].to_list()
DAL_df_2010_players = DAL_df_2010['PLAYER'].to_list()
DAL_df_2011_players = DAL_df_2011['PLAYER'].to_list()

DAL_df_2012_players = DAL_df_2012['PLAYER'].to_list()
DAL_df_2013_players = DAL_df_2013['PLAYER'].to_list()
DAL_df_2014_players = DAL_df_2014['PLAYER'].to_list()
DAL_df_2015_players = DAL_df_2015['PLAYER'].to_list()
DAL_df_2016_players = DAL_df_2016['PLAYER'].to_list()
DAL_df_2017_players = DAL_df_2017['PLAYER'].to_list()

DAL_df_2018_players = DAL_df_2018['PLAYER'].to_list()
DAL_df_2019_players = DAL_df_2019['PLAYER'].to_list()
DAL_df_2020_players = DAL_df_2020['PLAYER'].to_list()
DAL_df_2021_players = DAL_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#DAL_df_2004_players.remove("Mamadou N'Diaye")
#DAL_df_2005_players.remove("Didier Ilunga-Mbenga")
#DAL_df_2006_players.remove("Didier Ilunga-Mbenga")
#DAL_df_2007_players.remove("J.J. Barea")
#DAL_df_2007_players.remove("Didier Ilunga-Mbenga")
#DAL_df_2008_players.remove("J.J. Barea")

#DAL_df_2009_players.remove("Antoine Wright")
#DAL_df_2011_players.remove("Sasha Pavlović")
#DAL_df_2009_players.remove("J.J. Barea")
#DAL_df_2010_players.remove("J.J. Barea")
#DAL_df_2011_players.remove("J.J. Barea")
#DAL_df_2012_players.remove("J.J. Barea")
#DAL_df_2013_players.remove("J.J. Barea")
#DAL_df_2014_players.remove("J.J. Barea")
#DAL_df_2015_players.remove("J.J. Barea")
#DAL_df_2015_players.remove("Greg Smith")
#DAL_df_2016_players.remove("J.J. Barea")
#DAL_df_2016_players.remove("David Lee")
#DAL_df_2017_players.remove("J.J. Barea")
#DAL_df_2018_players.remove("J.J. Barea")
#DAL_df_2019_players.remove("J.J. Barea")
#DAL_df_2020_players.remove("J.J. Barea")
#DAL_df_2018_players.remove("Maxi Kleber")
#DAL_df_2018_players.remove("Dennis Smith")
#DAL_df_2019_players.remove("Maxi Kleber")
#DAL_df_2019_players.remove("Dennis Smith")
#DAL_df_2020_players.remove("Maxi Kleber")
#DAL_df_2021_players.remove("Maxi Kleber")
DAL_df_2020_players.remove("Michael Kidd-Gilchrist")

# %%
DAL_2000_gamelog = []



for p in DAL_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2000_gamelog.append(player_log)
DAL_2000_gamelog = pd.concat(DAL_2000_gamelog)    
DAL_2000_gamelogs = DAL_2000_gamelog.copy()
DAL_2000_gamelogs['GAME_SCORE'] = DAL_2000_gamelogs['GAME_SCORE'].astype(float)
DAL_2000_games = DAL_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2000_games_csv = DAL_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2000_games.csv', index=False)
DAL_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2000_games.csv')
DAL_2000_games_proc.head()
# Out:
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Cedric Ceballos"
# 2 results found.
# 0: Cedric Ceballos
# 1: Cedric Ball
# Pick one: 0
# Results for Cedric Ceballos:
#
# You searched for "Hubert Davis"
# 5 results found.
# 0: Hubert Davis
# 1: Aubrey Davis
# 2: Ben Davis
# 3: Harry Davis
# 4: Tyler Davis
# Pick one: 0
# Results for Hubert Davis:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Rick Hughes"
# 2 results found.
# 0: Rick Hughes
# 1: Kim Hughes
# Pick one: 0
# Results for Rick Hughes:
#
# ...

# %%
DAL_2001_gamelog = []


for p in DAL_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2001_gamelog.append(player_log)
DAL_2001_gamelog = pd.concat(DAL_2001_gamelog)    
DAL_2001_gamelogs = DAL_2001_gamelog.copy()
DAL_2001_gamelogs['GAME_SCORE'] = DAL_2001_gamelogs['GAME_SCORE'].astype(float)
DAL_2001_games = DAL_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2001_games_csv = DAL_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2001_games.csv', index=False)
DAL_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2001_games.csv')
DAL_2001_games_proc.head()
# Out:
# You searched for "Courtney Alexander"
# 2 results found.
# 0: Courtney Alexander
# 1: Cory Alexander
# Pick one: 0
# Results for Courtney Alexander:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Mark Bryant"
# 11 results found.
# 0: Mark Bryant
# 1: Mark Blount
# 2: Mark Bradtke
# 3: Em Bryant
# 4: Joe Bryant
# 5: Kobe Bryant
# 6: Gary Grant
# 7: Markel Brown
# 8: Mark Eaton
# 9: Mark Workman
# 10: Mark Sibley
# Pick one: 0
# Results for Mark Bryant:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Bill Curley"
# 14 results found.
# 0: Bill Curley
# 1: Bill Turner
# 2: Bill Allen
# 3: Bill Bradley
# 4: Bill Bradley
# ...

# %%
DAL_2002_gamelog = []


for p in DAL_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2002_gamelog.append(player_log)
DAL_2002_gamelog = pd.concat(DAL_2002_gamelog)    
DAL_2002_gamelogs = DAL_2002_gamelog.copy()
DAL_2002_gamelogs['GAME_SCORE'] = DAL_2002_gamelogs['GAME_SCORE'].astype(float)
DAL_2002_games = DAL_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2002_games_csv = DAL_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2002_games.csv', index=False)
DAL_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2002_games.csv')
DAL_2002_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Evan Eschmeyer"
# 1 result found.
# Evan Eschmeyer
# Results for Evan Eschmeyer:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Adrian Griffin"
# ...

# %%
DAL_2003_gamelog = []



for p in DAL_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2003_gamelog.append(player_log)
DAL_2003_gamelog = pd.concat(DAL_2003_gamelog)    
DAL_2003_gamelogs = DAL_2003_gamelog.copy()
DAL_2003_gamelogs['GAME_SCORE'] = DAL_2003_gamelogs['GAME_SCORE'].astype(float)
DAL_2003_games = DAL_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2003_games_csv = DAL_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2003_games.csv', index=False)
DAL_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2003_games.csv')
DAL_2003_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Evan Eschmeyer"
# 1 result found.
# Evan Eschmeyer
# Results for Evan Eschmeyer:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Adrian Griffin"
# 2 results found.
# 0: Adrian Griffin
# 1: Eddie Griffin
# Pick one: 0
# Results for Adrian Griffin:
#
# You searched for "Adam Harrington"
# 2 results found.
# 0: Adam Harrington
# 1: Al Harrington
# Pick one: 0
# Results for Adam Harrington:
#
# ...

# %%
# removed Mamadou N'Diaye

DAL_2004_gamelog = []



for p in DAL_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2004_gamelog.append(player_log)
DAL_2004_gamelog = pd.concat(DAL_2004_gamelog)    
DAL_2004_gamelogs = DAL_2004_gamelog.copy()
DAL_2004_gamelogs['GAME_SCORE'] = DAL_2004_gamelogs['GAME_SCORE'].astype(float)
DAL_2004_games = DAL_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2004_games_csv = DAL_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2004_games.csv', index=False)
DAL_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2004_games.csv')
DAL_2004_games_proc.head()
# Out:
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Tony Delk"
# 12 results found.
# 0: Tony Delk
# 1: Tony Snell
# 2: Tony Zeno
# 3: Tony Allen
# 4: Troy Bell
# 5: Don Dee
# 6: Tony Dumas
# 7: Tony Koski
# 8: Deng Adel
# 9: Sonny Dove
# 10: Tony Price
# 11: Tony White
# Pick one: 0
# Results for Tony Delk:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Danny Fortson"
# 1 result found.
# ...

# %%
# removed Didier Ilunga-Mbenga

DAL_2005_gamelog = []

for p in DAL_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2005_gamelog.append(player_log)
DAL_2005_gamelog = pd.concat(DAL_2005_gamelog)    
DAL_2005_gamelogs = DAL_2005_gamelog.copy()
DAL_2005_gamelogs['GAME_SCORE'] = DAL_2005_gamelogs['GAME_SCORE'].astype(float)
DAL_2005_games = DAL_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2005_games_csv = DAL_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2005_games.csv', index=False)
DAL_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2005_games.csv')
DAL_2005_games_proc.head()
# Out:
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Shawn Bradley"
# 1 result found.
# Shawn Bradley
# Results for Shawn Bradley:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Dan Dickau"
# 3 results found.
# 0: Dan Dickau
# 1: Dan Tieman
# 2: Dan Kraus
# Pick one: 0
# Results for Dan Dickau:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# ...

# %%
# removed Didier Ilunga-Mbenga
DAL_2006_gamelog = []

for p in DAL_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2006_gamelog.append(player_log)
DAL_2006_gamelog = pd.concat(DAL_2006_gamelog)    
DAL_2006_gamelogs = DAL_2006_gamelog.copy()
DAL_2006_gamelogs['GAME_SCORE'] = DAL_2006_gamelogs['GAME_SCORE'].astype(float)
DAL_2006_games = DAL_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2006_games_csv = DAL_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2006_games.csv', index=False)
DAL_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2006_games.csv')
DAL_2006_games_proc.head()
# Out:
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "DeSagana Diop"
# 1 result found.
# DeSagana Diop
# Results for DeSagana Diop:
#
# You searched for "Adrian Griffin"
# 2 results found.
# 0: Adrian Griffin
# 1: Eddie Griffin
# Pick one: 0
# Results for Adrian Griffin:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# 6: David Harrison
# 7: Kevin Martin
# Pick one: 0
# Results for Devin Harris:
#
# ...

# %%
DAL_2007_gamelog = []

for p in DAL_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2007_gamelog.append(player_log)
DAL_2007_gamelog = pd.concat(DAL_2007_gamelog)    
DAL_2007_gamelogs = DAL_2007_gamelog.copy()
DAL_2007_gamelogs['GAME_SCORE'] = DAL_2007_gamelogs['GAME_SCORE'].astype(float)
DAL_2007_games = DAL_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2007_games_csv = DAL_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2007_games.csv', index=False)
DAL_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2007_games.csv')
DAL_2007_games_proc.head()
# Out:
# You searched for "Maurice Ager"
# 8 results found.
# 0: Maurice Ager
# 1: Maurice Baker
# 2: Maurice Carter
# 3: Maurice King
# 4: Maurice Ndour
# 5: Maurice Taylor
# 6: Maurice Evans
# 7: Maurice Lucas
# Pick one: 0
# Results for Maurice Ager:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "DeSagana Diop"
# 1 result found.
# DeSagana Diop
# Results for DeSagana Diop:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# ...

# %%
DAL_2008_gamelog = []

for p in DAL_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2008_gamelog.append(player_log)
DAL_2008_gamelog = pd.concat(DAL_2008_gamelog)    
DAL_2008_gamelogs = DAL_2008_gamelog.copy()
DAL_2008_gamelogs['GAME_SCORE'] = DAL_2008_gamelogs['GAME_SCORE'].astype(float)
DAL_2008_games = DAL_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2008_games_csv = DAL_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2008_games.csv', index=False)
DAL_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2008_games.csv')
DAL_2008_games_proc.head()
# Out:
# You searched for "Maurice Ager"
# 8 results found.
# 0: Maurice Ager
# 1: Maurice Baker
# 2: Maurice Carter
# 3: Maurice King
# 4: Maurice Ndour
# 5: Maurice Taylor
# 6: Maurice Evans
# 7: Maurice Lucas
# Pick one: 0
# Results for Maurice Ager:
#
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "DeSagana Diop"
# 1 result found.
# DeSagana Diop
# Results for DeSagana Diop:
#
# You searched for "Nick Fazekas"
# 1 result found.
# ...

# %%
DAL_2009_gamelog = []

for p in DAL_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2009_gamelog.append(player_log)
DAL_2009_gamelog = pd.concat(DAL_2009_gamelog)    
DAL_2009_gamelogs = DAL_2009_gamelog.copy()
DAL_2009_gamelogs['GAME_SCORE'] = DAL_2009_gamelogs['GAME_SCORE'].astype(float)
DAL_2009_games = DAL_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2009_games_csv = DAL_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2009_games.csv', index=False)
DAL_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2009_games.csv')
DAL_2009_games_proc.head()
# Out:
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Matt Carroll"
# 1 result found.
# Matt Carroll
# Results for Matt Carroll:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "DeSagana Diop"
# 1 result found.
# DeSagana Diop
# Results for DeSagana Diop:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Gerald Green"
# 6 results found.
# 0: Gerald Green
# 1: Gerald Brown
# 2: Gerald Govan
# 3: Gerald Glass
# 4: Erick Green
# 5: Sean Green
# Pick one: 0
# Results for Gerald Green:
#
# You searched for "Ryan Hollins"
# 3 results found.
# 0: Ryan Hollins
# 1: Don Collins
# 2: John Collins
# Pick one: 0
# Results for Ryan Hollins:
#
# ...

# %%
DAL_2010_gamelog = []

for p in DAL_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2010_gamelog.append(player_log)
DAL_2010_gamelog = pd.concat(DAL_2010_gamelog)    
DAL_2010_gamelogs = DAL_2010_gamelog.copy()
DAL_2010_gamelogs['GAME_SCORE'] = DAL_2010_gamelogs['GAME_SCORE'].astype(float)
DAL_2010_games = DAL_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2010_games_csv = DAL_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2010_games.csv', index=False)
DAL_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2010_games.csv')
DAL_2010_games_proc.head()
# Out:
# You searched for "Rodrigue Beaubois"
# 1 result found.
# Rodrigue Beaubois
# Results for Rodrigue Beaubois:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Matt Carroll"
# 1 result found.
# Matt Carroll
# Results for Matt Carroll:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Josh Howard"
# 8 results found.
# 0: Josh Howard
# 1: Josh Hart
# 2: Mo Howard
# 3: Josh Hall
# 4: Greg Howard
# 5: Juwan Howard
# 6: Otis Howard
# 7: Josh Powell
# Pick one: 0
# Results for Josh Howard:
#
# ...

# %%
DAL_2011_gamelog = []

for p in DAL_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2011_gamelog.append(player_log)
DAL_2011_gamelog = pd.concat(DAL_2011_gamelog)    
DAL_2011_gamelogs = DAL_2011_gamelog.copy()
DAL_2011_gamelogs['GAME_SCORE'] = DAL_2011_gamelogs['GAME_SCORE'].astype(float)
DAL_2011_games = DAL_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2011_games_csv = DAL_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2011_games.csv', index=False)
DAL_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2011_games.csv')
DAL_2011_games_proc.head()
# Out:
# You searched for "Alexis Ajinça"
# 1 result found.
# Alexis Ajinca
# Results for Alexis Ajinca:
#
# You searched for "Rodrigue Beaubois"
# 1 result found.
# Rodrigue Beaubois
# Results for Rodrigue Beaubois:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Dominique Jones"
# ...

# %%
DAL_2012_gamelog = []

for p in DAL_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2012_gamelog.append(player_log)
DAL_2012_gamelog = pd.concat(DAL_2012_gamelog)    
DAL_2012_gamelogs = DAL_2012_gamelog.copy()
DAL_2012_gamelogs['GAME_SCORE'] = DAL_2012_gamelogs['GAME_SCORE'].astype(float)
DAL_2012_games = DAL_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2012_games_csv = DAL_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2012_games.csv', index=False)
DAL_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2012_games.csv')
DAL_2012_games_proc.head()
# Out:
# You searched for "Kelenna Azubuike"
# 1 result found.
# Kelenna Azubuike
# Results for Kelenna Azubuike:
#
# You searched for "Rodrigue Beaubois"
# 1 result found.
# Rodrigue Beaubois
# Results for Rodrigue Beaubois:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Yi Jianlian"
# 1 result found.
# Yi Jianlian
# Results for Yi Jianlian:
#
# You searched for "Dominique Jones"
# 1 result found.
# Dominique Jones
# Results for Dominique Jones:
#
# You searched for "Jason Kidd"
# 5 results found.
# 0: Jason Kidd
# 1: Jason Hart
# 2: Stanton Kidd
# 3: Warren Kidd
# ...

# %%
DAL_2013_gamelog = []

for p in DAL_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2013_gamelog.append(player_log)
DAL_2013_gamelog = pd.concat(DAL_2013_gamelog)    
DAL_2013_gamelogs = DAL_2013_gamelog.copy()
DAL_2013_gamelogs['GAME_SCORE'] = DAL_2013_gamelogs['GAME_SCORE'].astype(float)
DAL_2013_games = DAL_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2013_games_csv = DAL_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2013_games.csv', index=False)
DAL_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2013_games.csv')
DAL_2013_games_proc.head()
# Out:
# You searched for "Josh Akognon"
# 4 results found.
# 0: Josh Akognon
# 1: Josh Okogie
# 2: Josh Boone
# 3: Josh Jackson
# Pick one: 0
# Results for Josh Akognon:
#
# You searched for "Rodrigue Beaubois"
# 1 result found.
# Rodrigue Beaubois
# Results for Rodrigue Beaubois:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Jared Cunningham"
# 2 results found.
# 0: Jared Cunningham
# ...

# %%
DAL_2014_gamelog = []

for p in DAL_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2014_gamelog.append(player_log)
DAL_2014_gamelog = pd.concat(DAL_2014_gamelog)    
DAL_2014_gamelogs = DAL_2014_gamelog.copy()
DAL_2014_gamelogs['GAME_SCORE'] = DAL_2014_gamelogs['GAME_SCORE'].astype(float)
DAL_2014_games = DAL_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2014_games_csv = DAL_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2014_games.csv', index=False)
DAL_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2014_games.csv')
DAL_2014_games_proc.head()
# Out:
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# ...

# %%
# remofed jj barea
# removed greg smith

DAL_2015_gamelog = []

for p in DAL_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2015_gamelog.append(player_log)
DAL_2015_gamelog = pd.concat(DAL_2015_gamelog)    
DAL_2015_gamelogs = DAL_2015_gamelog.copy()
DAL_2015_gamelogs['GAME_SCORE'] = DAL_2015_gamelogs['GAME_SCORE'].astype(float)
DAL_2015_games = DAL_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2015_games_csv = DAL_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2015_games.csv', index=False)
DAL_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2015_games.csv')
DAL_2015_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Raymond Felton"
# 1 result found.
# Raymond Felton
# Results for Raymond Felton:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# 6: David Harrison
# 7: Kevin Martin
# Pick one: 0
# Results for Devin Harris:
#
# You searched for "Bernard James"
# ...

# %%
# removed david lee
DAL_2016_gamelog = []

for p in DAL_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2016_gamelog.append(player_log)
DAL_2016_gamelog = pd.concat(DAL_2016_gamelog)    
DAL_2016_gamelogs = DAL_2016_gamelog.copy()
DAL_2016_gamelogs['GAME_SCORE'] = DAL_2016_gamelogs['GAME_SCORE'].astype(float)
DAL_2016_games = DAL_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2016_games_csv = DAL_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2016_games.csv', index=False)
DAL_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2016_games.csv')
DAL_2016_games_proc.head()
# Out:
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Jeremy Evans"
# 5 results found.
# 0: Jeremy Evans
# 1: Tyreke Evans
# 2: Jeremy Lamb
# 3: Jeremy Lin
# 4: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Evans:
#
# You searched for "Raymond Felton"
# 1 result found.
# Raymond Felton
# Results for Raymond Felton:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# 6: David Harrison
# 7: Kevin Martin
# Pick one: 0
# Results for Devin Harris:
#
# You searched for "John Jenkins"
# 5 results found.
# 0: John Jenkins
# 1: John Collins
# 2: John Henson
# 3: John Johnson
# 4: John Mahnken
# Pick one: 0
# Results for John Jenkins:
#
# You searched for "Wesley Matthews"
# 2 results found.
# 0: Wesley Matthews
# 1: Wes Matthews
# Pick one: 0
# Results for Wesley Matthews:
#
# You searched for "JaVale McGee"
# ...

# %%
DAL_2017_gamelog = []

for p in DAL_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2017_gamelog.append(player_log)
DAL_2017_gamelog = pd.concat(DAL_2017_gamelog)    
DAL_2017_gamelogs = DAL_2017_gamelog.copy()
DAL_2017_gamelogs['GAME_SCORE'] = DAL_2017_gamelogs['GAME_SCORE'].astype(float)
DAL_2017_games = DAL_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2017_games_csv = DAL_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2017_games.csv', index=False)
DAL_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2017_games.csv')
DAL_2017_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Ben Bentil"
# 2 results found.
# 0: Ben Bentil
# 1: Ben Kelso
# Pick one: 0
# Results for Ben Bentil:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Nicolás Brussino"
# 1 result found.
# Nicolas Brussino
# Results for Nicolas Brussino:
#
# You searched for "Quinn Cook"
# 3 results found.
# 0: Quinn Cook
# 1: Brian Cook
# 2: Quincy Acy
# Pick one: 0
# Results for Quinn Cook:
#
# You searched for "Seth Curry"
# 4 results found.
# ...

# %%
DAL_2018_gamelog = []

for p in DAL_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2018_gamelog.append(player_log)
DAL_2018_gamelog = pd.concat(DAL_2018_gamelog)    
DAL_2018_gamelogs = DAL_2018_gamelog.copy()
DAL_2018_gamelogs['GAME_SCORE'] = DAL_2018_gamelogs['GAME_SCORE'].astype(float)
DAL_2018_games = DAL_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2018_games_csv = DAL_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2018_games.csv', index=False)
DAL_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2018_games.csv')
DAL_2018_games_proc.head()
# Out:
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Gian Clavell"
# 1 result found.
# Gian Clavell
# Results for Gian Clavell:
#
# You searched for "Antonius Cleveland"
# 1 result found.
# Antonius Cleveland
# Results for Antonius Cleveland:
#
# You searched for "Kyle Collinsworth"
# 1 result found.
# Kyle Collinsworth
# Results for Kyle Collinsworth:
#
# You searched for "Yogi Ferrell"
# 1 result found.
# Yogi Ferrell
# Results for Yogi Ferrell:
#
# You searched for "Dorian Finney-Smith"
# 1 result found.
# Dorian Finney-Smith
# Results for Dorian Finney-Smith:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# 6: David Harrison
# 7: Kevin Martin
# Pick one: 0
# Results for Devin Harris:
#
# You searched for "Aaron Harrison"
# 5 results found.
# ...

# %%
DAL_2019_gamelog = []

for p in DAL_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2019_gamelog.append(player_log)
DAL_2019_gamelog = pd.concat(DAL_2019_gamelog)    
DAL_2019_gamelogs = DAL_2019_gamelog.copy()
DAL_2019_gamelogs['GAME_SCORE'] = DAL_2019_gamelogs['GAME_SCORE'].astype(float)
DAL_2019_games = DAL_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2019_games_csv = DAL_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2019_games.csv', index=False)
DAL_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2019_games.csv')
DAL_2019_games_proc.head()
# Out:
# You searched for "Kostas Antetokounmpo"
# 1 result found.
# Kostas Antetokounmpo
# Results for Kostas Antetokounmpo:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Ryan Broekhoff"
# 1 result found.
# Ryan Broekhoff
# Results for Ryan Broekhoff:
#
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Luka Dončić"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Dorian Finney-Smith"
# 1 result found.
# Dorian Finney-Smith
# Results for Dorian Finney-Smith:
#
# You searched for "Tim Hardaway"
# 2 results found.
# 0: Tim Hardaway
# 1: Tim Hardaway Jr.
# Pick one: 1
# ...

# %%
DAL_2020_gamelog = []

for p in DAL_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2020_gamelog.append(player_log)
DAL_2020_gamelog = pd.concat(DAL_2020_gamelog)    
DAL_2020_gamelogs = DAL_2020_gamelog.copy()
DAL_2020_gamelogs['GAME_SCORE'] = DAL_2020_gamelogs['GAME_SCORE'].astype(float)
DAL_2020_games = DAL_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2020_games_csv = DAL_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2020_games.csv', index=False)
DAL_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2020_games.csv')
DAL_2020_games_proc.head()
# Out:
# You searched for "Ryan Broekhoff"
# 1 result found.
# Ryan Broekhoff
# Results for Ryan Broekhoff:
#
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Antonius Cleveland"
# 1 result found.
# Antonius Cleveland
# Results for Antonius Cleveland:
#
# You searched for "Seth Curry"
# 4 results found.
# 0: Seth Curry
# 1: Dell Curry
# 2: Eddy Curry
# 3: Stephen Curry
# Pick one: 0
# Results for Seth Curry:
#
# You searched for "Luka Dončić"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Dorian Finney-Smith"
# 1 result found.
# Dorian Finney-Smith
# Results for Dorian Finney-Smith:
#
# ...

# %%
DAL_2021_gamelog = []

for p in DAL_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    DAL_2021_gamelog.append(player_log)
DAL_2021_gamelog = pd.concat(DAL_2021_gamelog)    
DAL_2021_gamelogs = DAL_2021_gamelog.copy()
DAL_2021_gamelogs['GAME_SCORE'] = DAL_2021_gamelogs['GAME_SCORE'].astype(float)
DAL_2021_games = DAL_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_2021_games_csv = DAL_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2021_games.csv', index=False)
DAL_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2021_games.csv')
DAL_2021_games_proc.head()
# Out:
# You searched for "Tyler Bey"
# 7 results found.
# 0: Tyler Bey
# 1: Tyler Cook
# 2: Tyler Dorsey
# 3: Kyle Guy
# 4: Tyler Herro
# 5: Tyler Ulis
# 6: Ty Jerome
# Pick one: 0
# Results for Tyler Bey:
#
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Luka Dončić"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Dorian Finney-Smith"
# 1 result found.
# Dorian Finney-Smith
# Results for Dorian Finney-Smith:
#
# You searched for "Josh Green"
# 14 results found.
# 0: Josh Green
# 1: Josh Grant
# 2: Josh Gray
# 3: Jeff Green
# 4: Si Green
# 5: A.C. Green
# 6: Johnny Green
# 7: Ken Green
# 8: Mike Green
# ...

# %% [markdown]
# ## combine all seasons

# %%
DAL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2000_games.csv')
DAL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2001_games.csv')
DAL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2002_games.csv')
DAL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2003_games.csv')
DAL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2004_games.csv')
DAL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2005_games.csv')
DAL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2006_games.csv')
DAL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2007_games.csv')
DAL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2008_games.csv')
DAL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2009_games.csv')
DAL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2010_games.csv')
DAL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2011_games.csv')
DAL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2012_games.csv')
DAL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2013_games.csv')
DAL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2014_games.csv')
DAL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2015_games.csv')
DAL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2016_games.csv')
DAL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2017_games.csv')
DAL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2018_games.csv')
DAL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2019_games.csv')
DAL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2020_games.csv')
DAL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2021_games.csv')

# %%
DAL_season_dfs = [DAL_2000_games_io, DAL_2001_games_io, DAL_2002_games_io, DAL_2003_games_io, DAL_2004_games_io, DAL_2005_games_io,
                 DAL_2006_games_io, DAL_2007_games_io, DAL_2008_games_io, DAL_2009_games_io, DAL_2010_games_io, DAL_2011_games_io,
                 DAL_2012_games_io, DAL_2013_games_io, DAL_2014_games_io, DAL_2015_games_io, DAL_2016_games_io, DAL_2017_games_io,
                 DAL_2018_games_io, DAL_2019_games_io, DAL_2020_games_io, DAL_2021_games_io]

# %%
DAL_all = pd.concat(DAL_season_dfs)
DAL_all_sorted = DAL_all.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2004-12-02  26-166  DAL      HOME      HOU   W (+7)   1  49:36  15   32
# 0  2006-03-23  27-277  DAL      HOME      GSW   L (-1)   1  40:50  16   24
# 0  2007-12-08  27-224  DAL      HOME      UTA   W (+8)   1  42:26  14   19
# 0  2007-02-07  28-233  DAL      HOME      MEM  W (+16)   1  37:33  14   20
# 0  2009-11-03  31-137  DAL      HOME      UTA  W (+11)   1  39:06  12   22
# 0  2020-08-08  21-162  DAL      HOME      MIL   W (+4)   1  41:34  12   24
# 0  2021-02-12  21-350  DAL      HOME      NOP  W (+13)   1  40:01  17   30
# 1  2019-11-29  20-274  DAL      AWAY      PHO   W (+7)   1  37:33  12   24
# 1  2021-02-14  21-352  DAL      HOME      POR   L (-3)   1  36:21  14   20
# 2  2021-01-25  21-332  DAL      HOME      DEN   L (-4)   1  39:03  11   23
# 2  2019-12-28  20-303  DAL      AWAY      GSW  W (+20)   1  30:05   8   16
# ...
