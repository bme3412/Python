# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_DEN = []

# DEN
while season <= 2021:
    df_DEN = get_roster('DEN', season)
    df_DEN['Season'] = season
    df_DEN['Team'] = 'DEN'
    appended_data_DEN.append(df_DEN)
    season = season + 1
appended_data_DEN = pd.concat(appended_data_DEN)

# %%
DEN_df_all = appended_data_DEN.copy()
DEN_df_all_csv = DEN_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_players_all.csv', index=False)
DEN_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_players_all.csv')
DEN_df_all_csv_io.head()
# Out:
#    NUMBER             PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0       9  Tariq Abdul-Wahad  SG    6-6     223  1974-11-03          FR
# 1       7     Cory Alexander  PG    6-1     185  1973-06-22          US
# 2       4   Chauncey Billups  SG    6-3     202  1976-09-25          US
# 3      42         Ryan Bowen  SF    6-7     215  1975-11-20          US
# 4  13, 15         Keon Clark   C   6-11     220  1975-04-16          US
#
#   EXPERIENCE                   COLLEGE  Season Team
# 0          2  Michigan, San Jose State    2000  DEN
# 1          4                  Virginia    2000  DEN
# 2          2                  Colorado    2000  DEN
# 3          R                      Iowa    2000  DEN
# 4          1                      UNLV    2000  DEN

# %%
DEN_df_2000 = DEN_df_all[DEN_df_all['Season'] == 2000]
DEN_df_2001 = DEN_df_all[DEN_df_all['Season'] == 2001]
DEN_df_2002 = DEN_df_all[DEN_df_all['Season'] == 2002]
DEN_df_2003 = DEN_df_all[DEN_df_all['Season'] == 2003]
DEN_df_2004 = DEN_df_all[DEN_df_all['Season'] == 2004]
DEN_df_2005 = DEN_df_all[DEN_df_all['Season'] == 2005]
DEN_df_2006 = DEN_df_all[DEN_df_all['Season'] == 2006]
DEN_df_2007 = DEN_df_all[DEN_df_all['Season'] == 2007]
DEN_df_2008 = DEN_df_all[DEN_df_all['Season'] == 2008]
DEN_df_2009 = DEN_df_all[DEN_df_all['Season'] == 2009]
DEN_df_2010 = DEN_df_all[DEN_df_all['Season'] == 2010]
DEN_df_2011 = DEN_df_all[DEN_df_all['Season'] == 2011]
DEN_df_2012 = DEN_df_all[DEN_df_all['Season'] == 2012]
DEN_df_2013 = DEN_df_all[DEN_df_all['Season'] == 2013]
DEN_df_2014 = DEN_df_all[DEN_df_all['Season'] == 2014]
DEN_df_2015 = DEN_df_all[DEN_df_all['Season'] == 2015]
DEN_df_2016 = DEN_df_all[DEN_df_all['Season'] == 2016]
DEN_df_2017 = DEN_df_all[DEN_df_all['Season'] == 2017]
DEN_df_2018 = DEN_df_all[DEN_df_all['Season'] == 2018]
DEN_df_2019 = DEN_df_all[DEN_df_all['Season'] == 2019]
DEN_df_2020 = DEN_df_all[DEN_df_all['Season'] == 2020]
DEN_df_2021 = DEN_df_all[DEN_df_all['Season'] == 2021]

# %%
# changing names
DEN_df_2003.loc[DEN_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
DEN_df_2004.loc[DEN_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
DEN_df_2000_players = DEN_df_2000['PLAYER'].to_list()
DEN_df_2001_players = DEN_df_2001['PLAYER'].to_list()
DEN_df_2002_players = DEN_df_2002['PLAYER'].to_list()
DEN_df_2003_players = DEN_df_2003['PLAYER'].to_list()
DEN_df_2004_players = DEN_df_2004['PLAYER'].to_list()
DEN_df_2005_players = DEN_df_2005['PLAYER'].to_list()

DEN_df_2006_players = DEN_df_2006['PLAYER'].to_list()
DEN_df_2007_players = DEN_df_2007['PLAYER'].to_list()
DEN_df_2008_players = DEN_df_2008['PLAYER'].to_list()
DEN_df_2009_players = DEN_df_2009['PLAYER'].to_list()
DEN_df_2010_players = DEN_df_2010['PLAYER'].to_list()
DEN_df_2011_players = DEN_df_2011['PLAYER'].to_list()

DEN_df_2012_players = DEN_df_2012['PLAYER'].to_list()
DEN_df_2013_players = DEN_df_2013['PLAYER'].to_list()
DEN_df_2014_players = DEN_df_2014['PLAYER'].to_list()
DEN_df_2015_players = DEN_df_2015['PLAYER'].to_list()
DEN_df_2016_players = DEN_df_2016['PLAYER'].to_list()
DEN_df_2017_players = DEN_df_2017['PLAYER'].to_list()

DEN_df_2018_players = DEN_df_2018['PLAYER'].to_list()
DEN_df_2019_players = DEN_df_2019['PLAYER'].to_list()
DEN_df_2020_players = DEN_df_2020['PLAYER'].to_list()
DEN_df_2021_players = DEN_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
# 2003 - Nene Hiulario
#DEN_df_2003_players.remove('Nene Hilario')
#DEN_df_2004_players.remove('Nenê Hilário')
#DEN_df_2005_players.remove('Nenê Hilário')
#DEN_df_2006_players.remove('Nenê Hilário')
#DEN_df_2006_players.remove('Charles Smith')
#DEN_df_2007_players.remove('Nenê Hilário')
#DEN_df_2008_players.remove('Nenê Hilário')
#DEN_df_2009_players.remove('Nenê Hilário')
#DEN_df_2010_players.remove('Nenê Hilário')
#DEN_df_2011_players.remove('Nenê Hilário')
#DEN_df_2008_players.remove('Bobby Jones')
#DEN_df_2012_players.remove('Nenê Hilário')
#DEN_df_2017_players.remove("Johnny O'Bryant")
#DEN_df_2020_players.remove("Michael Porter")
#DEN_df_2021_players.remove("Michael Porter")
DEN_df_2021_players.remove("Greg Whittington")

# %%
DEN_2000_gamelog = []



for p in DEN_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2000_gamelog.append(player_log)
DEN_2000_gamelog = pd.concat(DEN_2000_gamelog)    
DEN_2000_gamelogs = DEN_2000_gamelog.copy()
DEN_2000_gamelogs['GAME_SCORE'] = DEN_2000_gamelogs['GAME_SCORE'].astype(float)
DEN_2000_games = DEN_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2000_games_csv = DEN_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2000_games.csv', index=False)
DEN_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2000_games.csv')
DEN_2000_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "Cory Alexander"
# 7 results found.
# 0: Cory Alexander
# 1: Gary Alexander
# 2: Joe Alexander
# 3: Cliff Alexander
# 4: Courtney Alexander
# 5: Kyle Alexander
# 6: Victor Alexander
# Pick one: 0
# Results for Cory Alexander:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Ryan Bowen"
# 13 results found.
# 0: Ryan Bowen
# 1: Brian Bowen
# 2: Ryan Gomes
# 3: Jordan Bowden
# 4: Don Boven
# 5: Bruce Bowen
# 6: Stan Brown
# 7: Ray Owes
# 8: Ron Rowan
# 9: Jordan Bone
# 10: Ron Boone
# 11: Red Owens
# 12: Ryan Reid
# Pick one: 0
# Results for Ryan Bowen:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Chris Gatling"
# 4 results found.
# ...

# %%
DEN_2001_gamelog = []


for p in DEN_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2001_gamelog.append(player_log)
DEN_2001_gamelog = pd.concat(DEN_2001_gamelog)    
DEN_2001_gamelogs = DEN_2001_gamelog.copy()
DEN_2001_gamelogs['GAME_SCORE'] = DEN_2001_gamelogs['GAME_SCORE'].astype(float)
DEN_2001_games = DEN_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2001_games_csv = DEN_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2001_games.csv', index=False)
DEN_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2001_games.csv')
DEN_2001_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "Ryan Bowen"
# 13 results found.
# 0: Ryan Bowen
# 1: Brian Bowen
# 2: Ryan Gomes
# 3: Jordan Bowden
# 4: Don Boven
# 5: Bruce Bowen
# 6: Stan Brown
# 7: Ray Owes
# 8: Ron Rowan
# 9: Jordan Bone
# 10: Ron Boone
# 11: Red Owens
# 12: Ryan Reid
# Pick one: 0
# Results for Ryan Bowen:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Terry Davis"
# 21 results found.
# 0: Terry Davis
# 1: Harry Davis
# 2: Jerry Eaves
# 3: Aubrey Davis
# 4: Baron Davis
# 5: Ben Davis
# 6: Brad Davis
# 7: Ed Davis
# 8: Lee Davis
# 9: Mark Davis
# 10: Mark Davis
# 11: Mel Davis
# 12: Red Davis
# 13: Ricky Davis
# 14: Ron Davis
# ...

# %%
DEN_2002_gamelog = []


for p in DEN_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2002_gamelog.append(player_log)
DEN_2002_gamelog = pd.concat(DEN_2002_gamelog)    
DEN_2002_gamelogs = DEN_2002_gamelog.copy()
DEN_2002_gamelogs['GAME_SCORE'] = DEN_2002_gamelogs['GAME_SCORE'].astype(float)
DEN_2002_games = DEN_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2002_games_csv = DEN_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2002_games.csv', index=False)
DEN_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2002_games.csv')
DEN_2002_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Mengke Bateer"
# 1 result found.
# Mengke Bateer
# Results for Mengke Bateer:
#
# You searched for "Ryan Bowen"
# 13 results found.
# 0: Ryan Bowen
# 1: Brian Bowen
# 2: Ryan Gomes
# 3: Jordan Bowden
# 4: Don Boven
# 5: Bruce Bowen
# 6: Stan Brown
# 7: Ray Owes
# 8: Ron Rowan
# 9: Jordan Bone
# 10: Ron Boone
# 11: Red Owens
# 12: Ryan Reid
# Pick one: 0
# Results for Ryan Bowen:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Zendon Hamilton"
# 3 results found.
# ...

# %%
DEN_2003_gamelog = []



for p in DEN_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2003_gamelog.append(player_log)
DEN_2003_gamelog = pd.concat(DEN_2003_gamelog)    
DEN_2003_gamelogs = DEN_2003_gamelog.copy()
DEN_2003_gamelogs['GAME_SCORE'] = DEN_2003_gamelogs['GAME_SCORE'].astype(float)
DEN_2003_games = DEN_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2003_games_csv = DEN_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2003_games.csv', index=False)
DEN_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2003_games.csv')
DEN_2003_games_proc.head()
# Out:
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Mark Blount"
# 7 results found.
# 0: Mark Blount
# 1: Mark Bryant
# 2: Corie Blount
# 3: Markel Brown
# 4: Mark Jones
# 5: Mark Jones
# 6: Mark Sibley
# Pick one: 0
# Results for Mark Blount:
#
# You searched for "Ryan Bowen"
# 13 results found.
# 0: Ryan Bowen
# 1: Brian Bowen
# 2: Ryan Gomes
# 3: Jordan Bowden
# 4: Don Boven
# 5: Bruce Bowen
# 6: Stan Brown
# 7: Ray Owes
# 8: Ron Rowan
# 9: Jordan Bone
# 10: Ron Boone
# 11: Red Owens
# 12: Ryan Reid
# Pick one: 0
# Results for Ryan Bowen:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# ...

# %%
# removed neno hilario

DEN_2004_gamelog = []



for p in DEN_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2004_gamelog.append(player_log)
DEN_2004_gamelog = pd.concat(DEN_2004_gamelog)    
DEN_2004_gamelogs = DEN_2004_gamelog.copy()
DEN_2004_gamelogs['GAME_SCORE'] = DEN_2004_gamelogs['GAME_SCORE'].astype(float)
DEN_2004_games = DEN_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2004_games_csv = DEN_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2004_games.csv', index=False)
DEN_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2004_games.csv')
DEN_2004_games_proc.head()
# Out:
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# You searched for "Ryan Bowen"
# 13 results found.
# 0: Ryan Bowen
# 1: Brian Bowen
# 2: Ryan Gomes
# 3: Jordan Bowden
# 4: Don Boven
# ...

# %%
# removed nene hilario

DEN_2005_gamelog = []

for p in DEN_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2005_gamelog.append(player_log)
DEN_2005_gamelog = pd.concat(DEN_2005_gamelog)    
DEN_2005_gamelogs = DEN_2005_gamelog.copy()
DEN_2005_gamelogs['GAME_SCORE'] = DEN_2005_gamelogs['GAME_SCORE'].astype(float)
DEN_2005_games = DEN_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2005_games_csv = DEN_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2005_games.csv', index=False)
DEN_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2005_games.csv')
DEN_2005_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Luis Flores"
# 1 result found.
# Luis Flores
# Results for Luis Flores:
#
# You searched for "DerMarr Johnson"
# 4 results found.
# 0: DerMarr Johnson
# 1: DeMarco Johnson
# 2: Dakari Johnson
# 3: Omari Johnson
# Pick one: 0
# Results for DerMarr Johnson:
#
# You searched for "Voshon Lenard"
# ...

# %%
# remvoed nene hilario

DEN_2006_gamelog = []

for p in DEN_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2006_gamelog.append(player_log)
DEN_2006_gamelog = pd.concat(DEN_2006_gamelog)    
DEN_2006_gamelogs = DEN_2006_gamelog.copy()
DEN_2006_gamelogs['GAME_SCORE'] = DEN_2006_gamelogs['GAME_SCORE'].astype(float)
DEN_2006_games = DEN_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2006_games_csv = DEN_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2006_games.csv', index=False)
DEN_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2006_games.csv')
DEN_2006_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# ...

# %%
# removed nene hilario 
DEN_2007_gamelog = []

for p in DEN_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2007_gamelog.append(player_log)
DEN_2007_gamelog = pd.concat(DEN_2007_gamelog)    
DEN_2007_gamelogs = DEN_2007_gamelog.copy()
DEN_2007_gamelogs['GAME_SCORE'] = DEN_2007_gamelogs['GAME_SCORE'].astype(float)
DEN_2007_games = DEN_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2007_games_csv = DEN_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2007_games.csv', index=False)
DEN_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2007_games.csv')
DEN_2007_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Yakhouba Diawara"
# ...

# %%
# removed nene hilario
# removed bobby jones
DEN_2008_gamelog = []

for p in DEN_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2008_gamelog.append(player_log)
DEN_2008_gamelog = pd.concat(DEN_2008_gamelog)    
DEN_2008_gamelogs = DEN_2008_gamelog.copy()
DEN_2008_gamelogs['GAME_SCORE'] = DEN_2008_gamelogs['GAME_SCORE'].astype(float)
DEN_2008_games = DEN_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2008_games_csv = DEN_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2008_games.csv', index=False)
DEN_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2008_games.csv')
DEN_2008_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Yakhouba Diawara"
# 1 result found.
# Yakhouba Diawara
# Results for Yakhouba Diawara:
#
# You searched for "Taurean Green"
# 3 results found.
# 0: Taurean Green
# 1: Sean Green
# 2: Taurean Prince
# Pick one: 0
# Results for Taurean Green:
#
# You searched for "Steven Hunter"
# 4 results found.
# ...

# %%
# removed nene hilario
DEN_2009_gamelog = []

for p in DEN_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2009_gamelog.append(player_log)
DEN_2009_gamelog = pd.concat(DEN_2009_gamelog)    
DEN_2009_gamelogs = DEN_2009_gamelog.copy()
DEN_2009_gamelogs['GAME_SCORE'] = DEN_2009_gamelogs['GAME_SCORE'].astype(float)
DEN_2009_games = DEN_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2009_games_csv = DEN_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2009_games.csv', index=False)
DEN_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2009_games.csv')
DEN_2009_games_proc.head()
# Out:
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Jason Hart"
# 9 results found.
# 0: Jason Hart
# 1: Josh Hart
# 2: Jaxson Hayes
# 3: Jason Kidd
# 4: Jason Smith
# ...

# %%
# removed nene hilario 
DEN_2010_gamelog = []

for p in DEN_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2010_gamelog.append(player_log)
DEN_2010_gamelog = pd.concat(DEN_2010_gamelog)    
DEN_2010_gamelogs = DEN_2010_gamelog.copy()
DEN_2010_gamelogs['GAME_SCORE'] = DEN_2010_gamelogs['GAME_SCORE'].astype(float)
DEN_2010_games = DEN_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2010_games_csv = DEN_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2010_games.csv', index=False)
DEN_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2010_games.csv')
DEN_2010_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# ...

# %%
# removed nene hilario
DEN_2011_gamelog = []

for p in DEN_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2011_gamelog.append(player_log)
DEN_2011_gamelog = pd.concat(DEN_2011_gamelog)    
DEN_2011_gamelogs = DEN_2011_gamelog.copy()
DEN_2011_gamelogs['GAME_SCORE'] = DEN_2011_gamelogs['GAME_SCORE'].astype(float)
DEN_2011_games = DEN_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2011_games_csv = DEN_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2011_games.csv', index=False)
DEN_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2011_games.csv')
DEN_2011_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# ...

# %%
# removed nene hilario
DEN_2012_gamelog = []

for p in DEN_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2012_gamelog.append(player_log)
DEN_2012_gamelog = pd.concat(DEN_2012_gamelog)    
DEN_2012_gamelogs = DEN_2012_gamelog.copy()
DEN_2012_gamelogs['GAME_SCORE'] = DEN_2012_gamelogs['GAME_SCORE'].astype(float)
DEN_2012_games = DEN_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2012_games_csv = DEN_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2012_games.csv', index=False)
DEN_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2012_games.csv')
DEN_2012_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Rudy Fernández"
# 2 results found.
# 0: Rudy Fernandez
# 1: Bruno Fernando
# Pick one: 0
# Results for Rudy Fernandez:
#
# ...

# %%
DEN_2013_gamelog = []

for p in DEN_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2013_gamelog.append(player_log)
DEN_2013_gamelog = pd.concat(DEN_2013_gamelog)    
DEN_2013_gamelogs = DEN_2013_gamelog.copy()
DEN_2013_gamelogs['GAME_SCORE'] = DEN_2013_gamelogs['GAME_SCORE'].astype(float)
DEN_2013_games = DEN_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2013_games_csv = DEN_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2013_games.csv', index=False)
DEN_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2013_games.csv')
DEN_2013_games_proc.head()
# Out:
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Jordan Hamilton"
# 4 results found.
# 0: Jordan Hamilton
# 1: Joe Hamilton
# 2: Justin Hamilton
# 3: Zendon Hamilton
# Pick one: 0
# Results for Jordan Hamilton:
#
# You searched for "Andre Iguodala"
# 1 result found.
# Andre Iguodala
# Results for Andre Iguodala:
#
# ...

# %%
DEN_2014_gamelog = []

for p in DEN_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2014_gamelog.append(player_log)
DEN_2014_gamelog = pd.concat(DEN_2014_gamelog)    
DEN_2014_gamelogs = DEN_2014_gamelog.copy()
DEN_2014_gamelogs['GAME_SCORE'] = DEN_2014_gamelogs['GAME_SCORE'].astype(float)
DEN_2014_games = DEN_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2014_games_csv = DEN_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2014_games.csv', index=False)
DEN_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2014_games.csv')
DEN_2014_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# 8: Brandon Roy
# 9: Ray Felix
# ...

# %%
DEN_2015_gamelog = []

for p in DEN_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2015_gamelog.append(player_log)
DEN_2015_gamelog = pd.concat(DEN_2015_gamelog)    
DEN_2015_gamelogs = DEN_2015_gamelog.copy()
DEN_2015_gamelogs['GAME_SCORE'] = DEN_2015_gamelogs['GAME_SCORE'].astype(float)
DEN_2015_games = DEN_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2015_games_csv = DEN_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2015_games.csv', index=False)
DEN_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2015_games.csv')
DEN_2015_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Ian Clark"
# 4 results found.
# 0: Ian Clark
# 1: Earl Clark
# 2: Gary Clark
# 3: Keon Clark
# Pick one: 0
# Results for Ian Clark:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# ...

# %%
DEN_2016_gamelog = []

for p in DEN_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2016_gamelog.append(player_log)
DEN_2016_gamelog = pd.concat(DEN_2016_gamelog)    
DEN_2016_gamelogs = DEN_2016_gamelog.copy()
DEN_2016_gamelogs['GAME_SCORE'] = DEN_2016_gamelogs['GAME_SCORE'].astype(float)
DEN_2016_games = DEN_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2016_games_csv = DEN_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2016_games.csv', index=False)
DEN_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2016_games.csv')
DEN_2016_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# 8: Brandon Roy
# 9: Ray Felix
# Pick one: 0
# Results for Randy Foye:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
# ...

# %%
DEN_2017_gamelog = []

for p in DEN_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2017_gamelog.append(player_log)
DEN_2017_gamelog = pd.concat(DEN_2017_gamelog)    
DEN_2017_gamelogs = DEN_2017_gamelog.copy()
DEN_2017_gamelogs['GAME_SCORE'] = DEN_2017_gamelogs['GAME_SCORE'].astype(float)
DEN_2017_games = DEN_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2017_games_csv = DEN_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2017_games.csv', index=False)
DEN_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2017_games.csv')
DEN_2017_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Alonzo Gee"
# 1 result found.
# ...

# %%
DEN_2018_gamelog = []

for p in DEN_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2018_gamelog.append(player_log)
DEN_2018_gamelog = pd.concat(DEN_2018_gamelog)    
DEN_2018_gamelogs = DEN_2018_gamelog.copy()
DEN_2018_gamelogs['GAME_SCORE'] = DEN_2018_gamelogs['GAME_SCORE'].astype(float)
DEN_2018_games = DEN_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2018_games_csv = DEN_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2018_games.csv', index=False)
DEN_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2018_games.csv')
DEN_2018_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Torrey Craig"
# 1 result found.
# Torrey Craig
# Results for Torrey Craig:
#
# You searched for "Kenneth Faried"
# 2 results found.
# 0: Kenneth Faried
# 1: Kenneth Gardner
# Pick one: 0
# Results for Kenneth Faried:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# ...

# %%
DEN_2019_gamelog = []

for p in DEN_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2019_gamelog.append(player_log)
DEN_2019_gamelog = pd.concat(DEN_2019_gamelog)    
DEN_2019_gamelogs = DEN_2019_gamelog.copy()
DEN_2019_gamelogs['GAME_SCORE'] = DEN_2019_gamelogs['GAME_SCORE'].astype(float)
DEN_2019_games = DEN_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2019_games_csv = DEN_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2019_games.csv', index=False)
DEN_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2019_games.csv')
DEN_2019_games_proc.head()
# Out:
# You searched for "DeVaughn Akoon-Purcell"
# 1 result found.
# DeVaughn Akoon-Purcell
# Results for DeVaughn Akoon-Purcell:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Torrey Craig"
# 1 result found.
# Torrey Craig
# Results for Torrey Craig:
#
# You searched for "Brandon Goodwin"
# 1 result found.
# Brandon Goodwin
# Results for Brandon Goodwin:
#
# You searched for "Gary Harris"
# 14 results found.
# 0: Gary Harris
# 1: Art Harris
# 2: Manny Harris
# 3: Tony Harris
# 4: Jalen Harris
# 5: Art Burris
# 6: Gary Forbes
# 7: Billy Harris
# 8: Bob Harris
# 9: Chris Harris
# 10: Joe Harris
# 11: Mike Harris
# 12: Gary Hill
# ...

# %%
# removed michael porter

DEN_2020_gamelog = []

for p in DEN_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2020_gamelog.append(player_log)
DEN_2020_gamelog = pd.concat(DEN_2020_gamelog)    
DEN_2020_gamelogs = DEN_2020_gamelog.copy()
DEN_2020_gamelogs['GAME_SCORE'] = DEN_2020_gamelogs['GAME_SCORE'].astype(float)
DEN_2020_games = DEN_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2020_games_csv = DEN_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2020_games.csv', index=False)
DEN_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2020_games.csv')
DEN_2020_games_proc.head()
# Out:
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Bol Bol"
# 11 results found.
# 0: Bol Bol
# 1: Bob Doll
# 2: Bob Brown
# 3: Bob Ford
# 4: Tom Gola
# 5: Bob Love
# 6: Don Ohl
# 7: Lou Roe
# 8: Bob Rule
# 9: Joe Wolf
# 10: Bob Wood
# Pick one: 0
# Results for Bol Bol:
#
# You searched for "Vlatko Čančar"
# 1 result found.
# Vlatko Cancar
# Results for Vlatko Cancar:
#
# You searched for "Tyler Cook"
# 8 results found.
# 0: Tyler Cook
# 1: Tyler Bey
# 2: Bert Cook
# 3: Omar Cook
# 4: Tyler Lydon
# 5: Tyler Ulis
# 6: Joe Cooke
# ...

# %%
# removed michael porter
# removed greg whittington
DEN_2021_gamelog = []

for p in DEN_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    DEN_2021_gamelog.append(player_log)
DEN_2021_gamelog = pd.concat(DEN_2021_gamelog)    
DEN_2021_gamelogs = DEN_2021_gamelog.copy()
DEN_2021_gamelogs['GAME_SCORE'] = DEN_2021_gamelogs['GAME_SCORE'].astype(float)
DEN_2021_games = DEN_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_2021_games_csv = DEN_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2021_games.csv', index=False)
DEN_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2021_games.csv')
DEN_2021_games_proc.head()
# Out:
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Bol Bol"
# 11 results found.
# 0: Bol Bol
# 1: Bob Doll
# 2: Bob Brown
# 3: Bob Ford
# 4: Tom Gola
# 5: Bob Love
# 6: Don Ohl
# 7: Lou Roe
# 8: Bob Rule
# 9: Joe Wolf
# 10: Bob Wood
# Pick one: 0
# Results for Bol Bol:
#
# You searched for "Facundo Campazzo"
# 1 result found.
# Facundo Campazzo
# Results for Facundo Campazzo:
#
# You searched for "Vlatko Čančar"
# 1 result found.
# Vlatko Cancar
# Results for Vlatko Cancar:
#
# You searched for "Gary Clark"
# 15 results found.
# 0: Gary Clark
# 1: Earl Clark
# 2: Ian Clark
# 3: Gary Alcorn
# 4: Cory Carr
# 5: Carlos Clark
# 6: Keon Clark
# 7: Coty Clarke
# 8: Gary Grant
# 9: Gary Gray
# 10: Gar Heard
# 11: Gary Neal
# 12: Jay Carty
# 13: Gary Keller
# 14: Gary Zeller
# Pick one: 0
# ...

# %% [markdown]
# ## combine all seasons

# %%
DEN_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2000_games.csv')
DEN_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2001_games.csv')
DEN_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2002_games.csv')
DEN_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2003_games.csv')
DEN_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2004_games.csv')
DEN_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2005_games.csv')
DEN_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2006_games.csv')
DEN_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2007_games.csv')
DEN_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2008_games.csv')
DEN_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2009_games.csv')
DEN_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2010_games.csv')
DEN_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2011_games.csv')
DEN_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2012_games.csv')
DEN_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2013_games.csv')
DEN_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2014_games.csv')
DEN_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2015_games.csv')
DEN_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2016_games.csv')
DEN_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2017_games.csv')
DEN_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2018_games.csv')
DEN_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2019_games.csv')
DEN_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2020_games.csv')
DEN_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2021_games.csv')

# %%
DEN_season_dfs = [DEN_2000_games_io, DEN_2001_games_io, DEN_2002_games_io, DEN_2003_games_io, DEN_2004_games_io, DEN_2005_games_io,
                 DEN_2006_games_io, DEN_2007_games_io, DEN_2008_games_io, DEN_2009_games_io, DEN_2010_games_io, DEN_2011_games_io,
                 DEN_2012_games_io, DEN_2013_games_io, DEN_2014_games_io, DEN_2015_games_io, DEN_2016_games_io, DEN_2017_games_io,
                 DEN_2018_games_io, DEN_2019_games_io, DEN_2020_games_io, DEN_2021_games_io]

# %%
DEN_all = pd.concat(DEN_season_dfs)
DEN_all_sorted = DEN_all.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-06  25-353  DEN      AWAY      SAC   L (-5)   1  41:24  20   33
# 0  2018-10-20  23-243  DEN      HOME      PHO  W (+28)   1  30:43  11   11
# 0  2007-03-17  31-283  DEN      HOME      PHO  W (+24)   1  42:38  16   22
# 1  2021-02-19  23-362  DEN      AWAY      CLE  W (+17)   1  38:15  21   25
# 0  2020-01-06  24-321  DEN      AWAY      ATL   W (+8)   1  36:50  16   25
# 0  2008-04-05  23-312  DEN      HOME      SAC   L (-3)   1  38:02  19   24
# 2  2021-01-31  25-347  DEN      HOME      UTA  W (+11)   1  37:20  17   26
# 1  2008-02-08  23-255  DEN      HOME      WAS  W (+11)   1  39:13  19   25
# 0  2015-04-10  26-245  DEN      HOME      DAL   L (-1)   1  45:46  15   23
# 0  2014-04-11  28-037  MIN      HOME      HOU   W (+2)   1  44:53  19   30
# 0  2011-02-07  26-254  DEN      HOME      HOU   L (-5)   1  39:28  16   24
# ...
