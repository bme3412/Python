# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_DET = []

# DET
while season <= 2021:
    df_DET = get_roster('DET', season)
    df_DET['Season'] = season
    df_DET['Team'] = 'DET'
    appended_data_DET.append(df_DET)
    season = season + 1
appended_data_DET = pd.concat(appended_data_DET)

# %%
DET_df_all = appended_data_DET.copy()
DET_df_all_csv = DET_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_players_all.csv', index=False)
DET_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_players_all.csv')
DET_df_all_csv_io.head()
# Out:
#   NUMBER         PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0     20   Marcus Brown  SG    6-3     185  1974-04-03          US          1
# 1     30   Jud Buechler  SF    6-6     220  1968-06-19          US          9
# 2     22    John Crotty  PG    6-1     185  1969-07-15          US          7
# 3     12  Michael Curry  SG    6-5     210  1968-08-22          US          5
# 4     33     Grant Hill  SF    6-8     225  1972-10-05          US          5
#
#                        COLLEGE  Season Team
# 0                 Murray State    2000  DET
# 1                      Arizona    2000  DET
# 2                     Virginia    2000  DET
# 3  Georgia Southern University    2000  DET
# 4                         Duke    2000  DET

# %%
DET_df_2000 = DET_df_all[DET_df_all['Season'] == 2000]
DET_df_2001 = DET_df_all[DET_df_all['Season'] == 2001]
DET_df_2002 = DET_df_all[DET_df_all['Season'] == 2002]
DET_df_2003 = DET_df_all[DET_df_all['Season'] == 2003]
DET_df_2004 = DET_df_all[DET_df_all['Season'] == 2004]
DET_df_2005 = DET_df_all[DET_df_all['Season'] == 2005]
DET_df_2006 = DET_df_all[DET_df_all['Season'] == 2006]
DET_df_2007 = DET_df_all[DET_df_all['Season'] == 2007]
DET_df_2008 = DET_df_all[DET_df_all['Season'] == 2008]
DET_df_2009 = DET_df_all[DET_df_all['Season'] == 2009]
DET_df_2010 = DET_df_all[DET_df_all['Season'] == 2010]
DET_df_2011 = DET_df_all[DET_df_all['Season'] == 2011]
DET_df_2012 = DET_df_all[DET_df_all['Season'] == 2012]
DET_df_2013 = DET_df_all[DET_df_all['Season'] == 2013]
DET_df_2014 = DET_df_all[DET_df_all['Season'] == 2014]
DET_df_2015 = DET_df_all[DET_df_all['Season'] == 2015]
DET_df_2016 = DET_df_all[DET_df_all['Season'] == 2016]
DET_df_2017 = DET_df_all[DET_df_all['Season'] == 2017]
DET_df_2018 = DET_df_all[DET_df_all['Season'] == 2018]
DET_df_2019 = DET_df_all[DET_df_all['Season'] == 2019]
DET_df_2020 = DET_df_all[DET_df_all['Season'] == 2020]
DET_df_2021 = DET_df_all[DET_df_all['Season'] == 2021]

# %%
# changing names
#DET_df_2003.loc[DET_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#DET_df_2004.loc[DET_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
DET_df_2000_players = DET_df_2000['PLAYER'].to_list()
DET_df_2001_players = DET_df_2001['PLAYER'].to_list()
DET_df_2002_players = DET_df_2002['PLAYER'].to_list()
DET_df_2003_players = DET_df_2003['PLAYER'].to_list()
DET_df_2004_players = DET_df_2004['PLAYER'].to_list()
DET_df_2005_players = DET_df_2005['PLAYER'].to_list()

DET_df_2006_players = DET_df_2006['PLAYER'].to_list()
DET_df_2007_players = DET_df_2007['PLAYER'].to_list()
DET_df_2008_players = DET_df_2008['PLAYER'].to_list()
DET_df_2009_players = DET_df_2009['PLAYER'].to_list()
DET_df_2010_players = DET_df_2010['PLAYER'].to_list()
DET_df_2011_players = DET_df_2011['PLAYER'].to_list()

DET_df_2012_players = DET_df_2012['PLAYER'].to_list()
DET_df_2013_players = DET_df_2013['PLAYER'].to_list()
DET_df_2014_players = DET_df_2014['PLAYER'].to_list()
DET_df_2015_players = DET_df_2015['PLAYER'].to_list()
DET_df_2016_players = DET_df_2016['PLAYER'].to_list()
DET_df_2017_players = DET_df_2017['PLAYER'].to_list()

DET_df_2018_players = DET_df_2018['PLAYER'].to_list()
DET_df_2019_players = DET_df_2019['PLAYER'].to_list()
DET_df_2020_players = DET_df_2020['PLAYER'].to_list()
DET_df_2021_players = DET_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
# 2003 - Nene Hiulario
#DET_df_2015_players.remove("Luigi Datome")
#DET_df_2014_players.remove("Luigi Datome")
#DET_df_2019_players.remove("Glenn Robinson")
#DET_df_2021_players.remove("Dennis Smith")
DET_df_2012_players.remove("Walker Russell")

# %%
DET_2000_gamelog = []



for p in DET_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2000_gamelog.append(player_log)
DET_2000_gamelog = pd.concat(DET_2000_gamelog)    
DET_2000_gamelogs = DET_2000_gamelog.copy()
DET_2000_gamelogs['GAME_SCORE'] = DET_2000_gamelogs['GAME_SCORE'].astype(float)
DET_2000_games = DET_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2000_games_csv = DET_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2000_games.csv', index=False)
DET_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2000_games.csv')
DET_2000_games_proc.head()
# Out:
# You searched for "Marcus Brown"
# 11 results found.
# 0: Marcus Brown
# 1: Markel Brown
# 2: Marcus Banks
# 3: Harold Brown
# 4: Larry Brown
# 5: Moses Brown
# 6: Myron Brown
# 7: Marcus Camby
# 8: Marcus Fizer
# 9: Marcus Smart
# 10: Marcus Webb
# Pick one: 0
# Results for Marcus Brown:
#
# You searched for "Jud Buechler"
# 1 result found.
# Jud Buechler
# Results for Jud Buechler:
#
# You searched for "John Crotty"
# 8 results found.
# 0: John Crotty
# 1: John Brown
# 2: John Chaney
# 3: John Coker
# 4: John Roche
# 5: John Morton
# 6: John Stroud
# 7: Johan Petro
# Pick one: 0
# Results for John Crotty:
#
# You searched for "Michael Curry"
# 7 results found.
# 0: Michael Curry
# 1: Michael Cage
# 2: Michael Wiley
# 3: Michael Cooper
# 4: Michael Porter
# 5: Michael Redd
# 6: Michael Young
# Pick one: 0
# Results for Michael Curry:
#
# You searched for "Grant Hill"
# 8 results found.
# 0: Grant Hill
# 1: Grant Riller
# 2: Gary Hill
# 3: Craig Dill
# 4: Armond Hill
# 5: Jordan Hill
# ...

# %%
DET_2001_gamelog = []


for p in DET_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2001_gamelog.append(player_log)
DET_2001_gamelog = pd.concat(DET_2001_gamelog)    
DET_2001_gamelogs = DET_2001_gamelog.copy()
DET_2001_gamelogs['GAME_SCORE'] = DET_2001_gamelogs['GAME_SCORE'].astype(float)
DET_2001_games = DET_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2001_games_csv = DET_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2001_games.csv', index=False)
DET_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2001_games.csv')
DET_2001_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Dana Barros"
# 3 results found.
# 0: Dana Barros
# 1: Earl Barron
# 2: Don Carlos
# Pick one: 0
# Results for Dana Barros:
#
# You searched for "Jud Buechler"
# 1 result found.
# Jud Buechler
# Results for Jud Buechler:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Cedric Ceballos"
# 2 results found.
# 0: Cedric Ceballos
# 1: Cedric Ball
# Pick one: 0
# Results for Cedric Ceballos:
#
# You searched for "Mateen Cleaves"
# 1 result found.
# Mateen Cleaves
# Results for Mateen Cleaves:
#
# You searched for "Michael Curry"
# 7 results found.
# 0: Michael Curry
# 1: Michael Cage
# 2: Michael Wiley
# 3: Michael Cooper
# 4: Michael Porter
# 5: Michael Redd
# 6: Michael Young
# Pick one: 0
# Results for Michael Curry:
#
# You searched for "Kornél Dávid"
# ...

# %%
DET_2002_gamelog = []


for p in DET_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2002_gamelog.append(player_log)
DET_2002_gamelog = pd.concat(DET_2002_gamelog)    
DET_2002_gamelogs = DET_2002_gamelog.copy()
DET_2002_gamelogs['GAME_SCORE'] = DET_2002_gamelogs['GAME_SCORE'].astype(float)
DET_2002_games = DET_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2002_games_csv = DET_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2002_games.csv', index=False)
DET_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2002_games.csv')
DET_2002_games_proc.head()
# Out:
# You searched for "Victor Alexander"
# 2 results found.
# 0: Victor Alexander
# 1: Cory Alexander
# Pick one: 0
# Results for Victor Alexander:
#
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Dana Barros"
# 3 results found.
# 0: Dana Barros
# 1: Earl Barron
# 2: Don Carlos
# Pick one: 0
# Results for Dana Barros:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# ...

# %%
DET_2003_gamelog = []



for p in DET_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2003_gamelog.append(player_log)
DET_2003_gamelog = pd.concat(DET_2003_gamelog)    
DET_2003_gamelogs = DET_2003_gamelog.copy()
DET_2003_gamelogs['GAME_SCORE'] = DET_2003_gamelogs['GAME_SCORE'].astype(float)
DET_2003_games = DET_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2003_games_csv = DET_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2003_games.csv', index=False)
DET_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2003_games.csv')
DET_2003_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Michael Curry"
# 7 results found.
# 0: Michael Curry
# 1: Michael Cage
# 2: Michael Wiley
# 3: Michael Cooper
# 4: Michael Porter
# 5: Michael Redd
# 6: Michael Young
# Pick one: 0
# ...

# %%
DET_2004_gamelog = []



for p in DET_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2004_gamelog.append(player_log)
DET_2004_gamelog = pd.concat(DET_2004_gamelog)    
DET_2004_gamelogs = DET_2004_gamelog.copy()
DET_2004_gamelogs['GAME_SCORE'] = DET_2004_gamelogs['GAME_SCORE'].astype(float)
DET_2004_games = DET_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2004_games_csv = DET_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2004_games.csv', index=False)
DET_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2004_games.csv')
DET_2004_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Elden Campbell"
# 1 result found.
# Elden Campbell
# Results for Elden Campbell:
#
# You searched for "Hubert Davis"
# 5 results found.
# 0: Hubert Davis
# 1: Aubrey Davis
# 2: Ben Davis
# 3: Harry Davis
# 4: Tyler Davis
# Pick one: 0
# Results for Hubert Davis:
#
# You searched for "Tremaine Fowlkes"
# 1 result found.
# Tremaine Fowlkes
# Results for Tremaine Fowlkes:
#
# You searched for "Darvin Ham"
# 1 result found.
# Darvin Ham
# Results for Darvin Ham:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Lindsey Hunter"
# 2 results found.
# 0: Lindsey Hunter
# 1: Vince Hunter
# Pick one: 0
# Results for Lindsey Hunter:
#
# ...

# %%
DET_2005_gamelog = []

for p in DET_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2005_gamelog.append(player_log)
DET_2005_gamelog = pd.concat(DET_2005_gamelog)    
DET_2005_gamelogs = DET_2005_gamelog.copy()
DET_2005_gamelogs['GAME_SCORE'] = DET_2005_gamelogs['GAME_SCORE'].astype(float)
DET_2005_games = DET_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2005_games_csv = DET_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2005_games.csv', index=False)
DET_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2005_games.csv')
DET_2005_games_proc.head()
# Out:
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Elden Campbell"
# 1 result found.
# Elden Campbell
# Results for Elden Campbell:
#
# You searched for "Derrick Coleman"
# 2 results found.
# 0: Derrick Coleman
# 1: Norris Coleman
# Pick one: 0
# Results for Derrick Coleman:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Ronald Dupree"
# 2 results found.
# 0: Ronald Dupree
# 1: Ronald Murray
# Pick one: 0
# Results for Ronald Dupree:
#
# You searched for "Anthony Goldwire"
# 2 results found.
# 0: Anthony Goldwire
# 1: Anthony Bowie
# Pick one: 0
# Results for Anthony Goldwire:
#
# You searched for "Darvin Ham"
# 1 result found.
# Darvin Ham
# Results for Darvin Ham:
#
# ...

# %%
DET_2006_gamelog = []

for p in DET_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2006_gamelog.append(player_log)
DET_2006_gamelog = pd.concat(DET_2006_gamelog)    
DET_2006_gamelogs = DET_2006_gamelog.copy()
DET_2006_gamelogs['GAME_SCORE'] = DET_2006_gamelogs['GAME_SCORE'].astype(float)
DET_2006_games = DET_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2006_games_csv = DET_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2006_games.csv', index=False)
DET_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2006_games.csv')
DET_2006_games_proc.head()
# Out:
# You searched for "Alex Acker"
# 8 results found.
# 0: Alex Acker
# 1: Alex Kirk
# 2: Alex Len
# 3: Alex Scales
# 4: Al Tucker
# 5: Alex Garcia
# 6: Alex Groza
# 7: Al Cervi
# Pick one: 0
# Results for Alex Acker:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# ...

# %%
DET_2007_gamelog = []

for p in DET_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2007_gamelog.append(player_log)
DET_2007_gamelog = pd.concat(DET_2007_gamelog)    
DET_2007_gamelogs = DET_2007_gamelog.copy()
DET_2007_gamelogs['GAME_SCORE'] = DET_2007_gamelogs['GAME_SCORE'].astype(float)
DET_2007_games = DET_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2007_games_csv = DET_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2007_games.csv', index=False)
DET_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2007_games.csv')
DET_2007_games_proc.head()
# Out:
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Will Blalock"
# 1 result found.
# Will Blalock
# Results for Will Blalock:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# 19: Charles Davis
# 20: Charlie Davis
# 21: Ed Davis
# 22: Harry Davis
# 23: Jim Davis
# 24: Josh Davis
# 25: Red Davis
# 26: Ron Davis
# 27: Warren Davis
# 28: Willie Davis
# Pick one: 0
# Results for Dale Davis:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Ronald Dupree"
# 2 results found.
# 0: Ronald Dupree
# 1: Ronald Murray
# Pick one: 0
# ...

# %%
DET_2008_gamelog = []

for p in DET_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2008_gamelog.append(player_log)
DET_2008_gamelog = pd.concat(DET_2008_gamelog)    
DET_2008_gamelogs = DET_2008_gamelog.copy()
DET_2008_gamelogs['GAME_SCORE'] = DET_2008_gamelogs['GAME_SCORE'].astype(float)
DET_2008_games = DET_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2008_games_csv = DET_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2008_games.csv', index=False)
DET_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2008_games.csv')
DET_2008_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "Ronald Dupree"
# 2 results found.
# 0: Ronald Dupree
# 1: Ronald Murray
# Pick one: 0
# Results for Ronald Dupree:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Jarvis Hayes"
# 4 results found.
# 0: Jarvis Hayes
# 1: Elvin Hayes
# 2: Jaxson Hayes
# 3: Jim Hayes
# Pick one: 0
# Results for Jarvis Hayes:
#
# You searched for "Walter Herrmann"
# 1 result found.
# Walter Herrmann
# Results for Walter Herrmann:
#
# You searched for "Lindsey Hunter"
# ...

# %%
DET_2009_gamelog = []

for p in DET_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2009_gamelog.append(player_log)
DET_2009_gamelog = pd.concat(DET_2009_gamelog)    
DET_2009_gamelogs = DET_2009_gamelog.copy()
DET_2009_gamelogs['GAME_SCORE'] = DET_2009_gamelogs['GAME_SCORE'].astype(float)
DET_2009_games = DET_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2009_games_csv = DET_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2009_games.csv', index=False)
DET_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2009_games.csv')
DET_2009_games_proc.head()
# Out:
# You searched for "Alex Acker"
# 8 results found.
# 0: Alex Acker
# 1: Alex Kirk
# 2: Alex Len
# 3: Alex Scales
# 4: Al Tucker
# 5: Alex Garcia
# 6: Alex Groza
# 7: Al Cervi
# Pick one: 0
# Results for Alex Acker:
#
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Walter Herrmann"
# ...

# %%
DET_2010_gamelog = []

for p in DET_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2010_gamelog.append(player_log)
DET_2010_gamelog = pd.concat(DET_2010_gamelog)    
DET_2010_gamelogs = DET_2010_gamelog.copy()
DET_2010_gamelogs['GAME_SCORE'] = DET_2010_gamelogs['GAME_SCORE'].astype(float)
DET_2010_games = DET_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2010_games_csv = DET_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2010_games.csv', index=False)
DET_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2010_games.csv')
DET_2010_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# 6: Ed Horton
# 7: Ken Norman
# 8: Ben Moore
# Pick one: 0
# Results for Ben Gordon:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# ...

# %%
DET_2011_gamelog = []

for p in DET_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2011_gamelog.append(player_log)
DET_2011_gamelog = pd.concat(DET_2011_gamelog)    
DET_2011_gamelogs = DET_2011_gamelog.copy()
DET_2011_gamelogs['GAME_SCORE'] = DET_2011_gamelogs['GAME_SCORE'].astype(float)
DET_2011_games = DET_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2011_games_csv = DET_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2011_games.csv', index=False)
DET_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2011_games.csv')
DET_2011_games_proc.head()
# Out:
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# 6: Ed Horton
# 7: Ken Norman
# 8: Ben Moore
# Pick one: 0
# Results for Ben Gordon:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Jason Maxiell"
# 1 result found.
# Jason Maxiell
# Results for Jason Maxiell:
#
# You searched for "Tracy McGrady"
# 2 results found.
# 0: Tracy McGrady
# 1: Tracy Murray
# Pick one: 0
# Results for Tracy McGrady:
#
# You searched for "Greg Monroe"
# 7 results found.
# 0: Greg Monroe
# ...

# %%
# removed nene hilario
DET_2012_gamelog = []

for p in DET_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2012_gamelog.append(player_log)
DET_2012_gamelog = pd.concat(DET_2012_gamelog)    
DET_2012_gamelogs = DET_2012_gamelog.copy()
DET_2012_gamelogs['GAME_SCORE'] = DET_2012_gamelogs['GAME_SCORE'].astype(float)
DET_2012_games = DET_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2012_games_csv = DET_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2012_games.csv', index=False)
DET_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2012_games.csv')
DET_2012_games_proc.head()
# Out:
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# 6: Ed Horton
# 7: Ken Norman
# 8: Ben Moore
# Pick one: 0
# Results for Ben Gordon:
#
# You searched for "Jonas Jerebko"
# 1 result found.
# Jonas Jerebko
# Results for Jonas Jerebko:
#
# You searched for "Brandon Knight"
# 5 results found.
# 0: Brandon Knight
# 1: Brandin Knight
# 2: Brandan Wright
# 3: Brevin Knight
# 4: Ron Knight
# Pick one: 0
# Results for Brandon Knight:
#
# You searched for "Vernon Macklin"
# 2 results found.
# 0: Vernon Macklin
# 1: Vernon Maxwell
# Pick one: 0
# Results for Vernon Macklin:
#
# ...

# %%
DET_2013_gamelog = []

for p in DET_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2013_gamelog.append(player_log)
DET_2013_gamelog = pd.concat(DET_2013_gamelog)    
DET_2013_gamelogs = DET_2013_gamelog.copy()
DET_2013_gamelogs['GAME_SCORE'] = DET_2013_gamelogs['GAME_SCORE'].astype(float)
DET_2013_games = DET_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2013_games_csv = DET_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2013_games.csv', index=False)
DET_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2013_games.csv')
DET_2013_games_proc.head()
# Out:
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Kim English"
# 3 results found.
# 0: Kim English
# 1: A.J. English
# 2: Alex English
# Pick one: 0
# Results for Kim English:
#
# You searched for "Jonas Jerebko"
# 1 result found.
# Jonas Jerebko
# Results for Jonas Jerebko:
#
# You searched for "Brandon Knight"
# 5 results found.
# 0: Brandon Knight
# 1: Brandin Knight
# 2: Brandan Wright
# 3: Brevin Knight
# 4: Ron Knight
# Pick one: 0
# Results for Brandon Knight:
#
# You searched for "Viacheslav Kravtsov"
# ...

# %%
DET_2014_gamelog = []

for p in DET_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2014_gamelog.append(player_log)
DET_2014_gamelog = pd.concat(DET_2014_gamelog)    
DET_2014_gamelogs = DET_2014_gamelog.copy()
DET_2014_gamelogs['GAME_SCORE'] = DET_2014_gamelogs['GAME_SCORE'].astype(float)
DET_2014_games = DET_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2014_games_csv = DET_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2014_games.csv', index=False)
DET_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2014_games.csv')
DET_2014_games_proc.head()
# Out:
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Josh Harrellson"
# 1 result found.
# Josh Harrellson
# Results for Josh Harrellson:
#
# You searched for "Brandon Jennings"
# 1 result found.
# Brandon Jennings
# Results for Brandon Jennings:
#
# You searched for "Jonas Jerebko"
# 1 result found.
# Jonas Jerebko
# Results for Jonas Jerebko:
#
# You searched for "Tony Mitchell"
# 5 results found.
# 0: Tony Mitchell
# 1: Tony Mitchell
# 2: Todd Mitchell
# 3: Mike Mitchell
# 4: Sam Mitchell
# Pick one: 0
# Results for Tony Mitchell:
#
# ...

# %%
# remove luigi datome
DET_2015_gamelog = []

for p in DET_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2015_gamelog.append(player_log)
DET_2015_gamelog = pd.concat(DET_2015_gamelog)    
DET_2015_gamelogs = DET_2015_gamelog.copy()
DET_2015_gamelogs['GAME_SCORE'] = DET_2015_gamelogs['GAME_SCORE'].astype(float)
DET_2015_games = DET_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2015_games_csv = DET_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2015_games.csv', index=False)
DET_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2015_games.csv')
DET_2015_games_proc.head()
# Out:
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Reggie Jackson"
# 6 results found.
# 0: Reggie Jackson
# 1: Reggie Hanson
# 2: Reggie Johnson
# 3: Cedric Jackson
# 4: Greg Jackson
# 5: Mervin Jackson
# Pick one: 0
# Results for Reggie Jackson:
#
# ...

# %%
DET_2016_gamelog = []

for p in DET_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2016_gamelog.append(player_log)
DET_2016_gamelog = pd.concat(DET_2016_gamelog)    
DET_2016_gamelogs = DET_2016_gamelog.copy()
DET_2016_gamelogs['GAME_SCORE'] = DET_2016_gamelogs['GAME_SCORE'].astype(float)
DET_2016_games = DET_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2016_games_csv = DET_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2016_games.csv', index=False)
DET_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2016_games.csv')
DET_2016_games_proc.head()
# Out:
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# ...

# %%
DET_2017_gamelog = []

for p in DET_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2017_gamelog.append(player_log)
DET_2017_gamelog = pd.concat(DET_2017_gamelog)    
DET_2017_gamelogs = DET_2017_gamelog.copy()
DET_2017_gamelogs['GAME_SCORE'] = DET_2017_gamelogs['GAME_SCORE'].astype(float)
DET_2017_games = DET_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2017_games_csv = DET_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2017_games.csv', index=False)
DET_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2017_games.csv')
DET_2017_games_proc.head()
# Out:
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# You searched for "Michael Gbinije"
# 2 results found.
# 0: Michael Gbinije
# 1: Michael Finley
# Pick one: 0
# Results for Michael Gbinije:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# 2: Bob Harris
# 3: Chris Harris
# 4: Tony Harris
# 5: Bob Harrison
# Pick one: 0
# ...

# %%
DET_2018_gamelog = []

for p in DET_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2018_gamelog.append(player_log)
DET_2018_gamelog = pd.concat(DET_2018_gamelog)    
DET_2018_gamelogs = DET_2018_gamelog.copy()
DET_2018_gamelogs['GAME_SCORE'] = DET_2018_gamelogs['GAME_SCORE'].astype(float)
DET_2018_games = DET_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2018_games_csv = DET_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2018_games.csv', index=False)
DET_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2018_games.csv')
DET_2018_games_proc.head()
# Out:
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Dwight Buycks"
# 1 result found.
# Dwight Buycks
# Results for Dwight Buycks:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# 2: Jamel Artis
# 3: Tyler Ennis
# 4: James Lang
# 5: James Silas
# 6: James Posey
# 7: James White
# 8: James Young
# 9: James Harden
# 10: James Phelan
# Pick one: 0
# Results for James Ennis:
#
# You searched for "Kay Felder"
# 6 results found.
# 0: Kay Felder
# 1: Ray Felix
# 2: Gary Keller
# 3: Ken Keller
# 4: Jay Miller
# ...

# %%
# removed glenn robinson

DET_2019_gamelog = []

for p in DET_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2019_gamelog.append(player_log)
DET_2019_gamelog = pd.concat(DET_2019_gamelog)    
DET_2019_gamelogs = DET_2019_gamelog.copy()
DET_2019_gamelogs['GAME_SCORE'] = DET_2019_gamelogs['GAME_SCORE'].astype(float)
DET_2019_games = DET_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2019_games_csv = DET_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2019_games.csv', index=False)
DET_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2019_games.csv')
DET_2019_games_proc.head()
# Out:
# You searched for "Bruce Brown"
# 16 results found.
# 0: Bruce Brown
# 1: Bruce Bowen
# 2: Andre Brown
# 3: Bob Brown
# 4: Bobby Brown
# 5: Chucky Brown
# 6: Dee Brown
# 7: Dee Brown
# 8: Fred Brown
# 9: Kwame Brown
# 10: Mike Brown
# 11: Rickey Brown
# 12: Roger Brown
# 13: Roger Brown
# 14: Troy Brown
# 15: Bryce Drew
# Pick one: 0
# Results for Bruce Brown:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Langston Galloway"
# 1 result found.
# Langston Galloway
# Results for Langston Galloway:
#
# ...

# %%
DET_2020_gamelog = []

for p in DET_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2020_gamelog.append(player_log)
DET_2020_gamelog = pd.concat(DET_2020_gamelog)    
DET_2020_gamelogs = DET_2020_gamelog.copy()
DET_2020_gamelogs['GAME_SCORE'] = DET_2020_gamelogs['GAME_SCORE'].astype(float)
DET_2020_games = DET_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2020_games_csv = DET_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2020_games.csv', index=False)
DET_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2020_games.csv')
DET_2020_games_proc.head()
# Out:
# You searched for "Jordan Bone"
# 10 results found.
# 0: Jordan Bone
# 1: Jordan Bowden
# 2: Jordan Ford
# 3: Jordan Bell
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Nwora
# 7: Jordan Hill
# 8: Jordan McRae
# 9: Ryan Bowen
# Pick one: 0
# Results for Jordan Bone:
#
# You searched for "Bruce Brown"
# 16 results found.
# 0: Bruce Brown
# 1: Bruce Bowen
# 2: Andre Brown
# 3: Bob Brown
# 4: Bobby Brown
# 5: Chucky Brown
# 6: Dee Brown
# 7: Dee Brown
# 8: Fred Brown
# 9: Kwame Brown
# 10: Mike Brown
# 11: Rickey Brown
# 12: Roger Brown
# 13: Roger Brown
# 14: Troy Brown
# 15: Bryce Drew
# Pick one: 0
# Results for Bruce Brown:
#
# You searched for "Sekou Doumbouya"
# 1 result found.
# Sekou Doumbouya
# Results for Sekou Doumbouya:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Tim Frazier"
# 4 results found.
# 0: Tim Frazier
# 1: Will Frazier
# 2: Jim Farmer
# 3: Walt Frazier
# Pick one: 0
# ...

# %%
DET_2021_gamelog = []

for p in DET_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    DET_2021_gamelog.append(player_log)
DET_2021_gamelog = pd.concat(DET_2021_gamelog)    
DET_2021_gamelogs = DET_2021_gamelog.copy()
DET_2021_gamelogs['GAME_SCORE'] = DET_2021_gamelogs['GAME_SCORE'].astype(float)
DET_2021_games = DET_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
DET_2021_games_csv = DET_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2021_games.csv', index=False)
DET_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2021_games.csv')
DET_2021_games_proc.head()
# Out:
# You searched for "Saddiq Bey"
# 1 result found.
# Saddiq Bey
# Results for Saddiq Bey:
#
# You searched for "Tyler Cook"
# 8 results found.
# 0: Tyler Cook
# 1: Tyler Bey
# 2: Bert Cook
# 3: Omar Cook
# 4: Tyler Lydon
# 5: Tyler Ulis
# 6: Joe Cooke
# 7: Tyler Herro
# Pick one: 0
# Results for Tyler Cook:
#
# You searched for "Hamidou Diallo"
# 1 result found.
# Hamidou Diallo
# Results for Hamidou Diallo:
#
# You searched for "Sekou Doumbouya"
# 1 result found.
# Sekou Doumbouya
# Results for Sekou Doumbouya:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Jerami Grant"
# 4 results found.
# 0: Jerami Grant
# 1: Jerian Grant
# 2: Horace Grant
# 3: Travis Grant
# Pick one: 0
# Results for Jerami Grant:
#
# You searched for "Blake Griffin"
# 3 results found.
# 0: Blake Griffin
# 1: Eddie Griffin
# 2: Paul Griffin
# Pick one: 0
# Results for Blake Griffin:
#
# You searched for "Killian Hayes"
# ...

# %% [markdown]
# ## combine all seasons

# %%
DET_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2000_games.csv')
DET_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2001_games.csv')
DET_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2002_games.csv')
DET_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2003_games.csv')
DET_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2004_games.csv')
DET_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2005_games.csv')
DET_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2006_games.csv')
DET_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2007_games.csv')
DET_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2008_games.csv')
DET_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2009_games.csv')
DET_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2010_games.csv')
DET_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2011_games.csv')
DET_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2012_games.csv')
DET_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2013_games.csv')
DET_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2014_games.csv')
DET_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2015_games.csv')
DET_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2016_games.csv')
DET_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2017_games.csv')
DET_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2018_games.csv')
DET_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2019_games.csv')
DET_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2020_games.csv')
DET_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2021_games.csv')

# %%
DET_season_dfs = [DET_2000_games_io, DET_2001_games_io, DET_2002_games_io, DET_2003_games_io, DET_2004_games_io, DET_2005_games_io,
                 DET_2006_games_io, DET_2007_games_io, DET_2008_games_io, DET_2009_games_io, DET_2010_games_io, DET_2011_games_io,
                 DET_2012_games_io, DET_2013_games_io, DET_2014_games_io, DET_2015_games_io, DET_2016_games_io, DET_2017_games_io,
                 DET_2018_games_io, DET_2019_games_io, DET_2020_games_io, DET_2021_games_io]

# %%
DET_all = pd.concat(DET_season_dfs)
DET_all_sorted = DET_all.sort_values(by=['GAME_SCORE'], ascending=False)
DET_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2001-04-03  26-149  DET      AWAY      CHI  W (+27)   1  41:40  21   36
# 0  2019-04-05  30-020  DET      AWAY      OKC  L (-13)   1  34:35  11   20
# 1  2018-10-23  29-221  DET      HOME      PHI   W (+1)   1  44:02  20   35
# 0  2012-03-21  28-352  DET      AWAY      DEN   L (-1)   1  41:20  13   22
# 0  2000-01-05  27-092  DET      AWAY      ATL  W (+12)   1  42:47  14   23
# 0  2003-11-28  25-287  DET      HOME      CLE   W (+4)   1  38:45  15   23
# 2  2019-01-12  29-302  DET      AWAY      LAC   W (+5)   1  40:04  13   23
# 0  2019-10-23  26-074  DET      AWAY      IND   W (+9)   1  40:48  12   18
# 0  2006-01-03  29-100  DET      HOME      ORL   W (+9)   1  43:10   9   15
# 1  2006-03-28  29-184  DET      HOME      DAL   W (+7)   1  37:16   8   14
# 1  2000-01-15  27-102  DET      AWAY      WAS   W (+5)   1  38:34  15   20
# ...
