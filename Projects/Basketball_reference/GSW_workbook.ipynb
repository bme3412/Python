# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_GSW = []

# GSW
while season <= 2021:
    df_GSW = get_roster('GSW', season)
    df_GSW['Season'] = season
    df_GSW['Team'] = 'GSW'
    appended_data_GSW.append(df_GSW)
    season = season + 1
appended_data_GSW = pd.concat(appended_data_GSW)

# %%
GSW_df_all = appended_data_GSW.copy()
GSW_df_all_csv = GSW_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_players_all.csv', index=False)
GSW_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_players_all.csv')
GSW_df_all_csv_io.head()
# Out:
#   NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      2       Drew Barry  PG    6-5     191  1973-02-17          US
# 1     10  Mookie Blaylock  PG    6-0     180  1967-03-20          US
# 2     21     Jason Caffey  PF    6-8     255  1973-06-12          US
# 3     43       Chris Carr  SG    6-5     207  1974-03-12          US
# 4     35   Terry Cummings  PF    6-9     220  1961-03-15          US
#
#   EXPERIENCE                    COLLEGE  Season Team
# 0          2               Georgia Tech    2000  GSW
# 1         10  Midland College, Oklahoma    2000  GSW
# 2          4                    Alabama    2000  GSW
# 3          4          Southern Illinois    2000  GSW
# 4         17                     DePaul    2000  GSW

# %%
GSW_df_2000 = GSW_df_all[GSW_df_all['Season'] == 2000]
GSW_df_2001 = GSW_df_all[GSW_df_all['Season'] == 2001]
GSW_df_2002 = GSW_df_all[GSW_df_all['Season'] == 2002]
GSW_df_2003 = GSW_df_all[GSW_df_all['Season'] == 2003]
GSW_df_2004 = GSW_df_all[GSW_df_all['Season'] == 2004]
GSW_df_2005 = GSW_df_all[GSW_df_all['Season'] == 2005]
GSW_df_2006 = GSW_df_all[GSW_df_all['Season'] == 2006]
GSW_df_2007 = GSW_df_all[GSW_df_all['Season'] == 2007]
GSW_df_2008 = GSW_df_all[GSW_df_all['Season'] == 2008]
GSW_df_2009 = GSW_df_all[GSW_df_all['Season'] == 2009]
GSW_df_2010 = GSW_df_all[GSW_df_all['Season'] == 2010]
GSW_df_2011 = GSW_df_all[GSW_df_all['Season'] == 2011]
GSW_df_2012 = GSW_df_all[GSW_df_all['Season'] == 2012]
GSW_df_2013 = GSW_df_all[GSW_df_all['Season'] == 2013]
GSW_df_2014 = GSW_df_all[GSW_df_all['Season'] == 2014]
GSW_df_2015 = GSW_df_all[GSW_df_all['Season'] == 2015]
GSW_df_2016 = GSW_df_all[GSW_df_all['Season'] == 2016]
GSW_df_2017 = GSW_df_all[GSW_df_all['Season'] == 2017]
GSW_df_2018 = GSW_df_all[GSW_df_all['Season'] == 2018]
GSW_df_2019 = GSW_df_all[GSW_df_all['Season'] == 2019]
GSW_df_2020 = GSW_df_all[GSW_df_all['Season'] == 2020]
GSW_df_2021 = GSW_df_all[GSW_df_all['Season'] == 2021]

# %%
# changing names
#GSW_df_2002.loc[GSW_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#GSW_df_2004.loc[GSW_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
GSW_df_2000_players = GSW_df_2000['PLAYER'].to_list()
GSW_df_2001_players = GSW_df_2001['PLAYER'].to_list()
GSW_df_2002_players = GSW_df_2002['PLAYER'].to_list()
GSW_df_2003_players = GSW_df_2003['PLAYER'].to_list()
GSW_df_2004_players = GSW_df_2004['PLAYER'].to_list()
GSW_df_2005_players = GSW_df_2005['PLAYER'].to_list()

GSW_df_2006_players = GSW_df_2006['PLAYER'].to_list()
GSW_df_2007_players = GSW_df_2007['PLAYER'].to_list()
GSW_df_2008_players = GSW_df_2008['PLAYER'].to_list()
GSW_df_2009_players = GSW_df_2009['PLAYER'].to_list()
GSW_df_2010_players = GSW_df_2010['PLAYER'].to_list()
GSW_df_2011_players = GSW_df_2011['PLAYER'].to_list()

GSW_df_2012_players = GSW_df_2012['PLAYER'].to_list()
GSW_df_2013_players = GSW_df_2013['PLAYER'].to_list()
GSW_df_2014_players = GSW_df_2014['PLAYER'].to_list()
GSW_df_2015_players = GSW_df_2015['PLAYER'].to_list()
GSW_df_2016_players = GSW_df_2016['PLAYER'].to_list()
GSW_df_2017_players = GSW_df_2017['PLAYER'].to_list()

GSW_df_2018_players = GSW_df_2018['PLAYER'].to_list()
GSW_df_2019_players = GSW_df_2019['PLAYER'].to_list()
GSW_df_2020_players = GSW_df_2020['PLAYER'].to_list()
GSW_df_2021_players = GSW_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#GSW_df_2000_players.remove("Mark Davis")
#GSW_df_2002_players.remove("Cedric Henderson")
#GSW_df_2003_players.remove("Mike Dunleavy")
#GSW_df_2004_players.remove("Mike Dunleavy")
#GSW_df_2005_players.remove("Mike Dunleavy")
#GSW_df_2006_players.remove("Mike Dunleavy")
#GSW_df_2007_players.remove("Mike Dunleavy")
#GSW_df_2007_players.remove("Patrick O'Bryant")
#GSW_df_2008_players.remove("Didier Ilunga-Mbenga")
#GSW_df_2008_players.remove("Patrick O'Bryant")
#GSW_df_2011_players.remove("David Lee")
#GSW_df_2010_players.remove("Reggie Williams")
#GSW_df_2011_players.remove("Reggie Williams")
#GSW_df_2012_players.remove("David Lee")
#GSW_df_2013_players.remove("Dwayne Jones")
#GSW_df_2013_players.remove("David Lee")
#GSW_df_2014_players.remove("David Lee")
#GSW_df_2014_players.remove("Jermaine O'Neal")
#GSW_df_2015_players.remove("David Lee")
#GSW_df_2015_players.remove("James Michael McAdoo")
#GSW_df_2016_players.remove("James Michael McAdoo")
#GSW_df_2017_players.remove("James Michael McAdoo")
#GSW_df_2020_players.remove("Glenn Robinson")
#GSW_df_2020_players.remove("D'Angelo Russell")
#GSW_df_2021_players.remove("Kelly Oubre")
GSW_df_2021_players.remove("Gary Payton")

# %%
GSW_2000_gamelog = []



for p in GSW_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2000_gamelog.append(player_log)
GSW_2000_gamelog = pd.concat(GSW_2000_gamelog)    
GSW_2000_gamelogs = GSW_2000_gamelog.copy()
GSW_2000_gamelogs['GAME_SCORE'] = GSW_2000_gamelogs['GAME_SCORE'].astype(float)
GSW_2000_games = GSW_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2000_games_csv = GSW_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2000_games.csv', index=False)
GSW_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2000_games.csv')
GSW_2000_games_proc.head()
# Out:
# You searched for "Drew Barry"
# 5 results found.
# 0: Drew Barry
# 1: Brent Barry
# 2: Moe Barr
# 3: Jon Barry
# 4: Rick Barry
# Pick one: 0
# Results for Drew Barry:
#
# You searched for "Mookie Blaylock"
# 1 result found.
# Mookie Blaylock
# Results for Mookie Blaylock:
#
# You searched for "Jason Caffey"
# 2 results found.
# 0: Jason Caffey
# 1: Jason Sasser
# Pick one: 0
# Results for Jason Caffey:
#
# You searched for "Chris Carr"
# 21 results found.
# 0: Chris Carr
# 1: Chris Babb
# 2: Cory Carr
# 3: Chris Ford
# 4: Chris Garner
# 5: Chris Harris
# 6: Chris Paul
# 7: Chris Taft
# 8: Chris Bosh
# 9: Chris Herren
# 10: Chris Jent
# 11: Chris Kaman
# 12: Chris King
# 13: Chris McCray
# 14: Chris Mihm
# 15: Chris Morris
# 16: Chris Munk
# 17: Chris Porter
# 18: Chris Richard
# 19: Chris Welp
# 20: Chris Silva
# Pick one: 0
# Results for Chris Carr:
#
# You searched for "Terry Cummings"
# 1 result found.
# Terry Cummings
# Results for Terry Cummings:
#
# ...

# %%
GSW_2001_gamelog = []


for p in GSW_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2001_gamelog.append(player_log)
GSW_2001_gamelog = pd.concat(GSW_2001_gamelog)    
GSW_2001_gamelogs = GSW_2001_gamelog.copy()
GSW_2001_gamelogs['GAME_SCORE'] = GSW_2001_gamelogs['GAME_SCORE'].astype(float)
GSW_2001_games = GSW_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2001_games_csv = GSW_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2001_games.csv', index=False)
GSW_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2001_games.csv')
GSW_2001_games_proc.head()
# Out:
# You searched for "Mookie Blaylock"
# 1 result found.
# Mookie Blaylock
# Results for Mookie Blaylock:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Chucky Brown"
# 3 results found.
# 0: Chucky Brown
# 1: Bruce Brown
# 2: Rickey Brown
# Pick one: 0
# Results for Chucky Brown:
#
# You searched for "John Coker"
# 28 results found.
# 0: John Coker
# 1: Ron Baker
# 2: John Barber
# 3: John Barr
# 4: John Brisker
# 5: John Chaney
# 6: John Comeaux
# 7: Joe Cooke
# 8: Joe Cooper
# 9: John Crotty
# 10: John Drew
# 11: John Duren
# 12: John Hazen
# 13: John Hummer
# 14: Jon Leuer
# 15: John Logan
# 16: John Long
# 17: John Richter
# 18: John Roche
# 19: John Turner
# 20: John Block
# 21: John Brown
# 22: Johnny Cox
# 23: John Lucas
# 24: John Olive
# 25: John Pilch
# 26: John Pinone
# 27: John Rudd
# Pick one: 0
# Results for John Coker:
#
# You searched for "Vonteego Cummings"
# ...

# %%
GSW_2002_gamelog = []


for p in GSW_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2002_gamelog.append(player_log)
GSW_2002_gamelog = pd.concat(GSW_2002_gamelog)    
GSW_2002_gamelogs = GSW_2002_gamelog.copy()
GSW_2002_gamelogs['GAME_SCORE'] = GSW_2002_gamelogs['GAME_SCORE'].astype(float)
GSW_2002_games = GSW_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2002_games_csv = GSW_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2002_games.csv', index=False)
GSW_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2002_games.csv')
GSW_2002_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Mookie Blaylock"
# 1 result found.
# Mookie Blaylock
# Results for Mookie Blaylock:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Danny Fortson"
# 1 result found.
# Danny Fortson
# Results for Danny Fortson:
#
# You searched for "Adonal Foyle"
# 2 results found.
# 0: Adonal Foyle
# 1: Donald Royal
# Pick one: 0
# Results for Adonal Foyle:
#
# You searched for "Dean Garrett"
# 5 results found.
# 0: Dean Garrett
# 1: Diante Garrett
# 2: Dick Garrett
# 3: Ken Durrett
# 4: Kevin Garnett
# Pick one: 0
# Results for Dean Garrett:
#
# You searched for "Larry Hughes"
# 6 results found.
# 0: Larry Hughes
# 1: Larry Bunce
# 2: Larry Fogle
# 3: Larry Jones
# 4: Larry Sykes
# 5: Larry Wright
# Pick one: 0
# Results for Larry Hughes:
#
# ...

# %%
GSW_2003_gamelog = []



for p in GSW_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2003_gamelog.append(player_log)
GSW_2003_gamelog = pd.concat(GSW_2003_gamelog)    
GSW_2003_gamelogs = GSW_2003_gamelog.copy()
GSW_2003_gamelogs['GAME_SCORE'] = GSW_2003_gamelogs['GAME_SCORE'].astype(float)
GSW_2003_games = GSW_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2003_games_csv = GSW_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2003_games.csv', index=False)
GSW_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2003_games.csv')
GSW_2003_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Danny Fortson"
# 1 result found.
# Danny Fortson
# Results for Danny Fortson:
#
# You searched for "Adonal Foyle"
# 2 results found.
# 0: Adonal Foyle
# 1: Donald Royal
# Pick one: 0
# Results for Adonal Foyle:
#
# You searched for "A.J. Guyton"
# 1 result found.
# A.J. Guyton
# Results for A.J. Guyton:
#
# You searched for "Antawn Jamison"
# 1 result found.
# Antawn Jamison
# Results for Antawn Jamison:
#
# You searched for "Chris Mills"
# 19 results found.
# 0: Chris Mills
# 1: Chris Childs
# 2: Chris Mihm
# 3: Chris Mullin
# 4: Chris Silva
# 5: Chris King
# 6: Darius Miles
# 7: Terry Mills
# 8: Chris Morris
# 9: Chris Munk
# ...

# %%
GSW_2004_gamelog = []



for p in GSW_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2004_gamelog.append(player_log)
GSW_2004_gamelog = pd.concat(GSW_2004_gamelog)    
GSW_2004_gamelogs = GSW_2004_gamelog.copy()
GSW_2004_gamelogs['GAME_SCORE'] = GSW_2004_gamelogs['GAME_SCORE'].astype(float)
GSW_2004_games = GSW_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2004_games_csv = GSW_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2004_games.csv', index=False)
GSW_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2004_games.csv')
GSW_2004_games_proc.head()
# Out:
# You searched for "J.R. Bremer"
# 3 results found.
# 0: J.R. Bremer
# 1: Jim Brewer
# 2: J.R. Reid
# Pick one: 0
# Results for J.R. Bremer:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Erick Dampier"
# 2 results found.
# 0: Erick Dampier
# 1: Erik Daniels
# Pick one: 0
# Results for Erick Dampier:
#
# You searched for "Adonal Foyle"
# 2 results found.
# 0: Adonal Foyle
# 1: Donald Royal
# Pick one: 0
# Results for Adonal Foyle:
#
# You searched for "Avery Johnson"
# 27 results found.
# 0: Avery Johnson
# 1: Amir Johnson
# 2: Andy Johnson
# 3: Dave Johnson
# 4: Larry Johnson
# 5: Larry Johnson
# 6: Trey Johnson
# 7: Alize Johnson
# 8: Armon Johnson
# ...

# %%
GSW_2005_gamelog = []

for p in GSW_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2005_gamelog.append(player_log)
GSW_2005_gamelog = pd.concat(GSW_2005_gamelog)    
GSW_2005_gamelogs = GSW_2005_gamelog.copy()
GSW_2005_gamelogs['GAME_SCORE'] = GSW_2005_gamelogs['GAME_SCORE'].astype(float)
GSW_2005_games = GSW_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2005_games_csv = GSW_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2005_games.csv', index=False)
GSW_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2005_games.csv')
GSW_2005_games_proc.head()
# Out:
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Žarko Čabarkapa"
# 1 result found.
# Zarko Cabarkapa
# Results for Zarko Cabarkapa:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# 12: Bill Davis
# 13: Dale Davis
# 14: Glen Davis
# 15: Paul Davis
# 16: Ralph Davis
# 17: Red Davis
# 18: Terry Davis
# 19: Walt Davis
# 20: Byron Irvin
# 21: Aaron James
# Pick one: 0
# Results for Baron Davis:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# ...

# %%
GSW_2006_gamelog = []

for p in GSW_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2006_gamelog.append(player_log)
GSW_2006_gamelog = pd.concat(GSW_2006_gamelog)    
GSW_2006_gamelogs = GSW_2006_gamelog.copy()
GSW_2006_gamelogs['GAME_SCORE'] = GSW_2006_gamelogs['GAME_SCORE'].astype(float)
GSW_2006_games = GSW_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2006_games_csv = GSW_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2006_games.csv', index=False)
GSW_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2006_games.csv')
GSW_2006_games_proc.head()
# Out:
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Žarko Čabarkapa"
# 1 result found.
# Zarko Cabarkapa
# Results for Zarko Cabarkapa:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# 12: Bill Davis
# 13: Dale Davis
# 14: Glen Davis
# 15: Paul Davis
# 16: Ralph Davis
# 17: Red Davis
# 18: Terry Davis
# 19: Walt Davis
# 20: Byron Irvin
# 21: Aaron James
# Pick one: 0
# Results for Baron Davis:
#
# You searched for "Ike Diogu"
# 4 results found.
# 0: Ike Diogu
# ...

# %%
GSW_2007_gamelog = []

for p in GSW_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2007_gamelog.append(player_log)
GSW_2007_gamelog = pd.concat(GSW_2007_gamelog)    
GSW_2007_gamelogs = GSW_2007_gamelog.copy()
GSW_2007_gamelogs['GAME_SCORE'] = GSW_2007_gamelogs['GAME_SCORE'].astype(float)
GSW_2007_games = GSW_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2007_games_csv = GSW_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2007_games.csv', index=False)
GSW_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2007_games.csv')
GSW_2007_games_proc.head()
# Out:
# You searched for "Kelenna Azubuike"
# 1 result found.
# Kelenna Azubuike
# Results for Kelenna Azubuike:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# 12: Bill Davis
# 13: Dale Davis
# 14: Glen Davis
# 15: Paul Davis
# 16: Ralph Davis
# 17: Red Davis
# 18: Terry Davis
# 19: Walt Davis
# 20: Byron Irvin
# 21: Aaron James
# Pick one: 0
# Results for Baron Davis:
#
# You searched for "Ike Diogu"
# ...

# %%
GSW_2008_gamelog = []

for p in GSW_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2008_gamelog.append(player_log)
GSW_2008_gamelog = pd.concat(GSW_2008_gamelog)    
GSW_2008_gamelogs = GSW_2008_gamelog.copy()
GSW_2008_gamelogs['GAME_SCORE'] = GSW_2008_gamelogs['GAME_SCORE'].astype(float)
GSW_2008_games = GSW_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2008_games_csv = GSW_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2008_games.csv', index=False)
GSW_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2008_games.csv')
GSW_2008_games_proc.head()
# Out:
# You searched for "Kelenna Azubuike"
# 1 result found.
# Kelenna Azubuike
# Results for Kelenna Azubuike:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# 12: Bill Davis
# 13: Dale Davis
# ...

# %%
GSW_2009_gamelog = []

for p in GSW_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2009_gamelog.append(player_log)
GSW_2009_gamelog = pd.concat(GSW_2009_gamelog)    
GSW_2009_gamelogs = GSW_2009_gamelog.copy()
GSW_2009_gamelogs['GAME_SCORE'] = GSW_2009_gamelogs['GAME_SCORE'].astype(float)
GSW_2009_games = GSW_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2009_games_csv = GSW_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2009_games.csv', index=False)
GSW_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2009_games.csv')
GSW_2009_games_proc.head()
# Out:
# You searched for "Kelenna Azubuike"
# 1 result found.
# Kelenna Azubuike
# Results for Kelenna Azubuike:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Jermareo Davidson"
# 1 result found.
# Jermareo Davidson
# Results for Jermareo Davidson:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# 2: Bob Carrington
# 3: Al Hairston
# 4: Matt Harpring
# Pick one: 0
# Results for Al Harrington:
#
# You searched for "Stephen Jackson"
# ...

# %%
GSW_2010_gamelog = []

for p in GSW_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2010_gamelog.append(player_log)
GSW_2010_gamelog = pd.concat(GSW_2010_gamelog)    
GSW_2010_gamelogs = GSW_2010_gamelog.copy()
GSW_2010_gamelogs['GAME_SCORE'] = GSW_2010_gamelogs['GAME_SCORE'].astype(float)
GSW_2010_games = GSW_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2010_games_csv = GSW_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2010_games.csv', index=False)
GSW_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2010_games.csv')
GSW_2010_games_proc.head()
# Out:
# You searched for "Kelenna Azubuike"
# 1 result found.
# Kelenna Azubuike
# Results for Kelenna Azubuike:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Chris Hunter"
# 14 results found.
# 0: Chris Hunter
# 1: Cedric Hunter
# 2: Chris Porter
# 3: Chris Anstey
# 4: Chris Boucher
# 5: Chris Dudley
# 6: Chris Engler
# 7: Chris Garner
# 8: Chris Herren
# 9: Les Hunter
# ...

# %%
GSW_2011_gamelog = []

for p in GSW_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2011_gamelog.append(player_log)
GSW_2011_gamelog = pd.concat(GSW_2011_gamelog)    
GSW_2011_gamelogs = GSW_2011_gamelog.copy()
GSW_2011_gamelogs['GAME_SCORE'] = GSW_2011_gamelogs['GAME_SCORE'].astype(float)
GSW_2011_games = GSW_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2011_games_csv = GSW_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2011_games.csv', index=False)
GSW_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2011_games.csv')
GSW_2011_games_proc.head()
# Out:
# You searched for "Jeff Adrien"
# 10 results found.
# 0: Jeff Adrien
# 1: Jeff Ayres
# 2: Jeff Green
# 3: Jeff Martin
# 4: Jeff Turner
# 5: Jeff Grayer
# 6: Jeff Malone
# 7: Jeff Ruland
# 8: Jeff Sanders
# 9: Jeff Taylor
# Pick one: 0
# Results for Jeff Adrien:
#
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# ...

# %%
GSW_2012_gamelog = []

for p in GSW_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2012_gamelog.append(player_log)
GSW_2012_gamelog = pd.concat(GSW_2012_gamelog)    
GSW_2012_gamelogs = GSW_2012_gamelog.copy()
GSW_2012_gamelogs['GAME_SCORE'] = GSW_2012_gamelogs['GAME_SCORE'].astype(float)
GSW_2012_games = GSW_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2012_games_csv = GSW_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2012_games.csv', index=False)
GSW_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2012_games.csv')
GSW_2012_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Keith Benson"
# 8 results found.
# 0: Keith Benson
# 1: Kent Benson
# 2: Keith Herron
# 3: Keith Edmonson
# 4: Keith Owens
# 5: Keith Bogans
# 6: Keith Booth
# 7: Keith Askins
# Pick one: 0
# Results for Keith Benson:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# ...

# %%
GSW_2013_gamelog = []

for p in GSW_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2013_gamelog.append(player_log)
GSW_2013_gamelog = pd.concat(GSW_2013_gamelog)    
GSW_2013_gamelogs = GSW_2013_gamelog.copy()
GSW_2013_gamelogs['GAME_SCORE'] = GSW_2013_gamelogs['GAME_SCORE'].astype(float)
GSW_2013_games = GSW_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2013_games_csv = GSW_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2013_games.csv', index=False)
GSW_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2013_games.csv')
GSW_2013_games_proc.head()
# Out:
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Festus Ezeli"
# 1 result found.
# Festus Ezeli
# Results for Festus Ezeli:
#
# You searched for "Draymond Green"
# 2 results found.
# 0: Draymond Green
# 1: Raymond Brown
# Pick one: 0
# Results for Draymond Green:
#
# You searched for "Jarrett Jack"
# 1 result found.
# Jarrett Jack
# ...

# %%
GSW_2014_gamelog = []

for p in GSW_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2014_gamelog.append(player_log)
GSW_2014_gamelog = pd.concat(GSW_2014_gamelog)    
GSW_2014_gamelogs = GSW_2014_gamelog.copy()
GSW_2014_gamelogs['GAME_SCORE'] = GSW_2014_gamelogs['GAME_SCORE'].astype(float)
GSW_2014_games = GSW_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2014_games_csv = GSW_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2014_games.csv', index=False)
GSW_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2014_games.csv')
GSW_2014_games_proc.head()
# Out:
# You searched for "Hilton Armstrong"
# 1 result found.
# Hilton Armstrong
# Results for Hilton Armstrong:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "MarShon Brooks"
# 2 results found.
# 0: MarShon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for MarShon Brooks:
#
# You searched for "Jordan Crawford"
# ...

# %%
GSW_2015_gamelog = []

for p in GSW_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2015_gamelog.append(player_log)
GSW_2015_gamelog = pd.concat(GSW_2015_gamelog)    
GSW_2015_gamelogs = GSW_2015_gamelog.copy()
GSW_2015_gamelogs['GAME_SCORE'] = GSW_2015_gamelogs['GAME_SCORE'].astype(float)
GSW_2015_games = GSW_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2015_games_csv = GSW_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2015_games.csv', index=False)
GSW_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2015_games.csv')
GSW_2015_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Festus Ezeli"
# 1 result found.
# Festus Ezeli
# Results for Festus Ezeli:
#
# You searched for "Draymond Green"
# 2 results found.
# 0: Draymond Green
# 1: Raymond Brown
# Pick one: 0
# Results for Draymond Green:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# ...

# %%
GSW_2016_gamelog = []

for p in GSW_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2016_gamelog.append(player_log)
GSW_2016_gamelog = pd.concat(GSW_2016_gamelog)    
GSW_2016_gamelogs = GSW_2016_gamelog.copy()
GSW_2016_gamelogs['GAME_SCORE'] = GSW_2016_gamelogs['GAME_SCORE'].astype(float)
GSW_2016_games = GSW_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2016_games_csv = GSW_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2016_games.csv', index=False)
GSW_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2016_games.csv')
GSW_2016_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Ian Clark"
# 4 results found.
# 0: Ian Clark
# 1: Earl Clark
# 2: Gary Clark
# 3: Keon Clark
# Pick one: 0
# Results for Ian Clark:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Festus Ezeli"
# 1 result found.
# Festus Ezeli
# Results for Festus Ezeli:
#
# You searched for "Draymond Green"
# 2 results found.
# 0: Draymond Green
# 1: Raymond Brown
# Pick one: 0
# ...

# %%
GSW_2017_gamelog = []

for p in GSW_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2017_gamelog.append(player_log)
GSW_2017_gamelog = pd.concat(GSW_2017_gamelog)    
GSW_2017_gamelogs = GSW_2017_gamelog.copy()
GSW_2017_gamelogs['GAME_SCORE'] = GSW_2017_gamelogs['GAME_SCORE'].astype(float)
GSW_2017_games = GSW_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2017_games_csv = GSW_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2017_games.csv', index=False)
GSW_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2017_games.csv')
GSW_2017_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Ian Clark"
# 4 results found.
# 0: Ian Clark
# 1: Earl Clark
# 2: Gary Clark
# 3: Keon Clark
# Pick one: 0
# Results for Ian Clark:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Kevin Durant"
# 5 results found.
# 0: Kevin Durant
# 1: Devin Durrant
# 2: Kevin Murphy
# 3: Ken Durrett
# 4: Kevin Martin
# Pick one: 0
# Results for Kevin Durant:
#
# You searched for "Draymond Green"
# 2 results found.
# 0: Draymond Green
# 1: Raymond Brown
# Pick one: 0
# Results for Draymond Green:
#
# You searched for "Andre Iguodala"
# 1 result found.
# Andre Iguodala
# ...

# %%
GSW_2018_gamelog = []

for p in GSW_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2018_gamelog.append(player_log)
GSW_2018_gamelog = pd.concat(GSW_2018_gamelog)    
GSW_2018_gamelogs = GSW_2018_gamelog.copy()
GSW_2018_gamelogs['GAME_SCORE'] = GSW_2018_gamelogs['GAME_SCORE'].astype(float)
GSW_2018_games = GSW_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2018_games_csv = GSW_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2018_games.csv', index=False)
GSW_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2018_games.csv')
GSW_2018_games_proc.head()
# Out:
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Chris Boucher"
# 5 results found.
# 0: Chris Boucher
# 1: Chris Bosh
# 2: Chris Hunter
# 3: Chris Porter
# 4: Chris Herren
# Pick one: 0
# Results for Chris Boucher:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Quinn Cook"
# 3 results found.
# 0: Quinn Cook
# 1: Brian Cook
# 2: Quincy Acy
# Pick one: 0
# Results for Quinn Cook:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Kevin Durant"
# 5 results found.
# 0: Kevin Durant
# 1: Devin Durrant
# 2: Kevin Murphy
# 3: Ken Durrett
# 4: Kevin Martin
# ...

# %%
GSW_2019_gamelog = []

for p in GSW_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2019_gamelog.append(player_log)
GSW_2019_gamelog = pd.concat(GSW_2019_gamelog)    
GSW_2019_gamelogs = GSW_2019_gamelog.copy()
GSW_2019_gamelogs['GAME_SCORE'] = GSW_2019_gamelogs['GAME_SCORE'].astype(float)
GSW_2019_games = GSW_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2019_games_csv = GSW_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2019_games.csv', index=False)
GSW_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2019_games.csv')
GSW_2019_games_proc.head()
# Out:
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Quinn Cook"
# 3 results found.
# 0: Quinn Cook
# 1: Brian Cook
# 2: Quincy Acy
# Pick one: 0
# Results for Quinn Cook:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Marcus Derrickson"
# 1 result found.
# Marcus Derrickson
# Results for Marcus Derrickson:
#
# ...

# %%
GSW_2020_gamelog = []

for p in GSW_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2020_gamelog.append(player_log)
GSW_2020_gamelog = pd.concat(GSW_2020_gamelog)    
GSW_2020_gamelogs = GSW_2020_gamelog.copy()
GSW_2020_gamelogs['GAME_SCORE'] = GSW_2020_gamelogs['GAME_SCORE'].astype(float)
GSW_2020_games = GSW_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2020_games_csv = GSW_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2020_games.csv', index=False)
GSW_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2020_games.csv')
GSW_2020_games_proc.head()
# Out:
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Ky Bowman"
# 4 results found.
# 0: Ky Bowman
# 1: Ira Bowman
# 2: Nate Bowman
# 3: Ken Norman
# Pick one: 0
# Results for Ky Bowman:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Jacob Evans"
# 5 results found.
# 0: Jacob Evans
# 1: Bob Evans
# 2: Jawun Evans
# 3: Earl Evans
# 4: Jacob Wiley
# Pick one: 0
# Results for Jacob Evans:
#
# You searched for "Draymond Green"
# ...

# %%
GSW_2021_gamelog = []

for p in GSW_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    GSW_2021_gamelog.append(player_log)
GSW_2021_gamelog = pd.concat(GSW_2021_gamelog)    
GSW_2021_gamelogs = GSW_2021_gamelog.copy()
GSW_2021_gamelogs['GAME_SCORE'] = GSW_2021_gamelogs['GAME_SCORE'].astype(float)
GSW_2021_games = GSW_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_2021_games_csv = GSW_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2021_games.csv', index=False)
GSW_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2021_games.csv')
GSW_2021_games_proc.head()
# Out:
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#
# You searched for "Draymond Green"
# 2 results found.
# 0: Draymond Green
# 1: Raymond Brown
# Pick one: 0
# Results for Draymond Green:
#
# You searched for "Damion Lee"
# 9 results found.
# 0: Damion Lee
# 1: David Lee
# 2: David Lee
# 3: Saben Lee
# 4: Don Dee
# 5: Damion James
# 6: Dick Lee
# 7: Ron Lee
# 8: Davon Reed
# Pick one: 0
# Results for Damion Lee:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
GSW_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2000_games.csv')
GSW_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2001_games.csv')
GSW_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2002_games.csv')
GSW_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2003_games.csv')
GSW_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2004_games.csv')
GSW_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2005_games.csv')
GSW_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2006_games.csv')
GSW_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2007_games.csv')
GSW_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2008_games.csv')
GSW_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2009_games.csv')
GSW_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2010_games.csv')
GSW_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2011_games.csv')
GSW_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2012_games.csv')
GSW_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2013_games.csv')
GSW_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2014_games.csv')
GSW_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2015_games.csv')
GSW_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2016_games.csv')
GSW_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2017_games.csv')
GSW_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2018_games.csv')
GSW_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2019_games.csv')
GSW_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2020_games.csv')
GSW_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2021_games.csv')

# %%
GSW_season_dfs = [GSW_2000_games_io, GSW_2001_games_io, GSW_2002_games_io, GSW_2003_games_io, GSW_2004_games_io, GSW_2005_games_io,
                 GSW_2006_games_io, GSW_2007_games_io, GSW_2008_games_io, GSW_2009_games_io, GSW_2010_games_io, GSW_2011_games_io,
                 GSW_2012_games_io, GSW_2013_games_io, GSW_2014_games_io, GSW_2015_games_io, GSW_2016_games_io, GSW_2017_games_io,
                 GSW_2018_games_io, GSW_2019_games_io, GSW_2020_games_io, GSW_2021_games_io]

# %%
GSW_all = pd.concat(GSW_season_dfs)
GSW_all_sorted = GSW_all.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2015-10-31  27-231  GSW      AWAY      NOP  W (+14)   1  35:38  17   27
# 0  2021-01-03  32-295  GSW      HOME      POR  W (+15)   1  36:27  18   31
# 0  2016-12-05  26-301  GSW      HOME      IND  W (+36)   1  29:03  21   33
# 0  2013-02-27  24-350  GSW      AWAY      NYK   L (-4)   1  48:00  18   28
# 0  2000-12-06  24-177  GSW      HOME      LAL   W (+3)   1  53:00  21   29
# 1  2000-12-03  24-174  GSW      AWAY      SEA  L (-16)   1  48:00  23   36
# 0  2015-01-23  24-349  GSW      HOME      SAC  W (+25)   1  32:49  16   25
# 1  2021-02-06  32-329  GSW      AWAY      DAL   L (-2)   1  37:04  19   31
# 1  2016-02-25  27-348  GSW      AWAY      ORL  W (+16)   1  34:02  20   27
# 0  2018-01-27  29-319  GSW      HOME      BOS   W (+4)   1  36:48  16   24
# 0  2018-11-29  30-061  GSW      AWAY      TOR   L (-3)   1  42:56  18   31
# ...
