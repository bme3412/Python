# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_HOU = []

# HOU
while season <= 2021:
    df_HOU = get_roster('HOU', season)
    df_HOU['Season'] = season
    df_HOU['Team'] = 'HOU'
    appended_data_HOU.append(df_HOU)
    season = season + 1
appended_data_HOU = pd.concat(appended_data_HOU)

# %%
HOU_df_all = appended_data_HOU.copy()
HOU_df_all_csv = HOU_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_players_all.csv', index=False)
HOU_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_players_all.csv')
HOU_df_all_csv_io.head()
# Out:
#   NUMBER            PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     40  Shandon Anderson  SF    6-6     208  1973-12-31          US
# 1      4   Charles Barkley  PF    6-6     252  1963-02-20          US
# 2     50      Matt Bullard  PF   6-10     215  1967-06-05          US
# 3     13       Kelvin Cato   C   6-11     255  1974-08-26          US
# 4     15       Bill Curley  PF    6-9     220  1972-05-29          US
#
#   EXPERIENCE                                  COLLEGE  Season Team
# 0          3                                  Georgia    2000  HOU
# 1         15                                   Auburn    2000  HOU
# 2          8                           Colorado, Iowa    2000  HOU
# 3          2  University of South Alabama, Iowa State    2000  HOU
# 4          3                           Boston College    2000  HOU

# %%
HOU_df_2000 = HOU_df_all[HOU_df_all['Season'] == 2000]
HOU_df_2001 = HOU_df_all[HOU_df_all['Season'] == 2001]
HOU_df_2002 = HOU_df_all[HOU_df_all['Season'] == 2002]
HOU_df_2003 = HOU_df_all[HOU_df_all['Season'] == 2003]
HOU_df_2004 = HOU_df_all[HOU_df_all['Season'] == 2004]
HOU_df_2005 = HOU_df_all[HOU_df_all['Season'] == 2005]
HOU_df_2006 = HOU_df_all[HOU_df_all['Season'] == 2006]
HOU_df_2007 = HOU_df_all[HOU_df_all['Season'] == 2007]
HOU_df_2008 = HOU_df_all[HOU_df_all['Season'] == 2008]
HOU_df_2009 = HOU_df_all[HOU_df_all['Season'] == 2009]
HOU_df_2010 = HOU_df_all[HOU_df_all['Season'] == 2010]
HOU_df_2011 = HOU_df_all[HOU_df_all['Season'] == 2011]
HOU_df_2012 = HOU_df_all[HOU_df_all['Season'] == 2012]
HOU_df_2013 = HOU_df_all[HOU_df_all['Season'] == 2013]
HOU_df_2014 = HOU_df_all[HOU_df_all['Season'] == 2014]
HOU_df_2015 = HOU_df_all[HOU_df_all['Season'] == 2015]
HOU_df_2016 = HOU_df_all[HOU_df_all['Season'] == 2016]
HOU_df_2017 = HOU_df_all[HOU_df_all['Season'] == 2017]
HOU_df_2018 = HOU_df_all[HOU_df_all['Season'] == 2018]
HOU_df_2019 = HOU_df_all[HOU_df_all['Season'] == 2019]
HOU_df_2020 = HOU_df_all[HOU_df_all['Season'] == 2020]
HOU_df_2021 = HOU_df_all[HOU_df_all['Season'] == 2021]

# %%
# changing names
#HOU_df_2002.loc[HOU_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#HOU_df_2004.loc[HOU_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
HOU_df_2000_players = HOU_df_2000['PLAYER'].to_list()
HOU_df_2001_players = HOU_df_2001['PLAYER'].to_list()
HOU_df_2002_players = HOU_df_2002['PLAYER'].to_list()
HOU_df_2003_players = HOU_df_2003['PLAYER'].to_list()
HOU_df_2004_players = HOU_df_2004['PLAYER'].to_list()
HOU_df_2005_players = HOU_df_2005['PLAYER'].to_list()

HOU_df_2006_players = HOU_df_2006['PLAYER'].to_list()
HOU_df_2007_players = HOU_df_2007['PLAYER'].to_list()
HOU_df_2008_players = HOU_df_2008['PLAYER'].to_list()
HOU_df_2009_players = HOU_df_2009['PLAYER'].to_list()
HOU_df_2010_players = HOU_df_2010['PLAYER'].to_list()
HOU_df_2011_players = HOU_df_2011['PLAYER'].to_list()

HOU_df_2012_players = HOU_df_2012['PLAYER'].to_list()
HOU_df_2013_players = HOU_df_2013['PLAYER'].to_list()
HOU_df_2014_players = HOU_df_2014['PLAYER'].to_list()
HOU_df_2015_players = HOU_df_2015['PLAYER'].to_list()
HOU_df_2016_players = HOU_df_2016['PLAYER'].to_list()
HOU_df_2017_players = HOU_df_2017['PLAYER'].to_list()

HOU_df_2018_players = HOU_df_2018['PLAYER'].to_list()
HOU_df_2019_players = HOU_df_2019['PLAYER'].to_list()
HOU_df_2020_players = HOU_df_2020['PLAYER'].to_list()
HOU_df_2021_players = HOU_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#HOU_df_2000_players.remove("Mark Davis")
#HOU_df_2008_players.remove("Bobby Jones")
#HOU_df_2009_players.remove("Metta World Peace")
#HOU_df_2012_players.remove("Greg Smith")
#HOU_df_2013_players.remove("Greg Smith")
#HOU_df_2014_players.remove("Greg Smith")
#HOU_df_2015_players.remove("Clint Capela")
#HOU_df_2016_players.remove("Clint Capela")
#HOU_df_2017_players.remove("Clint Capela")
#HOU_df_2018_players.remove("Clint Capela")
#HOU_df_2019_players.remove("Clint Capela")
#HOU_df_2020_players.remove("Clint Capela")
#HOU_df_2021_players.remove("Clint Capela")
#HOU_df_2017_players.remove("Nenê Hilário")
#HOU_df_2018_players.remove("Nenê Hilário")
#HOU_df_2019_players.remove("Nenê Hilário")
#HOU_df_2021_players.remove("Armoni Brooks")
#HOU_df_2021_players.remove("Cameron Oliver")
#HOU_df_2021_players.remove("Kevin Porter")
HOU_df_2021_players.remove("Jae'Sean Tate")

# %%
HOU_2000_gamelog = []



for p in HOU_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2000_gamelog.append(player_log)
HOU_2000_gamelog = pd.concat(HOU_2000_gamelog)    
HOU_2000_gamelogs = HOU_2000_gamelog.copy()
HOU_2000_gamelogs['GAME_SCORE'] = HOU_2000_gamelogs['GAME_SCORE'].astype(float)
HOU_2000_games = HOU_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2000_games_csv = HOU_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2000_games.csv', index=False)
HOU_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2000_games.csv')
HOU_2000_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Charles Barkley"
# 7 results found.
# 0: Charles Barkley
# 1: Charles Oakley
# 2: Charles Beasley
# 3: Charles Bradley
# 4: Charles Dudley
# 5: Charles Parks
# 6: Charlie Parsley
# Pick one: 0
# Results for Charles Barkley:
#
# You searched for "Matt Bullard"
# 2 results found.
# 0: Matt Bullard
# 1: Matt Barnes
# Pick one: 0
# Results for Matt Bullard:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Bill Curley"
# 14 results found.
# 0: Bill Curley
# 1: Bill Turner
# 2: Bill Allen
# 3: Bill Bradley
# 4: Bill Bradley
# 5: Bill Crow
# 6: Dell Curry
# 7: Bill Downey
# 8: Bill Garner
# 9: Bill Keller
# 10: Bill Miller
# 11: Bill Closs
# 12: Bill McGill
# 13: Bill Meyer
# Pick one: 0
# Results for Bill Curley:
#
# ...

# %%
HOU_2001_gamelog = []


for p in HOU_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2001_gamelog.append(player_log)
HOU_2001_gamelog = pd.concat(HOU_2001_gamelog)    
HOU_2001_gamelogs = HOU_2001_gamelog.copy()
HOU_2001_gamelogs['GAME_SCORE'] = HOU_2001_gamelogs['GAME_SCORE'].astype(float)
HOU_2001_games = HOU_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2001_games_csv = HOU_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2001_games.csv', index=False)
HOU_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2001_games.csv')
HOU_2001_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Matt Bullard"
# 2 results found.
# 0: Matt Bullard
# 1: Matt Barnes
# Pick one: 0
# Results for Matt Bullard:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Jason Collier"
# 3 results found.
# 0: Jason Collier
# 1: Jason Collins
# 2: Jarron Collins
# Pick one: 0
# Results for Jason Collier:
#
# You searched for "Sean Colson"
# 3 results found.
# 0: Sean Colson
# 1: Dean Tolson
# 2: Sean Rooks
# Pick one: 0
# Results for Sean Colson:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# You searched for "Dan Langhi"
# 6 results found.
# 0: Dan Langhi
# 1: Dan King
# 2: James Lang
# 3: Grant Long
# 4: Shawn Long
# ...

# %%
HOU_2002_gamelog = []


for p in HOU_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2002_gamelog.append(player_log)
HOU_2002_gamelog = pd.concat(HOU_2002_gamelog)    
HOU_2002_gamelogs = HOU_2002_gamelog.copy()
HOU_2002_gamelogs['GAME_SCORE'] = HOU_2002_gamelogs['GAME_SCORE'].astype(float)
HOU_2002_games = HOU_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2002_games_csv = HOU_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2002_games.csv', index=False)
HOU_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2002_games.csv')
HOU_2002_games_proc.head()
# Out:
# You searched for "Tierre Brown"
# 8 results found.
# 0: Tierre Brown
# 1: Andre Brown
# 2: Dee Brown
# 3: Dee Brown
# 4: George Brown
# 5: Larry Brown
# 6: Mike Brown
# 7: Troy Brown
# Pick one: 0
# Results for Tierre Brown:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Jason Collier"
# 3 results found.
# 0: Jason Collier
# 1: Jason Collins
# 2: Jarron Collins
# Pick one: 0
# Results for Jason Collier:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# You searched for "Eddie Griffin"
# 3 results found.
# 0: Eddie Griffin
# 1: Adrian Griffin
# 2: Blake Griffin
# Pick one: 0
# Results for Eddie Griffin:
#
# You searched for "Dan Langhi"
# 6 results found.
# 0: Dan Langhi
# 1: Dan King
# 2: James Lang
# 3: Grant Long
# 4: Shawn Long
# ...

# %%
HOU_2003_gamelog = []



for p in HOU_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2003_gamelog.append(player_log)
HOU_2003_gamelog = pd.concat(HOU_2003_gamelog)    
HOU_2003_gamelogs = HOU_2003_gamelog.copy()
HOU_2003_gamelogs['GAME_SCORE'] = HOU_2003_gamelogs['GAME_SCORE'].astype(float)
HOU_2003_games = HOU_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2003_games_csv = HOU_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2003_games.csv', index=False)
HOU_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2003_games.csv')
HOU_2003_games_proc.head()
# Out:
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Jason Collier"
# 3 results found.
# 0: Jason Collier
# 1: Jason Collins
# 2: Jarron Collins
# Pick one: 0
# Results for Jason Collier:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# You searched for "Eddie Griffin"
# 3 results found.
# 0: Eddie Griffin
# 1: Adrian Griffin
# 2: Blake Griffin
# Pick one: 0
# Results for Eddie Griffin:
#
# You searched for "Juaquin Hawkins"
# 1 result found.
# Juaquin Hawkins
# Results for Juaquin Hawkins:
#
# You searched for "Tito Maddox"
# 2 results found.
# 0: Tito Maddox
# 1: Jack Maddox
# Pick one: 0
# Results for Tito Maddox:
#
# You searched for "Yao Ming"
# 6 results found.
# 0: Yao Ming
# 1: Dan King
# 2: Dave Bing
# 3: Jim King
# 4: Ron King
# 5: Tom King
# ...

# %%
HOU_2004_gamelog = []



for p in HOU_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2004_gamelog.append(player_log)
HOU_2004_gamelog = pd.concat(HOU_2004_gamelog)    
HOU_2004_gamelogs = HOU_2004_gamelog.copy()
HOU_2004_gamelogs['GAME_SCORE'] = HOU_2004_gamelogs['GAME_SCORE'].astype(float)
HOU_2004_games = HOU_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2004_games_csv = HOU_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2004_games.csv', index=False)
HOU_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2004_games.csv')
HOU_2004_games_proc.head()
# Out:
# You searched for "Torraye Braggs"
# 1 result found.
# Torraye Braggs
# Results for Torraye Braggs:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Alton Ford"
# 6 results found.
# 0: Alton Ford
# 1: Don Ford
# 2: Alphonso Ford
# 3: Bob Ford
# 4: Al Horford
# 5: Leon Wood
# Pick one: 0
# Results for Alton Ford:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# You searched for "Adrian Griffin"
# 2 results found.
# 0: Adrian Griffin
# 1: Eddie Griffin
# Pick one: 0
# Results for Adrian Griffin:
#
# You searched for "Jim Jackson"
# 21 results found.
# 0: Jim Jackson
# 1: Al Jackson
# 2: Josh Jackson
# 3: Mike Jackson
# 4: Phil Jackson
# 5: Jim Paxson
# 6: Jim Paxson
# 7: Greg Jackson
# 8: Jaren Jackson
# 9: Jaren Jackson
# 10: Justin Jackson
# ...

# %%
HOU_2005_gamelog = []

for p in HOU_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2005_gamelog.append(player_log)
HOU_2005_gamelog = pd.concat(HOU_2005_gamelog)    
HOU_2005_gamelogs = HOU_2005_gamelog.copy()
HOU_2005_gamelogs['GAME_SCORE'] = HOU_2005_gamelogs['GAME_SCORE'].astype(float)
HOU_2005_games = HOU_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2005_games_csv = HOU_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2005_games.csv', index=False)
HOU_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2005_games.csv')
HOU_2005_games_proc.head()
# Out:
# You searched for "Vin Baker"
# 8 results found.
# 0: Vin Baker
# 1: Ron Baker
# 2: Von Wafer
# 3: Norm Baker
# 4: Tom Barker
# 5: Devin Booker
# 6: Thon Maker
# 7: Zan Tabak
# Pick one: 0
# Results for Vin Baker:
#
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# ...

# %%
HOU_2006_gamelog = []

for p in HOU_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2006_gamelog.append(player_log)
HOU_2006_gamelog = pd.concat(HOU_2006_gamelog)    
HOU_2006_gamelogs = HOU_2006_gamelog.copy()
HOU_2006_gamelogs['GAME_SCORE'] = HOU_2006_gamelogs['GAME_SCORE'].astype(float)
HOU_2006_games = HOU_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2006_games_csv = HOU_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2006_games.csv', index=False)
HOU_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2006_games.csv')
HOU_2006_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# ...

# %%
HOU_2007_gamelog = []

for p in HOU_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2007_gamelog.append(player_log)
HOU_2007_gamelog = pd.concat(HOU_2007_gamelog)    
HOU_2007_gamelogs = HOU_2007_gamelog.copy()
HOU_2007_gamelogs['GAME_SCORE'] = HOU_2007_gamelogs['GAME_SCORE'].astype(float)
HOU_2007_games = HOU_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2007_games_csv = HOU_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2007_games.csv', index=False)
HOU_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2007_games.csv')
HOU_2007_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Chuck Hayes"
# 5 results found.
# 0: Chuck Hayes
# 1: Chuck Share
# 2: Chuck Lloyd
# 3: Chuck Noble
# 4: Chuck Terry
# Pick one: 0
# Results for Chuck Hayes:
#
# You searched for "Luther Head"
# 2 results found.
# 0: Luther Head
# 1: Luther Green
# Pick one: 0
# Results for Luther Head:
#
# You searched for "Juwan Howard"
# 4 results found.
# 0: Juwan Howard
# 1: Brian Howard
# 2: Josh Howard
# 3: Juwan Morgan
# Pick one: 0
# Results for Juwan Howard:
#
# You searched for "John Lucas III"
# 2 results found.
# 0: John Lucas III
# 1: John Lucas
# Pick one: 0
# Results for John Lucas III:
#
# You searched for "Tracy McGrady"
# 2 results found.
# 0: Tracy McGrady
# 1: Tracy Murray
# Pick one: 0
# Results for Tracy McGrady:
#
# You searched for "Yao Ming"
# 6 results found.
# ...

# %%
HOU_2008_gamelog = []

for p in HOU_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2008_gamelog.append(player_log)
HOU_2008_gamelog = pd.concat(HOU_2008_gamelog)    
HOU_2008_gamelogs = HOU_2008_gamelog.copy()
HOU_2008_gamelogs['GAME_SCORE'] = HOU_2008_gamelogs['GAME_SCORE'].astype(float)
HOU_2008_games = HOU_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2008_games_csv = HOU_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2008_games.csv', index=False)
HOU_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2008_games.csv')
HOU_2008_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# You searched for "Gerald Green"
# 6 results found.
# 0: Gerald Green
# 1: Gerald Brown
# 2: Gerald Govan
# 3: Gerald Glass
# 4: Erick Green
# 5: Sean Green
# Pick one: 0
# Results for Gerald Green:
#
# You searched for "Mike Harris"
# 26 results found.
# 0: Mike Harris
# 1: Mike Barr
# 2: Mike Davis
# 3: Mike Davis
# 4: Mike Harper
# 5: Joe Harris
# 6: Jalen Harris
# 7: Mike Barrett
# 8: Mike Farmer
# 9: Mike Hall
# 10: Art Harris
# 11: Billy Harris
# ...

# %%
HOU_2009_gamelog = []

for p in HOU_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2009_gamelog.append(player_log)
HOU_2009_gamelog = pd.concat(HOU_2009_gamelog)    
HOU_2009_gamelogs = HOU_2009_gamelog.copy()
HOU_2009_gamelogs['GAME_SCORE'] = HOU_2009_gamelogs['GAME_SCORE'].astype(float)
HOU_2009_games = HOU_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2009_games_csv = HOU_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2009_games.csv', index=False)
HOU_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2009_games.csv')
HOU_2009_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Brent Barry"
# 4 results found.
# 0: Brent Barry
# 1: Drew Barry
# 2: Jon Barry
# 3: Rick Barry
# Pick one: 0
# Results for Brent Barry:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Joey Dorsey"
# 4 results found.
# 0: Joey Dorsey
# 1: Jacky Dorsey
# 2: Ron Dorsey
# 3: Tyler Dorsey
# Pick one: 0
# Results for Joey Dorsey:
#
# You searched for "Chuck Hayes"
# ...

# %%
HOU_2010_gamelog = []

for p in HOU_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2010_gamelog.append(player_log)
HOU_2010_gamelog = pd.concat(HOU_2010_gamelog)    
HOU_2010_gamelogs = HOU_2010_gamelog.copy()
HOU_2010_gamelogs['GAME_SCORE'] = HOU_2010_gamelogs['GAME_SCORE'].astype(float)
HOU_2010_games = HOU_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2010_games_csv = HOU_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2010_games.csv', index=False)
HOU_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2010_games.csv')
HOU_2010_games_proc.head()
# Out:
# You searched for "David Andersen"
# 4 results found.
# 0: David Andersen
# 1: Chris Andersen
# 2: Dan Anderson
# 3: Dan Anderson
# Pick one: 0
# Results for David Andersen:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Hilton Armstrong"
# 1 result found.
# Hilton Armstrong
# Results for Hilton Armstrong:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Will Conroy"
# 6 results found.
# 0: Will Conroy
# 1: Will Cherry
# 2: Bill Crow
# 3: Bill Henry
# 4: Will Barton
# 5: Willie Long
# Pick one: 0
# Results for Will Conroy:
#
# ...

# %%
HOU_2011_gamelog = []

for p in HOU_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2011_gamelog.append(player_log)
HOU_2011_gamelog = pd.concat(HOU_2011_gamelog)    
HOU_2011_gamelogs = HOU_2011_gamelog.copy()
HOU_2011_gamelogs['GAME_SCORE'] = HOU_2011_gamelogs['GAME_SCORE'].astype(float)
HOU_2011_games = HOU_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2011_games_csv = HOU_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2011_games.csv', index=False)
HOU_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2011_games.csv')
HOU_2011_games_proc.head()
# Out:
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Mike Harris"
# 26 results found.
# 0: Mike Harris
# 1: Mike Barr
# 2: Mike Davis
# 3: Mike Davis
# 4: Mike Harper
# 5: Joe Harris
# 6: Jalen Harris
# 7: Mike Barrett
# 8: Mike Farmer
# 9: Mike Hall
# 10: Art Harris
# 11: Billy Harris
# 12: Bob Harris
# 13: Elias Harris
# 14: Gary Harris
# 15: Manny Harris
# 16: Steve Harris
# 17: Tony Harris
# ...

# %%
HOU_2012_gamelog = []

for p in HOU_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2012_gamelog.append(player_log)
HOU_2012_gamelog = pd.concat(HOU_2012_gamelog)    
HOU_2012_gamelogs = HOU_2012_gamelog.copy()
HOU_2012_gamelogs['GAME_SCORE'] = HOU_2012_gamelogs['GAME_SCORE'].astype(float)
HOU_2012_games = HOU_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2012_games_csv = HOU_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2012_games.csv', index=False)
HOU_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2012_games.csv')
HOU_2012_games_proc.head()
# Out:
# You searched for "Jeff Adrien"
# 10 results found.
# 0: Jeff Adrien
# 1: Jeff Ayres
# 2: Jeff Green
# 3: Jeff Martin
# 4: Jeff Turner
# 5: Jeff Grayer
# 6: Jeff Malone
# 7: Jeff Ruland
# 8: Jeff Sanders
# 9: Jeff Taylor
# Pick one: 0
# Results for Jeff Adrien:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Jonny Flynn"
# 4 results found.
# 0: Jonny Flynn
# 1: Danny Finn
# ...

# %%
HOU_2013_gamelog = []

for p in HOU_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2013_gamelog.append(player_log)
HOU_2013_gamelog = pd.concat(HOU_2013_gamelog)    
HOU_2013_gamelogs = HOU_2013_gamelog.copy()
HOU_2013_gamelogs['GAME_SCORE'] = HOU_2013_gamelogs['GAME_SCORE'].astype(float)
HOU_2013_games = HOU_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2013_games_csv = HOU_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2013_games.csv', index=False)
HOU_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2013_games.csv')
HOU_2013_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "Ömer Aşık"
# 2 results found.
# 0: Omer Asik
# 1: Omar Cook
# Pick one: 0
# Results for Omer Asik:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Daequan Cook"
# 2 results found.
# 0: Daequan Cook
# 1: Darwin Cook
# Pick one: 0
# Results for Daequan Cook:
#
# You searched for "Carlos Delfino"
# 1 result found.
# ...

# %%
HOU_2014_gamelog = []

for p in HOU_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2014_gamelog.append(player_log)
HOU_2014_gamelog = pd.concat(HOU_2014_gamelog)    
HOU_2014_gamelogs = HOU_2014_gamelog.copy()
HOU_2014_gamelogs['GAME_SCORE'] = HOU_2014_gamelogs['GAME_SCORE'].astype(float)
HOU_2014_games = HOU_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2014_games_csv = HOU_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2014_games.csv', index=False)
HOU_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2014_games.csv')
HOU_2014_games_proc.head()
# Out:
# You searched for "Ömer Aşık"
# 2 results found.
# 0: Omer Asik
# 1: Omar Cook
# Pick one: 0
# Results for Omer Asik:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# ...

# %%
# removed clint capella
HOU_2015_gamelog = []

for p in HOU_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2015_gamelog.append(player_log)
HOU_2015_gamelog = pd.concat(HOU_2015_gamelog)    
HOU_2015_gamelogs = HOU_2015_gamelog.copy()
HOU_2015_gamelogs['GAME_SCORE'] = HOU_2015_gamelogs['GAME_SCORE'].astype(float)
HOU_2015_games = HOU_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2015_games_csv = HOU_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2015_games.csv', index=False)
HOU_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2015_games.csv')
HOU_2015_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Tarik Black"
# 3 results found.
# 0: Tarik Black
# 1: Charlie Black
# 2: Tom Black
# Pick one: 0
# Results for Tarik Black:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# 2: Lloyd Daniels
# 3: Mel Daniels
# Pick one: 0
# Results for Troy Daniels:
#
# You searched for "Joey Dorsey"
# 4 results found.
# 0: Joey Dorsey
# 1: Jacky Dorsey
# 2: Ron Dorsey
# 3: Tyler Dorsey
# Pick one: 0
# Results for Joey Dorsey:
#
# You searched for "Francisco García"
# ...

# %%
# removed clint capella
HOU_2016_gamelog = []

for p in HOU_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2016_gamelog.append(player_log)
HOU_2016_gamelog = pd.concat(HOU_2016_gamelog)    
HOU_2016_gamelogs = HOU_2016_gamelog.copy()
HOU_2016_gamelogs['GAME_SCORE'] = HOU_2016_gamelogs['GAME_SCORE'].astype(float)
HOU_2016_games = HOU_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2016_games_csv = HOU_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2016_games.csv', index=False)
HOU_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2016_games.csv')
HOU_2016_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Sam Dekker"
# 1 result found.
# Sam Dekker
# Results for Sam Dekker:
#
# You searched for "Andrew Goudelock"
# 1 result found.
# Andrew Goudelock
# Results for Andrew Goudelock:
#
# You searched for "James Harden"
# 11 results found.
# 0: James Harden
# 1: James Hardy
# 2: James Bailey
# 3: Jimmy Darden
# 4: Jared Harper
# 5: James Edwards
# 6: James Lang
# 7: James Phelan
# 8: James Ennis
# ...

# %%
# removed clint capella
# removed nene hilario

HOU_2017_gamelog = []

for p in HOU_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2017_gamelog.append(player_log)
HOU_2017_gamelog = pd.concat(HOU_2017_gamelog)    
HOU_2017_gamelogs = HOU_2017_gamelog.copy()
HOU_2017_gamelogs['GAME_SCORE'] = HOU_2017_gamelogs['GAME_SCORE'].astype(float)
HOU_2017_games = HOU_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2017_games_csv = HOU_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2017_games.csv', index=False)
HOU_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2017_games.csv')
HOU_2017_games_proc.head()
# Out:
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Bobby Brown"
# 14 results found.
# 0: Bobby Brown
# 1: Bob Brown
# 2: Tony Brown
# 3: Bobby Croft
# 4: Bruce Brown
# 5: John Brown
# 6: Larry Brown
# 7: Moses Brown
# 8: Randy Brown
# 9: Roger Brown
# 10: Roger Brown
# 11: Troy Brown
# ...

# %%
# removed clint capella
# removed nene hilario

HOU_2018_gamelog = []

for p in HOU_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2018_gamelog.append(player_log)
HOU_2018_gamelog = pd.concat(HOU_2018_gamelog)    
HOU_2018_gamelogs = HOU_2018_gamelog.copy()
HOU_2018_gamelogs['GAME_SCORE'] = HOU_2018_gamelogs['GAME_SCORE'].astype(float)
HOU_2018_games = HOU_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2018_games_csv = HOU_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2018_games.csv', index=False)
HOU_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2018_games.csv')
HOU_2018_games_proc.head()
# Out:
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Tarik Black"
# 3 results found.
# 0: Tarik Black
# 1: Charlie Black
# 2: Tom Black
# Pick one: 0
# Results for Tarik Black:
#
# You searched for "Bobby Brown"
# 14 results found.
# 0: Bobby Brown
# 1: Bob Brown
# 2: Tony Brown
# 3: Bobby Croft
# 4: Bruce Brown
# 5: John Brown
# 6: Larry Brown
# 7: Moses Brown
# 8: Randy Brown
# 9: Roger Brown
# 10: Roger Brown
# 11: Troy Brown
# 12: Bobby Cook
# 13: Bobby Lloyd
# Pick one: 0
# Results for Bobby Brown:
#
# You searched for "Markel Brown"
# 14 results found.
# ...

# %%
# removed clint capella
# removed nene hilario

HOU_2019_gamelog = []

for p in HOU_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2019_gamelog.append(player_log)
HOU_2019_gamelog = pd.concat(HOU_2019_gamelog)    
HOU_2019_gamelogs = HOU_2019_gamelog.copy()
HOU_2019_gamelogs['GAME_SCORE'] = HOU_2019_gamelogs['GAME_SCORE'].astype(float)
HOU_2019_games = HOU_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2019_games_csv = HOU_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2019_games.csv', index=False)
HOU_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2019_games.csv')
HOU_2019_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Chris Chiozza"
# 2 results found.
# 0: Chris Chiozza
# 1: Chris Childs
# Pick one: 0
# Results for Chris Chiozza:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Gary Clark"
# 15 results found.
# 0: Gary Clark
# 1: Earl Clark
# 2: Ian Clark
# 3: Gary Alcorn
# 4: Cory Carr
# 5: Carlos Clark
# 6: Keon Clark
# 7: Coty Clarke
# 8: Gary Grant
# 9: Gary Gray
# 10: Gar Heard
# 11: Gary Neal
# 12: Jay Carty
# 13: Gary Keller
# 14: Gary Zeller
# Pick one: 0
# Results for Gary Clark:
#
# You searched for "Vince Edwards"
# 5 results found.
# 0: Vince Edwards
# 1: Bill Edwards
# 2: Blue Edwards
# 3: Kevin Edwards
# 4: Shane Edwards
# Pick one: 0
# ...

# %%
# removed clint capella

HOU_2020_gamelog = []

for p in HOU_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2020_gamelog.append(player_log)
HOU_2020_gamelog = pd.concat(HOU_2020_gamelog)    
HOU_2020_gamelogs = HOU_2020_gamelog.copy()
HOU_2020_gamelogs['GAME_SCORE'] = HOU_2020_gamelogs['GAME_SCORE'].astype(float)
HOU_2020_games = HOU_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2020_games_csv = HOU_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2020_games.csv', index=False)
HOU_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2020_games.csv')
HOU_2020_games_proc.head()
# Out:
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Gary Clark"
# 15 results found.
# 0: Gary Clark
# 1: Earl Clark
# 2: Ian Clark
# 3: Gary Alcorn
# 4: Cory Carr
# 5: Carlos Clark
# 6: Keon Clark
# 7: Coty Clarke
# 8: Gary Grant
# 9: Gary Gray
# 10: Gar Heard
# 11: Gary Neal
# 12: Jay Carty
# ...

# %%
# removed clint capella
# removed Armoni Brooks
HOU_2021_gamelog = []

for p in HOU_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    HOU_2021_gamelog.append(player_log)
HOU_2021_gamelog = pd.concat(HOU_2021_gamelog)    
HOU_2021_gamelogs = HOU_2021_gamelog.copy()
HOU_2021_gamelogs['GAME_SCORE'] = HOU_2021_gamelogs['GAME_SCORE'].astype(float)
HOU_2021_games = HOU_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_2021_games_csv = HOU_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2021_games.csv', index=False)
HOU_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2021_games.csv')
HOU_2021_games_proc.head()
# Out:
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Eric Gordon"
# 12 results found.
# 0: Eric Gordon
# 1: Drew Gordon
# 2: Eric Dawson
# 3: Aaron Gordon
# 4: Ben Gordon
# 5: Paul Gordon
# 6: Erick Green
# 7: Eric Johnson
# 8: Phil Jordon
# 9: Eric Murdock
# 10: Eric Maynor
# 11: Eric Money
# Pick one: 0
# Results for Eric Gordon:
#
# You searched for "James Harden"
# 11 results found.
# 0: James Harden
# ...

# %% [markdown]
# ## combine all seasons

# %%
HOU_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2000_games.csv')
HOU_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2001_games.csv')
HOU_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2002_games.csv')
HOU_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2003_games.csv')
HOU_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2004_games.csv')
HOU_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2005_games.csv')
HOU_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2006_games.csv')
HOU_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2007_games.csv')
HOU_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2008_games.csv')
HOU_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2009_games.csv')
HOU_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2010_games.csv')
HOU_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2011_games.csv')
HOU_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2012_games.csv')
HOU_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2013_games.csv')
HOU_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2014_games.csv')
HOU_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2015_games.csv')
HOU_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2016_games.csv')
HOU_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2017_games.csv')
HOU_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2018_games.csv')
HOU_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2019_games.csv')
HOU_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2020_games.csv')
HOU_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2021_games.csv')

# %%
HOU_season_dfs = [HOU_2000_games_io, HOU_2001_games_io, HOU_2002_games_io, HOU_2003_games_io, HOU_2004_games_io, HOU_2005_games_io,
                 HOU_2006_games_io, HOU_2007_games_io, HOU_2008_games_io, HOU_2009_games_io, HOU_2010_games_io, HOU_2011_games_io,
                 HOU_2012_games_io, HOU_2013_games_io, HOU_2014_games_io, HOU_2015_games_io, HOU_2016_games_io, HOU_2017_games_io,
                 HOU_2018_games_io, HOU_2019_games_io, HOU_2020_games_io, HOU_2021_games_io]

# %%
HOU_all = pd.concat(HOU_season_dfs)
HOU_all_sorted = HOU_all.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
# 0  2019-02-28  29-186  HOU      HOME      MIA   W (+3)   1  43:52  16   32
# 1  2020-07-31  30-340  HOU      AWAY      DAL   W (+4)   1  43:29  14   20
# 1  2017-11-05  28-071  HOU      HOME      UTA  W (+27)   1  35:15  19   25
# 0  2016-12-31  27-127  HOU      HOME      NYK   W (+7)   1  42:05  14   26
# 1  2019-01-23  29-150  HOU      AWAY      NYK   W (+4)   1  40:00  17   38
# 1  2017-01-27  27-154  HOU      AWAY      PHI   W (+5)   1  39:09  16   28
# 2  2019-10-30  30-065  HOU      AWAY      WAS   W (+1)   1  37:30  18   32
# 3  2019-12-13  30-109  HOU      AWAY      ORL  W (+23)   1  36:14  19   31
# 2  2019-03-22  29-208  HOU      HOME      SAS   W (+6)   1  36:40  19   34
# ...
