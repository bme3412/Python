# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_IND = []

# IND
while season <= 2021:
    df_IND = get_roster('IND', season)
    df_IND['Season'] = season
    df_IND['Team'] = 'IND'
    appended_data_IND.append(df_IND)
    season = season + 1
appended_data_IND = pd.concat(appended_data_IND)

# %%
IND_df_all = appended_data_IND.copy()
IND_df_all_csv = IND_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_players_all.csv', index=False)
IND_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_players_all.csv')
IND_df_all_csv_io.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      24  Jonathan Bender  SF   6-11     202  1981-01-30          US
# 1       4      Travis Best  PG   5-11     182  1972-07-12          US
# 2      44  Austin Croshere  PF    6-9     235  1975-05-01          US
# 3      32       Dale Davis   C   6-11     230  1969-03-25          US
# 4      10      Jeff Foster   C   6-11     236  1977-01-16          US
#
#   EXPERIENCE                 COLLEGE  Season Team
# 0          R                     NaN    2000  IND
# 1          4            Georgia Tech    2000  IND
# 2          2              Providence    2000  IND
# 3          8                 Clemson    2000  IND
# 4          R  Texas State University    2000  IND

# %%
IND_df_2000 = IND_df_all[IND_df_all['Season'] == 2000]
IND_df_2001 = IND_df_all[IND_df_all['Season'] == 2001]
IND_df_2002 = IND_df_all[IND_df_all['Season'] == 2002]
IND_df_2003 = IND_df_all[IND_df_all['Season'] == 2003]
IND_df_2004 = IND_df_all[IND_df_all['Season'] == 2004]
IND_df_2005 = IND_df_all[IND_df_all['Season'] == 2005]
IND_df_2006 = IND_df_all[IND_df_all['Season'] == 2006]
IND_df_2007 = IND_df_all[IND_df_all['Season'] == 2007]
IND_df_2008 = IND_df_all[IND_df_all['Season'] == 2008]
IND_df_2009 = IND_df_all[IND_df_all['Season'] == 2009]
IND_df_2010 = IND_df_all[IND_df_all['Season'] == 2010]
IND_df_2011 = IND_df_all[IND_df_all['Season'] == 2011]
IND_df_2012 = IND_df_all[IND_df_all['Season'] == 2012]
IND_df_2013 = IND_df_all[IND_df_all['Season'] == 2013]
IND_df_2014 = IND_df_all[IND_df_all['Season'] == 2014]
IND_df_2015 = IND_df_all[IND_df_all['Season'] == 2015]
IND_df_2016 = IND_df_all[IND_df_all['Season'] == 2016]
IND_df_2017 = IND_df_all[IND_df_all['Season'] == 2017]
IND_df_2018 = IND_df_all[IND_df_all['Season'] == 2018]
IND_df_2019 = IND_df_all[IND_df_all['Season'] == 2019]
IND_df_2020 = IND_df_all[IND_df_all['Season'] == 2020]
IND_df_2021 = IND_df_all[IND_df_all['Season'] == 2021]

# %%
IND_df_2001.head(12)
IND_df_2001 = IND_df_2001.replace("Jermaine O'Neal", "Jermaine O'Neal")

# %%
# changing names
#IND_df_2002.loc[IND_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#IND_df_2004.loc[IND_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
IND_df_2000_players = IND_df_2000['PLAYER'].to_list()
IND_df_2001_players = IND_df_2001['PLAYER'].to_list()
IND_df_2002_players = IND_df_2002['PLAYER'].to_list()
IND_df_2003_players = IND_df_2003['PLAYER'].to_list()
IND_df_2004_players = IND_df_2004['PLAYER'].to_list()
IND_df_2005_players = IND_df_2005['PLAYER'].to_list()

IND_df_2006_players = IND_df_2006['PLAYER'].to_list()
IND_df_2007_players = IND_df_2007['PLAYER'].to_list()
IND_df_2008_players = IND_df_2008['PLAYER'].to_list()
IND_df_2009_players = IND_df_2009['PLAYER'].to_list()
IND_df_2010_players = IND_df_2010['PLAYER'].to_list()
IND_df_2011_players = IND_df_2011['PLAYER'].to_list()

IND_df_2012_players = IND_df_2012['PLAYER'].to_list()
IND_df_2013_players = IND_df_2013['PLAYER'].to_list()
IND_df_2014_players = IND_df_2014['PLAYER'].to_list()
IND_df_2015_players = IND_df_2015['PLAYER'].to_list()
IND_df_2016_players = IND_df_2016['PLAYER'].to_list()
IND_df_2017_players = IND_df_2017['PLAYER'].to_list()

IND_df_2018_players = IND_df_2018['PLAYER'].to_list()
IND_df_2019_players = IND_df_2019['PLAYER'].to_list()
IND_df_2020_players = IND_df_2020['PLAYER'].to_list()
IND_df_2021_players = IND_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
# drop Jermaine O'Neal 2001-2008
# create new df for Jermaine O'Neal
#IND_df_2001_players.remove("Jermaine O'Neal")
#IND_df_2002_players.remove("Jermaine O'Neal")
#IND_df_2003_players.remove("Jermaine O'Neal")
#IND_df_2004_players.remove("Jermaine O'Neal")
#IND_df_2005_players.remove("Jermaine O'Neal")
#IND_df_2006_players.remove("Jermaine O'Neal")
#IND_df_2007_players.remove("Jermaine O'Neal")
#IND_df_2008_players.remove("Jermaine O'Neal")

#IND_df_2002_players.remove("Metta World Peace")
#IND_df_2003_players.remove("Metta World Peace")
#IND_df_2004_players.remove("Metta World Peace")
#IND_df_2005_players.remove("Metta World Peace")
#IND_df_2006_players.remove("Metta World Peace")

#IND_df_2007_players.remove("Mike Dunleavy")
#IND_df_2008_players.remove("Mike Dunleavy")
#IND_df_2009_players.remove("Mike Dunleavy")
#IND_df_2010_players.remove("Mike Dunleavy")
#IND_df_2011_players.remove("Mike Dunleavy")

#IND_df_2012_players.remove("Jeff Ayres")
#IND_df_2013_players.remove("Jeff Ayres")

#IND_df_2016_players.remove("Glenn Robinson")
#IND_df_2017_players.remove("Glenn Robinson")
#IND_df_2018_players.remove("Glenn Robinson")

#IND_df_2019_players.remove("Kyle O'Quinn")

IND_df_2021_players.remove("Amida Brimah")

# %%
IND_2000_gamelog = []



for p in IND_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2000_gamelog.append(player_log)
IND_2000_gamelog = pd.concat(IND_2000_gamelog)    
IND_2000_gamelogs = IND_2000_gamelog.copy()
IND_2000_gamelogs['GAME_SCORE'] = IND_2000_gamelogs['GAME_SCORE'].astype(float)
IND_2000_games = IND_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2000_games_csv = IND_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2000_games.csv', index=False)
IND_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2000_games.csv')
IND_2000_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# 19: Charles Davis
# 20: Charlie Davis
# 21: Ed Davis
# 22: Harry Davis
# 23: Jim Davis
# 24: Josh Davis
# 25: Red Davis
# 26: Ron Davis
# 27: Warren Davis
# ...

# %%
# removed jermaine o'neal
IND_2001_gamelog = []


for p in IND_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2001_gamelog.append(player_log)
IND_2001_gamelog = pd.concat(IND_2001_gamelog)    
IND_2001_gamelogs = IND_2001_gamelog.copy()
IND_2001_gamelogs['GAME_SCORE'] = IND_2001_gamelogs['GAME_SCORE'].astype(float)
IND_2001_games = IND_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2001_games_csv = IND_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2001_games.csv', index=False)
IND_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2001_games.csv')
IND_2001_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Tyus Edney"
# 2 results found.
# 0: Tyus Edney
# 1: Tyus Jones
# Pick one: 0
# Results for Tyus Edney:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# 2: Bob Carrington
# 3: Al Hairston
# 4: Matt Harpring
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
IND_2002_gamelog = []


for p in IND_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2002_gamelog.append(player_log)
IND_2002_gamelog = pd.concat(IND_2002_gamelog)    
IND_2002_gamelogs = IND_2002_gamelog.copy()
IND_2002_gamelogs['GAME_SCORE'] = IND_2002_gamelogs['GAME_SCORE'].astype(float)
IND_2002_games = IND_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2002_games_csv = IND_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2002_games.csv', index=False)
IND_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2002_games.csv')
IND_2002_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Jamison Brewer"
# 1 result found.
# Jamison Brewer
# Results for Jamison Brewer:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
IND_2003_gamelog = []



for p in IND_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2003_gamelog.append(player_log)
IND_2003_gamelog = pd.concat(IND_2003_gamelog)    
IND_2003_gamelogs = IND_2003_gamelog.copy()
IND_2003_gamelogs['GAME_SCORE'] = IND_2003_gamelogs['GAME_SCORE'].astype(float)
IND_2003_games = IND_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2003_games_csv = IND_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2003_games.csv', index=False)
IND_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2003_games.csv')
IND_2003_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Jamison Brewer"
# 1 result found.
# Jamison Brewer
# Results for Jamison Brewer:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Tim Hardaway"
# 2 results found.
# 0: Tim Hardaway
# 1: Tim Hardaway Jr.
# Pick one: 0
# Results for Tim Hardaway:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# 2: Bob Carrington
# 3: Al Hairston
# ...

# %%
# removed jermaine o'neal
# removed metta world peace

IND_2004_gamelog = []



for p in IND_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2004_gamelog.append(player_log)
IND_2004_gamelog = pd.concat(IND_2004_gamelog)    
IND_2004_gamelogs = IND_2004_gamelog.copy()
IND_2004_gamelogs['GAME_SCORE'] = IND_2004_gamelogs['GAME_SCORE'].astype(float)
IND_2004_games = IND_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2004_games_csv = IND_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2004_games.csv', index=False)
IND_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2004_games.csv')
IND_2004_games_proc.head()
# Out:
# You searched for "Kenny Anderson"
# 10 results found.
# 0: Kenny Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Eric Anderson
# 6: Kim Anderson
# 7: Kyle Anderson
# 8: Ron Anderson
# 9: Ryan Anderson
# Pick one: 0
# Results for Kenny Anderson:
#
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Jamison Brewer"
# 1 result found.
# Jamison Brewer
# Results for Jamison Brewer:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# ...

# %%
# removed jermaine o'neal
# removed metta world peace

IND_2005_gamelog = []

for p in IND_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2005_gamelog.append(player_log)
IND_2005_gamelog = pd.concat(IND_2005_gamelog)    
IND_2005_gamelogs = IND_2005_gamelog.copy()
IND_2005_gamelogs['GAME_SCORE'] = IND_2005_gamelogs['GAME_SCORE'].astype(float)
IND_2005_games = IND_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2005_games_csv = IND_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2005_games.csv', index=False)
IND_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2005_games.csv')
IND_2005_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Michael Curry"
# 7 results found.
# 0: Michael Curry
# 1: Michael Cage
# 2: Michael Wiley
# 3: Michael Cooper
# 4: Michael Porter
# 5: Michael Redd
# 6: Michael Young
# Pick one: 0
# Results for Michael Curry:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# 19: Charles Davis
# 20: Charlie Davis
# 21: Ed Davis
# 22: Harry Davis
# 23: Jim Davis
# 24: Josh Davis
# 25: Red Davis
# ...

# %%
# removed jermaine o'neal
# removed metta world peace

IND_2006_gamelog = []

for p in IND_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2006_gamelog.append(player_log)
IND_2006_gamelog = pd.concat(IND_2006_gamelog)    
IND_2006_gamelogs = IND_2006_gamelog.copy()
IND_2006_gamelogs['GAME_SCORE'] = IND_2006_gamelogs['GAME_SCORE'].astype(float)
IND_2006_games = IND_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2006_games_csv = IND_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2006_games.csv', index=False)
IND_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2006_games.csv')
IND_2006_games_proc.head()
# Out:
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Eddie Gill"
# 4 results found.
# 0: Eddie Gill
# 1: Eddie Miles
# 2: Eddie Miller
# 3: Eddie Mast
# Pick one: 0
# Results for Eddie Gill:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# 2: Danny Ainge
# 3: Danny Green
# 4: Danny Wagner
# Pick one: 0
# Results for Danny Granger:
#
# You searched for "David Harrison"
# 3 results found.
# 0: David Harrison
# 1: Devin Harris
# 2: Aaron Harrison
# Pick one: 0
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
# removed mike dunleavy

IND_2007_gamelog = []

for p in IND_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2007_gamelog.append(player_log)
IND_2007_gamelog = pd.concat(IND_2007_gamelog)    
IND_2007_gamelogs = IND_2007_gamelog.copy()
IND_2007_gamelogs['GAME_SCORE'] = IND_2007_gamelogs['GAME_SCORE'].astype(float)
IND_2007_games = IND_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2007_games_csv = IND_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2007_games.csv', index=False)
IND_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2007_games.csv')
IND_2007_games_proc.head()
# Out:
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Maceo Baston"
# 2 results found.
# 0: Maceo Baston
# 1: Dave Batton
# Pick one: 0
# Results for Maceo Baston:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Ike Diogu"
# 4 results found.
# 0: Ike Diogu
# 1: Ike Anigbogu
# 2: Mike Davis
# 3: Mike Davis
# Pick one: 0
# Results for Ike Diogu:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# 2: Danny Ainge
# 3: Danny Green
# 4: Danny Wagner
# Pick one: 0
# Results for Danny Granger:
#
# You searched for "Orien Greene"
# 6 results found.
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
# removed mike dunleavy

IND_2008_gamelog = []

for p in IND_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2008_gamelog.append(player_log)
IND_2008_gamelog = pd.concat(IND_2008_gamelog)    
IND_2008_gamelogs = IND_2008_gamelog.copy()
IND_2008_gamelogs['GAME_SCORE'] = IND_2008_gamelogs['GAME_SCORE'].astype(float)
IND_2008_games = IND_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2008_games_csv = IND_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2008_games.csv', index=False)
IND_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2008_games.csv')
IND_2008_games_proc.head()
# Out:
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Travis Diener"
# 4 results found.
# 0: Travis Diener
# 1: Travis Wear
# 2: Travis Hansen
# 3: Travis Leslie
# Pick one: 0
# Results for Travis Diener:
#
# You searched for "Ike Diogu"
# 4 results found.
# 0: Ike Diogu
# 1: Ike Anigbogu
# 2: Mike Davis
# 3: Mike Davis
# Pick one: 0
# Results for Ike Diogu:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Stephen Graham"
# 1 result found.
# Stephen Graham
# Results for Stephen Graham:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# 2: Danny Ainge
# 3: Danny Green
# 4: Danny Wagner
# Pick one: 0
# Results for Danny Granger:
#
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
# removed mike dunleavy
IND_2009_gamelog = []

for p in IND_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2009_gamelog.append(player_log)
IND_2009_gamelog = pd.concat(IND_2009_gamelog)    
IND_2009_gamelogs = IND_2009_gamelog.copy()
IND_2009_gamelogs['GAME_SCORE'] = IND_2009_gamelogs['GAME_SCORE'].astype(float)
IND_2009_games = IND_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2009_games_csv = IND_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2009_games.csv', index=False)
IND_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2009_games.csv')
IND_2009_games_proc.head()
# Out:
# You searched for "Maceo Baston"
# 2 results found.
# 0: Maceo Baston
# 1: Dave Batton
# Pick one: 0
# Results for Maceo Baston:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Travis Diener"
# 4 results found.
# 0: Travis Diener
# 1: Travis Wear
# 2: Travis Hansen
# 3: Travis Leslie
# Pick one: 0
# Results for Travis Diener:
#
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# 2: Don Ford
# 3: Jake Ford
# 4: Phil Ford
# 5: T.J. Leaf
# 6: O.J. Mayo
# Pick one: 0
# Results for T.J. Ford:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Stephen Graham"
# 1 result found.
# Stephen Graham
# Results for Stephen Graham:
#
# You searched for "Danny Granger"
# ...

# %%
# removed jermaine o'neal
# removed metta world peace
# removed mike dunleavy

IND_2010_gamelog = []

for p in IND_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2010_gamelog.append(player_log)
IND_2010_gamelog = pd.concat(IND_2010_gamelog)    
IND_2010_gamelogs = IND_2010_gamelog.copy()
IND_2010_gamelogs['GAME_SCORE'] = IND_2010_gamelogs['GAME_SCORE'].astype(float)
IND_2010_games = IND_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2010_games_csv = IND_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2010_games.csv', index=False)
IND_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2010_games.csv')
IND_2010_games_proc.head()
# Out:
# You searched for "Travis Diener"
# 4 results found.
# 0: Travis Diener
# 1: Travis Wear
# 2: Travis Hansen
# 3: Travis Leslie
# Pick one: 0
# Results for Travis Diener:
#
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# 2: Don Ford
# 3: Jake Ford
# 4: Phil Ford
# 5: T.J. Leaf
# 6: O.J. Mayo
# Pick one: 0
# Results for T.J. Ford:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# 2: Danny Ainge
# 3: Danny Green
# 4: Danny Wagner
# Pick one: 0
# Results for Danny Granger:
#
# You searched for "Tyler Hansbrough"
# 2 results found.
# 0: Tyler Hansbrough
# 1: Ben Hansbrough
# Pick one: 0
# Results for Tyler Hansbrough:
#
# You searched for "Luther Head"
# ...

# %%
# removed mike dunleavy
IND_2011_gamelog = []

for p in IND_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2011_gamelog.append(player_log)
IND_2011_gamelog = pd.concat(IND_2011_gamelog)    
IND_2011_gamelogs = IND_2011_gamelog.copy()
IND_2011_gamelogs['GAME_SCORE'] = IND_2011_gamelogs['GAME_SCORE'].astype(float)
IND_2011_games = IND_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2011_games_csv = IND_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2011_games.csv', index=False)
IND_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2011_games.csv')
IND_2011_games_proc.head()
# Out:
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# 2: Don Ford
# 3: Jake Ford
# 4: Phil Ford
# 5: T.J. Leaf
# 6: O.J. Mayo
# Pick one: 0
# Results for T.J. Ford:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# ...

# %%
IND_2012_gamelog = []

for p in IND_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2012_gamelog.append(player_log)
IND_2012_gamelog = pd.concat(IND_2012_gamelog)    
IND_2012_gamelogs = IND_2012_gamelog.copy()
IND_2012_gamelogs['GAME_SCORE'] = IND_2012_gamelogs['GAME_SCORE'].astype(float)
IND_2012_games = IND_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2012_games_csv = IND_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2012_games.csv', index=False)
IND_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2012_games.csv')
IND_2012_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "Kyrylo Fesenko"
# 1 result found.
# Kyrylo Fesenko
# Results for Kyrylo Fesenko:
#
# You searched for "Jeff Foster"
# 9 results found.
# 0: Jeff Foster
# 1: Jeff Foote
# 2: Jeff Webster
# 3: Fred Foster
# 4: Greg Foster
# 5: Jimmy Foster
# 6: Rod Foster
# 7: Jeff Grayer
# 8: Jeff Turner
# Pick one: 0
# Results for Jeff Foster:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# ...

# %%
IND_2013_gamelog = []

for p in IND_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2013_gamelog.append(player_log)
IND_2013_gamelog = pd.concat(IND_2013_gamelog)    
IND_2013_gamelogs = IND_2013_gamelog.copy()
IND_2013_gamelogs['GAME_SCORE'] = IND_2013_gamelogs['GAME_SCORE'].astype(float)
IND_2013_games = IND_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2013_games_csv = IND_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2013_games.csv', index=False)
IND_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2013_games.csv')
IND_2013_games_proc.head()
# Out:
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "Danny Granger"
# 5 results found.
# 0: Danny Granger
# 1: Danny Vranes
# 2: Danny Ainge
# 3: Danny Green
# 4: Danny Wagner
# Pick one: 0
# Results for Danny Granger:
#
# You searched for "Gerald Green"
# 6 results found.
# 0: Gerald Green
# 1: Gerald Brown
# 2: Gerald Govan
# 3: Gerald Glass
# 4: Erick Green
# 5: Sean Green
# Pick one: 0
# Results for Gerald Green:
#
# You searched for "Ben Hansbrough"
# 2 results found.
# 0: Ben Hansbrough
# 1: Tyler Hansbrough
# Pick one: 0
# Results for Ben Hansbrough:
#
# You searched for "Tyler Hansbrough"
# 2 results found.
# ...

# %%
IND_2014_gamelog = []

for p in IND_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2014_gamelog.append(player_log)
IND_2014_gamelog = pd.concat(IND_2014_gamelog)    
IND_2014_gamelogs = IND_2014_gamelog.copy()
IND_2014_gamelogs['GAME_SCORE'] = IND_2014_gamelogs['GAME_SCORE'].astype(float)
IND_2014_games = IND_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2014_games_csv = IND_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2014_games.csv', index=False)
IND_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2014_games.csv')
IND_2014_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Chris Copeland"
# 2 results found.
# 0: Chris Copeland
# 1: Hollis Copeland
# Pick one: 0
# Results for Chris Copeland:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "Danny Granger"
# 5 results found.
# ...

# %%
IND_2015_gamelog = []

for p in IND_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2015_gamelog.append(player_log)
IND_2015_gamelog = pd.concat(IND_2015_gamelog)    
IND_2015_gamelogs = IND_2015_gamelog.copy()
IND_2015_gamelogs['GAME_SCORE'] = IND_2015_gamelogs['GAME_SCORE'].astype(float)
IND_2015_games = IND_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2015_games_csv = IND_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2015_games.csv', index=False)
IND_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2015_games.csv')
IND_2015_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Chris Copeland"
# 2 results found.
# 0: Chris Copeland
# 1: Hollis Copeland
# Pick one: 0
# Results for Chris Copeland:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "Roy Hibbert"
# 2 results found.
# 0: Roy Hibbert
# 1: Ray Tolbert
# Pick one: 0
# Results for Roy Hibbert:
#
# You searched for "George Hill"
# 11 results found.
# 0: George Hill
# 1: George Karl
# 2: George King
# 3: George King
# 4: Gary Hill
# 5: George Lee
# 6: George Mikan
# 7: George Wilson
# 8: George Zidek
# 9: George Bucci
# ...

# %%
# removed glenn robinson (duplicate
IND_2016_gamelog = []

for p in IND_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2016_gamelog.append(player_log)
IND_2016_gamelog = pd.concat(IND_2016_gamelog)    
IND_2016_gamelogs = IND_2016_gamelog.copy()
IND_2016_gamelogs['GAME_SCORE'] = IND_2016_gamelogs['GAME_SCORE'].astype(float)
IND_2016_games = IND_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2016_games_csv = IND_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2016_games.csv', index=False)
IND_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2016_games.csv')
IND_2016_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Rakeem Christmas"
# 1 result found.
# Rakeem Christmas
# Results for Rakeem Christmas:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "George Hill"
# 11 results found.
# 0: George Hill
# 1: George Karl
# 2: George King
# 3: George King
# ...

# %%
# removed glenn robinson

IND_2017_gamelog = []

for p in IND_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2017_gamelog.append(player_log)
IND_2017_gamelog = pd.concat(IND_2017_gamelog)    
IND_2017_gamelogs = IND_2017_gamelog.copy()
IND_2017_gamelogs['GAME_SCORE'] = IND_2017_gamelogs['GAME_SCORE'].astype(float)
IND_2017_games = IND_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2017_games_csv = IND_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2017_games.csv', index=False)
IND_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2017_games.csv')
IND_2017_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Rakeem Christmas"
# 1 result found.
# Rakeem Christmas
# Results for Rakeem Christmas:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "Al Jefferson"
# ...

# %%
# removed glenn robinson (son)

IND_2018_gamelog = []

for p in IND_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2018_gamelog.append(player_log)
IND_2018_gamelog = pd.concat(IND_2018_gamelog)    
IND_2018_gamelogs = IND_2018_gamelog.copy()
IND_2018_gamelogs['GAME_SCORE'] = IND_2018_gamelogs['GAME_SCORE'].astype(float)
IND_2018_games = IND_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2018_games_csv = IND_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2018_games.csv', index=False)
IND_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2018_games.csv')
IND_2018_games_proc.head()
# Out:
# You searched for "Ike Anigbogu"
# 2 results found.
# 0: Ike Anigbogu
# 1: Ike Diogu
# Pick one: 0
# Results for Ike Anigbogu:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "Al Jefferson"
# 3 results found.
# 0: Al Jefferson
# 1: Amile Jefferson
# 2: Cory Jefferson
# Pick one: 0
# Results for Al Jefferson:
#
# You searched for "Cory Joseph"
# 4 results found.
# 0: Cory Joseph
# 1: Garth Joseph
# 2: Kris Joseph
# 3: Yvon Joseph
# Pick one: 0
# Results for Cory Joseph:
#
# You searched for "T.J. Leaf"
# 5 results found.
# 0: T.J. Leaf
# 1: T.J. Ford
# ...

# %%
# removed kyle o'quinn

IND_2019_gamelog = []

for p in IND_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2019_gamelog.append(player_log)
IND_2019_gamelog = pd.concat(IND_2019_gamelog)    
IND_2019_gamelogs = IND_2019_gamelog.copy()
IND_2019_gamelogs['GAME_SCORE'] = IND_2019_gamelogs['GAME_SCORE'].astype(float)
IND_2019_games = IND_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2019_games_csv = IND_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2019_games.csv', index=False)
IND_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2019_games.csv')
IND_2019_games_proc.head()
# Out:
# You searched for "Ike Anigbogu"
# 2 results found.
# 0: Ike Anigbogu
# 1: Ike Diogu
# Pick one: 0
# Results for Ike Anigbogu:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# Pick one: 0
# Results for Tyreke Evans:
#
# You searched for "Aaron Holiday"
# 2 results found.
# 0: Aaron Holiday
# 1: Jrue Holiday
# Pick one: 0
# Results for Aaron Holiday:
#
# You searched for "Alize Johnson"
# 21 results found.
# 0: Alize Johnson
# 1: Amir Johnson
# 2: Arnie Johnson
# 3: Brice Johnson
# 4: Lee Johnson
# 5: Ollie Johnson
# 6: Andy Johnson
# 7: Armon Johnson
# 8: Avery Johnson
# 9: Clay Johnson
# 10: Dave Johnson
# ...

# %%
IND_2020_gamelog = []

for p in IND_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2020_gamelog.append(player_log)
IND_2020_gamelog = pd.concat(IND_2020_gamelog)    
IND_2020_gamelogs = IND_2020_gamelog.copy()
IND_2020_gamelogs['GAME_SCORE'] = IND_2020_gamelogs['GAME_SCORE'].astype(float)
IND_2020_games = IND_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2020_games_csv = IND_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2020_games.csv', index=False)
IND_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2020_games.csv')
IND_2020_games_proc.head()
# Out:
# You searched for "Goga Bitadze"
# 1 result found.
# Goga Bitadze
# Results for Goga Bitadze:
#
# You searched for "Brian Bowen"
# 8 results found.
# 0: Brian Bowen
# 1: Ryan Bowen
# 2: Bruce Bowen
# 3: Jordan Bowden
# 4: Brian Cook
# 5: Brian Howard
# 6: Brian Rowsom
# 7: Jordan Bone
# Pick one: 0
# Results for Brian Bowen:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Aaron Holiday"
# 2 results found.
# 0: Aaron Holiday
# 1: Jrue Holiday
# Pick one: 0
# Results for Aaron Holiday:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Alize Johnson"
# 21 results found.
# 0: Alize Johnson
# 1: Amir Johnson
# 2: Arnie Johnson
# 3: Brice Johnson
# 4: Lee Johnson
# 5: Ollie Johnson
# 6: Andy Johnson
# 7: Armon Johnson
# 8: Avery Johnson
# 9: Clay Johnson
# 10: Dave Johnson
# 11: Eddie Johnson
# 12: Eddie Johnson
# 13: Eric Johnson
# ...

# %%
# removed Amida Brimah
IND_2021_gamelog = []

for p in IND_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    IND_2021_gamelog.append(player_log)
IND_2021_gamelog = pd.concat(IND_2021_gamelog)    
IND_2021_gamelogs = IND_2021_gamelog.copy()
IND_2021_gamelogs['GAME_SCORE'] = IND_2021_gamelogs['GAME_SCORE'].astype(float)
IND_2021_games = IND_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
IND_2021_games_csv = IND_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2021_games.csv', index=False)
IND_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2021_games.csv')
IND_2021_games_proc.head()
# Out:
# You searched for "Goga Bitadze"
# 1 result found.
# Goga Bitadze
# Results for Goga Bitadze:
#
# You searched for "Brian Bowen"
# 8 results found.
# 0: Brian Bowen
# 1: Ryan Bowen
# 2: Bruce Bowen
# 3: Jordan Bowden
# 4: Brian Cook
# 5: Brian Howard
# 6: Brian Rowsom
# 7: Jordan Bone
# Pick one: 0
# Results for Brian Bowen:
#
# You searched for "Oshae Brissett"
# 1 result found.
# Oshae Brissett
# Results for Oshae Brissett:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Aaron Holiday"
# 2 results found.
# 0: Aaron Holiday
# 1: Jrue Holiday
# Pick one: 0
# Results for Aaron Holiday:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Jeremy Lamb"
# 6 results found.
# 0: Jeremy Lamb
# 1: Jeremy Lin
# 2: Jeremy Evans
# 3: Jerome Lane
# 4: Jeremy Pargo
# 5: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Lamb:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
IND_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2000_games.csv')
IND_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2001_games.csv')
IND_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2002_games.csv')
IND_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2003_games.csv')
IND_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2004_games.csv')
IND_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2005_games.csv')
IND_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2006_games.csv')
IND_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2007_games.csv')
IND_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2008_games.csv')
IND_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2009_games.csv')
IND_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2010_games.csv')
IND_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2011_games.csv')
IND_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2012_games.csv')
IND_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2013_games.csv')
IND_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2014_games.csv')
IND_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2015_games.csv')
IND_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2016_games.csv')
IND_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2017_games.csv')
IND_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2018_games.csv')
IND_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2019_games.csv')
IND_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2020_games.csv')
IND_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2021_games.csv')

# %%
IND_season_dfs = [IND_2000_games_io, IND_2001_games_io, IND_2002_games_io, IND_2003_games_io, IND_2004_games_io, IND_2005_games_io,
                 IND_2006_games_io, IND_2007_games_io, IND_2008_games_io, IND_2009_games_io, IND_2010_games_io, IND_2011_games_io,
                 IND_2012_games_io, IND_2013_games_io, IND_2014_games_io, IND_2015_games_io, IND_2016_games_io, IND_2017_games_io,
                 IND_2018_games_io, IND_2019_games_io, IND_2020_games_io, IND_2021_games_io]

# %%
IND_all = pd.concat(IND_season_dfs)
IND_all_sorted = IND_all.sort_values(by=['GAME_SCORE'], ascending=False)
IND_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-08-01  26-331  IND      HOME      PHI   W (+6)   1  40:37  20   29
# 0  2015-12-05  25-217  IND      AWAY      UTA   L (-3)   1  42:05  15   27
# 0  2021-02-17  24-290  IND      AWAY      MIN   W (+6)   1  45:35  13   21
# 0  2017-12-10  25-220  IND      HOME      DEN  W (+10)   1  45:03  15   28
# 0  2014-02-07  27-279  IND      HOME      POR   W (+5)   1  38:19  12   19
# 0  2014-02-07  27-279  IND      HOME      POR   W (+5)   1  38:19  12   19
# 0  2002-03-16  29-045  CHI      AWAY      HOU   W (+2)   1  56:16  18   34
# 0  2010-03-26  26-340  IND      HOME      UTA  W (+16)   1  37:48  14   23
# 1  2015-11-24  25-206  IND      AWAY      WAS  W (+17)   1  36:35  14   19
# 0  2000-11-08  35-076  IND      HOME      MIL  W (+11)   1  42:19  13   21
# 1  2020-08-03  26-333  IND      AWAY      WAS  W (+11)   1  39:34  14   26
# ...
