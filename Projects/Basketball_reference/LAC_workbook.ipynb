# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_LAC = []

# LAC
while season <= 2021:
    df_LAC = get_roster('LAC', season)
    df_LAC['Season'] = season
    df_LAC['Team'] = 'LAC'
    appended_data_LAC.append(df_LAC)
    season = season + 1
appended_data_LAC = pd.concat(appended_data_LAC)

# %%
LAC_df_all = appended_data_LAC.copy()
LAC_df_all_csv = LAC_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_players_all.csv', index=False)
LAC_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_players_all.csv')
LAC_df_all_csv_io.head()
# Out:
#   NUMBER            PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      1    Derek Anderson  SG    6-5     194  1974-07-18          US
# 1     30     Anthony Avent  PF    6-9     235  1969-10-18          US
# 2     44     Mario Bennett  PF    6-6     235  1973-08-01          US
# 3     41  Etdrick Bohannon  PF    6-9     220  1973-05-29          US
# 4     24     Pete Chilcutt  PF   6-10     230  1968-09-14          US
#
#   EXPERIENCE                                            COLLEGE  Season Team
# 0          2                               Ohio State, Kentucky    2000  LAC
# 1          5                                         Seton Hall    2000  LAC
# 2          3                                      Arizona State    2000  LAC
# 3          2  Arizona, Tennessee, Auburn University at Montg...    2000  LAC
# 4          8                                                UNC    2000  LAC

# %%
LAC_df_2000 = LAC_df_all[LAC_df_all['Season'] == 2000]
LAC_df_2001 = LAC_df_all[LAC_df_all['Season'] == 2001]
LAC_df_2002 = LAC_df_all[LAC_df_all['Season'] == 2002]
LAC_df_2003 = LAC_df_all[LAC_df_all['Season'] == 2003]
LAC_df_2004 = LAC_df_all[LAC_df_all['Season'] == 2004]
LAC_df_2005 = LAC_df_all[LAC_df_all['Season'] == 2005]
LAC_df_2006 = LAC_df_all[LAC_df_all['Season'] == 2006]
LAC_df_2007 = LAC_df_all[LAC_df_all['Season'] == 2007]
LAC_df_2008 = LAC_df_all[LAC_df_all['Season'] == 2008]
LAC_df_2009 = LAC_df_all[LAC_df_all['Season'] == 2009]
LAC_df_2010 = LAC_df_all[LAC_df_all['Season'] == 2010]
LAC_df_2011 = LAC_df_all[LAC_df_all['Season'] == 2011]
LAC_df_2012 = LAC_df_all[LAC_df_all['Season'] == 2012]
LAC_df_2013 = LAC_df_all[LAC_df_all['Season'] == 2013]
LAC_df_2014 = LAC_df_all[LAC_df_all['Season'] == 2014]
LAC_df_2015 = LAC_df_all[LAC_df_all['Season'] == 2015]
LAC_df_2016 = LAC_df_all[LAC_df_all['Season'] == 2016]
LAC_df_2017 = LAC_df_all[LAC_df_all['Season'] == 2017]
LAC_df_2018 = LAC_df_all[LAC_df_all['Season'] == 2018]
LAC_df_2019 = LAC_df_all[LAC_df_all['Season'] == 2019]
LAC_df_2020 = LAC_df_all[LAC_df_all['Season'] == 2020]
LAC_df_2021 = LAC_df_all[LAC_df_all['Season'] == 2021]

# %%
LAC_df_2001.head(12)
LAC_df_2001 = LAC_df_2001.replace("Jermaine O'Neal", "Jermaine O'Neal")

# %%
# changing names
#LAC_df_2002.loc[LAC_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#LAC_df_2004.loc[LAC_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
LAC_df_2000_players = LAC_df_2000['PLAYER'].to_list()
LAC_df_2001_players = LAC_df_2001['PLAYER'].to_list()
LAC_df_2002_players = LAC_df_2002['PLAYER'].to_list()
LAC_df_2003_players = LAC_df_2003['PLAYER'].to_list()
LAC_df_2004_players = LAC_df_2004['PLAYER'].to_list()
LAC_df_2005_players = LAC_df_2005['PLAYER'].to_list()

LAC_df_2006_players = LAC_df_2006['PLAYER'].to_list()
LAC_df_2007_players = LAC_df_2007['PLAYER'].to_list()
LAC_df_2008_players = LAC_df_2008['PLAYER'].to_list()
LAC_df_2009_players = LAC_df_2009['PLAYER'].to_list()
LAC_df_2010_players = LAC_df_2010['PLAYER'].to_list()
LAC_df_2011_players = LAC_df_2011['PLAYER'].to_list()

LAC_df_2012_players = LAC_df_2012['PLAYER'].to_list()
LAC_df_2013_players = LAC_df_2013['PLAYER'].to_list()
LAC_df_2014_players = LAC_df_2014['PLAYER'].to_list()
LAC_df_2015_players = LAC_df_2015['PLAYER'].to_list()
LAC_df_2016_players = LAC_df_2016['PLAYER'].to_list()
LAC_df_2017_players = LAC_df_2017['PLAYER'].to_list()

LAC_df_2018_players = LAC_df_2018['PLAYER'].to_list()
LAC_df_2019_players = LAC_df_2019['PLAYER'].to_list()
LAC_df_2020_players = LAC_df_2020['PLAYER'].to_list()
LAC_df_2021_players = LAC_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
# drop Jermaine O'Neal 2001-2008
#LAC_df_2000_players.remove("Charles Jones")
#LAC_df_2000_players.remove("Maurice Taylor")

#LAC_df_2005_players.remove("Mamadou N'Diaye")

#LAC_df_2006_players.remove("Boniface N'Dong")

#LAC_df_2007_players.remove("Luke Jackson")

#LAC_df_2011_players.remove("Mo Williams")
#LAC_df_2012_players.remove("Mo Williams")

LAC_df_2016_players.remove("Jeff Ayres")

# %%
# removed charles jones
# removed maurice taylor

LAC_2000_gamelog = []



for p in LAC_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2000_gamelog.append(player_log)
LAC_2000_gamelog = pd.concat(LAC_2000_gamelog)    
LAC_2000_gamelogs = LAC_2000_gamelog.copy()
LAC_2000_gamelogs['GAME_SCORE'] = LAC_2000_gamelogs['GAME_SCORE'].astype(float)
LAC_2000_games = LAC_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2000_games_csv = LAC_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2000_games.csv', index=False)
LAC_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2000_games.csv')
LAC_2000_games_proc.head()
# Out:
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Anthony Avent"
# 8 results found.
# 0: Anthony Avent
# 1: Anthony Davis
# 2: Anthony Mason
# 3: Anthony Bowie
# 4: Anthony Brown
# 5: Anthony Carter
# 6: Anthony Jones
# 7: Anthony Parker
# Pick one: 0
# Results for Anthony Avent:
#
# You searched for "Mario Bennett"
# 2 results found.
# 0: Mario Bennett
# 1: Mel Bennett
# Pick one: 0
# Results for Mario Bennett:
#
# You searched for "Etdrick Bohannon"
# 1 result found.
# Etdrick Bohannon
# Results for Etdrick Bohannon:
#
# You searched for "Pete Chilcutt"
# 1 result found.
# Pete Chilcutt
# Results for Pete Chilcutt:
#
# You searched for "Keith Closs"
# 8 results found.
# ...

# %%
LAC_2001_gamelog = []


for p in LAC_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2001_gamelog.append(player_log)
LAC_2001_gamelog = pd.concat(LAC_2001_gamelog)    
LAC_2001_gamelogs = LAC_2001_gamelog.copy()
LAC_2001_gamelogs['GAME_SCORE'] = LAC_2001_gamelogs['GAME_SCORE'].astype(float)
LAC_2001_games = LAC_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2001_games_csv = LAC_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2001_games.csv', index=False)
LAC_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2001_games.csv')
LAC_2001_games_proc.head()
# Out:
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Zendon Hamilton"
# 3 results found.
# 0: Zendon Hamilton
# 1: Dennis Hamilton
# 2: Jordan Hamilton
# Pick one: 0
# Results for Zendon Hamilton:
#
# You searched for "Corey Maggette"
# 1 result found.
# Corey Maggette
# Results for Corey Maggette:
#
# You searched for "Jeff McInnis"
# 2 results found.
# 0: Jeff McInnis
# 1: Jeff Mullins
# Pick one: 0
# Results for Jeff McInnis:
#
# You searched for "Darius Miles"
# 6 results found.
# 0: Darius Miles
# 1: Darius Miller
# 2: Darius Bazley
# 3: Aaron Miles
# 4: Chris Mills
# 5: Darius Morris
# Pick one: 0
# Results for Darius Miles:
#
# You searched for "Tyrone Nesby"
# 1 result found.
# Tyrone Nesby
# Results for Tyrone Nesby:
#
# You searched for "Lamar Odom"
# 1 result found.
# Lamar Odom
# Results for Lamar Odom:
#
# ...

# %%
LAC_2002_gamelog = []


for p in LAC_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2002_gamelog.append(player_log)
LAC_2002_gamelog = pd.concat(LAC_2002_gamelog)    
LAC_2002_gamelogs = LAC_2002_gamelog.copy()
LAC_2002_gamelogs['GAME_SCORE'] = LAC_2002_gamelogs['GAME_SCORE'].astype(float)
LAC_2002_games = LAC_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2002_games_csv = LAC_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2002_games.csv', index=False)
LAC_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2002_games.csv')
LAC_2002_games_proc.head()
# Out:
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Obinna Ekezie"
# 1 result found.
# Obinna Ekezie
# Results for Obinna Ekezie:
#
# You searched for "Tremaine Fowlkes"
# 1 result found.
# Tremaine Fowlkes
# Results for Tremaine Fowlkes:
#
# You searched for "Harold Jamison"
# 3 results found.
# 0: Harold Jamison
# 1: Harold Johnson
# 2: Harold Miner
# Pick one: 0
# Results for Harold Jamison:
#
# You searched for "Corey Maggette"
# 1 result found.
# Corey Maggette
# Results for Corey Maggette:
#
# You searched for "Jeff McInnis"
# 2 results found.
# 0: Jeff McInnis
# 1: Jeff Mullins
# Pick one: 0
# Results for Jeff McInnis:
#
# You searched for "Darius Miles"
# 6 results found.
# 0: Darius Miles
# 1: Darius Miller
# ...

# %%
LAC_2003_gamelog = []



for p in LAC_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2003_gamelog.append(player_log)
LAC_2003_gamelog = pd.concat(LAC_2003_gamelog)    
LAC_2003_gamelogs = LAC_2003_gamelog.copy()
LAC_2003_gamelogs['GAME_SCORE'] = LAC_2003_gamelogs['GAME_SCORE'].astype(float)
LAC_2003_games = LAC_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2003_games_csv = LAC_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2003_games.csv', index=False)
LAC_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2003_games.csv')
LAC_2003_games_proc.head()
# Out:
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Melvin Ely"
# 1 result found.
# Melvin Ely
# Results for Melvin Ely:
#
# You searched for "Tremaine Fowlkes"
# 1 result found.
# Tremaine Fowlkes
# Results for Tremaine Fowlkes:
#
# You searched for "Marko Jarić"
# 10 results found.
# 0: Marko Jaric
# 1: Marko Milic
# 2: Dario Saric
# 3: Mark Alarie
# 4: Mark Davis
# 5: Mark Davis
# 6: Marko Guduric
# 7: Mark Price
# 8: Mark Acres
# 9: Mark Macon
# Pick one: 0
# Results for Marko Jaric:
#
# You searched for "Corey Maggette"
# 1 result found.
# Corey Maggette
# Results for Corey Maggette:
#
# You searched for "Andre Miller"
# 7 results found.
# 0: Andre Miller
# 1: Eddie Miller
# 2: Harry Miller
# 3: Larry Miller
# 4: Mike Miller
# 5: Andre Moore
# 6: Andre Turner
# Pick one: 0
# Results for Andre Miller:
#
# ...

# %%
LAC_2004_gamelog = []



for p in LAC_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2004_gamelog.append(player_log)
LAC_2004_gamelog = pd.concat(LAC_2004_gamelog)    
LAC_2004_gamelogs = LAC_2004_gamelog.copy()
LAC_2004_gamelogs['GAME_SCORE'] = LAC_2004_gamelogs['GAME_SCORE'].astype(float)
LAC_2004_games = LAC_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2004_games_csv = LAC_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2004_games.csv', index=False)
LAC_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2004_games.csv')
LAC_2004_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Predrag Drobnjak"
# 1 result found.
# Predrag Drobnjak
# Results for Predrag Drobnjak:
#
# You searched for "Melvin Ely"
# 1 result found.
# Melvin Ely
# Results for Melvin Ely:
#
# You searched for "Eddie House"
# 6 results found.
# 0: Eddie House
# 1: Eddie Hughes
# 2: Eddie Jones
# 3: Eddie Mast
# 4: Eddie Miles
# 5: Eddie Owens
# Pick one: 0
# Results for Eddie House:
#
# You searched for "Marko Jarić"
# 10 results found.
# 0: Marko Jaric
# 1: Marko Milic
# 2: Dario Saric
# 3: Mark Alarie
# 4: Mark Davis
# ...

# %%
LAC_2005_gamelog = []

for p in LAC_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2005_gamelog.append(player_log)
LAC_2005_gamelog = pd.concat(LAC_2005_gamelog)    
LAC_2005_gamelogs = LAC_2005_gamelog.copy()
LAC_2005_gamelogs['GAME_SCORE'] = LAC_2005_gamelogs['GAME_SCORE'].astype(float)
LAC_2005_games = LAC_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2005_games_csv = LAC_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2005_games.csv', index=False)
LAC_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2005_games.csv')
LAC_2005_games_proc.head()
# Out:
# You searched for "Kenny Anderson"
# 10 results found.
# 0: Kenny Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Eric Anderson
# 6: Kim Anderson
# 7: Kyle Anderson
# 8: Ron Anderson
# 9: Ryan Anderson
# Pick one: 0
# Results for Kenny Anderson:
#
# You searched for "Maurice Baker"
# 9 results found.
# 0: Maurice Baker
# 1: Maurice Ager
# 2: Maurice Carter
# 3: Maurice Ndour
# 4: Maurice Stokes
# 5: Maurice Taylor
# 6: Maurice Evans
# 7: Maurice King
# 8: Maurice Lucas
# Pick one: 0
# Results for Maurice Baker:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Lionel Chalmers"
# 1 result found.
# Lionel Chalmers
# Results for Lionel Chalmers:
#
# You searched for "Marko Jarić"
# ...

# %%
# removed Boniface N'Dong

LAC_2006_gamelog = []

for p in LAC_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2006_gamelog.append(player_log)
LAC_2006_gamelog = pd.concat(LAC_2006_gamelog)    
LAC_2006_gamelogs = LAC_2006_gamelog.copy()
LAC_2006_gamelogs['GAME_SCORE'] = LAC_2006_gamelogs['GAME_SCORE'].astype(float)
LAC_2006_games = LAC_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2006_games_csv = LAC_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2006_games.csv', index=False)
LAC_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2006_games.csv')
LAC_2006_games_proc.head()
# Out:
# You searched for "Vin Baker"
# 8 results found.
# 0: Vin Baker
# 1: Ron Baker
# 2: Von Wafer
# 3: Norm Baker
# 4: Tom Barker
# 5: Devin Booker
# 6: Thon Maker
# 7: Zan Tabak
# Pick one: 0
# Results for Vin Baker:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Daniel Ewing"
# 3 results found.
# 0: Daniel Ewing
# 1: Daniel Orton
# 2: Daniel Theis
# Pick one: 0
# Results for Daniel Ewing:
#
# You searched for "Anthony Goldwire"
# 2 results found.
# 0: Anthony Goldwire
# 1: Anthony Bowie
# Pick one: 0
# Results for Anthony Goldwire:
#
# You searched for "Chris Kaman"
# 12 results found.
# 0: Chris Kaman
# 1: Chris Babb
# 2: Chris Carr
# 3: Chris Duhon
# 4: Chris King
# ...

# %%
# removed luke jackson

LAC_2007_gamelog = []

for p in LAC_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2007_gamelog.append(player_log)
LAC_2007_gamelog = pd.concat(LAC_2007_gamelog)    
LAC_2007_gamelogs = LAC_2007_gamelog.copy()
LAC_2007_gamelogs['GAME_SCORE'] = LAC_2007_gamelogs['GAME_SCORE'].astype(float)
LAC_2007_games = LAC_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2007_games_csv = LAC_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2007_games.csv', index=False)
LAC_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2007_games.csv')
LAC_2007_games_proc.head()
# Out:
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Will Conroy"
# 6 results found.
# 0: Will Conroy
# 1: Will Cherry
# 2: Bill Crow
# 3: Bill Henry
# 4: Will Barton
# 5: Willie Long
# Pick one: 0
# Results for Will Conroy:
#
# You searched for "Paul Davis"
# 29 results found.
# 0: Paul Davis
# 1: Bill Davis
# 2: Dale Davis
# 3: Mark Davis
# 4: Mark Davis
# 5: Mel Davis
# 6: Walt Davis
# 7: Paul Dawkins
# 8: Baron Davis
# 9: Ben Davis
# 10: Bob Davis
# 11: Brad Davis
# 12: Ed Davis
# 13: Emanual Davis
# 14: Glen Davis
# 15: Harry Davis
# 16: Jim Davis
# 17: Josh Davis
# 18: Lee Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Ralph Davis
# 22: Red Davis
# ...

# %%
LAC_2008_gamelog = []

for p in LAC_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2008_gamelog.append(player_log)
LAC_2008_gamelog = pd.concat(LAC_2008_gamelog)    
LAC_2008_gamelogs = LAC_2008_gamelog.copy()
LAC_2008_gamelogs['GAME_SCORE'] = LAC_2008_gamelogs['GAME_SCORE'].astype(float)
LAC_2008_games = LAC_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2008_games_csv = LAC_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2008_games.csv', index=False)
LAC_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2008_games.csv')
LAC_2008_games_proc.head()
# Out:
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Paul Davis"
# 29 results found.
# 0: Paul Davis
# 1: Bill Davis
# 2: Dale Davis
# 3: Mark Davis
# 4: Mark Davis
# 5: Mel Davis
# 6: Walt Davis
# 7: Paul Dawkins
# 8: Baron Davis
# 9: Ben Davis
# 10: Bob Davis
# 11: Brad Davis
# 12: Ed Davis
# 13: Emanual Davis
# 14: Glen Davis
# 15: Harry Davis
# 16: Jim Davis
# 17: Josh Davis
# 18: Lee Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Ralph Davis
# 22: Red Davis
# 23: Ron Davis
# 24: Paul Silas
# 25: Paul Eboua
# 26: Paul Cloyd
# 27: Pau Gasol
# 28: Paul Grant
# Pick one: 0
# Results for Paul Davis:
#
# ...

# %%
LAC_2009_gamelog = []

for p in LAC_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2009_gamelog.append(player_log)
LAC_2009_gamelog = pd.concat(LAC_2009_gamelog)    
LAC_2009_gamelogs = LAC_2009_gamelog.copy()
LAC_2009_gamelogs['GAME_SCORE'] = LAC_2009_gamelogs['GAME_SCORE'].astype(float)
LAC_2009_games = LAC_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2009_games_csv = LAC_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2009_games.csv', index=False)
LAC_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2009_games.csv')
LAC_2009_games_proc.head()
# Out:
# You searched for "Alex Acker"
# 8 results found.
# 0: Alex Acker
# 1: Alex Kirk
# 2: Alex Len
# 3: Alex Scales
# 4: Al Tucker
# 5: Alex Garcia
# 6: Alex Groza
# 7: Al Cervi
# Pick one: 0
# Results for Alex Acker:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Mardy Collins"
# 8 results found.
# 0: Mardy Collins
# 1: Art Collins
# 2: James Collins
# 3: Jarron Collins
# 4: Jason Collins
# 5: Jimmy Collins
# 6: Zach Collins
# 7: Marty Conlon
# Pick one: 0
# Results for Mardy Collins:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# 12: Bill Davis
# 13: Dale Davis
# 14: Glen Davis
# 15: Paul Davis
# ...

# %%
LAC_2010_gamelog = []

for p in LAC_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2010_gamelog.append(player_log)
LAC_2010_gamelog = pd.concat(LAC_2010_gamelog)    
LAC_2010_gamelogs = LAC_2010_gamelog.copy()
LAC_2010_gamelogs['GAME_SCORE'] = LAC_2010_gamelogs['GAME_SCORE'].astype(float)
LAC_2010_games = LAC_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2010_games_csv = LAC_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2010_games.csv', index=False)
LAC_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2010_games.csv')
LAC_2010_games_proc.head()
# Out:
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Bobby Brown"
# 14 results found.
# 0: Bobby Brown
# 1: Bob Brown
# 2: Tony Brown
# 3: Bobby Croft
# 4: Bruce Brown
# 5: John Brown
# 6: Larry Brown
# 7: Moses Brown
# 8: Randy Brown
# 9: Roger Brown
# 10: Roger Brown
# 11: Troy Brown
# 12: Bobby Cook
# 13: Bobby Lloyd
# Pick one: 0
# Results for Bobby Brown:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Mardy Collins"
# ...

# %%
# removed Mo Williams
LAC_2011_gamelog = []

for p in LAC_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2011_gamelog.append(player_log)
LAC_2011_gamelog = pd.concat(LAC_2011_gamelog)    
LAC_2011_gamelogs = LAC_2011_gamelog.copy()
LAC_2011_gamelogs['GAME_SCORE'] = LAC_2011_gamelogs['GAME_SCORE'].astype(float)
LAC_2011_games = LAC_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2011_games_csv = LAC_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2011_games.csv', index=False)
LAC_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2011_games.csv')
LAC_2011_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# ...

# %%
# removed Mo Williams

LAC_2012_gamelog = []

for p in LAC_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2012_gamelog.append(player_log)
LAC_2012_gamelog = pd.concat(LAC_2012_gamelog)    
LAC_2012_gamelogs = LAC_2012_gamelog.copy()
LAC_2012_gamelogs['GAME_SCORE'] = LAC_2012_gamelogs['GAME_SCORE'].astype(float)
LAC_2012_games = LAC_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2012_games_csv = LAC_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2012_games.csv', index=False)
LAC_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2012_games.csv')
LAC_2012_games_proc.head()
# Out:
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Courtney Fortson"
# 1 result found.
# Courtney Fortson
# Results for Courtney Fortson:
#
# ...

# %%
LAC_2013_gamelog = []

for p in LAC_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2013_gamelog.append(player_log)
LAC_2013_gamelog = pd.concat(LAC_2013_gamelog)    
LAC_2013_gamelogs = LAC_2013_gamelog.copy()
LAC_2013_gamelogs['GAME_SCORE'] = LAC_2013_gamelogs['GAME_SCORE'].astype(float)
LAC_2013_games = LAC_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2013_games_csv = LAC_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2013_games.csv', index=False)
LAC_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2013_games.csv')
LAC_2013_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# ...

# %%
LAC_2014_gamelog = []

for p in LAC_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2014_gamelog.append(player_log)
LAC_2014_gamelog = pd.concat(LAC_2014_gamelog)    
LAC_2014_gamelogs = LAC_2014_gamelog.copy()
LAC_2014_gamelogs['GAME_SCORE'] = LAC_2014_gamelogs['GAME_SCORE'].astype(float)
LAC_2014_games = LAC_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2014_games_csv = LAC_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2014_games.csv', index=False)
LAC_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2014_games.csv')
LAC_2014_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Glen Davis"
# 28 results found.
# 0: Glen Davis
# 1: Ben Davis
# 2: Lee Davis
# 3: Dale Davis
# 4: Ed Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Tyler Davis
# 9: Glen Combs
# 10: Baron Davis
# 11: Bill Davis
# 12: Bob Davis
# 13: Brad Davis
# 14: Brian Davis
# ...

# %%
LAC_2015_gamelog = []

for p in LAC_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2015_gamelog.append(player_log)
LAC_2015_gamelog = pd.concat(LAC_2015_gamelog)    
LAC_2015_gamelogs = LAC_2015_gamelog.copy()
LAC_2015_gamelogs['GAME_SCORE'] = LAC_2015_gamelogs['GAME_SCORE'].astype(float)
LAC_2015_games = LAC_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2015_games_csv = LAC_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2015_games.csv', index=False)
LAC_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2015_games.csv')
LAC_2015_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Jared Cunningham"
# 2 results found.
# 0: Jared Cunningham
# 1: Dante Cunningham
# Pick one: 0
# Results for Jared Cunningham:
#
# You searched for "Glen Davis"
# 28 results found.
# 0: Glen Davis
# 1: Ben Davis
# 2: Lee Davis
# 3: Dale Davis
# 4: Ed Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Tyler Davis
# 9: Glen Combs
# 10: Baron Davis
# 11: Bill Davis
# 12: Bob Davis
# 13: Brad Davis
# 14: Brian Davis
# 15: Jim Davis
# ...

# %%
# removed jeff ayres

LAC_2016_gamelog = []

for p in LAC_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2016_gamelog.append(player_log)
LAC_2016_gamelog = pd.concat(LAC_2016_gamelog)    
LAC_2016_gamelogs = LAC_2016_gamelog.copy()
LAC_2016_gamelogs['GAME_SCORE'] = LAC_2016_gamelogs['GAME_SCORE'].astype(float)
LAC_2016_games = LAC_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2016_games_csv = LAC_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2016_games.csv', index=False)
LAC_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2016_games.csv')
LAC_2016_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Branden Dawson"
# 3 results found.
# 0: Branden Dawson
# 1: Brandon Sampson
# 2: Brandon Davies
# Pick one: 0
# Results for Branden Dawson:
#
# You searched for "Jeff Green"
# 21 results found.
# 0: Jeff Green
# 1: Josh Green
# 2: Jeff Adrien
# 3: Jeff Grayer
# 4: Ken Green
# 5: Sean Green
# 6: Jeff Ayres
# 7: Jeff Cross
# 8: A.C. Green
# 9: Devin Green
# 10: Kenny Green
# 11: Mike Green
# 12: Si Green
# 13: Steve Green
# 14: Jeff Lebo
# 15: Jeff Martin
# 16: Jeff Turner
# 17: Jeff Webb
# 18: Jeff Foote
# 19: Jeff Slade
# 20: Jeff Teague
# Pick one: 0
# Results for Jeff Green:
#
# You searched for "Blake Griffin"
# 3 results found.
# 0: Blake Griffin
# 1: Eddie Griffin
# 2: Paul Griffin
# Pick one: 0
# ...

# %%
LAC_2017_gamelog = []

for p in LAC_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2017_gamelog.append(player_log)
LAC_2017_gamelog = pd.concat(LAC_2017_gamelog)    
LAC_2017_gamelogs = LAC_2017_gamelog.copy()
LAC_2017_gamelogs['GAME_SCORE'] = LAC_2017_gamelogs['GAME_SCORE'].astype(float)
LAC_2017_games = LAC_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2017_games_csv = LAC_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2017_games.csv', index=False)
LAC_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2017_games.csv')
LAC_2017_games_proc.head()
# Out:
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Raymond Felton"
# 1 result found.
# Raymond Felton
# Results for Raymond Felton:
#
# You searched for "Blake Griffin"
# 3 results found.
# 0: Blake Griffin
# 1: Eddie Griffin
# 2: Paul Griffin
# Pick one: 0
# Results for Blake Griffin:
#
# ...

# %%
LAC_2018_gamelog = []

for p in LAC_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2018_gamelog.append(player_log)
LAC_2018_gamelog = pd.concat(LAC_2018_gamelog)    
LAC_2018_gamelogs = LAC_2018_gamelog.copy()
LAC_2018_gamelogs['GAME_SCORE'] = LAC_2018_gamelogs['GAME_SCORE'].astype(float)
LAC_2018_games = LAC_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2018_games_csv = LAC_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2018_games.csv', index=False)
LAC_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2018_games.csv')
LAC_2018_games_proc.head()
# Out:
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Sam Dekker"
# 1 result found.
# Sam Dekker
# Results for Sam Dekker:
#
# You searched for "Jawun Evans"
# 4 results found.
# 0: Jawun Evans
# 1: Jacob Evans
# 2: Brian Evans
# 3: Earl Evans
# Pick one: 0
# Results for Jawun Evans:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Blake Griffin"
# 3 results found.
# 0: Blake Griffin
# 1: Eddie Griffin
# 2: Paul Griffin
# Pick one: 0
# Results for Blake Griffin:
#
# You searched for "Montrezl Harrell"
# 1 result found.
# Montrezl Harrell
# Results for Montrezl Harrell:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# ...

# %%
LAC_2019_gamelog = []

for p in LAC_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2019_gamelog.append(player_log)
LAC_2019_gamelog = pd.concat(LAC_2019_gamelog)    
LAC_2019_gamelogs = LAC_2019_gamelog.copy()
LAC_2019_gamelogs['GAME_SCORE'] = LAC_2019_gamelogs['GAME_SCORE'].astype(float)
LAC_2019_games = LAC_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2019_games_csv = LAC_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2019_games.csv', index=False)
LAC_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2019_games.csv')
LAC_2019_games_proc.head()
# Out:
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Ángel Delgado"
# 1 result found.
# Angel Delgado
# Results for Angel Delgado:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Shai Gilgeous-Alexander"
# 1 result found.
# Shai Gilgeous-Alexander
# Results for Shai Gilgeous-Alexander:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "JaMychal Green"
# 1 result found.
# JaMychal Green
# Results for JaMychal Green:
#
# ...

# %%
LAC_2020_gamelog = []

for p in LAC_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2020_gamelog.append(player_log)
LAC_2020_gamelog = pd.concat(LAC_2020_gamelog)    
LAC_2020_gamelogs = LAC_2020_gamelog.copy()
LAC_2020_gamelogs['GAME_SCORE'] = LAC_2020_gamelogs['GAME_SCORE'].astype(float)
LAC_2020_games = LAC_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2020_games_csv = LAC_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2020_games.csv', index=False)
LAC_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2020_games.csv')
LAC_2020_games_proc.head()
# Out:
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Amir Coffey"
# 1 result found.
# Amir Coffey
# Results for Amir Coffey:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# You searched for "JaMychal Green"
# 1 result found.
# JaMychal Green
# Results for JaMychal Green:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# 1: Maurice McHartley
# Pick one: 0
# Results for Maurice Harkless:
#
# You searched for "Montrezl Harrell"
# 1 result found.
# Montrezl Harrell
# Results for Montrezl Harrell:
#
# You searched for "Reggie Jackson"
# 6 results found.
# 0: Reggie Jackson
# 1: Reggie Hanson
# 2: Reggie Johnson
# 3: Cedric Jackson
# ...

# %%
LAC_2021_gamelog = []

for p in LAC_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    LAC_2021_gamelog.append(player_log)
LAC_2021_gamelog = pd.concat(LAC_2021_gamelog)    
LAC_2021_gamelogs = LAC_2021_gamelog.copy()
LAC_2021_gamelogs['GAME_SCORE'] = LAC_2021_gamelogs['GAME_SCORE'].astype(float)
LAC_2021_games = LAC_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_2021_games_csv = LAC_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2021_games.csv', index=False)
LAC_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2021_games.csv')
LAC_2021_games_proc.head()
# Out:
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Amir Coffey"
# 1 result found.
# Amir Coffey
# Results for Amir Coffey:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Yogi Ferrell"
# 1 result found.
# Yogi Ferrell
# Results for Yogi Ferrell:
#
# You searched for "Malik Fitts"
# 2 results found.
# 0: Malik Fitts
# 1: Malik Rose
# Pick one: 0
# Results for Malik Fitts:
#
# You searched for "Paul George"
# 12 results found.
# 0: Paul George
# 1: Jack George
# 2: Tate George
# 3: Paul Gordon
# 4: Paul Hogue
# 5: Paul Long
# 6: Paul Pierce
# 7: Paul Reed
# 8: Paul Grant
# 9: Paul Noel
# 10: Paul Nolen
# 11: Paul Seymour
# Pick one: 0
# Results for Paul George:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
LAC_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2000_games.csv')
LAC_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2001_games.csv')
LAC_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2002_games.csv')
LAC_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2003_games.csv')
LAC_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2004_games.csv')
LAC_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2005_games.csv')
LAC_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2006_games.csv')
LAC_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2007_games.csv')
LAC_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2008_games.csv')
LAC_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2009_games.csv')
LAC_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2010_games.csv')
LAC_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2011_games.csv')
LAC_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2012_games.csv')
LAC_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2013_games.csv')
LAC_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2014_games.csv')
LAC_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2015_games.csv')
LAC_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2016_games.csv')
LAC_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2017_games.csv')
LAC_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2018_games.csv')
LAC_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2019_games.csv')
LAC_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2020_games.csv')
LAC_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2021_games.csv')

# %%
LAC_season_dfs = [LAC_2000_games_io, LAC_2001_games_io, LAC_2002_games_io, LAC_2003_games_io, LAC_2004_games_io, LAC_2005_games_io,
                 LAC_2006_games_io, LAC_2007_games_io, LAC_2008_games_io, LAC_2009_games_io, LAC_2010_games_io, LAC_2011_games_io,
                 LAC_2012_games_io, LAC_2013_games_io, LAC_2014_games_io, LAC_2015_games_io, LAC_2016_games_io, LAC_2017_games_io,
                 LAC_2018_games_io, LAC_2019_games_io, LAC_2020_games_io, LAC_2021_games_io]

# %%
LAC_all = pd.concat(LAC_season_dfs)
LAC_all_sorted = LAC_all.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2015-04-01  29-330  LAC      AWAY      POR   W (+4)   1  39:24  13   21
# 0  2016-02-26  30-296  LAC      AWAY      SAC  W (+10)   1  36:20  13   20
# 0  2013-12-14  28-222  LAC      AWAY      WAS  W (+16)   1  32:49  11   14
# 0  2013-12-14  28-222  LAC      AWAY      WAS  W (+16)   1  32:49  11   14
# 1  2013-10-31  28-178  LAC      HOME      GSW  W (+11)   1  37:26  12   20
# 1  2013-10-31  28-178  LAC      HOME      GSW  W (+11)   1  37:26  12   20
# 0  2011-01-17  21-307  LAC      HOME      IND   W (+7)   1  36:56  19   24
# 0  2007-04-12  27-151  LAC      AWAY      LAL   W (+8)   1  42:51  10   15
# 0  2018-01-10  31-075  LAC      AWAY      GSW  W (+19)   1  35:07  16   27
# 0  2020-01-14  28-199  LAC      HOME      CLE  W (+25)   1  28:44  14   22
# 0  2005-12-23  26-287  LAC      AWAY      CHA   W (+9)   1  40:14  14   25
# ...
