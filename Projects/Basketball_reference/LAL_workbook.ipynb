# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_LAL = []

# LAL
while season <= 2021:
    df_LAL = get_roster('LAL', season)
    df_LAL['Season'] = season
    df_LAL['Team'] = 'LAL'
    appended_data_LAL.append(df_LAL)
    season = season + 1
appended_data_LAL = pd.concat(appended_data_LAL)

# %%
LAL_df_all = appended_data_LAL.copy()
LAL_df_all_csv = LAL_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_players_all.csv', index=False)
LAL_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_players_all.csv')
LAL_df_all_csv_io.head()
# Out:
#   NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      8     Kobe Bryant  SG    6-6     212  1978-08-23          US
# 1     11  John Celestand  PG    6-4     178  1977-03-06          US
# 2      2    Derek Fisher  PG    6-1     200  1974-08-09          US
# 3     17        Rick Fox  SF    6-7     230  1969-07-24          CA
# 4      3   Devean George  SF    6-8     220  1977-08-29          US
#
#   EXPERIENCE           COLLEGE  Season Team
# 0          3               NaN    2000  LAL
# 1          R         Villanova    2000  LAL
# 2          3       Little Rock    2000  LAL
# 3          8               UNC    2000  LAL
# 4          R  Augsburg College    2000  LAL

# %%
LAL_df_2000 = LAL_df_all[LAL_df_all['Season'] == 2000]
LAL_df_2001 = LAL_df_all[LAL_df_all['Season'] == 2001]
LAL_df_2002 = LAL_df_all[LAL_df_all['Season'] == 2002]
LAL_df_2003 = LAL_df_all[LAL_df_all['Season'] == 2003]
LAL_df_2004 = LAL_df_all[LAL_df_all['Season'] == 2004]
LAL_df_2005 = LAL_df_all[LAL_df_all['Season'] == 2005]
LAL_df_2006 = LAL_df_all[LAL_df_all['Season'] == 2006]
LAL_df_2007 = LAL_df_all[LAL_df_all['Season'] == 2007]
LAL_df_2008 = LAL_df_all[LAL_df_all['Season'] == 2008]
LAL_df_2009 = LAL_df_all[LAL_df_all['Season'] == 2009]
LAL_df_2010 = LAL_df_all[LAL_df_all['Season'] == 2010]
LAL_df_2011 = LAL_df_all[LAL_df_all['Season'] == 2011]
LAL_df_2012 = LAL_df_all[LAL_df_all['Season'] == 2012]
LAL_df_2013 = LAL_df_all[LAL_df_all['Season'] == 2013]
LAL_df_2014 = LAL_df_all[LAL_df_all['Season'] == 2014]
LAL_df_2015 = LAL_df_all[LAL_df_all['Season'] == 2015]
LAL_df_2016 = LAL_df_all[LAL_df_all['Season'] == 2016]
LAL_df_2017 = LAL_df_all[LAL_df_all['Season'] == 2017]
LAL_df_2018 = LAL_df_all[LAL_df_all['Season'] == 2018]
LAL_df_2019 = LAL_df_all[LAL_df_all['Season'] == 2019]
LAL_df_2020 = LAL_df_all[LAL_df_all['Season'] == 2020]
LAL_df_2021 = LAL_df_all[LAL_df_all['Season'] == 2021]

# %%
# changing names
#LAL_df_2002.loc[LAL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#LAL_df_2004.loc[LAL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
LAL_df_2000_players = LAL_df_2000['PLAYER'].to_list()
LAL_df_2001_players = LAL_df_2001['PLAYER'].to_list()
LAL_df_2002_players = LAL_df_2002['PLAYER'].to_list()
LAL_df_2003_players = LAL_df_2003['PLAYER'].to_list()
LAL_df_2004_players = LAL_df_2004['PLAYER'].to_list()
LAL_df_2005_players = LAL_df_2005['PLAYER'].to_list()

LAL_df_2006_players = LAL_df_2006['PLAYER'].to_list()
LAL_df_2007_players = LAL_df_2007['PLAYER'].to_list()
LAL_df_2008_players = LAL_df_2008['PLAYER'].to_list()
LAL_df_2009_players = LAL_df_2009['PLAYER'].to_list()
LAL_df_2010_players = LAL_df_2010['PLAYER'].to_list()
LAL_df_2011_players = LAL_df_2011['PLAYER'].to_list()

LAL_df_2012_players = LAL_df_2012['PLAYER'].to_list()
LAL_df_2013_players = LAL_df_2013['PLAYER'].to_list()
LAL_df_2014_players = LAL_df_2014['PLAYER'].to_list()
LAL_df_2015_players = LAL_df_2015['PLAYER'].to_list()
LAL_df_2016_players = LAL_df_2016['PLAYER'].to_list()
LAL_df_2017_players = LAL_df_2017['PLAYER'].to_list()

LAL_df_2018_players = LAL_df_2018['PLAYER'].to_list()
LAL_df_2019_players = LAL_df_2019['PLAYER'].to_list()
LAL_df_2020_players = LAL_df_2020['PLAYER'].to_list()
LAL_df_2021_players = LAL_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
# drop Shaquille O'Neal 2001-2004
# make separate df

#LAL_df_2000_players.remove("Shaquille O'Neal")
#LAL_df_2001_players.remove("Shaquille O'Neal")
#LAL_df_2002_players.remove("Shaquille O'Neal")
#LAL_df_2003_players.remove("Shaquille O'Neal")
#LAL_df_2004_players.remove("Shaquille O'Neal")

#LAL_df_2008_players.remove("Didier Ilunga-Mbenga")
#LAL_df_2009_players.remove("Didier Ilunga-Mbenga")
#LAL_df_2010_players.remove("Didier Ilunga-Mbenga")
#LAL_df_2011_players.remove("Metta World Peace")
#LAL_df_2012_players.remove("Metta World Peace")
#LAL_df_2013_players.remove("Metta World Peace")
#LAL_df_2016_players.remove("Metta World Peace")
#LAL_df_2017_players.remove("Metta World Peace")

#LAL_df_2016_players.remove("Larry Nance")
#LAL_df_2017_players.remove("Larry Nance")
#LAL_df_2018_players.remove("Larry Nance")

#LAL_df_2016_players.remove("D'Angelo Russell")
#LAL_df_2017_players.remove("D'Angelo Russell")

LAL_df_2018_players.remove("Gary Payton")
#LAL_df_2010_players.remove("Metta World Peace")

# %%
# removed Shaquille O'Neal

LAL_2000_gamelog = []



for p in LAL_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2000_gamelog.append(player_log)
LAL_2000_gamelog = pd.concat(LAL_2000_gamelog)    
LAL_2000_gamelogs = LAL_2000_gamelog.copy()
LAL_2000_gamelogs['GAME_SCORE'] = LAL_2000_gamelogs['GAME_SCORE'].astype(float)
LAL_2000_games = LAL_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2000_games_csv = LAL_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2000_games.csv', index=False)
LAL_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2000_games.csv')
LAL_2000_games_proc.head()
# Out:
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "John Celestand"
# 1 result found.
# John Celestand
# Results for John Celestand:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Rick Fox"
# 7 results found.
# 0: Rick Fox
# 1: Jim Fox
# 2: Dick Lee
# 3: Rock Lee
# 4: Rick Mount
# 5: Rick Robey
# 6: Ricky Ledo
# Pick one: 0
# Results for Rick Fox:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "A.C. Green"
# 11 results found.
# 0: A.C. Green
# 1: Josh Green
# 2: Danny Green
# 3: Erick Green
# 4: Jeff Green
# 5: Ken Green
# 6: Lamar Green
# 7: Mike Green
# 8: Sean Green
# 9: Si Green
# 10: A.J. Price
# Pick one: 0
# Results for A.C. Green:
#
# You searched for "Ron Harper"
# ...

# %%
# removed Shaquille O'Neal

LAL_2001_gamelog = []


for p in LAL_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2001_gamelog.append(player_log)
LAL_2001_gamelog = pd.concat(LAL_2001_gamelog)    
LAL_2001_gamelogs = LAL_2001_gamelog.copy()
LAL_2001_gamelogs['GAME_SCORE'] = LAL_2001_gamelogs['GAME_SCORE'].astype(float)
LAL_2001_games = LAL_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2001_games_csv = LAL_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2001_games.csv', index=False)
LAL_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2001_games.csv')
LAL_2001_games_proc.head()
# Out:
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Greg Foster"
# 12 results found.
# 0: Greg Foster
# 1: Fred Foster
# 2: Rod Foster
# 3: Greg Butler
# 4: Jeff Foster
# 5: Greg Hyder
# 6: Greg Kelser
# 7: Greg Kite
# 8: Greg Oden
# 9: Greg Ostertag
# 10: Greg Monroe
# 11: Greg Stokes
# Pick one: 0
# Results for Greg Foster:
#
# You searched for "Rick Fox"
# 7 results found.
# 0: Rick Fox
# 1: Jim Fox
# 2: Dick Lee
# 3: Rock Lee
# 4: Rick Mount
# 5: Rick Robey
# 6: Ricky Ledo
# Pick one: 0
# Results for Rick Fox:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Horace Grant"
# 3 results found.
# 0: Horace Grant
# 1: Harvey Grant
# 2: Jerami Grant
# ...

# %%
# removed Shaquille O'Neal

LAL_2002_gamelog = []


for p in LAL_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2002_gamelog.append(player_log)
LAL_2002_gamelog = pd.concat(LAL_2002_gamelog)    
LAL_2002_gamelogs = LAL_2002_gamelog.copy()
LAL_2002_gamelogs['GAME_SCORE'] = LAL_2002_gamelogs['GAME_SCORE'].astype(float)
LAL_2002_games = LAL_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2002_games_csv = LAL_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2002_games.csv', index=False)
LAL_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2002_games.csv')
LAL_2002_games_proc.head()
# Out:
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Joe Crispin"
# 1 result found.
# Joe Crispin
# Results for Joe Crispin:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Rick Fox"
# 7 results found.
# 0: Rick Fox
# 1: Jim Fox
# 2: Dick Lee
# 3: Rock Lee
# 4: Rick Mount
# 5: Rick Robey
# 6: Ricky Ledo
# Pick one: 0
# Results for Rick Fox:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Robert Horry"
# 7 results found.
# 0: Robert Horry
# 1: Robert Hahn
# 2: Robert Hite
# 3: Robert Sacre
# 4: Robert Whaley
# 5: Robert Reid
# 6: Robert Smith
# Pick one: 0
# Results for Robert Horry:
#
# You searched for "Lindsey Hunter"
# 2 results found.
# 0: Lindsey Hunter
# 1: Vince Hunter
# ...

# %%
 # removed Shaquille O'Neal
    
LAL_2003_gamelog = []



for p in LAL_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2003_gamelog.append(player_log)
LAL_2003_gamelog = pd.concat(LAL_2003_gamelog)    
LAL_2003_gamelogs = LAL_2003_gamelog.copy()
LAL_2003_gamelogs['GAME_SCORE'] = LAL_2003_gamelogs['GAME_SCORE'].astype(float)
LAL_2003_games = LAL_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2003_games_csv = LAL_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2003_games.csv', index=False)
LAL_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2003_games.csv')
LAL_2003_games_proc.head()
# Out:
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Rick Fox"
# 7 results found.
# 0: Rick Fox
# 1: Jim Fox
# 2: Dick Lee
# 3: Rock Lee
# 4: Rick Mount
# 5: Rick Robey
# 6: Ricky Ledo
# Pick one: 0
# Results for Rick Fox:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Robert Horry"
# 7 results found.
# 0: Robert Horry
# 1: Robert Hahn
# 2: Robert Hite
# 3: Robert Sacre
# 4: Robert Whaley
# 5: Robert Reid
# 6: Robert Smith
# Pick one: 0
# Results for Robert Horry:
#
# You searched for "Mark Madsen"
# 10 results found.
# 0: Mark Madsen
# 1: Mark Macon
# 2: Mark Wade
# 3: Mark Acres
# 4: Mark Eaton
# 5: Lars Hansen
# 6: Mark Jackson
# 7: Mark Alarie
# ...

# %%
LAL_2004_gamelog = []



for p in LAL_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2004_gamelog.append(player_log)
LAL_2004_gamelog = pd.concat(LAL_2004_gamelog)    
LAL_2004_gamelogs = LAL_2004_gamelog.copy()
LAL_2004_gamelogs['GAME_SCORE'] = LAL_2004_gamelogs['GAME_SCORE'].astype(float)
LAL_2004_games = LAL_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2004_games_csv = LAL_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2004_games.csv', index=False)
LAL_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2004_games.csv')
LAL_2004_games_proc.head()
# Out:
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Maurice Carter"
# 6 results found.
# 0: Maurice Carter
# 1: Maurice Ager
# 2: Maurice Baker
# 3: Maurice Martin
# 4: Maurice McHartley
# 5: Maurice Taylor
# Pick one: 0
# Results for Maurice Carter:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Rick Fox"
# 7 results found.
# 0: Rick Fox
# 1: Jim Fox
# 2: Dick Lee
# 3: Rock Lee
# 4: Rick Mount
# 5: Rick Robey
# 6: Ricky Ledo
# Pick one: 0
# Results for Rick Fox:
#
# You searched for "Devean George"
# 1 result found.
# ...

# %%
LAL_2005_gamelog = []

for p in LAL_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2005_gamelog.append(player_log)
LAL_2005_gamelog = pd.concat(LAL_2005_gamelog)    
LAL_2005_gamelogs = LAL_2005_gamelog.copy()
LAL_2005_gamelogs['GAME_SCORE'] = LAL_2005_gamelogs['GAME_SCORE'].astype(float)
LAL_2005_games = LAL_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2005_games_csv = LAL_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2005_games.csv', index=False)
LAL_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2005_games.csv')
LAL_2005_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Tony Bobbitt"
# 3 results found.
# 0: Tony Bobbitt
# 1: Tony Bennett
# 2: Tony Battie
# Pick one: 0
# Results for Tony Bobbitt:
#
# You searched for "Tierre Brown"
# 8 results found.
# 0: Tierre Brown
# 1: Andre Brown
# 2: Dee Brown
# 3: Dee Brown
# 4: George Brown
# 5: Larry Brown
# 6: Mike Brown
# 7: Troy Brown
# Pick one: 0
# Results for Tierre Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# ...

# %%
LAL_2006_gamelog = []

for p in LAL_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2006_gamelog.append(player_log)
LAL_2006_gamelog = pd.concat(LAL_2006_gamelog)    
LAL_2006_gamelogs = LAL_2006_gamelog.copy()
LAL_2006_gamelogs['GAME_SCORE'] = LAL_2006_gamelogs['GAME_SCORE'].astype(float)
LAL_2006_games = LAL_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2006_games_csv = LAL_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2006_games.csv', index=False)
LAL_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2006_games.csv')
LAL_2006_games_proc.head()
# Out:
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Devean George"
# 1 result found.
# Devean George
# Results for Devean George:
#
# You searched for "Devin Green"
# 14 results found.
# 0: Devin Green
# 1: Devin Brown
# ...

# %%
LAL_2007_gamelog = []

for p in LAL_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2007_gamelog.append(player_log)
LAL_2007_gamelog = pd.concat(LAL_2007_gamelog)    
LAL_2007_gamelogs = LAL_2007_gamelog.copy()
LAL_2007_gamelogs['GAME_SCORE'] = LAL_2007_gamelogs['GAME_SCORE'].astype(float)
LAL_2007_games = LAL_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2007_games_csv = LAL_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2007_games.csv', index=False)
LAL_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2007_games.csv')
LAL_2007_games_proc.head()
# Out:
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# 4: Maurice Ager
# 5: Maurice Baker
# Pick one: 0
# ...

# %%
# removed Didier Ilunga-Mbenga

LAL_2008_gamelog = []

for p in LAL_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2008_gamelog.append(player_log)
LAL_2008_gamelog = pd.concat(LAL_2008_gamelog)    
LAL_2008_gamelogs = LAL_2008_gamelog.copy()
LAL_2008_gamelogs['GAME_SCORE'] = LAL_2008_gamelogs['GAME_SCORE'].astype(float)
LAL_2008_games = LAL_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2008_games_csv = LAL_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2008_games.csv', index=False)
LAL_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2008_games.csv')
LAL_2008_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Javaris Crittenton"
# 1 result found.
# Javaris Crittenton
# ...

# %%
# removed Didier Ilunga-Mbenga

LAL_2009_gamelog = []

for p in LAL_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2009_gamelog.append(player_log)
LAL_2009_gamelog = pd.concat(LAL_2009_gamelog)    
LAL_2009_gamelogs = LAL_2009_gamelog.copy()
LAL_2009_gamelogs['GAME_SCORE'] = LAL_2009_gamelogs['GAME_SCORE'].astype(float)
LAL_2009_games = LAL_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2009_games_csv = LAL_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2009_games.csv', index=False)
LAL_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2009_games.csv')
LAL_2009_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Jordan Farmar"
# 4 results found.
# 0: Jordan Farmar
# 1: Jordan Ford
# 2: Jordan McRae
# 3: Jordan Adams
# Pick one: 0
# Results for Jordan Farmar:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# ...

# %%
# removed Didier Ilunga-Mbenga
# removed metta world peace

LAL_2010_gamelog = []

for p in LAL_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2010_gamelog.append(player_log)
LAL_2010_gamelog = pd.concat(LAL_2010_gamelog)    
LAL_2010_gamelogs = LAL_2010_gamelog.copy()
LAL_2010_gamelogs['GAME_SCORE'] = LAL_2010_gamelogs['GAME_SCORE'].astype(float)
LAL_2010_games = LAL_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2010_games_csv = LAL_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2010_games.csv', index=False)
LAL_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2010_games.csv')
LAL_2010_games_proc.head()
# Out:
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Jordan Farmar"
# 4 results found.
# 0: Jordan Farmar
# 1: Jordan Ford
# 2: Jordan McRae
# 3: Jordan Adams
# Pick one: 0
# Results for Jordan Farmar:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# Results for Derek Fisher:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# ...

# %%
LAL_2011_gamelog = []

for p in LAL_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2011_gamelog.append(player_log)
LAL_2011_gamelog = pd.concat(LAL_2011_gamelog)    
LAL_2011_gamelogs = LAL_2011_gamelog.copy()
LAL_2011_gamelogs['GAME_SCORE'] = LAL_2011_gamelogs['GAME_SCORE'].astype(float)
LAL_2011_games = LAL_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2011_games_csv = LAL_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2011_games.csv', index=False)
LAL_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2011_games.csv')
LAL_2011_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# ...

# %%
# removed Metta World peace

LAL_2012_gamelog = []

for p in LAL_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2012_gamelog.append(player_log)
LAL_2012_gamelog = pd.concat(LAL_2012_gamelog)    
LAL_2012_gamelogs = LAL_2012_gamelog.copy()
LAL_2012_gamelogs['GAME_SCORE'] = LAL_2012_gamelogs['GAME_SCORE'].astype(float)
LAL_2012_games = LAL_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2012_games_csv = LAL_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2012_games.csv', index=False)
LAL_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2012_games.csv')
LAL_2012_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Andrew Bynum"
# 4 results found.
# 0: Andrew Bynum
# 1: Andrew Bogut
# 2: Andrew Lang
# 3: Andrew Toney
# Pick one: 0
# Results for Andrew Bynum:
#
# You searched for "Devin Ebanks"
# 1 result found.
# Devin Ebanks
# Results for Devin Ebanks:
#
# ...

# %%
LAL_2013_gamelog = []

for p in LAL_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2013_gamelog.append(player_log)
LAL_2013_gamelog = pd.concat(LAL_2013_gamelog)    
LAL_2013_gamelogs = LAL_2013_gamelog.copy()
LAL_2013_gamelogs['GAME_SCORE'] = LAL_2013_gamelogs['GAME_SCORE'].astype(float)
LAL_2013_games = LAL_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2013_games_csv = LAL_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2013_games.csv', index=False)
LAL_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2013_games.csv')
LAL_2013_games_proc.head()
# Out:
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# 4: Keon Clark
# 5: Earl Evans
# 6: Earl Lloyd
# Pick one: 0
# Results for Earl Clark:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# 3: Kris Dunn
# 4: Chris Johnson
# 5: Chris Johnson
# 6: Chris Kaman
# 7: Chris Mihm
# 8: Chris Mullin
# 9: Chris Munk
# 10: Chris Bosh
# 11: Chris Ford
# 12: Chris Jent
# 13: Chris King
# 14: Chris Smith
# 15: Chris Smith
# Pick one: 0
# ...

# %%
LAL_2014_gamelog = []

for p in LAL_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2014_gamelog.append(player_log)
LAL_2014_gamelog = pd.concat(LAL_2014_gamelog)    
LAL_2014_gamelogs = LAL_2014_gamelog.copy()
LAL_2014_gamelogs['GAME_SCORE'] = LAL_2014_gamelogs['GAME_SCORE'].astype(float)
LAL_2014_games = LAL_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2014_games_csv = LAL_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2014_games.csv', index=False)
LAL_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2014_games.csv')
LAL_2014_games_proc.head()
# Out:
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "MarShon Brooks"
# 2 results found.
# 0: MarShon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for MarShon Brooks:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Jordan Farmar"
# 4 results found.
# 0: Jordan Farmar
# 1: Jordan Ford
# 2: Jordan McRae
# 3: Jordan Adams
# Pick one: 0
# Results for Jordan Farmar:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# ...

# %%
LAL_2015_gamelog = []

for p in LAL_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2015_gamelog.append(player_log)
LAL_2015_gamelog = pd.concat(LAL_2015_gamelog)    
LAL_2015_gamelogs = LAL_2015_gamelog.copy()
LAL_2015_gamelogs['GAME_SCORE'] = LAL_2015_gamelogs['GAME_SCORE'].astype(float)
LAL_2015_games = LAL_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2015_games_csv = LAL_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2015_games.csv', index=False)
LAL_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2015_games.csv')
LAL_2015_games_proc.head()
# Out:
# You searched for "Tarik Black"
# 3 results found.
# 0: Tarik Black
# 1: Charlie Black
# 2: Tom Black
# Pick one: 0
# Results for Tarik Black:
#
# You searched for "Vander Blue"
# 1 result found.
# Vander Blue
# Results for Vander Blue:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Jabari Brown"
# 5 results found.
# 0: Jabari Brown
# 1: Jabari Bird
# 2: Andre Brown
# 3: Jaylen Brown
# 4: Larry Brown
# Pick one: 0
# Results for Jabari Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Dwight Buycks"
# 1 result found.
# Dwight Buycks
# Results for Dwight Buycks:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# ...

# %%
# removed larry nance
# removed D'Angelo Russell

LAL_2016_gamelog = []

for p in LAL_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2016_gamelog.append(player_log)
LAL_2016_gamelog = pd.concat(LAL_2016_gamelog)    
LAL_2016_gamelogs = LAL_2016_gamelog.copy()
LAL_2016_gamelogs['GAME_SCORE'] = LAL_2016_gamelogs['GAME_SCORE'].astype(float)
LAL_2016_games = LAL_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2016_games_csv = LAL_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2016_games.csv', index=False)
LAL_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2016_games.csv')
LAL_2016_games_proc.head()
# Out:
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Tarik Black"
# 3 results found.
# 0: Tarik Black
# 1: Charlie Black
# 2: Tom Black
# Pick one: 0
# Results for Tarik Black:
#
# You searched for "Anthony Brown"
# 8 results found.
# 0: Anthony Brown
# 1: Anthony Bowie
# 2: Tony Brown
# 3: Anthony Bonner
# 4: Troy Brown
# 5: Anthony Cook
# 6: Anthony Mason
# 7: Anthony Morrow
# Pick one: 0
# Results for Anthony Brown:
#
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Roy Hibbert"
# 2 results found.
# 0: Roy Hibbert
# 1: Ray Tolbert
# Pick one: 0
# Results for Roy Hibbert:
#
# ...

# %%
LAL_2017_gamelog = []

for p in LAL_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2017_gamelog.append(player_log)
LAL_2017_gamelog = pd.concat(LAL_2017_gamelog)    
LAL_2017_gamelogs = LAL_2017_gamelog.copy()
LAL_2017_gamelogs['GAME_SCORE'] = LAL_2017_gamelogs['GAME_SCORE'].astype(float)
LAL_2017_games = LAL_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2017_games_csv = LAL_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2017_games.csv', index=False)
LAL_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2017_games.csv')
LAL_2017_games_proc.head()
# Out:
# You searched for "Tarik Black"
# 3 results found.
# 0: Tarik Black
# 1: Charlie Black
# 2: Tom Black
# Pick one: 0
# Results for Tarik Black:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Tyler Ennis"
# 6 results found.
# 0: Tyler Ennis
# 1: Tyler Davis
# 2: Tyler Ulis
# 3: James Ennis
# 4: Tyler Herro
# 5: Tyler Lydon
# Pick one: 0
# Results for Tyler Ennis:
#
# You searched for "Marcelo Huertas"
# 1 result found.
# Marcelo Huertas
# Results for Marcelo Huertas:
#
# You searched for "Brandon Ingram"
# 4 results found.
# 0: Brandon Ingram
# ...

# %%
# dropped gary payton (jr)

LAL_2018_gamelog = []

for p in LAL_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2018_gamelog.append(player_log)
LAL_2018_gamelog = pd.concat(LAL_2018_gamelog)    
LAL_2018_gamelogs = LAL_2018_gamelog.copy()
LAL_2018_gamelogs['GAME_SCORE'] = LAL_2018_gamelogs['GAME_SCORE'].astype(float)
LAL_2018_games = LAL_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2018_games_csv = LAL_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2018_games.csv', index=False)
LAL_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2018_games.csv')
LAL_2018_games_proc.head()
# Out:
# You searched for "Lonzo Ball"
# 4 results found.
# 0: Lonzo Ball
# 1: LaMelo Ball
# 2: Donta Hall
# 3: Alonzo Gee
# Pick one: 0
# Results for Lonzo Ball:
#
# You searched for "Vander Blue"
# 1 result found.
# Vander Blue
# Results for Vander Blue:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Thomas Bryant"
# 2 results found.
# 0: Thomas Bryant
# 1: Thomas Jordan
# Pick one: 0
# Results for Thomas Bryant:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Alex Caruso"
# 6 results found.
# 0: Alex Caruso
# 1: Al Carlson
# 2: Alex Garcia
# 3: Alex Scales
# 4: Alex Groza
# ...

# %%
LAL_2019_gamelog = []

for p in LAL_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2019_gamelog.append(player_log)
LAL_2019_gamelog = pd.concat(LAL_2019_gamelog)    
LAL_2019_gamelogs = LAL_2019_gamelog.copy()
LAL_2019_gamelogs['GAME_SCORE'] = LAL_2019_gamelogs['GAME_SCORE'].astype(float)
LAL_2019_games = LAL_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2019_games_csv = LAL_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2019_games.csv', index=False)
LAL_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2019_games.csv')
LAL_2019_games_proc.head()
# Out:
# You searched for "Lonzo Ball"
# 4 results found.
# 0: Lonzo Ball
# 1: LaMelo Ball
# 2: Donta Hall
# 3: Alonzo Gee
# Pick one: 0
# Results for Lonzo Ball:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Isaac Bonga"
# 2 results found.
# 0: Isaac Bonga
# 1: Isaac Okoro
# Pick one: 0
# Results for Isaac Bonga:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Alex Caruso"
# 6 results found.
# 0: Alex Caruso
# 1: Al Carlson
# 2: Alex Garcia
# 3: Alex Scales
# 4: Alex Groza
# 5: Alex Hannum
# Pick one: 0
# Results for Alex Caruso:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# ...

# %%
LAL_2020_gamelog = []

for p in LAL_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2020_gamelog.append(player_log)
LAL_2020_gamelog = pd.concat(LAL_2020_gamelog)    
LAL_2020_gamelogs = LAL_2020_gamelog.copy()
LAL_2020_gamelogs['GAME_SCORE'] = LAL_2020_gamelogs['GAME_SCORE'].astype(float)
LAL_2020_games = LAL_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2020_games_csv = LAL_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2020_games.csv', index=False)
LAL_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2020_games.csv')
LAL_2020_games_proc.head()
# Out:
# You searched for "Kostas Antetokounmpo"
# 1 result found.
# Kostas Antetokounmpo
# Results for Kostas Antetokounmpo:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Devontae Cacok"
# 1 result found.
# Devontae Cacok
# Results for Devontae Cacok:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Alex Caruso"
# 6 results found.
# 0: Alex Caruso
# 1: Al Carlson
# 2: Alex Garcia
# 3: Alex Scales
# 4: Alex Groza
# 5: Alex Hannum
# Pick one: 0
# Results for Alex Caruso:
#
# You searched for "Quinn Cook"
# 3 results found.
# 0: Quinn Cook
# 1: Brian Cook
# 2: Quincy Acy
# Pick one: 0
# Results for Quinn Cook:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# 2: Lloyd Daniels
# 3: Mel Daniels
# ...

# %%
LAL_2021_gamelog = []

for p in LAL_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    LAL_2021_gamelog.append(player_log)
LAL_2021_gamelog = pd.concat(LAL_2021_gamelog)    
LAL_2021_gamelogs = LAL_2021_gamelog.copy()
LAL_2021_gamelogs['GAME_SCORE'] = LAL_2021_gamelogs['GAME_SCORE'].astype(float)
LAL_2021_games = LAL_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_2021_games_csv = LAL_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2021_games.csv', index=False)
LAL_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2021_games.csv')
LAL_2021_games_proc.head()
# Out:
# You searched for "Kostas Antetokounmpo"
# 1 result found.
# Kostas Antetokounmpo
# Results for Kostas Antetokounmpo:
#
# You searched for "Devontae Cacok"
# 1 result found.
# Devontae Cacok
# Results for Devontae Cacok:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Alex Caruso"
# 6 results found.
# 0: Alex Caruso
# 1: Al Carlson
# 2: Alex Garcia
# 3: Alex Scales
# 4: Alex Groza
# 5: Alex Hannum
# Pick one: 0
# Results for Alex Caruso:
#
# You searched for "Quinn Cook"
# 3 results found.
# 0: Quinn Cook
# 1: Brian Cook
# 2: Quincy Acy
# Pick one: 0
# Results for Quinn Cook:
#
# You searched for "Anthony Davis"
# 9 results found.
# 0: Anthony Davis
# 1: Antonio Davis
# 2: Anthony Edwards
# 3: Anthony Lamb
# 4: Anthony Avent
# 5: Anthony Bowie
# 6: Johnny Davis
# 7: Anthony Jones
# 8: Anthony Mason
# Pick one: 0
# Results for Anthony Davis:
#
# You searched for "Andre Drummond"
# ...

# %% [markdown]
# ## Shaq Files

# %%
Shaq_2000_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/Shaq_2000_games.csv')
Shaq_2001_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/Shaq_2001_games.csv')
Shaq_2002_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/Shaq_2002_games.csv')
Shaq_2003_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/Shaq_2003_games.csv')
Shaq_2004_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/Shaq_2004_games.csv')

# %%
Shaq_2000_games.columns
# Out:
# Index(['Rk', 'G', 'Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'],
#       dtype='object')

# %%
# 2000
Shaq_2000_games_io = Shaq_2000_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2000_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2000_games_io['Player'] = player
Shaq_2000_games_io.head()
# Out:
# <ipython-input-31-f93231b43f04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2000_games_io['Player'] = player
#       DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  11/2/99  27-241  LAL         @      UTA   W (+7)  1  34:26:00   9.0  20.0
# 1  11/3/99  27-242  LAL       NaN      VAN  W (+15)  1  33:55:00  13.0  22.0
# 2  11/6/99  27-245  LAL         @      POR  L (-15)  1  33:08:00   9.0  14.0
# 3  11/7/99  27-246  LAL       NaN      DAL   W (+8)  1  37:04:00  10.0  14.0
# 4  11/9/99  27-248  LAL         @      DAL  W (+22)  1  38:09:00  12.0  16.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...  13.0  1.0  1.0  2.0  2.0  4.0  23.0        15.6  16.0
# ...

# %%
# 2001
Shaq_2001_games_io = Shaq_2001_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2001_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2001_games_io['Player'] = player
Shaq_2001_games_io.head()
# Out:
# <ipython-input-34-1f369cc46ff3>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2001_games_io['Player'] = player
#        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  10/31/00  28-239  LAL         @      POR  W (+10)  1  43:21:00  14.0  20.0
# 1   11/1/00  28-240  LAL       NaN      UTA   L (-5)  1  43:21:00  14.0  20.0
# 2   11/4/00  28-243  LAL         @      VAN   W (+9)  1  40:56:00  12.0  20.0
# 3   11/5/00  28-244  LAL       NaN      LAC   W (+5)  1  42:31:00  15.0  31.0
# 4   11/7/00  28-246  LAL         @      HOU  L (-10)  1  45:01:00   8.0  19.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...  11.0  5.0  1.0  4.0  1.0  1.0  36.0        34.8   7.0
# ...

# %%
#2002
Shaq_2002_games_io = Shaq_2002_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2002_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2002_games_io['Player'] = player
Shaq_2002_games_io.head()
# Out:
# <ipython-input-35-946b2ed762b2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2002_games_io['Player'] = player
#        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  10/30/01  29-238  LAL       NaN      POR  W (+11)  1  40:11:00  10.0  23.0
# 1   11/1/01  29-240  LAL         @      UTA   W (+4)  1  38:14:00  11.0  22.0
# 2   11/2/01  29-241  LAL       NaN      PHO  W (+23)  1  34:28:00  10.0  21.0
# 3   11/4/01  29-243  LAL       NaN      UTA   W (+4)  1  40:45:00  10.0  15.0
# 4   11/9/01  29-248  LAL       NaN      MEM  W (+24)  1  28:22:00   8.0  15.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...  18.0  5.0  1.0  5.0  3.0  3.0  29.0        25.3  10.0
# ...

# %%
#2003
Shaq_2003_games_io = Shaq_2003_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2003_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2003_games_io['Player'] = player
Shaq_2003_games_io.head()
# Out:
# <ipython-input-36-d496bdfb34f8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2003_games_io['Player'] = player
#        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  11/22/02  30-261  LAL       NaN      CHI  W (+13)  0     21:28   8.0  13.0
# 1  11/24/02  30-263  LAL       NaN      MIL  W (+12)  1  27:45:00  10.0  18.0
# 2  11/26/02  30-265  LAL         @      MIA  L (-12)  1  32:08:00   5.0  15.0
# 3  11/27/02  30-266  LAL         @      ORL  L (-10)  1  35:47:00  11.0  20.0
# 4  11/29/02  30-268  LAL         @      MEM   W (+6)  1  42:48:00  13.0  27.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...   7.0  0.0  1.0  0.0  3.0  1.0  17.0        11.2  14.0
# ...

# %%
#2004
Shaq_2004_games_io = Shaq_2004_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2004_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2004_games_io['Player'] = player
Shaq_2004_games_io.head()
# Out:
# <ipython-input-37-fafc21551df9>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2004_games_io['Player'] = player
#        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  10/28/03  31-236  LAL       NaN      DAL  W (+16)  1  31:09:00   8.0  15.0
# 1   11/1/03  31-240  LAL         @      PHO   W (+4)  1  39:17:00  11.0  19.0
# 2   11/2/03  31-241  LAL       NaN      GSW  W (+15)  1  39:21:00   8.0  19.0
# 3   11/4/03  31-243  LAL         @      MIL   W (+6)  1  38:39:00   9.0  15.0
# 4   11/6/03  31-245  LAL         @      SAS   W (+3)  1  50:17:00  12.0  23.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...   9.0  5.0  0.0  1.0  3.0  4.0  16.0        10.2  17.0
# ...

# %% [markdown]
# ## combine all seasons

# %%
LAL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2000_games.csv')
LAL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2001_games.csv')
LAL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2002_games.csv')
LAL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2003_games.csv')
LAL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2004_games.csv')
LAL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2005_games.csv')
LAL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2006_games.csv')
LAL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2007_games.csv')
LAL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2008_games.csv')
LAL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2009_games.csv')
LAL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2010_games.csv')
LAL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2011_games.csv')
LAL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2012_games.csv')
LAL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2013_games.csv')
LAL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2014_games.csv')
LAL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2015_games.csv')
LAL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2016_games.csv')
LAL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2017_games.csv')
LAL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2018_games.csv')
LAL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2019_games.csv')
LAL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2020_games.csv')
LAL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2021_games.csv')

# %%
# Out:
# <ipython-input-27-f93231b43f04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2000_games_io['Player'] = player
#       DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG   FGA  \
# 0  11/2/99  27-241  LAL         @      UTA   W (+7)  1  34:26:00   9.0  20.0
# 1  11/3/99  27-242  LAL       NaN      VAN  W (+15)  1  33:55:00  13.0  22.0
# 2  11/6/99  27-245  LAL         @      POR  L (-15)  1  33:08:00   9.0  14.0
# 3  11/7/99  27-246  LAL       NaN      DAL   W (+8)  1  37:04:00  10.0  14.0
# 4  11/9/99  27-248  LAL         @      DAL  W (+22)  1  38:09:00  12.0  16.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...  13.0  1.0  1.0  2.0  2.0  4.0  23.0        15.6  16.0
# ...

# %%
LAL_2000_games_io.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2000-03-12  21-202  LAL      HOME      SAC   W (+3)   1  43:00  15   24
# 1  2000-01-10  21-140  LAL      HOME      DEN  W (+35)   1  36:00  12   18
# 2  2000-04-14  21-235  LAL      HOME      SAC   W (+7)   1  39:46  13   21
# 3  2000-02-07  21-168  LAL      HOME      DEN   W (+8)   1  41:50  10   21
# 4  2000-03-24  21-214  LAL      HOME      PHO   W (+8)   1  33:13   9   15
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-       Player
# 0  ...   10    8    0    1    4   3   40        34.1   -5  Kobe Bryant
# 1  ...    7    4    4    1    1   2   30        31.6   38  Kobe Bryant
# 2  ...    5    5    3    3    1   1   31        29.8   10  Kobe Bryant
# 3  ...    9   11    1    3    4   2   29        27.0    7  Kobe Bryant
# 4  ...    6    7    2    0    1   5   28        26.8    6  Kobe Bryant
#
# [5 rows x 29 columns]

# %%
LAL_season_dfs = [LAL_2000_games_io, LAL_2001_games_io, LAL_2002_games_io, LAL_2003_games_io, LAL_2004_games_io, LAL_2005_games_io,
                 LAL_2006_games_io, LAL_2007_games_io, LAL_2008_games_io, LAL_2009_games_io, LAL_2010_games_io, LAL_2011_games_io,
                 LAL_2012_games_io, LAL_2013_games_io, LAL_2014_games_io, LAL_2015_games_io, LAL_2016_games_io, LAL_2017_games_io,
                 LAL_2018_games_io, LAL_2019_games_io, LAL_2020_games_io, LAL_2021_games_io, Shaq_2000_games_io,
                 Shaq_2001_games_io, Shaq_2002_games_io, Shaq_2003_games_io, Shaq_2004_games_io]

# %%
LAL_all = pd.concat(LAL_season_dfs)
LAL_all_sorted = LAL_all.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_all_sorted.head(25)
# Out:
#           DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP    FG  \
# 0   2006-01-22  27-152  LAL      HOME      TOR  W (+18)  1     41:56  28.0
# 0   2007-03-16  28-205  LAL      HOME      POR   W (+5)  1     49:58  23.0
# 1   2005-12-20  27-119  LAL      HOME      DAL  W (+22)  1     32:53  18.0
# 60      3/6/00  28-000  LAL         @      LAC  W (+20)  1  44:52:00  24.0
# 0   2019-12-08  26-272  LAL      HOME      MIN  W (+17)  1     39:16  20.0
# 0   2009-02-02  30-163  LAL      AWAY      NYK   W (+9)  1     36:48  19.0
# 0   2002-01-14  23-144  LAL      HOME      MEM  W (+39)  1     34:16  21.0
# 1   2007-04-15  28-235  LAL      HOME      SEA  W (+11)  1     42:05  18.0
# 0   2018-11-14  33-319  LAL      HOME      POR   W (+9)  1     36:00  13.0
# 2   2007-03-22  28-211  LAL      AWAY      MEM   W (+2)  1     45:11  20.0
# 0   2013-04-10  34-230  LAL      AWAY      POR   W (+7)  1     48:00  14.0
# ...
