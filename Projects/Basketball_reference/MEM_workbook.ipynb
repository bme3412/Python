# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2002
appended_data_MEM = []

# MEM
while season <= 2021:
    df_MEM = get_roster('MEM', season)
    df_MEM['Season'] = season
    df_MEM['Team'] = 'MEM'
    appended_data_MEM.append(df_MEM)
    season = season + 1
appended_data_MEM = pd.concat(appended_data_MEM)

# %%
MEM_df_all = appended_data_MEM.copy()
MEM_df_all_csv = MEM_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_players_all.csv', index=False)
MEM_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_players_all.csv')
MEM_df_all_csv_io.head()
# Out:
#    NUMBER             PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      25      Nick Anderson  SG    6-6     205  1968-01-20          US
# 1       9       Isaac Austin   C   6-10     255  1969-08-18          US
# 2      31      Shane Battier  SF    6-8     220  1978-09-09          US
# 3      32      Rodney Buford  SG    6-5     189  1977-11-02          US
# 4       8  Michael Dickerson  SG    6-5     190  1975-06-25          US
#
#   EXPERIENCE        COLLEGE  Season Team
# 0         12       Illinois    2002  MEM
# 1          8  Arizona State    2002  MEM
# 2          R           Duke    2002  MEM
# 3          2      Creighton    2002  MEM
# 4          3        Arizona    2002  MEM

# %%
#MEM_df_2000 = MEM_df_all[MEM_df_all['Season'] == 2000]
#MEM_df_2001 = MEM_df_all[MEM_df_all['Season'] == 2001]
MEM_df_2002 = MEM_df_all[MEM_df_all['Season'] == 2002]
MEM_df_2003 = MEM_df_all[MEM_df_all['Season'] == 2003]
MEM_df_2004 = MEM_df_all[MEM_df_all['Season'] == 2004]
MEM_df_2005 = MEM_df_all[MEM_df_all['Season'] == 2005]
MEM_df_2006 = MEM_df_all[MEM_df_all['Season'] == 2006]
MEM_df_2007 = MEM_df_all[MEM_df_all['Season'] == 2007]
MEM_df_2008 = MEM_df_all[MEM_df_all['Season'] == 2008]
MEM_df_2009 = MEM_df_all[MEM_df_all['Season'] == 2009]
MEM_df_2010 = MEM_df_all[MEM_df_all['Season'] == 2010]
MEM_df_2011 = MEM_df_all[MEM_df_all['Season'] == 2011]
MEM_df_2012 = MEM_df_all[MEM_df_all['Season'] == 2012]
MEM_df_2013 = MEM_df_all[MEM_df_all['Season'] == 2013]
MEM_df_2014 = MEM_df_all[MEM_df_all['Season'] == 2014]
MEM_df_2015 = MEM_df_all[MEM_df_all['Season'] == 2015]
MEM_df_2016 = MEM_df_all[MEM_df_all['Season'] == 2016]
MEM_df_2017 = MEM_df_all[MEM_df_all['Season'] == 2017]
MEM_df_2018 = MEM_df_all[MEM_df_all['Season'] == 2018]
MEM_df_2019 = MEM_df_all[MEM_df_all['Season'] == 2019]
MEM_df_2020 = MEM_df_all[MEM_df_all['Season'] == 2020]
MEM_df_2021 = MEM_df_all[MEM_df_all['Season'] == 2021]

# %%
# changing names
#MEM_df_2002.loc[MEM_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#MEM_df_2004.loc[MEM_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
#MEM_df_2000_players = MEM_df_2000['PLAYER'].to_list()
#MEM_df_2001_players = MEM_df_2001['PLAYER'].to_list()
MEM_df_2002_players = MEM_df_2002['PLAYER'].to_list()
MEM_df_2003_players = MEM_df_2003['PLAYER'].to_list()
MEM_df_2004_players = MEM_df_2004['PLAYER'].to_list()
MEM_df_2005_players = MEM_df_2005['PLAYER'].to_list()

MEM_df_2006_players = MEM_df_2006['PLAYER'].to_list()
MEM_df_2007_players = MEM_df_2007['PLAYER'].to_list()
MEM_df_2008_players = MEM_df_2008['PLAYER'].to_list()
MEM_df_2009_players = MEM_df_2009['PLAYER'].to_list()
MEM_df_2010_players = MEM_df_2010['PLAYER'].to_list()
MEM_df_2011_players = MEM_df_2011['PLAYER'].to_list()

MEM_df_2012_players = MEM_df_2012['PLAYER'].to_list()
MEM_df_2013_players = MEM_df_2013['PLAYER'].to_list()
MEM_df_2014_players = MEM_df_2014['PLAYER'].to_list()
MEM_df_2015_players = MEM_df_2015['PLAYER'].to_list()
MEM_df_2016_players = MEM_df_2016['PLAYER'].to_list()
MEM_df_2017_players = MEM_df_2017['PLAYER'].to_list()

MEM_df_2018_players = MEM_df_2018['PLAYER'].to_list()
MEM_df_2019_players = MEM_df_2019['PLAYER'].to_list()
MEM_df_2020_players = MEM_df_2020['PLAYER'].to_list()
MEM_df_2021_players = MEM_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#MEM_df_2008_players.remove("Bobby Jones")
#MEM_df_2008_players.remove("Juan Carlos Navarro")
#MEM_df_2016_players.remove("P.J. Hairston")
#MEM_df_2016_players.remove("Xavier Munford")
#MEM_df_2019_players.remove("Jaren Jackson")
#MEM_df_2020_players.remove("Jaren Jackson")
#MEM_df_2021_players.remove("Jaren Jackson")
MEM_df_2021_players.remove("Xavier Tillman")

# %%
MEM_2002_gamelog = []


for p in MEM_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2002_gamelog.append(player_log)
MEM_2002_gamelog = pd.concat(MEM_2002_gamelog)    
MEM_2002_gamelogs = MEM_2002_gamelog.copy()
MEM_2002_gamelogs['GAME_SCORE'] = MEM_2002_gamelogs['GAME_SCORE'].astype(float)
MEM_2002_games = MEM_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2002_games_csv = MEM_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2002_games.csv', index=False)
MEM_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2002_games.csv')
MEM_2002_games_proc.head()
# Out:
# You searched for "Nick Anderson"
# 14 results found.
# 0: Nick Anderson
# 1: Eric Anderson
# 2: Kim Anderson
# 3: Alan Anderson
# 4: Cliff Anderson
# 5: Dan Anderson
# 6: Dan Anderson
# 7: Derek Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: Kyle Anderson
# 11: Ron Anderson
# 12: Ryan Anderson
# 13: Rick Roberson
# Pick one: 0
# Results for Nick Anderson:
#
# You searched for "Isaac Austin"
# 1 result found.
# Isaac Austin
# Results for Isaac Austin:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Rodney Buford"
# 2 results found.
# 0: Rodney Buford
# 1: Rodney Hood
# Pick one: 0
# Results for Rodney Buford:
#
# You searched for "Michael Dickerson"
# 3 results found.
# 0: Michael Dickerson
# 1: Michael Anderson
# 2: Michael Jackson
# Pick one: 0
# Results for Michael Dickerson:
#
# You searched for "Isaac Fontaine"
# 1 result found.
# Isaac Fontaine
# Results for Isaac Fontaine:
#
# ...

# %%
    
MEM_2003_gamelog = []



for p in MEM_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2003_gamelog.append(player_log)
MEM_2003_gamelog = pd.concat(MEM_2003_gamelog)    
MEM_2003_gamelogs = MEM_2003_gamelog.copy()
MEM_2003_gamelogs['GAME_SCORE'] = MEM_2003_gamelogs['GAME_SCORE'].astype(float)
MEM_2003_games = MEM_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2003_games_csv = MEM_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2003_games.csv', index=False)
MEM_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2003_games.csv')
MEM_2003_games_proc.head()
# Out:
# You searched for "Robert Archibald"
# 1 result found.
# Robert Archibald
# Results for Robert Archibald:
#
# You searched for "Mike Batiste"
# 8 results found.
# 0: Mike Batiste
# 1: Mike Barrett
# 2: Mike Davis
# 3: Mike Davis
# 4: Mike Bantom
# 5: Mike Butler
# 6: Mike Ratliff
# 7: Mickey Davis
# Pick one: 0
# Results for Mike Batiste:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Michael Dickerson"
# 3 results found.
# 0: Michael Dickerson
# 1: Michael Anderson
# 2: Michael Jackson
# Pick one: 0
# Results for Michael Dickerson:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# ...

# %%
MEM_2004_gamelog = []



for p in MEM_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2004_gamelog.append(player_log)
MEM_2004_gamelog = pd.concat(MEM_2004_gamelog)    
MEM_2004_gamelogs = MEM_2004_gamelog.copy()
MEM_2004_gamelogs['GAME_SCORE'] = MEM_2004_gamelogs['GAME_SCORE'].astype(float)
MEM_2004_games = MEM_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2004_games_csv = MEM_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2004_games.csv', index=False)
MEM_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2004_games.csv')
MEM_2004_games_proc.head()
# Out:
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Troy Bell"
# 8 results found.
# 0: Troy Bell
# 1: Raja Bell
# 2: Troy Brown
# 3: Tony Delk
# 4: Tom Kelly
# 5: Tony Snell
# 6: Trey Burke
# 7: Bo Ellis
# Pick one: 0
# Results for Troy Bell:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Ryan Humphrey"
# 1 result found.
# Ryan Humphrey
# Results for Ryan Humphrey:
#
# You searched for "Dahntay Jones"
# 5 results found.
# 0: Dahntay Jones
# 1: Damian Jones
# 2: Dontae' Jones
# 3: Johnny Jones
# 4: Wah Wah Jones
# Pick one: 0
# Results for Dahntay Jones:
#
# You searched for "Mike Miller"
# 26 results found.
# 0: Mike Miller
# 1: Mike Butler
# 2: Bill Miller
# 3: Dick Miller
# 4: Mike Niles
# 5: Mike Conley
# 6: Mike Farmer
# 7: Mike Gale
# ...

# %%
MEM_2005_gamelog = []

for p in MEM_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2005_gamelog.append(player_log)
MEM_2005_gamelog = pd.concat(MEM_2005_gamelog)    
MEM_2005_gamelogs = MEM_2005_gamelog.copy()
MEM_2005_gamelogs['GAME_SCORE'] = MEM_2005_gamelogs['GAME_SCORE'].astype(float)
MEM_2005_games = MEM_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2005_games_csv = MEM_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2005_games.csv', index=False)
MEM_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2005_games.csv')
MEM_2005_games_proc.head()
# Out:
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Antonio Burks"
# 2 results found.
# 0: Antonio Burks
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Burks:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Andre Emmett"
# 2 results found.
# 0: Andre Emmett
# 1: Andre Barrett
# Pick one: 0
# Results for Andre Emmett:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Ryan Humphrey"
# 1 result found.
# Ryan Humphrey
# Results for Ryan Humphrey:
#
# You searched for "Dahntay Jones"
# 5 results found.
# 0: Dahntay Jones
# 1: Damian Jones
# 2: Dontae' Jones
# 3: Johnny Jones
# 4: Wah Wah Jones
# Pick one: 0
# ...

# %%
MEM_2006_gamelog = []

for p in MEM_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2006_gamelog.append(player_log)
MEM_2006_gamelog = pd.concat(MEM_2006_gamelog)    
MEM_2006_gamelogs = MEM_2006_gamelog.copy()
MEM_2006_gamelogs['GAME_SCORE'] = MEM_2006_gamelogs['GAME_SCORE'].astype(float)
MEM_2006_games = MEM_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2006_games_csv = MEM_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2006_games.csv', index=False)
MEM_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2006_games.csv')
MEM_2006_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Antonio Burks"
# 2 results found.
# 0: Antonio Burks
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Burks:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Bobby Jackson"
# 10 results found.
# 0: Bobby Jackson
# 1: Tony Jackson
# 2: Tony Jackson
# 3: Bobby Watson
# 4: Josh Jackson
# 5: Tracy Jackson
# 6: Bobby Wilson
# 7: Bobby Wilson
# 8: Bobby Jones
# 9: Bobby Jones
# Pick one: 0
# Results for Bobby Jackson:
#
# You searched for "Dahntay Jones"
# ...

# %%
MEM_2007_gamelog = []

for p in MEM_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2007_gamelog.append(player_log)
MEM_2007_gamelog = pd.concat(MEM_2007_gamelog)    
MEM_2007_gamelogs = MEM_2007_gamelog.copy()
MEM_2007_gamelogs['GAME_SCORE'] = MEM_2007_gamelogs['GAME_SCORE'].astype(float)
MEM_2007_games = MEM_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2007_games_csv = MEM_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2007_games.csv', index=False)
MEM_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2007_games.csv')
MEM_2007_games_proc.head()
# Out:
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Will Conroy"
# 6 results found.
# 0: Will Conroy
# 1: Will Cherry
# 2: Bill Crow
# 3: Bill Henry
# 4: Will Barton
# 5: Willie Long
# Pick one: 0
# Results for Will Conroy:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# You searched for "Junior Harrington"
# 1 result found.
# Junior Harrington
# Results for Junior Harrington:
#
# You searched for "Alexander Johnson"
# 1 result found.
# Alexander Johnson
# ...

# %%
# removed bobby jones
# removed Juan Carlos Navarro

MEM_2008_gamelog = []

for p in MEM_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2008_gamelog.append(player_log)
MEM_2008_gamelog = pd.concat(MEM_2008_gamelog)    
MEM_2008_gamelogs = MEM_2008_gamelog.copy()
MEM_2008_gamelogs['GAME_SCORE'] = MEM_2008_gamelogs['GAME_SCORE'].astype(float)
MEM_2008_games = MEM_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2008_games_csv = MEM_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2008_games.csv', index=False)
MEM_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2008_games.csv')
MEM_2008_games_proc.head()
# Out:
# You searched for "Andre Brown"
# 15 results found.
# 0: Andre Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Randy Brown
# 4: Bruce Brown
# 5: Damone Brown
# 6: Fred Brown
# 7: George Brown
# 8: Jabari Brown
# 9: Kwame Brown
# 10: Larry Brown
# 11: Mike Brown
# 12: Tierre Brown
# 13: Andre Moore
# 14: Andre Owens
# Pick one: 0
# Results for Andre Brown:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# ...

# %%
MEM_2009_gamelog = []

for p in MEM_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2009_gamelog.append(player_log)
MEM_2009_gamelog = pd.concat(MEM_2009_gamelog)    
MEM_2009_gamelogs = MEM_2009_gamelog.copy()
MEM_2009_gamelogs['GAME_SCORE'] = MEM_2009_gamelogs['GAME_SCORE'].astype(float)
MEM_2009_games = MEM_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2009_games_csv = MEM_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2009_games.csv', index=False)
MEM_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2009_games.csv')
MEM_2009_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# Results for Mike Conley:
#
# You searched for "Javaris Crittenton"
# 1 result found.
# Javaris Crittenton
# Results for Javaris Crittenton:
#
# You searched for "Adonal Foyle"
# 2 results found.
# 0: Adonal Foyle
# 1: Donald Royal
# Pick one: 0
# Results for Adonal Foyle:
#
# You searched for "Marc Gasol"
# ...

# %%
MEM_2010_gamelog = []

for p in MEM_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2010_gamelog.append(player_log)
MEM_2010_gamelog = pd.concat(MEM_2010_gamelog)    
MEM_2010_gamelogs = MEM_2010_gamelog.copy()
MEM_2010_gamelogs['GAME_SCORE'] = MEM_2010_gamelogs['GAME_SCORE'].astype(float)
MEM_2010_games = MEM_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2010_games_csv = MEM_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2010_games.csv', index=False)
MEM_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2010_games.csv')
MEM_2010_games_proc.head()
# Out:
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# Results for Mike Conley:
#
# You searched for "Marc Gasol"
# 7 results found.
# 0: Marc Gasol
# 1: Pau Gasol
# 2: Mark Eaton
# 3: Marc Jackson
# 4: Mark Macon
# 5: Mark Davis
# 6: Mark Davis
# ...

# %%
MEM_2011_gamelog = []

for p in MEM_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2011_gamelog.append(player_log)
MEM_2011_gamelog = pd.concat(MEM_2011_gamelog)    
MEM_2011_gamelogs = MEM_2011_gamelog.copy()
MEM_2011_gamelogs['GAME_SCORE'] = MEM_2011_gamelogs['GAME_SCORE'].astype(float)
MEM_2011_games = MEM_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2011_games_csv = MEM_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2011_games.csv', index=False)
MEM_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2011_games.csv')
MEM_2011_games_proc.head()
# Out:
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "DeMarre Carroll"
# ...

# %%
MEM_2012_gamelog = []

for p in MEM_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2012_gamelog.append(player_log)
MEM_2012_gamelog = pd.concat(MEM_2012_gamelog)    
MEM_2012_gamelogs = MEM_2012_gamelog.copy()
MEM_2012_gamelogs['GAME_SCORE'] = MEM_2012_gamelogs['GAME_SCORE'].astype(float)
MEM_2012_games = MEM_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2012_games_csv = MEM_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2012_games.csv', index=False)
MEM_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2012_games.csv')
MEM_2012_games_proc.head()
# Out:
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# ...

# %%
MEM_2013_gamelog = []

for p in MEM_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2013_gamelog.append(player_log)
MEM_2013_gamelog = pd.concat(MEM_2013_gamelog)    
MEM_2013_gamelogs = MEM_2013_gamelog.copy()
MEM_2013_gamelogs['GAME_SCORE'] = MEM_2013_gamelogs['GAME_SCORE'].astype(float)
MEM_2013_games = MEM_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2013_games_csv = MEM_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2013_games.csv', index=False)
MEM_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2013_games.csv')
MEM_2013_games_proc.head()
# Out:
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Darrell Arthur"
# 3 results found.
# 0: Darrell Arthur
# 1: Darrell Hardy
# 2: Darrell Walker
# Pick one: 0
# Results for Darrell Arthur:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# ...

# %%
MEM_2014_gamelog = []

for p in MEM_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2014_gamelog.append(player_log)
MEM_2014_gamelog = pd.concat(MEM_2014_gamelog)    
MEM_2014_gamelogs = MEM_2014_gamelog.copy()
MEM_2014_gamelogs['GAME_SCORE'] = MEM_2014_gamelogs['GAME_SCORE'].astype(float)
MEM_2014_games = MEM_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2014_games_csv = MEM_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2014_games.csv', index=False)
MEM_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2014_games.csv')
MEM_2014_games_proc.head()
# Out:
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Nick Calathes"
# 1 result found.
# Nick Calathes
# Results for Nick Calathes:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# ...

# %%
MEM_2015_gamelog = []

for p in MEM_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2015_gamelog.append(player_log)
MEM_2015_gamelog = pd.concat(MEM_2015_gamelog)    
MEM_2015_gamelogs = MEM_2015_gamelog.copy()
MEM_2015_gamelogs['GAME_SCORE'] = MEM_2015_gamelogs['GAME_SCORE'].astype(float)
MEM_2015_games = MEM_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2015_games_csv = MEM_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2015_games.csv', index=False)
MEM_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2015_games.csv')
MEM_2015_games_proc.head()
# Out:
# You searched for "Jordan Adams"
# 8 results found.
# 0: Jordan Adams
# 1: Alvan Adams
# 2: Don Adams
# 3: Hassan Adams
# 4: Jaylen Adams
# 5: Jordan Nwora
# 6: Jordan Farmar
# 7: Jordan McRae
# Pick one: 0
# Results for Jordan Adams:
#
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Nick Calathes"
# 1 result found.
# Nick Calathes
# Results for Nick Calathes:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# ...

# %%
MEM_2016_gamelog = []

for p in MEM_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2016_gamelog.append(player_log)
MEM_2016_gamelog = pd.concat(MEM_2016_gamelog)    
MEM_2016_gamelogs = MEM_2016_gamelog.copy()
MEM_2016_gamelogs['GAME_SCORE'] = MEM_2016_gamelogs['GAME_SCORE'].astype(float)
MEM_2016_games = MEM_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2016_games_csv = MEM_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2016_games.csv', index=False)
MEM_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2016_games.csv')
MEM_2016_games_proc.head()
# Out:
# You searched for "Jordan Adams"
# 8 results found.
# 0: Jordan Adams
# 1: Alvan Adams
# 2: Don Adams
# 3: Hassan Adams
# 4: Jaylen Adams
# 5: Jordan Nwora
# 6: Jordan Farmar
# 7: Jordan McRae
# Pick one: 0
# Results for Jordan Adams:
#
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Matt Barnes"
# ...

# %%
MEM_2017_gamelog = []

for p in MEM_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2017_gamelog.append(player_log)
MEM_2017_gamelog = pd.concat(MEM_2017_gamelog)    
MEM_2017_gamelogs = MEM_2017_gamelog.copy()
MEM_2017_gamelogs['GAME_SCORE'] = MEM_2017_gamelogs['GAME_SCORE'].astype(float)
MEM_2017_games = MEM_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2017_games_csv = MEM_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2017_games.csv', index=False)
MEM_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2017_games.csv')
MEM_2017_games_proc.head()
# Out:
# You searched for "Tony Allen"
# 26 results found.
# 0: Tony Allen
# 1: Bob Allen
# 2: Randy Allen
# 3: Ray Allen
# 4: Tony Fuller
# 5: Tony Kappen
# 6: Bill Allen
# 7: Lavoy Allen
# 8: Toby Bailey
# 9: Tony Bradley
# 10: Tony Brown
# 11: Tony Dawson
# 12: Tony Delk
# 13: Tony Farmer
# 14: Tony Parker
# 15: Tony Wroten
# 16: Tony Zeno
# 17: Tony Battie
# 18: Tony Dumas
# 19: Tony Jaros
# 20: Tony Lavelli
# 21: Tony Price
# 22: Tony Snell
# 23: Tony White
# 24: Lonzo Ball
# 25: Donta Hall
# Pick one: 0
# Results for Tony Allen:
#
# You searched for "Wade Baldwin"
# 1 result found.
# Wade Baldwin
# Results for Wade Baldwin:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# ...

# %%
MEM_2018_gamelog = []

for p in MEM_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2018_gamelog.append(player_log)
MEM_2018_gamelog = pd.concat(MEM_2018_gamelog)    
MEM_2018_gamelogs = MEM_2018_gamelog.copy()
MEM_2018_gamelogs['GAME_SCORE'] = MEM_2018_gamelogs['GAME_SCORE'].astype(float)
MEM_2018_games = MEM_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2018_games_csv = MEM_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2018_games.csv', index=False)
MEM_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2018_games.csv')
MEM_2018_games_proc.head()
# Out:
# You searched for "Dillon Brooks"
# 2 results found.
# 0: Dillon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for Dillon Brooks:
#
# You searched for "MarShon Brooks"
# 2 results found.
# 0: MarShon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for MarShon Brooks:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# Results for Mario Chalmers:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# Results for Mike Conley:
#
# You searched for "Deyonta Davis"
# 2 results found.
# 0: Deyonta Davis
# 1: Monti Davis
# Pick one: 0
# Results for Deyonta Davis:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# ...

# %%
MEM_2019_gamelog = []

for p in MEM_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2019_gamelog.append(player_log)
MEM_2019_gamelog = pd.concat(MEM_2019_gamelog)    
MEM_2019_gamelogs = MEM_2019_gamelog.copy()
MEM_2019_gamelogs['GAME_SCORE'] = MEM_2019_gamelogs['GAME_SCORE'].astype(float)
MEM_2019_games = MEM_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2019_games_csv = MEM_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2019_games.csv', index=False)
MEM_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2019_games.csv')
MEM_2019_games_proc.head()
# Out:
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Dillon Brooks"
# 2 results found.
# 0: Dillon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for Dillon Brooks:
#
# You searched for "MarShon Brooks"
# 2 results found.
# 0: MarShon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for MarShon Brooks:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "Jevon Carter"
# ...

# %%
MEM_2020_gamelog = []

for p in MEM_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2020_gamelog.append(player_log)
MEM_2020_gamelog = pd.concat(MEM_2020_gamelog)    
MEM_2020_gamelogs = MEM_2020_gamelog.copy()
MEM_2020_gamelogs['GAME_SCORE'] = MEM_2020_gamelogs['GAME_SCORE'].astype(float)
MEM_2020_games = MEM_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2020_games_csv = MEM_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2020_games.csv', index=False)
MEM_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2020_games.csv')
MEM_2020_games_proc.head()
# Out:
# You searched for "Grayson Allen"
# 2 results found.
# 0: Grayson Allen
# 1: Ray Allen
# Pick one: 0
# Results for Grayson Allen:
#
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Dillon Brooks"
# 2 results found.
# 0: Dillon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for Dillon Brooks:
#
# You searched for "Bruno Caboclo"
# ...

# %%
MEM_2021_gamelog = []

for p in MEM_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    MEM_2021_gamelog.append(player_log)
MEM_2021_gamelog = pd.concat(MEM_2021_gamelog)    
MEM_2021_gamelogs = MEM_2021_gamelog.copy()
MEM_2021_gamelogs['GAME_SCORE'] = MEM_2021_gamelogs['GAME_SCORE'].astype(float)
MEM_2021_games = MEM_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_2021_games_csv = MEM_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2021_games.csv', index=False)
MEM_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2021_games.csv')
MEM_2021_games_proc.head()
# Out:
# You searched for "Grayson Allen"
# 2 results found.
# 0: Grayson Allen
# 1: Ray Allen
# Pick one: 0
# Results for Grayson Allen:
#
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Desmond Bane"
# 2 results found.
# 0: Desmond Bane
# 1: Desmond Mason
# Pick one: 0
# Results for Desmond Bane:
#
# You searched for "Dillon Brooks"
# 2 results found.
# 0: Dillon Brooks
# 1: Aaron Brooks
# Pick one: 0
# Results for Dillon Brooks:
#
# You searched for "Brandon Clarke"
# 1 result found.
# Brandon Clarke
# Results for Brandon Clarke:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# ...

# %% [markdown]
# ## combine all seasons

# %%
MEM_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2002_games.csv')
MEM_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2003_games.csv')
MEM_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2004_games.csv')
MEM_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2005_games.csv')
MEM_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2006_games.csv')
MEM_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2007_games.csv')
MEM_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2008_games.csv')
MEM_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2009_games.csv')
MEM_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2010_games.csv')
MEM_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2011_games.csv')
MEM_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2012_games.csv')
MEM_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2013_games.csv')
MEM_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2014_games.csv')
MEM_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2015_games.csv')
MEM_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2016_games.csv')
MEM_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2017_games.csv')
MEM_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2018_games.csv')
MEM_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2019_games.csv')
MEM_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2020_games.csv')
MEM_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2021_games.csv')

# %%
MEM_season_dfs = [MEM_2002_games_io, MEM_2003_games_io, MEM_2004_games_io, MEM_2005_games_io,
                 MEM_2006_games_io, MEM_2007_games_io, MEM_2008_games_io, MEM_2009_games_io, MEM_2010_games_io, MEM_2011_games_io,
                 MEM_2012_games_io, MEM_2013_games_io, MEM_2014_games_io, MEM_2015_games_io, MEM_2016_games_io, MEM_2017_games_io,
                 MEM_2018_games_io, MEM_2019_games_io, MEM_2020_games_io, MEM_2021_games_io]

# %%
MEM_all = pd.concat(MEM_season_dfs)
MEM_all_sorted = MEM_all.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-12-23  21-135  MEM      HOME      SAS  L (-12)   1  35:10  18   27
# 0  2012-12-04  31-141  MEM      HOME      PHO  W (+10)   1  44:16  15   22
# 0  2017-01-30  29-111  MEM      AWAY      PHO  W (+19)   1  32:48  12   18
# 1  2021-04-23  21-256  MEM      AWAY      POR   W (+2)   1  36:16  11   17
# 0  2008-01-11  27-189  MEM      AWAY      GSW  L (-12)   1  44:43  17   25
# 2  2021-04-11  28-340  MEM      HOME      IND   L (-7)   1  32:14  16   25
# 0  2006-04-07  25-275  MEM      HOME      MIL  W (+10)   1  42:55  13   15
# 0  2015-12-01  30-306  MEM      AWAY      NOP   W (+9)   1  42:11  11   22
# 0  2004-03-29  27-076  MEM      AWAY      ATL   W (+3)   1  48:28  10   17
# 0  2009-11-01  21-361  MEM      AWAY      DEN  L (-10)   1  37:47  17   25
# 1  2017-03-29  29-169  MEM      HOME      IND  W (+13)   1  37:57  13   21
# ...
