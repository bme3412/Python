# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_MIA = []

# MIA
while season <= 2021:
    df_MIA = get_roster('MIA', season)
    df_MIA['Season'] = season
    df_MIA['Team'] = 'MIA'
    appended_data_MIA.append(df_MIA)
    season = season + 1
appended_data_MIA = pd.concat(appended_data_MIA)

# %%
MIA_df_all = appended_data_MIA.copy()
MIA_df_all_csv = MIA_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_players_all.csv', index=False)
MIA_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_players_all.csv')
MIA_df_all_csv_io.head()
# Out:
#   NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     12     Bruce Bowen  SF    6-7     185  1971-06-14          US
# 1     42      P.J. Brown  PF   6-11     225  1969-10-14          US
# 2     32   Rodney Buford  SG    6-5     189  1977-11-02          US
# 3     25  Anthony Carter  PG    6-1     190  1975-06-16          US
# 4      4  Duane Causwell   C    7-0     240  1968-05-31          US
#
#   EXPERIENCE              COLLEGE  Season Team
# 0          3  Cal State Fullerton    2000  MIA
# 1          6       Louisiana Tech    2000  MIA
# 2          R            Creighton    2000  MIA
# 3          R               Hawaii    2000  MIA
# 4          9               Temple    2000  MIA

# %%
MIA_df_2000 = MIA_df_all[MIA_df_all['Season'] == 2000]
MIA_df_2001 = MIA_df_all[MIA_df_all['Season'] == 2001]
MIA_df_2002 = MIA_df_all[MIA_df_all['Season'] == 2002]
MIA_df_2003 = MIA_df_all[MIA_df_all['Season'] == 2003]
MIA_df_2004 = MIA_df_all[MIA_df_all['Season'] == 2004]
MIA_df_2005 = MIA_df_all[MIA_df_all['Season'] == 2005]
MIA_df_2006 = MIA_df_all[MIA_df_all['Season'] == 2006]
MIA_df_2007 = MIA_df_all[MIA_df_all['Season'] == 2007]
MIA_df_2008 = MIA_df_all[MIA_df_all['Season'] == 2008]
MIA_df_2009 = MIA_df_all[MIA_df_all['Season'] == 2009]
MIA_df_2010 = MIA_df_all[MIA_df_all['Season'] == 2010]
MIA_df_2011 = MIA_df_all[MIA_df_all['Season'] == 2011]
MIA_df_2012 = MIA_df_all[MIA_df_all['Season'] == 2012]
MIA_df_2013 = MIA_df_all[MIA_df_all['Season'] == 2013]
MIA_df_2014 = MIA_df_all[MIA_df_all['Season'] == 2014]
MIA_df_2015 = MIA_df_all[MIA_df_all['Season'] == 2015]
MIA_df_2016 = MIA_df_all[MIA_df_all['Season'] == 2016]
MIA_df_2017 = MIA_df_all[MIA_df_all['Season'] == 2017]
MIA_df_2018 = MIA_df_all[MIA_df_all['Season'] == 2018]
MIA_df_2019 = MIA_df_all[MIA_df_all['Season'] == 2019]
MIA_df_2020 = MIA_df_all[MIA_df_all['Season'] == 2020]
MIA_df_2021 = MIA_df_all[MIA_df_all['Season'] == 2021]

# %%
# changing names
#MIA_df_2002.loc[MIA_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#MIA_df_2004.loc[MIA_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
MIA_df_2000_players = MIA_df_2000['PLAYER'].to_list()
MIA_df_2001_players = MIA_df_2001['PLAYER'].to_list()
MIA_df_2002_players = MIA_df_2002['PLAYER'].to_list()
MIA_df_2003_players = MIA_df_2003['PLAYER'].to_list()
MIA_df_2004_players = MIA_df_2004['PLAYER'].to_list()
MIA_df_2005_players = MIA_df_2005['PLAYER'].to_list()

MIA_df_2006_players = MIA_df_2006['PLAYER'].to_list()
MIA_df_2007_players = MIA_df_2007['PLAYER'].to_list()
MIA_df_2008_players = MIA_df_2008['PLAYER'].to_list()
MIA_df_2009_players = MIA_df_2009['PLAYER'].to_list()
MIA_df_2010_players = MIA_df_2010['PLAYER'].to_list()
MIA_df_2011_players = MIA_df_2011['PLAYER'].to_list()

MIA_df_2012_players = MIA_df_2012['PLAYER'].to_list()
MIA_df_2013_players = MIA_df_2013['PLAYER'].to_list()
MIA_df_2014_players = MIA_df_2014['PLAYER'].to_list()
MIA_df_2015_players = MIA_df_2015['PLAYER'].to_list()
MIA_df_2016_players = MIA_df_2016['PLAYER'].to_list()
MIA_df_2017_players = MIA_df_2017['PLAYER'].to_list()

MIA_df_2018_players = MIA_df_2018['PLAYER'].to_list()
MIA_df_2019_players = MIA_df_2019['PLAYER'].to_list()
MIA_df_2020_players = MIA_df_2020['PLAYER'].to_list()
MIA_df_2021_players = MIA_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#MIA_df_2008_players.remove("Bobby Jones")
#MIA_df_2003_players.remove('Ken Johnson')
#MIA_df_2005_players.remove("Shaquille O'Neal")
#MIA_df_2006_players.remove("Shaquille O'Neal")
#MIA_df_2007_players.remove("Shaquille O'Neal")
#MIA_df_2008_players.remove("Shaquille O'Neal")

#MIA_df_2008_players.remove("Luke Jackson")
#MIA_df_2008_players.remove("Bobby Jones")
#MIA_df_2009_players.remove("Jermaine O'Neal")
#MIA_df_2010_players.remove("Jermaine O'Neal")
#MIA_df_2015_players.remove("Henry Walker")
#MIA_df_2018_players.remove("Derrick Jones")
#MIA_df_2019_players.remove("Derrick Jones")
MIA_df_2020_players.remove("Derrick Jones")

# %%
MIA_2000_gamelog = []


for p in MIA_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2000_gamelog.append(player_log)
MIA_2000_gamelog = pd.concat(MIA_2000_gamelog)    
MIA_2000_gamelogs = MIA_2000_gamelog.copy()
MIA_2000_gamelogs['GAME_SCORE'] = MIA_2000_gamelogs['GAME_SCORE'].astype(float)
MIA_2000_games = MIA_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2000_games_csv = MIA_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2000_games.csv', index=False)
MIA_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2000_games.csv')
MIA_2000_games_proc.head()
# Out:
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "P.J. Brown"
# 12 results found.
# 0: P.J. Brown
# 1: Bob Brown
# 2: Dee Brown
# 3: Dee Brown
# 4: Fred Brown
# 5: John Brown
# 6: Leon Brown
# 7: Mike Brown
# 8: Stan Brown
# 9: Tony Brown
# 10: Troy Brown
# 11: J.J. Barea
# Pick one: 0
# Results for P.J. Brown:
#
# You searched for "Rodney Buford"
# 2 results found.
# 0: Rodney Buford
# 1: Rodney Hood
# Pick one: 0
# Results for Rodney Buford:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Duane Causwell"
# 1 result found.
# Duane Causwell
# Results for Duane Causwell:
#
# ...

# %%
MIA_2001_gamelog = []


for p in MIA_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2001_gamelog.append(player_log)
MIA_2001_gamelog = pd.concat(MIA_2001_gamelog)    
MIA_2001_gamelogs = MIA_2001_gamelog.copy()
MIA_2001_gamelogs['GAME_SCORE'] = MIA_2001_gamelogs['GAME_SCORE'].astype(float)
MIA_2001_games = MIA_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2001_games_csv = MIA_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2001_games.csv', index=False)
MIA_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2001_games.csv')
MIA_2001_games_proc.head()
# Out:
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Duane Causwell"
# 1 result found.
# Duane Causwell
# Results for Duane Causwell:
#
# You searched for "Cedric Ceballos"
# 2 results found.
# 0: Cedric Ceballos
# 1: Cedric Ball
# Pick one: 0
# Results for Cedric Ceballos:
#
# You searched for "Ricky Davis"
# 17 results found.
# 0: Ricky Davis
# 1: Mickey Davis
# 2: Mike Davis
# 3: Mike Davis
# 4: Bill Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Jim Davis
# 8: Mark Davis
# 9: Mark Davis
# 10: Ralph Davis
# 11: Red Davis
# 12: Ron Davis
# 13: Terry Davis
# ...

# %%
MIA_2002_gamelog = []


for p in MIA_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2002_gamelog.append(player_log)
MIA_2002_gamelog = pd.concat(MIA_2002_gamelog)    
MIA_2002_gamelogs = MIA_2002_gamelog.copy()
MIA_2002_gamelogs['GAME_SCORE'] = MIA_2002_gamelogs['GAME_SCORE'].astype(float)
MIA_2002_games = MIA_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2002_games_csv = MIA_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2002_games.csv', index=False)
MIA_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2002_games.csv')
MIA_2002_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Ernest Brown"
# 3 results found.
# 0: Ernest Brown
# 1: Fred Brown
# 2: Moses Brown
# Pick one: 0
# Results for Ernest Brown:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "LaPhonso Ellis"
# 1 result found.
# LaPhonso Ellis
# Results for LaPhonso Ellis:
#
# You searched for "Chris Gatling"
# 4 results found.
# 0: Chris Gatling
# 1: Chris King
# 2: Chris Mullin
# 3: Chris Garner
# Pick one: 0
# Results for Chris Gatling:
#
# You searched for "Kendall Gill"
# 2 results found.
# ...

# %%
# removed Ken Johnson
    
MIA_2003_gamelog = []



for p in MIA_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2003_gamelog.append(player_log)
MIA_2003_gamelog = pd.concat(MIA_2003_gamelog)    
MIA_2003_gamelogs = MIA_2003_gamelog.copy()
MIA_2003_gamelogs['GAME_SCORE'] = MIA_2003_gamelogs['GAME_SCORE'].astype(float)
MIA_2003_games = MIA_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2003_games_csv = MIA_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2003_games.csv', index=False)
MIA_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2003_games.csv')
MIA_2003_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Travis Best"
# 6 results found.
# 0: Travis Best
# 1: Travis Wear
# 2: Travis Grant
# 3: Travis Leslie
# 4: Travis Mays
# 5: David West
# Pick one: 0
# Results for Travis Best:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# ...

# %%
MIA_2004_gamelog = []



for p in MIA_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2004_gamelog.append(player_log)
MIA_2004_gamelog = pd.concat(MIA_2004_gamelog)    
MIA_2004_gamelogs = MIA_2004_gamelog.copy()
MIA_2004_gamelogs['GAME_SCORE'] = MIA_2004_gamelogs['GAME_SCORE'].astype(float)
MIA_2004_games = MIA_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2004_games_csv = MIA_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2004_games.csv', index=False)
MIA_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2004_games.csv')
MIA_2004_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Jerome Beasley"
# 4 results found.
# 0: Jerome Beasley
# 1: Jerome Kersey
# 2: Jerome Allen
# 3: John Beasley
# Pick one: 0
# Results for Jerome Beasley:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Bimbo Coles"
# 1 result found.
# Bimbo Coles
# Results for Bimbo Coles:
#
# You searched for "Brian Grant"
# 9 results found.
# 0: Brian Grant
# ...

# %%
# removed shaaq - for now

MIA_2005_gamelog = []

for p in MIA_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2005_gamelog.append(player_log)
MIA_2005_gamelog = pd.concat(MIA_2005_gamelog)    
MIA_2005_gamelogs = MIA_2005_gamelog.copy()
MIA_2005_gamelogs['GAME_SCORE'] = MIA_2005_gamelogs['GAME_SCORE'].astype(float)
MIA_2005_games = MIA_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2005_games_csv = MIA_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2005_games.csv', index=False)
MIA_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2005_games.csv')
MIA_2005_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# ...

# %%
# removed shaq
MIA_2006_gamelog = []

for p in MIA_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2006_gamelog.append(player_log)
MIA_2006_gamelog = pd.concat(MIA_2006_gamelog)    
MIA_2006_gamelogs = MIA_2006_gamelog.copy()
MIA_2006_gamelogs['GAME_SCORE'] = MIA_2006_gamelogs['GAME_SCORE'].astype(float)
MIA_2006_games = MIA_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2006_games_csv = MIA_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2006_games.csv', index=False)
MIA_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2006_games.csv')
MIA_2006_games_proc.head()
# Out:
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# ...

# %%
# removed shaq

MIA_2007_gamelog = []

for p in MIA_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2007_gamelog.append(player_log)
MIA_2007_gamelog = pd.concat(MIA_2007_gamelog)    
MIA_2007_gamelogs = MIA_2007_gamelog.copy()
MIA_2007_gamelogs['GAME_SCORE'] = MIA_2007_gamelogs['GAME_SCORE'].astype(float)
MIA_2007_games = MIA_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2007_games_csv = MIA_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2007_games.csv', index=False)
MIA_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2007_games.csv')
MIA_2007_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# Results for Udonis Haslem:
#
# You searched for "Robert Hite"
# 10 results found.
# 0: Robert Hite
# 1: Robert Hahn
# 2: Robert Smith
# 3: Robert Horry
# 4: Robert Pack
# 5: Robert Reid
# 6: Robert Sacre
# 7: Robert Swift
# 8: Robert Whaley
# 9: Rory White
# Pick one: 0
# Results for Robert Hite:
#
# You searched for "Eddie Jones"
# 21 results found.
# ...

# %%
# removed shaq
# removed luke jackson
# removed bobby jones

MIA_2008_gamelog = []

for p in MIA_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2008_gamelog.append(player_log)
MIA_2008_gamelog = pd.concat(MIA_2008_gamelog)    
MIA_2008_gamelogs = MIA_2008_gamelog.copy()
MIA_2008_gamelogs['GAME_SCORE'] = MIA_2008_gamelogs['GAME_SCORE'].astype(float)
MIA_2008_games = MIA_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2008_games_csv = MIA_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2008_games.csv', index=False)
MIA_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2008_games.csv')
MIA_2008_games_proc.head()
# Out:
# You searched for "Blake Ahearn"
# 1 result found.
# Blake Ahearn
# Results for Blake Ahearn:
#
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Mark Blount"
# 7 results found.
# 0: Mark Blount
# 1: Mark Bryant
# 2: Corie Blount
# 3: Markel Brown
# 4: Mark Jones
# 5: Mark Jones
# 6: Mark Sibley
# Pick one: 0
# Results for Mark Blount:
#
# You searched for "Daequan Cook"
# 2 results found.
# ...

# %%
# removed jermaine o'neal

MIA_2009_gamelog = []

for p in MIA_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2009_gamelog.append(player_log)
MIA_2009_gamelog = pd.concat(MIA_2009_gamelog)    
MIA_2009_gamelogs = MIA_2009_gamelog.copy()
MIA_2009_gamelogs['GAME_SCORE'] = MIA_2009_gamelogs['GAME_SCORE'].astype(float)
MIA_2009_games = MIA_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2009_games_csv = MIA_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2009_games.csv', index=False)
MIA_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2009_games.csv')
MIA_2009_games_proc.head()
# Out:
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Mark Blount"
# 7 results found.
# 0: Mark Blount
# 1: Mark Bryant
# 2: Corie Blount
# 3: Markel Brown
# 4: Mark Jones
# 5: Mark Jones
# 6: Mark Sibley
# Pick one: 0
# Results for Mark Blount:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# Results for Mario Chalmers:
#
# You searched for "Daequan Cook"
# 2 results found.
# 0: Daequan Cook
# 1: Darwin Cook
# Pick one: 0
# ...

# %%
# removed jermaine o'neal

MIA_2010_gamelog = []

for p in MIA_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2010_gamelog.append(player_log)
MIA_2010_gamelog = pd.concat(MIA_2010_gamelog)    
MIA_2010_gamelogs = MIA_2010_gamelog.copy()
MIA_2010_gamelogs['GAME_SCORE'] = MIA_2010_gamelogs['GAME_SCORE'].astype(float)
MIA_2010_games = MIA_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2010_games_csv = MIA_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2010_games.csv', index=False)
MIA_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2010_games.csv')
MIA_2010_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# Results for Mario Chalmers:
#
# You searched for "Daequan Cook"
# 2 results found.
# 0: Daequan Cook
# 1: Darwin Cook
# Pick one: 0
# Results for Daequan Cook:
#
# You searched for "Yakhouba Diawara"
# 1 result found.
# Yakhouba Diawara
# Results for Yakhouba Diawara:
#
# You searched for "Udonis Haslem"
# 2 results found.
# ...

# %%
MIA_2011_gamelog = []

for p in MIA_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2011_gamelog.append(player_log)
MIA_2011_gamelog = pd.concat(MIA_2011_gamelog)    
MIA_2011_gamelogs = MIA_2011_gamelog.copy()
MIA_2011_gamelogs['GAME_SCORE'] = MIA_2011_gamelogs['GAME_SCORE'].astype(float)
MIA_2011_games = MIA_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2011_games_csv = MIA_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2011_games.csv', index=False)
MIA_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2011_games.csv')
MIA_2011_games_proc.head()
# Out:
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# ...

# %%
MIA_2012_gamelog = []

for p in MIA_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2012_gamelog.append(player_log)
MIA_2012_gamelog = pd.concat(MIA_2012_gamelog)    
MIA_2012_gamelogs = MIA_2012_gamelog.copy()
MIA_2012_gamelogs['GAME_SCORE'] = MIA_2012_gamelogs['GAME_SCORE'].astype(float)
MIA_2012_games = MIA_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2012_games_csv = MIA_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2012_games.csv', index=False)
MIA_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2012_games.csv')
MIA_2012_games_proc.head()
# Out:
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# Results for Mario Chalmers:
#
# You searched for "Norris Cole"
# 2 results found.
# 0: Norris Cole
# 1: Norris Coleman
# Pick one: 0
# Results for Norris Cole:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# ...

# %%
MIA_2013_gamelog = []

for p in MIA_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2013_gamelog.append(player_log)
MIA_2013_gamelog = pd.concat(MIA_2013_gamelog)    
MIA_2013_gamelogs = MIA_2013_gamelog.copy()
MIA_2013_gamelogs['GAME_SCORE'] = MIA_2013_gamelogs['GAME_SCORE'].astype(float)
MIA_2013_games = MIA_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2013_games_csv = MIA_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2013_games.csv', index=False)
MIA_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2013_games.csv')
MIA_2013_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# ...

# %%
MIA_2014_gamelog = []

for p in MIA_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2014_gamelog.append(player_log)
MIA_2014_gamelog = pd.concat(MIA_2014_gamelog)    
MIA_2014_gamelogs = MIA_2014_gamelog.copy()
MIA_2014_gamelogs['GAME_SCORE'] = MIA_2014_gamelogs['GAME_SCORE'].astype(float)
MIA_2014_games = MIA_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2014_games_csv = MIA_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2014_games.csv', index=False)
MIA_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2014_games.csv')
MIA_2014_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Shane Battier"
# 1 result found.
# Shane Battier
# Results for Shane Battier:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# ...

# %%
# removed henry walker
MIA_2015_gamelog = []

for p in MIA_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2015_gamelog.append(player_log)
MIA_2015_gamelog = pd.concat(MIA_2015_gamelog)    
MIA_2015_gamelogs = MIA_2015_gamelog.copy()
MIA_2015_gamelogs['GAME_SCORE'] = MIA_2015_gamelogs['GAME_SCORE'].astype(float)
MIA_2015_games = MIA_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2015_games_csv = MIA_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2015_games.csv', index=False)
MIA_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2015_games.csv')
MIA_2015_games_proc.head()
# Out:
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# ...

# %%
MIA_2016_gamelog = []

for p in MIA_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2016_gamelog.append(player_log)
MIA_2016_gamelog = pd.concat(MIA_2016_gamelog)    
MIA_2016_gamelogs = MIA_2016_gamelog.copy()
MIA_2016_gamelogs['GAME_SCORE'] = MIA_2016_gamelogs['GAME_SCORE'].astype(float)
MIA_2016_games = MIA_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2016_games_csv = MIA_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2016_games.csv', index=False)
MIA_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2016_games.csv')
MIA_2016_games_proc.head()
# Out:
# You searched for "Chris Andersen"
# 4 results found.
# 0: Chris Andersen
# 1: David Andersen
# 2: Eric Anderson
# 3: Chris Herren
# Pick one: 0
# Results for Chris Andersen:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Mario Chalmers"
# 1 result found.
# Mario Chalmers
# Results for Mario Chalmers:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# ...

# %%
MIA_2017_gamelog = []

for p in MIA_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2017_gamelog.append(player_log)
MIA_2017_gamelog = pd.concat(MIA_2017_gamelog)    
MIA_2017_gamelogs = MIA_2017_gamelog.copy()
MIA_2017_gamelogs['GAME_SCORE'] = MIA_2017_gamelogs['GAME_SCORE'].astype(float)
MIA_2017_games = MIA_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2017_games_csv = MIA_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2017_games.csv', index=False)
MIA_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2017_games.csv')
MIA_2017_games_proc.head()
# Out:
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# Results for Udonis Haslem:
#
# You searched for "James Johnson"
# 32 results found.
# 0: James Johnson
# 1: Amir Johnson
# 2: Dave Johnson
# 3: Joe Johnson
# 4: James Robinson
# 5: James Cotton
# 6: Andy Johnson
# 7: Armon Johnson
# 8: Avery Johnson
# 9: Cameron Johnson
# 10: Charles Johnson
# 11: Cheese Johnson
# 12: Chris Johnson
# 13: Chris Johnson
# 14: Ed Johnson
# 15: Gus Johnson
# 16: JaJuan Johnson
# 17: John Johnson
# 18: Ken Johnson
# 19: Ken Johnson
# 20: Larry Johnson
# 21: Larry Johnson
# ...

# %%
# removed Derrick Jones

MIA_2018_gamelog = []

for p in MIA_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2018_gamelog.append(player_log)
MIA_2018_gamelog = pd.concat(MIA_2018_gamelog)    
MIA_2018_gamelogs = MIA_2018_gamelog.copy()
MIA_2018_gamelogs['GAME_SCORE'] = MIA_2018_gamelogs['GAME_SCORE'].astype(float)
MIA_2018_games = MIA_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2018_games_csv = MIA_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2018_games.csv', index=False)
MIA_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2018_games.csv')
MIA_2018_games_proc.head()
# Out:
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# Results for Udonis Haslem:
#
# You searched for "James Johnson"
# 32 results found.
# 0: James Johnson
# 1: Amir Johnson
# 2: Dave Johnson
# 3: Joe Johnson
# 4: James Robinson
# 5: James Cotton
# 6: Andy Johnson
# 7: Armon Johnson
# 8: Avery Johnson
# 9: Cameron Johnson
# 10: Charles Johnson
# 11: Cheese Johnson
# 12: Chris Johnson
# 13: Chris Johnson
# 14: Ed Johnson
# 15: Gus Johnson
# 16: JaJuan Johnson
# ...

# %%
# removed derrick jones
MIA_2019_gamelog = []

for p in MIA_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2019_gamelog.append(player_log)
MIA_2019_gamelog = pd.concat(MIA_2019_gamelog)    
MIA_2019_gamelogs = MIA_2019_gamelog.copy()
MIA_2019_gamelogs['GAME_SCORE'] = MIA_2019_gamelogs['GAME_SCORE'].astype(float)
MIA_2019_games = MIA_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2019_games_csv = MIA_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2019_games.csv', index=False)
MIA_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2019_games.csv')
MIA_2019_games_proc.head()
# Out:
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# Results for Udonis Haslem:
#
# You searched for "James Johnson"
# 32 results found.
# 0: James Johnson
# 1: Amir Johnson
# 2: Dave Johnson
# 3: Joe Johnson
# 4: James Robinson
# ...

# %%
# removed derrick jones
MIA_2020_gamelog = []

for p in MIA_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2020_gamelog.append(player_log)
MIA_2020_gamelog = pd.concat(MIA_2020_gamelog)    
MIA_2020_gamelogs = MIA_2020_gamelog.copy()
MIA_2020_gamelogs['GAME_SCORE'] = MIA_2020_gamelogs['GAME_SCORE'].astype(float)
MIA_2020_games = MIA_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2020_games_csv = MIA_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2020_games.csv', index=False)
MIA_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2020_games.csv')
MIA_2020_games_proc.head()
# Out:
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Kyle Alexander"
# 5 results found.
# 0: Kyle Alexander
# 1: Joe Alexander
# 2: Cory Alexander
# 3: Gary Alexander
# 4: Kyle Anderson
# Pick one: 0
# Results for Kyle Alexander:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Udonis Haslem"
# 2 results found.
# 0: Udonis Haslem
# 1: Adonis Thomas
# Pick one: 0
# Results for Udonis Haslem:
#
# You searched for "Tyler Herro"
# 4 results found.
# ...

# %%
MIA_2021_gamelog = []

for p in MIA_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    MIA_2021_gamelog.append(player_log)
MIA_2021_gamelog = pd.concat(MIA_2021_gamelog)    
MIA_2021_gamelogs = MIA_2021_gamelog.copy()
MIA_2021_gamelogs['GAME_SCORE'] = MIA_2021_gamelogs['GAME_SCORE'].astype(float)
MIA_2021_games = MIA_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_2021_games_csv = MIA_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2021_games.csv', index=False)
MIA_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2021_games.csv')
MIA_2021_games_proc.head()
# Out:
# You searched for "Precious Achiuwa"
# 1 result found.
# Precious Achiuwa
# Results for Precious Achiuwa:
#
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Avery Bradley"
# 4 results found.
# 0: Avery Bradley
# 1: Alex Bradley
# 2: Joe Bradley
# 3: Tony Bradley
# Pick one: 0
# Results for Avery Bradley:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# ...

# %% [markdown]
# ## Shaw Files

# %%
Shaq_2005_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/Shaq_2005_games.csv')
Shaq_2006_games = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/Shaq_2006_games.csv')

# %%
Shaq_2005_games.columns
# Out:
# Index(['Rk', 'G', 'Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'],
#       dtype='object')

# %%
# 2005
Shaq_2005_games_io = Shaq_2005_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2005_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2005_games_io['Player'] = player
Shaq_2005_games_io.head()
# Out:
# <ipython-input-6-466830c3767d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2005_games_io['Player'] = player
#        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS        MP   FG   FGA  \
# 0   11/3/04  32-242  MIA         @      NJN  W (+23)  1     22:19  7.0   9.0
# 1   11/4/04  32-243  MIA       NaN      CLE   W (+6)  1  32:59:00  7.0  17.0
# 2   11/6/04  32-245  MIA         @      WAS  W (+12)  1  27:51:00  5.0  10.0
# 3   11/9/04  32-248  MIA       NaN      WAS  W (+10)  1  27:54:00  8.0  13.0
# 4  11/11/04  32-250  MIA       NaN      DAL  L (-20)  1  30:10:00  8.0  13.0
#
#    ...   TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  ...   5.0  2.0  0.0  2.0  2.0  5.0  16.0        11.6  14.0
# ...

# %%
# 2006
Shaq_2006_games_io = Shaq_2006_games[['Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-']]
Shaq_2006_games_io.columns = ['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS',
       'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE', '+/-']
player = "Shaquille O'Neal"
Shaq_2006_games_io['Player'] = player
Shaq_2006_games_io.head()
# Out:
# <ipython-input-7-ec8b83d74b1d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Shaq_2006_games_io['Player'] = player
#       DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT        GS        MP   FG  \
# 0  11/2/05  33-241  MIA         @      MEM  W (+19)         1  27:51:00  6.0
# 1  11/3/05  33-242  MIA       NaN      IND   L (-3)         1  29:09:00  6.0
# 2  11/5/05  33-244  MIA         @      MIL   L (-5)  Inactive       NaN  NaN
# 3  11/7/05  33-246  MIA       NaN      NJN   W (+1)  Inactive       NaN  NaN
# 4  11/9/05  33-248  MIA         @      IND   L (-5)  Inactive       NaN  NaN
#
#     FGA  ...  TRB  AST  STL  BLK  TOV   PF   PTS  GAME_SCORE   +/-  \
# 0  14.0  ...  6.0  3.0  1.0  3.0  3.0  2.0  12.0         7.0  16.0
# ...

# %% [markdown]
# ## combine all seasons

# %%
MIA_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2000_games.csv')
MIA_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2001_games.csv')
MIA_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2002_games.csv')
MIA_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2003_games.csv')
MIA_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2004_games.csv')
MIA_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2005_games.csv')
MIA_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2006_games.csv')
MIA_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2007_games.csv')
MIA_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2008_games.csv')
MIA_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2009_games.csv')
MIA_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2010_games.csv')
MIA_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2011_games.csv')
MIA_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2012_games.csv')
MIA_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2013_games.csv')
MIA_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2014_games.csv')
MIA_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2015_games.csv')
MIA_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2016_games.csv')
MIA_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2017_games.csv')
MIA_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2018_games.csv')
MIA_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2019_games.csv')
MIA_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2020_games.csv')
MIA_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2021_games.csv')

# %%
MIA_season_dfs = [MIA_2000_games_io, MIA_2001_games_io, MIA_2002_games_io, MIA_2003_games_io, MIA_2004_games_io, MIA_2005_games_io,
                 MIA_2006_games_io, MIA_2007_games_io, MIA_2008_games_io, MIA_2009_games_io, MIA_2010_games_io, MIA_2011_games_io,
                 MIA_2012_games_io, MIA_2013_games_io, MIA_2014_games_io, MIA_2015_games_io, MIA_2016_games_io, MIA_2017_games_io,
                 MIA_2018_games_io, MIA_2019_games_io, MIA_2020_games_io, MIA_2021_games_io, Shaq_2005_games_io, Shaq_2006_games_io]

# %%
MIA_all = pd.concat(MIA_season_dfs)
MIA_all_sorted = MIA_all.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP    FG   FGA  \
# 0  2009-03-09  27-051  MIA      HOME      CHI   W (+3)  1  49:51  15.0  21.0
# 0  2014-03-03  29-063  MIA      HOME      CHA  W (+17)  1  41:12  22.0  33.0
# 0  2014-03-03  29-063  MIA      HOME      CHA  W (+17)  1  41:12  22.0  33.0
# 1  2009-02-28  27-042  MIA      HOME      NYK   W (+5)  1  41:18  16.0  29.0
# 0  2011-02-03  26-035  MIA      AWAY      ORL   W (+4)  1  42:39  17.0  25.0
# 0  2007-12-28  25-345  MIA      HOME      ORL   L (-7)  1  51:35  16.0  21.0
# 1  2013-02-26  28-058  MIA      HOME      SAC  W (+12)  1  47:45  14.0  23.0
# 0  2000-02-23  30-015  MIA      HOME      NJN  W (+14)  1  32:33  13.0  14.0
# 2  2009-04-12  27-085  MIA      HOME      NYK  W (+17)  1  39:17  19.0  30.0
# 1  2014-03-18  29-078  MIA      AWAY      CLE   W (+4)  1  41:40  14.0  19.0
# 2  2014-03-18  29-078  MIA      AWAY      CLE   W (+4)  1  41:40  14.0  19.0
# ...
