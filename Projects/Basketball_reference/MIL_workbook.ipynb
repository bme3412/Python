# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_MIL = []

# MIL
while season <= 2021:
    df_MIL = get_roster('MIL', season)
    df_MIL['Season'] = season
    df_MIL['Team'] = 'MIL'
    appended_data_MIL.append(df_MIL)
    season = season + 1
appended_data_MIL = pd.concat(appended_data_MIL)

# %%
MIL_df_all = appended_data_MIL.copy()
MIL_df_all_csv = MIL_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_players_all.csv', index=False)
MIL_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_players_all.csv')
MIL_df_all_csv_io.head()
# Out:
#   NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     34        Ray Allen  SG    6-5     205  1975-07-20          US
# 1     11     Rafer Alston  PG    6-2     171  1976-07-24          US
# 2     10      Sam Cassell  PG    6-3     185  1969-11-18          US
# 3     15  Vinny Del Negro  PG    6-4     185  1966-08-09          US
# 4      9       Dale Ellis  SG    6-7     205  1960-08-06          US
#
#   EXPERIENCE        COLLEGE  Season Team
# 0          3          UConn    2000  MIL
# 1          R   Fresno State    2000  MIL
# 2          6  Florida State    2000  MIL
# 3          9       NC State    2000  MIL
# 4         16      Tennessee    2000  MIL

# %%
MIL_df_2000 = MIL_df_all[MIL_df_all['Season'] == 2000]
MIL_df_2001 = MIL_df_all[MIL_df_all['Season'] == 2001]
MIL_df_2002 = MIL_df_all[MIL_df_all['Season'] == 2002]
MIL_df_2003 = MIL_df_all[MIL_df_all['Season'] == 2003]
MIL_df_2004 = MIL_df_all[MIL_df_all['Season'] == 2004]
MIL_df_2005 = MIL_df_all[MIL_df_all['Season'] == 2005]
MIL_df_2006 = MIL_df_all[MIL_df_all['Season'] == 2006]
MIL_df_2007 = MIL_df_all[MIL_df_all['Season'] == 2007]
MIL_df_2008 = MIL_df_all[MIL_df_all['Season'] == 2008]
MIL_df_2009 = MIL_df_all[MIL_df_all['Season'] == 2009]
MIL_df_2010 = MIL_df_all[MIL_df_all['Season'] == 2010]
MIL_df_2011 = MIL_df_all[MIL_df_all['Season'] == 2011]
MIL_df_2012 = MIL_df_all[MIL_df_all['Season'] == 2012]
MIL_df_2013 = MIL_df_all[MIL_df_all['Season'] == 2013]
MIL_df_2014 = MIL_df_all[MIL_df_all['Season'] == 2014]
MIL_df_2015 = MIL_df_all[MIL_df_all['Season'] == 2015]
MIL_df_2016 = MIL_df_all[MIL_df_all['Season'] == 2016]
MIL_df_2017 = MIL_df_all[MIL_df_all['Season'] == 2017]
MIL_df_2018 = MIL_df_all[MIL_df_all['Season'] == 2018]
MIL_df_2019 = MIL_df_all[MIL_df_all['Season'] == 2019]
MIL_df_2020 = MIL_df_all[MIL_df_all['Season'] == 2020]
MIL_df_2021 = MIL_df_all[MIL_df_all['Season'] == 2021]

# %%
# changing names
#MIL_df_2002.loc[MIL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#MIL_df_2004.loc[MIL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
MIL_df_2000_players = MIL_df_2000['PLAYER'].to_list()
MIL_df_2001_players = MIL_df_2001['PLAYER'].to_list()
MIL_df_2002_players = MIL_df_2002['PLAYER'].to_list()
MIL_df_2003_players = MIL_df_2003['PLAYER'].to_list()
MIL_df_2004_players = MIL_df_2004['PLAYER'].to_list()
MIL_df_2005_players = MIL_df_2005['PLAYER'].to_list()

MIL_df_2006_players = MIL_df_2006['PLAYER'].to_list()
MIL_df_2007_players = MIL_df_2007['PLAYER'].to_list()
MIL_df_2008_players = MIL_df_2008['PLAYER'].to_list()
MIL_df_2009_players = MIL_df_2009['PLAYER'].to_list()
MIL_df_2010_players = MIL_df_2010['PLAYER'].to_list()
MIL_df_2011_players = MIL_df_2011['PLAYER'].to_list()

MIL_df_2012_players = MIL_df_2012['PLAYER'].to_list()
MIL_df_2013_players = MIL_df_2013['PLAYER'].to_list()
MIL_df_2014_players = MIL_df_2014['PLAYER'].to_list()
MIL_df_2015_players = MIL_df_2015['PLAYER'].to_list()
MIL_df_2016_players = MIL_df_2016['PLAYER'].to_list()
MIL_df_2017_players = MIL_df_2017['PLAYER'].to_list()

MIL_df_2018_players = MIL_df_2018['PLAYER'].to_list()
MIL_df_2019_players = MIL_df_2019['PLAYER'].to_list()
MIL_df_2020_players = MIL_df_2020['PLAYER'].to_list()
MIL_df_2021_players = MIL_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#MIL_df_2005_players.remove("Mo Williams")
#MIL_df_2006_players.remove("Mo Williams")
#MIL_df_2007_players.remove("Mo Williams")
#MIL_df_2008_players.remove("Mo Williams")
#MIL_df_2012_players.remove("Mike Dunleavy")
#MIL_df_2013_players.remove("Mike Dunleavy")
#MIL_df_2015_players.remove("Chris Johnson")
#MIL_df_2015_players.remove("Johnny O'Bryant")
#MIL_df_2016_players.remove("Johnny O'Bryant")
#MIL_df_2017_players.remove("Gary Payton")
#MIL_df_2018_players.remove("Xavier Munford")
#MIL_df_2018_players.remove("Gary Payton")
#MIL_df_2020_players.remove("Frank Mason")
MIL_df_2021_players.remove("Elijah Bryant")

# %%
MIL_2000_gamelog = []


for p in MIL_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2000_gamelog.append(player_log)
MIL_2000_gamelog = pd.concat(MIL_2000_gamelog)    
MIL_2000_gamelogs = MIL_2000_gamelog.copy()
MIL_2000_gamelogs['GAME_SCORE'] = MIL_2000_gamelogs['GAME_SCORE'].astype(float)
MIL_2000_games = MIL_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2000_games_csv = MIL_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2000_games.csv', index=False)
MIL_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2000_games.csv')
MIL_2000_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Vinny Del Negro"
# 1 result found.
# Vinny Del Negro
# Results for Vinny Del Negro:
#
# You searched for "Dale Ellis"
# 8 results found.
# 0: Dale Ellis
# 1: Dale Davis
# 2: Joe Ellis
# 3: Bo Ellis
# 4: Boo Ellis
# 5: Harold Ellis
# 6: Dave Zeller
# 7: Dave Feitl
# Pick one: 0
# Results for Dale Ellis:
#
# ...

# %%
MIL_2001_gamelog = []


for p in MIL_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2001_gamelog.append(player_log)
MIL_2001_gamelog = pd.concat(MIL_2001_gamelog)    
MIL_2001_gamelogs = MIL_2001_gamelog.copy()
MIL_2001_gamelogs['GAME_SCORE'] = MIL_2001_gamelogs['GAME_SCORE'].astype(float)
MIL_2001_games = MIL_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2001_games_csv = MIL_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2001_games.csv', index=False)
MIL_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2001_games.csv')
MIL_2001_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Jason Caffey"
# 2 results found.
# 0: Jason Caffey
# 1: Jason Sasser
# Pick one: 0
# Results for Jason Caffey:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Darvin Ham"
# 1 result found.
# Darvin Ham
# Results for Darvin Ham:
#
# You searched for "Jason Hart"
# 9 results found.
# 0: Jason Hart
# 1: Josh Hart
# 2: Jaxson Hayes
# ...

# %%
MIL_2002_gamelog = []


for p in MIL_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2002_gamelog.append(player_log)
MIL_2002_gamelog = pd.concat(MIL_2002_gamelog)    
MIL_2002_gamelogs = MIL_2002_gamelog.copy()
MIL_2002_gamelogs['GAME_SCORE'] = MIL_2002_gamelogs['GAME_SCORE'].astype(float)
MIL_2002_games = MIL_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2002_games_csv = MIL_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2002_games.csv', index=False)
MIL_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2002_games.csv')
MIL_2002_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Greg Anthony"
# 6 results found.
# 0: Greg Anthony
# 1: Joel Anthony
# 2: Cole Anthony
# 3: Greg Sutton
# 4: Greg Anderson
# 5: Greg Jackson
# Pick one: 0
# Results for Greg Anthony:
#
# You searched for "Jason Caffey"
# 2 results found.
# 0: Jason Caffey
# 1: Jason Sasser
# Pick one: 0
# Results for Jason Caffey:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# ...

# %%
    
MIL_2003_gamelog = []



for p in MIL_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2003_gamelog.append(player_log)
MIL_2003_gamelog = pd.concat(MIL_2003_gamelog)    
MIL_2003_gamelogs = MIL_2003_gamelog.copy()
MIL_2003_gamelogs['GAME_SCORE'] = MIL_2003_gamelogs['GAME_SCORE'].astype(float)
MIL_2003_games = MIL_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2003_games_csv = MIL_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2003_games.csv', index=False)
MIL_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2003_games.csv')
MIL_2003_games_proc.head()
# Out:
# You searched for "Ray Allen"
# 21 results found.
# 0: Ray Allen
# 1: Randy Allen
# 2: Bob Allen
# 3: Lavoy Allen
# 4: Tony Allen
# 5: Bill Allen
# 6: Grayson Allen
# 7: Malik Allen
# 8: Ray Blume
# 9: Ray Corley
# 10: Ray Ellefson
# 11: Ray Felix
# 12: Jay Miller
# 13: Ray Owes
# 14: Ray Ramsey
# 15: Ray Epps
# 16: Roy Marble
# 17: Raja Bell
# 18: Troy Bell
# 19: Gary Hill
# 20: Gary Neal
# Pick one: 0
# Results for Ray Allen:
#
# You searched for "Jason Caffey"
# 2 results found.
# 0: Jason Caffey
# 1: Jason Sasser
# Pick one: 0
# Results for Jason Caffey:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Marcus Haislip"
# 1 result found.
# Marcus Haislip
# Results for Marcus Haislip:
#
# You searched for "Ervin Johnson"
# 28 results found.
# 0: Ervin Johnson
# ...

# %%
MIL_2004_gamelog = []



for p in MIL_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2004_gamelog.append(player_log)
MIL_2004_gamelog = pd.concat(MIL_2004_gamelog)    
MIL_2004_gamelogs = MIL_2004_gamelog.copy()
MIL_2004_gamelogs['GAME_SCORE'] = MIL_2004_gamelogs['GAME_SCORE'].astype(float)
MIL_2004_games = MIL_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2004_games_csv = MIL_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2004_games.csv', index=False)
MIL_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2004_games.csv')
MIL_2004_games_proc.head()
# Out:
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# 2: Don Ford
# 3: Jake Ford
# 4: Phil Ford
# 5: T.J. Leaf
# 6: O.J. Mayo
# Pick one: 0
# Results for T.J. Ford:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Marcus Haislip"
# 1 result found.
# Marcus Haislip
# Results for Marcus Haislip:
#
# You searched for "Damon Jones"
# 24 results found.
# 0: Damon Jones
# 1: Mason Jones
# 2: Damian Jones
# 3: Damion James
# 4: Jalen Jones
# 5: James Jones
# 6: Major Jones
# 7: Sam Jones
# 8: Aaron James
# 9: Alvin Jones
# 10: DeQuan Jones
# 11: Dwayne Jones
# 12: Earl Jones
# 13: Jake Jones
# 14: Jimmy Jones
# 15: Kevin Jones
# 16: Larry Jones
# 17: Mark Jones
# 18: Mark Jones
# 19: Robin Jones
# 20: Solomon Jones
# 21: Wali Jones
# 22: Diamond Stone
# 23: Damone Brown
# Pick one: 0
# Results for Damon Jones:
#
# You searched for "Brevin Knight"
# 5 results found.
# 0: Brevin Knight
# ...

# %%
# removed Mo Williams

MIL_2005_gamelog = []

for p in MIL_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2005_gamelog.append(player_log)
MIL_2005_gamelog = pd.concat(MIL_2005_gamelog)    
MIL_2005_gamelogs = MIL_2005_gamelog.copy()
MIL_2005_gamelogs['GAME_SCORE'] = MIL_2005_gamelogs['GAME_SCORE'].astype(float)
MIL_2005_games = MIL_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2005_games_csv = MIL_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2005_games.csv', index=False)
MIL_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2005_games.csv')
MIL_2005_games_proc.head()
# Out:
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Marcus Fizer"
# 4 results found.
# 0: Marcus Fizer
# 1: Marcus Liberty
# 2: Marcus Paige
# 3: Marcus Webb
# Pick one: 0
# Results for Marcus Fizer:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Reece Gaines"
# 1 result found.
# Reece Gaines
# Results for Reece Gaines:
#
# You searched for "Kendall Gill"
# 2 results found.
# 0: Kendall Gill
# 1: Kendall Rhine
# Pick one: 0
# Results for Kendall Gill:
#
# You searched for "Anthony Goldwire"
# 2 results found.
# 0: Anthony Goldwire
# 1: Anthony Bowie
# Pick one: 0
# Results for Anthony Goldwire:
#
# You searched for "Zendon Hamilton"
# 3 results found.
# 0: Zendon Hamilton
# 1: Dennis Hamilton
# 2: Jordan Hamilton
# Pick one: 0
# Results for Zendon Hamilton:
#
# You searched for "Eddie House"
# ...

# %%
# removed mo williams
MIL_2006_gamelog = []

for p in MIL_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2006_gamelog.append(player_log)
MIL_2006_gamelog = pd.concat(MIL_2006_gamelog)    
MIL_2006_gamelogs = MIL_2006_gamelog.copy()
MIL_2006_gamelogs['GAME_SCORE'] = MIL_2006_gamelogs['GAME_SCORE'].astype(float)
MIL_2006_games = MIL_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2006_games_csv = MIL_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2006_games.csv', index=False)
MIL_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2006_games.csv')
MIL_2006_games_proc.head()
# Out:
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Josh Davis"
# 27 results found.
# 0: Josh Davis
# 1: Bob Davis
# 2: Jim Davis
# 3: Ron Davis
# 4: Josh Reaves
# 5: Josh Hall
# 6: Bob Davies
# 7: Ben Davis
# 8: Bill Davis
# 9: Brad Davis
# 10: Dale Davis
# 11: Ed Davis
# 12: Glen Davis
# 13: Johnny Davis
# 14: Lee Davis
# 15: Mark Davis
# 16: Mark Davis
# 17: Mel Davis
# 18: Mike Davis
# 19: Mike Davis
# 20: Monti Davis
# 21: Paul Davis
# 22: Ralph Davis
# 23: Red Davis
# 24: Walt Davis
# 25: Josh Hart
# 26: Josh Grant
# Pick one: 0
# Results for Josh Davis:
#
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# ...

# %%
# removed mo williams

MIL_2007_gamelog = []

for p in MIL_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2007_gamelog.append(player_log)
MIL_2007_gamelog = pd.concat(MIL_2007_gamelog)    
MIL_2007_gamelogs = MIL_2007_gamelog.copy()
MIL_2007_gamelogs['GAME_SCORE'] = MIL_2007_gamelogs['GAME_SCORE'].astype(float)
MIL_2007_games = MIL_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2007_games_csv = MIL_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2007_games.csv', index=False)
MIL_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2007_games.csv')
MIL_2007_games_proc.head()
# Out:
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Lynn Greer"
# 6 results found.
# 0: Lynn Greer
# 1: Danny Green
# 2: Ken Green
# 3: Kenny Green
# 4: Sean Green
# 5: Hal Greer
# ...

# %%
# removed mo williams

MIL_2008_gamelog = []

for p in MIL_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2008_gamelog.append(player_log)
MIL_2008_gamelog = pd.concat(MIL_2008_gamelog)    
MIL_2008_gamelogs = MIL_2008_gamelog.copy()
MIL_2008_gamelogs['GAME_SCORE'] = MIL_2008_gamelogs['GAME_SCORE'].astype(float)
MIL_2008_games = MIL_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2008_games_csv = MIL_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2008_games.csv', index=False)
MIL_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2008_games.csv')
MIL_2008_games_proc.head()
# Out:
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Royal Ivey"
# 1 result found.
# Royal Ivey
# Results for Royal Ivey:
#
# You searched for "Yi Jianlian"
# 1 result found.
# Yi Jianlian
# Results for Yi Jianlian:
#
# You searched for "Desmond Mason"
# 2 results found.
# 0: Desmond Mason
# 1: Desmond Bane
# Pick one: 0
# Results for Desmond Mason:
#
# You searched for "Michael Redd"
# 5 results found.
# 0: Michael Redd
# 1: Michael Cage
# 2: Michael Curry
# 3: Michael Porter
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Redd:
#
# ...

# %%
MIL_2009_gamelog = []

for p in MIL_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2009_gamelog.append(player_log)
MIL_2009_gamelog = pd.concat(MIL_2009_gamelog)    
MIL_2009_gamelogs = MIL_2009_gamelog.copy()
MIL_2009_gamelogs['GAME_SCORE'] = MIL_2009_gamelogs['GAME_SCORE'].astype(float)
MIL_2009_games = MIL_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2009_games_csv = MIL_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2009_games.csv', index=False)
MIL_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2009_games.csv')
MIL_2009_games_proc.head()
# Out:
# You searched for "Joe Alexander"
# 4 results found.
# 0: Joe Alexander
# 1: Cory Alexander
# 2: Kyle Alexander
# 3: Gary Alexander
# Pick one: 0
# Results for Joe Alexander:
#
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# ...

# %%
MIL_2010_gamelog = []

for p in MIL_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2010_gamelog.append(player_log)
MIL_2010_gamelog = pd.concat(MIL_2010_gamelog)    
MIL_2010_gamelogs = MIL_2010_gamelog.copy()
MIL_2010_gamelogs['GAME_SCORE'] = MIL_2010_gamelogs['GAME_SCORE'].astype(float)
MIL_2010_games = MIL_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2010_games_csv = MIL_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2010_games.csv', index=False)
MIL_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2010_games.csv')
MIL_2010_games_proc.head()
# Out:
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Dan Gadzuric"
# 1 result found.
# Dan Gadzuric
# Results for Dan Gadzuric:
#
# You searched for "Ersan İlyasova"
# 1 result found.
# Ersan Ilyasova
# Results for Ersan Ilyasova:
#
# You searched for "Royal Ivey"
# 1 result found.
# Royal Ivey
# Results for Royal Ivey:
#
# ...

# %%
MIL_2011_gamelog = []

for p in MIL_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2011_gamelog.append(player_log)
MIL_2011_gamelog = pd.concat(MIL_2011_gamelog)    
MIL_2011_gamelogs = MIL_2011_gamelog.copy()
MIL_2011_gamelogs['GAME_SCORE'] = MIL_2011_gamelogs['GAME_SCORE'].astype(float)
MIL_2011_games = MIL_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2011_games_csv = MIL_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2011_games.csv', index=False)
MIL_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2011_games.csv')
MIL_2011_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Jon Brockman"
# 1 result found.
# Jon Brockman
# Results for Jon Brockman:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Chris Douglas-Roberts"
# 1 result found.
# Chris Douglas-Roberts
# Results for Chris Douglas-Roberts:
#
# You searched for "Drew Gooden"
# ...

# %%
# removed mike dunleavy 
MIL_2012_gamelog = []

for p in MIL_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2012_gamelog.append(player_log)
MIL_2012_gamelog = pd.concat(MIL_2012_gamelog)    
MIL_2012_gamelogs = MIL_2012_gamelog.copy()
MIL_2012_gamelogs['GAME_SCORE'] = MIL_2012_gamelogs['GAME_SCORE'].astype(float)
MIL_2012_games = MIL_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2012_games_csv = MIL_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2012_games.csv', index=False)
MIL_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2012_games.csv')
MIL_2012_games_proc.head()
# Out:
# You searched for "Andrew Bogut"
# 4 results found.
# 0: Andrew Bogut
# 1: Andrew Bynum
# 2: Andrew Toney
# 3: Andrew Gaze
# Pick one: 0
# Results for Andrew Bogut:
#
# You searched for "Jon Brockman"
# 1 result found.
# Jon Brockman
# Results for Jon Brockman:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# 2: Bob Harris
# 3: Chris Harris
# 4: Tony Harris
# 5: Bob Harrison
# Pick one: 0
# Results for Tobias Harris:
#
# You searched for "Darington Hobson"
# 1 result found.
# Darington Hobson
# Results for Darington Hobson:
#
# ...

# %%
# removed mike dunleavy
MIL_2013_gamelog = []

for p in MIL_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2013_gamelog.append(player_log)
MIL_2013_gamelog = pd.concat(MIL_2013_gamelog)    
MIL_2013_gamelogs = MIL_2013_gamelog.copy()
MIL_2013_gamelogs['GAME_SCORE'] = MIL_2013_gamelogs['GAME_SCORE'].astype(float)
MIL_2013_games = MIL_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2013_games_csv = MIL_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2013_games.csv', index=False)
MIL_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2013_games.csv')
MIL_2013_games_proc.head()
# Out:
# You searched for "Gustavo Ayón"
# 1 result found.
# Gustavo Ayon
# Results for Gustavo Ayon:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Marquis Daniels"
# 1 result found.
# Marquis Daniels
# Results for Marquis Daniels:
#
# You searched for "Monta Ellis"
# 5 results found.
# 0: Monta Ellis
# 1: Monti Davis
# 2: Bo Ellis
# 3: Boo Ellis
# 4: Joe Ellis
# Pick one: 0
# Results for Monta Ellis:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# 2: Bob Harris
# 3: Chris Harris
# 4: Tony Harris
# 5: Bob Harrison
# Pick one: 0
# Results for Tobias Harris:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# 3: John Clawson
# 4: John Dickson
# 5: John Hazen
# ...

# %%
MIL_2014_gamelog = []

for p in MIL_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2014_gamelog.append(player_log)
MIL_2014_gamelog = pd.concat(MIL_2014_gamelog)    
MIL_2014_gamelogs = MIL_2014_gamelog.copy()
MIL_2014_gamelogs['GAME_SCORE'] = MIL_2014_gamelogs['GAME_SCORE'].astype(float)
MIL_2014_games = MIL_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2014_games_csv = MIL_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2014_games.csv', index=False)
MIL_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2014_games.csv')
MIL_2014_games_proc.head()
# Out:
# You searched for "Jeff Adrien"
# 10 results found.
# 0: Jeff Adrien
# 1: Jeff Ayres
# 2: Jeff Green
# 3: Jeff Martin
# 4: Jeff Turner
# 5: Jeff Grayer
# 6: Jeff Malone
# 7: Jeff Ruland
# 8: Jeff Sanders
# 9: Jeff Taylor
# Pick one: 0
# Results for Jeff Adrien:
#
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# 3: John Clawson
# 4: John Dickson
# 5: John Hazen
# 6: Jack Hewson
# 7: Roy Hinson
# 8: John Jenkins
# 9: John Morton
# 10: Don Nelson
# 11: Ron Nelson
# 12: John Pinone
# 13: John Thompson
# 14: John Windsor
# 15: John Chaney
# 16: John Hargis
# 17: John Hummer
# 18: John Long
# ...

# %%
# removed chris johnson
# removed Johnny O'Bryant
MIL_2015_gamelog = []

for p in MIL_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2015_gamelog.append(player_log)
MIL_2015_gamelog = pd.concat(MIL_2015_gamelog)    
MIL_2015_gamelogs = MIL_2015_gamelog.copy()
MIL_2015_gamelogs['GAME_SCORE'] = MIL_2015_gamelogs['GAME_SCORE'].astype(float)
MIL_2015_games = MIL_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2015_games_csv = MIL_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2015_games.csv', index=False)
MIL_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2015_games.csv')
MIL_2015_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# 2: Chris Dudley
# Pick one: 0
# Results for Jared Dudley:
#
# You searched for "Tyler Ennis"
# 6 results found.
# 0: Tyler Ennis
# 1: Tyler Davis
# 2: Tyler Ulis
# 3: James Ennis
# 4: Tyler Herro
# 5: Tyler Lydon
# Pick one: 0
# Results for Tyler Ennis:
#
# You searched for "Jorge Gutiérrez"
# 1 result found.
# Jorge Gutierrez
# Results for Jorge Gutierrez:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# 3: John Clawson
# 4: John Dickson
# ...

# %%
# removed Johnny O'Bryant

MIL_2016_gamelog = []

for p in MIL_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2016_gamelog.append(player_log)
MIL_2016_gamelog = pd.concat(MIL_2016_gamelog)    
MIL_2016_gamelogs = MIL_2016_gamelog.copy()
MIL_2016_gamelogs['GAME_SCORE'] = MIL_2016_gamelogs['GAME_SCORE'].astype(float)
MIL_2016_games = MIL_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2016_games_csv = MIL_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2016_games.csv', index=False)
MIL_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2016_games.csv')
MIL_2016_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Chris Copeland"
# 2 results found.
# 0: Chris Copeland
# 1: Hollis Copeland
# Pick one: 0
# Results for Chris Copeland:
#
# You searched for "Jared Cunningham"
# 2 results found.
# 0: Jared Cunningham
# 1: Dante Cunningham
# Pick one: 0
# Results for Jared Cunningham:
#
# You searched for "Tyler Ennis"
# 6 results found.
# 0: Tyler Ennis
# 1: Tyler Davis
# 2: Tyler Ulis
# 3: James Ennis
# 4: Tyler Herro
# 5: Tyler Lydon
# Pick one: 0
# Results for Tyler Ennis:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# ...

# %%
# removed gary payton (jr)

MIL_2017_gamelog = []

for p in MIL_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2017_gamelog.append(player_log)
MIL_2017_gamelog = pd.concat(MIL_2017_gamelog)    
MIL_2017_gamelogs = MIL_2017_gamelog.copy()
MIL_2017_gamelogs['GAME_SCORE'] = MIL_2017_gamelogs['GAME_SCORE'].astype(float)
MIL_2017_games = MIL_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2017_games_csv = MIL_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2017_games.csv', index=False)
MIL_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2017_games.csv')
MIL_2017_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Matthew Dellavedova"
# 1 result found.
# Matthew Dellavedova
# Results for Matthew Dellavedova:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# 1: Steve Hawes
# 2: Spencer Haywood
# Pick one: 0
# Results for Spencer Hawes:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# 3: John Clawson
# 4: John Dickson
# 5: John Hazen
# 6: Jack Hewson
# 7: Roy Hinson
# 8: John Jenkins
# 9: John Morton
# 10: Don Nelson
# ...

# %%
# removed xxavier munford
# removed gary payton

MIL_2018_gamelog = []

for p in MIL_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2018_gamelog.append(player_log)
MIL_2018_gamelog = pd.concat(MIL_2018_gamelog)    
MIL_2018_gamelogs = MIL_2018_gamelog.copy()
MIL_2018_gamelogs['GAME_SCORE'] = MIL_2018_gamelogs['GAME_SCORE'].astype(float)
MIL_2018_games = MIL_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2018_games_csv = MIL_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2018_games.csv', index=False)
MIL_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2018_games.csv')
MIL_2018_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Joel Bolomboy"
# 1 result found.
# Joel Bolomboy
# Results for Joel Bolomboy:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Matthew Dellavedova"
# 1 result found.
# Matthew Dellavedova
# Results for Matthew Dellavedova:
#
# You searched for "John Henson"
# 23 results found.
# 0: John Henson
# 1: John Johnson
# 2: John Paxson
# 3: John Clawson
# 4: John Dickson
# 5: John Hazen
# 6: Jack Hewson
# 7: Roy Hinson
# 8: John Jenkins
# 9: John Morton
# 10: Don Nelson
# 11: Ron Nelson
# 12: John Pinone
# 13: John Thompson
# ...

# %%
MIL_2019_gamelog = []

for p in MIL_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2019_gamelog.append(player_log)
MIL_2019_gamelog = pd.concat(MIL_2019_gamelog)    
MIL_2019_gamelogs = MIL_2019_gamelog.copy()
MIL_2019_gamelogs['GAME_SCORE'] = MIL_2019_gamelogs['GAME_SCORE'].astype(float)
MIL_2019_games = MIL_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2019_games_csv = MIL_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2019_games.csv', index=False)
MIL_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2019_games.csv')
MIL_2019_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Bonzie Colson"
# 1 result found.
# Bonzie Colson
# Results for Bonzie Colson:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Matthew Dellavedova"
# 1 result found.
# Matthew Dellavedova
# Results for Matthew Dellavedova:
#
# You searched for "Donte DiVincenzo"
# 1 result found.
# Donte DiVincenzo
# ...

# %%
# removed frank mason 
MIL_2020_gamelog = []

for p in MIL_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2020_gamelog.append(player_log)
MIL_2020_gamelog = pd.concat(MIL_2020_gamelog)    
MIL_2020_gamelogs = MIL_2020_gamelog.copy()
MIL_2020_gamelogs['GAME_SCORE'] = MIL_2020_gamelogs['GAME_SCORE'].astype(float)
MIL_2020_games = MIL_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2020_games_csv = MIL_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2020_games.csv', index=False)
MIL_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2020_games.csv')
MIL_2020_games_proc.head()
# Out:
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Thanasis Antetokounmpo"
# 2 results found.
# 0: Thanasis Antetokounmpo
# 1: Giannis Antetokounmpo
# Pick one: 0
# Results for Thanasis Antetokounmpo:
#
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Donte DiVincenzo"
# 1 result found.
# Donte DiVincenzo
# Results for Donte DiVincenzo:
#
# You searched for "George Hill"
# 11 results found.
# 0: George Hill
# 1: George Karl
# 2: George King
# 3: George King
# 4: Gary Hill
# ...

# %%
# removed Elijah Bryant
MIL_2021_gamelog = []

for p in MIL_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    MIL_2021_gamelog.append(player_log)
MIL_2021_gamelog = pd.concat(MIL_2021_gamelog)    
MIL_2021_gamelogs = MIL_2021_gamelog.copy()
MIL_2021_gamelogs['GAME_SCORE'] = MIL_2021_gamelogs['GAME_SCORE'].astype(float)
MIL_2021_games = MIL_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_2021_games_csv = MIL_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2021_games.csv', index=False)
MIL_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2021_games.csv')
MIL_2021_games_proc.head()
# Out:
# You searched for "Jaylen Adams"
# 6 results found.
# 0: Jaylen Adams
# 1: Alvan Adams
# 2: Hassan Adams
# 3: Jordan Adams
# 4: Steven Adams
# 5: Jaylen Hoard
# Pick one: 0
# Results for Jaylen Adams:
#
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# 0: Giannis Antetokounmpo
# 1: Thanasis Antetokounmpo
# Pick one: 0
# Results for Giannis Antetokounmpo:
#
# You searched for "Thanasis Antetokounmpo"
# 2 results found.
# 0: Thanasis Antetokounmpo
# 1: Giannis Antetokounmpo
# Pick one: 0
# Results for Thanasis Antetokounmpo:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Torrey Craig"
# 1 result found.
# Torrey Craig
# Results for Torrey Craig:
#
# You searched for "Mamadi Diakite"
# 1 result found.
# Mamadi Diakite
# Results for Mamadi Diakite:
#
# You searched for "Donte DiVincenzo"
# ...

# %% [markdown]
# ## combine all seasons

# %%
MIL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2000_games.csv')
MIL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2001_games.csv')
MIL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2002_games.csv')
MIL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2003_games.csv')
MIL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2004_games.csv')
MIL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2005_games.csv')
MIL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2006_games.csv')
MIL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2007_games.csv')
MIL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2008_games.csv')
MIL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2009_games.csv')
MIL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2010_games.csv')
MIL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2011_games.csv')
MIL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2012_games.csv')
MIL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2013_games.csv')
MIL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2014_games.csv')
MIL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2015_games.csv')
MIL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2016_games.csv')
MIL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2017_games.csv')
MIL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2018_games.csv')
MIL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2019_games.csv')
MIL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2020_games.csv')
MIL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2021_games.csv')

# %%
MIL_season_dfs = [MIL_2000_games_io, MIL_2001_games_io, MIL_2002_games_io, MIL_2003_games_io, MIL_2004_games_io, MIL_2005_games_io,
                 MIL_2006_games_io, MIL_2007_games_io, MIL_2008_games_io, MIL_2009_games_io, MIL_2010_games_io, MIL_2011_games_io,
                 MIL_2012_games_io, MIL_2013_games_io, MIL_2014_games_io, MIL_2015_games_io, MIL_2016_games_io, MIL_2017_games_io,
                 MIL_2018_games_io, MIL_2019_games_io, MIL_2020_games_io, MIL_2021_games_io]

# %%
MIL_all = pd.concat(MIL_season_dfs)
MIL_all_sorted = MIL_all.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2019-03-17  24-101  MIL      HOME      PHI   L (-5)   1  36:12  15   26
# 0  2019-11-25  24-354  MIL      HOME      UTA   W (+4)   1  38:30  17   31
# 1  2020-01-28  28-169  MIL      HOME      WAS  W (+20)   1  35:52  16   26
# 1  2019-04-04  24-119  MIL      AWAY      PHI   W (+6)   1  34:58  13   22
# 0  2018-01-26  23-051  MIL      HOME      BRK  W (+25)   1  32:54  14   20
# 0  2021-04-02  26-117  MIL      AWAY      POR  W (+18)   1  33:05  18   21
# 0  2006-11-11  27-079  MIL      HOME      UTA   L (-2)   1  45:44  18   32
# 1  2021-02-10  26-066  MIL      AWAY      PHO   L (-1)   1  37:55  15   23
# 2  2018-12-14  24-008  MIL      AWAY      CLE  W (+12)   1  37:31  14   19
# 0  2002-04-14  26-268  MIL      HOME      CHH   W (+7)   1  44:17  15   23
# 2  2021-05-13  26-158  MIL      AWAY      IND   W (+9)   1  35:05  14   18
# ...
