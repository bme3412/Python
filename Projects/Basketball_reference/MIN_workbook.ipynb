# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_MIN = []

# MIN
while season <= 2021:
    df_MIN = get_roster('MIN', season)
    df_MIN['Season'] = season
    df_MIN['Team'] = 'MIN'
    appended_data_MIN.append(df_MIN)
    season = season + 1
appended_data_MIN = pd.concat(appended_data_MIN)

# %%
MIN_df_all = appended_data_MIN.copy()
MIN_df_all_csv = MIN_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_players_all.csv', index=False)
MIN_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_players_all.csv')
MIN_df_all_csv_io.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0       5    William Avery  PG    6-2     197  1979-08-08          US
# 1       7  Terrell Brandon  PG   5-11     180  1970-05-20          US
# 2      21    Kevin Garnett  PF   6-11     240  1976-05-19          US
# 3      22     Dean Garrett   C   6-10     225  1966-11-27          US
# 4      20     Tom Hammonds  PF    6-9     215  1967-03-27          US
#
#   EXPERIENCE       COLLEGE  Season Team
# 0          R          Duke    2000  MIN
# 1          8        Oregon    2000  MIN
# 2          4           NaN    2000  MIN
# 3          3       Indiana    2000  MIN
# 4         10  Georgia Tech    2000  MIN

# %%
MIN_df_2000 = MIN_df_all[MIN_df_all['Season'] == 2000]
MIN_df_2001 = MIN_df_all[MIN_df_all['Season'] == 2001]
MIN_df_2002 = MIN_df_all[MIN_df_all['Season'] == 2002]
MIN_df_2003 = MIN_df_all[MIN_df_all['Season'] == 2003]
MIN_df_2004 = MIN_df_all[MIN_df_all['Season'] == 2004]
MIN_df_2005 = MIN_df_all[MIN_df_all['Season'] == 2005]
MIN_df_2006 = MIN_df_all[MIN_df_all['Season'] == 2006]
MIN_df_2007 = MIN_df_all[MIN_df_all['Season'] == 2007]
MIN_df_2008 = MIN_df_all[MIN_df_all['Season'] == 2008]
MIN_df_2009 = MIN_df_all[MIN_df_all['Season'] == 2009]
MIN_df_2010 = MIN_df_all[MIN_df_all['Season'] == 2010]
MIN_df_2011 = MIN_df_all[MIN_df_all['Season'] == 2011]
MIN_df_2012 = MIN_df_all[MIN_df_all['Season'] == 2012]
MIN_df_2013 = MIN_df_all[MIN_df_all['Season'] == 2013]
MIN_df_2014 = MIN_df_all[MIN_df_all['Season'] == 2014]
MIN_df_2015 = MIN_df_all[MIN_df_all['Season'] == 2015]
MIN_df_2016 = MIN_df_all[MIN_df_all['Season'] == 2016]
MIN_df_2017 = MIN_df_all[MIN_df_all['Season'] == 2017]
MIN_df_2018 = MIN_df_all[MIN_df_all['Season'] == 2018]
MIN_df_2019 = MIN_df_all[MIN_df_all['Season'] == 2019]
MIN_df_2020 = MIN_df_all[MIN_df_all['Season'] == 2020]
MIN_df_2021 = MIN_df_all[MIN_df_all['Season'] == 2021]

# %%
# changing names
#MIN_df_2002.loc[MIN_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#MIN_df_2004.loc[MIN_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
MIN_df_2000_players = MIN_df_2000['PLAYER'].to_list()
MIN_df_2001_players = MIN_df_2001['PLAYER'].to_list()
MIN_df_2002_players = MIN_df_2002['PLAYER'].to_list()
MIN_df_2003_players = MIN_df_2003['PLAYER'].to_list()
MIN_df_2004_players = MIN_df_2004['PLAYER'].to_list()
MIN_df_2005_players = MIN_df_2005['PLAYER'].to_list()

MIN_df_2006_players = MIN_df_2006['PLAYER'].to_list()
MIN_df_2007_players = MIN_df_2007['PLAYER'].to_list()
MIN_df_2008_players = MIN_df_2008['PLAYER'].to_list()
MIN_df_2009_players = MIN_df_2009['PLAYER'].to_list()
MIN_df_2010_players = MIN_df_2010['PLAYER'].to_list()
MIN_df_2011_players = MIN_df_2011['PLAYER'].to_list()

MIN_df_2012_players = MIN_df_2012['PLAYER'].to_list()
MIN_df_2013_players = MIN_df_2013['PLAYER'].to_list()
MIN_df_2014_players = MIN_df_2014['PLAYER'].to_list()
MIN_df_2015_players = MIN_df_2015['PLAYER'].to_list()
MIN_df_2016_players = MIN_df_2016['PLAYER'].to_list()
MIN_df_2017_players = MIN_df_2017['PLAYER'].to_list()

MIN_df_2018_players = MIN_df_2018['PLAYER'].to_list()
MIN_df_2019_players = MIN_df_2019['PLAYER'].to_list()
MIN_df_2020_players = MIN_df_2020['PLAYER'].to_list()
MIN_df_2021_players = MIN_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#MIN_df_2010_players.remove("Sasha Pavlović")
#MIN_df_2012_players.remove("J.J. Barea")
#MIN_df_2013_players.remove("J.J. Barea")
#MIN_df_2014_players.remove("J.J. Barea")
#MIN_df_2015_players.remove("Glenn Robinson")
#MIN_df_2015_players.remove("Mo Williams")
#MIN_df_2016_players.remove("Greg Smith")
MIN_df_2020_players.remove("D'Angelo Russell")
MIN_df_2021_players.remove("D'Angelo Russell")

# %%
MIN_2000_gamelog = []


for p in MIN_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2000_gamelog.append(player_log)
MIN_2000_gamelog = pd.concat(MIN_2000_gamelog)    
MIN_2000_gamelogs = MIN_2000_gamelog.copy()
MIN_2000_gamelogs['GAME_SCORE'] = MIN_2000_gamelogs['GAME_SCORE'].astype(float)
MIN_2000_games = MIN_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2000_games_csv = MIN_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2000_games.csv', index=False)
MIN_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2000_games.csv')
MIN_2000_games_proc.head()
# Out:
# You searched for "William Avery"
# 1 result found.
# William Avery
# Results for William Avery:
#
# You searched for "Terrell Brandon"
# 1 result found.
# Terrell Brandon
# Results for Terrell Brandon:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Dean Garrett"
# 5 results found.
# 0: Dean Garrett
# 1: Diante Garrett
# 2: Dick Garrett
# 3: Ken Durrett
# 4: Kevin Garnett
# Pick one: 0
# Results for Dean Garrett:
#
# You searched for "Tom Hammonds"
# 2 results found.
# 0: Tom Hammonds
# 1: Tom Hawkins
# Pick one: 0
# Results for Tom Hammonds:
#
# You searched for "Bobby Jackson"
# 10 results found.
# 0: Bobby Jackson
# 1: Tony Jackson
# 2: Tony Jackson
# 3: Bobby Watson
# 4: Josh Jackson
# 5: Tracy Jackson
# 6: Bobby Wilson
# 7: Bobby Wilson
# 8: Bobby Jones
# 9: Bobby Jones
# Pick one: 0
# ...

# %%
MIN_2001_gamelog = []


for p in MIN_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2001_gamelog.append(player_log)
MIN_2001_gamelog = pd.concat(MIN_2001_gamelog)    
MIN_2001_gamelogs = MIN_2001_gamelog.copy()
MIN_2001_gamelogs['GAME_SCORE'] = MIN_2001_gamelogs['GAME_SCORE'].astype(float)
MIN_2001_games = MIN_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2001_games_csv = MIN_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2001_games.csv', index=False)
MIN_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2001_games.csv')
MIN_2001_games_proc.head()
# Out:
# You searched for "William Avery"
# 1 result found.
# William Avery
# Results for William Avery:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Terrell Brandon"
# 1 result found.
# Terrell Brandon
# Results for Terrell Brandon:
#
# You searched for "Todd Day"
# 5 results found.
# 0: Todd Day
# 1: Rudy Gay
# 2: Don May
# 3: Don Ray
# 4: Todd Mundt
# Pick one: 0
# Results for Todd Day:
#
# You searched for "LaPhonso Ellis"
# 1 result found.
# LaPhonso Ellis
# Results for LaPhonso Ellis:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Dean Garrett"
# 5 results found.
# 0: Dean Garrett
# 1: Diante Garrett
# 2: Dick Garrett
# 3: Ken Durrett
# 4: Kevin Garnett
# Pick one: 0
# Results for Dean Garrett:
#
# ...

# %%
MIN_2002_gamelog = []


for p in MIN_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2002_gamelog.append(player_log)
MIN_2002_gamelog = pd.concat(MIN_2002_gamelog)    
MIN_2002_gamelogs = MIN_2002_gamelog.copy()
MIN_2002_gamelogs['GAME_SCORE'] = MIN_2002_gamelogs['GAME_SCORE'].astype(float)
MIN_2002_games = MIN_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2002_games_csv = MIN_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2002_games.csv', index=False)
MIN_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2002_games.csv')
MIN_2002_games_proc.head()
# Out:
# You searched for "William Avery"
# 1 result found.
# William Avery
# Results for William Avery:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Terrell Brandon"
# 1 result found.
# Terrell Brandon
# Results for Terrell Brandon:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# 4: Maurice Ager
# 5: Maurice Baker
# Pick one: 0
# Results for Maurice Evans:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Dean Garrett"
# 5 results found.
# 0: Dean Garrett
# 1: Diante Garrett
# 2: Dick Garrett
# 3: Ken Durrett
# 4: Kevin Garnett
# Pick one: 0
# Results for Dean Garrett:
#
# You searched for "Marc Jackson"
# 24 results found.
# 0: Marc Jackson
# ...

# %%
    
MIN_2003_gamelog = []



for p in MIN_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2003_gamelog.append(player_log)
MIN_2003_gamelog = pd.concat(MIN_2003_gamelog)    
MIN_2003_gamelogs = MIN_2003_gamelog.copy()
MIN_2003_gamelogs['GAME_SCORE'] = MIN_2003_gamelogs['GAME_SCORE'].astype(float)
MIN_2003_games = MIN_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2003_games_csv = MIN_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2003_games.csv', index=False)
MIN_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2003_games.csv')
MIN_2003_games_proc.head()
# Out:
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Kendall Gill"
# 2 results found.
# 0: Kendall Gill
# 1: Kendall Rhine
# Pick one: 0
# Results for Kendall Gill:
#
# You searched for "Troy Hudson"
# 3 results found.
# 0: Troy Hudson
# 1: Roy Hinson
# 2: Lou Hudson
# Pick one: 0
# Results for Troy Hudson:
#
# You searched for "Marc Jackson"
# 24 results found.
# 0: Marc Jackson
# 1: Mark Jackson
# 2: Aaron Jackson
# 3: Al Jackson
# 4: Jaren Jackson
# 5: Jaren Jackson
# 6: Mike Jackson
# 7: Myron Jackson
# 8: Marc Gasol
# 9: Cedric Jackson
# 10: Frank Jackson
# 11: Greg Jackson
# 12: Jim Jackson
# 13: Josh Jackson
# 14: Luke Jackson
# 15: Luke Jackson
# 16: Mervin Jackson
# 17: Phil Jackson
# 18: Ralph Jackson
# 19: Tony Jackson
# 20: Tony Jackson
# 21: Tracy Jackson
# 22: Mark Macon
# 23: Marcus Banks
# ...

# %%
MIN_2004_gamelog = []



for p in MIN_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2004_gamelog.append(player_log)
MIN_2004_gamelog = pd.concat(MIN_2004_gamelog)    
MIN_2004_gamelogs = MIN_2004_gamelog.copy()
MIN_2004_gamelogs['GAME_SCORE'] = MIN_2004_gamelogs['GAME_SCORE'].astype(float)
MIN_2004_games = MIN_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2004_games_csv = MIN_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2004_games.csv', index=False)
MIN_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2004_games.csv')
MIN_2004_games_proc.head()
# Out:
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Ndudi Ebi"
# 1 result found.
# Ndudi Ebi
# Results for Ndudi Ebi:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Anthony Goldwire"
# 2 results found.
# 0: Anthony Goldwire
# 1: Anthony Bowie
# Pick one: 0
# Results for Anthony Goldwire:
#
# You searched for "Trenton Hassell"
# 1 result found.
# Trenton Hassell
# Results for Trenton Hassell:
#
# You searched for "Fred Hoiberg"
# 3 results found.
# 0: Fred Hoiberg
# 1: Fred Foster
# 2: Fred Roberts
# Pick one: 0
# Results for Fred Hoiberg:
#
# You searched for "Troy Hudson"
# 3 results found.
# 0: Troy Hudson
# 1: Roy Hinson
# 2: Lou Hudson
# Pick one: 0
# Results for Troy Hudson:
#
# ...

# %%
MIN_2005_gamelog = []

for p in MIN_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2005_gamelog.append(player_log)
MIN_2005_gamelog = pd.concat(MIN_2005_gamelog)    
MIN_2005_gamelogs = MIN_2005_gamelog.copy()
MIN_2005_gamelogs['GAME_SCORE'] = MIN_2005_gamelogs['GAME_SCORE'].astype(float)
MIN_2005_games = MIN_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2005_games_csv = MIN_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2005_games.csv', index=False)
MIN_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2005_games.csv')
MIN_2005_games_proc.head()
# Out:
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Sam Cassell"
# 3 results found.
# 0: Sam Cassell
# 1: Sam Cash
# 2: Sam Pellom
# Pick one: 0
# Results for Sam Cassell:
#
# You searched for "Ndudi Ebi"
# 1 result found.
# Ndudi Ebi
# Results for Ndudi Ebi:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Eddie Griffin"
# 3 results found.
# 0: Eddie Griffin
# 1: Adrian Griffin
# 2: Blake Griffin
# Pick one: 0
# Results for Eddie Griffin:
#
# You searched for "Trenton Hassell"
# 1 result found.
# Trenton Hassell
# Results for Trenton Hassell:
#
# You searched for "Fred Hoiberg"
# ...

# %%
MIN_2006_gamelog = []

for p in MIN_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2006_gamelog.append(player_log)
MIN_2006_gamelog = pd.concat(MIN_2006_gamelog)    
MIN_2006_gamelogs = MIN_2006_gamelog.copy()
MIN_2006_gamelogs['GAME_SCORE'] = MIN_2006_gamelogs['GAME_SCORE'].astype(float)
MIN_2006_games = MIN_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2006_games_csv = MIN_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2006_games.csv', index=False)
MIN_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2006_games.csv')
MIN_2006_games_proc.head()
# Out:
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Mark Blount"
# 7 results found.
# 0: Mark Blount
# 1: Mark Bryant
# 2: Corie Blount
# 3: Markel Brown
# 4: Mark Jones
# 5: Mark Jones
# 6: Mark Sibley
# Pick one: 0
# Results for Mark Blount:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Ricky Davis"
# 17 results found.
# 0: Ricky Davis
# 1: Mickey Davis
# 2: Mike Davis
# 3: Mike Davis
# 4: Bill Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Jim Davis
# 8: Mark Davis
# 9: Mark Davis
# 10: Ralph Davis
# 11: Red Davis
# 12: Ron Davis
# 13: Terry Davis
# 14: Ricky Marsh
# ...

# %%
MIN_2007_gamelog = []

for p in MIN_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2007_gamelog.append(player_log)
MIN_2007_gamelog = pd.concat(MIN_2007_gamelog)    
MIN_2007_gamelogs = MIN_2007_gamelog.copy()
MIN_2007_gamelogs['GAME_SCORE'] = MIN_2007_gamelogs['GAME_SCORE'].astype(float)
MIN_2007_games = MIN_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2007_games_csv = MIN_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2007_games.csv', index=False)
MIN_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2007_games.csv')
MIN_2007_games_proc.head()
# Out:
# You searched for "Mark Blount"
# 7 results found.
# 0: Mark Blount
# 1: Mark Bryant
# 2: Corie Blount
# 3: Markel Brown
# 4: Mark Jones
# 5: Mark Jones
# 6: Mark Sibley
# Pick one: 0
# Results for Mark Blount:
#
# You searched for "Ricky Davis"
# 17 results found.
# 0: Ricky Davis
# 1: Mickey Davis
# 2: Mike Davis
# 3: Mike Davis
# 4: Bill Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Jim Davis
# 8: Mark Davis
# 9: Mark Davis
# 10: Ralph Davis
# 11: Red Davis
# 12: Ron Davis
# 13: Terry Davis
# 14: Ricky Marsh
# 15: Ricky Rubio
# 16: Ricky Grace
# Pick one: 0
# Results for Ricky Davis:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# 8: Brandon Roy
# 9: Ray Felix
# Pick one: 0
# Results for Randy Foye:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# ...

# %%
MIN_2008_gamelog = []

for p in MIN_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2008_gamelog.append(player_log)
MIN_2008_gamelog = pd.concat(MIN_2008_gamelog)    
MIN_2008_gamelogs = MIN_2008_gamelog.copy()
MIN_2008_gamelogs['GAME_SCORE'] = MIN_2008_gamelogs['GAME_SCORE'].astype(float)
MIN_2008_games = MIN_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2008_games_csv = MIN_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2008_games.csv', index=False)
MIN_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2008_games.csv')
MIN_2008_games_proc.head()
# Out:
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# 8: Brandon Roy
# 9: Ray Felix
# Pick one: 0
# Results for Randy Foye:
#
# You searched for "Ryan Gomes"
# 4 results found.
# 0: Ryan Gomes
# 1: Ryan Bowen
# 2: Ray Owes
# 3: Ryan Reid
# Pick one: 0
# ...

# %%
MIN_2009_gamelog = []

for p in MIN_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2009_gamelog.append(player_log)
MIN_2009_gamelog = pd.concat(MIN_2009_gamelog)    
MIN_2009_gamelogs = MIN_2009_gamelog.copy()
MIN_2009_gamelogs['GAME_SCORE'] = MIN_2009_gamelogs['GAME_SCORE'].astype(float)
MIN_2009_games = MIN_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2009_games_csv = MIN_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2009_games.csv', index=False)
MIN_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2009_games.csv')
MIN_2009_games_proc.head()
# Out:
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Bobby Brown"
# 14 results found.
# 0: Bobby Brown
# 1: Bob Brown
# 2: Tony Brown
# 3: Bobby Croft
# 4: Bruce Brown
# 5: John Brown
# 6: Larry Brown
# 7: Moses Brown
# 8: Randy Brown
# 9: Roger Brown
# 10: Roger Brown
# 11: Troy Brown
# 12: Bobby Cook
# 13: Bobby Lloyd
# Pick one: 0
# Results for Bobby Brown:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "Jason Collins"
# 11 results found.
# ...

# %%
# removed sasha pavlovic

MIN_2010_gamelog = []

for p in MIN_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2010_gamelog.append(player_log)
MIN_2010_gamelog = pd.concat(MIN_2010_gamelog)    
MIN_2010_gamelogs = MIN_2010_gamelog.copy()
MIN_2010_gamelogs['GAME_SCORE'] = MIN_2010_gamelogs['GAME_SCORE'].astype(float)
MIN_2010_games = MIN_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2010_games_csv = MIN_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2010_games.csv', index=False)
MIN_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2010_games.csv')
MIN_2010_games_proc.head()
# Out:
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Jonny Flynn"
# 4 results found.
# 0: Jonny Flynn
# 1: Danny Finn
# 2: Lonnie Lynn
# 3: Johnny Egan
# Pick one: 0
# Results for Jonny Flynn:
#
# You searched for "Ryan Gomes"
# 4 results found.
# 0: Ryan Gomes
# 1: Ryan Bowen
# 2: Ray Owes
# 3: Ryan Reid
# Pick one: 0
# Results for Ryan Gomes:
#
# You searched for "Jason Hart"
# 9 results found.
# 0: Jason Hart
# 1: Josh Hart
# 2: Jaxson Hayes
# 3: Jason Kidd
# 4: Jason Smith
# 5: Jason Terry
# 6: Jon Barry
# 7: Jay Carty
# 8: Jason Sasser
# Pick one: 0
# Results for Jason Hart:
#
# ...

# %%
MIN_2011_gamelog = []

for p in MIN_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2011_gamelog.append(player_log)
MIN_2011_gamelog = pd.concat(MIN_2011_gamelog)    
MIN_2011_gamelogs = MIN_2011_gamelog.copy()
MIN_2011_gamelogs['GAME_SCORE'] = MIN_2011_gamelogs['GAME_SCORE'].astype(float)
MIN_2011_games = MIN_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2011_games_csv = MIN_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2011_games.csv', index=False)
MIN_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2011_games.csv')
MIN_2011_games_proc.head()
# Out:
# You searched for "Maurice Ager"
# 8 results found.
# 0: Maurice Ager
# 1: Maurice Baker
# 2: Maurice Carter
# 3: Maurice King
# 4: Maurice Ndour
# 5: Maurice Taylor
# 6: Maurice Evans
# 7: Maurice Lucas
# Pick one: 0
# Results for Maurice Ager:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Jonny Flynn"
# 4 results found.
# 0: Jonny Flynn
# 1: Danny Finn
# 2: Lonnie Lynn
# 3: Johnny Egan
# Pick one: 0
# Results for Jonny Flynn:
#
# You searched for "Sundiata Gaines"
# 1 result found.
# Sundiata Gaines
# Results for Sundiata Gaines:
#
# ...

# %%
# remvoed j.j. barea

MIN_2012_gamelog = []

for p in MIN_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2012_gamelog.append(player_log)
MIN_2012_gamelog = pd.concat(MIN_2012_gamelog)    
MIN_2012_gamelogs = MIN_2012_gamelog.copy()
MIN_2012_gamelogs['GAME_SCORE'] = MIN_2012_gamelogs['GAME_SCORE'].astype(float)
MIN_2012_games = MIN_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2012_games_csv = MIN_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2012_games.csv', index=False)
MIN_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2012_games.csv')
MIN_2012_games_proc.head()
# Out:
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Wesley Johnson"
# 10 results found.
# 0: Wesley Johnson
# 1: Clay Johnson
# 2: Lee Johnson
# 3: Mickey Johnson
# 4: Neil Johnson
# 5: Stanley Johnson
# 6: Stew Johnson
# 7: Trey Johnson
# 8: Tyler Johnson
# 9: Wesley Person
# Pick one: 0
# Results for Wesley Johnson:
#
# You searched for "Malcolm Lee"
# 2 results found.
# 0: Malcolm Lee
# 1: Malcolm Miller
# Pick one: 0
# Results for Malcolm Lee:
#
# You searched for "Kevin Love"
# 15 results found.
# 0: Kevin Love
# 1: Kevin Loder
# 2: Kevin Jones
# 3: Kevin Joyce
# 4: Kevin Ollie
# 5: Kevin Grevey
# 6: Kevin Hervey
# 7: Kevin Knox
# 8: Kevon Looney
# 9: Stan Love
# 10: Kevin Lynch
# 11: Kevin Porter
# ...

# %%
# removed jj barea
MIN_2013_gamelog = []

for p in MIN_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2013_gamelog.append(player_log)
MIN_2013_gamelog = pd.concat(MIN_2013_gamelog)    
MIN_2013_gamelogs = MIN_2013_gamelog.copy()
MIN_2013_gamelogs['GAME_SCORE'] = MIN_2013_gamelogs['GAME_SCORE'].astype(float)
MIN_2013_games = MIN_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2013_games_csv = MIN_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2013_games.csv', index=False)
MIN_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2013_games.csv')
MIN_2013_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Will Conroy"
# 6 results found.
# 0: Will Conroy
# 1: Will Cherry
# 2: Bill Crow
# 3: Bill Henry
# 4: Will Barton
# 5: Willie Long
# Pick one: 0
# Results for Will Conroy:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# You searched for "Mickaël Gelabale"
# 1 result found.
# Mickael Gelabale
# Results for Mickael Gelabale:
#
# You searched for "Lazar Hayward"
# 1 result found.
# Lazar Hayward
# Results for Lazar Hayward:
#
# You searched for "Josh Howard"
# 8 results found.
# 0: Josh Howard
# 1: Josh Hart
# 2: Mo Howard
# 3: Josh Hall
# 4: Greg Howard
# 5: Juwan Howard
# 6: Otis Howard
# 7: Josh Powell
# ...

# %%
MIN_2014_gamelog = []

for p in MIN_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2014_gamelog.append(player_log)
MIN_2014_gamelog = pd.concat(MIN_2014_gamelog)    
MIN_2014_gamelogs = MIN_2014_gamelog.copy()
MIN_2014_gamelogs['GAME_SCORE'] = MIN_2014_gamelogs['GAME_SCORE'].astype(float)
MIN_2014_games = MIN_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2014_games_csv = MIN_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2014_games.csv', index=False)
MIN_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2014_games.csv')
MIN_2014_games_proc.head()
# Out:
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Robbie Hummel"
# 1 result found.
# Robbie Hummel
# Results for Robbie Hummel:
#
# You searched for "Othyus Jeffers"
# 1 result found.
# Othyus Jeffers
# Results for Othyus Jeffers:
#
# You searched for "Kevin Love"
# 15 results found.
# 0: Kevin Love
# 1: Kevin Loder
# 2: Kevin Jones
# 3: Kevin Joyce
# 4: Kevin Ollie
# 5: Kevin Grevey
# 6: Kevin Hervey
# 7: Kevin Knox
# 8: Kevon Looney
# 9: Stan Love
# 10: Kevin Lynch
# 11: Kevin Porter
# ...

# %%
# removed glenn robinson
# removed mo williams

MIN_2015_gamelog = []

for p in MIN_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2015_gamelog.append(player_log)
MIN_2015_gamelog = pd.concat(MIN_2015_gamelog)    
MIN_2015_gamelogs = MIN_2015_gamelog.copy()
MIN_2015_gamelogs['GAME_SCORE'] = MIN_2015_gamelogs['GAME_SCORE'].astype(float)
MIN_2015_games = MIN_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2015_games_csv = MIN_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2015_games.csv', index=False)
MIN_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2015_games.csv')
MIN_2015_games_proc.head()
# Out:
# You searched for "Jeff Adrien"
# 10 results found.
# 0: Jeff Adrien
# 1: Jeff Ayres
# 2: Jeff Green
# 3: Jeff Martin
# 4: Jeff Turner
# 5: Jeff Grayer
# 6: Jeff Malone
# 7: Jeff Ruland
# 8: Jeff Sanders
# 9: Jeff Taylor
# Pick one: 0
# Results for Jeff Adrien:
#
# You searched for "Anthony Bennett"
# 3 results found.
# 0: Anthony Bennett
# 1: Tony Bennett
# 2: Anthony Bonner
# Pick one: 0
# Results for Anthony Bennett:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Lorenzo Brown"
# 2 results found.
# 0: Lorenzo Brown
# 1: Lorenzo Romar
# Pick one: 0
# Results for Lorenzo Brown:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# 2: Lloyd Daniels
# 3: Mel Daniels
# Pick one: 0
# Results for Troy Daniels:
# ...

# %%
# removed greg smith

MIN_2016_gamelog = []

for p in MIN_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2016_gamelog.append(player_log)
MIN_2016_gamelog = pd.concat(MIN_2016_gamelog)    
MIN_2016_gamelogs = MIN_2016_gamelog.copy()
MIN_2016_gamelogs['GAME_SCORE'] = MIN_2016_gamelogs['GAME_SCORE'].astype(float)
MIN_2016_games = MIN_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2016_games_csv = MIN_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2016_games.csv', index=False)
MIN_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2016_games.csv')
MIN_2016_games_proc.head()
# Out:
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Kevin Garnett"
# 6 results found.
# 0: Kevin Garnett
# 1: Calvin Garrett
# 2: Dean Garrett
# 3: Kevin Kunnert
# 4: Kevin Grevey
# 5: Kevin Martin
# Pick one: 0
# Results for Kevin Garnett:
#
# You searched for "Tyus Jones"
# 17 results found.
# 0: Tyus Jones
# 1: Tre Jones
# 2: Tyus Edney
# 3: Bill Jones
# 4: Earl Jones
# 5: Fred Jones
# 6: Jake Jones
# 7: James Jones
# 8: K.C. Jones
# 9: Mark Jones
# 10: Mark Jones
# 11: Nick Jones
# 12: Rich Jones
# 13: Sam Jones
# 14: Steve Jones
# 15: Wali Jones
# 16: Wil Jones
# Pick one: 0
# Results for Tyus Jones:
#
# You searched for "Zach LaVine"
# 3 results found.
# 0: Zach LaVine
# 1: Mack Calvin
# 2: Zach Lofton
# Pick one: 0
# Results for Zach LaVine:
#
# You searched for "Kevin Martin"
# 15 results found.
# ...

# %%
MIN_2017_gamelog = []

for p in MIN_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2017_gamelog.append(player_log)
MIN_2017_gamelog = pd.concat(MIN_2017_gamelog)    
MIN_2017_gamelogs = MIN_2017_gamelog.copy()
MIN_2017_gamelogs['GAME_SCORE'] = MIN_2017_gamelogs['GAME_SCORE'].astype(float)
MIN_2017_games = MIN_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2017_games_csv = MIN_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2017_games.csv', index=False)
MIN_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2017_games.csv')
MIN_2017_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Kris Dunn"
# 6 results found.
# 0: Kris Dunn
# 1: Chris Duhon
# 2: Pat Dunn
# 3: T.R. Dunn
# 4: Chris Munk
# 5: Chris Quinn
# Pick one: 0
# Results for Kris Dunn:
#
# You searched for "Jordan Hill"
# 8 results found.
# 0: Jordan Hill
# 1: Jordan Bell
# 2: Jordan Ford
# 3: Jordan Bone
# 4: Grant Hill
# 5: Jordan Loyd
# 6: Jordan Poole
# 7: John Mills
# Pick one: 0
# Results for Jordan Hill:
#
# You searched for "Tyus Jones"
# 17 results found.
# 0: Tyus Jones
# 1: Tre Jones
# 2: Tyus Edney
# 3: Bill Jones
# 4: Earl Jones
# 5: Fred Jones
# 6: Jake Jones
# 7: James Jones
# ...

# %%
MIN_2018_gamelog = []

for p in MIN_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2018_gamelog.append(player_log)
MIN_2018_gamelog = pd.concat(MIN_2018_gamelog)    
MIN_2018_gamelogs = MIN_2018_gamelog.copy()
MIN_2018_gamelogs['GAME_SCORE'] = MIN_2018_gamelogs['GAME_SCORE'].astype(float)
MIN_2018_games = MIN_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2018_games_csv = MIN_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2018_games.csv', index=False)
MIN_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2018_games.csv')
MIN_2018_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Anthony Brown"
# 8 results found.
# 0: Anthony Brown
# 1: Anthony Bowie
# 2: Tony Brown
# 3: Anthony Bonner
# 4: Troy Brown
# 5: Anthony Cook
# 6: Anthony Mason
# 7: Anthony Morrow
# Pick one: 0
# Results for Anthony Brown:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# ...

# %%
MIN_2019_gamelog = []

for p in MIN_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2019_gamelog.append(player_log)
MIN_2019_gamelog = pd.concat(MIN_2019_gamelog)    
MIN_2019_gamelogs = MIN_2019_gamelog.copy()
MIN_2019_gamelogs['GAME_SCORE'] = MIN_2019_gamelogs['GAME_SCORE'].astype(float)
MIN_2019_games = MIN_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2019_games_csv = MIN_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2019_games.csv', index=False)
MIN_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2019_games.csv')
MIN_2019_games_proc.head()
# Out:
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Mitch Creek"
# 3 results found.
# 0: Mitch Creek
# 1: Rich Peek
# 2: Mitch McGary
# Pick one: 0
# Results for Mitch Creek:
#
# You searched for "Luol Deng"
# 1 result found.
# Luol Deng
# Results for Luol Deng:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Taj Gibson"
# ...

# %%
MIN_2020_gamelog = []

for p in MIN_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2020_gamelog.append(player_log)
MIN_2020_gamelog = pd.concat(MIN_2020_gamelog)    
MIN_2020_gamelogs = MIN_2020_gamelog.copy()
MIN_2020_gamelogs['GAME_SCORE'] = MIN_2020_gamelogs['GAME_SCORE'].astype(float)
MIN_2020_games = MIN_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2020_games_csv = MIN_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2020_games.csv', index=False)
MIN_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2020_games.csv')
MIN_2020_games_proc.head()
# Out:
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Jarrett Culver"
# 2 results found.
# 0: Jarrett Culver
# 1: Jarrett Allen
# Pick one: 0
# Results for Jarrett Culver:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# ...

# %%
# removed Elijah Bryant
MIN_2021_gamelog = []

for p in MIN_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    MIN_2021_gamelog.append(player_log)
MIN_2021_gamelog = pd.concat(MIN_2021_gamelog)    
MIN_2021_gamelogs = MIN_2021_gamelog.copy()
MIN_2021_gamelogs['GAME_SCORE'] = MIN_2021_gamelogs['GAME_SCORE'].astype(float)
MIN_2021_games = MIN_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_2021_games_csv = MIN_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2021_games.csv', index=False)
MIN_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2021_games.csv')
MIN_2021_games_proc.head()
# Out:
# You searched for "Malik Beasley"
# 3 results found.
# 0: Malik Beasley
# 1: Malik Sealy
# 2: Malik Allen
# Pick one: 0
# Results for Malik Beasley:
#
# You searched for "Jarrett Culver"
# 2 results found.
# 0: Jarrett Culver
# 1: Jarrett Allen
# Pick one: 0
# Results for Jarrett Culver:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# 23: Tyler Davis
# 24: Walt Davis
# 25: Ed Earle
# 26: Ed Gayda
# 27: Ed Melvin
# 28: Ed Beach
# 29: Ed Leede
# 30: Ed Mikan
# 31: Ed Nealy
# 32: Med Park
# 33: Todd Day
# Pick one: 0
# Results for Ed Davis:
#
# You searched for "Anthony Edwards"
# 3 results found.
# 0: Anthony Edwards
# ...

# %% [markdown]
# ## combine all seasons

# %%
MIN_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2000_games.csv')
MIN_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2001_games.csv')
MIN_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2002_games.csv')
MIN_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2003_games.csv')
MIN_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2004_games.csv')
MIN_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2005_games.csv')
MIN_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2006_games.csv')
MIN_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2007_games.csv')
MIN_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2008_games.csv')
MIN_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2009_games.csv')
MIN_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2010_games.csv')
MIN_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2011_games.csv')
MIN_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2012_games.csv')
MIN_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2013_games.csv')
MIN_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2014_games.csv')
MIN_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2015_games.csv')
MIN_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2016_games.csv')
MIN_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2017_games.csv')
MIN_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2018_games.csv')
MIN_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2019_games.csv')
MIN_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2020_games.csv')
MIN_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2021_games.csv')

# %%
MIN_season_dfs = [MIN_2000_games_io, MIN_2001_games_io, MIN_2002_games_io, MIN_2003_games_io, MIN_2004_games_io, MIN_2005_games_io,
                 MIN_2006_games_io, MIN_2007_games_io, MIN_2008_games_io, MIN_2009_games_io, MIN_2010_games_io, MIN_2011_games_io,
                 MIN_2012_games_io, MIN_2013_games_io, MIN_2014_games_io, MIN_2015_games_io, MIN_2016_games_io, MIN_2017_games_io,
                 MIN_2018_games_io, MIN_2019_games_io, MIN_2020_games_io, MIN_2021_games_io]

# %%
MIN_all = pd.concat(MIN_season_dfs)
MIN_all_sorted = MIN_all.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2018-03-28  22-133  MIN      HOME      ATL  W (+12)   1  41:21  19   32
# 0  2016-11-30  21-015  MIN      HOME      NYK   L (-2)   1  41:32  15   22
# 0  2005-01-04  28-230  MIN      HOME      PHO   L (-7)   1  41:11  19   28
# 0  2019-10-25  23-344  MIN      AWAY      CHO  W (+22)   1  27:43  13   18
# 0  2013-12-22  25-106  MIN      AWAY      LAC   L (-4)   1  43:23  15   23
# 0  2003-02-16  26-273  MIN      HOME      GSW   W (+7)   1  41:12  17   27
# 0  2013-12-22  25-106  MIN      AWAY      LAC   L (-4)   1  43:23  15   23
# 0  2008-01-27  23-023  MIN      HOME      NJN   W (+3)   1  42:07  13   21
# 1  2014-04-11  28-037  MIN      HOME      HOU   W (+2)   1  44:53  19   30
# 0  2012-03-23  23-198  MIN      AWAY      OKC   L (-9)   1  49:19  16   27
# 1  2004-12-10  28-205  MIN      HOME      SAC   W (+8)   1  43:53  11   22
# ...
