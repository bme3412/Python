# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 20)

# %%
df_1980_raw = pd.read_csv('1980Players_Advanced.csv')
df_1980_raw.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', ' ',
#        'OWS', 'DWS', 'WS', 'WS/48', ' .1', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
df_1980 = df_1980_raw[['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 
       'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']] 
df_1980.head()
# Out:
#                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  \
# 0  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3  0.639  0.001  0.344
# 1         Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003  0.258
# 2           Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002  0.270
# 3       Tiny Archibald*  PG   31  BOS  80  2864  15.3  0.574  0.023  0.548
# 4         Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000  0.833
#
#    ...  TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...  15.7  24.1  9.5  5.3  14.8  0.227   4.8   2.4  7.2   7.3
# 1  ...   9.9  13.3  1.2  0.8   2.0  0.080  -1.0  -0.2 -1.2   0.2
# 2  ...  18.2  21.9  3.1  3.9   7.0  0.155   1.7   1.9  3.6   3.1
# 3  ...  19.7  17.0  5.9  2.9   8.9  0.148   1.4  -0.3  1.1   2.3
# 4  ...  24.8   7.9  0.1  0.5   0.6  0.053  -2.3   0.9 -1.4   0.1
#
# [5 rows x 26 columns]

# %%
file_list = ['1980Players_Advanced.csv',

'1981Players_Advanced.csv',
'1982Players_Advanced.csv',
'1983Players_Advanced.csv',
'1984Players_Advanced.csv',
'1985Players_Advanced.csv',
'1986Players_Advanced.csv',
'1987Players_Advanced.csv',
'1988Players_Advanced.csv',
'1989Players_Advanced.csv',
'1990Players_Advanced.csv',
'1991Players_Advanced.csv',
'1992Players_Advanced.csv',
'1993Players_Advanced.csv',
'1994Players_Advanced.csv',
'1995Players_Advanced.csv',
'1996Players_Advanced.csv',
'1997Players_Advanced.csv',
'1998Players_Advanced.csv',
'1999Players_Advanced.csv',
'2000Players_Advanced.csv',
'2001Players_Advanced.csv',
'2002Players_Advanced.csv',
'2003Players_Advanced.csv',
'2004Players_Advanced.csv',
'2005Players_Advanced.csv',
'2006Players_Advanced.csv',
'2007Players_Advanced.csv',
'2008Players_Advanced.csv',
'2009Players_Advanced.csv',
'2010Players_Advanced.csv',
'2011Players_Advanced.csv',
'2012Players_Advanced.csv',
'2013Players_Advanced.csv',
'2014Players_Advanced.csv',
'2015Players_Advanced.csv',
'2016Players_Advanced.csv',
'2017Players_Advanced.csv',
'2018Players_Advanced.csv',
'2019Players_Advanced.csv',
'2020Players_Advanced.csv']

# %%
file_list

dataframe_list = [pd.read_csv(file_name) for file_name in file_list]
dataframe_list[0] # 1980
type(dataframe_list[20])
#type(dataframe_list)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe_list[10].columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', ' ',
#        'OWS', 'DWS', 'WS', 'WS/48', ' .1', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
dataframe_list[0] = dataframe_list[0][['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
       'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']]
dataframe_list[0].columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
df_list = [dataframe_list[i][['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
       'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']] for i in range(0,40)]
df_list[0].columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
df_list[39].head()
# Out:
#          Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  TOV%  \
# 0  Álex Abrines  SG   25  OKC  31   588   6.3  0.507  0.809  0.083  ...   7.9
# 1    Quincy Acy  PF   28  PHO  10   123   2.9  0.379  0.833  0.556  ...  15.2
# 2  Jaylen Adams  PG   22  ATL  34   428   7.6  0.474  0.673  0.082  ...  19.7
# 3  Steven Adams   C   25  OKC  80  2669  18.5  0.591  0.002  0.361  ...  12.6
# 4   Bam Adebayo   C   21  MIA  82  1913  17.9  0.623  0.031  0.465  ...  17.1
#
#    USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  12.2  0.1  0.6  0.6  0.053  -3.7   0.4 -3.3  -0.2
# 1   9.2 -0.1  0.0 -0.1 -0.022  -7.6  -0.5 -8.1  -0.2
# 2  13.5 -0.1  0.2  0.1  0.011  -3.8  -0.5 -4.3  -0.2
# 3  16.4  5.1  4.0  9.1  0.163   0.7   0.4  1.1   2.1
# 4  15.8  3.4  3.4  6.8  0.171  -0.4   2.2  1.8   1.8
#
# [5 rows x 26 columns]

# %%
type(df_list[0:10])
# Out:
# list

# %%
df_1981 = df_list[0]
df_1981['Season'] = 1981

df_1982 = df_list[1]
df_1982['Season'] = 1982


df_1983 = df_list[2]
df_1983['Season'] = 1983

df_1984 = df_list[3]
df_1984['Season'] = 1984

df_1985 = df_list[4]
df_1985['Season'] = 1985

df_1986 = df_list[5]
df_1986['Season'] = 1986

df_1987 = df_list[6]
df_1987['Season'] = 1987

df_1988 = df_list[7]
df_1988['Season'] = 1988

df_1989 = df_list[8]
df_1989['Season'] = 1989

df_1990 = df_list[9]
df_1990['Season'] = 1990

df_1991 = df_list[10]
df_1991['Season'] = 1991

df_1992 = df_list[11]
df_1992['Season'] = 1992

df_1993 = df_list[12]
df_1993['Season'] = 1993

df_1994 = df_list[13]
df_1994['Season'] = 1994

df_1995 = df_list[14]
df_1995['Season'] = 1995

df_1996 = df_list[15]
df_1996['Season'] = 1996

df_1997 = df_list[16]
df_1997['Season'] = 1997

df_1998 = df_list[17]
df_1998['Season'] = 1998

df_1999 = df_list[18]
df_1999['Season'] = 1999

df_2000 = df_list[19]
df_2000['Season'] = 2000

df_2001 = df_list[20]
df_2001['Season'] = 2001

df_2002 = df_list[21]
df_2002['Season'] = 2002

df_2003 = df_list[22]
df_2003['Season'] = 2003

df_2004 = df_list[23]
df_2004['Season'] = 2004

df_2005 = df_list[24]
df_2005['Season'] = 2005

df_2006 = df_list[25]
df_2006['Season'] = 2006

df_2007 = df_list[26]
df_2007['Season'] = 2007

df_2008 = df_list[27]
df_2008['Season'] = 2008

df_2009 = df_list[28]
df_2009['Season'] = 2009

df_2010 = df_list[29]
df_2010['Season'] = 2010

df_2011 = df_list[30]
df_2011['Season'] = 2011

df_2012 = df_list[31]
df_2012['Season'] = 2012

df_2013 = df_list[32]
df_2013['Season'] = 2013

df_2014 = df_list[33]
df_2014['Season'] = 2014

df_2015 = df_list[34]
df_2015['Season'] = 2015

df_2016 = df_list[35]
df_2016['Season'] = 2016

df_2017 = df_list[36]
df_2017['Season'] = 2017

df_2018 = df_list[37]
df_2018['Season'] = 2018

df_2019 = df_list[38]
df_2019['Season'] = 2019

df_2020 = df_list[39]
df_2020['Season'] = 2020

df_list = [
    df_1981,
    df_1982,
df_1983,
df_1984,
df_1985,
df_1986,
df_1987,
df_1988,
df_1989,
df_1990,
df_1991,
df_1992,
df_1993,
df_1994,
df_1995,
df_1996,
df_1997,
df_1998,
df_1999,
df_2000,
df_2001,
df_2002,
df_2003,
df_2004,
df_2005,
df_2006,
df_2007,
df_2008,
df_2009,
df_2010,
df_2011,
df_2012,
df_2013,
df_2014,
df_2015,
df_2016,
df_2017,
df_2018,
df_2019,
df_2020
]
# Out:
# <ipython-input-31-5082d65e03cf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1982['Season'] = 1982
# <ipython-input-31-5082d65e03cf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1983['Season'] = 1983
# <ipython-input-31-5082d65e03cf>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
master_df = pd.concat(df_list)
master_df[master_df['G']>55].sort_values(by=['WS/48'],ascending=False).head()
# Out:
#               Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  \
# 254     LeBron James  PF   28  MIA  76  2877  31.6  0.640  0.188  0.395  ...
# 205  Michael Jordan*  SG   27  CHI  82  3034  31.6  0.605  0.051  0.365  ...
# 272     LeBron James  SF   24  CLE  81  3054  31.7  0.591  0.238  0.472  ...
# 116    Stephen Curry  PG   27  GSW  79  2700  31.5  0.669  0.554  0.250  ...
# 235  Michael Jordan*  SG   32  CHI  82  3090  29.4  0.582  0.141  0.355  ...
#
#      USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP  Season
# 254  30.2  14.6  4.7  19.3  0.322   9.3   2.4  11.7   9.9    2014
# 205  32.9  14.9  5.4  20.3  0.321   8.9   3.2  12.0  10.8    1992
# 272  33.8  13.7  6.5  20.3  0.318   9.5   3.7  13.2  11.8    2010
# 116  32.6  13.8  4.1  17.9  0.318  10.3   1.6  11.9   9.5    2017
# 235  33.3  14.2  6.2  20.4  0.317   8.3   2.2  10.5   9.8    1997
#
# [5 rows x 27 columns]

# %%
df_1998.sort_values(by=['WS/48'],ascending=False).head()
# Out:
#                 Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  \
# 34       Elmer Bennett  PG   26  HOU   4    16  32.1  0.579  0.500  1.000
# 44         Bruce Bowen  SF   25  MIA   1     1  37.7    NaN    NaN    NaN
# 279  Larry Krystkowiak  PF   32  LAL   3    11  27.2  0.521  0.000  1.000
# 256    Michael Jordan*  SG   33  CHI  82  3106  27.8  0.567  0.157  0.304
# 208     Darrin Hancock  SF   25  SAS   1     8  18.3  0.694  0.000  1.000
#
#      ...  USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP  Season
# 34   ...  24.6   0.1  0.0   0.1  0.436   5.8   6.0  11.8   0.1    1998
# 44   ...   0.0   0.0  0.0   0.0  0.321  36.8  60.7  97.4   0.0    1998
# 279  ...  15.8   0.0  0.0   0.1  0.315   1.4   8.8  10.2   0.0    1998
# 256  ...  33.2  13.3  5.0  18.3  0.283   7.8   1.1   8.9   8.6    1998
# 208  ...  16.7   0.1  0.0   0.0  0.274  -2.2  -1.5  -3.7   0.0    1998
#
# [5 rows x 27 columns]

# %%
michael_jordan_df = master_df[master_df['Player']=='Michael Jordan*']
lebron_james_df = master_df[master_df['Player']=='LeBron James']
kobe_bryant_df = master_df[master_df['Player']=='Kobe Bryant*']

larry_bird_df = master_df[master_df['Player']=='Larry Bird*']
magic_johnson_df = master_df[master_df['Player']=='Magic Johnson*']
kevin_durant_df = master_df[master_df['Player']=='Kevin Durant']
steph_curry_df = master_df[master_df['Player']=='Stephen Curry']

# %%
kobe_bryant_df.head()
# Out:
#           Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  \
# 61  Kobe Bryant*  SF   18  LAL  71  1103  14.4  0.544  0.322  0.393  ...
# 65  Kobe Bryant*  SF   19  LAL  79  2056  18.5  0.548  0.241  0.501  ...
# 59  Kobe Bryant*  SG   20  LAL  50  1896  18.9  0.549  0.130  0.375  ...
# 67  Kobe Bryant*  SG   21  LAL  66  2524  21.7  0.546  0.122  0.341  ...
# 61  Kobe Bryant*  SG   22  LAL  68  2783  24.5  0.552  0.132  0.369  ...
#
#     USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP  Season
# 61  24.7  0.5  1.3   1.8  0.079  -0.2   0.1 -0.1   0.5    1998
# 65  27.2  4.5  1.8   6.3  0.147   2.2  -0.8  1.4   1.8    1999
# 59  25.3  3.7  1.5   5.2  0.130   2.1  -0.1  2.1   1.9    2000
# 67  26.8  6.1  4.5  10.6  0.202   3.5   1.6  5.1   4.5    2001
# 61  31.8  9.2  2.2  11.3  0.196   5.1  -0.3  4.8   4.7    2002
#
# [5 rows x 27 columns]

# %%
kevin_durant_df.head()
# Out:
#            Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  \
# 151  Kevin Durant  SG   19  SEA  80  2768  15.8  0.519  0.150  0.328  ...
# 167  Kevin Durant  SF   20  OKC  74  2885  20.8  0.577  0.165  0.377  ...
# 149  Kevin Durant  SF   21  OKC  82  3239  26.2  0.607  0.210  0.504  ...
# 183  Kevin Durant  SF   22  OKC  78  3038  23.6  0.589  0.269  0.439  ...
# 137  Kevin Durant  SF   23  OKC  66  2546  26.2  0.610  0.265  0.386  ...
#
#      USG%   OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP  Season
# 151  28.1   0.4  1.9   2.3  0.040   0.5  -0.7 -0.1   1.3    2009
# 167  28.3   5.2  2.7   7.9  0.132   3.4  -0.1  3.3   3.8    2010
# 149  32.0  11.1  5.0  16.1  0.238   6.3   0.8  7.1   7.5    2011
# 183  30.6   8.6  3.3  12.0  0.189   5.2  -0.3  4.9   5.3    2012
# 137  31.3   8.5  3.7  12.2  0.230   6.2   0.8  7.0   5.8    2013
#
# [5 rows x 27 columns]

# %%
steph_curry_df.head()
# Out:
#             Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  \
# 120  Stephen Curry  PG   21  GSW  80  2896  16.3  0.568  0.332  0.175  ...
# 153  Stephen Curry  PG   22  GSW  74  2489  19.4  0.595  0.325  0.216  ...
# 109  Stephen Curry  PG   23  GSW  26   732  21.2  0.605  0.409  0.159  ...
# 119  Stephen Curry  PG   24  GSW  78  2983  21.3  0.589  0.432  0.210  ...
# 149  Stephen Curry  PG   25  GSW  78  2846  24.1  0.610  0.445  0.252  ...
#
#      USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP  Season
# 120  21.8  3.0  1.6   4.7  0.077   1.1  -0.5  0.7   2.0    2011
# 153  24.4  5.4  1.3   6.6  0.128   3.0  -0.7  2.3   2.7    2012
# 109  24.0  1.8  0.4   2.2  0.144   4.1   0.3  4.3   1.2    2013
# 119  26.4  8.4  2.8  11.2  0.180   5.3   0.1  5.4   5.6    2014
# 149  28.3  9.3  4.0  13.4  0.225   6.3   1.1  7.4   6.7    2015
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
ax = michael_jordan_df.plot(x='Age', y='PER', figsize=(20, 18))
lebron_james_df.plot(ax=ax, x='Age', y='PER')
kobe_bryant_df.plot(ax=ax, x='Age', y='PER')
kevin_durant_df.plot(ax=ax, x='Age', y='PER')
larry_bird_df.plot(ax=ax, x='Age', y='PER')
magic_johnson_df.plot(ax=ax, x='Age', y='PER')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
import import_ipynb

# %%
from NBA_since_2000 import master_df

# %%
game_logs = master_df()
game_logs.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2001-11-23  24-347  ATL      HOME      DET   W (+7)   1  45:12  21   30
# 0  2020-01-26  21-129  ATL      HOME      WAS  W (+19)   1  38:59  13   24
# 0  2006-03-19  24-263  ATL      HOME      ORL   W (+1)   1  47:33  17   24
# 0  2019-03-01  20-163  ATL      HOME      CHI   L (-7)   1  55:50  17   33
# 0  2004-03-12  25-342  ATL      HOME      WAS  W (+14)   1  45:26  14   24
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-               Player
# 0  ...   12    5    2    1    2   1   50        46.0   12  Shareef Abdur-Rahim
# 0  ...    6   14    1    0    5   2   45        39.4   22           Trae Young
# 0  ...    3   11    0    0    0   3   40        37.8    7          Joe Johnson
# 0  ...    8   16    1    1    9   2   49        37.8   -9           Trae Young
# 0  ...    2    7    2    1    2   0   42        37.4   17      Stephen Jackson
#
# [5 rows x 29 columns]

# %%
type(game_logs)
# Out:
# pandas.core.frame.DataFrame

# %%
lebron_james_games = game_logs[game_logs['Player']=='LeBron James']
lebron_james_games.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2008-01-15  23-016  CLE      AWAY      MEM   W (+8)   1  47:10  18   28
# 0  2009-12-30  25-000  CLE      HOME      ATL   W (+5)   1  43:12  15   23
# 1  2008-03-05  23-066  CLE      AWAY      NYK  W (+14)   1  43:50  16   30
# 0  2006-04-01  21-092  CLE      HOME      MIA   W (+7)   1  45:29  16   25
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...   11    7    3    2    3   2   57        53.2    6  LeBron James
# 0  ...    8    9    3    1    4   1   51        45.0   10  LeBron James
# 0  ...   10    6    2    2    3   3   48        44.7    7  LeBron James
# 1  ...    8   10    4    0    2   3   50        44.0   11  LeBron James
# 0  ...   12    9    2    0    4   3   47        43.8   13  LeBron James
#
# [5 rows x 29 columns]

# %%
lebron_james_games[['Years', 'Days']] = lebron_james_games['AGE'].str.split('-',expand=True)
# Out:
# /Users/brendan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
lebron_james_games['Years'] = lebron_james_games['Years'].astype(str).astype(int)
lebron_james_games['Days'] = lebron_james_games['Days'].astype(str).astype(int)
lebron_james_games['Age'] = lebron_james_games['Years'] + (lebron_james_games['Days']/365)
# Out:
# <ipython-input-142-f1258cbf4737>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lebron_james_games['Years'] = lebron_james_games['Years'].astype(str).astype(int)
# <ipython-input-142-f1258cbf4737>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lebron_james_games['Days'] = lebron_james_games['Days'].astype(str).astype(int)
# <ipython-input-142-f1258cbf4737>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
lebron_james_games.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2008-01-15  23-016  CLE      AWAY      MEM   W (+8)   1  47:10  18   28
# 0  2009-12-30  25-000  CLE      HOME      ATL   W (+5)   1  43:12  15   23
# 1  2008-03-05  23-066  CLE      AWAY      NYK  W (+14)   1  43:50  16   30
# 0  2006-04-01  21-092  CLE      HOME      MIA   W (+7)   1  45:29  16   25
#
#    ...  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player  Years  Days  \
# 0  ...    2    3   2   57        53.2    6  LeBron James     32   308
# 0  ...    1    4   1   51        45.0   10  LeBron James     23    16
# 0  ...    2    3   3   48        44.7    7  LeBron James     25     0
# 1  ...    0    2   3   50        44.0   11  LeBron James     23    66
# 0  ...    0    4   3   47        43.8   13  LeBron James     21    92
#
#          Age
# 0  32.843836
# 0  23.043836
# 0  25.000000
# 1  23.180822
# 0  21.252055
#
# ...

# %%
lebron_james_games.plot.scatter(x='Age', y='GAME_SCORE', figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='GAME_SCORE'>
