# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonplayerinfo
import pandas as pd

# %%
# get_players retruns a list of dictionaries
# each dictionary is a player
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:5]
# Out:
# Number of players fetched: 4501
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False}]

# %%
# get player list and ID
df_players = pd.DataFrame.from_dict(nba_players)
df_players.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False

# %%
player_list = df_players['full_name'].to_list()
player_id = df_players['id'].to_list()
type(player_list)
len(player_list)
# Out:
# 4501

# %%
player_master_list = []
def get_nba_id():
    nba_players = players.get_active_players()
    
    for player in nba_players:
        career_stats = playercareerstats.PlayerCareerStats(player_id=player['id'])
        career_df = career_stats.get_data_frames()[0]
        career_df['NAME'] = player['full_name']
get_nba_id()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
# ...

# %%
player_master_list
# Out:
# []

# %%
nba_teams = teams.get_teams()
df_teams = pd.DataFrame.from_dict(nba_teams)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
nba_players = players.get_active_players()
nba_players_active_df = pd.DataFrame.from_dict(nba_players)
nba_players_active_df.head(25)
# Out:
#          id                 full_name first_name         last_name  is_active
# 0    203500              Steven Adams     Steven             Adams       True
# 1   1628389               Bam Adebayo        Bam           Adebayo       True
# 2    200746         LaMarcus Aldridge   LaMarcus          Aldridge       True
# 3   1629734            Kyle Alexander       Kyle         Alexander       True
# 4   1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker       True
# 5   1628960             Grayson Allen    Grayson             Allen       True
# 6   1628386             Jarrett Allen    Jarrett             Allen       True
# 7   1628443              Kadeem Allen     Kadeem             Allen       True
# 8    202329           Al-Farouq Aminu  Al-Farouq             Aminu       True
# 9   1626147           Justin Anderson     Justin          Anderson       True
# 10   203937             Kyle Anderson       Kyle          Anderson       True
# ...

# %%
from nba_api.stats.endpoints import commonplayerinfo

# Basic Request
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)
player_info

# %%
from nba_api.stats.endpoints import commonplayerinfo

# Basic Request
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)
player_info.available_seasons.get_data_frame()

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/basketball_reference_scraper/teams.py in <module>
#       5 try:
# ----> 6     from constants import TEAM_TO_TEAM_ABBR, TEAM_SETS
#       7     from utils import remove_accents
#
# ModuleNotFoundError: No module named 'constants'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c6c2d6f687e5> in <module>
# ----> 1 from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/basketball_reference_scraper/teams.py in <module>
#       8 except:
#       9     from basketball_reference_scraper.constants import TEAM_TO_TEAM_ABBR, TEAM_SETS
# ...

# %%
df = get_roster('GSW', 2019)
print(df)
# Out:
#     NUMBER             PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0        2        Jordan Bell   C    6-8     216 1995-01-07          US
# 1       12       Andrew Bogut   C    7-0     260 1984-11-28          AU
# 2        4         Quinn Cook  PG    6-1     180 1993-03-23          US
# 3        0   DeMarcus Cousins   C   6-10     270 1990-08-13          US
# 4       30      Stephen Curry  PG    6-3     185 1988-03-14          US
# 5       32  Marcus Derrickson  PF    6-7     249 1996-02-01          US
# 6       35       Kevin Durant  SF   6-10     240 1988-09-29          US
# 7       10        Jacob Evans  SG    6-4     210 1997-06-18          US
# 8       23     Draymond Green  PF    6-6     230 1990-03-04          US
# 9        9     Andre Iguodala  SF    6-6     215 1984-01-28          US
# 10      21      Jonas Jerebko  PF   6-10     231 1987-03-02          SE
# 11      15       Damian Jones   C   6-11     245 1995-06-30          US
# ...

# %%
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot

# %%
s = get_stats('Stephen Curry', stat_type='PER_GAME', playoffs=False, career=False)
s
# Out:
# You searched for "Stephen Curry"
# 3 results found.
# 0: Stephen Curry
# 1: Stephen Chubin
# 2: Seth Curry
# Pick one: 0
# Results for Stephen Curry:
#      SEASON   AGE TEAM LEAGUE POS   G  GS    MP    FG   FGA  ...    FT%  ORB  \
# 0   2009-10  21.0  GSW    NBA  PG  80  77  36.2   6.6  14.3  ...  0.885  0.6
# 1   2010-11  22.0  GSW    NBA  PG  74  74  33.6   6.8  14.2  ...  0.934  0.7
# 2   2011-12  23.0  GSW    NBA  PG  26  23  28.2   5.6  11.4  ...  0.809  0.6
# 3   2012-13  24.0  GSW    NBA  PG  78  78  38.2   8.0  17.8  ...  0.900  0.8
# 4   2013-14  25.0  GSW    NBA  PG  78  78  36.5   8.4  17.7  ...  0.885  0.6
# 5   2014-15  26.0  GSW    NBA  PG  80  80  32.7   8.2  16.8  ...  0.914  0.7
# 6   2015-16  27.0  GSW    NBA  PG  79  79  34.2  10.2  20.2  ...  0.908  0.9
# 7   2016-17  28.0  GSW    NBA  PG  79  79  33.4   8.5  18.3  ...  0.898  0.8
# 8   2017-18  29.0  GSW    NBA  PG  51  51  32.0   8.4  16.9  ...  0.921  0.7
# ...

# %%
df = get_game_logs('LeBron James', '2010-01-19', '2014-01-20', playoffs=False)
df
# Out:
# You searched for "LeBron James"
# 5 results found.
# 0: LeBron James
# 1: Aaron James
# 2: Damion James
# 3: Henry James
# 4: Jerome James
# Pick one: 0
# Results for LeBron James:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  FG FGA  ...  \
# 44 2010-01-19  25-020  CLE      HOME      TOR   W (+8)  1  41:01   8  18  ...
# 45 2010-01-21  25-022  CLE      HOME      LAL   W (+6)  1  40:24  13  25  ...
# 46 2010-01-23  25-024  CLE      HOME      OKC   W (+1)  1  42:38   9  19  ...
# 47 2010-01-25  25-026  CLE      AWAY      MIA   W (+1)  1  38:31   9  23  ...
# 48 2010-01-27  25-028  CLE      HOME      MIN  W (+14)  1  30:33   3   8  ...
# ..        ...     ...  ...       ...      ...      ... ..    ...  ..  ..  ...
# 37 2014-01-10  29-011  MIA      AWAY      BRK   L (-9)  1  49:22  12  21  ...
# 38 2014-01-15  29-016  MIA      AWAY      WAS  L (-17)  1  41:04   8  18  ...
# 39 2014-01-17  29-018  MIA      AWAY      PHI  W (+15)  1  36:31   7  13  ...
# ...

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
df_bos=get_roster('BOS', 2022)
df_bos
# Out:
#     NUMBER            PLAYER  POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0      NaN         Kris Dunn    G    6-3     205 1994-03-18          US
# 1      NaN    Grant Williams    F    6-6     236 1998-11-30          US
# 2      NaN   Josh Richardson    G    6-5     200 1993-09-15          US
# 3      NaN     Jabari Parker    F    6-8     245 1995-03-15          US
# 4      NaN    Carsen Edwards    G   5-11     200 1998-03-12          US
# 5      NaN      Jaylen Brown  F-G    6-6     223 1996-10-24          US
# 6      NaN   Dennis Schröder    G    6-3     172 1993-09-15          DE
# 7      NaN        Al Horford  C-F    6-9     240 1986-06-03          DO
# 8      NaN   Robert Williams  C-F    6-8     237 1997-10-17          US
# 9      NaN       Enes Kanter    C   6-10     250 1992-05-20          CH
# 10     NaN  Payton Pritchard    G    6-1     195 1998-01-28          US
# 11     NaN      Marcus Smart    G    6-3     220 1994-03-06          US
# ...

# %%
from basketball_reference_scraper.players import get_game_logs, get_player_headshot

df = get_game_logs('Pau Gasol', '2010-01-12', '2010-01-20', playoffs=False)
print(df)

url = get_player_headshot('Kobe Bryant')
print(url)
# Out:
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# 5: Paul Long
# 6: Paul Silas
# Pick one: 0
# Results for Pau Gasol:
#
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP FG FGA  ...  \
# 40 2010-01-15  29-193  LAL      HOME      LAC  W (+40)  1  30:29  4  10  ...
# 42 2010-01-18  29-196  LAL      HOME      ORL   W (+6)  1  39:32  8  14  ...
#
#    DRB TRB AST STL BLK TOV PF PTS GAME_SCORE  +/-
# 40   2   6   3   0   3   1  0  20       21.2  +22
# 42   7  10   2   1   0   1  4  17       14.4   +7
#
# [2 rows x 28 columns]
# You searched for "Kobe Bryant"
# 4 results found.
# 0: Kobe Bryant
# 1: Joe Bryant
# 2: Em Bryant
# 3: Mark Bryant
# Pick one: 0
# Results for Kobe Bryant:
#
# https://d2cwpp38twqe55.cloudfront.net/req/202006192/images/players/bryanko01.jpg

# %% [markdown]
# ## Get all team codes

# %%
"""Team List:
ATLANTA HAWKS : ATL
ST. LOUIS HAWKS : SLH
MILWAUKEE HAWKS : MIL
TRI-CITIES BLACKHAWKS : TCB
BOSTON CELTICS : BOS
BROOKLYN NETS : BRK
NEW JERSEY NETS : NJN
CHICAGO BULLS : CHI
CHARLOTTE HORNETS (1988-2004): CHH
CHARLOTTE HORNETS (2014-Present): CHO
CHARLOTTE BOBCATS : CHA
CLEVELAND CAVALIERS : CLE
DALLAS MAVERICKS : DAL
DENVER NUGGETS : DEN
DETROIT PISTONS : DET
FORT WAYNE PISTONS : FWP
GOLDEN STATE WARRIORS : GSW
SAN FRANCISCO WARRIORS : SFW
PHILADELPHIA WARRIORS : PHI
HOUSTON ROCKETS : HOU
INDIANA PACERS : IND
LOS ANGELES CLIPPERS : LAC
SAN DIEGO CLIPPERS : SDC
BUFFALO BRAVES : BUF
LOS ANGELES LAKERS : LAL
MINNEAPOLIS LAKERS : MIN
MEMPHIS GRIZZLIES : MEM
VANCOUVER GRIZZLIES : VAN
MIAMI HEAT : MIA
MILWAUKEE BUCKS : MIL
MINNESOTA TIMBERWOLVES : MIN
NEW ORLEANS PELICANS : NOP
NEW ORLEANS/OKLAHOMA CITY HORNETS : NOK
NEW ORLEANS HORNETS : NOH
NEW YORK KNICKS : NYK
OKLAHOMA CITY THUNDER : OKC
SEATTLE SUPERSONICS : SEA
ORLANDO MAGIC : ORL
PHILADELPHIA 76ERS : PHI
SYRACUSE NATIONALS : SYR
PHOENIX SUNS : PHO
PORTLAND TRAIL BLAZERS : POR
SACRAMENTO KINGS : SAC
KANSAS CITY KINGS : KCK
KANSAS CITY-OMAHA KINGS : KCK
CINCINNATI ROYALS : CIN
ROCHESTER ROYALS : ROR
SAN ANTONIO SPURS : SAS
TORONTO RAPTORS : TOR
UTAH JAZZ : UTA
NEW ORLEANS JAZZ : NOJ
WASHINGTON WIZARDS : WAS
WASHINGTON BULLETS : WAS
CAPITAL BULLETS : CAP
BALTIMORE BULLETS : BAL
CHICAGO ZEPHYRS : CHI
CHICAGO PACKERS : CHI
ANDERSON PACKERS : AND
CHICAGO STAGS : CHI
INDIANAPOLIS OLYMPIANS : IND
SHEBOYGAN RED SKINS : SRS
ST. LOUIS BOMBERS : SLB
WASHINGTON CAPITOLS : WAS
WATERLOO HAWKS : WAT
SAN DIEGO ROCKETS : SDR
"""

# %%
df_ATL = get_roster('ATL', 2021)
df_BOS = get_roster('BOS', 2021)
df_BRK = get_roster('BRK', 2021)
df_CHI = get_roster('CHI', 2021)
df_CHA = get_roster('CHO', 2021)
df_CLE = get_roster('CLE', 2021)
df_DAL = get_roster('DAL', 2021)
df_DEN = get_roster('DEN', 2021)
df_DET = get_roster('DET', 2021)
df_GSW = get_roster('GSW', 2021)
df_PHI = get_roster('PHI', 2021)
df_HOU = get_roster('HOU', 2021)
df_IND = get_roster('IND', 2021)
df_LAC = get_roster('LAC', 2021)
df_LAL = get_roster('LAL', 2021)
df_MEM = get_roster('MEM', 2021)
df_MIA = get_roster('MIA', 2021)
df_MIL = get_roster('MIL', 2021)
df_MIN = get_roster('MIN', 2021)
df_NOP = get_roster('NOP', 2021)
df_NYK = get_roster('NYK', 2021)
df_OKC = get_roster('OKC', 2021)
df_ORL = get_roster('ORL', 2021)
df_PHO = get_roster('PHO', 2021)
df_POR = get_roster('POR', 2021)
df_SAC = get_roster('SAC', 2021)
df_SAS = get_roster('SAS', 2021)
df_TOR = get_roster('TOR', 2021)
df_UTA = get_roster('UTA', 2021)
df_WAS = get_roster('WAS', 2021)

# %%
df_DAL.head()
# Out:
#    NUMBER               PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       2            Tyler Bey  SF    6-7     215 1998-02-10          US
# 1      13        Jalen Brunson  PG    6-1     190 1996-08-31          US
# 2       3           Trey Burke  PG    6-0     185 1992-11-12          US
# 3      33  Willie Cauley-Stein   C    7-0     240 1993-08-18          US
# 4      77          Luka Dončić  PG    6-7     230 1999-02-28          SI
#
#   EXPERIENCE    COLLEGE
# 0          R   Colorado
# 1          2  Villanova
# 2          7   Michigan
# 3          5   Kentucky
# 4          2        NaN

# %%
list_of_teams = [df_ATL, df_BOS, df_BRK, df_CHI, df_CHA, df_CLE, df_DAL,
                 df_DEN, df_DET, df_GSW, df_PHI, df_HOU, df_IND, df_LAC, df_LAL,
                 df_MEM, df_MIA, df_MIL, df_MIN, df_NOP, df_NYK, df_OKC,
                 df_ORL, df_PHO, df_POR, df_SAC, df_SAS, df_TOR, df_UTA, df_WAS]

# %%
type(list_of_teams)
# Out:
# list

# %%
import pandas as pd
df_raw = pd.concat(list_of_teams)
df_raw.tail()
# Out:
#    NUMBER             PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 16     12    Jerome Robinson  SG    6-4     190 1997-02-22          US
# 17     14          Ish Smith  PG    6-0     175 1988-07-05          US
# 18     21      Moritz Wagner   C   6-11     245 1997-04-26          DE
# 19      4  Russell Westbrook  PG    6-3     200 1988-11-12          US
# 20      5    Cassius Winston  PG    6-1     185 1998-02-28          US
#
#    EXPERIENCE         COLLEGE
# 16          2  Boston College
# 17         10     Wake Forest
# 18          2        Michigan
# 19         12            UCLA
# 20          R  Michigan State

# %%
bron = get_stats('Lebron James', stat_type='PER_GAME', career=False)
bron
# Out:
# You searched for "Lebron James"
# 5 results found.
# 0: LeBron James
# 1: Aaron James
# 2: Damion James
# 3: Henry James
# 4: Jerome James
# Pick one: 0
# Results for LeBron James:
#      SEASON   AGE TEAM LEAGUE POS     G    GS    MP    FG   FGA  ...    FT%  \
# 0   2003-04  19.0  CLE    NBA  SG  79.0  79.0  39.5   7.9  18.9  ...  0.754
# 1   2004-05  20.0  CLE    NBA  SF  80.0  80.0  42.4   9.9  21.1  ...  0.750
# 2   2005-06  21.0  CLE    NBA  SF  79.0  79.0  42.5  11.1  23.1  ...  0.738
# 3   2006-07  22.0  CLE    NBA  SF  78.0  78.0  40.9   9.9  20.8  ...  0.698
# 4   2007-08  23.0  CLE    NBA  SF  75.0  74.0  40.4  10.6  21.9  ...  0.712
# 5   2008-09  24.0  CLE    NBA  SF  81.0  81.0  37.7   9.7  19.9  ...  0.780
# 6   2009-10  25.0  CLE    NBA  SF  76.0  76.0  39.0  10.1  20.1  ...  0.767
# 7   2010-11  26.0  MIA    NBA  SF  79.0  79.0  38.8   9.6  18.8  ...  0.759
# 8   2011-12  27.0  MIA    NBA  SF  62.0  62.0  37.5  10.0  18.9  ...  0.771
# ...

# %%
df_bron = df_raw[df_raw['PLAYER'] =='LeBron James']
df_bron
# Out:
#    NUMBER        PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY EXPERIENCE  \
# 11     23  LeBron James  PG    6-9     250 1984-12-30          US         17
#
#    COLLEGE
# 11     NaN

# %%
pierce = get_stats('Paul Pierce', stat_type='PER_GAME', career=False)
pierce
# Out:
# You searched for "Paul Pierce"
# 5 results found.
# 0: Paul Pierce
# 1: Paul George
# 2: Paul Pressey
# 3: Paul Reed
# 4: Paul Zipser
# Pick one: 0
# Results for Paul Pierce:
#      SEASON   AGE TEAM LEAGUE POS     G    GS    MP   FG   FGA  ...    FT%  \
# 0   1998-99  21.0  BOS    NBA  SF  48.0  47.0  34.0  5.9  13.5  ...  0.713
# 1   1999-00  22.0  BOS    NBA  SF  73.0  72.0  35.4  6.7  15.1  ...  0.798
# 2   2000-01  23.0  BOS    NBA  SF  82.0  82.0  38.0  8.4  18.5  ...  0.745
# 3   2001-02  24.0  BOS    NBA  SG  82.0  82.0  40.3  8.6  19.5  ...  0.809
# 4   2002-03  25.0  BOS    NBA  SG  79.0  79.0  39.2  8.4  20.2  ...  0.802
# 5   2003-04  26.0  BOS    NBA  SG  80.0  80.0  38.7  7.5  18.7  ...  0.819
# 6   2004-05  27.0  BOS    NBA  SF  82.0  82.0  36.1  6.8  14.9  ...  0.822
# 7   2005-06  28.0  BOS    NBA  SF  79.0  79.0  39.0  8.7  18.5  ...  0.772
# 8   2006-07  29.0  BOS    NBA  SG  47.0  46.0  37.0  7.9  18.1  ...  0.796
# ...

# %%
pierce
# Out:
#      SEASON   AGE TEAM LEAGUE POS     G    GS    MP   FG   FGA  ...    FT%  \
# 0   1998-99  21.0  BOS    NBA  SF  48.0  47.0  34.0  5.9  13.5  ...  0.713
# 1   1999-00  22.0  BOS    NBA  SF  73.0  72.0  35.4  6.7  15.1  ...  0.798
# 2   2000-01  23.0  BOS    NBA  SF  82.0  82.0  38.0  8.4  18.5  ...  0.745
# 3   2001-02  24.0  BOS    NBA  SG  82.0  82.0  40.3  8.6  19.5  ...  0.809
# 4   2002-03  25.0  BOS    NBA  SG  79.0  79.0  39.2  8.4  20.2  ...  0.802
# 5   2003-04  26.0  BOS    NBA  SG  80.0  80.0  38.7  7.5  18.7  ...  0.819
# 6   2004-05  27.0  BOS    NBA  SF  82.0  82.0  36.1  6.8  14.9  ...  0.822
# 7   2005-06  28.0  BOS    NBA  SF  79.0  79.0  39.0  8.7  18.5  ...  0.772
# 8   2006-07  29.0  BOS    NBA  SG  47.0  46.0  37.0  7.9  18.1  ...  0.796
# 9   2007-08  30.0  BOS    NBA  SF  80.0  80.0  35.9  6.4  13.7  ...  0.843
# 10  2008-09  31.0  BOS    NBA  SF  81.0  81.0  37.5  6.7  14.6  ...  0.830
# ...
