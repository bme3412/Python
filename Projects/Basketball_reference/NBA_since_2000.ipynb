# %%
# prview
import pandas as pd

# %% [markdown]
# ## ATL

# %%
ATL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2000_games.csv')
ATL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2001_games.csv')
ATL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2002_games.csv')
ATL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2003_games.csv')
ATL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2004_games.csv')
ATL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2005_games.csv')
ATL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2006_games.csv')
ATL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2007_games.csv')
ATL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2008_games.csv')
ATL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2009_games.csv')
ATL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2010_games.csv')
ATL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2011_games.csv')
ATL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2012_games.csv')
ATL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2013_games.csv')
ATL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2014_games.csv')
ATL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2015_games.csv')
ATL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2016_games.csv')
ATL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2017_games.csv')
ATL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2018_games.csv')
ATL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2019_games.csv')
ATL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2020_games.csv')
ATL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ATL/ATL_2021_games.csv')

# %%
ATL_season_dfs = [ATL_2000_games_io, ATL_2001_games_io, ATL_2002_games_io, ATL_2003_games_io, ATL_2004_games_io, ATL_2005_games_io,
                 ATL_2006_games_io, ATL_2007_games_io, ATL_2008_games_io, ATL_2009_games_io, ATL_2010_games_io, ATL_2011_games_io,
                 ATL_2012_games_io, ATL_2013_games_io, ATL_2014_games_io, ATL_2015_games_io, ATL_2016_games_io, ATL_2017_games_io,
                 ATL_2018_games_io, ATL_2019_games_io, ATL_2020_games_io, ATL_2021_games_io]

# %%
ATL_since_2000 = pd.concat(ATL_season_dfs)
ATL_since_2000 = ATL_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
ATL_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2001-11-23  24-347  ATL      HOME      DET   W (+7)   1  45:12  21   30
# 0  2020-01-26  21-129  ATL      HOME      WAS  W (+19)   1  38:59  13   24
# 0  2006-03-19  24-263  ATL      HOME      ORL   W (+1)   1  47:33  17   24
# 0  2019-03-01  20-163  ATL      HOME      CHI   L (-7)   1  55:50  17   33
# 0  2004-03-12  25-342  ATL      HOME      WAS  W (+14)   1  45:26  14   24
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-               Player
# 0  ...   12    5    2    1    2   1   50        46.0   12  Shareef Abdur-Rahim
# 0  ...    6   14    1    0    5   2   45        39.4   22           Trae Young
# 0  ...    3   11    0    0    0   3   40        37.8    7          Joe Johnson
# 0  ...    8   16    1    1    9   2   49        37.8   -9           Trae Young
# 0  ...    2    7    2    1    2   0   42        37.4   17      Stephen Jackson
#
# [5 rows x 29 columns]

# %% [markdown]
# ## BOS

# %%
BOS_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2000_games.csv')
BOS_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2001_games.csv')
BOS_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2002_games.csv')
BOS_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2003_games.csv')
BOS_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2004_games.csv')
BOS_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2005_games.csv')
BOS_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2006_games.csv')
BOS_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2007_games.csv')
BOS_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2008_games.csv')
BOS_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2009_games.csv')
BOS_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2010_games.csv')
BOS_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2011_games.csv')
BOS_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2012_games.csv')
BOS_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2013_games.csv')
BOS_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2014_games.csv')
BOS_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2015_games.csv')
BOS_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2016_games.csv')
BOS_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2017_games.csv')
BOS_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2018_games.csv')
BOS_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2019_games.csv')
BOS_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2020_games.csv')
BOS_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BOS/BOS_2021_games.csv')

# %%
BOS_season_dfs = [BOS_2000_games_io, BOS_2001_games_io, BOS_2002_games_io, BOS_2003_games_io, BOS_2004_games_io, BOS_2005_games_io,
                 BOS_2006_games_io, BOS_2007_games_io, BOS_2008_games_io, BOS_2009_games_io, BOS_2010_games_io, BOS_2011_games_io,
                 BOS_2012_games_io, BOS_2013_games_io, BOS_2014_games_io, BOS_2015_games_io, BOS_2016_games_io, BOS_2017_games_io,
                 BOS_2018_games_io, BOS_2019_games_io, BOS_2020_games_io, BOS_2021_games_io]

# %%
BOS_since_2000 = pd.concat(BOS_season_dfs)
BOS_since_2000 = BOS_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
BOS_since_2000.head(55)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-04-30  23-058  BOS      HOME      SAS   W (+3)   1  45:20  20   37
# 0  2016-12-20  27-317  BOS      AWAY      MEM   W (+3)   1  38:17  10   16
# 1  2021-04-09  23-037  BOS      HOME      MIN   W (+9)   1  41:00  16   25
# 0  2012-12-19  35-067  BOS      HOME      CLE  W (+12)   1  33:36  13   16
# 0  2001-01-17  24-158  BOS      AWAY      SAC   L (-5)   1  45:10  16   29
# 0  2017-11-20  25-242  BOS      AWAY      DAL   W (+8)   1  38:46  16   22
# 0  2020-01-11  21-314  BOS      HOME      NOP  W (+35)   1  30:23  16   22
# 0  2018-11-16  26-238  BOS      HOME      TOR   W (+7)   1  38:33  18   26
# 1  2016-12-30  27-327  BOS      HOME      MIA   W (+3)   1  37:09  15   26
# 1  2013-03-18  26-202  BOS      HOME      MIA   L (-2)   1  40:07  14   21
# 0  2002-11-02  25-020  BOS      AWAY      NYK  W (+10)   1  40:00  12   22
# ...

# %% [markdown]
# ## BRK

# %%
BRK_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2013_games.csv')
BRK_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2014_games.csv')
BRK_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2015_games.csv')
BRK_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2016_games.csv')
BRK_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2017_games.csv')
BRK_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2018_games.csv')
BRK_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2019_games.csv')
BRK_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2020_games.csv')
BRK_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/BRK/BRK_2021_games.csv')

# %%
BRK_season_dfs = [BRK_2013_games_io, BRK_2014_games_io, BRK_2015_games_io, BRK_2016_games_io, BRK_2017_games_io,
                 BRK_2018_games_io, BRK_2019_games_io, BRK_2020_games_io, BRK_2021_games_io]

# %%
BRK_since_2000 = pd.concat(BRK_season_dfs)
BRK_since_2000 = BRK_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
BRK_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-01-31  27-314  BRK      HOME      CHI  W (+15)   1  31:53  19   23
# 0  2020-12-26  31-122  HOU      AWAY      POR   L (-2)   1  43:16  12   21
# 1  2020-03-03  25-191  BRK      AWAY      BOS   W (+9)   1  35:49  17   26
# 2  2019-10-23  27-214  BRK      HOME      MIN   L (-1)   1  38:10  17   33
# 0  2018-04-09  26-000  BRK      HOME      CHI   W (+9)   1  33:42  12   15
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...    5    5    1    0    4   3   54        45.9   20  Kyrie Irving
# 0  ...    4   17    1    0    5   1   44        42.4   -6  James Harden
# 1  ...    4    5    1    0    3   1   51        40.7   15  Caris LeVert
# 2  ...    8    7    0    1    0   4   50        40.5   18  Kyrie Irving
# 0  ...    5    4    1    1    1   2   41        39.5   14  Allen Crabbe
#
# [5 rows x 29 columns]

# %% [markdown]
# ## CHI

# %%
CHI_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2000_games.csv')
CHI_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2001_games.csv')
CHI_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2002_games.csv')
CHI_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2003_games.csv')
CHI_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2004_games.csv')
CHI_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2005_games.csv')
CHI_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2006_games.csv')
CHI_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2007_games.csv')
CHI_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2008_games.csv')
CHI_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2009_games.csv')
CHI_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2010_games.csv')
CHI_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2011_games.csv')
CHI_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2012_games.csv')
CHI_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2013_games.csv')
CHI_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2014_games.csv')
CHI_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2015_games.csv')
CHI_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2016_games.csv')
CHI_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2017_games.csv')
CHI_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2018_games.csv')
CHI_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2019_games.csv')
CHI_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2020_games.csv')
CHI_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CHI/CHI_2021_games.csv')

# %%
CHI_season_dfs = [CHI_2000_games_io, CHI_2001_games_io, CHI_2002_games_io, CHI_2003_games_io, CHI_2004_games_io, CHI_2005_games_io,
                 CHI_2006_games_io, CHI_2007_games_io, CHI_2008_games_io, CHI_2009_games_io, CHI_2010_games_io, CHI_2011_games_io,
                 CHI_2012_games_io, CHI_2013_games_io, CHI_2014_games_io, CHI_2015_games_io, CHI_2016_games_io, CHI_2017_games_io,
                 CHI_2018_games_io, CHI_2019_games_io, CHI_2020_games_io, CHI_2021_games_io]

# %%
CHI_since_2000 = pd.concat(CHI_season_dfs)
CHI_since_2000 = CHI_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
CHI_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-01-02  27-110  CHI      HOME      CHO   W (+7)   1  38:19  15   24
# 0  2000-04-13  21-033  CHI      HOME      WAS   L (-6)   1  42:46  16   21
# 0  2016-01-14  26-122  CHI      AWAY      PHI   W (+4)   1  49:03  15   30
# 0  2021-02-12  30-111  ORL      AWAY      SAC  W (+11)   1  34:09  17   22
# 0  2015-01-10  34-188  CHI      HOME      MIL   W (+8)   1  38:35  17   30
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 0  ...   12    6    3    1    2   0   52        51.5   15    Jimmy Butler
# 0  ...   12    2    0    3    1   2   44        42.6  -11     Elton Brand
# 0  ...   10    6    3    0    4   4   53        42.6   11    Jimmy Butler
# 0  ...    9    4    2    0    1   1   42        39.5    9  Nikola Vučević
# 0  ...   18    3    1    0    3   3   46        38.9    5       Pau Gasol
#
# [5 rows x 29 columns]

# %% [markdown]
# ## CHO

# %% [markdown]
# ## CLE

# %%
CLE_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2000_games.csv')
CLE_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2001_games.csv')
CLE_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2002_games.csv')
CLE_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2003_games.csv')
CLE_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2004_games.csv')
CLE_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2005_games.csv')
CLE_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2006_games.csv')
CLE_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2007_games.csv')
CLE_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2008_games.csv')
CLE_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2009_games.csv')
CLE_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2010_games.csv')
CLE_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2011_games.csv')
CLE_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2012_games.csv')
CLE_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2013_games.csv')
CLE_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2014_games.csv')
CLE_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2015_games.csv')
CLE_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2016_games.csv')
CLE_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2017_games.csv')
CLE_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2018_games.csv')
CLE_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2019_games.csv')
CLE_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2020_games.csv')
CLE_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/CLE/CLE_2021_games.csv')

# %%
CLE_season_dfs = [CLE_2000_games_io, CLE_2001_games_io, CLE_2002_games_io, CLE_2003_games_io, CLE_2004_games_io, CLE_2005_games_io,
                 CLE_2006_games_io, CLE_2007_games_io, CLE_2008_games_io, CLE_2009_games_io, CLE_2010_games_io, CLE_2011_games_io,
                 CLE_2012_games_io, CLE_2013_games_io, CLE_2014_games_io, CLE_2015_games_io, CLE_2016_games_io, CLE_2017_games_io,
                 CLE_2018_games_io, CLE_2019_games_io, CLE_2020_games_io, CLE_2021_games_io]

# %%
CLE_since_2000 = pd.concat(CLE_season_dfs)
CLE_since_2000 = CLE_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
CLE_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2015-03-12  22-354  CLE      AWAY      SAS   W (+3)   1  46:34  20   32
# 0  2008-01-15  23-016  CLE      AWAY      MEM   W (+8)   1  47:10  18   28
# 0  2009-12-30  25-000  CLE      HOME      ATL   W (+5)   1  43:12  15   23
# 1  2008-03-05  23-066  CLE      AWAY      NYK  W (+14)   1  43:50  16   30
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...   11    7    3    2    3   2   57        53.2    6  LeBron James
# 0  ...    3    5    4    0    2   3   57        48.2    5  Kyrie Irving
# 0  ...    8    9    3    1    4   1   51        45.0   10  LeBron James
# 0  ...   10    6    2    2    3   3   48        44.7    7  LeBron James
# 1  ...    8   10    4    0    2   3   50        44.0   11  LeBron James
#
# [5 rows x 29 columns]

# %% [markdown]
# ## DAL

# %%
DAL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2000_games.csv')
DAL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2001_games.csv')
DAL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2002_games.csv')
DAL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2003_games.csv')
DAL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2004_games.csv')
DAL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2005_games.csv')
DAL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2006_games.csv')
DAL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2007_games.csv')
DAL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2008_games.csv')
DAL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2009_games.csv')
DAL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2010_games.csv')
DAL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2011_games.csv')
DAL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2012_games.csv')
DAL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2013_games.csv')
DAL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2014_games.csv')
DAL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2015_games.csv')
DAL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2016_games.csv')
DAL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2017_games.csv')
DAL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2018_games.csv')
DAL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2019_games.csv')
DAL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2020_games.csv')
DAL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DAL/DAL_2021_games.csv')

# %%
DAL_season_dfs = [DAL_2000_games_io, DAL_2001_games_io, DAL_2002_games_io, DAL_2003_games_io, DAL_2004_games_io, DAL_2005_games_io,
                 DAL_2006_games_io, DAL_2007_games_io, DAL_2008_games_io, DAL_2009_games_io, DAL_2010_games_io, DAL_2011_games_io,
                 DAL_2012_games_io, DAL_2013_games_io, DAL_2014_games_io, DAL_2015_games_io, DAL_2016_games_io, DAL_2017_games_io,
                 DAL_2018_games_io, DAL_2019_games_io, DAL_2020_games_io, DAL_2021_games_io]

# %%
DAL_since_2000 = pd.concat(DAL_season_dfs)
DAL_since_2000 = DAL_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
DAL_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2004-12-02  26-166  DAL      HOME      HOU   W (+7)   1  49:36  15   32
# 0  2006-03-23  27-277  DAL      HOME      GSW   L (-1)   1  40:50  16   24
# 0  2007-12-08  27-224  DAL      HOME      UTA   W (+8)   1  42:26  14   19
# 0  2007-02-07  28-233  DAL      HOME      MEM  W (+16)   1  37:33  14   20
# 0  2009-11-03  31-137  DAL      HOME      UTA  W (+11)   1  39:06  12   22
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...   16    2    3    4    1   2   53        48.0   12  Dirk Nowitzki
# 0  ...    9    5    2    1    5   3   51        44.1    3  Dirk Nowitzki
# 0  ...   10    2    0    1    1   4   47        43.4   19    Josh Howard
# 0  ...   10    6    3    4    0   3   38        42.6   14  Dirk Nowitzki
# 0  ...   11    5    2    5    0   2   40        41.3   23  Dirk Nowitzki
#
# [5 rows x 29 columns]

# %% [markdown]
# ## DEN

# %%
DEN_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2000_games.csv')
DEN_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2001_games.csv')
DEN_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2002_games.csv')
DEN_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2003_games.csv')
DEN_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2004_games.csv')
DEN_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2005_games.csv')
DEN_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2006_games.csv')
DEN_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2007_games.csv')
DEN_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2008_games.csv')
DEN_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2009_games.csv')
DEN_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2010_games.csv')
DEN_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2011_games.csv')
DEN_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2012_games.csv')
DEN_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2013_games.csv')
DEN_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2014_games.csv')
DEN_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2015_games.csv')
DEN_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2016_games.csv')
DEN_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2017_games.csv')
DEN_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2018_games.csv')
DEN_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2019_games.csv')
DEN_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2020_games.csv')
DEN_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DEN/DEN_2021_games.csv')

# %%
DEN_season_dfs = [DEN_2000_games_io, DEN_2001_games_io, DEN_2002_games_io, DEN_2003_games_io, DEN_2004_games_io, DEN_2005_games_io,
                 DEN_2006_games_io, DEN_2007_games_io, DEN_2008_games_io, DEN_2009_games_io, DEN_2010_games_io, DEN_2011_games_io,
                 DEN_2012_games_io, DEN_2013_games_io, DEN_2014_games_io, DEN_2015_games_io, DEN_2016_games_io, DEN_2017_games_io,
                 DEN_2018_games_io, DEN_2019_games_io, DEN_2020_games_io, DEN_2021_games_io]

# %%
DEN_since_2000 = pd.concat(DEN_season_dfs)
DEN_since_2000 = DEN_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
DEN_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-06  25-353  DEN      AWAY      SAC   L (-5)   1  41:24  20   33
# 0  2018-10-20  23-243  DEN      HOME      PHO  W (+28)   1  30:43  11   11
# 0  2007-03-17  31-283  DEN      HOME      PHO  W (+24)   1  42:38  16   22
# 1  2021-02-19  23-362  DEN      AWAY      CLE  W (+17)   1  38:15  21   25
# 0  2020-01-06  24-321  DEN      AWAY      ATL   W (+8)   1  36:50  16   25
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...    8   12    1    3    1   2   50        47.4    2   Nikola Jokić
# 0  ...   11   11    4    1    0   3   35        45.8   29   Nikola Jokić
# 0  ...    5   15    0    1    1   2   44        45.1   31  Allen Iverson
# 1  ...    6    2    2    0    1   4   50        43.5   24   Jamal Murray
# 0  ...    8    5    2    1    0   3   47        42.9    0   Nikola Jokić
#
# [5 rows x 29 columns]

# %% [markdown]
# ## DET

# %%
DET_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2000_games.csv')
DET_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2001_games.csv')
DET_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2002_games.csv')
DET_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2003_games.csv')
DET_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2004_games.csv')
DET_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2005_games.csv')
DET_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2006_games.csv')
DET_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2007_games.csv')
DET_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2008_games.csv')
DET_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2009_games.csv')
DET_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2010_games.csv')
DET_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2011_games.csv')
DET_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2012_games.csv')
DET_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2013_games.csv')
DET_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2014_games.csv')
DET_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2015_games.csv')
DET_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2016_games.csv')
DET_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2017_games.csv')
DET_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2018_games.csv')
DET_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2019_games.csv')
DET_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2020_games.csv')
DET_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/DET/DET_2021_games.csv')

# %%
DET_season_dfs = [DET_2000_games_io, DET_2001_games_io, DET_2002_games_io, DET_2003_games_io, DET_2004_games_io, DET_2005_games_io,
                 DET_2006_games_io, DET_2007_games_io, DET_2008_games_io, DET_2009_games_io, DET_2010_games_io, DET_2011_games_io,
                 DET_2012_games_io, DET_2013_games_io, DET_2014_games_io, DET_2015_games_io, DET_2016_games_io, DET_2017_games_io,
                 DET_2018_games_io, DET_2019_games_io, DET_2020_games_io, DET_2021_games_io]

# %%
DET_since_2000 = pd.concat(DET_season_dfs)
DET_since_2000 = DET_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
DET_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2001-04-03  26-149  DET      AWAY      CHI  W (+27)   1  41:40  21   36
# 0  2019-04-05  30-020  DET      AWAY      OKC  L (-13)   1  34:35  11   20
# 1  2018-10-23  29-221  DET      HOME      PHI   W (+1)   1  44:02  20   35
# 0  2012-03-21  28-352  DET      AWAY      DEN   L (-1)   1  41:20  13   22
# 0  2000-01-05  27-092  DET      AWAY      ATL  W (+12)   1  42:47  14   23
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-            Player
# 0  ...    4    5    1    0    4   2   57        40.3   34  Jerry Stackhouse
# 0  ...    7    3    2    0    1   0   45        39.8  -11     Blake Griffin
# 1  ...   14    6    0    1    1   4   50        38.8    4     Blake Griffin
# 0  ...    0    8    2    0    2   5   45        38.0   10        Ben Gordon
# 0  ...    3    6    2    1    1   1   42        37.5   20        Grant Hill
#
# [5 rows x 29 columns]

# %% [markdown]
# ## GSW

# %%
GSW_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2000_games.csv')
GSW_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2001_games.csv')
GSW_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2002_games.csv')
GSW_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2003_games.csv')
GSW_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2004_games.csv')
GSW_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2005_games.csv')
GSW_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2006_games.csv')
GSW_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2007_games.csv')
GSW_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2008_games.csv')
GSW_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2009_games.csv')
GSW_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2010_games.csv')
GSW_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2011_games.csv')
GSW_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2012_games.csv')
GSW_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2013_games.csv')
GSW_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2014_games.csv')
GSW_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2015_games.csv')
GSW_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2016_games.csv')
GSW_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2017_games.csv')
GSW_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2018_games.csv')
GSW_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2019_games.csv')
GSW_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2020_games.csv')
GSW_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/GSW/GSW_2021_games.csv')

# %%
GSW_season_dfs = [GSW_2000_games_io, GSW_2001_games_io, GSW_2002_games_io, GSW_2003_games_io, GSW_2004_games_io, GSW_2005_games_io,
                 GSW_2006_games_io, GSW_2007_games_io, GSW_2008_games_io, GSW_2009_games_io, GSW_2010_games_io, GSW_2011_games_io,
                 GSW_2012_games_io, GSW_2013_games_io, GSW_2014_games_io, GSW_2015_games_io, GSW_2016_games_io, GSW_2017_games_io,
                 GSW_2018_games_io, GSW_2019_games_io, GSW_2020_games_io, GSW_2021_games_io]

# %%
GSW_since_2000 = pd.concat(GSW_season_dfs)
GSW_since_2000 = GSW_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
GSW_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2015-10-31  27-231  GSW      AWAY      NOP  W (+14)   1  35:38  17   27
# 0  2021-01-03  32-295  GSW      HOME      POR  W (+15)   1  36:27  18   31
# 0  2016-12-05  26-301  GSW      HOME      IND  W (+36)   1  29:03  21   33
# 0  2013-02-27  24-350  GSW      AWAY      NYK   L (-4)   1  48:00  18   28
# 0  2000-12-06  24-177  GSW      HOME      LAL   W (+3)   1  53:00  21   29
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 0  ...    4    9    4    0    2   3   53        49.2   16   Stephen Curry
# 0  ...    5    4    0    0    5   0   62        46.8   20   Stephen Curry
# 0  ...    2    1    0    0    0   0   60        46.2   37   Klay Thompson
# 0  ...    6    7    3    0    4   3   54        46.1   -4   Stephen Curry
# 0  ...   13    5    2    1    4   2   51        46.0    3  Antawn Jamison
#
# [5 rows x 29 columns]

# %% [markdown]
# ## HOU

# %%
HOU_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2000_games.csv')
HOU_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2001_games.csv')
HOU_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2002_games.csv')
HOU_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2003_games.csv')
HOU_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2004_games.csv')
HOU_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2005_games.csv')
HOU_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2006_games.csv')
HOU_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2007_games.csv')
HOU_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2008_games.csv')
HOU_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2009_games.csv')
HOU_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2010_games.csv')
HOU_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2011_games.csv')
HOU_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2012_games.csv')
HOU_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2013_games.csv')
HOU_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2014_games.csv')
HOU_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2015_games.csv')
HOU_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2016_games.csv')
HOU_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2017_games.csv')
HOU_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2018_games.csv')
HOU_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2019_games.csv')
HOU_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2020_games.csv')
HOU_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/HOU/HOU_2021_games.csv')

# %%
HOU_season_dfs = [HOU_2000_games_io, HOU_2001_games_io, HOU_2002_games_io, HOU_2003_games_io, HOU_2004_games_io, HOU_2005_games_io,
                 HOU_2006_games_io, HOU_2007_games_io, HOU_2008_games_io, HOU_2009_games_io, HOU_2010_games_io, HOU_2011_games_io,
                 HOU_2012_games_io, HOU_2013_games_io, HOU_2014_games_io, HOU_2015_games_io, HOU_2016_games_io, HOU_2017_games_io,
                 HOU_2018_games_io, HOU_2019_games_io, HOU_2020_games_io, HOU_2021_games_io]

# %%
HOU_since_2000 = pd.concat(HOU_season_dfs)
HOU_since_2000 = HOU_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
HOU_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
# 0  2019-02-28  29-186  HOU      HOME      MIA   W (+3)   1  43:52  16   32
# 1  2020-07-31  30-340  HOU      AWAY      DAL   W (+4)   1  43:29  14   20
# 1  2017-11-05  28-071  HOU      HOME      UTA  W (+27)   1  35:15  19   25
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...   10   11    4    1    5   2   60        56.6    7  James Harden
# 0  ...    3    8    3    1    5   3   60        52.4   50  James Harden
# 0  ...    7   10    4    1    4   1   58        52.2   10  James Harden
# 1  ...    9    8    3    3    1   5   49        49.8    8  James Harden
# 1  ...    2   13    2    0    7   3   56        49.2   25  James Harden
#
# [5 rows x 29 columns]

# %% [markdown]
# ## IND

# %%
IND_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2000_games.csv')
IND_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2001_games.csv')
IND_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2002_games.csv')
IND_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2003_games.csv')
IND_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2004_games.csv')
IND_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2005_games.csv')
IND_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2006_games.csv')
IND_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2007_games.csv')
IND_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2008_games.csv')
IND_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2009_games.csv')
IND_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2010_games.csv')
IND_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2011_games.csv')
IND_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2012_games.csv')
IND_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2013_games.csv')
IND_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2014_games.csv')
IND_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2015_games.csv')
IND_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2016_games.csv')
IND_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2017_games.csv')
IND_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2018_games.csv')
IND_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2019_games.csv')
IND_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2020_games.csv')
IND_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/IND/IND_2021_games.csv')

# %%
IND_season_dfs = [IND_2000_games_io, IND_2001_games_io, IND_2002_games_io, IND_2003_games_io, IND_2004_games_io, IND_2005_games_io,
                 IND_2006_games_io, IND_2007_games_io, IND_2008_games_io, IND_2009_games_io, IND_2010_games_io, IND_2011_games_io,
                 IND_2012_games_io, IND_2013_games_io, IND_2014_games_io, IND_2015_games_io, IND_2016_games_io, IND_2017_games_io,
                 IND_2018_games_io, IND_2019_games_io, IND_2020_games_io, IND_2021_games_io]

# %%
IND_since_2000 = pd.concat(IND_season_dfs)
IND_since_2000 = IND_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
IND_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-08-01  26-331  IND      HOME      PHI   W (+6)   1  40:37  20   29
# 0  2021-02-17  24-290  IND      AWAY      MIN   W (+6)   1  45:35  13   21
# 0  2015-12-05  25-217  IND      AWAY      UTA   L (-3)   1  42:05  15   27
# 0  2017-12-10  25-220  IND      HOME      DEN  W (+10)   1  45:03  15   28
# 0  2014-02-07  27-279  IND      HOME      POR   W (+5)   1  38:19  12   19
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-            Player
# 0  ...    4    3    0    2    1   4   53        42.8   18       T.J. Warren
# 0  ...   16   10    3    1    3   4   36        37.8    6  Domantas Sabonis
# 0  ...    8    3    3    0    2   4   48        37.8  -12       Paul George
# 0  ...    7    6    2    1    4   1   47        37.6   12    Victor Oladipo
# 0  ...    9    8    2    1    1   4   37        37.3   11       George Hill
#
# [5 rows x 29 columns]

# %% [markdown]
# ## LAC

# %%
LAC_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2000_games.csv')
LAC_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2001_games.csv')
LAC_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2002_games.csv')
LAC_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2003_games.csv')
LAC_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2004_games.csv')
LAC_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2005_games.csv')
LAC_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2006_games.csv')
LAC_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2007_games.csv')
LAC_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2008_games.csv')
LAC_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2009_games.csv')
LAC_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2010_games.csv')
LAC_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2011_games.csv')
LAC_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2012_games.csv')
LAC_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2013_games.csv')
LAC_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2014_games.csv')
LAC_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2015_games.csv')
LAC_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2016_games.csv')
LAC_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2017_games.csv')
LAC_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2018_games.csv')
LAC_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2019_games.csv')
LAC_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2020_games.csv')
LAC_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAC/LAC_2021_games.csv')

# %%
LAC_season_dfs = [LAC_2000_games_io, LAC_2001_games_io, LAC_2002_games_io, LAC_2003_games_io, LAC_2004_games_io, LAC_2005_games_io,
                 LAC_2006_games_io, LAC_2007_games_io, LAC_2008_games_io, LAC_2009_games_io, LAC_2010_games_io, LAC_2011_games_io,
                 LAC_2012_games_io, LAC_2013_games_io, LAC_2014_games_io, LAC_2015_games_io, LAC_2016_games_io, LAC_2017_games_io,
                 LAC_2018_games_io, LAC_2019_games_io, LAC_2020_games_io, LAC_2021_games_io]

# %%
LAC_since_2000 = pd.concat(LAC_season_dfs)
LAC_since_2000 = LAC_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
LAC_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2015-04-01  29-330  LAC      AWAY      POR   W (+4)   1  39:24  13   21
# 0  2016-02-26  30-296  LAC      AWAY      SAC  W (+10)   1  36:20  13   20
# 0  2013-12-14  28-222  LAC      AWAY      WAS  W (+16)   1  32:49  11   14
# 1  2013-10-31  28-178  LAC      HOME      GSW  W (+11)   1  37:26  12   20
# 0  2011-01-17  21-307  LAC      HOME      IND   W (+7)   1  36:56  19   24
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...    5   17    4    0    1   2   41        47.5    6     Chris Paul
# 0  ...    8   13    2    0    2   1   40        42.7   14     Chris Paul
# 0  ...    3   12    3    0    2   2   38        42.5   24     Chris Paul
# 1  ...    2   15    6    0    6   4   42        42.3   17     Chris Paul
# 0  ...   14    3    0    1    4   3   47        40.0   17  Blake Griffin
#
# [5 rows x 29 columns]

# %% [markdown]
# ## LAL

# %%
LAL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2000_games.csv')
LAL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2001_games.csv')
LAL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2002_games.csv')
LAL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2003_games.csv')
LAL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2004_games.csv')
LAL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2005_games.csv')
LAL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2006_games.csv')
LAL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2007_games.csv')
LAL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2008_games.csv')
LAL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2009_games.csv')
LAL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2010_games.csv')
LAL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2011_games.csv')
LAL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2012_games.csv')
LAL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2013_games.csv')
LAL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2014_games.csv')
LAL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2015_games.csv')
LAL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2016_games.csv')
LAL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2017_games.csv')
LAL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2018_games.csv')
LAL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2019_games.csv')
LAL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2020_games.csv')
LAL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/LAL/LAL_2021_games.csv')

# %%
LAL_season_dfs = [LAL_2000_games_io, LAL_2001_games_io, LAL_2002_games_io, LAL_2003_games_io, LAL_2004_games_io, LAL_2005_games_io,
                 LAL_2006_games_io, LAL_2007_games_io, LAL_2008_games_io, LAL_2009_games_io, LAL_2010_games_io, LAL_2011_games_io,
                 LAL_2012_games_io, LAL_2013_games_io, LAL_2014_games_io, LAL_2015_games_io, LAL_2016_games_io, LAL_2017_games_io,
                 LAL_2018_games_io, LAL_2019_games_io, LAL_2020_games_io, LAL_2021_games_io]

# %%
LAL_since_2000 = pd.concat(LAL_season_dfs)
LAL_since_2000 = LAL_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
LAL_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0  2007-03-16  28-205  LAL      HOME      POR   W (+5)   1  49:58  23   39
# 1  2005-12-20  27-119  LAL      HOME      DAL  W (+22)   1  32:53  18   31
# 0  2019-12-08  26-272  LAL      HOME      MIN  W (+17)   1  39:16  20   29
# 0  2009-02-02  30-163  LAL      AWAY      NYK   W (+9)   1  36:48  19   31
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...    6    2    3    1    3   1   81        63.5   25    Kobe Bryant
# 0  ...    7    3    3    0    2   3   65        50.9    4    Kobe Bryant
# 1  ...    8    0    3    0    2   3   62        49.7   35    Kobe Bryant
# 0  ...    7    6    4    1    1   1   50        48.5   19  Anthony Davis
# 0  ...    0    3    0    1    2   1   61        47.3   19    Kobe Bryant
#
# [5 rows x 29 columns]

# %% [markdown]
# ## MEM

# %%
#MEM_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2000_games.csv')
#MEM_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2001_games.csv')
MEM_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2002_games.csv')
MEM_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2003_games.csv')
MEM_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2004_games.csv')
MEM_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2005_games.csv')
MEM_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2006_games.csv')
MEM_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2007_games.csv')
MEM_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2008_games.csv')
MEM_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2009_games.csv')
MEM_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2010_games.csv')
MEM_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2011_games.csv')
MEM_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2012_games.csv')
MEM_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2013_games.csv')
MEM_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2014_games.csv')
MEM_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2015_games.csv')
MEM_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2016_games.csv')
MEM_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2017_games.csv')
MEM_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2018_games.csv')
MEM_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2019_games.csv')
MEM_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2020_games.csv')
MEM_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MEM/MEM_2021_games.csv')

# %%
MEM_season_dfs = [MEM_2002_games_io, MEM_2003_games_io, MEM_2004_games_io, MEM_2005_games_io,
                 MEM_2006_games_io, MEM_2007_games_io, MEM_2008_games_io, MEM_2009_games_io, MEM_2010_games_io, MEM_2011_games_io,
                 MEM_2012_games_io, MEM_2013_games_io, MEM_2014_games_io, MEM_2015_games_io, MEM_2016_games_io, MEM_2017_games_io,
                 MEM_2018_games_io, MEM_2019_games_io, MEM_2020_games_io, MEM_2021_games_io]

# %%
MEM_since_2000 = pd.concat(MEM_season_dfs)
MEM_since_2000 = MEM_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
MEM_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-12-23  21-135  MEM      HOME      SAS  L (-12)   1  35:10  18   27
# 0  2012-12-04  31-141  MEM      HOME      PHO  W (+10)   1  44:16  15   22
# 0  2017-01-30  29-111  MEM      AWAY      PHO  W (+19)   1  32:48  12   18
# 1  2021-04-23  21-256  MEM      AWAY      POR   W (+2)   1  36:16  11   17
# 0  2008-01-11  27-189  MEM      AWAY      GSW  L (-12)   1  44:43  17   25
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...    2    9    2    1    1   1   44        40.1   10      Ja Morant
# 0  ...   22    0    1    3    3   2   38        37.3   16  Zach Randolph
# 0  ...    6    9    2    0    2   2   38        37.1   29    Mike Conley
# 1  ...    5   13    1    0    0   0   33        36.7    4      Ja Morant
# 0  ...   11    3    1    1    3   2   43        36.0    2      Pau Gasol
#
# [5 rows x 29 columns]

# %% [markdown]
# ## MIA

# %%
MIA_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2000_games.csv')
MIA_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2001_games.csv')
MIA_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2002_games.csv')
MIA_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2003_games.csv')
MIA_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2004_games.csv')
MIA_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2005_games.csv')
MIA_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2006_games.csv')
MIA_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2007_games.csv')
MIA_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2008_games.csv')
MIA_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2009_games.csv')
MIA_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2010_games.csv')
MIA_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2011_games.csv')
MIA_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2012_games.csv')
MIA_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2013_games.csv')
MIA_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2014_games.csv')
MIA_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2015_games.csv')
MIA_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2016_games.csv')
MIA_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2017_games.csv')
MIA_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2018_games.csv')
MIA_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2019_games.csv')
MIA_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2020_games.csv')
MIA_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIA/MIA_2021_games.csv')

# %%
MIA_season_dfs = [MIA_2000_games_io, MIA_2001_games_io, MIA_2002_games_io, MIA_2003_games_io, MIA_2004_games_io, MIA_2005_games_io,
                 MIA_2006_games_io, MIA_2007_games_io, MIA_2008_games_io, MIA_2009_games_io, MIA_2010_games_io, MIA_2011_games_io,
                 MIA_2012_games_io, MIA_2013_games_io, MIA_2014_games_io, MIA_2015_games_io, MIA_2016_games_io, MIA_2017_games_io,
                 MIA_2018_games_io, MIA_2019_games_io, MIA_2020_games_io, MIA_2021_games_io]

# %%
MIA_since_2000 = pd.concat(MIA_season_dfs)
MIA_since_2000 = MIA_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
MIA_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2009-03-09  27-051  MIA      HOME      CHI   W (+3)   1  49:51  15   21
# 0  2014-03-03  29-063  MIA      HOME      CHA  W (+17)   1  41:12  22   33
# 1  2009-02-28  27-042  MIA      HOME      NYK   W (+5)   1  41:18  16   29
# 0  2011-02-03  26-035  MIA      AWAY      ORL   W (+4)   1  42:39  17   25
# 0  2007-12-28  25-345  MIA      HOME      ORL   L (-7)   1  51:35  16   21
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...    6   12    4    3    5   0   48        49.0   20   Dwyane Wade
# 0  ...    7    4    0    0    2   2   61        48.8   16  LeBron James
# 1  ...    8   10    4    4    2   1   46        47.5    8   Dwyane Wade
# 0  ...   11    8    1    1    3   2   51        46.7    2  LeBron James
# 0  ...    7   11    3    3    5   4   48        45.2   -2   Dwyane Wade
#
# [5 rows x 29 columns]

# %% [markdown]
# ## MIL

# %%
MIL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2000_games.csv')
MIL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2001_games.csv')
MIL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2002_games.csv')
MIL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2003_games.csv')
MIL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2004_games.csv')
MIL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2005_games.csv')
MIL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2006_games.csv')
MIL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2007_games.csv')
MIL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2008_games.csv')
MIL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2009_games.csv')
MIL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2010_games.csv')
MIL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2011_games.csv')
MIL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2012_games.csv')
MIL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2013_games.csv')
MIL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2014_games.csv')
MIL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2015_games.csv')
MIL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2016_games.csv')
MIL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2017_games.csv')
MIL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2018_games.csv')
MIL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2019_games.csv')
MIL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2020_games.csv')
MIL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIL/MIL_2021_games.csv')

# %%
MIL_season_dfs = [MIL_2000_games_io, MIL_2001_games_io, MIL_2002_games_io, MIL_2003_games_io, MIL_2004_games_io, MIL_2005_games_io,
                 MIL_2006_games_io, MIL_2007_games_io, MIL_2008_games_io, MIL_2009_games_io, MIL_2010_games_io, MIL_2011_games_io,
                 MIL_2012_games_io, MIL_2013_games_io, MIL_2014_games_io, MIL_2015_games_io, MIL_2016_games_io, MIL_2017_games_io,
                 MIL_2018_games_io, MIL_2019_games_io, MIL_2020_games_io, MIL_2021_games_io]

# %%
MIL_since_2000 = pd.concat(MIL_season_dfs)
MIL_since_2000 = MIL_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
MIL_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2019-03-17  24-101  MIL      HOME      PHI   L (-5)   1  36:12  15   26
# 0  2019-11-25  24-354  MIL      HOME      UTA   W (+4)   1  38:30  17   31
# 1  2020-01-28  28-169  MIL      HOME      WAS  W (+20)   1  35:52  16   26
# 1  2019-04-04  24-119  MIL      AWAY      PHI   W (+6)   1  34:58  13   22
# 0  2018-01-26  23-051  MIL      HOME      BRK  W (+25)   1  32:54  14   20
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-  \
# 0  ...   16    7    2    1    1   1   52        50.4   12
# 0  ...   14    6    2    0    0   1   50        45.1   14
# 1  ...   10    6    0    0    2   2   51        44.0   24
# 1  ...   13    6    0    5    0   2   45        43.6    9
# 0  ...   13    7    2    2    1   2   41        43.4   19
#
#                   Player
# 0  Giannis Antetokounmpo
# 0  Giannis Antetokounmpo
# 1        Khris Middleton
# 1  Giannis Antetokounmpo
# 0  Giannis Antetokounmpo
#
# ...

# %% [markdown]
# ## MIN

# %%
MIN_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2000_games.csv')
MIN_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2001_games.csv')
MIN_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2002_games.csv')
MIN_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2003_games.csv')
MIN_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2004_games.csv')
MIN_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2005_games.csv')
MIN_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2006_games.csv')
MIN_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2007_games.csv')
MIN_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2008_games.csv')
MIN_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2009_games.csv')
MIN_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2010_games.csv')
MIN_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2011_games.csv')
MIN_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2012_games.csv')
MIN_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2013_games.csv')
MIN_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2014_games.csv')
MIN_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2015_games.csv')
MIN_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2016_games.csv')
MIN_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2017_games.csv')
MIN_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2018_games.csv')
MIN_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2019_games.csv')
MIN_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2020_games.csv')
MIN_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/MIN/MIN_2021_games.csv')

# %%
MIN_season_dfs = [MIN_2000_games_io, MIN_2001_games_io, MIN_2002_games_io, MIN_2003_games_io, MIN_2004_games_io, MIN_2005_games_io,
                 MIN_2006_games_io, MIN_2007_games_io, MIN_2008_games_io, MIN_2009_games_io, MIN_2010_games_io, MIN_2011_games_io,
                 MIN_2012_games_io, MIN_2013_games_io, MIN_2014_games_io, MIN_2015_games_io, MIN_2016_games_io, MIN_2017_games_io,
                 MIN_2018_games_io, MIN_2019_games_io, MIN_2020_games_io, MIN_2021_games_io]

# %%
MIN_since_2000 = pd.concat(MIN_season_dfs)
MIN_since_2000 = MIN_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
MIN_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2018-03-28  22-133  MIN      HOME      ATL  W (+12)   1  41:21  19   32
# 0  2016-11-30  21-015  MIN      HOME      NYK   L (-2)   1  41:32  15   22
# 0  2005-01-04  28-230  MIN      HOME      PHO   L (-7)   1  41:11  19   28
# 0  2019-10-25  23-344  MIN      AWAY      CHO  W (+22)   1  27:43  13   18
# 0  2003-02-16  26-273  MIN      HOME      GSW   W (+7)   1  41:12  17   27
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-              Player
# 0  ...   15    4    0    1    2   4   56        46.0    7  Karl-Anthony Towns
# 0  ...   18    2    1    3    4   2   47        42.7    7  Karl-Anthony Towns
# 0  ...   17    4    2    0    3   2   47        41.5    1       Kevin Garnett
# 0  ...   15    8    4    2    2   3   37        41.1   25  Karl-Anthony Towns
# 0  ...   22    6    1    5    2   2   37        41.0    6       Kevin Garnett
#
# [5 rows x 29 columns]

# %% [markdown]
# ## NYK

# %%
NYK_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2000_games.csv')
NYK_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2001_games.csv')
NYK_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2002_games.csv')
NYK_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2003_games.csv')
NYK_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2004_games.csv')
NYK_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2005_games.csv')
NYK_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2006_games.csv')
NYK_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2007_games.csv')
NYK_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2008_games.csv')
NYK_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2009_games.csv')
NYK_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2010_games.csv')
NYK_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2011_games.csv')
NYK_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2012_games.csv')
NYK_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2013_games.csv')
NYK_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2014_games.csv')
NYK_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2015_games.csv')
NYK_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2016_games.csv')
NYK_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2017_games.csv')
NYK_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2018_games.csv')
NYK_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2019_games.csv')
NYK_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2020_games.csv')
NYK_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2021_games.csv')

# %%
NYK_season_dfs = [NYK_2000_games_io, NYK_2001_games_io, NYK_2002_games_io, NYK_2003_games_io, NYK_2004_games_io, NYK_2005_games_io,
                 NYK_2006_games_io, NYK_2007_games_io, NYK_2008_games_io, NYK_2009_games_io, NYK_2010_games_io, NYK_2011_games_io,
                 NYK_2012_games_io, NYK_2013_games_io, NYK_2014_games_io, NYK_2015_games_io, NYK_2016_games_io, NYK_2017_games_io,
                 NYK_2018_games_io, NYK_2019_games_io, NYK_2020_games_io, NYK_2021_games_io]

# %%
NYK_since_2000 = pd.concat(NYK_season_dfs)
NYK_since_2000 = NYK_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2014-01-24  29-240  NYK      HOME      CHA  W (+29)   1  38:39  23   35
# 0  2003-02-16  31-302  NYK      AWAY      LAL   W (+7)   1  43:29  18   29
# 0  2013-04-02  28-308  NYK      AWAY      MIA  W (+12)   1  40:20  18   26
# 0  2011-02-07  26-254  DEN      HOME      HOU   L (-5)   1  39:28  16   24
# 0  2003-12-29  26-312  PHO      AWAY      LAC   W (+8)   1  41:46  15   23
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-           Player
# 0  ...   13    0    0    0    0   1   62        50.6   34  Carmelo Anthony
# 0  ...    4    5    2    0    0   3   53        44.6    3    Allan Houston
# 0  ...    2    2    1    1    0   3   50        41.1   15  Carmelo Anthony
# 0  ...   11    0    1    3    4   2   50        40.8   -3  Carmelo Anthony
# 0  ...    4    9    5    0    2   1   40        40.4    8  Stephon Marbury
#
# [5 rows x 29 columns]

# %% [markdown]
# ## OKC

# %%
OKC_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2009_games.csv')
OKC_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2010_games.csv')
OKC_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2011_games.csv')
OKC_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2012_games.csv')
OKC_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2013_games.csv')
OKC_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2014_games.csv')
OKC_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2015_games.csv')
OKC_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2016_games.csv')
OKC_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2017_games.csv')
OKC_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2018_games.csv')
OKC_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2019_games.csv')
OKC_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2020_games.csv')
OKC_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/OKC/OKC_2021_games.csv')

# %%
OKC_season_dfs = [OKC_2009_games_io, OKC_2010_games_io, OKC_2011_games_io,
                 OKC_2012_games_io, OKC_2013_games_io, OKC_2014_games_io, OKC_2015_games_io, OKC_2016_games_io, OKC_2017_games_io,
                 OKC_2018_games_io, OKC_2019_games_io, OKC_2020_games_io, OKC_2021_games_io]

# %%
OKC_since_2000 = pd.concat(OKC_season_dfs)
OKC_since_2000 = OKC_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
OKC_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT  RESULT  GS     MP  FG  FGA  \
# 0  2017-04-09  28-148  OKC      AWAY      DEN  W (+1)   1  36:57  17   32
# 0  2015-02-06  26-086  OKC      HOME      NOP  L (-3)   1  39:42  15   28
# 0  2014-01-17  25-110  OKC      HOME      GSW  W (+6)   1  43:30  19   28
# 1  2017-03-29  28-137  OKC      AWAY      ORL  W (+8)   1  41:49  21   40
# 2  2017-03-07  28-115  OKC      HOME      POR  L (-5)   1  35:56  21   39
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# 0  ...   16   10    1    0    2   1   50        45.6   10  Russell Westbrook
# 0  ...    9   11    4    0    3   4   48        45.4    5  Russell Westbrook
# 0  ...    4    6    2    1    5   1   54        44.3    7       Kevin Durant
# 1  ...   13   11    3    0    7   3   57        44.2    8  Russell Westbrook
# 2  ...    3    9    3    1    4   4   58        43.6    7  Russell Westbrook
#
# [5 rows x 29 columns]

# %% [markdown]
# ## ORL

# %%
ORL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2000_games.csv')
ORL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2001_games.csv')
ORL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2002_games.csv')
ORL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2003_games.csv')
ORL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2004_games.csv')
ORL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2005_games.csv')
ORL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2006_games.csv')
ORL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2007_games.csv')
ORL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2008_games.csv')
ORL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2009_games.csv')
ORL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2010_games.csv')
ORL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2011_games.csv')
ORL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2012_games.csv')
ORL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2013_games.csv')
ORL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2014_games.csv')
ORL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2015_games.csv')
ORL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2016_games.csv')
ORL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2017_games.csv')
ORL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2018_games.csv')
ORL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2019_games.csv')
ORL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2020_games.csv')
ORL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2021_games.csv')

# %%
ORL_season_dfs = [ORL_2000_games_io, ORL_2001_games_io, ORL_2002_games_io, ORL_2003_games_io, ORL_2004_games_io, ORL_2005_games_io,
                 ORL_2006_games_io, ORL_2007_games_io, ORL_2008_games_io, ORL_2009_games_io, ORL_2010_games_io, ORL_2011_games_io,
                 ORL_2012_games_io, ORL_2013_games_io, ORL_2014_games_io, ORL_2015_games_io, ORL_2016_games_io, ORL_2017_games_io,
                 ORL_2018_games_io, ORL_2019_games_io, ORL_2020_games_io, ORL_2021_games_io]

# %%
ORL_since_2000 = pd.concat(ORL_season_dfs)
ORL_since_2000 = ORL_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT  RESULT  GS     MP  FG  FGA  \
# 0  2004-03-10  24-291  ORL      HOME      WAS  W (+9)   1  45:50  20   37
# 1  2003-11-14  24-174  ORL      AWAY      DEN  L (-5)   1  41:34  20   30
# 0  2003-02-23  23-275  ORL      AWAY      NJN  W (+8)   1  45:18  16   27
# 0  2009-02-17  23-071  ORL      HOME      CHA  W (+5)   1  46:41  16   23
# 0  2012-01-12  26-035  ORL      AWAY      GSW  W (+8)   1  43:37  12   21
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...   10    5    1    0    6   1   62        42.8   10  Tracy McGrady
# 1  ...    6    5    2    2    4   2   51        42.7   -1  Tracy McGrady
# 0  ...   10   13    0    2    4   0   46        42.2    7  Tracy McGrady
# 0  ...   19    0    1    8    5   5   45        41.8   16  Dwight Howard
# 0  ...   23    3    4    2    3   2   45        41.3   12  Dwight Howard
#
# [5 rows x 29 columns]

# %% [markdown]
# ## PHI

# %%
PHI_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2000_games.csv')
PHI_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2001_games.csv')
PHI_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2002_games.csv')
PHI_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2003_games.csv')
PHI_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2004_games.csv')
PHI_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2005_games.csv')
PHI_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2006_games.csv')
PHI_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2007_games.csv')
PHI_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2008_games.csv')
PHI_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2009_games.csv')
PHI_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2010_games.csv')
PHI_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2011_games.csv')
PHI_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2012_games.csv')
PHI_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2013_games.csv')
PHI_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2014_games.csv')
PHI_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2015_games.csv')
PHI_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2016_games.csv')
PHI_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2017_games.csv')
PHI_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2018_games.csv')
PHI_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2019_games.csv')
PHI_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2020_games.csv')
PHI_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2021_games.csv')

# %%
PHI_season_dfs = [PHI_2000_games_io, PHI_2001_games_io, PHI_2002_games_io, PHI_2003_games_io, PHI_2004_games_io, PHI_2005_games_io,
                 PHI_2006_games_io, PHI_2007_games_io, PHI_2008_games_io, PHI_2009_games_io, PHI_2010_games_io, PHI_2011_games_io,
                 PHI_2012_games_io, PHI_2013_games_io, PHI_2014_games_io, PHI_2015_games_io, PHI_2016_games_io, PHI_2017_games_io,
                 PHI_2018_games_io, PHI_2019_games_io, PHI_2020_games_io, PHI_2021_games_io]

# %%
PHI_since_2000 = pd.concat(PHI_season_dfs)
PHI_since_2000 = PHI_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-19  26-340  PHI      HOME      CHI   W (+7)   1  35:16  17   26
# 0  2005-02-12  29-250  PHI      HOME      ORL  W (+13)   1  42:01  17   36
# 0  2017-11-15  23-244  PHI      AWAY      LAL   W (+6)   1  34:29  14   20
# 0  2007-03-17  31-283  DEN      HOME      PHO  W (+24)   1  42:38  16   22
# 0  2005-12-23  30-199  PHI      AWAY      ATL   L (-3)   1  44:30  17   31
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...   17    5    2    4    2   2   50        50.8   22    Joel Embiid
# 0  ...    4    6    5    1    3   1   60        48.5   27  Allen Iverson
# 0  ...   15    7    0    7    2   4   46        47.9   19    Joel Embiid
# 0  ...    5   15    0    1    1   2   44        45.1   31  Allen Iverson
# 0  ...    6    5    2    0    0   0   53        44.6   -5  Allen Iverson
#
# [5 rows x 29 columns]

# %% [markdown]
# ## PHO

# %%
PHO_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2000_games.csv')
PHO_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2001_games.csv')
PHO_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2002_games.csv')
PHO_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2003_games.csv')
PHO_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2004_games.csv')
PHO_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2005_games.csv')
PHO_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2006_games.csv')
PHO_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2007_games.csv')
PHO_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2008_games.csv')
PHO_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2009_games.csv')
PHO_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2010_games.csv')
PHO_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2011_games.csv')
PHO_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2012_games.csv')
PHO_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2013_games.csv')
PHO_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2014_games.csv')
PHO_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2015_games.csv')
PHO_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2016_games.csv')
PHO_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2017_games.csv')
PHO_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2018_games.csv')
PHO_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2019_games.csv')
PHO_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2020_games.csv')
PHO_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2021_games.csv')

# %%
PHO_season_dfs = [PHO_2000_games_io, PHO_2001_games_io, PHO_2002_games_io, PHO_2003_games_io, PHO_2004_games_io, PHO_2005_games_io,
                 PHO_2006_games_io, PHO_2007_games_io, PHO_2008_games_io, PHO_2009_games_io, PHO_2010_games_io, PHO_2011_games_io,
                 PHO_2012_games_io, PHO_2013_games_io, PHO_2014_games_io, PHO_2015_games_io, PHO_2016_games_io, PHO_2017_games_io,
                 PHO_2018_games_io, PHO_2019_games_io, PHO_2020_games_io, PHO_2021_games_io]

# %%
PHO_since_2000 = pd.concat(PHO_season_dfs)
PHO_since_2000 = PHO_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2008-11-05  25-355  PHO      AWAY      IND  W (+10)   1  44:00  17   21
# 0  2000-01-16  33-031  PHO      HOME      DEN  W (+13)   1  42:31  17   26
# 0  2006-02-22  27-291  PHO      HOME      BOS   W (+9)   1  43:02  15   22
# 1  2009-02-20  26-084  PHO      HOME      OKC  W (+22)   1  41:42  16   21
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# 0  ...    8    6    3    1    5   3   70        54.5   -6       Devin Booker
# 0  ...   11    6    5    2    4   3   49        50.2   11  Amar'e Stoudemire
# 0  ...    8    4    0    2    0   2   50        44.8   25  Clifford Robinson
# 0  ...   15    0    4    3    2   3   44        44.8    7       Shawn Marion
# 1  ...    7    7    6    0    1   3   41        43.5   29    Leandro Barbosa
#
# [5 rows x 29 columns]

# %% [markdown]
# ## POR

# %%
POR_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2000_games.csv')
POR_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2001_games.csv')
POR_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2002_games.csv')
POR_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2003_games.csv')
POR_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2004_games.csv')
POR_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2005_games.csv')
POR_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2006_games.csv')
POR_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2007_games.csv')
POR_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2008_games.csv')
POR_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2009_games.csv')
POR_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2010_games.csv')
POR_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2011_games.csv')
POR_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2012_games.csv')
POR_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2013_games.csv')
POR_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2014_games.csv')
POR_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2015_games.csv')
POR_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2016_games.csv')
POR_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2017_games.csv')
POR_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2018_games.csv')
POR_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2019_games.csv')
POR_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2020_games.csv')
POR_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2021_games.csv')

# %%
POR_season_dfs = [POR_2000_games_io, POR_2001_games_io, POR_2002_games_io, POR_2003_games_io, POR_2004_games_io, POR_2005_games_io,
                 POR_2006_games_io, POR_2007_games_io, POR_2008_games_io, POR_2009_games_io, POR_2010_games_io, POR_2011_games_io,
                 POR_2012_games_io, POR_2013_games_io, POR_2014_games_io, POR_2015_games_io, POR_2016_games_io, POR_2017_games_io,
                 POR_2018_games_io, POR_2019_games_io, POR_2020_games_io, POR_2021_games_io]

# %%
POR_since_2000 = pd.concat(POR_season_dfs)
POR_since_2000 = POR_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
POR_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-08-11  30-027  POR      AWAY      DAL   W (+3)   1  41:05  17   32
# 1  2020-01-26  29-195  POR      HOME      IND  W (+10)   1  38:28  14   23
# 0  2017-04-08  26-267  POR      HOME      UTA  W (+15)   1  41:49  18   34
# 2  2020-01-20  29-189  POR      HOME      GSW   W (+5)   1  45:08  17   37
# 0  2016-02-19  25-219  POR      HOME      GSW  W (+32)   1  31:06  18   28
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 0  ...    5    8    1    0    3   2   61        50.5    8  Damian Lillard
# 1  ...    6   13    1    0    1   0   50        49.6   19  Damian Lillard
# 0  ...    6    5    1    1    0   0   59        48.6   19  Damian Lillard
# 2  ...   10    7    1    0    2   1   61        48.4   13  Damian Lillard
# 0  ...    0    7    6    0    0   3   51        47.9   26  Damian Lillard
#
# [5 rows x 29 columns]

# %% [markdown]
# ## SAC

# %%
SAC_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2000_games.csv')
SAC_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2001_games.csv')
SAC_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2002_games.csv')
SAC_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2003_games.csv')
SAC_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2004_games.csv')
SAC_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2005_games.csv')
SAC_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2006_games.csv')
SAC_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2007_games.csv')
SAC_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2008_games.csv')
SAC_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2009_games.csv')
SAC_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2010_games.csv')
SAC_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2011_games.csv')
SAC_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2012_games.csv')
SAC_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2013_games.csv')
SAC_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2014_games.csv')
SAC_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2015_games.csv')
SAC_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2016_games.csv')
SAC_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2017_games.csv')
SAC_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2018_games.csv')
SAC_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2019_games.csv')
SAC_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2020_games.csv')
SAC_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2021_games.csv')

# %%
SAC_season_dfs = [SAC_2000_games_io, SAC_2001_games_io, SAC_2002_games_io, SAC_2003_games_io, SAC_2004_games_io, SAC_2005_games_io,
                 SAC_2006_games_io, SAC_2007_games_io, SAC_2008_games_io, SAC_2009_games_io, SAC_2010_games_io, SAC_2011_games_io,
                 SAC_2012_games_io, SAC_2013_games_io, SAC_2014_games_io, SAC_2015_games_io, SAC_2016_games_io, SAC_2017_games_io,
                 SAC_2018_games_io, SAC_2019_games_io, SAC_2020_games_io, SAC_2021_games_io]

# %%
SAC_since_2000 = pd.concat(SAC_season_dfs)
SAC_since_2000 = SAC_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2016-12-20  26-129  SAC      HOME      POR   W (+5)   1  40:35  17   28
# 0  2016-01-25  25-165  SAC      HOME      CHO   L (-1)   1  45:40  21   30
# 0  2021-01-17  23-028  SAC      HOME      NOP   L (-5)   1  39:02  17   27
# 0  2001-01-05  27-310  SAC      HOME      IND   L (-2)   1  49:58  24   47
# 1  2021-03-25  23-095  SAC      HOME      GSW  W (+22)   1  35:40  16   22
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-            Player
# 0  ...   14    1    1    3    5   5   55        43.2    3  DeMarcus Cousins
# 0  ...   12    4    1    2    7   6   56        42.0   15  DeMarcus Cousins
# 0  ...    4   13    4    0    2   3   43        41.6   18      De'Aaron Fox
# 0  ...   26    5    3    2    4   4   51        40.6   -1      Chris Webber
# 1  ...    2    7    3    0    2   3   44        39.9    9      De'Aaron Fox
#
# [5 rows x 29 columns]

# %% [markdown]
# ## SAS

# %%
SAS_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2000_games.csv')
SAS_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2001_games.csv')
SAS_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2002_games.csv')
SAS_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2003_games.csv')
SAS_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2004_games.csv')
SAS_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2005_games.csv')
SAS_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2006_games.csv')
SAS_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2007_games.csv')
SAS_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2008_games.csv')
SAS_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2009_games.csv')
SAS_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2010_games.csv')
SAS_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2011_games.csv')
SAS_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2012_games.csv')
SAS_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2013_games.csv')
SAS_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2014_games.csv')
SAS_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2015_games.csv')
SAS_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2016_games.csv')
SAS_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2017_games.csv')
SAS_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2018_games.csv')
SAS_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2019_games.csv')
SAS_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2020_games.csv')
SAS_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2021_games.csv')

# %%
SAS_season_dfs = [SAS_2000_games_io, SAS_2001_games_io, SAS_2002_games_io, SAS_2003_games_io, SAS_2004_games_io, SAS_2005_games_io,
                 SAS_2006_games_io, SAS_2007_games_io, SAS_2008_games_io, SAS_2009_games_io, SAS_2010_games_io, SAS_2011_games_io,
                 SAS_2012_games_io, SAS_2013_games_io, SAS_2014_games_io, SAS_2015_games_io, SAS_2016_games_io, SAS_2017_games_io,
                 SAS_2018_games_io, SAS_2019_games_io, SAS_2020_games_io, SAS_2021_games_io]

# %%
SAS_since_2000 = pd.concat(SAS_season_dfs)
SAS_since_2000 = SAS_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT  RESULT  GS     MP  FG  FGA  \
# 0  2008-02-13  30-200  SAS      AWAY      CLE  W (+7)   1  40:34  15   20
# 0  2019-01-10  33-175  SAS      HOME      OKC  W (+7)   1  48:34  20   33
# 0  2003-03-04  26-313  SAS      HOME      PHO  L (-7)   1  43:39  14   18
# 0  2008-11-05  26-172  SAS      AWAY      MIN  W (+4)   1  50:32  22   36
# 0  2001-12-26  25-245  SAS      HOME      DAL  L (-3)   1  50:21  19   28
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# 0  ...    5    8    3    1    1   2   46        46.6   12      Manu Ginóbili
# 0  ...    9    4    0    4    5   2   56        45.0    7  LaMarcus Aldridge
# 0  ...   21    8    2    4    2   1   35        44.7   -6         Tim Duncan
# 0  ...    7   10    0    0    4   0   55        43.3    7        Tony Parker
# 0  ...   11    4    0    3    6   5   53        42.8   -1         Tim Duncan
#
# [5 rows x 29 columns]

# %% [markdown]
# ## TOR

# %%
TOR_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2000_games.csv')
TOR_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2001_games.csv')
TOR_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2002_games.csv')
TOR_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2003_games.csv')
TOR_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2004_games.csv')
TOR_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2005_games.csv')
TOR_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2006_games.csv')
TOR_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2007_games.csv')
TOR_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2008_games.csv')
TOR_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2009_games.csv')
TOR_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2010_games.csv')
TOR_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2011_games.csv')
TOR_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2012_games.csv')
TOR_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2013_games.csv')
TOR_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2014_games.csv')
TOR_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2015_games.csv')
TOR_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2016_games.csv')
TOR_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2017_games.csv')
TOR_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2018_games.csv')
TOR_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2019_games.csv')
TOR_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2020_games.csv')
TOR_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2021_games.csv')

# %%
TOR_season_dfs = [TOR_2000_games_io, TOR_2001_games_io, TOR_2002_games_io, TOR_2003_games_io, TOR_2004_games_io, TOR_2005_games_io,
                 TOR_2006_games_io, TOR_2007_games_io, TOR_2008_games_io, TOR_2009_games_io, TOR_2010_games_io, TOR_2011_games_io,
                 TOR_2012_games_io, TOR_2013_games_io, TOR_2014_games_io, TOR_2015_games_io, TOR_2016_games_io, TOR_2017_games_io,
                 TOR_2018_games_io, TOR_2019_games_io, TOR_2020_games_io, TOR_2021_games_io]

# %%
TOR_since_2000 = pd.concat(TOR_season_dfs)
TOR_since_2000 = TOR_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-02  26-343  TOR      AWAY      ORL  W (+15)   1  37:06  17   23
# 0  2018-01-01  28-147  TOR      HOME      MIL   W (+4)   1  43:27  17   29
# 0  2016-02-26  29-338  TOR      HOME      CLE   W (+2)   1  42:49  15   20
# 0  2008-11-18  24-239  TOR      AWAY      ORL  L (-13)   1  44:46  14   19
# 0  2000-11-18  23-297  TOR      HOME      MIL   W (+9)   1  44:43  14   31
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-         Player
# 0  ...    3    2    3    3    1   2   54        50.3   20  Fred VanVleet
# 0  ...    5    8    1    1    2   4   52        44.1    9  DeMar DeRozan
# 0  ...    5    9    4    0    2   4   43        41.6   11     Kyle Lowry
# 0  ...   18    4    2    1    3   1   40        41.0   -7     Chris Bosh
# 0  ...   10    4    3    2    2   3   48        40.5    8   Vince Carter
#
# [5 rows x 29 columns]

# %% [markdown]
# ## UTA

# %%
UTA_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2000_games.csv')
UTA_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2001_games.csv')
UTA_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2002_games.csv')
UTA_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2003_games.csv')
UTA_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2004_games.csv')
UTA_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2005_games.csv')
UTA_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2006_games.csv')
UTA_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2007_games.csv')
UTA_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2008_games.csv')
UTA_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2009_games.csv')
UTA_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2010_games.csv')
UTA_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2011_games.csv')
UTA_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2012_games.csv')
UTA_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2013_games.csv')
UTA_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2014_games.csv')
UTA_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2015_games.csv')
UTA_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2016_games.csv')
UTA_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2017_games.csv')
UTA_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2018_games.csv')
UTA_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2019_games.csv')
UTA_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2020_games.csv')
UTA_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2021_games.csv')

# %%
UTA_season_dfs = [UTA_2000_games_io, UTA_2001_games_io, UTA_2002_games_io, UTA_2003_games_io, UTA_2004_games_io, UTA_2005_games_io,
                 UTA_2006_games_io, UTA_2007_games_io, UTA_2008_games_io, UTA_2009_games_io, UTA_2010_games_io, UTA_2011_games_io,
                 UTA_2012_games_io, UTA_2013_games_io, UTA_2014_games_io, UTA_2015_games_io, UTA_2016_games_io, UTA_2017_games_io,
                 UTA_2018_games_io, UTA_2019_games_io, UTA_2020_games_io, UTA_2021_games_io]

# %%
UTA_since_2000 = pd.concat(UTA_season_dfs)
UTA_since_2000 = UTA_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2000-12-20  37-149  UTA      AWAY      PHI   W (+2)   1  43:11  13   18
# 0  2009-01-12  29-231  UTA      HOME      IND   W (+7)   1  40:13  13   19
# 0  2017-03-22  24-269  UTA      HOME      NYK   W (+7)   1  38:05  13   15
# 0  2003-03-12  39-231  UTA      AWAY      ORL   W (+3)   1  42:08  12   19
# 0  2018-02-02  21-148  UTA      AWAY      PHO  W (+32)   1  33:05  14   19
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-            Player
# 0  ...   13    3    2    4    3   2   41        39.0    1       Karl Malone
# 0  ...    9    3    1    0    1   2   43        38.9   13       Mehmet Okur
# 0  ...   15    1    1    4    3   2   35        38.9   13       Rudy Gobert
# 0  ...    9    7    4    0    1   2   40        38.9    2       Karl Malone
# 0  ...    5    6    2    0    2   0   40        38.4   36  Donovan Mitchell
#
# [5 rows x 29 columns]

# %% [markdown]
# ## WAS

# %%
WAS_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2000_games.csv')
WAS_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2001_games.csv')
WAS_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2002_games.csv')
WAS_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2003_games.csv')
WAS_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2004_games.csv')
WAS_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2005_games.csv')
WAS_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2006_games.csv')
WAS_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2007_games.csv')
WAS_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2008_games.csv')
WAS_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2009_games.csv')
WAS_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2010_games.csv')
WAS_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2011_games.csv')
WAS_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2012_games.csv')
WAS_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2013_games.csv')
WAS_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2014_games.csv')
WAS_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2015_games.csv')
WAS_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2016_games.csv')
WAS_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2017_games.csv')
WAS_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2018_games.csv')
WAS_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2019_games.csv')
WAS_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2020_games.csv')
WAS_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2021_games.csv')

# %%
WAS_season_dfs = [WAS_2000_games_io, WAS_2001_games_io, WAS_2002_games_io, WAS_2003_games_io, WAS_2004_games_io, WAS_2005_games_io,
                 WAS_2006_games_io, WAS_2007_games_io, WAS_2008_games_io, WAS_2009_games_io, WAS_2010_games_io, WAS_2011_games_io,
                 WAS_2012_games_io, WAS_2013_games_io, WAS_2014_games_io, WAS_2015_games_io, WAS_2016_games_io, WAS_2017_games_io,
                 WAS_2018_games_io, WAS_2019_games_io, WAS_2020_games_io, WAS_2021_games_io]

# %%
WAS_since_2000 = pd.concat(WAS_season_dfs)
WAS_since_2000 = WAS_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_since_2000.head(5)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-12-17  24-345  WAS      AWAY      LAL   W (+6)   1  49:00  17   32
# 0  2021-01-06  27-192  WAS      AWAY      PHI   L (-5)   1  38:15  20   35
# 0  2006-02-25  24-050  WAS      HOME      NYK  W (+21)   1  30:16  13   16
# 0  2019-10-30  26-124  WAS      HOME      HOU   L (-1)   1  40:30  14   20
# 0  2013-03-25  22-200  WAS      HOME      MEM  W (+13)   1  44:33  13   22
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 0  ...    8    8    2    0    3   3   60        47.8   10  Gilbert Arenas
# 0  ...    7    5    1    0    4   3   60        45.7   -9    Bradley Beal
# 0  ...    1    2    4    0    1   2   46        43.5   20  Gilbert Arenas
# 0  ...    6    8    3    0    5   4   46        41.8    8    Bradley Beal
# 0  ...    7    8    1    1    2   2   47        41.4   26       John Wall
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Combine all

# %%
NBA_since_2000 = pd.concat([ATL_since_2000, BOS_since_2000, BRK_since_2000, CHI_since_2000,
                CLE_since_2000, DET_since_2000, DEN_since_2000, GSW_since_2000, HOU_since_2000, IND_since_2000,
                           LAC_since_2000, LAL_since_2000, MEM_since_2000, MIA_since_2000, MIL_since_2000,
                           MIN_since_2000, OKC_since_2000, ORL_since_2000, PHI_since_2000, PHO_since_2000,
                           POR_since_2000, SAC_since_2000, SAS_since_2000, TOR_since_2000, UTA_since_2000,
                           WAS_since_2000])

# %%
NBA_since_2000 = NBA_since_2000.sort_values(by=['GAME_SCORE'], ascending=False)
NBA_since_2000.head(10)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
# 0  2019-02-28  29-186  HOU      HOME      MIA   W (+3)   1  43:52  16   32
# 0  2017-01-02  27-110  CHI      HOME      CHO   W (+7)   1  38:19  15   24
# 0  2007-03-16  28-205  LAL      HOME      POR   W (+5)   1  49:58  23   39
# 0  2021-02-19  26-340  PHI      HOME      CHI   W (+7)   1  35:16  17   26
# 0  2020-08-11  30-027  POR      AWAY      DAL   W (+3)   1  41:05  17   32
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# ...

# %%
NBA_since_2000.shape
# Out:
# (230326, 29)

# %% [markdown]
# ## Most Points

# %%
NBA_since_2000_pts = NBA_since_2000.sort_values(by=['PTS'], ascending=False)
NBA_since_2000_pts.head(10)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2007-03-16  28-205  LAL      HOME      POR   W (+5)   1  49:58  23   39
# 1  2005-12-20  27-119  LAL      HOME      DAL  W (+22)   1  32:53  18   31
# 0  2021-01-03  32-295  GSW      HOME      POR  W (+15)   1  36:27  18   31
# 0  2004-03-10  24-291  ORL      HOME      WAS   W (+9)   1  45:50  20   37
# 0  2009-02-02  30-163  LAL      AWAY      NYK   W (+9)   1  36:48  19   31
# 2  2020-01-20  29-189  POR      HOME      GSW   W (+5)   1  45:08  17   37
# 1  2019-01-23  29-150  HOU      AWAY      NYK   W (+4)   1  40:00  17   38
# 0  2014-03-03  29-063  MIA      HOME      CHA  W (+17)   1  41:12  22   33
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# ...

# %% [markdown]
# ## Most assists

# %%
NBA_since_2000_ast = NBA_since_2000.sort_values(by=['AST'], ascending=False)
NBA_since_2000_ast.head(10)
# Out:
#            DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 18   2021-05-03  32-172  WAS      HOME      IND  W (+13)   1  38:38   5    8
# 13   2019-01-10  30-059  OKC      AWAY      SAS   L (-7)   1  49:35  11   22
# 116  2010-10-29  24-249  BOS      HOME      NYK   W (+4)   1  45:20   4   12
# 1    2008-04-14  22-003  MIL      HOME      CHI  L (-16)   1  44:27   7   12
# 3    2011-01-05  24-317  BOS      HOME      SAS   W (+2)   1  43:30   6   10
# 7    2001-11-22  23-267  IND      HOME      WAS   W (+7)   1  45:02   6   15
# 13   2016-12-17  28-035  OKC      HOME      PHO  W (+13)   1  34:01   9   17
# 13   2001-12-15  25-271  CLE      HOME      PHI   L (-3)   1  43:43   6   12
# 206  2001-03-26  33-303  DEN      AWAY      CHI   W (+5)   1  49:21   2    9
# 19   2006-01-02  31-329  PHO      AWAY      NYK   L (-7)   1  55:28  10   25
#
#      ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# ...

# %% [markdown]
# ## Most rebounds

# %%
NBA_since_2000_reb = NBA_since_2000.sort_values(by=['TRB'], ascending=False)
NBA_since_2000_reb.head(10)
# Out:
#           DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 5   2010-11-12  22-066  MIN      HOME      NYK   W (+9)   1  40:39  11   26
# 19  2021-04-10  28-325  POR      HOME      DET  W (+15)   1  37:04   9   16
# 62  2012-04-11  24-167  LAL      AWAY      SAS  W (+14)   1  36:41   7   20
# 0   1999-12-14  33-172  ATL      HOME      MIN  W (+11)   1  41:04  11   11
# 3   2014-04-10  27-268  DEN      AWAY      GSW   W (+1)   1  42:45  10   15
# 1   2012-12-31  22-068  ORL      HOME      MIA   L (-2)   1  46:34   9   17
# 6   2001-01-31  34-220  ATL      HOME      TOR   W (+5)   1  41:22   8   12
# 7   2015-11-03  22-085  DET      HOME      IND  L (-12)   1  43:13  12   17
# 0   2001-01-31  34-220  ATL      HOME      TOR   W (+5)   1  41:22   8   12
# 16  2002-03-24  27-195  DET      HOME      BOS   W (+8)   1  43:42   6    9
#
#     ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-           Player
# ...

# %% [markdown]
# ## +/-

# %%
NBA_since_2000_plus = NBA_since_2000.sort_values(by=['+/-'], ascending=False)
NBA_since_2000_plus.head(10)
# Out:
#            DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 102  2001-11-08  26-105  MIN      HOME      CHI  W (+53)   1  26:57   7   10
# 206  2001-11-08  24-248  MIN      HOME      CHI  W (+53)   1  21:32   6    8
# 0    2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
# 23   2018-12-08  26-248  BOS      AWAY      CHI  W (+56)   1  32:16   8   15
# 7    2021-05-01  24-363  IND      AWAY      OKC  W (+57)   1  29:30  10   13
# 51   2009-02-02  26-078  PHO      HOME      SAC  W (+48)   1  27:35   6   12
# 117  2021-05-01  22-315  IND      AWAY      OKC  W (+57)   1  40:01   6   11
# 8    2021-04-02  27-000  TOR      HOME      GSW  W (+53)   1  31:08  14   24
# 4    2008-12-02  32-068  DEN      HOME      TOR  W (+39)   1  31:53   8   12
# 123  2016-03-28  25-341  UTA      HOME      LAL  W (+48)   1  29:12   8   11
#
#      ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# ...

# %% [markdown]
# ## Blocks

# %%
NBA_since_2000_blk = NBA_since_2000.sort_values(by=['BLK'], ascending=False)
NBA_since_2000_blk.shape
# Out:
# (230326, 29)

# %% [markdown]
# ## Steals

# %%
NBA_since_2000_stl = NBA_since_2000.sort_values(by=['STL'], ascending=False)
NBA_since_2000_stl.head(10)
# Out:
#            DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 13   2009-01-24  24-185  POR      HOME      WAS  W (+13)   1  39:04   7   18
# 85   2017-02-10  26-343  GSW      AWAY      MEM  W (+15)   1  37:44   2    6
# 2    2018-01-20  31-085  LAC      AWAY      UTA  L (-12)   1  40:01   9   21
# 10   1999-12-03  22-051  BOS      HOME      MIA  W (+12)   1  38:26   9   22
# 133  2008-11-05  22-170  MIA      HOME      PHI  W (+23)   1  30:32   3    8
# 58   2007-02-10  30-201  HOU      HOME      CHA  W (+21)   1  41:13   5   13
# 38   2002-12-20  27-196  PHI      HOME      LAL   W (+3)   1  48:21  11   33
# 13   2001-12-15  25-271  CLE      HOME      PHI   L (-3)   1  43:43   6   12
# 61   2000-03-19  24-286  PHI      HOME      ORL   W (+4)   1  41:42   8   22
# 4    2010-11-02  20-057  WAS      HOME      PHI   W (+1)   1  44:48   9   16
#
#      ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# ...

# %% [markdown]
# ## Find Triple Doubles (by Type)

# %%
dbl_pts = NBA_since_2000[NBA_since_2000['PTS']>=10]
dbl_reb = NBA_since_2000[NBA_since_2000['TRB']>=10]
dbl_ast = NBA_since_2000[NBA_since_2000['AST']>=10]
dbl_blk = NBA_since_2000[NBA_since_2000['BLK']>=10]
dbl_stl = NBA_since_2000[NBA_since_2000['STL']>=10]
dbl_pts_reb = dbl_pts[dbl_pts['TRB']>=10]
dbl_pts_ast = dbl_pts[dbl_pts['AST']>=10]
dbl_reb_ast = dbl_reb[dbl_reb['AST']>=10]
trip_dub_pts_reb_ast = dbl_pts_reb[dbl_pts_reb['AST']>=10]
trip_dub_pts_reb_blk = dbl_pts_reb[dbl_pts_reb['BLK']>=10]
trip_dub_reb_ast_stl = dbl_reb_ast[dbl_reb_ast["STL"]>=10]
trip_dub_pts_reb_ast.shape, trip_dub_pts_reb_blk.shape, trip_dub_reb_ast_stl.shape
# Out:
# ((1055, 29), (13, 29), (1, 29))

# %%
trip_dub_pts_reb_ast.shape
trip_dub_pts_reb_ast.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2016-12-31  27-127  HOU      HOME      NYK   W (+7)   1  42:05  14   26
# 1  2017-01-27  27-154  HOU      AWAY      PHI   W (+5)   1  39:09  16   28
# 0  2018-10-20  23-243  DEN      HOME      PHO  W (+28)   1  30:43  11   11
# 0  2017-04-09  28-148  OKC      AWAY      DEN   W (+1)   1  36:57  17   32
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-             Player
# 0  ...   10   11    4    1    5   2   60        56.6    7       James Harden
# 0  ...   16   17    0    0    8   2   53        48.7   13       James Harden
# 1  ...   13   13    2    1    5   4   51        46.9   13       James Harden
# 0  ...   11   11    4    1    0   3   35        45.8   29       Nikola Jokić
# 0  ...   16   10    1    0    2   1   50        45.6   10  Russell Westbrook
#
# [5 rows x 29 columns]

# %%
# Trip-Dub, points, rebounds, assists

# %%
trip_dub_pra = trip_dub_pts_reb_ast['Player'].value_counts(normalize=True).to_frame()
trip_dub_pra['Count'] = trip_dub_pts_reb_ast['Player'].value_counts().to_frame()
trip_dub_pra['Player'].astype(float).to_frame()
trip_dub_pra_25 = trip_dub_pra.nlargest(25, ['Player'])
trip_dub_pra_25.reset_index()
trip_dub_pra_25_ = trip_dub_pra_25.rename(columns={'index':'Player', 'Player': '% of Trip-Dubs'})
trip_dub_pra_25_.head()
# Out:
#                    % of Trip-Dubs  Count
# Russell Westbrook        0.174408    184
# LeBron James             0.093839     99
# James Harden             0.066351     70
# Nikola Jokić             0.054028     57
# Ben Simmons              0.030332     32

# %%
trip_dub_pra_25.head()
# Out:
#                      Player  Count
# Russell Westbrook  0.174408    184
# LeBron James       0.093839     99
# James Harden       0.066351     70
# Nikola Jokić       0.054028     57
# Ben Simmons        0.030332     32

# %%
trip_dub_pra_25['Count'].sum()
# Out:
# 737

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,20))
trip_dub_pra_25_['% of Trip-Dubs'].plot.barh(figsize=(20,12))
plt.gca().invert_yaxis()
plt.title('Triple Doubles since 2000: Points, Rebounds, Assist', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Triple Doubles since 2000: Points, Rebounds, Assist')

# %%
y = trip_dub_pra_25_['Count']
x = trip_dub_pra_25_['% of Trip-Dubs']
fig, ax = plt.subplots(figsize=(15,10))
ax.barh(y.index, y,height=0.75, color='blue')
plt.gca().invert_yaxis()
for i, v in enumerate(y):
    ax.text(v +1, i, str(v), color='black', fontsize=12, ha='left', va='center')
plt.title('Triple Double Leaders since 2000: Points, Rebounds, Assists', fontsize=24)
plt.xlabel("# of Triple-Doubles [points, rebounds, assists]")
plt.savefig('trip_dub_pra.png')
plt.show()

# %%
# Trip-Dub, points, rebounds, blocks

# %%
trip_dub_prb = trip_dub_pts_reb_blk['Player'].value_counts().to_frame()
trip_dub_prb['Count'] = trip_dub_pts_reb_blk['Player'].value_counts().to_frame()
trip_dub_prb['Player'].astype(float).to_frame()
trip_dub_prb_25 = trip_dub_prb.nlargest(25, ['Player'])
trip_dub_prb_25.reset_index()
trip_dub_prb_25_ = trip_dub_prb_25.rename(columns={'index':'Player', 'Player': '% of Trip-Dubs'})
trip_dub_prb_25_.head()
# Out:
#                   % of Trip-Dubs  Count
# Dikembe Mutombo                2      2
# Hassan Whiteside               2      2
# Ben Wallace                    2      2
# Joakim Noah                    1      1
# Dwight Howard                  1      1

# %%
trip_dub_prb_25.plot(kind='barh', figsize=(20,12))
plt.gca().invert_yaxis()
plt.title('Triple Doubles since 2000: Points, Rebounds, Blocks', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Triple Doubles since 2000: Points, Rebounds, Blocks')

# %%
y = trip_dub_prb_25_['Count']
x = trip_dub_prb_25_['% of Trip-Dubs']
fig, ax = plt.subplots(figsize=(15,10))
ax.barh(y.index, y,height=0.75, color='green')
plt.gca().invert_yaxis()
for i, v in enumerate(y):
    ax.text(v, i, str(v), color='black', fontsize=12, ha='left', va='center')
plt.title('Triple Double Leaders since 2000: Points, Rebounds, Blocks', fontsize=24)
plt.xlabel("# of Triple-Doubles [points, rebounds, blocks]", fontsize=18)
plt.savefig('trip_dub_prb.png')
plt.show()

# %%
trip_dub_rsa = trip_dub_reb_ast_stl['Player'].value_counts().to_frame()
trip_dub_rsa['Count'] = trip_dub_reb_ast_stl['Player'].value_counts().to_frame()
trip_dub_rsa['Player'].astype(float).to_frame()
trip_dub_rsa_25 = trip_dub_rsa.nlargest(25, ['Player'])
trip_dub_rsa_25.reset_index()
trip_dub_rsa_25_ = trip_dub_rsa_25.rename(columns={'index':'Player', 'Player': '% of Trip-Dubs'})
trip_dub_rsa_25_.style.set_caption("Triple-Doubles: Rebounds, steals, assists [no points]")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7603a_">
#   <caption>Triple-Doubles: Rebounds, steals, assists [no points]</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >% of Trip-Dubs</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7603a_level0_row0" class="row_heading level0 row0" >Draymond Green</th>
#       <td id="T_7603a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7603a_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
trip_dub_reb_ast_stl
# Out:
#           DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 85  2017-02-10  26-343  GSW      AWAY      MEM  W (+15)   1  37:44   2    6
#
#     ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 85  ...   11   10   10    5    2   3    4        21.2   26  Draymond Green
#
# [1 rows x 29 columns]

# %%
trip_dub_rsa_25.plot(kind='barh', figsize=(20,12))
plt.gca().invert_yaxis()
plt.title('Triple Doubles since 2000: Rebounds, Steals, Assists', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Triple Doubles since 2000: Rebounds, Steals, Assists')

# %%
y = trip_dub_rsa_25_['Count']
x = trip_dub_rsa_25_['% of Trip-Dubs']
fig, ax = plt.subplots(figsize=(15,10))
ax.barh(y.index, y,height=0.05, color='red')
plt.gca().invert_yaxis()
for i, v in enumerate(y):
    ax.text(v, i, str(v), color='black', fontsize=12, ha='left', va='center')
plt.title('Triple Double Leaders since 2000: Points, Rebounds, Blocks', fontsize=24)

plt.xlabel("# of Triple-Doubles [points, rebounds, blocks]", fontsize=18)
plt.savefig('trip_dub_rsa.png')
plt.show()

# %%
trip_dub_reb_ast_stl
# Out:
#           DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 85  2017-02-10  26-343  GSW      AWAY      MEM  W (+15)   1  37:44   2    6
#
#     ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-          Player
# 85  ...   11   10   10    5    2   3    4        21.2   26  Draymond Green
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Groupby Player

# %%
NBA_since_2000.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...    6    2    3    1    3   1   81        63.5   25   Kobe Bryant
# 0  ...   10   11    4    1    5   2   60        56.6    7  James Harden
# 0  ...    8    6    3    1    5   3   70        54.5   -6  Devin Booker
# 0  ...   11    7    3    2    3   2   57        53.2    6  LeBron James
# 0  ...    3    8    3    1    5   3   60        52.4   50  James Harden
#
# [5 rows x 29 columns]

# %%
NBA_since_2000.columns
# Out:
# Index(['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS', 'MP',
#        'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE',
#        '+/-', 'Player'],
#       dtype='object')

# %%
NBA_since_2000_grouped = NBA_since_2000.groupby('Player').agg({
    'GS':'count',
    'FG': 'mean',
    'FGA': 'mean',
    '3P': 'mean',
    '3PA': 'mean',
    'FT': 'mean',
    'FTA': 'mean',
    'TRB': 'mean',
    'AST': 'mean',
    'STL':'mean',
    'BLK':'mean',
    'PTS': 'mean',
    'GAME_SCORE':'mean'
})
NBA_since_2000_grouped.sort_values('GAME_SCORE', ascending=False).head(25)
# Out:
#                          GS         FG        FGA        3P       3PA  \
# Player
# Chris Wright              1  11.000000  14.000000  0.000000  0.000000
# James Harden            704   8.539773  19.191761  3.191761  8.816761
# LeBron James           1305   9.862835  19.566284  1.515709  4.387739
# Kevin Durant            800   9.402500  18.801250  1.988750  5.116250
# Anthony Davis            98   8.693878  17.438776  1.000000  3.244898
# Joel Embiid             259   8.200772  16.845560  1.138996  3.463320
# Karl-Anthony Towns      407   8.565111  16.240786  1.542998  3.914005
# Giannis Antetokounmpo   523   8.282983  15.428298  0.661568  2.332696
# Stephen Curry           754   8.347480  17.527851  3.736074  8.633952
# Darrick Martin            1   6.000000  11.000000  3.000000  5.000000
# Kobe Bryant            1134   9.432099  21.032628  1.468254  4.456790
# Nikola Jokić            411   7.423358  13.941606  1.043796  3.004866
# ...

# %%
NBA_since_2000.head()
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0  2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0  2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
#
#    ...  TRB  AST  STL  BLK  TOV  PF  PTS  GAME_SCORE  +/-        Player
# 0  ...    6    2    3    1    3   1   81        63.5   25   Kobe Bryant
# 0  ...   10   11    4    1    5   2   60        56.6    7  James Harden
# 0  ...    8    6    3    1    5   3   70        54.5   -6  Devin Booker
# 0  ...   11    7    3    2    3   2   57        53.2    6  LeBron James
# 0  ...    3    8    3    1    5   3   60        52.4   50  James Harden
#
# [5 rows x 29 columns]

# %%
NBA_since_2000['DATE'] = pd.to_datetime(NBA_since_2000['DATE'])
NBA_since_2000['DATE']
# Out:
# 0     2006-01-22
# 0     2018-01-30
# 0     2017-03-24
# 0     2017-11-03
# 0     2019-11-30
#          ...
# 503   2007-11-25
# 512   2007-03-26
# 409   2009-11-15
# 417   2015-12-19
# 329   2011-12-28
# Name: DATE, Length: 230326, dtype: datetime64[ns]

# %%
type(NBA_since_2000['DATE'])
# Out:
# pandas.core.series.Series

# %%
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
from datetime import datetime

# %%
def season_row(row):
    if datetime.strptime(SEASON_2000_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2000_START, "%Y-%m-%d"):
        return 2000
    elif datetime.strptime(SEASON_2001_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2001_START, "%Y-%m-%d"):
        return 2001
    elif datetime.strptime(SEASON_2002_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2002_START, "%Y-%m-%d"):
        return 2002
    elif datetime.strptime(SEASON_2003_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2003_START, "%Y-%m-%d"):
        return 2003
    elif datetime.strptime(SEASON_2004_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2004_START, "%Y-%m-%d"):
        return 2004
    elif datetime.strptime(SEASON_2005_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2005_START, "%Y-%m-%d"):
        return 2005
    elif datetime.strptime(SEASON_2006_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2006_START, "%Y-%m-%d"):
        return 2006
    elif datetime.strptime(SEASON_2007_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2007_START, "%Y-%m-%d"):
        return 2007
    elif datetime.strptime(SEASON_2008_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2008_START, "%Y-%m-%d"):
        return 2008
    elif datetime.strptime(SEASON_2009_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2009_START, "%Y-%m-%d"):
        return 2009
    elif datetime.strptime(SEASON_2010_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2010_START, "%Y-%m-%d"):
        return 2010
    elif datetime.strptime(SEASON_2011_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2011_START, "%Y-%m-%d"):
        return 2011
    elif datetime.strptime(SEASON_2012_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2012_START, "%Y-%m-%d"):
        return 2012
    elif datetime.strptime(SEASON_2013_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2013_START, "%Y-%m-%d"):
        return 2013
    elif datetime.strptime(SEASON_2014_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2014_START, "%Y-%m-%d"):
        return 2014
    elif datetime.strptime(SEASON_2015_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2015_START, "%Y-%m-%d"):
        return 2015
    elif datetime.strptime(SEASON_2016_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2016_START, "%Y-%m-%d"):
        return 2016
    elif datetime.strptime(SEASON_2017_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2017_START, "%Y-%m-%d"):
        return 2017
    elif datetime.strptime(SEASON_2018_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2018_START, "%Y-%m-%d"):
        return 2018
    elif datetime.strptime(SEASON_2019_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2019_START, "%Y-%m-%d"):
        return 2019
    elif datetime.strptime(SEASON_2020_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2020_START, "%Y-%m-%d"):
        return 2020
    elif datetime.strptime(SEASON_2021_END, "%Y-%m-%d") > row['DATE'] > datetime.strptime(SEASON_2021_START, "%Y-%m-%d"):
        return 2021

# %%
NBA_since_2000['Season'] = NBA_since_2000.apply(season_row,axis=1)


NBA_since_2000.columns
# Out:
# Index(['DATE', 'AGE', 'TEAM', 'HOME/AWAY', 'OPPONENT', 'RESULT', 'GS', 'MP',
#        'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GAME_SCORE',
#        '+/-', 'Player', 'Season'],
#       dtype='object')

# %%
NBA_since_2000.head(50)
# Out:
#         DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0 2006-01-22  27-152  LAL      HOME      TOR  W (+18)   1  41:56  28   46
# 0 2018-01-30  28-157  HOU      HOME      ORL   W (+7)   1  46:26  19   30
# 0 2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0 2017-11-03  32-308  CLE      AWAY      WAS   W (+8)   1  42:41  23   34
# 0 2019-11-30  30-096  HOU      HOME      ATL  W (+47)   1  30:41  16   24
# 0 2019-02-28  29-186  HOU      HOME      MIA   W (+3)   1  43:52  16   32
# 0 2017-01-02  27-110  CHI      HOME      CHO   W (+7)   1  38:19  15   24
# 0 2007-03-16  28-205  LAL      HOME      POR   W (+5)   1  49:58  23   39
# 0 2021-02-19  26-340  PHI      HOME      CHI   W (+7)   1  35:16  17   26
# 0 2020-08-11  30-027  POR      AWAY      DAL   W (+3)   1  41:05  17   32
# 0 2019-03-17  24-101  MIL      HOME      PHI   L (-5)   1  36:12  15   26
# 0 2021-02-02  26-343  TOR      AWAY      ORL  W (+15)   1  37:06  17   23
# ...
