# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2014-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_NYK = []

# NYK
while season <= 2021:
    df_NYK = get_roster('NYK', season)
    df_NYK['Season'] = season
    df_NYK['Team'] = 'NYK'
    appended_data_NYK.append(df_NYK)
    season = season + 1
appended_data_NYK = pd.concat(appended_data_NYK)

# %%
NYK_df_all = appended_data_NYK.copy()
NYK_df_all_csv = NYK_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_players_all.csv', index=False)
NYK_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_players_all.csv')
NYK_df_all_csv_io.head()
# Out:
#   NUMBER            PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     41  Etdrick Bohannon  PF    6-9     220  1973-05-29          US
# 1      9      Rick Brunson  PG    6-4     190  1972-06-14          US
# 2     23      Marcus Camby   C   6-11     220  1974-03-22          US
# 3      1      Chris Childs  PG    6-3     195  1967-11-20          US
# 4     14      Chris Dudley   C   6-11     235  1965-02-22          US
#
#   EXPERIENCE                                            COLLEGE  Season Team
# 0          2  Arizona, Tennessee, Auburn University at Montg...    2000  NYK
# 1          2                                             Temple    2000  NYK
# 2          3                                              UMass    2000  NYK
# 3          5                                        Boise State    2000  NYK
# 4         12                                               Yale    2000  NYK

# %%
NYK_df_2000 = NYK_df_all[NYK_df_all['Season'] == 2000]
NYK_df_2001 = NYK_df_all[NYK_df_all['Season'] == 2001]
NYK_df_2002 = NYK_df_all[NYK_df_all['Season'] == 2002]
NYK_df_2003 = NYK_df_all[NYK_df_all['Season'] == 2003]
NYK_df_2004 = NYK_df_all[NYK_df_all['Season'] == 2004]
NYK_df_2005 = NYK_df_all[NYK_df_all['Season'] == 2005]
NYK_df_2006 = NYK_df_all[NYK_df_all['Season'] == 2006]
NYK_df_2007 = NYK_df_all[NYK_df_all['Season'] == 2007]
NYK_df_2008 = NYK_df_all[NYK_df_all['Season'] == 2008]
NYK_df_2009 = NYK_df_all[NYK_df_all['Season'] == 2009]
NYK_df_2010 = NYK_df_all[NYK_df_all['Season'] == 2010]
NYK_df_2011 = NYK_df_all[NYK_df_all['Season'] == 2011]
NYK_df_2012 = NYK_df_all[NYK_df_all['Season'] == 2012]
NYK_df_2013 = NYK_df_all[NYK_df_all['Season'] == 2013]
NYK_df_2014 = NYK_df_all[NYK_df_all['Season'] == 2014]
NYK_df_2015 = NYK_df_all[NYK_df_all['Season'] == 2015]
NYK_df_2016 = NYK_df_all[NYK_df_all['Season'] == 2016]
NYK_df_2017 = NYK_df_all[NYK_df_all['Season'] == 2017]
NYK_df_2018 = NYK_df_all[NYK_df_all['Season'] == 2018]
NYK_df_2019 = NYK_df_all[NYK_df_all['Season'] == 2019]
NYK_df_2020 = NYK_df_all[NYK_df_all['Season'] == 2020]
NYK_df_2021 = NYK_df_all[NYK_df_all['Season'] == 2021]

# %%
# changing names
#NYK_df_2002.loc[NYK_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#NYK_df_2004.loc[NYK_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
NYK_df_2000_players = NYK_df_2000['PLAYER'].to_list()
NYK_df_2001_players = NYK_df_2001['PLAYER'].to_list()
NYK_df_2002_players = NYK_df_2002['PLAYER'].to_list()
NYK_df_2003_players = NYK_df_2003['PLAYER'].to_list()
NYK_df_2004_players = NYK_df_2004['PLAYER'].to_list()
NYK_df_2005_players = NYK_df_2005['PLAYER'].to_list()

NYK_df_2006_players = NYK_df_2006['PLAYER'].to_list()
NYK_df_2007_players = NYK_df_2007['PLAYER'].to_list()
NYK_df_2008_players = NYK_df_2008['PLAYER'].to_list()
NYK_df_2009_players = NYK_df_2009['PLAYER'].to_list()
NYK_df_2010_players = NYK_df_2010['PLAYER'].to_list()
NYK_df_2011_players = NYK_df_2011['PLAYER'].to_list()

NYK_df_2012_players = NYK_df_2012['PLAYER'].to_list()
NYK_df_2013_players = NYK_df_2013['PLAYER'].to_list()
NYK_df_2014_players = NYK_df_2014['PLAYER'].to_list()
NYK_df_2015_players = NYK_df_2015['PLAYER'].to_list()
NYK_df_2016_players = NYK_df_2016['PLAYER'].to_list()
NYK_df_2017_players = NYK_df_2017['PLAYER'].to_list()

NYK_df_2018_players = NYK_df_2018['PLAYER'].to_list()
NYK_df_2019_players = NYK_df_2019['PLAYER'].to_list()
NYK_df_2020_players = NYK_df_2020['PLAYER'].to_list()
NYK_df_2021_players = NYK_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#NYK_df_2000_players.remove("Larry Johnson")
#NYK_df_2001_players.remove("Larry Johnson")
#NYK_df_2006_players.remove("David Lee")
#NYK_df_2007_players.remove("David Lee")
#NYK_df_2008_players.remove("David Lee")
#NYK_df_2009_players.remove("David Lee")
#NYK_df_2010_players.remove("David Lee")
#NYK_df_2009_players.remove("Mouhamed Sene")
#NYK_df_2010_players.remove("Henry Walker")
#NYK_df_2011_players.remove("Henry Walker")
#NYK_df_2012_players.remove("Henry Walker")
#NYK_df_2014_players.remove("Chris Smith")
#NYK_df_2014_players.remove("Metta World Peace")
#NYK_df_2016_players.remove("Kyle O'Quinn")
#NYK_df_2017_players.remove("Kyle O'Quinn")
#NYK_df_2018_players.remove("Kyle O'Quinn")
#NYK_df_2018_players.remove("Frank Ntilikina")
#NYK_df_2019_players.remove("Frank Ntilikina")
#NYK_df_2020_players.remove("Frank Ntilikina")
#NYK_df_2021_players.remove("Frank Ntilikina")
#NYK_df_2019_players.remove("Dennis Smith")
NYK_df_2020_players.remove("Dennis Smith")
NYK_df_2021_players.remove("Dennis Smith")

# %%
# removed larry johnson
NYK_2000_gamelog = []


for p in NYK_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2000_gamelog.append(player_log)
NYK_2000_gamelog = pd.concat(NYK_2000_gamelog)    
NYK_2000_gamelogs = NYK_2000_gamelog.copy()
NYK_2000_gamelogs['GAME_SCORE'] = NYK_2000_gamelogs['GAME_SCORE'].astype(float)
NYK_2000_games = NYK_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2000_games_csv = NYK_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2000_games.csv', index=False)
NYK_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2000_games.csv')
NYK_2000_games_proc.head()
# Out:
# You searched for "Etdrick Bohannon"
# 1 result found.
# Etdrick Bohannon
# Results for Etdrick Bohannon:
#
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Chris Childs"
# 5 results found.
# 0: Chris Childs
# 1: Chris Mills
# 2: Chris Chiozza
# 3: Chris Silva
# 4: Chris Richard
# Pick one: 0
# Results for Chris Childs:
#
# You searched for "Chris Dudley"
# 8 results found.
# 0: Chris Dudley
# 1: Charles Dudley
# 2: Chris Anstey
# 3: Jared Dudley
# 4: Chris Duhon
# 5: Chris Engler
# 6: Chris Hunter
# 7: Chris Mullin
# Pick one: 0
# Results for Chris Dudley:
#
# You searched for "Patrick Ewing"
# ...

# %%
# removed larry johnson
NYK_2001_gamelog = []


for p in NYK_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2001_gamelog.append(player_log)
NYK_2001_gamelog = pd.concat(NYK_2001_gamelog)    
NYK_2001_gamelogs = NYK_2001_gamelog.copy()
NYK_2001_gamelogs['GAME_SCORE'] = NYK_2001_gamelogs['GAME_SCORE'].astype(float)
NYK_2001_games = NYK_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2001_games_csv = NYK_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2001_games.csv', index=False)
NYK_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2001_games.csv')
NYK_2001_games_proc.head()
# Out:
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Chris Childs"
# 5 results found.
# 0: Chris Childs
# 1: Chris Mills
# 2: Chris Chiozza
# 3: Chris Silva
# 4: Chris Richard
# Pick one: 0
# Results for Chris Childs:
#
# You searched for "Othella Harrington"
# 1 result found.
# Othella Harrington
# Results for Othella Harrington:
#
# You searched for "Allan Houston"
# 3 results found.
# 0: Allan Houston
# 1: Allan Bristow
# 2: Byron Houston
# Pick one: 0
# Results for Allan Houston:
#
# You searched for "Mark Jackson"
# 25 results found.
# 0: Mark Jackson
# 1: Marc Jackson
# 2: Aaron Jackson
# 3: Al Jackson
# ...

# %%
NYK_2002_gamelog = []


for p in NYK_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2002_gamelog.append(player_log)
NYK_2002_gamelog = pd.concat(NYK_2002_gamelog)    
NYK_2002_gamelogs = NYK_2002_gamelog.copy()
NYK_2002_gamelogs['GAME_SCORE'] = NYK_2002_gamelogs['GAME_SCORE'].astype(float)
NYK_2002_games = NYK_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2002_games_csv = NYK_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2002_games.csv', index=False)
NYK_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2002_games.csv')
NYK_2002_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Othella Harrington"
# 1 result found.
# Othella Harrington
# Results for Othella Harrington:
#
# You searched for "Allan Houston"
# 3 results found.
# 0: Allan Houston
# 1: Allan Bristow
# 2: Byron Houston
# Pick one: 0
# Results for Allan Houston:
#
# You searched for "Mark Jackson"
# 25 results found.
# 0: Mark Jackson
# 1: Marc Jackson
# 2: Aaron Jackson
# 3: Al Jackson
# 4: Frank Jackson
# 5: Jaren Jackson
# 6: Jaren Jackson
# 7: Mike Jackson
# 8: Myron Jackson
# 9: Mark Macon
# 10: Mark Eaton
# 11: Greg Jackson
# 12: Jim Jackson
# 13: Josh Jackson
# ...

# %%
    
NYK_2003_gamelog = []



for p in NYK_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2003_gamelog.append(player_log)
NYK_2003_gamelog = pd.concat(NYK_2003_gamelog)    
NYK_2003_gamelogs = NYK_2003_gamelog.copy()
NYK_2003_gamelogs['GAME_SCORE'] = NYK_2003_gamelogs['GAME_SCORE'].astype(float)
NYK_2003_games = NYK_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2003_games_csv = NYK_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2003_games.csv', index=False)
NYK_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2003_games.csv')
NYK_2003_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Othella Harrington"
# 1 result found.
# Othella Harrington
# Results for Othella Harrington:
#
# You searched for "Allan Houston"
# 3 results found.
# 0: Allan Houston
# 1: Allan Bristow
# 2: Byron Houston
# Pick one: 0
# Results for Allan Houston:
#
# You searched for "Travis Knight"
# 3 results found.
# 0: Travis Knight
# 1: Brevin Knight
# 2: Brandin Knight
# Pick one: 0
# Results for Travis Knight:
#
# You searched for "Lee Nailon"
# 2 results found.
# 0: Lee Nailon
# 1: Zeke Nnaji
# Pick one: 0
# ...

# %%
NYK_2004_gamelog = []



for p in NYK_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2004_gamelog.append(player_log)
NYK_2004_gamelog = pd.concat(NYK_2004_gamelog)    
NYK_2004_gamelogs = NYK_2004_gamelog.copy()
NYK_2004_gamelogs['GAME_SCORE'] = NYK_2004_gamelogs['GAME_SCORE'].astype(float)
NYK_2004_games = NYK_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2004_games_csv = NYK_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2004_games.csv', index=False)
NYK_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2004_games.csv')
NYK_2004_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Vin Baker"
# 8 results found.
# 0: Vin Baker
# 1: Ron Baker
# 2: Von Wafer
# 3: Norm Baker
# 4: Tom Barker
# 5: Devin Booker
# 6: Thon Maker
# 7: Zan Tabak
# Pick one: 0
# Results for Vin Baker:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Anfernee Hardaway"
# 1 result found.
# Anfernee Hardaway
# Results for Anfernee Hardaway:
#
# You searched for "Othella Harrington"
# 1 result found.
# Othella Harrington
# Results for Othella Harrington:
#
# You searched for "Allan Houston"
# 3 results found.
# 0: Allan Houston
# ...

# %%
NYK_2005_gamelog = []

for p in NYK_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2005_gamelog.append(player_log)
NYK_2005_gamelog = pd.concat(NYK_2005_gamelog)    
NYK_2005_gamelogs = NYK_2005_gamelog.copy()
NYK_2005_gamelogs['GAME_SCORE'] = NYK_2005_gamelogs['GAME_SCORE'].astype(float)
NYK_2005_games = NYK_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2005_games_csv = NYK_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2005_games.csv', index=False)
NYK_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2005_games.csv')
NYK_2005_games_proc.head()
# Out:
# You searched for "Shandon Anderson"
# 1 result found.
# Shandon Anderson
# Results for Shandon Anderson:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Vin Baker"
# 8 results found.
# 0: Vin Baker
# 1: Ron Baker
# 2: Von Wafer
# 3: Norm Baker
# 4: Tom Barker
# 5: Devin Booker
# 6: Thon Maker
# 7: Zan Tabak
# Pick one: 0
# Results for Vin Baker:
#
# You searched for "Jamison Brewer"
# 1 result found.
# Jamison Brewer
# Results for Jamison Brewer:
#
# You searched for "Jackie Butler"
# 3 results found.
# 0: Jackie Butler
# 1: Mike Butler
# 2: Jackie Ridgle
# Pick one: 0
# Results for Jackie Butler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Anfernee Hardaway"
# 1 result found.
# Anfernee Hardaway
# Results for Anfernee Hardaway:
#
# You searched for "Allan Houston"
# ...

# %%
# removed david Lee
NYK_2006_gamelog = []

for p in NYK_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2006_gamelog.append(player_log)
NYK_2006_gamelog = pd.concat(NYK_2006_gamelog)    
NYK_2006_gamelogs = NYK_2006_gamelog.copy()
NYK_2006_gamelogs['GAME_SCORE'] = NYK_2006_gamelogs['GAME_SCORE'].astype(float)
NYK_2006_games = NYK_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2006_games_csv = NYK_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2006_games.csv', index=False)
NYK_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2006_games.csv')
NYK_2006_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Jackie Butler"
# 3 results found.
# 0: Jackie Butler
# 1: Mike Butler
# 2: Jackie Ridgle
# Pick one: 0
# Results for Jackie Butler:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Antonio Davis"
# 6 results found.
# 0: Antonio Davis
# 1: Antonio Daniels
# 2: Anthony Davis
# 3: Antonio Burks
# 4: Antonio Harvey
# ...

# %%
NYK_2007_gamelog = []

for p in NYK_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2007_gamelog.append(player_log)
NYK_2007_gamelog = pd.concat(NYK_2007_gamelog)    
NYK_2007_gamelogs = NYK_2007_gamelog.copy()
NYK_2007_gamelogs['GAME_SCORE'] = NYK_2007_gamelogs['GAME_SCORE'].astype(float)
NYK_2007_games = NYK_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2007_games_csv = NYK_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2007_games.csv', index=False)
NYK_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2007_games.csv')
NYK_2007_games_proc.head()
# Out:
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Mardy Collins"
# 8 results found.
# 0: Mardy Collins
# 1: Art Collins
# 2: James Collins
# 3: Jarron Collins
# 4: Jason Collins
# 5: Jimmy Collins
# 6: Zach Collins
# 7: Marty Conlon
# Pick one: 0
# Results for Mardy Collins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Steve Francis"
# 3 results found.
# 0: Steve Francis
# 1: Steve Bracey
# 2: Steve Harris
# Pick one: 0
# Results for Steve Francis:
#
# ...

# %%
NYK_2008_gamelog = []

for p in NYK_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2008_gamelog.append(player_log)
NYK_2008_gamelog = pd.concat(NYK_2008_gamelog)    
NYK_2008_gamelogs = NYK_2008_gamelog.copy()
NYK_2008_gamelogs['GAME_SCORE'] = NYK_2008_gamelogs['GAME_SCORE'].astype(float)
NYK_2008_games = NYK_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2008_games_csv = NYK_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2008_games.csv', index=False)
NYK_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2008_games.csv')
NYK_2008_games_proc.head()
# Out:
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Mardy Collins"
# 8 results found.
# 0: Mardy Collins
# 1: Art Collins
# 2: James Collins
# 3: Jarron Collins
# 4: Jason Collins
# 5: Jimmy Collins
# 6: Zach Collins
# 7: Marty Conlon
# Pick one: 0
# Results for Mardy Collins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Jerome James"
# 8 results found.
# 0: Jerome James
# 1: Jerome Lane
# 2: Jerome Allen
# 3: Jerome Harmon
# 4: Aaron James
# 5: Gene James
# 6: LeBron James
# ...

# %%
# removed Mouhamed Sene

NYK_2009_gamelog = []

for p in NYK_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2009_gamelog.append(player_log)
NYK_2009_gamelog = pd.concat(NYK_2009_gamelog)    
NYK_2009_gamelogs = NYK_2009_gamelog.copy()
NYK_2009_gamelogs['GAME_SCORE'] = NYK_2009_gamelogs['GAME_SCORE'].astype(float)
NYK_2009_games = NYK_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2009_games_csv = NYK_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2009_games.csv', index=False)
NYK_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2009_games.csv')
NYK_2009_games_proc.head()
# Out:
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Mardy Collins"
# 8 results found.
# 0: Mardy Collins
# 1: Art Collins
# 2: James Collins
# 3: Jarron Collins
# 4: Jason Collins
# 5: Jimmy Collins
# 6: Zach Collins
# 7: Marty Conlon
# Pick one: 0
# Results for Mardy Collins:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Joe Crawford"
# 4 results found.
# 0: Joe Crawford
# 1: Jamal Crawford
# 2: Jordan Crawford
# 3: Joe Strawder
# Pick one: 0
# Results for Joe Crawford:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# 2: Chris Dudley
# ...

# %%
# henry walker

NYK_2010_gamelog = []

for p in NYK_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2010_gamelog.append(player_log)
NYK_2010_gamelog = pd.concat(NYK_2010_gamelog)    
NYK_2010_gamelogs = NYK_2010_gamelog.copy()
NYK_2010_gamelogs['GAME_SCORE'] = NYK_2010_gamelogs['GAME_SCORE'].astype(float)
NYK_2010_games = NYK_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2010_games_csv = NYK_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2010_games.csv', index=False)
NYK_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2010_games.csv')
NYK_2010_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Jonathan Bender"
# 3 results found.
# 0: Jonathan Bender
# 1: Jonathan Kerner
# 2: Jonathan Gibson
# Pick one: 0
# Results for Jonathan Bender:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Eddy Curry"
# 4 results found.
# 0: Eddy Curry
# 1: Dell Curry
# 2: Seth Curry
# 3: Kenny Carr
# Pick one: 0
# Results for Eddy Curry:
#
# You searched for "Toney Douglas"
# 4 results found.
# 0: Toney Douglas
# 1: John Douglas
# 2: Leon Douglas
# 3: Tony Dumas
# Pick one: 0
# Results for Toney Douglas:
#
# You searched for "Chris Duhon"
# 16 results found.
# 0: Chris Duhon
# 1: Chris Quinn
# ...

# %%
NYK_2011_gamelog = []

for p in NYK_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2011_gamelog.append(player_log)
NYK_2011_gamelog = pd.concat(NYK_2011_gamelog)    
NYK_2011_gamelogs = NYK_2011_gamelog.copy()
NYK_2011_gamelogs['GAME_SCORE'] = NYK_2011_gamelogs['GAME_SCORE'].astype(float)
NYK_2011_games = NYK_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2011_games_csv = NYK_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2011_games.csv', index=False)
NYK_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2011_games.csv')
NYK_2011_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Chauncey Billups"
# 1 result found.
# Chauncey Billups
# Results for Chauncey Billups:
#
# You searched for "Derrick Brown"
# 8 results found.
# 0: Derrick Brown
# 1: Kedrick Brown
# 2: Derrick Rose
# 3: Darrell Brown
# 4: Devin Brown
# 5: Derrick Byars
# 6: Derrick Gervin
# 7: Derrick Rowland
# Pick one: 0
# Results for Derrick Brown:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# ...

# %%
# remvoed j.j. barea

NYK_2012_gamelog = []

for p in NYK_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2012_gamelog.append(player_log)
NYK_2012_gamelog = pd.concat(NYK_2012_gamelog)    
NYK_2012_gamelogs = NYK_2012_gamelog.copy()
NYK_2012_gamelogs['GAME_SCORE'] = NYK_2012_gamelogs['GAME_SCORE'].astype(float)
NYK_2012_games = NYK_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2012_games_csv = NYK_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2012_games.csv', index=False)
NYK_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2012_games.csv')
NYK_2012_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Renaldo Balkman"
# 1 result found.
# Renaldo Balkman
# Results for Renaldo Balkman:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Baron Davis"
# 22 results found.
# 0: Baron Davis
# 1: Ron Davis
# 2: Ben Davis
# 3: Bob Davis
# 4: Brad Davis
# 5: Brian Davis
# 6: Harry Davis
# 7: Mark Davis
# 8: Mark Davis
# 9: Warren Davis
# 10: Bob Davies
# 11: Brandon Davies
# ...

# %%
NYK_2013_gamelog = []

for p in NYK_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2013_gamelog.append(player_log)
NYK_2013_gamelog = pd.concat(NYK_2013_gamelog)    
NYK_2013_gamelogs = NYK_2013_gamelog.copy()
NYK_2013_gamelogs['GAME_SCORE'] = NYK_2013_gamelogs['GAME_SCORE'].astype(float)
NYK_2013_games = NYK_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2013_games_csv = NYK_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2013_games.csv', index=False)
NYK_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2013_games.csv')
NYK_2013_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Chris Copeland"
# 2 results found.
# 0: Chris Copeland
# ...

# %%
# removed chris smith
# removed metta world peace

NYK_2014_gamelog = []

for p in NYK_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2014_gamelog.append(player_log)
NYK_2014_gamelog = pd.concat(NYK_2014_gamelog)    
NYK_2014_gamelogs = NYK_2014_gamelog.copy()
NYK_2014_gamelogs['GAME_SCORE'] = NYK_2014_gamelogs['GAME_SCORE'].astype(float)
NYK_2014_games = NYK_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2014_games_csv = NYK_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2014_games.csv', index=False)
NYK_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2014_games.csv')
NYK_2014_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# 4: Keon Clark
# 5: Earl Evans
# 6: Earl Lloyd
# Pick one: 0
# Results for Earl Clark:
#
# You searched for "Raymond Felton"
# 1 result found.
# Raymond Felton
# Results for Raymond Felton:
#
# You searched for "Tim Hardaway"
# 2 results found.
# 0: Tim Hardaway
# ...

# %%
NYK_2015_gamelog = []

for p in NYK_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2015_gamelog.append(player_log)
NYK_2015_gamelog = pd.concat(NYK_2015_gamelog)    
NYK_2015_gamelogs = NYK_2015_gamelog.copy()
NYK_2015_gamelogs['GAME_SCORE'] = NYK_2015_gamelogs['GAME_SCORE'].astype(float)
NYK_2015_games = NYK_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2015_games_csv = NYK_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2015_games.csv', index=False)
NYK_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2015_games.csv')
NYK_2015_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Cleanthony Early"
# 1 result found.
# Cleanthony Early
# Results for Cleanthony Early:
#
# You searched for "Langston Galloway"
# 1 result found.
# Langston Galloway
# Results for Langston Galloway:
#
# ...

# %%
# removed kyle o'qiuinn

NYK_2016_gamelog = []

for p in NYK_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2016_gamelog.append(player_log)
NYK_2016_gamelog = pd.concat(NYK_2016_gamelog)    
NYK_2016_gamelogs = NYK_2016_gamelog.copy()
NYK_2016_gamelogs['GAME_SCORE'] = NYK_2016_gamelogs['GAME_SCORE'].astype(float)
NYK_2016_games = NYK_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2016_games_csv = NYK_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2016_games.csv', index=False)
NYK_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2016_games.csv')
NYK_2016_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Thanasis Antetokounmpo"
# 2 results found.
# 0: Thanasis Antetokounmpo
# 1: Giannis Antetokounmpo
# Pick one: 0
# Results for Thanasis Antetokounmpo:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Cleanthony Early"
# 1 result found.
# Cleanthony Early
# Results for Cleanthony Early:
#
# You searched for "Jimmer Fredette"
# 1 result found.
# Jimmer Fredette
# Results for Jimmer Fredette:
#
# You searched for "Langston Galloway"
# 1 result found.
# Langston Galloway
# Results for Langston Galloway:
#
# You searched for "Jerian Grant"
# 3 results found.
# ...

# %%
NYK_2017_gamelog = []

for p in NYK_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2017_gamelog.append(player_log)
NYK_2017_gamelog = pd.concat(NYK_2017_gamelog)    
NYK_2017_gamelogs = NYK_2017_gamelog.copy()
NYK_2017_gamelogs['GAME_SCORE'] = NYK_2017_gamelogs['GAME_SCORE'].astype(float)
NYK_2017_games = NYK_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2017_games_csv = NYK_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2017_games.csv', index=False)
NYK_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2017_games.csv')
NYK_2017_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Ron Baker"
# 45 results found.
# 0: Ron Baker
# 1: Vin Baker
# 2: Norm Baker
# 3: Tom Barker
# 4: Ron Brewer
# 5: Ron Carter
# 6: Ron Harper
# 7: Thon Maker
# 8: Von Wafer
# 9: John Barber
# 10: John Barr
# 11: Moe Barr
# 12: Jon Barry
# 13: Aron Baynes
# 14: Moe Becker
# 15: Ron Behagen
# 16: Ron Boone
# 17: Don Boven
# 18: Don Buse
# 19: John Coker
# 20: Ron Davis
# 21: Ron Lee
# 22: Jon Leuer
# 23: Ron Mercer
# 24: Bob Naber
# 25: Tony Parker
# 26: Ron Reed
# 27: Tom Riker
# 28: Ron Riley
# 29: Ron Watts
# 30: Jon Teske
# 31: Don Bielke
# 32: Ron Bonham
# 33: Don Grate
# 34: Ron Horn
# 35: Red Kerr
# 36: Ron King
# 37: Rob Kurz
# 38: Ron Moore
# 39: Ron Rowan
# 40: Ron Sobie
# 41: Ron Widby
# 42: Byron Beck
# 43: Tom Black
# 44: Zan Tabak
# Pick one: 0
# Results for Ron Baker:
#
# You searched for "Willy Hernangómez"
# 1 result found.
# Willy Hernangomez
# ...

# %%
# removed Frank Ntilikina
NYK_2018_gamelog = []

for p in NYK_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2018_gamelog.append(player_log)
NYK_2018_gamelog = pd.concat(NYK_2018_gamelog)    
NYK_2018_gamelogs = NYK_2018_gamelog.copy()
NYK_2018_gamelogs['GAME_SCORE'] = NYK_2018_gamelogs['GAME_SCORE'].astype(float)
NYK_2018_games = NYK_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2018_games_csv = NYK_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2018_games.csv', index=False)
NYK_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2018_games.csv')
NYK_2018_games_proc.head()
# Out:
# You searched for "Ron Baker"
# 45 results found.
# 0: Ron Baker
# 1: Vin Baker
# 2: Norm Baker
# 3: Tom Barker
# 4: Ron Brewer
# 5: Ron Carter
# 6: Ron Harper
# 7: Thon Maker
# 8: Von Wafer
# 9: John Barber
# 10: John Barr
# 11: Moe Barr
# 12: Jon Barry
# 13: Aron Baynes
# 14: Moe Becker
# 15: Ron Behagen
# 16: Ron Boone
# 17: Don Boven
# 18: Don Buse
# 19: John Coker
# 20: Ron Davis
# 21: Ron Lee
# 22: Jon Leuer
# 23: Ron Mercer
# 24: Bob Naber
# 25: Tony Parker
# 26: Ron Reed
# 27: Tom Riker
# 28: Ron Riley
# 29: Ron Watts
# 30: Jon Teske
# 31: Don Bielke
# 32: Ron Bonham
# 33: Don Grate
# 34: Ron Horn
# 35: Red Kerr
# 36: Ron King
# 37: Rob Kurz
# 38: Ron Moore
# 39: Ron Rowan
# 40: Ron Sobie
# 41: Ron Widby
# 42: Byron Beck
# 43: Tom Black
# 44: Zan Tabak
# Pick one: 0
# Results for Ron Baker:
#
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# ...

# %%
# removed dennis smith
NYK_2019_gamelog = []

for p in NYK_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2019_gamelog.append(player_log)
NYK_2019_gamelog = pd.concat(NYK_2019_gamelog)    
NYK_2019_gamelogs = NYK_2019_gamelog.copy()
NYK_2019_gamelogs['GAME_SCORE'] = NYK_2019_gamelogs['GAME_SCORE'].astype(float)
NYK_2019_games = NYK_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2019_games_csv = NYK_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2019_games.csv', index=False)
NYK_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2019_games.csv')
NYK_2019_games_proc.head()
# Out:
# You searched for "Kadeem Allen"
# 1 result found.
# Kadeem Allen
# Results for Kadeem Allen:
#
# You searched for "Ron Baker"
# 45 results found.
# 0: Ron Baker
# 1: Vin Baker
# 2: Norm Baker
# 3: Tom Barker
# 4: Ron Brewer
# 5: Ron Carter
# 6: Ron Harper
# 7: Thon Maker
# 8: Von Wafer
# 9: John Barber
# 10: John Barr
# 11: Moe Barr
# 12: Jon Barry
# 13: Aron Baynes
# 14: Moe Becker
# 15: Ron Behagen
# 16: Ron Boone
# 17: Don Boven
# 18: Don Buse
# 19: John Coker
# 20: Ron Davis
# 21: Ron Lee
# 22: Jon Leuer
# 23: Ron Mercer
# 24: Bob Naber
# 25: Tony Parker
# 26: Ron Reed
# 27: Tom Riker
# 28: Ron Riley
# 29: Ron Watts
# 30: Jon Teske
# 31: Don Bielke
# 32: Ron Bonham
# 33: Don Grate
# 34: Ron Horn
# 35: Red Kerr
# 36: Ron King
# 37: Rob Kurz
# 38: Ron Moore
# 39: Ron Rowan
# 40: Ron Sobie
# 41: Ron Widby
# 42: Byron Beck
# 43: Tom Black
# 44: Zan Tabak
# Pick one: 0
# Results for Ron Baker:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# ...

# %%
NYK_2020_gamelog = []

for p in NYK_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2020_gamelog.append(player_log)
NYK_2020_gamelog = pd.concat(NYK_2020_gamelog)    
NYK_2020_gamelogs = NYK_2020_gamelog.copy()
NYK_2020_gamelogs['GAME_SCORE'] = NYK_2020_gamelogs['GAME_SCORE'].astype(float)
NYK_2020_games = NYK_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2020_games_csv = NYK_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2020_games.csv', index=False)
NYK_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2020_games.csv')
NYK_2020_games_proc.head()
# Out:
# You searched for "Kadeem Allen"
# 1 result found.
# Kadeem Allen
# Results for Kadeem Allen:
#
# You searched for "RJ Barrett"
# 7 results found.
# 0: RJ Barrett
# 1: Jim Barnett
# 2: Andre Barrett
# 3: Ernie Barrett
# 4: Mike Barrett
# 5: Drew Barry
# 6: Rick Barry
# Pick one: 0
# Results for RJ Barrett:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Damyean Dotson"
# 1 result found.
# Damyean Dotson
# Results for Damyean Dotson:
#
# You searched for "Wayne Ellington"
# 1 result found.
# Wayne Ellington
# Results for Wayne Ellington:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# ...

# %%
NYK_2021_gamelog = []

for p in NYK_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    NYK_2021_gamelog.append(player_log)
NYK_2021_gamelog = pd.concat(NYK_2021_gamelog)    
NYK_2021_gamelogs = NYK_2021_gamelog.copy()
NYK_2021_gamelogs['GAME_SCORE'] = NYK_2021_gamelogs['GAME_SCORE'].astype(float)
NYK_2021_games = NYK_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_2021_games_csv = NYK_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2021_games.csv', index=False)
NYK_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2021_games.csv')
NYK_2021_games_proc.head()
# Out:
# You searched for "RJ Barrett"
# 7 results found.
# 0: RJ Barrett
# 1: Jim Barnett
# 2: Andre Barrett
# 3: Ernie Barrett
# 4: Mike Barrett
# 5: Drew Barry
# 6: Rick Barry
# Pick one: 0
# Results for RJ Barrett:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Taj Gibson"
# 5 results found.
# 0: Taj Gibson
# 1: Dee Gibson
# 2: Mel Gibson
# 3: Hoot Gibson
# 4: Mike Gibson
# Pick one: 0
# Results for Taj Gibson:
#
# You searched for "Jared Harper"
# 8 results found.
# 0: Jared Harper
# 1: Derek Harper
# 2: Fred Carter
# 3: Jake Carter
# 4: James Harden
# 5: Mike Harper
# 6: Ron Harper
# 7: Jared Reiner
# Pick one: 0
# Results for Jared Harper:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
NYK_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2000_games.csv')
NYK_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2001_games.csv')
NYK_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2002_games.csv')
NYK_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2003_games.csv')
NYK_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2004_games.csv')
NYK_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2005_games.csv')
NYK_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2006_games.csv')
NYK_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2007_games.csv')
NYK_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2008_games.csv')
NYK_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2009_games.csv')
NYK_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2010_games.csv')
NYK_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2011_games.csv')
NYK_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2012_games.csv')
NYK_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2013_games.csv')
NYK_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2014_games.csv')
NYK_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2015_games.csv')
NYK_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2016_games.csv')
NYK_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2017_games.csv')
NYK_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2018_games.csv')
NYK_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2019_games.csv')
NYK_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2020_games.csv')
NYK_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/NYK/NYK_2021_games.csv')

# %%
NYK_season_dfs = [NYK_2000_games_io, NYK_2001_games_io, NYK_2002_games_io, NYK_2003_games_io, NYK_2004_games_io, NYK_2005_games_io,
                 NYK_2006_games_io, NYK_2007_games_io, NYK_2008_games_io, NYK_2009_games_io, NYK_2010_games_io, NYK_2011_games_io,
                 NYK_2012_games_io, NYK_2013_games_io, NYK_2014_games_io, NYK_2015_games_io, NYK_2016_games_io, NYK_2017_games_io,
                 NYK_2018_games_io, NYK_2019_games_io, NYK_2020_games_io, NYK_2021_games_io]

# %%
NYK_all = pd.concat(NYK_season_dfs)
NYK_all_sorted = NYK_all.sort_values(by=['GAME_SCORE'], ascending=False)
NYK_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2014-01-24  29-240  NYK      HOME      CHA  W (+29)   1  38:39  23   35
# 0  2014-01-24  29-240  NYK      HOME      CHA  W (+29)   1  38:39  23   35
# 0  2003-02-16  31-302  NYK      AWAY      LAL   W (+7)   1  43:29  18   29
# 1  2013-04-02  28-308  NYK      AWAY      MIA  W (+12)   1  40:20  18   26
# 0  2011-02-07  26-254  DEN      HOME      HOU   L (-5)   1  39:28  16   24
# 0  2003-12-29  26-312  PHO      AWAY      LAC   W (+8)   1  41:46  15   23
# 0  2008-12-20  28-275  GSW      AWAY      CHA   W (+7)   1  45:51  14   26
# 0  2007-01-26  26-312  NYK      HOME      MIA  W (+20)   1  39:29  20   30
# 1  2011-02-06  28-082  NYK      HOME      PHI  W (+14)   1  36:27  17   21
# 1  2003-03-16  31-330  NYK      HOME      MIL   W (+9)   1  44:17  13   25
# 1  2007-04-07  24-123  NYK      AWAY      MIL   W (+5)   1  50:10  17   20
# ...
