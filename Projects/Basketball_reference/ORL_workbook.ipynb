# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_ORL = []

# ORL
while season <= 2021:
    df_ORL = get_roster('ORL', season)
    df_ORL['Season'] = season
    df_ORL['Team'] = 'ORL'
    appended_data_ORL.append(df_ORL)
    season = season + 1
appended_data_ORL = pd.concat(appended_data_ORL)

# %%
ORL_df_all = appended_data_ORL.copy()
ORL_df_all_csv = ORL_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_players_all.csv', index=False)
ORL_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_players_all.csv')
ORL_df_all_csv_io.head()
# Out:
#   NUMBER             PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      9  Tariq Abdul-Wahad  SG    6-6     223  1974-11-03          FR
# 1     13       John Amaechi   C   6-10     270  1970-11-26          US
# 2     10  Darrell Armstrong  PG    6-0     170  1968-06-22          US
# 3     31      Chucky Atkins  PG   5-11     160  1974-08-14          US
# 4     11       Earl Boykins  PG    5-5     135  1976-06-02          US
#
#   EXPERIENCE                        COLLEGE  Season Team
# 0          2       Michigan, San Jose State    2000  ORL
# 1          1         Vanderbilt, Penn State    2000  ORL
# 2          5  Fayetteville State University    2000  ORL
# 3          R                  South Florida    2000  ORL
# 4          1               Eastern Michigan    2000  ORL

# %%
ORL_df_2000 = ORL_df_all[ORL_df_all['Season'] == 2000]
ORL_df_2001 = ORL_df_all[ORL_df_all['Season'] == 2001]
ORL_df_2002 = ORL_df_all[ORL_df_all['Season'] == 2002]
ORL_df_2003 = ORL_df_all[ORL_df_all['Season'] == 2003]
ORL_df_2004 = ORL_df_all[ORL_df_all['Season'] == 2004]
ORL_df_2005 = ORL_df_all[ORL_df_all['Season'] == 2005]
ORL_df_2006 = ORL_df_all[ORL_df_all['Season'] == 2006]
ORL_df_2007 = ORL_df_all[ORL_df_all['Season'] == 2007]
ORL_df_2008 = ORL_df_all[ORL_df_all['Season'] == 2008]
ORL_df_2009 = ORL_df_all[ORL_df_all['Season'] == 2009]
ORL_df_2010 = ORL_df_all[ORL_df_all['Season'] == 2010]
ORL_df_2011 = ORL_df_all[ORL_df_all['Season'] == 2011]
ORL_df_2012 = ORL_df_all[ORL_df_all['Season'] == 2012]
ORL_df_2013 = ORL_df_all[ORL_df_all['Season'] == 2013]
ORL_df_2014 = ORL_df_all[ORL_df_all['Season'] == 2014]
ORL_df_2015 = ORL_df_all[ORL_df_all['Season'] == 2015]
ORL_df_2016 = ORL_df_all[ORL_df_all['Season'] == 2016]
ORL_df_2017 = ORL_df_all[ORL_df_all['Season'] == 2017]
ORL_df_2018 = ORL_df_all[ORL_df_all['Season'] == 2018]
ORL_df_2019 = ORL_df_all[ORL_df_all['Season'] == 2019]
ORL_df_2020 = ORL_df_all[ORL_df_all['Season'] == 2020]
ORL_df_2021 = ORL_df_all[ORL_df_all['Season'] == 2021]

# %%
# changing names
#ORL_df_2002.loc[ORL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#ORL_df_2004.loc[ORL_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
ORL_df_2000_players = ORL_df_2000['PLAYER'].to_list()
ORL_df_2001_players = ORL_df_2001['PLAYER'].to_list()
ORL_df_2002_players = ORL_df_2002['PLAYER'].to_list()
ORL_df_2003_players = ORL_df_2003['PLAYER'].to_list()
ORL_df_2004_players = ORL_df_2004['PLAYER'].to_list()
ORL_df_2005_players = ORL_df_2005['PLAYER'].to_list()

ORL_df_2006_players = ORL_df_2006['PLAYER'].to_list()
ORL_df_2007_players = ORL_df_2007['PLAYER'].to_list()
ORL_df_2008_players = ORL_df_2008['PLAYER'].to_list()
ORL_df_2009_players = ORL_df_2009['PLAYER'].to_list()
ORL_df_2010_players = ORL_df_2010['PLAYER'].to_list()
ORL_df_2011_players = ORL_df_2011['PLAYER'].to_list()

ORL_df_2012_players = ORL_df_2012['PLAYER'].to_list()
ORL_df_2013_players = ORL_df_2013['PLAYER'].to_list()
ORL_df_2014_players = ORL_df_2014['PLAYER'].to_list()
ORL_df_2015_players = ORL_df_2015['PLAYER'].to_list()
ORL_df_2016_players = ORL_df_2016['PLAYER'].to_list()
ORL_df_2017_players = ORL_df_2017['PLAYER'].to_list()

ORL_df_2018_players = ORL_df_2018['PLAYER'].to_list()
ORL_df_2019_players = ORL_df_2019['PLAYER'].to_list()
ORL_df_2020_players = ORL_df_2020['PLAYER'].to_list()
ORL_df_2021_players = ORL_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#ORL_df_2000_players.remove("Larry Johnson")
#ORL_df_2005_players.remove("Kiwane Garris")
#ORL_df_2005_players.remove("Mark Jones")
#ORL_df_2013_players.remove("E'Twaun Moore")
#ORL_df_2013_players.remove("Kyle O'Quinn")
#ORL_df_2014_players.remove("Kyle O'Quinn")
#ORL_df_2015_players.remove("Kyle O'Quinn")
#ORL_df_2014_players.remove("E'Twaun Moore")
#ORL_df_2019_players.remove("Mohamed Bamba")
#ORL_df_2020_players.remove("Mohamed Bamba")
#ORL_df_2021_players.remove("Mohamed Bamba")
#ORL_df_2021_players.remove("Wendell Carter")
#ORL_df_2021_players.remove("Robert Franks")
ORL_df_2021_players.remove("Frank Mason")

# %%
# removed Kiwane Garris
ORL_2000_gamelog = []


for p in ORL_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2000_gamelog.append(player_log)
ORL_2000_gamelog = pd.concat(ORL_2000_gamelog)    
ORL_2000_gamelogs = ORL_2000_gamelog.copy()
ORL_2000_gamelogs['GAME_SCORE'] = ORL_2000_gamelogs['GAME_SCORE'].astype(float)
ORL_2000_games = ORL_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2000_games_csv = ORL_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2000_games.csv', index=False)
ORL_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2000_games.csv')
ORL_2000_games_proc.head()
# Out:
# You searched for "Tariq Abdul-Wahad"
# 1 result found.
# Tariq Abdul-Wahad
# Results for Tariq Abdul-Wahad:
#
# You searched for "John Amaechi"
# 6 results found.
# 0: John Amaechi
# 1: John Janisch
# 2: John Lambert
# 3: John Mandic
# 4: John Wallace
# 5: John Shumate
# Pick one: 0
# Results for John Amaechi:
#
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Michael Doleac"
# 8 results found.
# 0: Michael Doleac
# 1: Michael Holton
# 2: Michael Jordan
# 3: Michael Wiley
# 4: Michael Ansley
# 5: Michael Cooper
# 6: Michael Finley
# 7: Michael Porter
# Pick one: 0
# Results for Michael Doleac:
#
# You searched for "Pat Garrity"
# 1 result found.
# Pat Garrity
# Results for Pat Garrity:
#
# ...

# %%
ORL_2001_gamelog = []


for p in ORL_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2001_gamelog.append(player_log)
ORL_2001_gamelog = pd.concat(ORL_2001_gamelog)    
ORL_2001_gamelogs = ORL_2001_gamelog.copy()
ORL_2001_gamelogs['GAME_SCORE'] = ORL_2001_gamelogs['GAME_SCORE'].astype(float)
ORL_2001_games = ORL_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2001_games_csv = ORL_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2001_games.csv', index=False)
ORL_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2001_games.csv')
ORL_2001_games_proc.head()
# Out:
# You searched for "Cory Alexander"
# 7 results found.
# 0: Cory Alexander
# 1: Gary Alexander
# 2: Joe Alexander
# 3: Cliff Alexander
# 4: Courtney Alexander
# 5: Kyle Alexander
# 6: Victor Alexander
# Pick one: 0
# Results for Cory Alexander:
#
# You searched for "John Amaechi"
# 6 results found.
# 0: John Amaechi
# 1: John Janisch
# 2: John Lambert
# 3: John Mandic
# 4: John Wallace
# 5: John Shumate
# Pick one: 0
# Results for John Amaechi:
#
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Dee Brown"
# 24 results found.
# 0: Dee Brown
# 1: Dee Brown
# 2: Andre Brown
# 3: Bob Brown
# 4: Devin Brown
# 5: Fred Brown
# 6: Leon Brown
# 7: Mike Brown
# 8: Bruce Brown
# 9: Damone Brown
# 10: George Brown
# 11: John Brown
# 12: Kwame Brown
# 13: Lewis Brown
# 14: Moses Brown
# 15: P.J. Brown
# 16: Roger Brown
# 17: Roger Brown
# 18: Stan Brown
# 19: Tierre Brown
# 20: Tony Brown
# 21: Troy Brown
# ...

# %%
ORL_2002_gamelog = []


for p in ORL_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2002_gamelog.append(player_log)
ORL_2002_gamelog = pd.concat(ORL_2002_gamelog)    
ORL_2002_gamelogs = ORL_2002_gamelog.copy()
ORL_2002_gamelogs['GAME_SCORE'] = ORL_2002_gamelogs['GAME_SCORE'].astype(float)
ORL_2002_games = ORL_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2002_games_csv = ORL_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2002_games.csv', index=False)
ORL_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2002_games.csv')
ORL_2002_games_proc.head()
# Out:
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Dee Brown"
# 24 results found.
# 0: Dee Brown
# 1: Dee Brown
# 2: Andre Brown
# 3: Bob Brown
# 4: Devin Brown
# 5: Fred Brown
# 6: Leon Brown
# 7: Mike Brown
# 8: Bruce Brown
# 9: Damone Brown
# 10: George Brown
# 11: John Brown
# 12: Kwame Brown
# 13: Lewis Brown
# 14: Moses Brown
# 15: P.J. Brown
# 16: Roger Brown
# 17: Roger Brown
# 18: Stan Brown
# 19: Tierre Brown
# 20: Tony Brown
# 21: Troy Brown
# 22: Jim Browne
# 23: Dee Gibson
# Pick one: 0
# Results for Dee Brown:
#
# You searched for "Jud Buechler"
# 1 result found.
# Jud Buechler
# Results for Jud Buechler:
#
# You searched for "Andrew DeClercq"
# 1 result found.
# Andrew DeClercq
# Results for Andrew DeClercq:
#
# You searched for "Patrick Ewing"
# 4 results found.
# 0: Patrick Ewing
# 1: Patrick Ewing
# 2: Patrick Eddie
# 3: Patrick McCaw
# Pick one: 0
# Results for Patrick Ewing:
#
# ...

# %%
    
ORL_2003_gamelog = []



for p in ORL_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2003_gamelog.append(player_log)
ORL_2003_gamelog = pd.concat(ORL_2003_gamelog)    
ORL_2003_gamelogs = ORL_2003_gamelog.copy()
ORL_2003_gamelogs['GAME_SCORE'] = ORL_2003_gamelogs['GAME_SCORE'].astype(float)
ORL_2003_games = ORL_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2003_games_csv = ORL_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2003_games.csv', index=False)
ORL_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2003_games.csv')
ORL_2003_games_proc.head()
# Out:
# You searched for "Darrell Armstrong"
# 1 result found.
# Darrell Armstrong
# Results for Darrell Armstrong:
#
# You searched for "Pat Burke"
# 7 results found.
# 0: Pat Burke
# 1: Walt Budko
# 2: Trey Burke
# 3: Pat Dunn
# 4: Pat Durham
# 5: Pat Frink
# 6: Walt Kirk
# Pick one: 0
# Results for Pat Burke:
#
# You searched for "Andrew DeClercq"
# 1 result found.
# Andrew DeClercq
# Results for Andrew DeClercq:
#
# You searched for "Pat Garrity"
# 1 result found.
# Pat Garrity
# Results for Pat Garrity:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Horace Grant"
# 3 results found.
# 0: Horace Grant
# 1: Harvey Grant
# 2: Jerami Grant
# Pick one: 0
# Results for Horace Grant:
#
# You searched for "Grant Hill"
# 8 results found.
# 0: Grant Hill
# 1: Grant Riller
# ...

# %%
ORL_2004_gamelog = []



for p in ORL_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2004_gamelog.append(player_log)
ORL_2004_gamelog = pd.concat(ORL_2004_gamelog)    
ORL_2004_gamelogs = ORL_2004_gamelog.copy()
ORL_2004_gamelogs['GAME_SCORE'] = ORL_2004_gamelogs['GAME_SCORE'].astype(float)
ORL_2004_games = ORL_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2004_games_csv = ORL_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2004_games.csv', index=False)
ORL_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2004_games.csv')
ORL_2004_games_proc.head()
# Out:
# You searched for "Robert Archibald"
# 1 result found.
# Robert Archibald
# Results for Robert Archibald:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Andrew DeClercq"
# 1 result found.
# Andrew DeClercq
# Results for Andrew DeClercq:
#
# You searched for "Derrick Dial"
# 4 results found.
# 0: Derrick Dial
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick White
# Pick one: 0
# Results for Derrick Dial:
#
# You searched for "Reece Gaines"
# 1 result found.
# Reece Gaines
# Results for Reece Gaines:
#
# You searched for "Pat Garrity"
# 1 result found.
# Pat Garrity
# Results for Pat Garrity:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# ...

# %%
# removed mark jones
ORL_2005_gamelog = []



for p in ORL_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2005_gamelog.append(player_log)
ORL_2005_gamelog = pd.concat(ORL_2005_gamelog)    
ORL_2005_gamelogs = ORL_2005_gamelog.copy()
ORL_2005_gamelogs['GAME_SCORE'] = ORL_2005_gamelogs['GAME_SCORE'].astype(float)
ORL_2005_games = ORL_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2005_games_csv = ORL_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2005_games.csv', index=False)
ORL_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2005_games.csv')
ORL_2005_games_proc.head()
# Out:
# You searched for "Stacey Augmon"
# 1 result found.
# Stacey Augmon
# Results for Stacey Augmon:
#
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Doug Christie"
# 2 results found.
# ...

# %%
ORL_2006_gamelog = []

for p in ORL_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2006_gamelog.append(player_log)
ORL_2006_gamelog = pd.concat(ORL_2006_gamelog)    
ORL_2006_gamelogs = ORL_2006_gamelog.copy()
ORL_2006_gamelogs['GAME_SCORE'] = ORL_2006_gamelogs['GAME_SCORE'].astype(float)
ORL_2006_games = ORL_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2006_games_csv = ORL_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2006_games.csv', index=False)
ORL_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2006_games.csv')
ORL_2006_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Stacey Augmon"
# 1 result found.
# Stacey Augmon
# Results for Stacey Augmon:
#
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Kelvin Cato"
# 4 results found.
# 0: Kelvin Cato
# 1: Calvin Natt
# 2: Kevin Knox
# 3: Kevin Love
# Pick one: 0
# Results for Kelvin Cato:
#
# You searched for "Travis Diener"
# 4 results found.
# 0: Travis Diener
# 1: Travis Wear
# 2: Travis Hansen
# 3: Travis Leslie
# Pick one: 0
# Results for Travis Diener:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# ...

# %%
ORL_2007_gamelog = []

for p in ORL_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2007_gamelog.append(player_log)
ORL_2007_gamelog = pd.concat(ORL_2007_gamelog)    
ORL_2007_gamelogs = ORL_2007_gamelog.copy()
ORL_2007_gamelogs['GAME_SCORE'] = ORL_2007_gamelogs['GAME_SCORE'].astype(float)
ORL_2007_games = ORL_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2007_games_csv = ORL_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2007_games.csv', index=False)
ORL_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2007_games.csv')
ORL_2007_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "James Augustine"
# 1 result found.
# James Augustine
# Results for James Augustine:
#
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Travis Diener"
# 4 results found.
# 0: Travis Diener
# 1: Travis Wear
# 2: Travis Hansen
# 3: Travis Leslie
# Pick one: 0
# Results for Travis Diener:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# ...

# %%
ORL_2008_gamelog = []

for p in ORL_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2008_gamelog.append(player_log)
ORL_2008_gamelog = pd.concat(ORL_2008_gamelog)    
ORL_2008_gamelogs = ORL_2008_gamelog.copy()
ORL_2008_gamelogs['GAME_SCORE'] = ORL_2008_gamelogs['GAME_SCORE'].astype(float)
ORL_2008_games = ORL_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2008_games_csv = ORL_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2008_games.csv', index=False)
ORL_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2008_games.csv')
ORL_2008_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "James Augustine"
# 1 result found.
# James Augustine
# Results for James Augustine:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Keyon Dooling"
# 1 result found.
# Keyon Dooling
# Results for Keyon Dooling:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# ...

# %%
ORL_2009_gamelog = []

for p in ORL_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2009_gamelog.append(player_log)
ORL_2009_gamelog = pd.concat(ORL_2009_gamelog)    
ORL_2009_gamelogs = ORL_2009_gamelog.copy()
ORL_2009_gamelogs['GAME_SCORE'] = ORL_2009_gamelogs['GAME_SCORE'].astype(float)
ORL_2009_games = ORL_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2009_games_csv = ORL_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2009_games.csv', index=False)
ORL_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2009_games.csv')
ORL_2009_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Adonal Foyle"
# 2 results found.
# 0: Adonal Foyle
# 1: Donald Royal
# Pick one: 0
# Results for Adonal Foyle:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# ...

# %%
ORL_2010_gamelog = []

for p in ORL_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2010_gamelog.append(player_log)
ORL_2010_gamelog = pd.concat(ORL_2010_gamelog)    
ORL_2010_gamelogs = ORL_2010_gamelog.copy()
ORL_2010_gamelogs['GAME_SCORE'] = ORL_2010_gamelogs['GAME_SCORE'].astype(float)
ORL_2010_games = ORL_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2010_games_csv = ORL_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2010_games.csv', index=False)
ORL_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2010_games.csv')
ORL_2010_games_proc.head()
# Out:
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# ...

# %%
ORL_2011_gamelog = []

for p in ORL_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2011_gamelog.append(player_log)
ORL_2011_gamelog = pd.concat(ORL_2011_gamelog)    
ORL_2011_gamelogs = ORL_2011_gamelog.copy()
ORL_2011_gamelogs['GAME_SCORE'] = ORL_2011_gamelogs['GAME_SCORE'].astype(float)
ORL_2011_games = ORL_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2011_games_csv = ORL_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2011_games.csv', index=False)
ORL_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2011_games.csv')
ORL_2011_games_proc.head()
# Out:
# You searched for "Malik Allen"
# 10 results found.
# 0: Malik Allen
# 1: Bill Allen
# 2: Lavoy Allen
# 3: Randy Allen
# 4: Ray Allen
# 5: Willie Allen
# 6: Malik Beasley
# 7: Malik Rose
# 8: Malik Monk
# 9: Malik Sealy
# Pick one: 0
# Results for Malik Allen:
#
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Brandon Bass"
# 5 results found.
# 0: Brandon Bass
# 1: Brandon Paul
# 2: Brandon Rush
# 3: Brandon Davies
# 4: Brandon Roy
# Pick one: 0
# Results for Brandon Bass:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# ...

# %%
ORL_2012_gamelog = []

for p in ORL_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2012_gamelog.append(player_log)
ORL_2012_gamelog = pd.concat(ORL_2012_gamelog)    
ORL_2012_gamelogs = ORL_2012_gamelog.copy()
ORL_2012_gamelogs['GAME_SCORE'] = ORL_2012_gamelogs['GAME_SCORE'].astype(float)
ORL_2012_games = ORL_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2012_games_csv = ORL_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2012_games.csv', index=False)
ORL_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2012_games.csv')
ORL_2012_games_proc.head()
# Out:
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# 4: Keon Clark
# 5: Earl Evans
# 6: Earl Lloyd
# Pick one: 0
# Results for Earl Clark:
#
# You searched for "Glen Davis"
# 28 results found.
# 0: Glen Davis
# 1: Ben Davis
# 2: Lee Davis
# 3: Dale Davis
# 4: Ed Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Tyler Davis
# 9: Glen Combs
# 10: Baron Davis
# 11: Bill Davis
# 12: Bob Davis
# 13: Brad Davis
# 14: Brian Davis
# 15: Jim Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# ...

# %%
# removed E'Twaun Moore
# Kyle O'Quinn
ORL_2013_gamelog = []

for p in ORL_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2013_gamelog.append(player_log)
ORL_2013_gamelog = pd.concat(ORL_2013_gamelog)    
ORL_2013_gamelogs = ORL_2013_gamelog.copy()
ORL_2013_gamelogs['GAME_SCORE'] = ORL_2013_gamelogs['GAME_SCORE'].astype(float)
ORL_2013_games = ORL_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2013_games_csv = ORL_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2013_games.csv', index=False)
ORL_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2013_games.csv')
ORL_2013_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Gustavo Ayón"
# 1 result found.
# Gustavo Ayon
# Results for Gustavo Ayon:
#
# You searched for "Glen Davis"
# 28 results found.
# 0: Glen Davis
# 1: Ben Davis
# 2: Lee Davis
# 3: Dale Davis
# 4: Ed Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Tyler Davis
# 9: Glen Combs
# 10: Baron Davis
# 11: Bill Davis
# 12: Bob Davis
# 13: Brad Davis
# 14: Brian Davis
# 15: Jim Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Ralph Davis
# 23: Walt Davis
# 24: Walter Davis
# 25: Warren Davis
# 26: Glen Rice
# 27: Glen Rice
# Pick one: 0
# Results for Glen Davis:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# 1: Maurice McHartley
# Pick one: 0
# Results for Maurice Harkless:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# ...

# %%
# removed etwan moore

ORL_2014_gamelog = []

for p in ORL_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2014_gamelog.append(player_log)
ORL_2014_gamelog = pd.concat(ORL_2014_gamelog)    
ORL_2014_gamelogs = ORL_2014_gamelog.copy()
ORL_2014_gamelogs['GAME_SCORE'] = ORL_2014_gamelogs['GAME_SCORE'].astype(float)
ORL_2014_games = ORL_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2014_games_csv = ORL_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2014_games.csv', index=False)
ORL_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2014_games.csv')
ORL_2014_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Glen Davis"
# 28 results found.
# 0: Glen Davis
# 1: Ben Davis
# 2: Lee Davis
# 3: Dale Davis
# 4: Ed Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Tyler Davis
# 9: Glen Combs
# 10: Baron Davis
# 11: Bill Davis
# 12: Bob Davis
# 13: Brad Davis
# 14: Brian Davis
# 15: Jim Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Ralph Davis
# 23: Walt Davis
# 24: Walter Davis
# 25: Warren Davis
# 26: Glen Rice
# 27: Glen Rice
# Pick one: 0
# Results for Glen Davis:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# 1: Maurice McHartley
# Pick one: 0
# Results for Maurice Harkless:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# ...

# %%
ORL_2015_gamelog = []

for p in ORL_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2015_gamelog.append(player_log)
ORL_2015_gamelog = pd.concat(ORL_2015_gamelog)    
ORL_2015_gamelogs = ORL_2015_gamelog.copy()
ORL_2015_gamelogs['GAME_SCORE'] = ORL_2015_gamelogs['GAME_SCORE'].astype(float)
ORL_2015_games = ORL_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2015_games_csv = ORL_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2015_games.csv', index=False)
ORL_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2015_games.csv')
ORL_2015_games_proc.head()
# Out:
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# You searched for "Aaron Gordon"
# 6 results found.
# 0: Aaron Gordon
# 1: Ben Gordon
# 2: Drew Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Aaron Gray
# Pick one: 0
# Results for Aaron Gordon:
#
# You searched for "Ben Gordon"
# 9 results found.
# 0: Ben Gordon
# 1: Drew Gordon
# 2: Aaron Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Ken Green
# 6: Ed Horton
# 7: Ken Norman
# 8: Ben Moore
# Pick one: 0
# Results for Ben Gordon:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# ...

# %%
# removed kyle o'qiuinn

ORL_2016_gamelog = []

for p in ORL_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2016_gamelog.append(player_log)
ORL_2016_gamelog = pd.concat(ORL_2016_gamelog)    
ORL_2016_gamelogs = ORL_2016_gamelog.copy()
ORL_2016_gamelogs['GAME_SCORE'] = ORL_2016_gamelogs['GAME_SCORE'].astype(float)
ORL_2016_games = ORL_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2016_games_csv = ORL_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2016_games.csv', index=False)
ORL_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2016_games.csv')
ORL_2016_games_proc.head()
# Out:
# You searched for "Keith Appling"
# 2 results found.
# 0: Keith Appling
# 1: Keith Askins
# Pick one: 0
# Results for Keith Appling:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# You searched for "Aaron Gordon"
# 6 results found.
# 0: Aaron Gordon
# 1: Ben Gordon
# 2: Drew Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Aaron Gray
# Pick one: 0
# Results for Aaron Gordon:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# 2: Bob Harris
# 3: Chris Harris
# 4: Tony Harris
# 5: Bob Harrison
# Pick one: 0
# Results for Tobias Harris:
#
# You searched for "Mario Hezonja"
# 1 result found.
# Mario Hezonja
# Results for Mario Hezonja:
#
# ...

# %%
ORL_2017_gamelog = []

for p in ORL_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2017_gamelog.append(player_log)
ORL_2017_gamelog = pd.concat(ORL_2017_gamelog)    
ORL_2017_gamelogs = ORL_2017_gamelog.copy()
ORL_2017_gamelogs['GAME_SCORE'] = ORL_2017_gamelogs['GAME_SCORE'].astype(float)
ORL_2017_games = ORL_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2017_games_csv = ORL_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2017_games.csv', index=False)
ORL_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2017_games.csv')
ORL_2017_games_proc.head()
# Out:
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Anthony Brown"
# 8 results found.
# 0: Anthony Brown
# 1: Anthony Bowie
# 2: Tony Brown
# 3: Anthony Bonner
# 4: Troy Brown
# 5: Anthony Cook
# 6: Anthony Mason
# 7: Anthony Morrow
# Pick one: 0
# Results for Anthony Brown:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Patricio Garino"
# 1 result found.
# Patricio Garino
# Results for Patricio Garino:
#
# You searched for "Marcus Georges-Hunt"
# 1 result found.
# Marcus Georges-Hunt
# Results for Marcus Georges-Hunt:
#
# You searched for "Aaron Gordon"
# 6 results found.
# 0: Aaron Gordon
# 1: Ben Gordon
# 2: Drew Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Aaron Gray
# Pick one: 0
# ...

# %%
ORL_2018_gamelog = []

for p in ORL_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2018_gamelog.append(player_log)
ORL_2018_gamelog = pd.concat(ORL_2018_gamelog)    
ORL_2018_gamelogs = ORL_2018_gamelog.copy()
ORL_2018_gamelogs['GAME_SCORE'] = ORL_2018_gamelogs['GAME_SCORE'].astype(float)
ORL_2018_games = ORL_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2018_games_csv = ORL_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2018_games.csv', index=False)
ORL_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2018_games.csv')
ORL_2018_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Jamel Artis"
# 5 results found.
# 0: Jamel Artis
# 1: Jalen Harris
# 2: James Ennis
# 3: Jarell Martin
# 4: James Hardy
# Pick one: 0
# Results for Jamel Artis:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Khem Birch"
# 1 result found.
# Khem Birch
# Results for Khem Birch:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Aaron Gordon"
# 6 results found.
# 0: Aaron Gordon
# 1: Ben Gordon
# 2: Drew Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Aaron Gray
# Pick one: 0
# Results for Aaron Gordon:
#
# You searched for "Mario Hezonja"
# 1 result found.
# Mario Hezonja
# ...

# %%
# removed Mohamed Bamba
ORL_2019_gamelog = []

for p in ORL_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2019_gamelog.append(player_log)
ORL_2019_gamelog = pd.concat(ORL_2019_gamelog)    
ORL_2019_gamelogs = ORL_2019_gamelog.copy()
ORL_2019_gamelogs['GAME_SCORE'] = ORL_2019_gamelogs['GAME_SCORE'].astype(float)
ORL_2019_games = ORL_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2019_games_csv = ORL_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2019_games.csv', index=False)
ORL_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2019_games.csv')
ORL_2019_games_proc.head()
# Out:
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Khem Birch"
# 1 result found.
# Khem Birch
# Results for Khem Birch:
#
# You searched for "Isaiah Briscoe"
# 2 results found.
# 0: Isaiah Briscoe
# 1: Isaiah Rider
# Pick one: 0
# Results for Isaiah Briscoe:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Troy Caupain"
# 1 result found.
# Troy Caupain
# Results for Troy Caupain:
#
# You searched for "Evan Fournier"
# 2 results found.
# 0: Evan Fournier
# 1: Evan Turner
# Pick one: 0
# Results for Evan Fournier:
#
# You searched for "Melvin Frazier"
# 1 result found.
# Melvin Frazier
# Results for Melvin Frazier:
#
# You searched for "Aaron Gordon"
# 6 results found.
# 0: Aaron Gordon
# 1: Ben Gordon
# 2: Drew Gordon
# 3: Eric Gordon
# 4: Paul Gordon
# 5: Aaron Gray
# Pick one: 0
# Results for Aaron Gordon:
#
# ...

# %%
ORL_2020_gamelog = []

for p in ORL_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2020_gamelog.append(player_log)
ORL_2020_gamelog = pd.concat(ORL_2020_gamelog)    
ORL_2020_gamelogs = ORL_2020_gamelog.copy()
ORL_2020_gamelogs['GAME_SCORE'] = ORL_2020_gamelogs['GAME_SCORE'].astype(float)
ORL_2020_games = ORL_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2020_games_csv = ORL_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2020_games.csv', index=False)
ORL_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2020_games.csv')
ORL_2020_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Khem Birch"
# 1 result found.
# Khem Birch
# Results for Khem Birch:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Gary Clark"
# 15 results found.
# 0: Gary Clark
# 1: Earl Clark
# 2: Ian Clark
# 3: Gary Alcorn
# 4: Cory Carr
# 5: Carlos Clark
# 6: Keon Clark
# 7: Coty Clarke
# 8: Gary Grant
# 9: Gary Gray
# 10: Gar Heard
# 11: Gary Neal
# 12: Jay Carty
# 13: Gary Keller
# 14: Gary Zeller
# Pick one: 0
# Results for Gary Clark:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# 2: Jamel Artis
# 3: Tyler Ennis
# 4: James Lang
# 5: James Silas
# 6: James Posey
# 7: James White
# 8: James Young
# 9: James Harden
# ...

# %%
ORL_2021_gamelog = []

for p in ORL_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    ORL_2021_gamelog.append(player_log)
ORL_2021_gamelog = pd.concat(ORL_2021_gamelog)    
ORL_2021_gamelogs = ORL_2021_gamelog.copy()
ORL_2021_gamelogs['GAME_SCORE'] = ORL_2021_gamelogs['GAME_SCORE'].astype(float)
ORL_2021_games = ORL_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_2021_games_csv = ORL_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2021_games.csv', index=False)
ORL_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2021_games.csv')
ORL_2021_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Cole Anthony"
# 3 results found.
# 0: Cole Anthony
# 1: Joel Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Cole Anthony:
#
# You searched for "Dwayne Bacon"
# 4 results found.
# 0: Dwayne Bacon
# 1: Dwayne Sutton
# 2: Dwayne Morton
# 3: Wayne Pack
# Pick one: 0
# Results for Dwayne Bacon:
#
# You searched for "Khem Birch"
# 1 result found.
# Khem Birch
# Results for Khem Birch:
#
# You searched for "Jordan Bone"
# 10 results found.
# 0: Jordan Bone
# 1: Jordan Bowden
# 2: Jordan Ford
# 3: Jordan Bell
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Nwora
# 7: Jordan Hill
# 8: Jordan McRae
# 9: Ryan Bowen
# Pick one: 0
# Results for Jordan Bone:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Devin Cannady"
# 2 results found.
# 0: Devin Cannady
# 1: Kevin McKenna
# ...

# %% [markdown]
# ## combine all seasons

# %%
ORL_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2000_games.csv')
ORL_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2001_games.csv')
ORL_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2002_games.csv')
ORL_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2003_games.csv')
ORL_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2004_games.csv')
ORL_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2005_games.csv')
ORL_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2006_games.csv')
ORL_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2007_games.csv')
ORL_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2008_games.csv')
ORL_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2009_games.csv')
ORL_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2010_games.csv')
ORL_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2011_games.csv')
ORL_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2012_games.csv')
ORL_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2013_games.csv')
ORL_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2014_games.csv')
ORL_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2015_games.csv')
ORL_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2016_games.csv')
ORL_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2017_games.csv')
ORL_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2018_games.csv')
ORL_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2019_games.csv')
ORL_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2020_games.csv')
ORL_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/ORL/ORL_2021_games.csv')

# %%
ORL_season_dfs = [ORL_2000_games_io, ORL_2001_games_io, ORL_2002_games_io, ORL_2003_games_io, ORL_2004_games_io, ORL_2005_games_io,
                 ORL_2006_games_io, ORL_2007_games_io, ORL_2008_games_io, ORL_2009_games_io, ORL_2010_games_io, ORL_2011_games_io,
                 ORL_2012_games_io, ORL_2013_games_io, ORL_2014_games_io, ORL_2015_games_io, ORL_2016_games_io, ORL_2017_games_io,
                 ORL_2018_games_io, ORL_2019_games_io, ORL_2020_games_io, ORL_2021_games_io]

# %%
ORL_all = pd.concat(ORL_season_dfs)
ORL_all_sorted = ORL_all.sort_values(by=['GAME_SCORE'], ascending=False)
ORL_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2004-03-10  24-291  ORL      HOME      WAS   W (+9)   1  45:50  20   37
# 1  2003-11-14  24-174  ORL      AWAY      DEN   L (-5)   1  41:34  20   30
# 0  2003-02-23  23-275  ORL      AWAY      NJN   W (+8)   1  45:18  16   27
# 0  2009-02-17  23-071  ORL      HOME      CHA   W (+5)   1  46:41  16   23
# 0  2012-01-12  26-035  ORL      AWAY      GSW   W (+8)   1  43:37  12   21
# 0  2011-01-28  25-051  ORL      AWAY      CHI   L (-9)   1  42:18  14   20
# 0  2016-03-18  23-319  ORL      HOME      CLE   L (-6)   1  39:19  16   22
# 0  2021-02-12  30-111  ORL      AWAY      SAC  W (+11)   1  34:09  17   22
# 0  2001-04-13  21-324  ORL      AWAY      WAS   L (-3)   1  44:19  19   31
# 1  2003-02-21  23-273  ORL      HOME      CHI  W (+14)   1  32:48  15   32
# 0  2002-03-08  22-288  ORL      HOME      WAS   W (+3)   1  41:56  18   29
# ...
