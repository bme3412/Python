# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_PHI = []

# PHI
while season <= 2021:
    df_PHI = get_roster('PHI', season)
    df_PHI['Season'] = season
    df_PHI['Team'] = 'PHI'
    appended_data_PHI.append(df_PHI)
    season = season + 1
appended_data_PHI = pd.concat(appended_data_PHI)

# %%
PHI_df_all = appended_data_PHI.copy()
PHI_df_all_csv = PHI_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_players_all.csv', index=False)
PHI_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_players_all.csv')
PHI_df_all_csv_io.head()
# Out:
#   NUMBER        PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0     12   Bruce Bowen  SF    6-7     185  1971-06-14          US          3
# 1     11    Ira Bowman  SG    6-5     195  1973-06-11          US          R
# 2     52   Matt Geiger   C    7-0     243  1969-09-10          US          7
# 3     40   Tyrone Hill  PF    6-9     240  1968-03-19          US          9
# 4     21  Larry Hughes  SG    6-5     184  1979-01-23          US          1
#
#                 COLLEGE  Season Team
# 0   Cal State Fullerton    2000  PHI
# 1      Providence, Penn    2000  PHI
# 2  Auburn, Georgia Tech    2000  PHI
# 3                Xavier    2000  PHI
# 4           Saint Louis    2000  PHI

# %%
PHI_df_2000 = PHI_df_all[PHI_df_all['Season'] == 2000]
PHI_df_2001 = PHI_df_all[PHI_df_all['Season'] == 2001]
PHI_df_2002 = PHI_df_all[PHI_df_all['Season'] == 2002]
PHI_df_2003 = PHI_df_all[PHI_df_all['Season'] == 2003]
PHI_df_2004 = PHI_df_all[PHI_df_all['Season'] == 2004]
PHI_df_2005 = PHI_df_all[PHI_df_all['Season'] == 2005]
PHI_df_2006 = PHI_df_all[PHI_df_all['Season'] == 2006]
PHI_df_2007 = PHI_df_all[PHI_df_all['Season'] == 2007]
PHI_df_2008 = PHI_df_all[PHI_df_all['Season'] == 2008]
PHI_df_2009 = PHI_df_all[PHI_df_all['Season'] == 2009]
PHI_df_2010 = PHI_df_all[PHI_df_all['Season'] == 2010]
PHI_df_2011 = PHI_df_all[PHI_df_all['Season'] == 2011]
PHI_df_2012 = PHI_df_all[PHI_df_all['Season'] == 2012]
PHI_df_2013 = PHI_df_all[PHI_df_all['Season'] == 2013]
PHI_df_2014 = PHI_df_all[PHI_df_all['Season'] == 2014]
PHI_df_2015 = PHI_df_all[PHI_df_all['Season'] == 2015]
PHI_df_2016 = PHI_df_all[PHI_df_all['Season'] == 2016]
PHI_df_2017 = PHI_df_all[PHI_df_all['Season'] == 2017]
PHI_df_2018 = PHI_df_all[PHI_df_all['Season'] == 2018]
PHI_df_2019 = PHI_df_all[PHI_df_all['Season'] == 2019]
PHI_df_2020 = PHI_df_all[PHI_df_all['Season'] == 2020]
PHI_df_2021 = PHI_df_all[PHI_df_all['Season'] == 2021]

# %%
# changing names
#PHI_df_2002.loc[PHI_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#PHI_df_2004.loc[PHI_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
PHI_df_2000_players = PHI_df_2000['PLAYER'].to_list()
PHI_df_2001_players = PHI_df_2001['PLAYER'].to_list()
PHI_df_2002_players = PHI_df_2002['PLAYER'].to_list()
PHI_df_2003_players = PHI_df_2003['PLAYER'].to_list()
PHI_df_2004_players = PHI_df_2004['PLAYER'].to_list()
PHI_df_2005_players = PHI_df_2005['PLAYER'].to_list()

PHI_df_2006_players = PHI_df_2006['PLAYER'].to_list()
PHI_df_2007_players = PHI_df_2007['PLAYER'].to_list()
PHI_df_2008_players = PHI_df_2008['PLAYER'].to_list()
PHI_df_2009_players = PHI_df_2009['PLAYER'].to_list()
PHI_df_2010_players = PHI_df_2010['PLAYER'].to_list()
PHI_df_2011_players = PHI_df_2011['PLAYER'].to_list()

PHI_df_2012_players = PHI_df_2012['PLAYER'].to_list()
PHI_df_2013_players = PHI_df_2013['PLAYER'].to_list()
PHI_df_2014_players = PHI_df_2014['PLAYER'].to_list()
PHI_df_2015_players = PHI_df_2015['PLAYER'].to_list()
PHI_df_2016_players = PHI_df_2016['PLAYER'].to_list()
PHI_df_2017_players = PHI_df_2017['PLAYER'].to_list()

PHI_df_2018_players = PHI_df_2018['PLAYER'].to_list()
PHI_df_2019_players = PHI_df_2019['PLAYER'].to_list()
PHI_df_2020_players = PHI_df_2020['PLAYER'].to_list()
PHI_df_2021_players = PHI_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#PHI_df_2000_players.remove("Larry Johnson")
#PHI_df_2003_players.remove("Efthimios Rentzias")
#PHI_df_2007_players.remove("Bobby Jones")
#PHI_df_2015_players.remove("Larry Drew")
#PHI_df_2015_players.remove("Chris Johnson")
#PHI_df_2015_players.remove("Glenn Robinson")
#PHI_df_2017_players.remove("Gerald Henderson")
#PHI_df_2018_players.remove("Larry Drew")
#PHI_df_2018_players.remove("James Michael McAdoo")
#PHI_df_2020_players.remove("Kyle O'Quinn")
#PHI_df_2020_players.remove("Glenn Robinson")
PHI_df_2021_players.remove("Dakota Mathias")

# %%
PHI_2000_gamelog = []


for p in PHI_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2000_gamelog.append(player_log)
PHI_2000_gamelog = pd.concat(PHI_2000_gamelog)    
PHI_2000_gamelogs = PHI_2000_gamelog.copy()
PHI_2000_gamelogs['GAME_SCORE'] = PHI_2000_gamelogs['GAME_SCORE'].astype(float)
PHI_2000_games = PHI_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2000_games_csv = PHI_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2000_games.csv', index=False)
PHI_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2000_games.csv')
PHI_2000_games_proc.head()
# Out:
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Ira Bowman"
# 3 results found.
# 0: Ira Bowman
# 1: Ky Bowman
# 2: Nate Bowman
# Pick one: 0
# Results for Ira Bowman:
#
# You searched for "Matt Geiger"
# 4 results found.
# 0: Matt Geiger
# 1: Matt Bonner
# 2: Matt Freije
# 3: Tate George
# Pick one: 0
# Results for Matt Geiger:
#
# You searched for "Tyrone Hill"
# 5 results found.
# 0: Tyrone Hill
# 1: Tyrone Britt
# 2: Armond Hill
# 3: Grant Hill
# 4: Tyronn Lue
# Pick one: 0
# Results for Tyrone Hill:
#
# You searched for "Larry Hughes"
# 6 results found.
# 0: Larry Hughes
# 1: Larry Bunce
# 2: Larry Fogle
# 3: Larry Jones
# 4: Larry Sykes
# 5: Larry Wright
# Pick one: 0
# Results for Larry Hughes:
#
# You searched for "Allen Iverson"
# 2 results found.
# 0: Allen Iverson
# 1: Willie Iverson
# Pick one: 0
# ...

# %%
PHI_2001_gamelog = []


for p in PHI_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2001_gamelog.append(player_log)
PHI_2001_gamelog = pd.concat(PHI_2001_gamelog)    
PHI_2001_gamelogs = PHI_2001_gamelog.copy()
PHI_2001_gamelogs['GAME_SCORE'] = PHI_2001_gamelogs['GAME_SCORE'].astype(float)
PHI_2001_games = PHI_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2001_games_csv = PHI_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2001_games.csv', index=False)
PHI_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2001_games.csv')
PHI_2001_games_proc.head()
# Out:
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Rodney Buford"
# 2 results found.
# 0: Rodney Buford
# 1: Rodney Hood
# Pick one: 0
# Results for Rodney Buford:
#
# You searched for "Matt Geiger"
# 4 results found.
# 0: Matt Geiger
# 1: Matt Bonner
# 2: Matt Freije
# 3: Tate George
# Pick one: 0
# Results for Matt Geiger:
#
# You searched for "Tyrone Hill"
# 5 results found.
# 0: Tyrone Hill
# 1: Tyrone Britt
# 2: Armond Hill
# 3: Grant Hill
# 4: Tyronn Lue
# Pick one: 0
# Results for Tyrone Hill:
#
# You searched for "Allen Iverson"
# 2 results found.
# 0: Allen Iverson
# 1: Willie Iverson
# Pick one: 0
# Results for Allen Iverson:
#
# You searched for "Jumaine Jones"
# 3 results found.
# 0: Jumaine Jones
# 1: Dwayne Jones
# 2: Jake Jones
# Pick one: 0
# Results for Jumaine Jones:
#
# You searched for "Toni Kukoč"
# 2 results found.
# 0: Toni Kukoc
# 1: Tony Koski
# Pick one: 0
# ...

# %%
PHI_2002_gamelog = []


for p in PHI_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2002_gamelog.append(player_log)
PHI_2002_gamelog = pd.concat(PHI_2002_gamelog)    
PHI_2002_gamelogs = PHI_2002_gamelog.copy()
PHI_2002_gamelogs['GAME_SCORE'] = PHI_2002_gamelogs['GAME_SCORE'].astype(float)
PHI_2002_games = PHI_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2002_games_csv = PHI_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2002_games.csv', index=False)
PHI_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2002_games.csv')
PHI_2002_games_proc.head()
# Out:
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Ira Bowman"
# 3 results found.
# 0: Ira Bowman
# 1: Ky Bowman
# 2: Nate Bowman
# Pick one: 0
# Results for Ira Bowman:
#
# You searched for "Damone Brown"
# 14 results found.
# 0: Damone Brown
# 1: Raymond Brown
# 2: Andre Brown
# 3: Dee Brown
# 4: Dee Brown
# 5: Devin Brown
# 6: Harold Brown
# 7: Kwame Brown
# 8: Leon Brown
# 9: Mike Brown
# 10: Moses Brown
# 11: Myron Brown
# 12: Tony Brown
# 13: Damon Jones
# Pick one: 0
# Results for Damone Brown:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Derrick Coleman"
# 2 results found.
# 0: Derrick Coleman
# 1: Norris Coleman
# Pick one: 0
# Results for Derrick Coleman:
#
# ...

# %%
# removed Efthimios Rentzias
    
PHI_2003_gamelog = []



for p in PHI_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2003_gamelog.append(player_log)
PHI_2003_gamelog = pd.concat(PHI_2003_gamelog)    
PHI_2003_gamelogs = PHI_2003_gamelog.copy()
PHI_2003_gamelogs['GAME_SCORE'] = PHI_2003_gamelogs['GAME_SCORE'].astype(float)
PHI_2003_games = PHI_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2003_games_csv = PHI_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2003_games.csv', index=False)
PHI_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2003_games.csv')
PHI_2003_games_proc.head()
# Out:
# You searched for "Mark Bryant"
# 11 results found.
# 0: Mark Bryant
# 1: Mark Blount
# 2: Mark Bradtke
# 3: Em Bryant
# 4: Joe Bryant
# 5: Kobe Bryant
# 6: Gary Grant
# 7: Markel Brown
# 8: Mark Eaton
# 9: Mark Workman
# 10: Mark Sibley
# Pick one: 0
# Results for Mark Bryant:
#
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Derrick Coleman"
# 2 results found.
# 0: Derrick Coleman
# 1: Norris Coleman
# Pick one: 0
# Results for Derrick Coleman:
#
# You searched for "Tyrone Hill"
# 5 results found.
# 0: Tyrone Hill
# 1: Tyrone Britt
# 2: Armond Hill
# 3: Grant Hill
# 4: Tyronn Lue
# Pick one: 0
# Results for Tyrone Hill:
#
# You searched for "Allen Iverson"
# 2 results found.
# 0: Allen Iverson
# 1: Willie Iverson
# Pick one: 0
# Results for Allen Iverson:
#
# You searched for "Art Long"
# 7 results found.
# 0: Art Long
# 1: Grant Long
# ...

# %%
PHI_2004_gamelog = []



for p in PHI_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2004_gamelog.append(player_log)
PHI_2004_gamelog = pd.concat(PHI_2004_gamelog)    
PHI_2004_gamelogs = PHI_2004_gamelog.copy()
PHI_2004_gamelogs['GAME_SCORE'] = PHI_2004_gamelogs['GAME_SCORE'].astype(float)
PHI_2004_games = PHI_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2004_games_csv = PHI_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2004_games.csv', index=False)
PHI_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2004_games.csv')
PHI_2004_games_proc.head()
# Out:
# You searched for "Greg Buckner"
# 4 results found.
# 0: Greg Buckner
# 1: Greg Butler
# 2: Greg Bunch
# 3: Greg Jackson
# Pick one: 0
# Results for Greg Buckner:
#
# You searched for "Derrick Coleman"
# 2 results found.
# 0: Derrick Coleman
# 1: Norris Coleman
# Pick one: 0
# Results for Derrick Coleman:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# 9: Willie Porter
# 10: Willie Wise
# 11: Willie Long
# 12: Willie Rogers
# 13: Willie White
# Pick one: 0
# Results for Willie Green:
#
# You searched for "Zendon Hamilton"
# 3 results found.
# 0: Zendon Hamilton
# 1: Dennis Hamilton
# 2: Jordan Hamilton
# Pick one: 0
# Results for Zendon Hamilton:
#
# You searched for "Allen Iverson"
# 2 results found.
# ...

# %%
PHI_2005_gamelog = []



for p in PHI_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2005_gamelog.append(player_log)
PHI_2005_gamelog = pd.concat(PHI_2005_gamelog)    
PHI_2005_gamelogs = PHI_2005_gamelog.copy()
PHI_2005_gamelogs['GAME_SCORE'] = PHI_2005_gamelogs['GAME_SCORE'].astype(float)
PHI_2005_games = PHI_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2005_games_csv = PHI_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2005_games.csv', index=False)
PHI_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2005_games.csv')
PHI_2005_games_proc.head()
# Out:
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Kedrick Brown"
# 2 results found.
# 0: Kedrick Brown
# 1: Derrick Brown
# Pick one: 0
# Results for Kedrick Brown:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Josh Davis"
# 27 results found.
# 0: Josh Davis
# 1: Bob Davis
# 2: Jim Davis
# 3: Ron Davis
# 4: Josh Reaves
# 5: Josh Hall
# 6: Bob Davies
# 7: Ben Davis
# 8: Bill Davis
# 9: Brad Davis
# 10: Dale Davis
# 11: Ed Davis
# 12: Glen Davis
# 13: Johnny Davis
# 14: Lee Davis
# 15: Mark Davis
# 16: Mark Davis
# 17: Mel Davis
# 18: Mike Davis
# 19: Mike Davis
# 20: Monti Davis
# 21: Paul Davis
# 22: Ralph Davis
# 23: Red Davis
# 24: Walt Davis
# 25: Josh Hart
# 26: Josh Grant
# ...

# %%
PHI_2006_gamelog = []

for p in PHI_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2006_gamelog.append(player_log)
PHI_2006_gamelog = pd.concat(PHI_2006_gamelog)    
PHI_2006_gamelogs = PHI_2006_gamelog.copy()
PHI_2006_gamelogs['GAME_SCORE'] = PHI_2006_gamelogs['GAME_SCORE'].astype(float)
PHI_2006_games = PHI_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2006_games_csv = PHI_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2006_games.csv', index=False)
PHI_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2006_games.csv')
PHI_2006_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Deng Gai"
# 4 results found.
# 0: Deng Gai
# 1: Deng Adel
# 2: Don May
# 3: Don Ray
# Pick one: 0
# Results for Deng Gai:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# ...

# %%
# removed Bobby Jones

PHI_2007_gamelog = []

for p in PHI_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2007_gamelog.append(player_log)
PHI_2007_gamelog = pd.concat(PHI_2007_gamelog)    
PHI_2007_gamelogs = PHI_2007_gamelog.copy()
PHI_2007_gamelogs['GAME_SCORE'] = PHI_2007_gamelogs['GAME_SCORE'].astype(float)
PHI_2007_games = PHI_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2007_games_csv = PHI_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2007_games.csv', index=False)
PHI_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2007_games.csv')
PHI_2007_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# 9: Willie Porter
# 10: Willie Wise
# 11: Willie Long
# 12: Willie Rogers
# 13: Willie White
# Pick one: 0
# Results for Willie Green:
#
# You searched for "Alan Henderson"
# 9 results found.
# 0: Alan Henderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ryan Anderson
# 5: Dave Henderson
# 6: J.R. Henderson
# 7: Kevin Henderson
# 8: Tom Henderson
# Pick one: 0
# ...

# %%
PHI_2008_gamelog = []

for p in PHI_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2008_gamelog.append(player_log)
PHI_2008_gamelog = pd.concat(PHI_2008_gamelog)    
PHI_2008_gamelogs = PHI_2008_gamelog.copy()
PHI_2008_gamelogs['GAME_SCORE'] = PHI_2008_gamelogs['GAME_SCORE'].astype(float)
PHI_2008_games = PHI_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2008_games_csv = PHI_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2008_games.csv', index=False)
PHI_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2008_games.csv')
PHI_2008_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# ...

# %%
PHI_2009_gamelog = []

for p in PHI_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2009_gamelog.append(player_log)
PHI_2009_gamelog = pd.concat(PHI_2009_gamelog)    
PHI_2009_gamelogs = PHI_2009_gamelog.copy()
PHI_2009_gamelogs['GAME_SCORE'] = PHI_2009_gamelogs['GAME_SCORE'].astype(float)
PHI_2009_games = PHI_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2009_games_csv = PHI_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2009_games.csv', index=False)
PHI_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2009_games.csv')
PHI_2009_games_proc.head()
# Out:
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# 9: Willie Porter
# 10: Willie Wise
# 11: Willie Long
# 12: Willie Rogers
# 13: Willie White
# Pick one: 0
# Results for Willie Green:
#
# You searched for "Andre Iguodala"
# 1 result found.
# Andre Iguodala
# Results for Andre Iguodala:
#
# You searched for "Royal Ivey"
# 1 result found.
# ...

# %%
PHI_2010_gamelog = []

for p in PHI_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2010_gamelog.append(player_log)
PHI_2010_gamelog = pd.concat(PHI_2010_gamelog)    
PHI_2010_gamelogs = PHI_2010_gamelog.copy()
PHI_2010_gamelogs['GAME_SCORE'] = PHI_2010_gamelogs['GAME_SCORE'].astype(float)
PHI_2010_games = PHI_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2010_games_csv = PHI_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2010_games.csv', index=False)
PHI_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2010_games.csv')
PHI_2010_games_proc.head()
# Out:
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "Rodney Carney"
# 3 results found.
# 0: Rodney Carney
# 1: Rodney McCray
# 2: Rodney Monroe
# Pick one: 0
# Results for Rodney Carney:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Willie Green"
# 14 results found.
# 0: Willie Green
# 1: Willie Reed
# 2: Willie Allen
# 3: Willis Reed
# 4: Willie Warren
# 5: Willie Burton
# 6: Mike Green
# 7: Tommie Green
# 8: Willie Jones
# 9: Willie Porter
# 10: Willie Wise
# 11: Willie Long
# 12: Willie Rogers
# 13: Willie White
# Pick one: 0
# Results for Willie Green:
#
# You searched for "Jrue Holiday"
# 2 results found.
# 0: Jrue Holiday
# ...

# %%
PHI_2011_gamelog = []

for p in PHI_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2011_gamelog.append(player_log)
PHI_2011_gamelog = pd.concat(PHI_2011_gamelog)    
PHI_2011_gamelogs = PHI_2011_gamelog.copy()
PHI_2011_gamelogs['GAME_SCORE'] = PHI_2011_gamelogs['GAME_SCORE'].astype(float)
PHI_2011_games = PHI_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2011_games_csv = PHI_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2011_games.csv', index=False)
PHI_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2011_games.csv')
PHI_2011_games_proc.head()
# Out:
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Craig Brackins"
# 1 result found.
# Craig Brackins
# Results for Craig Brackins:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# 1: Steve Hawes
# 2: Spencer Haywood
# Pick one: 0
# Results for Spencer Hawes:
#
# You searched for "Jrue Holiday"
# 2 results found.
# 0: Jrue Holiday
# 1: Aaron Holiday
# Pick one: 0
# Results for Jrue Holiday:
#
# You searched for "Andre Iguodala"
# 1 result found.
# Andre Iguodala
# Results for Andre Iguodala:
#
# You searched for "Jason Kapono"
# ...

# %%
PHI_2012_gamelog = []

for p in PHI_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2012_gamelog.append(player_log)
PHI_2012_gamelog = pd.concat(PHI_2012_gamelog)    
PHI_2012_gamelogs = PHI_2012_gamelog.copy()
PHI_2012_gamelogs['GAME_SCORE'] = PHI_2012_gamelogs['GAME_SCORE'].astype(float)
PHI_2012_games = PHI_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2012_games_csv = PHI_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2012_games.csv', index=False)
PHI_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2012_games.csv')
PHI_2012_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Tony Battie"
# 8 results found.
# 0: Tony Battie
# 1: John Battle
# 2: Kenny Battle
# 3: Tony Harris
# 4: Tony White
# 5: Tony Allen
# 6: Tony Bobbitt
# 7: Tony Bennett
# Pick one: 0
# Results for Tony Battie:
#
# You searched for "Craig Brackins"
# 1 result found.
# Craig Brackins
# Results for Craig Brackins:
#
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# 1: Steve Hawes
# 2: Spencer Haywood
# Pick one: 0
# Results for Spencer Hawes:
#
# You searched for "Jrue Holiday"
# 2 results found.
# 0: Jrue Holiday
# 1: Aaron Holiday
# Pick one: 0
# ...

# %%
PHI_2013_gamelog = []

for p in PHI_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2013_gamelog.append(player_log)
PHI_2013_gamelog = pd.concat(PHI_2013_gamelog)    
PHI_2013_gamelogs = PHI_2013_gamelog.copy()
PHI_2013_gamelogs['GAME_SCORE'] = PHI_2013_gamelogs['GAME_SCORE'].astype(float)
PHI_2013_games = PHI_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2013_games_csv = PHI_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2013_games.csv', index=False)
PHI_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2013_games.csv')
PHI_2013_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# 1: Steve Hawes
# 2: Spencer Haywood
# Pick one: 0
# Results for Spencer Hawes:
#
# You searched for "Jrue Holiday"
# 2 results found.
# 0: Jrue Holiday
# 1: Aaron Holiday
# Pick one: 0
# Results for Jrue Holiday:
#
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Royal Ivey"
# 1 result found.
# Royal Ivey
# Results for Royal Ivey:
#
# You searched for "Charles Jenkins"
# 5 results found.
# 0: Charles Jenkins
# ...

# %%
PHI_2014_gamelog = []

for p in PHI_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2014_gamelog.append(player_log)
PHI_2014_gamelog = pd.concat(PHI_2014_gamelog)    
PHI_2014_gamelogs = PHI_2014_gamelog.copy()
PHI_2014_gamelogs['GAME_SCORE'] = PHI_2014_gamelogs['GAME_SCORE'].astype(float)
PHI_2014_games = PHI_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2014_games_csv = PHI_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2014_games.csv', index=False)
PHI_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2014_games.csv')
PHI_2014_games_proc.head()
# Out:
# You searched for "Lavoy Allen"
# 6 results found.
# 0: Lavoy Allen
# 1: Randy Allen
# 2: Ray Allen
# 3: Bob Allen
# 4: Malik Allen
# 5: Tony Allen
# Pick one: 0
# Results for Lavoy Allen:
#
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "Lorenzo Brown"
# 2 results found.
# 0: Lorenzo Brown
# 1: Lorenzo Romar
# Pick one: 0
# Results for Lorenzo Brown:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Brandon Davies"
# 5 results found.
# 0: Brandon Davies
# 1: Brandon Bass
# 2: Baron Davis
# 3: Brad Davis
# 4: Brandon Clarke
# Pick one: 0
# Results for Brandon Davies:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# ...

# %%
# removed larry drew
# removed chris johnson
# removed glenn robinson 

PHI_2015_gamelog = []

for p in PHI_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2015_gamelog.append(player_log)
PHI_2015_gamelog = pd.concat(PHI_2015_gamelog)    
PHI_2015_gamelogs = PHI_2015_gamelog.copy()
PHI_2015_gamelogs['GAME_SCORE'] = PHI_2015_gamelogs['GAME_SCORE'].astype(float)
PHI_2015_games = PHI_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2015_games_csv = PHI_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2015_games.csv', index=False)
PHI_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2015_games.csv')
PHI_2015_games_proc.head()
# Out:
# You searched for "Furkan Aldemir"
# 1 result found.
# Furkan Aldemir
# Results for Furkan Aldemir:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Brandon Davies"
# 5 results found.
# 0: Brandon Davies
# 1: Brandon Bass
# 2: Baron Davis
# 3: Brad Davis
# 4: Brandon Clarke
# Pick one: 0
# Results for Brandon Davies:
#
# You searched for "Tim Frazier"
# 4 results found.
# 0: Tim Frazier
# 1: Will Frazier
# 2: Jim Farmer
# 3: Walt Frazier
# Pick one: 0
# Results for Tim Frazier:
#
# You searched for "Drew Gordon"
# 6 results found.
# 0: Drew Gordon
# 1: Drew Gooden
# 2: Ben Gordon
# 3: Eric Gordon
# 4: Aaron Gordon
# 5: Paul Gordon
# Pick one: 0
# Results for Drew Gordon:
#
# ...

# %%
PHI_2016_gamelog = []

for p in PHI_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2016_gamelog.append(player_log)
PHI_2016_gamelog = pd.concat(PHI_2016_gamelog)    
PHI_2016_gamelogs = PHI_2016_gamelog.copy()
PHI_2016_gamelogs['GAME_SCORE'] = PHI_2016_gamelogs['GAME_SCORE'].astype(float)
PHI_2016_games = PHI_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2016_games_csv = PHI_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2016_games.csv', index=False)
PHI_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2016_games.csv')
PHI_2016_games_proc.head()
# Out:
# You searched for "Elton Brand"
# 1 result found.
# Elton Brand
# Results for Elton Brand:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Jerami Grant"
# 4 results found.
# 0: Jerami Grant
# 1: Jerian Grant
# 2: Horace Grant
# 3: Travis Grant
# Pick one: 0
# Results for Jerami Grant:
#
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Carl Landry"
# 4 results found.
# 0: Carl Landry
# 1: Carl Henry
# 2: Carl Bailey
# 3: Marcus Landry
# Pick one: 0
# Results for Carl Landry:
#
# You searched for "Kendall Marshall"
# 2 results found.
# 0: Kendall Marshall
# 1: Donyell Marshall
# Pick one: 0
# Results for Kendall Marshall:
#
# You searched for "T.J. McConnell"
# 1 result found.
# T.J. McConnell
# Results for T.J. McConnell:
#
# ...

# %%
# removed Gerald Henderson

PHI_2017_gamelog = []

for p in PHI_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2017_gamelog.append(player_log)
PHI_2017_gamelog = pd.concat(PHI_2017_gamelog)    
PHI_2017_gamelogs = PHI_2017_gamelog.copy()
PHI_2017_gamelogs['GAME_SCORE'] = PHI_2017_gamelogs['GAME_SCORE'].astype(float)
PHI_2017_games = PHI_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2017_games_csv = PHI_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2017_games.csv', index=False)
PHI_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2017_games.csv')
PHI_2017_games_proc.head()
# Out:
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "Jerami Grant"
# 4 results found.
# 0: Jerami Grant
# 1: Jerian Grant
# 2: Horace Grant
# 3: Travis Grant
# Pick one: 0
# Results for Jerami Grant:
#
# You searched for "Justin Harper"
# 4 results found.
# 0: Justin Harper
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Justin Harper:
#
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Ersan İlyasova"
# 1 result found.
# Ersan Ilyasova
# Results for Ersan Ilyasova:
#
# You searched for "Shawn Long"
# ...

# %%
# removed larry drew
# removed James Michael McAdoo
PHI_2018_gamelog = []

for p in PHI_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2018_gamelog.append(player_log)
PHI_2018_gamelog = pd.concat(PHI_2018_gamelog)    
PHI_2018_gamelogs = PHI_2018_gamelog.copy()
PHI_2018_gamelogs['GAME_SCORE'] = PHI_2018_gamelogs['GAME_SCORE'].astype(float)
PHI_2018_games = PHI_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2018_games_csv = PHI_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2018_games.csv', index=False)
PHI_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2018_games.csv')
PHI_2018_games_proc.head()
# Out:
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "Markelle Fultz"
# 1 result found.
# Markelle Fultz
# Results for Markelle Fultz:
#
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Ersan İlyasova"
# 1 result found.
# Ersan Ilyasova
# Results for Ersan Ilyasova:
#
# ...

# %%
PHI_2019_gamelog = []

for p in PHI_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2019_gamelog.append(player_log)
PHI_2019_gamelog = pd.concat(PHI_2019_gamelog)    
PHI_2019_gamelogs = PHI_2019_gamelog.copy()
PHI_2019_gamelogs['GAME_SCORE'] = PHI_2019_gamelogs['GAME_SCORE'].astype(float)
PHI_2019_games = PHI_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2019_games_csv = PHI_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2019_games.csv', index=False)
PHI_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2019_games.csv')
PHI_2019_games_proc.head()
# Out:
# You searched for "Jonah Bolden"
# 2 results found.
# 0: Jonah Bolden
# 1: Jordan Bowden
# Pick one: 0
# Results for Jonah Bolden:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Jimmy Butler"
# 6 results found.
# 0: Jimmy Butler
# 1: Mike Butler
# 2: Jimmy Conner
# 3: Jimmy Foster
# 4: Jimmy Oliver
# 5: Jimmy Walker
# Pick one: 0
# Results for Jimmy Butler:
#
# You searched for "Wilson Chandler"
# 2 results found.
# 0: Wilson Chandler
# 1: Tyson Chandler
# Pick one: 0
# Results for Wilson Chandler:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# 2: Jamel Artis
# 3: Tyler Ennis
# 4: James Lang
# ...

# %%
# removed kyle o'quinn
# removed glenn robinson
PHI_2020_gamelog = []

for p in PHI_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2020_gamelog.append(player_log)
PHI_2020_gamelog = pd.concat(PHI_2020_gamelog)    
PHI_2020_gamelogs = PHI_2020_gamelog.copy()
PHI_2020_gamelogs['GAME_SCORE'] = PHI_2020_gamelogs['GAME_SCORE'].astype(float)
PHI_2020_games = PHI_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2020_games_csv = PHI_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2020_games.csv', index=False)
PHI_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2020_games.csv')
PHI_2020_games_proc.head()
# Out:
# You searched for "Jonah Bolden"
# 2 results found.
# 0: Jonah Bolden
# 1: Jordan Bowden
# Pick one: 0
# Results for Jonah Bolden:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "James Ennis"
# 11 results found.
# 0: James Ennis
# 1: James Jones
# 2: Jamel Artis
# 3: Tyler Ennis
# 4: James Lang
# 5: James Silas
# 6: James Posey
# 7: James White
# 8: James Young
# 9: James Harden
# 10: James Phelan
# Pick one: 0
# Results for James Ennis:
#
# You searched for "Tobias Harris"
# 6 results found.
# 0: Tobias Harris
# 1: Elias Harris
# 2: Bob Harris
# 3: Chris Harris
# 4: Tony Harris
# 5: Bob Harrison
# Pick one: 0
# ...

# %%
# remvoed dakota mathias
PHI_2021_gamelog = []

for p in PHI_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    PHI_2021_gamelog.append(player_log)
PHI_2021_gamelog = pd.concat(PHI_2021_gamelog)    
PHI_2021_gamelogs = PHI_2021_gamelog.copy()
PHI_2021_gamelogs['GAME_SCORE'] = PHI_2021_gamelogs['GAME_SCORE'].astype(float)
PHI_2021_games = PHI_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_2021_games_csv = PHI_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2021_games.csv', index=False)
PHI_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2021_games.csv')
PHI_2021_games_proc.head()
# Out:
# You searched for "Tony Bradley"
# 10 results found.
# 0: Tony Bradley
# 1: Toby Bailey
# 2: Joe Bradley
# 3: Tony Allen
# 4: Alex Bradley
# 5: Alonzo Bradley
# 6: Avery Bradley
# 7: Bill Bradley
# 8: Bill Bradley
# 9: Jim Bradley
# Pick one: 0
# Results for Tony Bradley:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Gary Clark"
# 15 results found.
# 0: Gary Clark
# 1: Earl Clark
# 2: Ian Clark
# 3: Gary Alcorn
# 4: Cory Carr
# 5: Carlos Clark
# 6: Keon Clark
# 7: Coty Clarke
# 8: Gary Grant
# 9: Gary Gray
# 10: Gar Heard
# 11: Gary Neal
# 12: Jay Carty
# 13: Gary Keller
# 14: Gary Zeller
# Pick one: 0
# Results for Gary Clark:
#
# You searched for "Seth Curry"
# 4 results found.
# 0: Seth Curry
# 1: Dell Curry
# 2: Eddy Curry
# 3: Stephen Curry
# Pick one: 0
# Results for Seth Curry:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
PHI_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2000_games.csv')
PHI_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2001_games.csv')
PHI_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2002_games.csv')
PHI_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2003_games.csv')
PHI_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2004_games.csv')
PHI_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2005_games.csv')
PHI_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2006_games.csv')
PHI_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2007_games.csv')
PHI_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2008_games.csv')
PHI_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2009_games.csv')
PHI_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2010_games.csv')
PHI_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2011_games.csv')
PHI_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2012_games.csv')
PHI_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2013_games.csv')
PHI_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2014_games.csv')
PHI_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2015_games.csv')
PHI_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2016_games.csv')
PHI_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2017_games.csv')
PHI_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2018_games.csv')
PHI_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2019_games.csv')
PHI_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2020_games.csv')
PHI_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHI/PHI_2021_games.csv')

# %%
PHI_season_dfs = [PHI_2000_games_io, PHI_2001_games_io, PHI_2002_games_io, PHI_2003_games_io, PHI_2004_games_io, PHI_2005_games_io,
                 PHI_2006_games_io, PHI_2007_games_io, PHI_2008_games_io, PHI_2009_games_io, PHI_2010_games_io, PHI_2011_games_io,
                 PHI_2012_games_io, PHI_2013_games_io, PHI_2014_games_io, PHI_2015_games_io, PHI_2016_games_io, PHI_2017_games_io,
                 PHI_2018_games_io, PHI_2019_games_io, PHI_2020_games_io, PHI_2021_games_io]

# %%
PHI_all = pd.concat(PHI_season_dfs)
PHI_all_sorted = PHI_all.sort_values(by=['GAME_SCORE'], ascending=False)
PHI_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-19  26-340  PHI      HOME      CHI   W (+7)   1  35:16  17   26
# 0  2005-02-12  29-250  PHI      HOME      ORL  W (+13)   1  42:01  17   36
# 0  2017-11-15  23-244  PHI      AWAY      LAL   W (+6)   1  34:29  14   20
# 0  2007-03-17  31-283  DEN      HOME      PHO  W (+24)   1  42:38  16   22
# 0  2005-12-23  30-199  PHI      AWAY      ATL   L (-3)   1  44:30  17   31
# 0  2020-02-24  25-345  PHI      HOME      ATL  W (+17)   1  36:22  17   24
# 1  2021-01-12  26-302  PHI      HOME      MIA   W (+3)   1  39:20  16   23
# 1  2004-12-18  29-194  PHI      AWAY      MIL  W (+19)   1  40:39  17   29
# 1  2020-01-20  23-184  PHI      AWAY      BRK   W (+6)   1  42:20  12   14
# 0  2001-01-06  25-213  PHI      AWAY      CLE   W (+4)   1  43:56  20   30
# 1  2006-01-11  30-218  PHI      HOME      UTA   L (-8)   1  43:52  16   25
# ...
