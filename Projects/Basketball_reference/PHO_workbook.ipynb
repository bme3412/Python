# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_PHO = []

# PHO
while season <= 2021:
    df_PHO = get_roster('PHO', season)
    df_PHO['Season'] = season
    df_PHO['Team'] = 'PHO'
    appended_data_PHO.append(df_PHO)
    season = season + 1
appended_data_PHO = pd.concat(appended_data_PHO)

# %%
PHO_df_all = appended_data_PHO.copy()
PHO_df_all_csv = PHO_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_players_all.csv', index=False)
PHO_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_players_all.csv')
PHO_df_all_csv_io.head()
# Out:
#    NUMBER        PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0      12   Toby Bailey  SG    6-6     213  1975-11-19          US          1
# 1      40  Corie Blount  PF    6-9     240  1969-01-04          US          6
# 2       3   Rex Chapman  SG    6-4     185  1967-10-05          US         11
# 3      43     Ben Davis  PF    6-9     240  1972-12-26          US          3
# 4      11      Todd Day  SG    6-6     188  1970-01-07          US          6
#
#            COLLEGE  Season Team
# 0             UCLA    2000  PHO
# 1       Cincinnati    2000  PHO
# 2         Kentucky    2000  PHO
# 3  Kansas, Arizona    2000  PHO
# 4         Arkansas    2000  PHO

# %%
PHO_df_2000 = PHO_df_all[PHO_df_all['Season'] == 2000]
PHO_df_2001 = PHO_df_all[PHO_df_all['Season'] == 2001]
PHO_df_2002 = PHO_df_all[PHO_df_all['Season'] == 2002]
PHO_df_2003 = PHO_df_all[PHO_df_all['Season'] == 2003]
PHO_df_2004 = PHO_df_all[PHO_df_all['Season'] == 2004]
PHO_df_2005 = PHO_df_all[PHO_df_all['Season'] == 2005]
PHO_df_2006 = PHO_df_all[PHO_df_all['Season'] == 2006]
PHO_df_2007 = PHO_df_all[PHO_df_all['Season'] == 2007]
PHO_df_2008 = PHO_df_all[PHO_df_all['Season'] == 2008]
PHO_df_2009 = PHO_df_all[PHO_df_all['Season'] == 2009]
PHO_df_2010 = PHO_df_all[PHO_df_all['Season'] == 2010]
PHO_df_2011 = PHO_df_all[PHO_df_all['Season'] == 2011]
PHO_df_2012 = PHO_df_all[PHO_df_all['Season'] == 2012]
PHO_df_2013 = PHO_df_all[PHO_df_all['Season'] == 2013]
PHO_df_2014 = PHO_df_all[PHO_df_all['Season'] == 2014]
PHO_df_2015 = PHO_df_all[PHO_df_all['Season'] == 2015]
PHO_df_2016 = PHO_df_all[PHO_df_all['Season'] == 2016]
PHO_df_2017 = PHO_df_all[PHO_df_all['Season'] == 2017]
PHO_df_2018 = PHO_df_all[PHO_df_all['Season'] == 2018]
PHO_df_2019 = PHO_df_all[PHO_df_all['Season'] == 2019]
PHO_df_2020 = PHO_df_all[PHO_df_all['Season'] == 2020]
PHO_df_2021 = PHO_df_all[PHO_df_all['Season'] == 2021]

# %%
# changing names
#PHO_df_2002.loc[PHO_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#PHO_df_2004.loc[PHO_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
PHO_df_2000_players = PHO_df_2000['PLAYER'].to_list()
PHO_df_2001_players = PHO_df_2001['PLAYER'].to_list()
PHO_df_2002_players = PHO_df_2002['PLAYER'].to_list()
PHO_df_2003_players = PHO_df_2003['PLAYER'].to_list()
PHO_df_2004_players = PHO_df_2004['PLAYER'].to_list()
PHO_df_2005_players = PHO_df_2005['PLAYER'].to_list()

PHO_df_2006_players = PHO_df_2006['PLAYER'].to_list()
PHO_df_2007_players = PHO_df_2007['PLAYER'].to_list()
PHO_df_2008_players = PHO_df_2008['PLAYER'].to_list()
PHO_df_2009_players = PHO_df_2009['PLAYER'].to_list()
PHO_df_2010_players = PHO_df_2010['PLAYER'].to_list()
PHO_df_2011_players = PHO_df_2011['PLAYER'].to_list()

PHO_df_2012_players = PHO_df_2012['PLAYER'].to_list()
PHO_df_2013_players = PHO_df_2013['PLAYER'].to_list()
PHO_df_2014_players = PHO_df_2014['PLAYER'].to_list()
PHO_df_2015_players = PHO_df_2015['PLAYER'].to_list()
PHO_df_2016_players = PHO_df_2016['PLAYER'].to_list()
PHO_df_2017_players = PHO_df_2017['PLAYER'].to_list()

PHO_df_2018_players = PHO_df_2018['PLAYER'].to_list()
PHO_df_2019_players = PHO_df_2019['PLAYER'].to_list()
PHO_df_2020_players = PHO_df_2020['PLAYER'].to_list()
PHO_df_2021_players = PHO_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#PHO_df_2000_players.remove("Larry Johnson")
#PHO_df_2008_players.remove("Shaquille O'Neal")
#PHO_df_2009_players.remove("Dee Brown")
#PHO_df_2009_players.remove("Shaquille O'Neal")
#PHO_df_2013_players.remove("Jermaine O'Neal")
#PHO_df_2017_players.remove("Derrick Jones")
#PHO_df_2018_players.remove("Mike James")
#PHO_df_2018_players.remove("Derrick Jones")
#PHO_df_2019_players.remove("George King")
#PHO_df_2019_players.remove("Kelly Oubre")
#PHO_df_2020_players.remove("Kelly Oubre")
PHO_df_2021_players.remove("E'Twaun Moore")

# %%
PHO_2000_gamelog = []


for p in PHO_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2000_gamelog.append(player_log)
PHO_2000_gamelog = pd.concat(PHO_2000_gamelog)    
PHO_2000_gamelogs = PHO_2000_gamelog.copy()
PHO_2000_gamelogs['GAME_SCORE'] = PHO_2000_gamelogs['GAME_SCORE'].astype(float)
PHO_2000_games = PHO_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2000_games_csv = PHO_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2000_games.csv', index=False)
PHO_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2000_games.csv')
PHO_2000_games_proc.head()
# Out:
# You searched for "Toby Bailey"
# 10 results found.
# 0: Toby Bailey
# 1: Tony Bradley
# 2: Tony Allen
# 3: John Bagley
# 4: Carl Bailey
# 5: Gus Bailey
# 6: Thurl Bailey
# 7: Bob Riley
# 8: Tony Battie
# 9: Toby Kimball
# Pick one: 0
# Results for Toby Bailey:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Rex Chapman"
# 1 result found.
# Rex Chapman
# Results for Rex Chapman:
#
# You searched for "Ben Davis"
# 29 results found.
# 0: Ben Davis
# 1: Bob Davis
# 2: Ed Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mel Davis
# 6: Red Davis
# 7: Ron Davis
# 8: Bob Davies
# 9: Baron Davis
# 10: Bill Davis
# 11: Brad Davis
# 12: Brian Davis
# 13: Jim Davis
# 14: Aubrey Davis
# 15: Dale Davis
# 16: Hubert Davis
# 17: Josh Davis
# 18: Mark Davis
# 19: Mark Davis
# 20: Mike Davis
# 21: Mike Davis
# 22: Monti Davis
# 23: Paul Davis
# 24: Terry Davis
# 25: Tyler Davis
# 26: Walt Davis
# ...

# %%
PHO_2001_gamelog = []


for p in PHO_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2001_gamelog.append(player_log)
PHO_2001_gamelog = pd.concat(PHO_2001_gamelog)    
PHO_2001_gamelogs = PHO_2001_gamelog.copy()
PHO_2001_gamelogs['GAME_SCORE'] = PHO_2001_gamelogs['GAME_SCORE'].astype(float)
PHO_2001_games = PHO_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2001_games_csv = PHO_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2001_games.csv', index=False)
PHO_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2001_games.csv')
PHO_2001_games_proc.head()
# Out:
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Vinny Del Negro"
# 1 result found.
# Vinny Del Negro
# Results for Vinny Del Negro:
#
# You searched for "Tony Delk"
# 12 results found.
# 0: Tony Delk
# 1: Tony Snell
# 2: Tony Zeno
# 3: Tony Allen
# 4: Troy Bell
# 5: Don Dee
# 6: Tony Dumas
# 7: Tony Koski
# 8: Deng Adel
# 9: Sonny Dove
# 10: Tony Price
# 11: Tony White
# Pick one: 0
# Results for Tony Delk:
#
# You searched for "Chris Dudley"
# 8 results found.
# 0: Chris Dudley
# 1: Charles Dudley
# 2: Chris Anstey
# 3: Jared Dudley
# 4: Chris Duhon
# 5: Chris Engler
# 6: Chris Hunter
# 7: Chris Mullin
# Pick one: 0
# Results for Chris Dudley:
#
# You searched for "Mario Elie"
# 3 results found.
# 0: Mario Elie
# 1: Marko Milic
# 2: Mario West
# Pick one: 0
# Results for Mario Elie:
#
# You searched for "Rubén Garcés"
# 1 result found.
# Ruben Garces
# Results for Ruben Garces:
#
# ...

# %%
PHO_2002_gamelog = []


for p in PHO_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2002_gamelog.append(player_log)
PHO_2002_gamelog = pd.concat(PHO_2002_gamelog)    
PHO_2002_gamelogs = PHO_2002_gamelog.copy()
PHO_2002_gamelogs['GAME_SCORE'] = PHO_2002_gamelogs['GAME_SCORE'].astype(float)
PHO_2002_games = PHO_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2002_games_csv = PHO_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2002_games.csv', index=False)
PHO_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2002_games.csv')
PHO_2002_games_proc.head()
# Out:
# You searched for "Charlie Bell"
# 6 results found.
# 0: Charlie Bell
# 1: Charlie Black
# 2: Charlie Brown
# 3: Charlie Paulk
# 4: Charlie Tyra
# 5: Charlie Ward
# Pick one: 0
# Results for Charlie Bell:
#
# You searched for "Jud Buechler"
# 1 result found.
# Jud Buechler
# Results for Jud Buechler:
#
# You searched for "Joe Crispin"
# 1 result found.
# Joe Crispin
# Results for Joe Crispin:
#
# You searched for "Vinny Del Negro"
# 1 result found.
# Vinny Del Negro
# Results for Vinny Del Negro:
#
# You searched for "Tony Delk"
# 12 results found.
# 0: Tony Delk
# 1: Tony Snell
# 2: Tony Zeno
# 3: Tony Allen
# 4: Troy Bell
# 5: Don Dee
# 6: Tony Dumas
# 7: Tony Koski
# 8: Deng Adel
# 9: Sonny Dove
# 10: Tony Price
# 11: Tony White
# Pick one: 0
# Results for Tony Delk:
#
# You searched for "Alton Ford"
# 6 results found.
# 0: Alton Ford
# 1: Don Ford
# 2: Alphonso Ford
# 3: Bob Ford
# 4: Al Horford
# 5: Leon Wood
# Pick one: 0
# Results for Alton Ford:
#
# ...

# %%
    
PHO_2003_gamelog = []



for p in PHO_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2003_gamelog.append(player_log)
PHO_2003_gamelog = pd.concat(PHO_2003_gamelog)    
PHO_2003_gamelogs = PHO_2003_gamelog.copy()
PHO_2003_gamelogs['GAME_SCORE'] = PHO_2003_gamelogs['GAME_SCORE'].astype(float)
PHO_2003_games = PHO_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2003_games_csv = PHO_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2003_games.csv', index=False)
PHO_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2003_games.csv')
PHO_2003_games_proc.head()
# Out:
# You searched for "Randy Brown"
# 18 results found.
# 0: Randy Brown
# 1: Andre Brown
# 2: Larry Brown
# 3: Tony Brown
# 4: Randy Allen
# 5: Randy Breuer
# 6: Bobby Brown
# 7: Fred Brown
# 8: Gerald Brown
# 9: Raymond Brown
# 10: Rickey Brown
# 11: Roger Brown
# 12: Roger Brown
# 13: Stan Brown
# 14: Troy Brown
# 15: Randy Foye
# 16: Randy Stoll
# 17: Randy Woods
# Pick one: 0
# Results for Randy Brown:
#
# You searched for "Alton Ford"
# 6 results found.
# 0: Alton Ford
# 1: Don Ford
# 2: Alphonso Ford
# 3: Bob Ford
# 4: Al Horford
# 5: Leon Wood
# Pick one: 0
# Results for Alton Ford:
#
# You searched for "Tom Gugliotta"
# 1 result found.
# Tom Gugliotta
# Results for Tom Gugliotta:
#
# You searched for "Anfernee Hardaway"
# 1 result found.
# Anfernee Hardaway
# Results for Anfernee Hardaway:
#
# You searched for "Casey Jacobsen"
# 1 result found.
# Casey Jacobsen
# Results for Casey Jacobsen:
#
# You searched for "Joe Johnson"
# 40 results found.
# 0: Joe Johnson
# 1: John Johnson
# ...

# %%
PHO_2004_gamelog = []



for p in PHO_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2004_gamelog.append(player_log)
PHO_2004_gamelog = pd.concat(PHO_2004_gamelog)    
PHO_2004_gamelogs = PHO_2004_gamelog.copy()
PHO_2004_gamelogs['GAME_SCORE'] = PHO_2004_gamelogs['GAME_SCORE'].astype(float)
PHO_2004_games = PHO_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2004_games_csv = PHO_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2004_games.csv', index=False)
PHO_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2004_games.csv')
PHO_2004_games_proc.head()
# Out:
# You searched for "Robert Archibald"
# 1 result found.
# Robert Archibald
# Results for Robert Archibald:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Žarko Čabarkapa"
# 1 result found.
# Zarko Cabarkapa
# Results for Zarko Cabarkapa:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Tom Gugliotta"
# 1 result found.
# Tom Gugliotta
# Results for Tom Gugliotta:
#
# You searched for "Anfernee Hardaway"
# 1 result found.
# Anfernee Hardaway
# Results for Anfernee Hardaway:
#
# You searched for "Donnell Harvey"
# 1 result found.
# Donnell Harvey
# Results for Donnell Harvey:
#
# You searched for "Casey Jacobsen"
# 1 result found.
# Casey Jacobsen
# Results for Casey Jacobsen:
#
# You searched for "Joe Johnson"
# 40 results found.
# 0: Joe Johnson
# 1: John Johnson
# 2: Lee Johnson
# 3: Ron Johnson
# ...

# %%
PHO_2005_gamelog = []



for p in PHO_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2005_gamelog.append(player_log)
PHO_2005_gamelog = pd.concat(PHO_2005_gamelog)    
PHO_2005_gamelogs = PHO_2005_gamelog.copy()
PHO_2005_gamelogs['GAME_SCORE'] = PHO_2005_gamelogs['GAME_SCORE'].astype(float)
PHO_2005_games = PHO_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2005_games_csv = PHO_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2005_games.csv', index=False)
PHO_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2005_games.csv')
PHO_2005_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Žarko Čabarkapa"
# 1 result found.
# Zarko Cabarkapa
# Results for Zarko Cabarkapa:
#
# You searched for "Steven Hunter"
# 4 results found.
# 0: Steven Hunter
# 1: Steve Colter
# 2: Steve Hamer
# 3: Steven Kramer
# Pick one: 0
# Results for Steven Hunter:
#
# You searched for "Jim Jackson"
# 21 results found.
# 0: Jim Jackson
# 1: Al Jackson
# 2: Josh Jackson
# 3: Mike Jackson
# 4: Phil Jackson
# 5: Jim Paxson
# 6: Jim Paxson
# 7: Greg Jackson
# 8: Jaren Jackson
# 9: Jaren Jackson
# 10: Justin Jackson
# 11: Luke Jackson
# 12: Luke Jackson
# 13: Marc Jackson
# 14: Mark Jackson
# 15: Tony Jackson
# 16: Tony Jackson
# 17: Sam Jacobson
# 18: Jim Wilson
# 19: Jim Eakins
# 20: Jim Chones
# Pick one: 0
# Results for Jim Jackson:
#
# You searched for "Casey Jacobsen"
# 1 result found.
# Casey Jacobsen
# Results for Casey Jacobsen:
# ...

# %%
PHO_2006_gamelog = []

for p in PHO_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2006_gamelog.append(player_log)
PHO_2006_gamelog = pd.concat(PHO_2006_gamelog)    
PHO_2006_gamelogs = PHO_2006_gamelog.copy()
PHO_2006_gamelogs['GAME_SCORE'] = PHO_2006_gamelogs['GAME_SCORE'].astype(float)
PHO_2006_games = PHO_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2006_games_csv = PHO_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2006_games.csv', index=False)
PHO_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2006_games.csv')
PHO_2006_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Pat Burke"
# 7 results found.
# 0: Pat Burke
# 1: Walt Budko
# 2: Trey Burke
# 3: Pat Dunn
# 4: Pat Durham
# 5: Pat Frink
# 6: Walt Kirk
# Pick one: 0
# Results for Pat Burke:
#
# You searched for "Josh Davis"
# 27 results found.
# 0: Josh Davis
# 1: Bob Davis
# 2: Jim Davis
# 3: Ron Davis
# 4: Josh Reaves
# 5: Josh Hall
# 6: Bob Davies
# 7: Ben Davis
# 8: Bill Davis
# 9: Brad Davis
# 10: Dale Davis
# 11: Ed Davis
# 12: Glen Davis
# 13: Johnny Davis
# 14: Lee Davis
# 15: Mark Davis
# 16: Mark Davis
# 17: Mel Davis
# ...

# %%
PHO_2007_gamelog = []

for p in PHO_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2007_gamelog.append(player_log)
PHO_2007_gamelog = pd.concat(PHO_2007_gamelog)    
PHO_2007_gamelogs = PHO_2007_gamelog.copy()
PHO_2007_gamelogs['GAME_SCORE'] = PHO_2007_gamelogs['GAME_SCORE'].astype(float)
PHO_2007_games = PHO_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2007_games_csv = PHO_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2007_games.csv', index=False)
PHO_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2007_games.csv')
PHO_2007_games_proc.head()
# Out:
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Pat Burke"
# 7 results found.
# 0: Pat Burke
# 1: Walt Budko
# 2: Trey Burke
# 3: Pat Dunn
# 4: Pat Durham
# 5: Pat Frink
# 6: Walt Kirk
# Pick one: 0
# Results for Pat Burke:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# You searched for "James Jones"
# 32 results found.
# 0: James Jones
# 1: Jake Jones
# 2: Jalen Jones
# 3: James Ennis
# 4: Damon Jones
# 5: Jimmy Jones
# 6: Sam Jones
# 7: James Posey
# 8: Tre Jones
# 9: Mason Jones
# 10: James Johnson
# ...

# %%
PHO_2008_gamelog = []

for p in PHO_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2008_gamelog.append(player_log)
PHO_2008_gamelog = pd.concat(PHO_2008_gamelog)    
PHO_2008_gamelogs = PHO_2008_gamelog.copy()
PHO_2008_gamelogs['GAME_SCORE'] = PHO_2008_gamelogs['GAME_SCORE'].astype(float)
PHO_2008_games = PHO_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2008_games_csv = PHO_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2008_games.csv', index=False)
PHO_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2008_games.csv')
PHO_2008_games_proc.head()
# Out:
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Grant Hill"
# 8 results found.
# 0: Grant Hill
# 1: Grant Riller
# 2: Gary Hill
# 3: Craig Dill
# 4: Armond Hill
# 5: Jordan Hill
# 6: Tyrone Hill
# 7: Grant Long
# Pick one: 0
# Results for Grant Hill:
#
# You searched for "Linton Johnson"
# 9 results found.
# 0: Linton Johnson
# 1: Britton Johnsen
# ...

# %%
# removed dee brown

PHO_2009_gamelog = []

for p in PHO_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2009_gamelog.append(player_log)
PHO_2009_gamelog = pd.concat(PHO_2009_gamelog)    
PHO_2009_gamelogs = PHO_2009_gamelog.copy()
PHO_2009_gamelogs['GAME_SCORE'] = PHO_2009_gamelogs['GAME_SCORE'].astype(float)
PHO_2009_games = PHO_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2009_games_csv = PHO_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2009_games.csv', index=False)
PHO_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2009_games.csv')
PHO_2009_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# 2: Chris Dudley
# ...

# %%
PHO_2010_gamelog = []

for p in PHO_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2010_gamelog.append(player_log)
PHO_2010_gamelog = pd.concat(PHO_2010_gamelog)    
PHO_2010_gamelogs = PHO_2010_gamelog.copy()
PHO_2010_gamelogs['GAME_SCORE'] = PHO_2010_gamelogs['GAME_SCORE'].astype(float)
PHO_2010_games = PHO_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2010_games_csv = PHO_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2010_games.csv', index=False)
PHO_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2010_games.csv')
PHO_2010_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# 4: Keon Clark
# 5: Earl Evans
# 6: Earl Lloyd
# Pick one: 0
# Results for Earl Clark:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# ...

# %%
PHO_2011_gamelog = []

for p in PHO_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2011_gamelog.append(player_log)
PHO_2011_gamelog = pd.concat(PHO_2011_gamelog)    
PHO_2011_gamelogs = PHO_2011_gamelog.copy()
PHO_2011_gamelogs['GAME_SCORE'] = PHO_2011_gamelogs['GAME_SCORE'].astype(float)
PHO_2011_games = PHO_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2011_games_csv = PHO_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2011_games.csv', index=False)
PHO_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2011_games.csv')
PHO_2011_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Earl Clark"
# 7 results found.
# 0: Earl Clark
# 1: Gary Clark
# 2: Carlos Clark
# 3: Ian Clark
# 4: Keon Clark
# 5: Earl Evans
# 6: Earl Lloyd
# Pick one: 0
# Results for Earl Clark:
#
# ...

# %%
PHO_2012_gamelog = []

for p in PHO_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2012_gamelog.append(player_log)
PHO_2012_gamelog = pd.concat(PHO_2012_gamelog)    
PHO_2012_gamelogs = PHO_2012_gamelog.copy()
PHO_2012_gamelogs['GAME_SCORE'] = PHO_2012_gamelogs['GAME_SCORE'].astype(float)
PHO_2012_games = PHO_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2012_games_csv = PHO_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2012_games.csv', index=False)
PHO_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2012_games.csv')
PHO_2012_games_proc.head()
# Out:
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Josh Childress"
# 1 result found.
# Josh Childress
# Results for Josh Childress:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# 2: Chris Dudley
# Pick one: 0
# Results for Jared Dudley:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Grant Hill"
# 8 results found.
# 0: Grant Hill
# 1: Grant Riller
# 2: Gary Hill
# 3: Craig Dill
# 4: Armond Hill
# 5: Jordan Hill
# 6: Tyrone Hill
# 7: Grant Long
# Pick one: 0
# Results for Grant Hill:
#
# You searched for "Robin Lopez"
# 4 results found.
# 0: Robin Lopez
# 1: Robin Jones
# 2: Brook Lopez
# 3: Raul Lopez
# Pick one: 0
# Results for Robin Lopez:
#
# ...

# %%
# removed jermaine o'neakl 
PHO_2013_gamelog = []

for p in PHO_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2013_gamelog.append(player_log)
PHO_2013_gamelog = pd.concat(PHO_2013_gamelog)    
PHO_2013_gamelogs = PHO_2013_gamelog.copy()
PHO_2013_gamelogs['GAME_SCORE'] = PHO_2013_gamelogs['GAME_SCORE'].astype(float)
PHO_2013_games = PHO_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2013_games_csv = PHO_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2013_games.csv', index=False)
PHO_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2013_games.csv')
PHO_2013_games_proc.head()
# Out:
# You searched for "Michael Beasley"
# 5 results found.
# 0: Michael Beasley
# 1: Michael Bradley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Wiley
# Pick one: 0
# Results for Michael Beasley:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# 2: Chris Dudley
# Pick one: 0
# Results for Jared Dudley:
#
# You searched for "Diante Garrett"
# 3 results found.
# 0: Diante Garrett
# 1: Dean Garrett
# 2: Dick Garrett
# Pick one: 0
# Results for Diante Garrett:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Hamed Haddadi"
# 1 result found.
# Hamed Haddadi
# Results for Hamed Haddadi:
#
# ...

# %%
PHO_2014_gamelog = []

for p in PHO_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2014_gamelog.append(player_log)
PHO_2014_gamelog = pd.concat(PHO_2014_gamelog)    
PHO_2014_gamelogs = PHO_2014_gamelog.copy()
PHO_2014_gamelogs['GAME_SCORE'] = PHO_2014_gamelogs['GAME_SCORE'].astype(float)
PHO_2014_games = PHO_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2014_games_csv = PHO_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2014_games.csv', index=False)
PHO_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2014_games.csv')
PHO_2014_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Dionte Christmas"
# 1 result found.
# Dionte Christmas
# Results for Dionte Christmas:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# You searched for "Archie Goodwin"
# 1 result found.
# Archie Goodwin
# Results for Archie Goodwin:
#
# You searched for "Gerald Green"
# 6 results found.
# 0: Gerald Green
# 1: Gerald Brown
# 2: Gerald Govan
# 3: Gerald Glass
# 4: Erick Green
# 5: Sean Green
# Pick one: 0
# Results for Gerald Green:
#
# You searched for "Viacheslav Kravtsov"
# 1 result found.
# Viacheslav Kravtsov
# ...

# %%
PHO_2015_gamelog = []

for p in PHO_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2015_gamelog.append(player_log)
PHO_2015_gamelog = pd.concat(PHO_2015_gamelog)    
PHO_2015_gamelogs = PHO_2015_gamelog.copy()
PHO_2015_gamelogs['GAME_SCORE'] = PHO_2015_gamelogs['GAME_SCORE'].astype(float)
PHO_2015_games = PHO_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2015_games_csv = PHO_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2015_games.csv', index=False)
PHO_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2015_games.csv')
PHO_2015_games_proc.head()
# Out:
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Seth Curry"
# 4 results found.
# 0: Seth Curry
# 1: Dell Curry
# 2: Eddy Curry
# 3: Stephen Curry
# Pick one: 0
# Results for Seth Curry:
#
# You searched for "Goran Dragić"
# 2 results found.
# 0: Goran Dragic
# 1: Zoran Dragic
# Pick one: 0
# Results for Goran Dragic:
#
# You searched for "Zoran Dragić"
# 2 results found.
# 0: Zoran Dragic
# 1: Goran Dragic
# Pick one: 0
# Results for Zoran Dragic:
#
# You searched for "Tyler Ennis"
# 6 results found.
# 0: Tyler Ennis
# 1: Tyler Davis
# 2: Tyler Ulis
# ...

# %%
PHO_2016_gamelog = []

for p in PHO_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2016_gamelog.append(player_log)
PHO_2016_gamelog = pd.concat(PHO_2016_gamelog)    
PHO_2016_gamelogs = PHO_2016_gamelog.copy()
PHO_2016_gamelogs['GAME_SCORE'] = PHO_2016_gamelogs['GAME_SCORE'].astype(float)
PHO_2016_games = PHO_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2016_games_csv = PHO_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2016_games.csv', index=False)
PHO_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2016_games.csv')
PHO_2016_games_proc.head()
# Out:
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# 8: Kevin Porter
# 9: Kevin Porter
# 10: Devin Ebanks
# Pick one: 0
# Results for Devin Booker:
#
# You searched for "Lorenzo Brown"
# 2 results found.
# 0: Lorenzo Brown
# 1: Lorenzo Romar
# Pick one: 0
# Results for Lorenzo Brown:
#
# You searched for "Chase Budinger"
# 1 result found.
# Chase Budinger
# Results for Chase Budinger:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Bryce Cotton"
# 2 results found.
# 0: Bryce Cotton
# 1: Jack Cotton
# Pick one: 0
# Results for Bryce Cotton:
#
# You searched for "Archie Goodwin"
# 1 result found.
# Archie Goodwin
# ...

# %%
# removed Derrick Jones

PHO_2017_gamelog = []

for p in PHO_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2017_gamelog.append(player_log)
PHO_2017_gamelog = pd.concat(PHO_2017_gamelog)    
PHO_2017_gamelogs = PHO_2017_gamelog.copy()
PHO_2017_gamelogs['GAME_SCORE'] = PHO_2017_gamelogs['GAME_SCORE'].astype(float)
PHO_2017_games = PHO_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2017_games_csv = PHO_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2017_games.csv', index=False)
PHO_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2017_games.csv')
PHO_2017_games_proc.head()
# Out:
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# 8: Kevin Porter
# 9: Kevin Porter
# 10: Devin Ebanks
# Pick one: 0
# Results for Devin Booker:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# ...

# %%
# removed mike james
# removed derrick jones

PHO_2018_gamelog = []

for p in PHO_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2018_gamelog.append(player_log)
PHO_2018_gamelog = pd.concat(PHO_2018_gamelog)    
PHO_2018_gamelogs = PHO_2018_gamelog.copy()
PHO_2018_gamelogs['GAME_SCORE'] = PHO_2018_gamelogs['GAME_SCORE'].astype(float)
PHO_2018_games = PHO_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2018_games_csv = PHO_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2018_games.csv', index=False)
PHO_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2018_games.csv')
PHO_2018_games_proc.head()
# Out:
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Eric Bledsoe"
# 1 result found.
# Eric Bledsoe
# Results for Eric Bledsoe:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# 8: Kevin Porter
# 9: Kevin Porter
# 10: Devin Ebanks
# Pick one: 0
# Results for Devin Booker:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Tyson Chandler"
# 3 results found.
# 0: Tyson Chandler
# 1: Wilson Chandler
# 2: Tyson Wheeler
# Pick one: 0
# Results for Tyson Chandler:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Troy Daniels"
# 4 results found.
# 0: Troy Daniels
# 1: Erik Daniels
# 2: Lloyd Daniels
# 3: Mel Daniels
# Pick one: 0
# ...

# %%
# remove george king
# removed kelly oubre 
PHO_2019_gamelog = []

for p in PHO_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2019_gamelog.append(player_log)
PHO_2019_gamelog = pd.concat(PHO_2019_gamelog)    
PHO_2019_gamelogs = PHO_2019_gamelog.copy()
PHO_2019_gamelogs['GAME_SCORE'] = PHO_2019_gamelogs['GAME_SCORE'].astype(float)
PHO_2019_games = PHO_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2019_games_csv = PHO_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2019_games.csv', index=False)
PHO_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2019_games.csv')
PHO_2019_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Ryan Anderson"
# 14 results found.
# 0: Ryan Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Ron Anderson
# 5: Kyle Anderson
# 6: Eric Anderson
# 7: Greg Anderson
# 8: J.J. Anderson
# 9: Kenny Anderson
# 10: Kim Anderson
# 11: Nick Anderson
# 12: Alan Henderson
# 13: Ryan Robertson
# Pick one: 0
# Results for Ryan Anderson:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# ...

# %%
# removed kelly oubre

PHO_2020_gamelog = []

for p in PHO_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2020_gamelog.append(player_log)
PHO_2020_gamelog = pd.concat(PHO_2020_gamelog)    
PHO_2020_gamelogs = PHO_2020_gamelog.copy()
PHO_2020_gamelogs['GAME_SCORE'] = PHO_2020_gamelogs['GAME_SCORE'].astype(float)
PHO_2020_games = PHO_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2020_games_csv = PHO_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2020_games.csv', index=False)
PHO_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2020_games.csv')
PHO_2020_games_proc.head()
# Out:
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "Jonah Bolden"
# 2 results found.
# 0: Jonah Bolden
# 1: Jordan Bowden
# Pick one: 0
# Results for Jonah Bolden:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# 8: Kevin Porter
# 9: Kevin Porter
# 10: Devin Ebanks
# Pick one: 0
# Results for Devin Booker:
#
# You searched for "Mikal Bridges"
# 3 results found.
# 0: Mikal Bridges
# 1: Bill Bridges
# 2: Miles Bridges
# Pick one: 0
# Results for Mikal Bridges:
#
# You searched for "Jevon Carter"
# 5 results found.
# 0: Jevon Carter
# ...

# %%
# remvoed E'Twaun Moore
PHO_2021_gamelog = []

for p in PHO_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    PHO_2021_gamelog.append(player_log)
PHO_2021_gamelog = pd.concat(PHO_2021_gamelog)    
PHO_2021_gamelogs = PHO_2021_gamelog.copy()
PHO_2021_gamelogs['GAME_SCORE'] = PHO_2021_gamelogs['GAME_SCORE'].astype(float)
PHO_2021_games = PHO_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_2021_games_csv = PHO_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2021_games.csv', index=False)
PHO_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2021_games.csv')
PHO_2021_games_proc.head()
# Out:
# You searched for "Ty-Shon Alexander"
# 1 result found.
# Ty-Shon Alexander
# Results for Ty-Shon Alexander:
#
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Devin Booker"
# 11 results found.
# 0: Devin Booker
# 1: Melvin Booker
# 2: Vin Baker
# 3: Trevor Booker
# 4: Kevin Brooks
# 5: Devin Brown
# 6: David Cooke
# 7: Kevin Loder
# 8: Kevin Porter
# 9: Kevin Porter
# 10: Devin Ebanks
# Pick one: 0
# Results for Devin Booker:
#
# You searched for "Mikal Bridges"
# 3 results found.
# 0: Mikal Bridges
# 1: Bill Bridges
# 2: Miles Bridges
# Pick one: 0
# Results for Mikal Bridges:
#
# You searched for "Jevon Carter"
# 5 results found.
# 0: Jevon Carter
# 1: Ron Carter
# 2: Jake Carter
# 3: Kevin Porter
# 4: Kevin Porter
# Pick one: 0
# Results for Jevon Carter:
#
# You searched for "Torrey Craig"
# 1 result found.
# Torrey Craig
# Results for Torrey Craig:
#
# You searched for "Jae Crowder"
# 4 results found.
# ...

# %% [markdown]
# ## combine all seasons

# %%
PHO_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2000_games.csv')
PHO_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2001_games.csv')
PHO_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2002_games.csv')
PHO_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2003_games.csv')
PHO_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2004_games.csv')
PHO_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2005_games.csv')
PHO_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2006_games.csv')
PHO_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2007_games.csv')
PHO_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2008_games.csv')
PHO_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2009_games.csv')
PHO_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2010_games.csv')
PHO_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2011_games.csv')
PHO_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2012_games.csv')
PHO_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2013_games.csv')
PHO_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2014_games.csv')
PHO_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2015_games.csv')
PHO_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2016_games.csv')
PHO_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2017_games.csv')
PHO_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2018_games.csv')
PHO_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2019_games.csv')
PHO_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2020_games.csv')
PHO_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/PHO/PHO_2021_games.csv')

# %%
PHO_season_dfs = [PHO_2000_games_io, PHO_2001_games_io, PHO_2002_games_io, PHO_2003_games_io, PHO_2004_games_io, PHO_2005_games_io,
                 PHO_2006_games_io, PHO_2007_games_io, PHO_2008_games_io, PHO_2009_games_io, PHO_2010_games_io, PHO_2011_games_io,
                 PHO_2012_games_io, PHO_2013_games_io, PHO_2014_games_io, PHO_2015_games_io, PHO_2016_games_io, PHO_2017_games_io,
                 PHO_2018_games_io, PHO_2019_games_io, PHO_2020_games_io, PHO_2021_games_io]

# %%
PHO_all = pd.concat(PHO_season_dfs)
PHO_all_sorted = PHO_all.sort_values(by=['GAME_SCORE'], ascending=False)
PHO_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2017-03-24  20-145  PHO      AWAY      BOS  L (-10)   1  44:58  21   40
# 0  2008-11-05  25-355  PHO      AWAY      IND  W (+10)   1  44:00  17   21
# 0  2000-01-16  33-031  PHO      HOME      DEN  W (+13)   1  42:31  17   26
# 0  2006-02-22  27-291  PHO      HOME      BOS   W (+9)   1  43:02  15   22
# 1  2009-02-20  26-084  PHO      HOME      OKC  W (+22)   1  41:42  16   21
# 0  2005-01-02  22-047  PHO      HOME      POR  W (+19)   1  41:11  20   27
# 0  2001-01-02  26-340  PHO      AWAY      SAC   L (-4)   1  49:51  20   27
# 0  2007-02-25  24-101  PHO      AWAY      ATL   W (+9)   1  44:33  14   25
# 1  2005-04-08  22-143  PHO      AWAY      GSW   L (-8)   1  42:09  15   25
# 0  2003-12-29  26-312  PHO      AWAY      LAC   W (+8)   1  41:46  15   23
# 2  2004-12-18  26-225  PHO      HOME      WAS  W (+14)   1  43:40  13   18
# ...
