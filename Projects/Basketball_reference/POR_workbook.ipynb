# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_POR = []

# POR
while season <= 2021:
    df_POR = get_roster('POR', season)
    df_POR['Season'] = season
    df_POR['Team'] = 'POR'
    appended_data_POR.append(df_POR)
    season = season + 1
appended_data_POR = pd.concat(appended_data_POR)

# %%
POR_df_all = appended_data_POR.copy()
POR_df_all_csv = POR_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_players_all.csv', index=False)
POR_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_players_all.csv')
POR_df_all_csv_io.head()
# Out:
#   NUMBER          PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0     50    Greg Anthony  PG    6-0     176  1967-11-15          US
# 1      2   Stacey Augmon  SG    6-8     205  1968-08-01          US
# 2     44     Brian Grant  PF    6-9     254  1972-03-05          US
# 3     14      Gary Grant  PG    6-3     185  1965-04-21          US
# 4     34  Antonio Harvey  PF   6-11     225  1970-07-06          US
#
#   EXPERIENCE                                          COLLEGE  Season Team
# 0          8                     University of Portland, UNLV    2000  POR
# 1          8                                             UNLV    2000  POR
# 2          5                                           Xavier    2000  POR
# 3         11                                         Michigan    2000  POR
# 4          4  Southern Illinois, Georgia, Pfeiffer University    2000  POR

# %%
POR_df_2000 = POR_df_all[POR_df_all['Season'] == 2000]
POR_df_2001 = POR_df_all[POR_df_all['Season'] == 2001]
POR_df_2002 = POR_df_all[POR_df_all['Season'] == 2002]
POR_df_2003 = POR_df_all[POR_df_all['Season'] == 2003]
POR_df_2004 = POR_df_all[POR_df_all['Season'] == 2004]
POR_df_2005 = POR_df_all[POR_df_all['Season'] == 2005]
POR_df_2006 = POR_df_all[POR_df_all['Season'] == 2006]
POR_df_2007 = POR_df_all[POR_df_all['Season'] == 2007]
POR_df_2008 = POR_df_all[POR_df_all['Season'] == 2008]
POR_df_2009 = POR_df_all[POR_df_all['Season'] == 2009]
POR_df_2010 = POR_df_all[POR_df_all['Season'] == 2010]
POR_df_2011 = POR_df_all[POR_df_all['Season'] == 2011]
POR_df_2012 = POR_df_all[POR_df_all['Season'] == 2012]
POR_df_2013 = POR_df_all[POR_df_all['Season'] == 2013]
POR_df_2014 = POR_df_all[POR_df_all['Season'] == 2014]
POR_df_2015 = POR_df_all[POR_df_all['Season'] == 2015]
POR_df_2016 = POR_df_all[POR_df_all['Season'] == 2016]
POR_df_2017 = POR_df_all[POR_df_all['Season'] == 2017]
POR_df_2018 = POR_df_all[POR_df_all['Season'] == 2018]
POR_df_2019 = POR_df_all[POR_df_all['Season'] == 2019]
POR_df_2020 = POR_df_all[POR_df_all['Season'] == 2020]
POR_df_2021 = POR_df_all[POR_df_all['Season'] == 2021]

# %%
# changing names
#POR_df_2002.loc[POR_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#POR_df_2004.loc[POR_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
POR_df_2000_players = POR_df_2000['PLAYER'].to_list()
POR_df_2001_players = POR_df_2001['PLAYER'].to_list()
POR_df_2002_players = POR_df_2002['PLAYER'].to_list()
POR_df_2003_players = POR_df_2003['PLAYER'].to_list()
POR_df_2004_players = POR_df_2004['PLAYER'].to_list()
POR_df_2005_players = POR_df_2005['PLAYER'].to_list()

POR_df_2006_players = POR_df_2006['PLAYER'].to_list()
POR_df_2007_players = POR_df_2007['PLAYER'].to_list()
POR_df_2008_players = POR_df_2008['PLAYER'].to_list()
POR_df_2009_players = POR_df_2009['PLAYER'].to_list()
POR_df_2010_players = POR_df_2010['PLAYER'].to_list()
POR_df_2011_players = POR_df_2011['PLAYER'].to_list()

POR_df_2012_players = POR_df_2012['PLAYER'].to_list()
POR_df_2013_players = POR_df_2013['PLAYER'].to_list()
POR_df_2014_players = POR_df_2014['PLAYER'].to_list()
POR_df_2015_players = POR_df_2015['PLAYER'].to_list()
POR_df_2016_players = POR_df_2016['PLAYER'].to_list()
POR_df_2017_players = POR_df_2017['PLAYER'].to_list()

POR_df_2018_players = POR_df_2018['PLAYER'].to_list()
POR_df_2019_players = POR_df_2019['PLAYER'].to_list()
POR_df_2020_players = POR_df_2020['PLAYER'].to_list()
POR_df_2021_players = POR_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#POR_df_2000_players.remove("Jermaine O'Neal")
#POR_df_2003_players.remove("Charles Smith")
#POR_df_2006_players.remove("Charles Smith")
#POR_df_2010_players.remove("Jeff Ayres")
#POR_df_2013_players.remove("Sasha Pavlović")
#POR_df_2014_players.remove("Mo Williams")
#POR_df_2016_players.remove("Gerald Henderson")
#POR_df_2019_players.remove("Gary Trent")
#POR_df_2020_players.remove("Gary Trent")
POR_df_2021_players.remove("Gary Trent")
POR_df_2021_players.remove("Derrick Jones")

# %%
POR_2000_gamelog = []


for p in POR_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2000_gamelog.append(player_log)
POR_2000_gamelog = pd.concat(POR_2000_gamelog)    
POR_2000_gamelogs = POR_2000_gamelog.copy()
POR_2000_gamelogs['GAME_SCORE'] = POR_2000_gamelogs['GAME_SCORE'].astype(float)
POR_2000_games = POR_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2000_games_csv = POR_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2000_games.csv', index=False)
POR_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2000_games.csv')
POR_2000_games_proc.head()
# Out:
# You searched for "Greg Anthony"
# 6 results found.
# 0: Greg Anthony
# 1: Joel Anthony
# 2: Cole Anthony
# 3: Greg Sutton
# 4: Greg Anderson
# 5: Greg Jackson
# Pick one: 0
# Results for Greg Anthony:
#
# You searched for "Stacey Augmon"
# 1 result found.
# Stacey Augmon
# Results for Stacey Augmon:
#
# You searched for "Brian Grant"
# 9 results found.
# 0: Brian Grant
# 1: Jerian Grant
# 2: Brian Evans
# 3: Bud Grant
# 4: Greg Grant
# 5: Brian Heaney
# 6: Brian Shaw
# 7: Brian Bowen
# 8: Brian Martin
# Pick one: 0
# Results for Brian Grant:
#
# You searched for "Gary Grant"
# 20 results found.
# 0: Gary Grant
# 1: Gary Gray
# 2: Gary Trent
# 3: Gary Trent
# 4: Gary Garland
# 5: Greg Grant
# 6: Harvey Grant
# 7: Paul Grant
# 8: Gary Bradds
# 9: Mark Bryant
# 10: Gary Clark
# 11: Bud Grant
# 12: Josh Grant
# 13: Gary Gregor
# 14: Gary Neal
# 15: Gary Bergen
# 16: Carl Braun
# 17: Gary Brokaw
# 18: Gary Freeman
# 19: Aaron Gray
# Pick one: 0
# Results for Gary Grant:
#
# ...

# %%
POR_2001_gamelog = []


for p in POR_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2001_gamelog.append(player_log)
POR_2001_gamelog = pd.concat(POR_2001_gamelog)    
POR_2001_gamelogs = POR_2001_gamelog.copy()
POR_2001_gamelogs['GAME_SCORE'] = POR_2001_gamelogs['GAME_SCORE'].astype(float)
POR_2001_games = POR_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2001_games_csv = POR_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2001_games.csv', index=False)
POR_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2001_games.csv')
POR_2001_games_proc.head()
# Out:
# You searched for "Greg Anthony"
# 6 results found.
# 0: Greg Anthony
# 1: Joel Anthony
# 2: Cole Anthony
# 3: Greg Sutton
# 4: Greg Anderson
# 5: Greg Jackson
# Pick one: 0
# Results for Greg Anthony:
#
# You searched for "Stacey Augmon"
# 1 result found.
# Stacey Augmon
# Results for Stacey Augmon:
#
# You searched for "Erick Barkley"
# 5 results found.
# 0: Erick Barkley
# 1: Rick Barry
# 2: Dick Farley
# 3: Eric Riley
# 4: Derrick Byars
# Pick one: 0
# Results for Erick Barkley:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# 19: Charles Davis
# 20: Charlie Davis
# 21: Ed Davis
# 22: Harry Davis
# 23: Jim Davis
# 24: Josh Davis
# 25: Red Davis
# 26: Ron Davis
# ...

# %%
POR_2002_gamelog = []


for p in POR_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2002_gamelog.append(player_log)
POR_2002_gamelog = pd.concat(POR_2002_gamelog)    
POR_2002_gamelogs = POR_2002_gamelog.copy()
POR_2002_gamelogs['GAME_SCORE'] = POR_2002_gamelogs['GAME_SCORE'].astype(float)
POR_2002_games = POR_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2002_games_csv = POR_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2002_games.csv', index=False)
POR_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2002_games.csv')
POR_2002_games_proc.head()
# Out:
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Erick Barkley"
# 5 results found.
# 0: Erick Barkley
# 1: Rick Barry
# 2: Dick Farley
# 3: Eric Riley
# 4: Derrick Byars
# Pick one: 0
# Results for Erick Barkley:
#
# You searched for "Ruben Boumtje-Boumtje"
# 1 result found.
# Ruben Boumtje-Boumtje
# Results for Ruben Boumtje-Boumtje:
#
# You searched for "Rick Brunson"
# 6 results found.
# 0: Rick Brunson
# 1: Ricky Blanton
# 2: Nick Johnson
# 3: Rich Johnson
# 4: Rick Wilson
# 5: Rickey Brown
# Pick one: 0
# Results for Rick Brunson:
#
# You searched for "Mitchell Butler"
# 1 result found.
# Mitchell Butler
# Results for Mitchell Butler:
#
# You searched for "Dale Davis"
# ...

# %%
    
POR_2003_gamelog = []



for p in POR_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2003_gamelog.append(player_log)
POR_2003_gamelog = pd.concat(POR_2003_gamelog)    
POR_2003_gamelogs = POR_2003_gamelog.copy()
POR_2003_gamelogs['GAME_SCORE'] = POR_2003_gamelogs['GAME_SCORE'].astype(float)
POR_2003_games = POR_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2003_games_csv = POR_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2003_games.csv', index=False)
POR_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2003_games.csv')
POR_2003_games_proc.head()
# Out:
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Ruben Boumtje-Boumtje"
# 1 result found.
# Ruben Boumtje-Boumtje
# Results for Ruben Boumtje-Boumtje:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# 2: Bill Davis
# 3: Glen Davis
# 4: Lee Davis
# 5: Mark Davis
# 6: Mark Davis
# 7: Mel Davis
# 8: Mike Davis
# 9: Mike Davis
# 10: Paul Davis
# 11: Ralph Davis
# 12: Tyler Davis
# 13: Walter Davis
# 14: Dale Ellis
# 15: Baron Davis
# 16: Ben Davis
# 17: Bob Davis
# 18: Brad Davis
# 19: Charles Davis
# ...

# %%
POR_2004_gamelog = []



for p in POR_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2004_gamelog.append(player_log)
POR_2004_gamelog = pd.concat(POR_2004_gamelog)    
POR_2004_gamelogs = POR_2004_gamelog.copy()
POR_2004_gamelogs['GAME_SCORE'] = POR_2004_gamelogs['GAME_SCORE'].astype(float)
POR_2004_games = POR_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2004_games_csv = POR_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2004_games.csv', index=False)
POR_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2004_games.csv')
POR_2004_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Ruben Boumtje-Boumtje"
# 1 result found.
# Ruben Boumtje-Boumtje
# Results for Ruben Boumtje-Boumtje:
#
# You searched for "Matt Carroll"
# 1 result found.
# Matt Carroll
# Results for Matt Carroll:
#
# You searched for "Omar Cook"
# 9 results found.
# 0: Omar Cook
# 1: Omer Asik
# 2: Bert Cook
# 3: Bobby Cook
# 4: Brian Cook
# 5: Jeff Cook
# 6: Norm Cook
# 7: Tyler Cook
# 8: Mark Crow
# Pick one: 0
# Results for Omar Cook:
#
# You searched for "Dale Davis"
# 29 results found.
# 0: Dale Davis
# 1: Walt Davis
# ...

# %%
POR_2005_gamelog = []



for p in POR_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2005_gamelog.append(player_log)
POR_2005_gamelog = pd.concat(POR_2005_gamelog)    
POR_2005_gamelogs = POR_2005_gamelog.copy()
POR_2005_gamelogs['GAME_SCORE'] = POR_2005_gamelogs['GAME_SCORE'].astype(float)
POR_2005_games = POR_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2005_games_csv = POR_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2005_games.csv', index=False)
POR_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2005_games.csv')
POR_2005_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Maurice Baker"
# 9 results found.
# 0: Maurice Baker
# 1: Maurice Ager
# 2: Maurice Carter
# 3: Maurice Ndour
# 4: Maurice Stokes
# 5: Maurice Taylor
# 6: Maurice Evans
# 7: Maurice King
# 8: Maurice Lucas
# Pick one: 0
# Results for Maurice Baker:
#
# You searched for "Geno Carlisle"
# 3 results found.
# 0: Geno Carlisle
# 1: Chet Carlisle
# 2: Rick Carlisle
# Pick one: 0
# Results for Geno Carlisle:
#
# You searched for "Richie Frahm"
# 2 results found.
# 0: Richie Frahm
# 1: Richie Regan
# Pick one: 0
# ...

# %%
POR_2006_gamelog = []

for p in POR_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2006_gamelog.append(player_log)
POR_2006_gamelog = pd.concat(POR_2006_gamelog)    
POR_2006_gamelogs = POR_2006_gamelog.copy()
POR_2006_gamelogs['GAME_SCORE'] = POR_2006_gamelogs['GAME_SCORE'].astype(float)
POR_2006_games = POR_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2006_games_csv = POR_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2006_games.csv', index=False)
POR_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2006_games.csv')
POR_2006_games_proc.head()
# Out:
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "Jarrett Jack"
# 1 result found.
# Jarrett Jack
# Results for Jarrett Jack:
#
# You searched for "Viktor Khryapa"
# 1 result found.
# Viktor Khryapa
# Results for Viktor Khryapa:
#
# You searched for "Voshon Lenard"
# 1 result found.
# Voshon Lenard
# Results for Voshon Lenard:
#
# You searched for "Darius Miles"
# 6 results found.
# 0: Darius Miles
# 1: Darius Miller
# 2: Darius Bazley
# 3: Aaron Miles
# 4: Chris Mills
# 5: Darius Morris
# Pick one: 0
# Results for Darius Miles:
#
# You searched for "Sergei Monia"
# 1 result found.
# Sergei Monia
# Results for Sergei Monia:
#
# ...

# %%
POR_2007_gamelog = []

for p in POR_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2007_gamelog.append(player_log)
POR_2007_gamelog = pd.concat(POR_2007_gamelog)    
POR_2007_gamelogs = POR_2007_gamelog.copy()
POR_2007_gamelogs['GAME_SCORE'] = POR_2007_gamelogs['GAME_SCORE'].astype(float)
POR_2007_games = POR_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2007_games_csv = POR_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2007_games.csv', index=False)
POR_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2007_games.csv')
POR_2007_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Dan Dickau"
# 3 results found.
# 0: Dan Dickau
# 1: Dan Tieman
# 2: Dan Kraus
# Pick one: 0
# Results for Dan Dickau:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "Stephen Graham"
# 1 result found.
# Stephen Graham
# Results for Stephen Graham:
#
# You searched for "Jarrett Jack"
# 1 result found.
# Jarrett Jack
# Results for Jarrett Jack:
#
# You searched for "Fred Jones"
# 29 results found.
# 0: Fred Jones
# 1: Tre Jones
# 2: Fred Foster
# 3: Fred Jacobs
# 4: Bill Jones
# 5: Earl Jones
# 6: Jake Jones
# 7: Jalen Jones
# 8: James Jones
# 9: K.C. Jones
# 10: Larry Jones
# 11: Mark Jones
# 12: Mark Jones
# 13: Nick Jones
# 14: Ozell Jones
# 15: Perry Jones
# 16: Rich Jones
# 17: Sam Jones
# 18: Steve Jones
# 19: Tyus Jones
# 20: Wali Jones
# 21: Wil Jones
# 22: Red Owens
# 23: Fred Paine
# ...

# %%
POR_2008_gamelog = []

for p in POR_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2008_gamelog.append(player_log)
POR_2008_gamelog = pd.concat(POR_2008_gamelog)    
POR_2008_gamelogs = POR_2008_gamelog.copy()
POR_2008_gamelogs['GAME_SCORE'] = POR_2008_gamelogs['GAME_SCORE'].astype(float)
POR_2008_games = POR_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2008_games_csv = POR_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2008_games.csv', index=False)
POR_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2008_games.csv')
POR_2008_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# You searched for "Taurean Green"
# 3 results found.
# 0: Taurean Green
# 1: Sean Green
# 2: Taurean Prince
# Pick one: 0
# Results for Taurean Green:
#
# You searched for "Jarrett Jack"
# 1 result found.
# Jarrett Jack
# Results for Jarrett Jack:
#
# You searched for "James Jones"
# 32 results found.
# 0: James Jones
# 1: Jake Jones
# 2: Jalen Jones
# 3: James Ennis
# 4: Damon Jones
# 5: Jimmy Jones
# 6: Sam Jones
# 7: James Posey
# 8: Tre Jones
# 9: Mason Jones
# 10: James Johnson
# ...

# %%
POR_2009_gamelog = []

for p in POR_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2009_gamelog.append(player_log)
POR_2009_gamelog = pd.concat(POR_2009_gamelog)    
POR_2009_gamelogs = POR_2009_gamelog.copy()
POR_2009_gamelogs['GAME_SCORE'] = POR_2009_gamelogs['GAME_SCORE'].astype(float)
POR_2009_games = POR_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2009_games_csv = POR_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2009_games.csv', index=False)
POR_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2009_games.csv')
POR_2009_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Ike Diogu"
# 4 results found.
# 0: Ike Diogu
# 1: Ike Anigbogu
# 2: Mike Davis
# 3: Mike Davis
# Pick one: 0
# Results for Ike Diogu:
#
# You searched for "Rudy Fernández"
# 2 results found.
# 0: Rudy Fernandez
# 1: Bruno Fernando
# Pick one: 0
# Results for Rudy Fernandez:
#
# You searched for "Channing Frye"
# 1 result found.
# Channing Frye
# Results for Channing Frye:
#
# ...

# %%
POR_2010_gamelog = []

for p in POR_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2010_gamelog.append(player_log)
POR_2010_gamelog = pd.concat(POR_2010_gamelog)    
POR_2010_gamelogs = POR_2010_gamelog.copy()
POR_2010_gamelogs['GAME_SCORE'] = POR_2010_gamelogs['GAME_SCORE'].astype(float)
POR_2010_games = POR_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2010_games_csv = POR_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2010_games.csv', index=False)
POR_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2010_games.csv')
POR_2010_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# ...

# %%
POR_2011_gamelog = []

for p in POR_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2011_gamelog.append(player_log)
POR_2011_gamelog = pd.concat(POR_2011_gamelog)    
POR_2011_gamelogs = POR_2011_gamelog.copy()
POR_2011_gamelogs['GAME_SCORE'] = POR_2011_gamelogs['GAME_SCORE'].astype(float)
POR_2011_games = POR_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2011_games_csv = POR_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2011_games.csv', index=False)
POR_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2011_games.csv')
POR_2011_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# ...

# %%
POR_2012_gamelog = []

for p in POR_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2012_gamelog.append(player_log)
POR_2012_gamelog = pd.concat(POR_2012_gamelog)    
POR_2012_gamelogs = POR_2012_gamelog.copy()
POR_2012_gamelogs['GAME_SCORE'] = POR_2012_gamelogs['GAME_SCORE'].astype(float)
POR_2012_games = POR_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2012_games_csv = POR_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2012_games.csv', index=False)
POR_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2012_games.csv')
POR_2012_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Marcus Camby"
# 6 results found.
# 0: Marcus Camby
# 1: Marcus Banks
# 2: Marcus Landry
# 3: Marcus Paige
# 4: Marcus Webb
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Camby:
#
# You searched for "Jamal Crawford"
# 3 results found.
# 0: Jamal Crawford
# 1: Joe Crawford
# 2: Jordan Crawford
# Pick one: 0
# Results for Jamal Crawford:
#
# You searched for "Raymond Felton"
# 1 result found.
# Raymond Felton
# Results for Raymond Felton:
#
# You searched for "Jonny Flynn"
# 4 results found.
# 0: Jonny Flynn
# 1: Danny Finn
# 2: Lonnie Lynn
# 3: Johnny Egan
# Pick one: 0
# Results for Jonny Flynn:
#
# ...

# %%
# removed Sasha Pavlović
POR_2013_gamelog = []

for p in POR_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2013_gamelog.append(player_log)
POR_2013_gamelog = pd.concat(POR_2013_gamelog)    
POR_2013_gamelogs = POR_2013_gamelog.copy()
POR_2013_gamelogs['GAME_SCORE'] = POR_2013_gamelogs['GAME_SCORE'].astype(float)
POR_2013_games = POR_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2013_games_csv = POR_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2013_games.csv', index=False)
POR_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2013_games.csv')
POR_2013_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Luke Babbitt"
# 2 results found.
# 0: Luke Babbitt
# 1: Luke Witte
# Pick one: 0
# Results for Luke Babbitt:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Victor Claver"
# 1 result found.
# Victor Claver
# Results for Victor Claver:
#
# You searched for "Joel Freeland"
# 1 result found.
# Joel Freeland
# Results for Joel Freeland:
#
# You searched for "J.J. Hickson"
# 3 results found.
# 0: J.J. Hickson
# 1: John Dickson
# 2: D.J. Wilson
# Pick one: 0
# Results for J.J. Hickson:
#
# You searched for "Jared Jeffries"
# 1 result found.
# Jared Jeffries
# ...

# %%
# removed mo williams

POR_2014_gamelog = []

for p in POR_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2014_gamelog.append(player_log)
POR_2014_gamelog = pd.concat(POR_2014_gamelog)    
POR_2014_gamelogs = POR_2014_gamelog.copy()
POR_2014_gamelogs['GAME_SCORE'] = POR_2014_gamelogs['GAME_SCORE'].astype(float)
POR_2014_games = POR_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2014_games_csv = POR_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2014_games.csv', index=False)
POR_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2014_games.csv')
POR_2014_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Victor Claver"
# 1 result found.
# Victor Claver
# Results for Victor Claver:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Joel Freeland"
# 1 result found.
# Joel Freeland
# Results for Joel Freeland:
#
# You searched for "Meyers Leonard"
# 1 result found.
# Meyers Leonard
# Results for Meyers Leonard:
#
# You searched for "Damian Lillard"
# 1 result found.
# Damian Lillard
# Results for Damian Lillard:
#
# You searched for "Robin Lopez"
# 4 results found.
# ...

# %%
POR_2015_gamelog = []

for p in POR_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2015_gamelog.append(player_log)
POR_2015_gamelog = pd.concat(POR_2015_gamelog)    
POR_2015_gamelogs = POR_2015_gamelog.copy()
POR_2015_gamelogs['GAME_SCORE'] = POR_2015_gamelogs['GAME_SCORE'].astype(float)
POR_2015_games = POR_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2015_games_csv = POR_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2015_games.csv', index=False)
POR_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2015_games.csv')
POR_2015_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Will Barton"
# 8 results found.
# 0: Will Barton
# 1: Willie Burton
# 2: Bill Martin
# 3: Bill Walton
# 4: Earl Barron
# 5: Bill Buntin
# 6: Bill Newton
# 7: Will Bynum
# Pick one: 0
# Results for Will Barton:
#
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Victor Claver"
# 1 result found.
# Victor Claver
# Results for Victor Claver:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# ...

# %%
POR_2016_gamelog = []

for p in POR_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2016_gamelog.append(player_log)
POR_2016_gamelog = pd.concat(POR_2016_gamelog)    
POR_2016_gamelogs = POR_2016_gamelog.copy()
POR_2016_gamelogs['GAME_SCORE'] = POR_2016_gamelogs['GAME_SCORE'].astype(float)
POR_2016_games = POR_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2016_games_csv = POR_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2016_games.csv', index=False)
POR_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2016_games.csv')
POR_2016_games_proc.head()
# Out:
# You searched for "Cliff Alexander"
# 3 results found.
# 0: Cliff Alexander
# 1: Cory Alexander
# 2: Cliff Anderson
# Pick one: 0
# Results for Cliff Alexander:
#
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# 23: Tyler Davis
# 24: Walt Davis
# 25: Ed Earle
# 26: Ed Gayda
# 27: Ed Melvin
# 28: Ed Beach
# ...

# %%
POR_2017_gamelog = []

for p in POR_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2017_gamelog.append(player_log)
POR_2017_gamelog = pd.concat(POR_2017_gamelog)    
POR_2017_gamelogs = POR_2017_gamelog.copy()
POR_2017_gamelogs['GAME_SCORE'] = POR_2017_gamelogs['GAME_SCORE'].astype(float)
POR_2017_games = POR_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2017_games_csv = POR_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2017_games.csv', index=False)
POR_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2017_games.csv')
POR_2017_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# 23: Tyler Davis
# 24: Walt Davis
# 25: Ed Earle
# 26: Ed Gayda
# 27: Ed Melvin
# 28: Ed Beach
# 29: Ed Leede
# 30: Ed Mikan
# 31: Ed Nealy
# 32: Med Park
# 33: Todd Day
# Pick one: 0
# Results for Ed Davis:
#
# You searched for "Maurice Harkless"
# 2 results found.
# ...

# %%
POR_2018_gamelog = []

for p in POR_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2018_gamelog.append(player_log)
POR_2018_gamelog = pd.concat(POR_2018_gamelog)    
POR_2018_gamelogs = POR_2018_gamelog.copy()
POR_2018_gamelogs['GAME_SCORE'] = POR_2018_gamelogs['GAME_SCORE'].astype(float)
POR_2018_games = POR_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2018_games_csv = POR_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2018_games.csv', index=False)
POR_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2018_games.csv')
POR_2018_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Wade Baldwin"
# 1 result found.
# Wade Baldwin
# Results for Wade Baldwin:
#
# You searched for "Zach Collins"
# 9 results found.
# 0: Zach Collins
# 1: Art Collins
# 2: Don Collins
# 3: Doug Collins
# 4: James Collins
# 5: Jason Collins
# 6: John Collins
# 7: Mardy Collins
# 8: Zach Norvell
# Pick one: 0
# Results for Zach Collins:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# 14: Bill Davis
# 15: Dale Davis
# 16: Josh Davis
# 17: Mark Davis
# 18: Mark Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Paul Davis
# 22: Terry Davis
# ...

# %%
# removed gary trent 
POR_2019_gamelog = []

for p in POR_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2019_gamelog.append(player_log)
POR_2019_gamelog = pd.concat(POR_2019_gamelog)    
POR_2019_gamelogs = POR_2019_gamelog.copy()
POR_2019_gamelogs['GAME_SCORE'] = POR_2019_gamelogs['GAME_SCORE'].astype(float)
POR_2019_games = POR_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2019_games_csv = POR_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2019_games.csv', index=False)
POR_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2019_games.csv')
POR_2019_games_proc.head()
# Out:
# You searched for "Al-Farouq Aminu"
# 1 result found.
# Al-Farouq Aminu
# Results for Al-Farouq Aminu:
#
# You searched for "Wade Baldwin"
# 1 result found.
# Wade Baldwin
# Results for Wade Baldwin:
#
# You searched for "Zach Collins"
# 9 results found.
# 0: Zach Collins
# 1: Art Collins
# 2: Don Collins
# 3: Doug Collins
# 4: James Collins
# 5: Jason Collins
# 6: John Collins
# 7: Mardy Collins
# 8: Zach Norvell
# Pick one: 0
# Results for Zach Collins:
#
# You searched for "Seth Curry"
# 4 results found.
# 0: Seth Curry
# 1: Dell Curry
# 2: Eddy Curry
# 3: Stephen Curry
# Pick one: 0
# Results for Seth Curry:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# 1: Maurice McHartley
# Pick one: 0
# Results for Maurice Harkless:
#
# You searched for "Rodney Hood"
# 4 results found.
# 0: Rodney Hood
# 1: Rodney Buford
# 2: Rodney Monroe
# 3: Rodney White
# Pick one: 0
# Results for Rodney Hood:
#
# You searched for "Enes Kanter"
# 2 results found.
# ...

# %%
# removed kelly oubre

POR_2020_gamelog = []

for p in POR_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2020_gamelog.append(player_log)
POR_2020_gamelog = pd.concat(POR_2020_gamelog)    
POR_2020_gamelogs = POR_2020_gamelog.copy()
POR_2020_gamelogs['GAME_SCORE'] = POR_2020_gamelogs['GAME_SCORE'].astype(float)
POR_2020_games = POR_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2020_games_csv = POR_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2020_games.csv', index=False)
POR_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2020_games.csv')
POR_2020_games_proc.head()
# Out:
# You searched for "Jaylen Adams"
# 6 results found.
# 0: Jaylen Adams
# 1: Alvan Adams
# 2: Hassan Adams
# 3: Jordan Adams
# 4: Steven Adams
# 5: Jaylen Hoard
# Pick one: 0
# Results for Jaylen Adams:
#
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Moses Brown"
# 17 results found.
# 0: Moses Brown
# 1: Mike Brown
# 2: Roger Brown
# 3: Roger Brown
# 4: Bob Brown
# 5: Bobby Brown
# 6: Damone Brown
# 7: Dee Brown
# 8: Dee Brown
# 9: Ernest Brown
# 10: Fred Brown
# 11: John Brown
# 12: Lewis Brown
# 13: Marcus Brown
# 14: Markel Brown
# 15: Myron Brown
# 16: Tony Brown
# Pick one: 0
# Results for Moses Brown:
#
# You searched for "Zach Collins"
# 9 results found.
# 0: Zach Collins
# 1: Art Collins
# 2: Don Collins
# ...

# %%
# remvoed Derrick Jones
POR_2021_gamelog = []

for p in POR_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    POR_2021_gamelog.append(player_log)
POR_2021_gamelog = pd.concat(POR_2021_gamelog)    
POR_2021_gamelogs = POR_2021_gamelog.copy()
POR_2021_gamelogs['GAME_SCORE'] = POR_2021_gamelogs['GAME_SCORE'].astype(float)
POR_2021_games = POR_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
POR_2021_games_csv = POR_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2021_games.csv', index=False)
POR_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2021_games.csv')
POR_2021_games_proc.head()
# Out:
# You searched for "Carmelo Anthony"
# 1 result found.
# Carmelo Anthony
# Results for Carmelo Anthony:
#
# You searched for "Keljin Blevins"
# 2 results found.
# 0: Keljin Blevins
# 1: Leon Blevins
# Pick one: 0
# Results for Keljin Blevins:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "CJ Elleby"
# 2 results found.
# 0: CJ Elleby
# 1: Raja Bell
# Pick one: 0
# Results for CJ Elleby:
#
# You searched for "Harry Giles"
# 15 results found.
# 0: Harry Giles
# 1: Harry Miller
# 2: Harry Barnes
# 3: Harry Davis
# 4: Harry Dinnel
# 5: Larry Jones
# 6: Aaron Miles
# 7: Larry Miller
# 8: Terry Mills
# 9: Harry Rogers
# 10: Larry Sykes
# 11: Garry Witts
# 12: Barry Yates
# 13: Harry Zeller
# 14: Larry Fogle
# Pick one: 0
# Results for Harry Giles:
#
# You searched for "Rondae Hollis-Jefferson"
# 1 result found.
# Rondae Hollis-Jefferson
# Results for Rondae Hollis-Jefferson:
#
# You searched for "Rodney Hood"
# ...

# %% [markdown]
# ## combine all seasons

# %%
POR_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2000_games.csv')
POR_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2001_games.csv')
POR_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2002_games.csv')
POR_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2003_games.csv')
POR_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2004_games.csv')
POR_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2005_games.csv')
POR_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2006_games.csv')
POR_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2007_games.csv')
POR_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2008_games.csv')
POR_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2009_games.csv')
POR_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2010_games.csv')
POR_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2011_games.csv')
POR_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2012_games.csv')
POR_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2013_games.csv')
POR_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2014_games.csv')
POR_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2015_games.csv')
POR_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2016_games.csv')
POR_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2017_games.csv')
POR_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2018_games.csv')
POR_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2019_games.csv')
POR_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2020_games.csv')
POR_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/POR/POR_2021_games.csv')

# %%
POR_season_dfs = [POR_2000_games_io, POR_2001_games_io, POR_2002_games_io, POR_2003_games_io, POR_2004_games_io, POR_2005_games_io,
                 POR_2006_games_io, POR_2007_games_io, POR_2008_games_io, POR_2009_games_io, POR_2010_games_io, POR_2011_games_io,
                 POR_2012_games_io, POR_2013_games_io, POR_2014_games_io, POR_2015_games_io, POR_2016_games_io, POR_2017_games_io,
                 POR_2018_games_io, POR_2019_games_io, POR_2020_games_io, POR_2021_games_io]

# %%
POR_all = pd.concat(POR_season_dfs)
POR_all_sorted = POR_all.sort_values(by=['GAME_SCORE'], ascending=False)
POR_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2020-08-11  30-027  POR      AWAY      DAL   W (+3)   1  41:05  17   32
# 1  2020-01-26  29-195  POR      HOME      IND  W (+10)   1  38:28  14   23
# 0  2017-04-08  26-267  POR      HOME      UTA  W (+15)   1  41:49  18   34
# 2  2020-01-20  29-189  POR      HOME      GSW   W (+5)   1  45:08  17   37
# 0  2016-02-19  25-219  POR      HOME      GSW  W (+32)   1  31:06  18   28
# 3  2019-11-08  29-116  POR      HOME      BRK   L (-4)   1  40:21  19   33
# 0  2021-03-16  30-244  POR      HOME      NOP   W (+1)   1  40:36  13   20
# 4  2020-02-01  29-201  POR      HOME      UTA  W (+17)   1  36:19  17   29
# 5  2020-08-06  30-022  POR      AWAY      DEN  W (+10)   1  40:44  13   21
# 0  2008-12-18  24-148  POR      HOME      PHO   W (+5)   1  43:49  14   27
# 6  2020-01-31  29-200  POR      AWAY      LAL   W (+8)   1  40:16  17   30
# ...
