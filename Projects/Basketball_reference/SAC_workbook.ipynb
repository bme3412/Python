# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_SAC = []

# SAC
while season <= 2021:
    df_SAC = get_roster('SAC', season)
    df_SAC['Season'] = season
    df_SAC['Team'] = 'SAC'
    appended_data_SAC.append(df_SAC)
    season = season + 1
appended_data_SAC = pd.concat(appended_data_SAC)

# %%
SAC_df_all = appended_data_SAC.copy()
SAC_df_all_csv = SAC_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_players_all.csv', index=False)
SAC_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_players_all.csv')
SAC_df_all_csv_io.head()
# Out:
#    NUMBER         PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      25  Nick Anderson  SG    6-6     205  1968-01-20          US
# 1      20      Jon Barry  SG    6-4     195  1969-07-25          US
# 2      23  Tyrone Corbin  SF    6-6     210  1962-12-31          US
# 3       0      Tony Delk  PG    6-1     189  1974-01-28          US
# 4      21    Vlade Divac   C    7-1     243  1968-02-03          RS
#
#   EXPERIENCE                                  COLLEGE  Season Team
# 0         10                                 Illinois    2000  SAC
# 1          7  University of the Pacific, Georgia Tech    2000  SAC
# 2         14                                   DePaul    2000  SAC
# 3          3                                 Kentucky    2000  SAC
# 4         10                                      NaN    2000  SAC

# %%
SAC_df_2000 = SAC_df_all[SAC_df_all['Season'] == 2000]
SAC_df_2001 = SAC_df_all[SAC_df_all['Season'] == 2001]
SAC_df_2002 = SAC_df_all[SAC_df_all['Season'] == 2002]
SAC_df_2003 = SAC_df_all[SAC_df_all['Season'] == 2003]
SAC_df_2004 = SAC_df_all[SAC_df_all['Season'] == 2004]
SAC_df_2005 = SAC_df_all[SAC_df_all['Season'] == 2005]
SAC_df_2006 = SAC_df_all[SAC_df_all['Season'] == 2006]
SAC_df_2007 = SAC_df_all[SAC_df_all['Season'] == 2007]
SAC_df_2008 = SAC_df_all[SAC_df_all['Season'] == 2008]
SAC_df_2009 = SAC_df_all[SAC_df_all['Season'] == 2009]
SAC_df_2010 = SAC_df_all[SAC_df_all['Season'] == 2010]
SAC_df_2011 = SAC_df_all[SAC_df_all['Season'] == 2011]
SAC_df_2012 = SAC_df_all[SAC_df_all['Season'] == 2012]
SAC_df_2013 = SAC_df_all[SAC_df_all['Season'] == 2013]
SAC_df_2014 = SAC_df_all[SAC_df_all['Season'] == 2014]
SAC_df_2015 = SAC_df_all[SAC_df_all['Season'] == 2015]
SAC_df_2016 = SAC_df_all[SAC_df_all['Season'] == 2016]
SAC_df_2017 = SAC_df_all[SAC_df_all['Season'] == 2017]
SAC_df_2018 = SAC_df_all[SAC_df_all['Season'] == 2018]
SAC_df_2019 = SAC_df_all[SAC_df_all['Season'] == 2019]
SAC_df_2020 = SAC_df_all[SAC_df_all['Season'] == 2020]
SAC_df_2021 = SAC_df_all[SAC_df_all['Season'] == 2021]

# %%
# changing names
#SAC_df_2002.loc[SAC_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#SAC_df_2004.loc[SAC_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
SAC_df_2000_players = SAC_df_2000['PLAYER'].to_list()
SAC_df_2001_players = SAC_df_2001['PLAYER'].to_list()
SAC_df_2002_players = SAC_df_2002['PLAYER'].to_list()
SAC_df_2003_players = SAC_df_2003['PLAYER'].to_list()
SAC_df_2004_players = SAC_df_2004['PLAYER'].to_list()
SAC_df_2005_players = SAC_df_2005['PLAYER'].to_list()

SAC_df_2006_players = SAC_df_2006['PLAYER'].to_list()
SAC_df_2007_players = SAC_df_2007['PLAYER'].to_list()
SAC_df_2008_players = SAC_df_2008['PLAYER'].to_list()
SAC_df_2009_players = SAC_df_2009['PLAYER'].to_list()
SAC_df_2010_players = SAC_df_2010['PLAYER'].to_list()
SAC_df_2011_players = SAC_df_2011['PLAYER'].to_list()

SAC_df_2012_players = SAC_df_2012['PLAYER'].to_list()
SAC_df_2013_players = SAC_df_2013['PLAYER'].to_list()
SAC_df_2014_players = SAC_df_2014['PLAYER'].to_list()
SAC_df_2015_players = SAC_df_2015['PLAYER'].to_list()
SAC_df_2016_players = SAC_df_2016['PLAYER'].to_list()
SAC_df_2017_players = SAC_df_2017['PLAYER'].to_list()

SAC_df_2018_players = SAC_df_2018['PLAYER'].to_list()
SAC_df_2019_players = SAC_df_2019['PLAYER'].to_list()
SAC_df_2020_players = SAC_df_2020['PLAYER'].to_list()
SAC_df_2021_players = SAC_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#SAC_df_2006_players.remove("Metta World Peace")
#SAC_df_2007_players.remove("Metta World Peace")
#SAC_df_2008_players.remove("Metta World Peace")
#SAC_df_2014_players.remove("Hamady N'Diaye")
#SAC_df_2018_players.remove("Frank Mason")
#SAC_df_2019_players.remove("Marvin Bagley")
#SAC_df_2019_players.remove("Frank Mason")
#SAC_df_2020_players.remove("Marvin Bagley")
#SAC_df_2021_players.remove("Marvin Bagley")
SAC_df_2021_players.remove("Glenn Robinson")

# %%
SAC_2000_gamelog = []


for p in SAC_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2000_gamelog.append(player_log)
SAC_2000_gamelog = pd.concat(SAC_2000_gamelog)    
SAC_2000_gamelogs = SAC_2000_gamelog.copy()
SAC_2000_gamelogs['GAME_SCORE'] = SAC_2000_gamelogs['GAME_SCORE'].astype(float)
SAC_2000_games = SAC_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2000_games_csv = SAC_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2000_games.csv', index=False)
SAC_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2000_games.csv')
SAC_2000_games_proc.head()
# Out:
# You searched for "Nick Anderson"
# 14 results found.
# 0: Nick Anderson
# 1: Eric Anderson
# 2: Kim Anderson
# 3: Alan Anderson
# 4: Cliff Anderson
# 5: Dan Anderson
# 6: Dan Anderson
# 7: Derek Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: Kyle Anderson
# 11: Ron Anderson
# 12: Ryan Anderson
# 13: Rick Roberson
# Pick one: 0
# Results for Nick Anderson:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# You searched for "Tyrone Corbin"
# 2 results found.
# ...

# %%
SAC_2001_gamelog = []


for p in SAC_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2001_gamelog.append(player_log)
SAC_2001_gamelog = pd.concat(SAC_2001_gamelog)    
SAC_2001_gamelogs = SAC_2001_gamelog.copy()
SAC_2001_gamelogs['GAME_SCORE'] = SAC_2001_gamelogs['GAME_SCORE'].astype(float)
SAC_2001_games = SAC_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2001_games_csv = SAC_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2001_games.csv', index=False)
SAC_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2001_games.csv')
SAC_2001_games_proc.head()
# Out:
# You searched for "Nick Anderson"
# 14 results found.
# 0: Nick Anderson
# 1: Eric Anderson
# 2: Kim Anderson
# 3: Alan Anderson
# 4: Cliff Anderson
# 5: Dan Anderson
# 6: Dan Anderson
# 7: Derek Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: Kyle Anderson
# 11: Ron Anderson
# 12: Ryan Anderson
# 13: Rick Roberson
# Pick one: 0
# Results for Nick Anderson:
#
# You searched for "Jon Barry"
# 30 results found.
# 0: Jon Barry
# 1: John Barr
# 2: Moe Barr
# 3: Ron Perry
# 4: John Bagley
# 5: Ron Baker
# 6: John Barber
# 7: Brent Barry
# 8: Drew Barry
# 9: Rick Barry
# 10: Jay Carty
# 11: Bob Ferry
# 12: John Garris
# 13: Joe Harris
# 14: Don May
# 15: Don Ray
# 16: Jason Terry
# 17: John Warren
# 18: Vin Baker
# 19: Tom Barker
# 20: Mike Barr
# 21: Cory Carr
# 22: Ron Carter
# 23: Ron Harper
# 24: Jason Hart
# 25: Josh Hart
# 26: Jon Leuer
# 27: Jack Parr
# 28: Von Wafer
# 29: John Wall
# Pick one: 0
# Results for Jon Barry:
#
# You searched for "Doug Christie"
# 2 results found.
# ...

# %%
SAC_2002_gamelog = []


for p in SAC_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2002_gamelog.append(player_log)
SAC_2002_gamelog = pd.concat(SAC_2002_gamelog)    
SAC_2002_gamelogs = SAC_2002_gamelog.copy()
SAC_2002_gamelogs['GAME_SCORE'] = SAC_2002_gamelogs['GAME_SCORE'].astype(float)
SAC_2002_games = SAC_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2002_games_csv = SAC_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2002_games.csv', index=False)
SAC_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2002_games.csv')
SAC_2002_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Chucky Brown"
# 3 results found.
# 0: Chucky Brown
# 1: Bruce Brown
# 2: Rickey Brown
# Pick one: 0
# Results for Chucky Brown:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Mateen Cleaves"
# 1 result found.
# Mateen Cleaves
# Results for Mateen Cleaves:
#
# You searched for "Vlade Divac"
# 1 result found.
# Vlade Divac
# Results for Vlade Divac:
#
# You searched for "Lawrence Funderburke"
# 1 result found.
# Lawrence Funderburke
# Results for Lawrence Funderburke:
#
# ...

# %%
    
SAC_2003_gamelog = []



for p in SAC_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2003_gamelog.append(player_log)
SAC_2003_gamelog = pd.concat(SAC_2003_gamelog)    
SAC_2003_gamelogs = SAC_2003_gamelog.copy()
SAC_2003_gamelogs['GAME_SCORE'] = SAC_2003_gamelogs['GAME_SCORE'].astype(float)
SAC_2003_games = SAC_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2003_games_csv = SAC_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2003_games.csv', index=False)
SAC_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2003_games.csv')
SAC_2003_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Mateen Cleaves"
# 1 result found.
# Mateen Cleaves
# Results for Mateen Cleaves:
#
# You searched for "Vlade Divac"
# 1 result found.
# Vlade Divac
# Results for Vlade Divac:
#
# You searched for "Lawrence Funderburke"
# 1 result found.
# Lawrence Funderburke
# Results for Lawrence Funderburke:
#
# ...

# %%
SAC_2004_gamelog = []



for p in SAC_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2004_gamelog.append(player_log)
SAC_2004_gamelog = pd.concat(SAC_2004_gamelog)    
SAC_2004_gamelogs = SAC_2004_gamelog.copy()
SAC_2004_gamelogs['GAME_SCORE'] = SAC_2004_gamelogs['GAME_SCORE'].astype(float)
SAC_2004_games = SAC_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2004_games_csv = SAC_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2004_games.csv', index=False)
SAC_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2004_games.csv')
SAC_2004_games_proc.head()
# Out:
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Rodney Buford"
# 2 results found.
# 0: Rodney Buford
# 1: Rodney Hood
# Pick one: 0
# Results for Rodney Buford:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Vlade Divac"
# 1 result found.
# Vlade Divac
# Results for Vlade Divac:
#
# You searched for "Bobby Jackson"
# 10 results found.
# 0: Bobby Jackson
# 1: Tony Jackson
# 2: Tony Jackson
# 3: Bobby Watson
# 4: Josh Jackson
# 5: Tracy Jackson
# 6: Bobby Wilson
# 7: Bobby Wilson
# 8: Bobby Jones
# 9: Bobby Jones
# Pick one: 0
# ...

# %%
SAC_2005_gamelog = []



for p in SAC_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2005_gamelog.append(player_log)
SAC_2005_gamelog = pd.concat(SAC_2005_gamelog)    
SAC_2005_gamelogs = SAC_2005_gamelog.copy()
SAC_2005_gamelogs['GAME_SCORE'] = SAC_2005_gamelogs['GAME_SCORE'].astype(float)
SAC_2005_games = SAC_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2005_games_csv = SAC_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2005_games.csv', index=False)
SAC_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2005_games.csv')
SAC_2005_games_proc.head()
# Out:
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# ...

# %%
SAC_2006_gamelog = []

for p in SAC_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2006_gamelog.append(player_log)
SAC_2006_gamelog = pd.concat(SAC_2006_gamelog)    
SAC_2006_gamelogs = SAC_2006_gamelog.copy()
SAC_2006_gamelogs['GAME_SCORE'] = SAC_2006_gamelogs['GAME_SCORE'].astype(float)
SAC_2006_games = SAC_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2006_games_csv = SAC_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2006_games.csv', index=False)
SAC_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2006_games.csv')
SAC_2006_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Jason Hart"
# 9 results found.
# 0: Jason Hart
# 1: Josh Hart
# 2: Jaxson Hayes
# 3: Jason Kidd
# 4: Jason Smith
# 5: Jason Terry
# 6: Jon Barry
# 7: Jay Carty
# 8: Jason Sasser
# Pick one: 0
# Results for Jason Hart:
#
# You searched for "Kevin Martin"
# 15 results found.
# 0: Kevin Martin
# 1: Kelan Martin
# 2: Kenyon Martin
# 3: Devin Harris
# 4: Brian Martin
# ...

# %%
SAC_2007_gamelog = []

for p in SAC_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2007_gamelog.append(player_log)
SAC_2007_gamelog = pd.concat(SAC_2007_gamelog)    
SAC_2007_gamelogs = SAC_2007_gamelog.copy()
SAC_2007_gamelogs['GAME_SCORE'] = SAC_2007_gamelogs['GAME_SCORE'].astype(float)
SAC_2007_games = SAC_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2007_games_csv = SAC_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2007_games.csv', index=False)
SAC_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2007_games.csv')
SAC_2007_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Quincy Douby"
# 2 results found.
# 0: Quincy Douby
# 1: Quincy Acy
# Pick one: 0
# Results for Quincy Douby:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Jason Hart"
# 9 results found.
# 0: Jason Hart
# 1: Josh Hart
# 2: Jaxson Hayes
# 3: Jason Kidd
# 4: Jason Smith
# 5: Jason Terry
# 6: Jon Barry
# 7: Jay Carty
# 8: Jason Sasser
# Pick one: 0
# Results for Jason Hart:
#
# ...

# %%
SAC_2008_gamelog = []

for p in SAC_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2008_gamelog.append(player_log)
SAC_2008_gamelog = pd.concat(SAC_2008_gamelog)    
SAC_2008_gamelogs = SAC_2008_gamelog.copy()
SAC_2008_gamelogs['GAME_SCORE'] = SAC_2008_gamelogs['GAME_SCORE'].astype(float)
SAC_2008_games = SAC_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2008_games_csv = SAC_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2008_games.csv', index=False)
SAC_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2008_games.csv')
SAC_2008_games_proc.head()
# Out:
# You searched for "Shareef Abdur-Rahim"
# 1 result found.
# Shareef Abdur-Rahim
# Results for Shareef Abdur-Rahim:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Quincy Douby"
# 2 results found.
# 0: Quincy Douby
# 1: Quincy Acy
# Pick one: 0
# Results for Quincy Douby:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Orien Greene"
# 6 results found.
# 0: Orien Greene
# 1: Erick Green
# 2: Ken Green
# 3: Donte Greene
# 4: Rickey Green
# 5: Tommie Green
# Pick one: 0
# Results for Orien Greene:
#
# You searched for "Spencer Hawes"
# 3 results found.
# ...

# %%
SAC_2009_gamelog = []

for p in SAC_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2009_gamelog.append(player_log)
SAC_2009_gamelog = pd.concat(SAC_2009_gamelog)    
SAC_2009_gamelogs = SAC_2009_gamelog.copy()
SAC_2009_gamelogs['GAME_SCORE'] = SAC_2009_gamelogs['GAME_SCORE'].astype(float)
SAC_2009_games = SAC_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2009_games_csv = SAC_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2009_games.csv', index=False)
SAC_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2009_games.csv')
SAC_2009_games_proc.head()
# Out:
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Bobby Brown"
# 14 results found.
# 0: Bobby Brown
# 1: Bob Brown
# 2: Tony Brown
# 3: Bobby Croft
# 4: Bruce Brown
# 5: John Brown
# 6: Larry Brown
# 7: Moses Brown
# 8: Randy Brown
# 9: Roger Brown
# 10: Roger Brown
# 11: Troy Brown
# 12: Bobby Cook
# 13: Bobby Lloyd
# Pick one: 0
# Results for Bobby Brown:
#
# You searched for "Ike Diogu"
# 4 results found.
# 0: Ike Diogu
# 1: Ike Anigbogu
# 2: Mike Davis
# 3: Mike Davis
# Pick one: 0
# Results for Ike Diogu:
#
# You searched for "Quincy Douby"
# 2 results found.
# 0: Quincy Douby
# 1: Quincy Acy
# Pick one: 0
# Results for Quincy Douby:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# ...

# %%
SAC_2010_gamelog = []

for p in SAC_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2010_gamelog.append(player_log)
SAC_2010_gamelog = pd.concat(SAC_2010_gamelog)    
SAC_2010_gamelogs = SAC_2010_gamelog.copy()
SAC_2010_gamelogs['GAME_SCORE'] = SAC_2010_gamelogs['GAME_SCORE'].astype(float)
SAC_2010_games = SAC_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2010_games_csv = SAC_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2010_games.csv', index=False)
SAC_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2010_games.csv')
SAC_2010_games_proc.head()
# Out:
# You searched for "Hilton Armstrong"
# 1 result found.
# Hilton Armstrong
# Results for Hilton Armstrong:
#
# You searched for "Jon Brockman"
# 1 result found.
# Jon Brockman
# Results for Jon Brockman:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Joey Dorsey"
# 4 results found.
# 0: Joey Dorsey
# 1: Jacky Dorsey
# 2: Ron Dorsey
# 3: Tyler Dorsey
# Pick one: 0
# Results for Joey Dorsey:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# Pick one: 0
# Results for Tyreke Evans:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Donté Greene"
# 6 results found.
# 0: Donte Greene
# 1: Danny Green
# 2: Javonte Green
# 3: Orien Greene
# 4: Johnny Green
# 5: Tommie Green
# Pick one: 0
# Results for Donte Greene:
#
# You searched for "Spencer Hawes"
# 3 results found.
# 0: Spencer Hawes
# ...

# %%
SAC_2011_gamelog = []

for p in SAC_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2011_gamelog.append(player_log)
SAC_2011_gamelog = pd.concat(SAC_2011_gamelog)    
SAC_2011_gamelogs = SAC_2011_gamelog.copy()
SAC_2011_gamelogs['GAME_SCORE'] = SAC_2011_gamelogs['GAME_SCORE'].astype(float)
SAC_2011_games = SAC_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2011_games_csv = SAC_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2011_games.csv', index=False)
SAC_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2011_games.csv')
SAC_2011_games_proc.head()
# Out:
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Samuel Dalembert"
# 1 result found.
# Samuel Dalembert
# Results for Samuel Dalembert:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# Pick one: 0
# Results for Tyreke Evans:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Donté Greene"
# 6 results found.
# 0: Donte Greene
# 1: Danny Green
# 2: Javonte Green
# 3: Orien Greene
# 4: Johnny Green
# 5: Tommie Green
# Pick one: 0
# Results for Donte Greene:
#
# You searched for "Luther Head"
# 2 results found.
# 0: Luther Head
# 1: Luther Green
# Pick one: 0
# Results for Luther Head:
#
# You searched for "Darnell Jackson"
# 5 results found.
# ...

# %%
SAC_2012_gamelog = []

for p in SAC_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2012_gamelog.append(player_log)
SAC_2012_gamelog = pd.concat(SAC_2012_gamelog)    
SAC_2012_gamelogs = SAC_2012_gamelog.copy()
SAC_2012_gamelogs['GAME_SCORE'] = SAC_2012_gamelogs['GAME_SCORE'].astype(float)
SAC_2012_games = SAC_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2012_games_csv = SAC_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2012_games.csv', index=False)
SAC_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2012_games.csv')
SAC_2012_games_proc.head()
# Out:
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# Pick one: 0
# Results for Tyreke Evans:
#
# You searched for "Jimmer Fredette"
# 1 result found.
# Jimmer Fredette
# Results for Jimmer Fredette:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Donté Greene"
# 6 results found.
# 0: Donte Greene
# 1: Danny Green
# 2: Javonte Green
# 3: Orien Greene
# 4: Johnny Green
# 5: Tommie Green
# Pick one: 0
# Results for Donte Greene:
#
# You searched for "Chuck Hayes"
# 5 results found.
# 0: Chuck Hayes
# 1: Chuck Share
# 2: Chuck Lloyd
# 3: Chuck Noble
# 4: Chuck Terry
# Pick one: 0
# Results for Chuck Hayes:
#
# You searched for "J.J. Hickson"
# 3 results found.
# 0: J.J. Hickson
# 1: John Dickson
# ...

# %%
SAC_2013_gamelog = []

for p in SAC_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2013_gamelog.append(player_log)
SAC_2013_gamelog = pd.concat(SAC_2013_gamelog)    
SAC_2013_gamelogs = SAC_2013_gamelog.copy()
SAC_2013_gamelogs['GAME_SCORE'] = SAC_2013_gamelogs['GAME_SCORE'].astype(float)
SAC_2013_games = SAC_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2013_games_csv = SAC_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2013_games.csv', index=False)
SAC_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2013_games.csv')
SAC_2013_games_proc.head()
# Out:
# You searched for "Cole Aldrich"
# 1 result found.
# Cole Aldrich
# Results for Cole Aldrich:
#
# You searched for "Aaron Brooks"
# 5 results found.
# 0: Aaron Brooks
# 1: MarShon Brooks
# 2: Dillon Brooks
# 3: Kevin Brooks
# 4: Aaron Gordon
# Pick one: 0
# Results for Aaron Brooks:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Toney Douglas"
# 4 results found.
# 0: Toney Douglas
# 1: John Douglas
# 2: Leon Douglas
# 3: Tony Dumas
# Pick one: 0
# Results for Toney Douglas:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# Pick one: 0
# Results for Tyreke Evans:
#
# You searched for "Jimmer Fredette"
# 1 result found.
# Jimmer Fredette
# Results for Jimmer Fredette:
#
# You searched for "Francisco García"
# 1 result found.
# Francisco Garcia
# Results for Francisco Garcia:
#
# You searched for "Chuck Hayes"
# ...

# %%
# removed Hamady N'Diaye

SAC_2014_gamelog = []

for p in SAC_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2014_gamelog.append(player_log)
SAC_2014_gamelog = pd.concat(SAC_2014_gamelog)    
SAC_2014_gamelogs = SAC_2014_gamelog.copy()
SAC_2014_gamelogs['GAME_SCORE'] = SAC_2014_gamelogs['GAME_SCORE'].astype(float)
SAC_2014_games = SAC_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2014_games_csv = SAC_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2014_games.csv', index=False)
SAC_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2014_games.csv')
SAC_2014_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Jared Cunningham"
# 2 results found.
# 0: Jared Cunningham
# 1: Dante Cunningham
# Pick one: 0
# Results for Jared Cunningham:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Jimmer Fredette"
# 1 result found.
# Jimmer Fredette
# Results for Jimmer Fredette:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# You searched for "Aaron Gray"
# ...

# %%
SAC_2015_gamelog = []

for p in SAC_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2015_gamelog.append(player_log)
SAC_2015_gamelog = pd.concat(SAC_2015_gamelog)    
SAC_2015_gamelogs = SAC_2015_gamelog.copy()
SAC_2015_gamelogs['GAME_SCORE'] = SAC_2015_gamelogs['GAME_SCORE'].astype(float)
SAC_2015_games = SAC_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2015_games_csv = SAC_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2015_games.csv', index=False)
SAC_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2015_games.csv')
SAC_2015_games_proc.head()
# Out:
# You searched for "Sim Bhullar"
# 1 result found.
# Sim Bhullar
# Results for Sim Bhullar:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Reggie Evans"
# 10 results found.
# 0: Reggie Evans
# 1: Reggie Geary
# 2: Reggie Hanson
# 3: Reggie Hearn
# 4: Reggie King
# 5: Reggie Lewis
# 6: Reggie Royals
# 7: Reggie Theus
# 8: Reggie Perry
# 9: Reggie Jordan
# Pick one: 0
# Results for Reggie Evans:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# You searched for "Ryan Hollins"
# 3 results found.
# 0: Ryan Hollins
# ...

# %%
SAC_2016_gamelog = []

for p in SAC_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2016_gamelog.append(player_log)
SAC_2016_gamelog = pd.concat(SAC_2016_gamelog)    
SAC_2016_gamelogs = SAC_2016_gamelog.copy()
SAC_2016_gamelogs['GAME_SCORE'] = SAC_2016_gamelogs['GAME_SCORE'].astype(float)
SAC_2016_games = SAC_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2016_games_csv = SAC_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2016_games.csv', index=False)
SAC_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2016_games.csv')
SAC_2016_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# ...

# %%
SAC_2017_gamelog = []

for p in SAC_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2017_gamelog.append(player_log)
SAC_2017_gamelog = pd.concat(SAC_2017_gamelog)    
SAC_2017_gamelogs = SAC_2017_gamelog.copy()
SAC_2017_gamelogs['GAME_SCORE'] = SAC_2017_gamelogs['GAME_SCORE'].astype(float)
SAC_2017_games = SAC_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2017_games_csv = SAC_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2017_games.csv', index=False)
SAC_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2017_games.csv')
SAC_2017_games_proc.head()
# Out:
# You searched for "Arron Afflalo"
# 1 result found.
# Arron Afflalo
# Results for Arron Afflalo:
#
# You searched for "Matt Barnes"
# 10 results found.
# 0: Matt Barnes
# 1: Matt Bonner
# 2: Marty Byrnes
# 3: Harry Barnes
# 4: Jim Barnes
# 5: Marvin Barnes
# 6: Matt Maloney
# 7: Matt Mooney
# 8: Matt Walsh
# 9: Matt Bullard
# Pick one: 0
# Results for Matt Barnes:
#
# You searched for "Omri Casspi"
# 1 result found.
# Omri Casspi
# Results for Omri Casspi:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Darren Collison"
# 3 results found.
# 0: Darren Collison
# 1: Darren Tillis
# 2: Jarron Collins
# Pick one: 0
# Results for Darren Collison:
#
# You searched for "DeMarcus Cousins"
# 2 results found.
# 0: DeMarcus Cousins
# 1: Marcus Cousin
# Pick one: 0
# Results for DeMarcus Cousins:
#
# You searched for "Tyreke Evans"
# 3 results found.
# 0: Tyreke Evans
# 1: Jeremy Evans
# 2: Mike Evans
# ...

# %%
SAC_2018_gamelog = []

for p in SAC_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2018_gamelog.append(player_log)
SAC_2018_gamelog = pd.concat(SAC_2018_gamelog)    
SAC_2018_gamelogs = SAC_2018_gamelog.copy()
SAC_2018_gamelogs['GAME_SCORE'] = SAC_2018_gamelogs['GAME_SCORE'].astype(float)
SAC_2018_games = SAC_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2018_games_csv = SAC_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2018_games.csv', index=False)
SAC_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2018_games.csv')
SAC_2018_games_proc.head()
# Out:
# You searched for "Bogdan Bogdanović"
# 2 results found.
# 0: Bogdan Bogdanovic
# 1: Bojan Bogdanovic
# Pick one: 0
# Results for Bogdan Bogdanovic:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Jack Cooley"
# 15 results found.
# 0: Jack Cooley
# 1: Jack Foley
# 2: Jack Haley
# 3: Jack Kiley
# 4: Jack Smiley
# 5: Jack Toomay
# 6: Jack Coleman
# 7: Ray Corley
# 8: Jack Cotton
# 9: Jacky Dorsey
# 10: Jack Rocker
# 11: Jack George
# 12: Jackie Moore
# 13: Jack Nichols
# 14: Jack Tingle
# Pick one: 0
# Results for Jack Cooley:
#
# You searched for "De'Aaron Fox"
# 1 result found.
# De'Aaron Fox
# ...

# %%
# removed Marvin BAgley
SAC_2019_gamelog = []

for p in SAC_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2019_gamelog.append(player_log)
SAC_2019_gamelog = pd.concat(SAC_2019_gamelog)    
SAC_2019_gamelogs = SAC_2019_gamelog.copy()
SAC_2019_gamelogs['GAME_SCORE'] = SAC_2019_gamelogs['GAME_SCORE'].astype(float)
SAC_2019_games = SAC_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2019_games_csv = SAC_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2019_games.csv', index=False)
SAC_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2019_games.csv')
SAC_2019_games_proc.head()
# Out:
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Bogdan Bogdanović"
# 2 results found.
# 0: Bogdan Bogdanovic
# 1: Bojan Bogdanovic
# Pick one: 0
# Results for Bogdan Bogdanovic:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Yogi Ferrell"
# 1 result found.
# Yogi Ferrell
# Results for Yogi Ferrell:
#
# You searched for "De'Aaron Fox"
# 1 result found.
# ...

# %%
# removed kelly oubre

SAC_2020_gamelog = []

for p in SAC_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2020_gamelog.append(player_log)
SAC_2020_gamelog = pd.concat(SAC_2020_gamelog)    
SAC_2020_gamelogs = SAC_2020_gamelog.copy()
SAC_2020_gamelogs['GAME_SCORE'] = SAC_2020_gamelogs['GAME_SCORE'].astype(float)
SAC_2020_games = SAC_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2020_games_csv = SAC_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2020_games.csv', index=False)
SAC_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2020_games.csv')
SAC_2020_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Kent Bazemore"
# 1 result found.
# Kent Bazemore
# Results for Kent Bazemore:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Bogdan Bogdanović"
# 2 results found.
# 0: Bogdan Bogdanovic
# 1: Bojan Bogdanovic
# Pick one: 0
# Results for Bogdan Bogdanovic:
#
# You searched for "Corey Brewer"
# 4 results found.
# 0: Corey Brewer
# 1: Corey Crowder
# 2: Corey Beck
# 3: Ron Brewer
# Pick one: 0
# Results for Corey Brewer:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Yogi Ferrell"
# 1 result found.
# Yogi Ferrell
# Results for Yogi Ferrell:
#
# ...

# %%
# remvoed Marvin Bagley
SAC_2021_gamelog = []

for p in SAC_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    SAC_2021_gamelog.append(player_log)
SAC_2021_gamelog = pd.concat(SAC_2021_gamelog)    
SAC_2021_gamelogs = SAC_2021_gamelog.copy()
SAC_2021_gamelogs['GAME_SCORE'] = SAC_2021_gamelogs['GAME_SCORE'].astype(float)
SAC_2021_games = SAC_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_2021_games_csv = SAC_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2021_games.csv', index=False)
SAC_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2021_games.csv')
SAC_2021_games_proc.head()
# Out:
# You searched for "Harrison Barnes"
# 3 results found.
# 0: Harrison Barnes
# 1: Harry Barnes
# 2: Marvin Barnes
# Pick one: 0
# Results for Harrison Barnes:
#
# You searched for "Nemanja Bjelica"
# 1 result found.
# Nemanja Bjelica
# Results for Nemanja Bjelica:
#
# You searched for "Terence Davis"
# 3 results found.
# 0: Terence Davis
# 1: Terry Davis
# 2: Terence Morris
# Pick one: 0
# Results for Terence Davis:
#
# You searched for "De'Aaron Fox"
# 1 result found.
# De'Aaron Fox
# Results for De'Aaron Fox:
#
# You searched for "Kyle Guy"
# 5 results found.
# 0: Kyle Guy
# 1: Kyle Macy
# 2: Tyler Bey
# 3: Kyle Kuzma
# 4: Kyle Lowry
# Pick one: 0
# Results for Kyle Guy:
#
# You searched for "Tyrese Haliburton"
# 1 result found.
# Tyrese Haliburton
# Results for Tyrese Haliburton:
#
# You searched for "Maurice Harkless"
# 2 results found.
# 0: Maurice Harkless
# 1: Maurice McHartley
# Pick one: 0
# Results for Maurice Harkless:
#
# You searched for "Buddy Hield"
# 1 result found.
# ...

# %% [markdown]
# ## combine all seasons

# %%
SAC_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2000_games.csv')
SAC_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2001_games.csv')
SAC_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2002_games.csv')
SAC_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2003_games.csv')
SAC_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2004_games.csv')
SAC_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2005_games.csv')
SAC_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2006_games.csv')
SAC_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2007_games.csv')
SAC_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2008_games.csv')
SAC_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2009_games.csv')
SAC_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2010_games.csv')
SAC_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2011_games.csv')
SAC_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2012_games.csv')
SAC_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2013_games.csv')
SAC_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2014_games.csv')
SAC_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2015_games.csv')
SAC_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2016_games.csv')
SAC_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2017_games.csv')
SAC_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2018_games.csv')
SAC_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2019_games.csv')
SAC_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2020_games.csv')
SAC_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAC/SAC_2021_games.csv')

# %%
SAC_season_dfs = [SAC_2000_games_io, SAC_2001_games_io, SAC_2002_games_io, SAC_2003_games_io, SAC_2004_games_io, SAC_2005_games_io,
                 SAC_2006_games_io, SAC_2007_games_io, SAC_2008_games_io, SAC_2009_games_io, SAC_2010_games_io, SAC_2011_games_io,
                 SAC_2012_games_io, SAC_2013_games_io, SAC_2014_games_io, SAC_2015_games_io, SAC_2016_games_io, SAC_2017_games_io,
                 SAC_2018_games_io, SAC_2019_games_io, SAC_2020_games_io, SAC_2021_games_io]

# %%
SAC_all = pd.concat(SAC_season_dfs)
SAC_all_sorted = SAC_all.sort_values(by=['GAME_SCORE'], ascending=False)
SAC_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2016-12-20  26-129  SAC      HOME      POR   W (+5)   1  40:35  17   28
# 0  2016-01-25  25-165  SAC      HOME      CHO   L (-1)   1  45:40  21   30
# 0  2021-01-17  23-028  SAC      HOME      NOP   L (-5)   1  39:02  17   27
# 0  2001-01-05  27-310  SAC      HOME      IND   L (-2)   1  49:58  24   47
# 1  2021-03-25  23-095  SAC      HOME      GSW  W (+22)   1  35:40  16   22
# 1  2017-01-30  26-170  SAC      AWAY      PHI   L (-3)   1  32:16  11   16
# 1  2001-02-02  27-338  SAC      HOME      VAN  W (+10)   1  38:42  15   23
# 0  2009-11-02  26-274  SAC      HOME      MEM  W (+11)   1  52:28  14   27
# 0  2002-03-19  29-018  SAC      HOME      HOU  W (+23)   1  31:54  15   20
# 0  2011-03-14  23-282  SAC      HOME      GSW  W (+10)   1  41:27  13   20
# 0  2009-04-01  26-059  SAC      AWAY      GSW   L (-2)   1  46:05  11   22
# ...
