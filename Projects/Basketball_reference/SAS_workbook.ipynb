# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_SAS = []

# SAS
while season <= 2021:
    df_SAS = get_roster('SAS', season)
    df_SAS['Season'] = season
    df_SAS['Team'] = 'SAS'
    appended_data_SAS.append(df_SAS)
    season = season + 1
appended_data_SAS = pd.concat(appended_data_SAS)

# %%
SAS_df_all = appended_data_SAS.copy()
SAS_df_all_csv = SAS_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_players_all.csv', index=False)
SAS_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_players_all.csv')
SAS_df_all_csv_io.head()
# Out:
#    NUMBER           PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0      52     Chucky Brown  PF    6-7     214  1968-02-29          US
# 1      33  Antonio Daniels  SG    6-4     195  1975-03-19          US
# 2       5     Derrick Dial  SG    6-4     184  1975-12-20          US
# 3      21       Tim Duncan  PF   6-11     250  1976-04-25          VI
# 4      17       Mario Elie  SF    6-5     210  1963-11-26          US
#
#   EXPERIENCE                         COLLEGE  Season Team
# 0         10                        NC State    2000  SAS
# 1          2                   Bowling Green    2000  SAS
# 2          R                Eastern Michigan    2000  SAS
# 3          2                     Wake Forest    2000  SAS
# 4          9  American International College    2000  SAS

# %%
SAS_df_2000 = SAS_df_all[SAS_df_all['Season'] == 2000]
SAS_df_2001 = SAS_df_all[SAS_df_all['Season'] == 2001]
SAS_df_2002 = SAS_df_all[SAS_df_all['Season'] == 2002]
SAS_df_2003 = SAS_df_all[SAS_df_all['Season'] == 2003]
SAS_df_2004 = SAS_df_all[SAS_df_all['Season'] == 2004]
SAS_df_2005 = SAS_df_all[SAS_df_all['Season'] == 2005]
SAS_df_2006 = SAS_df_all[SAS_df_all['Season'] == 2006]
SAS_df_2007 = SAS_df_all[SAS_df_all['Season'] == 2007]
SAS_df_2008 = SAS_df_all[SAS_df_all['Season'] == 2008]
SAS_df_2009 = SAS_df_all[SAS_df_all['Season'] == 2009]
SAS_df_2010 = SAS_df_all[SAS_df_all['Season'] == 2010]
SAS_df_2011 = SAS_df_all[SAS_df_all['Season'] == 2011]
SAS_df_2012 = SAS_df_all[SAS_df_all['Season'] == 2012]
SAS_df_2013 = SAS_df_all[SAS_df_all['Season'] == 2013]
SAS_df_2014 = SAS_df_all[SAS_df_all['Season'] == 2014]
SAS_df_2015 = SAS_df_all[SAS_df_all['Season'] == 2015]
SAS_df_2016 = SAS_df_all[SAS_df_all['Season'] == 2016]
SAS_df_2017 = SAS_df_all[SAS_df_all['Season'] == 2017]
SAS_df_2018 = SAS_df_all[SAS_df_all['Season'] == 2018]
SAS_df_2019 = SAS_df_all[SAS_df_all['Season'] == 2019]
SAS_df_2020 = SAS_df_all[SAS_df_all['Season'] == 2020]
SAS_df_2021 = SAS_df_all[SAS_df_all['Season'] == 2021]

# %%
# changing names
#SAS_df_2002.loc[SAS_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#SAS_df_2004.loc[SAS_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
SAS_df_2000_players = SAS_df_2000['PLAYER'].to_list()
SAS_df_2001_players = SAS_df_2001['PLAYER'].to_list()
SAS_df_2002_players = SAS_df_2002['PLAYER'].to_list()
SAS_df_2003_players = SAS_df_2003['PLAYER'].to_list()
SAS_df_2004_players = SAS_df_2004['PLAYER'].to_list()
SAS_df_2005_players = SAS_df_2005['PLAYER'].to_list()

SAS_df_2006_players = SAS_df_2006['PLAYER'].to_list()
SAS_df_2007_players = SAS_df_2007['PLAYER'].to_list()
SAS_df_2008_players = SAS_df_2008['PLAYER'].to_list()
SAS_df_2009_players = SAS_df_2009['PLAYER'].to_list()
SAS_df_2010_players = SAS_df_2010['PLAYER'].to_list()
SAS_df_2011_players = SAS_df_2011['PLAYER'].to_list()

SAS_df_2012_players = SAS_df_2012['PLAYER'].to_list()
SAS_df_2013_players = SAS_df_2013['PLAYER'].to_list()
SAS_df_2014_players = SAS_df_2014['PLAYER'].to_list()
SAS_df_2015_players = SAS_df_2015['PLAYER'].to_list()
SAS_df_2016_players = SAS_df_2016['PLAYER'].to_list()
SAS_df_2017_players = SAS_df_2017['PLAYER'].to_list()

SAS_df_2018_players = SAS_df_2018['PLAYER'].to_list()
SAS_df_2019_players = SAS_df_2019['PLAYER'].to_list()
SAS_df_2020_players = SAS_df_2020['PLAYER'].to_list()
SAS_df_2021_players = SAS_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#SAS_df_2002_players.remove("Charles Smith")
#SAS_df_2008_players.remove("Bobby Jones")
#SAS_df_2014_players.remove("Jeff Ayres")
#SAS_df_2015_players.remove("Jeff Ayres")
#SAS_df_2015_players.remove("Reggie Williams")
SAS_df_2017_players.remove("David Lee")

# %%
SAS_2000_gamelog = []


for p in SAS_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2000_gamelog.append(player_log)
SAS_2000_gamelog = pd.concat(SAS_2000_gamelog)    
SAS_2000_gamelogs = SAS_2000_gamelog.copy()
SAS_2000_gamelogs['GAME_SCORE'] = SAS_2000_gamelogs['GAME_SCORE'].astype(float)
SAS_2000_games = SAS_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2000_games_csv = SAS_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2000_games.csv', index=False)
SAS_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2000_games.csv')
SAS_2000_games_proc.head()
# Out:
# You searched for "Chucky Brown"
# 3 results found.
# 0: Chucky Brown
# 1: Bruce Brown
# 2: Rickey Brown
# Pick one: 0
# Results for Chucky Brown:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Derrick Dial"
# 4 results found.
# 0: Derrick Dial
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick White
# Pick one: 0
# Results for Derrick Dial:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Mario Elie"
# 3 results found.
# 0: Mario Elie
# 1: Marko Milic
# 2: Mario West
# Pick one: 0
# Results for Mario Elie:
#
# You searched for "Sean Elliott"
# 2 results found.
# 0: Sean Elliott
# 1: Bob Elliott
# Pick one: 0
# Results for Sean Elliott:
#
# You searched for "Jaren Jackson"
# 19 results found.
# 0: Jaren Jackson
# 1: Jaren Jackson
# 2: Aaron Jackson
# 3: Greg Jackson
# ...

# %%
SAS_2001_gamelog = []


for p in SAS_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2001_gamelog.append(player_log)
SAS_2001_gamelog = pd.concat(SAS_2001_gamelog)    
SAS_2001_gamelogs = SAS_2001_gamelog.copy()
SAS_2001_gamelogs['GAME_SCORE'] = SAS_2001_gamelogs['GAME_SCORE'].astype(float)
SAS_2001_games = SAS_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2001_games_csv = SAS_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2001_games.csv', index=False)
SAS_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2001_games.csv')
SAS_2001_games_proc.head()
# Out:
# You searched for "Derek Anderson"
# 12 results found.
# 0: Derek Anderson
# 1: Eric Anderson
# 2: Greg Anderson
# 3: Andrew Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: James Anderson
# 7: Jerome Anderson
# 8: Kenny Anderson
# 9: Kyle Anderson
# 10: Nick Anderson
# 11: Ron Anderson
# Pick one: 0
# Results for Derek Anderson:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Derrick Dial"
# 4 results found.
# 0: Derrick Dial
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick White
# Pick one: 0
# Results for Derrick Dial:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Sean Elliott"
# 2 results found.
# 0: Sean Elliott
# 1: Bob Elliott
# Pick one: 0
# Results for Sean Elliott:
#
# You searched for "Danny Ferry"
# 6 results found.
# 0: Danny Ferry
# 1: Danny Finn
# ...

# %%
SAS_2002_gamelog = []


for p in SAS_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2002_gamelog.append(player_log)
SAS_2002_gamelog = pd.concat(SAS_2002_gamelog)    
SAS_2002_gamelogs = SAS_2002_gamelog.copy()
SAS_2002_gamelogs['GAME_SCORE'] = SAS_2002_gamelogs['GAME_SCORE'].astype(float)
SAS_2002_games = SAS_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2002_games_csv = SAS_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2002_games.csv', index=False)
SAS_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2002_games.csv')
SAS_2002_games_proc.head()
# Out:
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Mark Bryant"
# 11 results found.
# 0: Mark Bryant
# 1: Mark Blount
# 2: Mark Bradtke
# 3: Em Bryant
# 4: Joe Bryant
# 5: Kobe Bryant
# 6: Gary Grant
# 7: Markel Brown
# 8: Mark Eaton
# 9: Mark Workman
# 10: Mark Sibley
# Pick one: 0
# Results for Mark Bryant:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Danny Ferry"
# 6 results found.
# 0: Danny Ferry
# 1: Danny Finn
# 2: Danny Ainge
# 3: Danny Doyle
# 4: Danny Green
# 5: Danny Wagner
# Pick one: 0
# Results for Danny Ferry:
#
# You searched for "Jason Hart"
# 9 results found.
# ...

# %%
    
SAS_2003_gamelog = []



for p in SAS_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2003_gamelog.append(player_log)
SAS_2003_gamelog = pd.concat(SAS_2003_gamelog)    
SAS_2003_gamelogs = SAS_2003_gamelog.copy()
SAS_2003_gamelogs['GAME_SCORE'] = SAS_2003_gamelogs['GAME_SCORE'].astype(float)
SAS_2003_games = SAS_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2003_games_csv = SAS_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2003_games.csv', index=False)
SAS_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2003_games.csv')
SAS_2003_games_proc.head()
# Out:
# You searched for "Mengke Bateer"
# 1 result found.
# Mengke Bateer
# Results for Mengke Bateer:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# 14: Jim Browne
# Pick one: 0
# Results for Devin Brown:
#
# You searched for "Speedy Claxton"
# 1 result found.
# Speedy Claxton
# Results for Speedy Claxton:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Danny Ferry"
# 6 results found.
# 0: Danny Ferry
# 1: Danny Finn
# 2: Danny Ainge
# 3: Danny Doyle
# ...

# %%
SAS_2004_gamelog = []



for p in SAS_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2004_gamelog.append(player_log)
SAS_2004_gamelog = pd.concat(SAS_2004_gamelog)    
SAS_2004_gamelogs = SAS_2004_gamelog.copy()
SAS_2004_gamelogs['GAME_SCORE'] = SAS_2004_gamelogs['GAME_SCORE'].astype(float)
SAS_2004_games = SAS_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2004_games_csv = SAS_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2004_games.csv', index=False)
SAS_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2004_games.csv')
SAS_2004_games_proc.head()
# Out:
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# 14: Jim Browne
# Pick one: 0
# Results for Devin Brown:
#
# You searched for "Matt Carroll"
# 1 result found.
# Matt Carroll
# Results for Matt Carroll:
#
# You searched for "Anthony Carter"
# 8 results found.
# 0: Anthony Carter
# 1: Anthony Parker
# 2: Anthony Bonner
# 3: Anthony Miller
# 4: Anthony Peeler
# 5: Anthony Taylor
# 6: Anthony Tucker
# 7: Anthony Avent
# Pick one: 0
# Results for Anthony Carter:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# ...

# %%
SAS_2005_gamelog = []



for p in SAS_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2005_gamelog.append(player_log)
SAS_2005_gamelog = pd.concat(SAS_2005_gamelog)    
SAS_2005_gamelogs = SAS_2005_gamelog.copy()
SAS_2005_gamelogs['GAME_SCORE'] = SAS_2005_gamelogs['GAME_SCORE'].astype(float)
SAS_2005_games = SAS_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2005_games_csv = SAS_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2005_games.csv', index=False)
SAS_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2005_games.csv')
SAS_2005_games_proc.head()
# Out:
# You searched for "Brent Barry"
# 4 results found.
# 0: Brent Barry
# 1: Drew Barry
# 2: Jon Barry
# 3: Rick Barry
# Pick one: 0
# Results for Brent Barry:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# 14: Jim Browne
# Pick one: 0
# Results for Devin Brown:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Manu Ginóbili"
# 1 result found.
# Manu Ginobili
# Results for Manu Ginobili:
#
# You searched for "Dion Glover"
# 3 results found.
# ...

# %%
SAS_2006_gamelog = []

for p in SAS_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2006_gamelog.append(player_log)
SAS_2006_gamelog = pd.concat(SAS_2006_gamelog)    
SAS_2006_gamelogs = SAS_2006_gamelog.copy()
SAS_2006_gamelogs['GAME_SCORE'] = SAS_2006_gamelogs['GAME_SCORE'].astype(float)
SAS_2006_games = SAS_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2006_games_csv = SAS_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2006_games.csv', index=False)
SAS_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2006_games.csv')
SAS_2006_games_proc.head()
# Out:
# You searched for "Brent Barry"
# 4 results found.
# 0: Brent Barry
# 1: Drew Barry
# 2: Jon Barry
# 3: Rick Barry
# Pick one: 0
# Results for Brent Barry:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Manu Ginóbili"
# 1 result found.
# Manu Ginobili
# Results for Manu Ginobili:
#
# You searched for "Robert Horry"
# 7 results found.
# 0: Robert Horry
# 1: Robert Hahn
# 2: Robert Hite
# 3: Robert Sacre
# 4: Robert Whaley
# ...

# %%
SAS_2007_gamelog = []

for p in SAS_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2007_gamelog.append(player_log)
SAS_2007_gamelog = pd.concat(SAS_2007_gamelog)    
SAS_2007_gamelogs = SAS_2007_gamelog.copy()
SAS_2007_gamelogs['GAME_SCORE'] = SAS_2007_gamelogs['GAME_SCORE'].astype(float)
SAS_2007_games = SAS_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2007_games_csv = SAS_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2007_games.csv', index=False)
SAS_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2007_games.csv')
SAS_2007_games_proc.head()
# Out:
# You searched for "Brent Barry"
# 4 results found.
# 0: Brent Barry
# 1: Drew Barry
# 2: Jon Barry
# 3: Rick Barry
# Pick one: 0
# Results for Brent Barry:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Jackie Butler"
# 3 results found.
# 0: Jackie Butler
# 1: Mike Butler
# 2: Jackie Ridgle
# Pick one: 0
# Results for Jackie Butler:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Melvin Ely"
# 1 result found.
# Melvin Ely
# Results for Melvin Ely:
#
# ...

# %%
SAS_2008_gamelog = []

for p in SAS_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2008_gamelog.append(player_log)
SAS_2008_gamelog = pd.concat(SAS_2008_gamelog)    
SAS_2008_gamelogs = SAS_2008_gamelog.copy()
SAS_2008_gamelogs['GAME_SCORE'] = SAS_2008_gamelogs['GAME_SCORE'].astype(float)
SAS_2008_games = SAS_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2008_games_csv = SAS_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2008_games.csv', index=False)
SAS_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2008_games.csv')
SAS_2008_games_proc.head()
# Out:
# You searched for "Brent Barry"
# 4 results found.
# 0: Brent Barry
# 1: Drew Barry
# 2: Jon Barry
# 3: Rick Barry
# Pick one: 0
# Results for Brent Barry:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# ...

# %%
SAS_2009_gamelog = []

for p in SAS_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2009_gamelog.append(player_log)
SAS_2009_gamelog = pd.concat(SAS_2009_gamelog)    
SAS_2009_gamelogs = SAS_2009_gamelog.copy()
SAS_2009_gamelogs['GAME_SCORE'] = SAS_2009_gamelogs['GAME_SCORE'].astype(float)
SAS_2009_games = SAS_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2009_games_csv = SAS_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2009_games.csv', index=False)
SAS_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2009_games.csv')
SAS_2009_games_proc.head()
# Out:
# You searched for "Blake Ahearn"
# 1 result found.
# Blake Ahearn
# Results for Blake Ahearn:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Bruce Bowen"
# 6 results found.
# 0: Bruce Bowen
# 1: Bruce Brown
# 2: Brian Bowen
# 3: Ryan Bowen
# 4: Bruce Flowers
# 5: Bruce Hale
# Pick one: 0
# Results for Bruce Bowen:
#
# You searched for "Austin Croshere"
# 1 result found.
# Austin Croshere
# Results for Austin Croshere:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Desmon Farmer"
# 1 result found.
# Desmon Farmer
# Results for Desmon Farmer:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# ...

# %%
SAS_2010_gamelog = []

for p in SAS_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2010_gamelog.append(player_log)
SAS_2010_gamelog = pd.concat(SAS_2010_gamelog)    
SAS_2010_gamelogs = SAS_2010_gamelog.copy()
SAS_2010_gamelogs['GAME_SCORE'] = SAS_2010_gamelogs['GAME_SCORE'].astype(float)
SAS_2010_games = SAS_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2010_games_csv = SAS_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2010_games.csv', index=False)
SAS_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2010_games.csv')
SAS_2010_games_proc.head()
# Out:
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Keith Bogans"
# 5 results found.
# 0: Keith Bogans
# 1: Keith Owens
# 2: Keith Askins
# 3: Keith Booth
# 4: Keith Benson
# Pick one: 0
# Results for Keith Bogans:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Michael Finley"
# 8 results found.
# 0: Michael Finley
# 1: Michael Wiley
# 2: Michael Ansley
# 3: Michael Beasley
# 4: Michael Bradley
# 5: Michael Gbinije
# 6: Michael Wilson
# 7: Michael Ruffin
# Pick one: 0
# Results for Michael Finley:
#
# You searched for "Manu Ginóbili"
# 1 result found.
# Manu Ginobili
# Results for Manu Ginobili:
#
# ...

# %%
SAS_2011_gamelog = []

for p in SAS_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2011_gamelog.append(player_log)
SAS_2011_gamelog = pd.concat(SAS_2011_gamelog)    
SAS_2011_gamelogs = SAS_2011_gamelog.copy()
SAS_2011_gamelogs['GAME_SCORE'] = SAS_2011_gamelogs['GAME_SCORE'].astype(float)
SAS_2011_games = SAS_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2011_games_csv = SAS_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2011_games.csv', index=False)
SAS_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2011_games.csv')
SAS_2011_games_proc.head()
# Out:
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# Pick one: 0
# Results for Tim Duncan:
#
# You searched for "Alonzo Gee"
# 1 result found.
# Alonzo Gee
# Results for Alonzo Gee:
#
# You searched for "Manu Ginóbili"
# 1 result found.
# Manu Ginobili
# Results for Manu Ginobili:
#
# You searched for "Danny Green"
# 20 results found.
# 0: Danny Green
# 1: Kenny Green
# ...

# %%
SAS_2012_gamelog = []

for p in SAS_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2012_gamelog.append(player_log)
SAS_2012_gamelog = pd.concat(SAS_2012_gamelog)    
SAS_2012_gamelogs = SAS_2012_gamelog.copy()
SAS_2012_gamelogs['GAME_SCORE'] = SAS_2012_gamelogs['GAME_SCORE'].astype(float)
SAS_2012_games = SAS_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2012_games_csv = SAS_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2012_games.csv', index=False)
SAS_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2012_games.csv')
SAS_2012_games_proc.head()
# Out:
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Derrick Byars"
# 7 results found.
# 0: Derrick Byars
# 1: Derrick Brown
# 2: Derrick Dial
# 3: Derrick Favors
# 4: Derrick Jones
# 5: Derrick McKey
# 6: Derrick Rose
# Pick one: 0
# Results for Derrick Byars:
#
# You searched for "Eric Dawson"
# 8 results found.
# 0: Eric Dawson
# 1: Eric Anderson
# 2: Tony Dawson
# 3: Eric Gordon
# 4: Eric Johnson
# 5: Eric Maynor
# 6: Eric Snow
# ...

# %%
SAS_2013_gamelog = []

for p in SAS_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2013_gamelog.append(player_log)
SAS_2013_gamelog = pd.concat(SAS_2013_gamelog)    
SAS_2013_gamelogs = SAS_2013_gamelog.copy()
SAS_2013_gamelogs['GAME_SCORE'] = SAS_2013_gamelogs['GAME_SCORE'].astype(float)
SAS_2013_games = SAS_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2013_games_csv = SAS_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2013_games.csv', index=False)
SAS_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2013_games.csv')
SAS_2013_games_proc.head()
# Out:
# You searched for "James Anderson"
# 10 results found.
# 0: James Anderson
# 1: Alan Anderson
# 2: Dan Anderson
# 3: Dan Anderson
# 4: Derek Anderson
# 5: Greg Anderson
# 6: J.J. Anderson
# 7: Jerome Anderson
# 8: Kim Anderson
# 9: Kyle Anderson
# Pick one: 0
# Results for James Anderson:
#
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Nando De Colo"
# 1 result found.
# Nando De Colo
# Results for Nando De Colo:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# ...

# %%
SAS_2014_gamelog = []

for p in SAS_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2014_gamelog.append(player_log)
SAS_2014_gamelog = pd.concat(SAS_2014_gamelog)    
SAS_2014_gamelogs = SAS_2014_gamelog.copy()
SAS_2014_gamelogs['GAME_SCORE'] = SAS_2014_gamelogs['GAME_SCORE'].astype(float)
SAS_2014_games = SAS_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2014_games_csv = SAS_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2014_games.csv', index=False)
SAS_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2014_games.csv')
SAS_2014_games_proc.head()
# Out:
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Shannon Brown"
# 2 results found.
# 0: Shannon Brown
# 1: Stan Brown
# Pick one: 0
# Results for Shannon Brown:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Nando De Colo"
# 1 result found.
# Nando De Colo
# Results for Nando De Colo:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# ...

# %%
SAS_2015_gamelog = []

for p in SAS_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2015_gamelog.append(player_log)
SAS_2015_gamelog = pd.concat(SAS_2015_gamelog)    
SAS_2015_gamelogs = SAS_2015_gamelog.copy()
SAS_2015_gamelogs['GAME_SCORE'] = SAS_2015_gamelogs['GAME_SCORE'].astype(float)
SAS_2015_games = SAS_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2015_games_csv = SAS_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2015_games.csv', index=False)
SAS_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2015_games.csv')
SAS_2015_games_proc.head()
# Out:
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# ...

# %%
SAS_2016_gamelog = []

for p in SAS_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2016_gamelog.append(player_log)
SAS_2016_gamelog = pd.concat(SAS_2016_gamelog)    
SAS_2016_gamelogs = SAS_2016_gamelog.copy()
SAS_2016_gamelogs['GAME_SCORE'] = SAS_2016_gamelogs['GAME_SCORE'].astype(float)
SAS_2016_games = SAS_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2016_games_csv = SAS_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2016_games.csv', index=False)
SAS_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2016_games.csv')
SAS_2016_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# You searched for "Tim Duncan"
# 2 results found.
# 0: Tim Duncan
# 1: Andy Duncan
# ...

# %%
SAS_2017_gamelog = []

for p in SAS_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2017_gamelog.append(player_log)
SAS_2017_gamelog = pd.concat(SAS_2017_gamelog)    
SAS_2017_gamelogs = SAS_2017_gamelog.copy()
SAS_2017_gamelogs['GAME_SCORE'] = SAS_2017_gamelogs['GAME_SCORE'].astype(float)
SAS_2017_games = SAS_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2017_games_csv = SAS_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2017_games.csv', index=False)
SAS_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2017_games.csv')
SAS_2017_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Joel Anthony"
# 3 results found.
# 0: Joel Anthony
# 1: Cole Anthony
# 2: Greg Anthony
# Pick one: 0
# Results for Joel Anthony:
#
# You searched for "Dāvis Bertāns"
# 3 results found.
# 0: Davis Bertans
# 1: Dairis Bertans
# 2: David Burns
# Pick one: 0
# Results for Davis Bertans:
#
# You searched for "Dewayne Dedmon"
# 1 result found.
# Dewayne Dedmon
# Results for Dewayne Dedmon:
#
# You searched for "Bryn Forbes"
# 2 results found.
# ...

# %%
SAS_2018_gamelog = []

for p in SAS_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2018_gamelog.append(player_log)
SAS_2018_gamelog = pd.concat(SAS_2018_gamelog)    
SAS_2018_gamelogs = SAS_2018_gamelog.copy()
SAS_2018_gamelogs['GAME_SCORE'] = SAS_2018_gamelogs['GAME_SCORE'].astype(float)
SAS_2018_games = SAS_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2018_games_csv = SAS_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2018_games.csv', index=False)
SAS_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2018_games.csv')
SAS_2018_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Kyle Anderson"
# 16 results found.
# 0: Kyle Anderson
# 1: Kim Anderson
# 2: Ryan Anderson
# 3: Alan Anderson
# 4: Dan Anderson
# 5: Dan Anderson
# 6: Derek Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Nick Anderson
# 13: Ron Anderson
# 14: Willie Anderson
# 15: Kyle Alexander
# Pick one: 0
# Results for Kyle Anderson:
#
# You searched for "Dāvis Bertāns"
# 3 results found.
# 0: Davis Bertans
# 1: Dairis Bertans
# 2: David Burns
# Pick one: 0
# Results for Davis Bertans:
#
# You searched for "Matt Costello"
# 2 results found.
# 0: Matt Costello
# 1: Larry Costello
# Pick one: 0
# Results for Matt Costello:
#
# You searched for "Bryn Forbes"
# 2 results found.
# 0: Bryn Forbes
# 1: Gary Forbes
# Pick one: 0
# Results for Bryn Forbes:
#
# You searched for "Pau Gasol"
# 7 results found.
# ...

# %%
SAS_2019_gamelog = []

for p in SAS_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2019_gamelog.append(player_log)
SAS_2019_gamelog = pd.concat(SAS_2019_gamelog)    
SAS_2019_gamelogs = SAS_2019_gamelog.copy()
SAS_2019_gamelogs['GAME_SCORE'] = SAS_2019_gamelogs['GAME_SCORE'].astype(float)
SAS_2019_games = SAS_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2019_games_csv = SAS_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2019_games.csv', index=False)
SAS_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2019_games.csv')
SAS_2019_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Dāvis Bertāns"
# 3 results found.
# 0: Davis Bertans
# 1: Dairis Bertans
# 2: David Burns
# Pick one: 0
# Results for Davis Bertans:
#
# You searched for "Dante Cunningham"
# 3 results found.
# 0: Dante Cunningham
# 1: Dick Cunningham
# 2: Jared Cunningham
# Pick one: 0
# Results for Dante Cunningham:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Drew Eubanks"
# 1 result found.
# Drew Eubanks
# Results for Drew Eubanks:
#
# You searched for "Bryn Forbes"
# 2 results found.
# 0: Bryn Forbes
# 1: Gary Forbes
# Pick one: 0
# Results for Bryn Forbes:
#
# You searched for "Pau Gasol"
# 7 results found.
# 0: Pau Gasol
# 1: Marc Gasol
# 2: Paul Watson
# 3: Paul Davis
# 4: Paul Grant
# ...

# %%
SAS_2020_gamelog = []

for p in SAS_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2020_gamelog.append(player_log)
SAS_2020_gamelog = pd.concat(SAS_2020_gamelog)    
SAS_2020_gamelogs = SAS_2020_gamelog.copy()
SAS_2020_gamelogs['GAME_SCORE'] = SAS_2020_gamelogs['GAME_SCORE'].astype(float)
SAS_2020_games = SAS_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2020_games_csv = SAS_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2020_games.csv', index=False)
SAS_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2020_games.csv')
SAS_2020_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Drew Eubanks"
# 1 result found.
# Drew Eubanks
# Results for Drew Eubanks:
#
# You searched for "Bryn Forbes"
# 2 results found.
# 0: Bryn Forbes
# 1: Gary Forbes
# Pick one: 0
# Results for Bryn Forbes:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# You searched for "Keldon Johnson"
# 12 results found.
# 0: Keldon Johnson
# 1: Ken Johnson
# 2: Ken Johnson
# 3: Kevin Johnson
# 4: Armon Johnson
# 5: Clemon Johnson
# 6: Ed Johnson
# 7: Eddie Johnson
# ...

# %%
SAS_2021_gamelog = []

for p in SAS_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    SAS_2021_gamelog.append(player_log)
SAS_2021_gamelog = pd.concat(SAS_2021_gamelog)    
SAS_2021_gamelogs = SAS_2021_gamelog.copy()
SAS_2021_gamelogs['GAME_SCORE'] = SAS_2021_gamelogs['GAME_SCORE'].astype(float)
SAS_2021_games = SAS_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_2021_games_csv = SAS_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2021_games.csv', index=False)
SAS_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2021_games.csv')
SAS_2021_games_proc.head()
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:
#
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Drew Eubanks"
# 1 result found.
# Drew Eubanks
# Results for Drew Eubanks:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# You searched for "Keldon Johnson"
# 12 results found.
# 0: Keldon Johnson
# 1: Ken Johnson
# 2: Ken Johnson
# 3: Kevin Johnson
# 4: Armon Johnson
# 5: Clemon Johnson
# 6: Ed Johnson
# 7: Eddie Johnson
# 8: Eddie Johnson
# 9: Ervin Johnson
# 10: Linton Johnson
# 11: Ron Johnson
# Pick one: 0
# Results for Keldon Johnson:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
SAS_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2000_games.csv')
SAS_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2001_games.csv')
SAS_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2002_games.csv')
SAS_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2003_games.csv')
SAS_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2004_games.csv')
SAS_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2005_games.csv')
SAS_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2006_games.csv')
SAS_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2007_games.csv')
SAS_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2008_games.csv')
SAS_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2009_games.csv')
SAS_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2010_games.csv')
SAS_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2011_games.csv')
SAS_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2012_games.csv')
SAS_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2013_games.csv')
SAS_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2014_games.csv')
SAS_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2015_games.csv')
SAS_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2016_games.csv')
SAS_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2017_games.csv')
SAS_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2018_games.csv')
SAS_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2019_games.csv')
SAS_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2020_games.csv')
SAS_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/SAS/SAS_2021_games.csv')

# %%
SAS_season_dfs = [SAS_2000_games_io, SAS_2001_games_io, SAS_2002_games_io, SAS_2003_games_io, SAS_2004_games_io, SAS_2005_games_io,
                 SAS_2006_games_io, SAS_2007_games_io, SAS_2008_games_io, SAS_2009_games_io, SAS_2010_games_io, SAS_2011_games_io,
                 SAS_2012_games_io, SAS_2013_games_io, SAS_2014_games_io, SAS_2015_games_io, SAS_2016_games_io, SAS_2017_games_io,
                 SAS_2018_games_io, SAS_2019_games_io, SAS_2020_games_io, SAS_2021_games_io]

# %%
SAS_all = pd.concat(SAS_season_dfs)
SAS_all_sorted = SAS_all.sort_values(by=['GAME_SCORE'], ascending=False)
SAS_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2008-02-13  30-200  SAS      AWAY      CLE   W (+7)   1  40:34  15   20
# 0  2019-01-10  33-175  SAS      HOME      OKC   W (+7)   1  48:34  20   33
# 0  2003-03-04  26-313  SAS      HOME      PHO   L (-7)   1  43:39  14   18
# 0  2008-11-05  26-172  SAS      AWAY      MIN   W (+4)   1  50:32  22   36
# 0  2001-12-26  25-245  SAS      HOME      DAL   L (-3)   1  50:21  19   28
# 0  2005-01-21  27-177  SAS      AWAY      PHO   W (+5)   1  43:52  16   22
# 1  2003-01-14  26-264  SAS      HOME      PHO   W (+8)   1  50:50  16   25
# 0  1999-12-09  23-228  SAS      HOME      VAN   W (+8)   1  47:33  15   22
# 1  2019-03-24  33-248  SAS      AWAY      BOS  W (+19)   1  37:24  20   31
# 1  2008-02-21  30-208  SAS      AWAY      MIN   W (+1)   1  37:55  13   18
# 1  2009-03-25  26-312  SAS      AWAY      ATL  W (+10)   1  39:12  18   25
# ...
