# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_TOR = []

# TOR
while season <= 2021:
    df_TOR = get_roster('TOR', season)
    df_TOR['Season'] = season
    df_TOR['Team'] = 'TOR'
    appended_data_TOR.append(df_TOR)
    season = season + 1
appended_data_TOR = pd.concat(appended_data_TOR)

# %%
TOR_df_all = appended_data_TOR.copy()
TOR_df_all_csv = TOR_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_players_all.csv', index=False)
TOR_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_players_all.csv')
TOR_df_all_csv_io.head()
# Out:
#   NUMBER         PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0     14  Muggsy Bogues  PG    5-3     136  1965-01-09          US         12
# 1      7      Dee Brown  PG    6-1     160  1968-11-29          US          9
# 2     15   Vince Carter  SF    6-6     220  1977-01-26          US          1
# 3     13  Doug Christie  SG    6-6     200  1970-05-09          US          7
# 4     30     Dell Curry  SG    6-4     190  1964-06-25          US         13
#
#                    COLLEGE  Season Team
# 0              Wake Forest    2000  TOR
# 1  Jacksonville University    2000  TOR
# 2                      UNC    2000  TOR
# 3               Pepperdine    2000  TOR
# 4            Virginia Tech    2000  TOR

# %%
TOR_df_2000 = TOR_df_all[TOR_df_all['Season'] == 2000]
TOR_df_2001 = TOR_df_all[TOR_df_all['Season'] == 2001]
TOR_df_2002 = TOR_df_all[TOR_df_all['Season'] == 2002]
TOR_df_2003 = TOR_df_all[TOR_df_all['Season'] == 2003]
TOR_df_2004 = TOR_df_all[TOR_df_all['Season'] == 2004]
TOR_df_2005 = TOR_df_all[TOR_df_all['Season'] == 2005]
TOR_df_2006 = TOR_df_all[TOR_df_all['Season'] == 2006]
TOR_df_2007 = TOR_df_all[TOR_df_all['Season'] == 2007]
TOR_df_2008 = TOR_df_all[TOR_df_all['Season'] == 2008]
TOR_df_2009 = TOR_df_all[TOR_df_all['Season'] == 2009]
TOR_df_2010 = TOR_df_all[TOR_df_all['Season'] == 2010]
TOR_df_2011 = TOR_df_all[TOR_df_all['Season'] == 2011]
TOR_df_2012 = TOR_df_all[TOR_df_all['Season'] == 2012]
TOR_df_2013 = TOR_df_all[TOR_df_all['Season'] == 2013]
TOR_df_2014 = TOR_df_all[TOR_df_all['Season'] == 2014]
TOR_df_2015 = TOR_df_all[TOR_df_all['Season'] == 2015]
TOR_df_2016 = TOR_df_all[TOR_df_all['Season'] == 2016]
TOR_df_2017 = TOR_df_all[TOR_df_all['Season'] == 2017]
TOR_df_2018 = TOR_df_all[TOR_df_all['Season'] == 2018]
TOR_df_2019 = TOR_df_all[TOR_df_all['Season'] == 2019]
TOR_df_2020 = TOR_df_all[TOR_df_all['Season'] == 2020]
TOR_df_2021 = TOR_df_all[TOR_df_all['Season'] == 2021]

# %%
# changing names
#TOR_df_2002.loc[TOR_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#TOR_df_2004.loc[TOR_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
TOR_df_2000_players = TOR_df_2000['PLAYER'].to_list()
TOR_df_2001_players = TOR_df_2001['PLAYER'].to_list()
TOR_df_2002_players = TOR_df_2002['PLAYER'].to_list()
TOR_df_2003_players = TOR_df_2003['PLAYER'].to_list()
TOR_df_2004_players = TOR_df_2004['PLAYER'].to_list()
TOR_df_2005_players = TOR_df_2005['PLAYER'].to_list()

TOR_df_2006_players = TOR_df_2006['PLAYER'].to_list()
TOR_df_2007_players = TOR_df_2007['PLAYER'].to_list()
TOR_df_2008_players = TOR_df_2008['PLAYER'].to_list()
TOR_df_2009_players = TOR_df_2009['PLAYER'].to_list()
TOR_df_2010_players = TOR_df_2010['PLAYER'].to_list()
TOR_df_2011_players = TOR_df_2011['PLAYER'].to_list()

TOR_df_2012_players = TOR_df_2012['PLAYER'].to_list()
TOR_df_2013_players = TOR_df_2013['PLAYER'].to_list()
TOR_df_2014_players = TOR_df_2014['PLAYER'].to_list()
TOR_df_2015_players = TOR_df_2015['PLAYER'].to_list()
TOR_df_2016_players = TOR_df_2016['PLAYER'].to_list()
TOR_df_2017_players = TOR_df_2017['PLAYER'].to_list()

TOR_df_2018_players = TOR_df_2018['PLAYER'].to_list()
TOR_df_2019_players = TOR_df_2019['PLAYER'].to_list()
TOR_df_2020_players = TOR_df_2020['PLAYER'].to_list()
TOR_df_2021_players = TOR_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#TOR_df_2001_players.remove("Mamadou N'Diaye")
#TOR_df_2002_players.remove("Mamadou N'Diaye")
#TOR_df_2003_players.remove("Mamadou N'Diaye")
#TOR_df_2007_players.remove("Luke Jackson")
#TOR_df_2009_players.remove("Patrick O'Bryant")
#TOR_df_2009_players.remove("Jermaine O'Neal")
#TOR_df_2010_players.remove("Patrick O'Bryant")
TOR_df_2021_players.remove("Gary Trent")

# %%
TOR_2000_gamelog = []


for p in TOR_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2000_gamelog.append(player_log)
TOR_2000_gamelog = pd.concat(TOR_2000_gamelog)    
TOR_2000_gamelogs = TOR_2000_gamelog.copy()
TOR_2000_gamelogs['GAME_SCORE'] = TOR_2000_gamelogs['GAME_SCORE'].astype(float)
TOR_2000_games = TOR_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2000_games_csv = TOR_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2000_games.csv', index=False)
TOR_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2000_games.csv')
TOR_2000_games_proc.head()
# Out:
# You searched for "Muggsy Bogues"
# 1 result found.
# Muggsy Bogues
# Results for Muggsy Bogues:
#
# You searched for "Dee Brown"
# 24 results found.
# 0: Dee Brown
# 1: Dee Brown
# 2: Andre Brown
# 3: Bob Brown
# 4: Devin Brown
# 5: Fred Brown
# 6: Leon Brown
# 7: Mike Brown
# 8: Bruce Brown
# 9: Damone Brown
# 10: George Brown
# 11: John Brown
# 12: Kwame Brown
# 13: Lewis Brown
# 14: Moses Brown
# 15: P.J. Brown
# 16: Roger Brown
# 17: Roger Brown
# 18: Stan Brown
# 19: Tierre Brown
# 20: Tony Brown
# 21: Troy Brown
# 22: Jim Browne
# 23: Dee Gibson
# Pick one: 0
# Results for Dee Brown:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Doug Christie"
# 2 results found.
# 0: Doug Christie
# 1: Doug Kistler
# Pick one: 0
# Results for Doug Christie:
#
# You searched for "Dell Curry"
# 5 results found.
# ...

# %%
# removed Mamadou N'Diaye
TOR_2001_gamelog = []


for p in TOR_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2001_gamelog.append(player_log)
TOR_2001_gamelog = pd.concat(TOR_2001_gamelog)    
TOR_2001_gamelogs = TOR_2001_gamelog.copy()
TOR_2001_gamelogs['GAME_SCORE'] = TOR_2001_gamelogs['GAME_SCORE'].astype(float)
TOR_2001_games = TOR_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2001_games_csv = TOR_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2001_games.csv', index=False)
TOR_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2001_games.csv')
TOR_2001_games_proc.head()
# Out:
# You searched for "Muggsy Bogues"
# 1 result found.
# Muggsy Bogues
# Results for Muggsy Bogues:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Chris Childs"
# 5 results found.
# 0: Chris Childs
# 1: Chris Mills
# 2: Chris Chiozza
# 3: Chris Silva
# 4: Chris Richard
# Pick one: 0
# Results for Chris Childs:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Tyrone Corbin"
# 2 results found.
# 0: Tyrone Corbin
# 1: Tyrone Britt
# Pick one: 0
# Results for Tyrone Corbin:
#
# You searched for "Dell Curry"
# 5 results found.
# 0: Dell Curry
# 1: Seth Curry
# 2: Will Cherry
# 3: Bill Curley
# 4: Eddy Curry
# Pick one: 0
# Results for Dell Curry:
#
# ...

# %%
# removed Mamadou N'Diaye
TOR_2002_gamelog = []


for p in TOR_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2002_gamelog.append(player_log)
TOR_2002_gamelog = pd.concat(TOR_2002_gamelog)    
TOR_2002_gamelogs = TOR_2002_gamelog.copy()
TOR_2002_gamelogs['GAME_SCORE'] = TOR_2002_gamelogs['GAME_SCORE'].astype(float)
TOR_2002_games = TOR_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2002_games_csv = TOR_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2002_games.csv', index=False)
TOR_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2002_games.csv')
TOR_2002_games_proc.head()
# Out:
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Chris Childs"
# 5 results found.
# 0: Chris Childs
# 1: Chris Mills
# 2: Chris Chiozza
# 3: Chris Silva
# 4: Chris Richard
# Pick one: 0
# Results for Chris Childs:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Dell Curry"
# 5 results found.
# ...

# %%
# removed Mamadou N'Diaye
    
TOR_2003_gamelog = []



for p in TOR_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2003_gamelog.append(player_log)
TOR_2003_gamelog = pd.concat(TOR_2003_gamelog)    
TOR_2003_gamelogs = TOR_2003_gamelog.copy()
TOR_2003_gamelogs['GAME_SCORE'] = TOR_2003_gamelogs['GAME_SCORE'].astype(float)
TOR_2003_games = TOR_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2003_games_csv = TOR_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2003_games.csv', index=False)
TOR_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2003_games.csv')
TOR_2003_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Maceo Baston"
# 2 results found.
# 0: Maceo Baston
# 1: Dave Batton
# Pick one: 0
# Results for Maceo Baston:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# 2: Michael Ansley
# 3: Michael Finley
# 4: Michael Frazier
# 5: Michael Wiley
# 6: Michael Bytzura
# Pick one: 0
# Results for Michael Bradley:
#
# You searched for "Damone Brown"
# 14 results found.
# 0: Damone Brown
# 1: Raymond Brown
# 2: Andre Brown
# 3: Dee Brown
# 4: Dee Brown
# 5: Devin Brown
# 6: Harold Brown
# 7: Kwame Brown
# 8: Leon Brown
# 9: Mike Brown
# 10: Moses Brown
# 11: Myron Brown
# 12: Tony Brown
# 13: Damon Jones
# Pick one: 0
# Results for Damone Brown:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# ...

# %%
TOR_2004_gamelog = []



for p in TOR_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2004_gamelog.append(player_log)
TOR_2004_gamelog = pd.concat(TOR_2004_gamelog)    
TOR_2004_gamelogs = TOR_2004_gamelog.copy()
TOR_2004_gamelogs['GAME_SCORE'] = TOR_2004_gamelogs['GAME_SCORE'].astype(float)
TOR_2004_games = TOR_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2004_games_csv = TOR_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2004_games.csv', index=False)
TOR_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2004_games.csv')
TOR_2004_games_proc.head()
# Out:
# You searched for "Robert Archibald"
# 1 result found.
# Robert Archibald
# Results for Robert Archibald:
#
# You searched for "Mengke Bateer"
# 1 result found.
# Mengke Bateer
# Results for Mengke Bateer:
#
# You searched for "Lonny Baxter"
# 3 results found.
# 0: Lonny Baxter
# 1: Sonny Parker
# 2: Kenny Battle
# Pick one: 0
# Results for Lonny Baxter:
#
# You searched for "Corie Blount"
# 2 results found.
# 0: Corie Blount
# 1: Mark Blount
# Pick one: 0
# Results for Corie Blount:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Michael Bradley"
# 7 results found.
# 0: Michael Bradley
# 1: Michael Beasley
# ...

# %%
TOR_2005_gamelog = []



for p in TOR_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2005_gamelog.append(player_log)
TOR_2005_gamelog = pd.concat(TOR_2005_gamelog)    
TOR_2005_gamelogs = TOR_2005_gamelog.copy()
TOR_2005_gamelogs['GAME_SCORE'] = TOR_2005_gamelogs['GAME_SCORE'].astype(float)
TOR_2005_games = TOR_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2005_games_csv = TOR_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2005_games.csv', index=False)
TOR_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2005_games.csv')
TOR_2005_games_proc.head()
# Out:
# You searched for "Rafer Alston"
# 1 result found.
# Rafer Alston
# Results for Rafer Alston:
#
# You searched for "Rafael Araújo"
# 1 result found.
# Rafael Araujo
# Results for Rafael Araujo:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Vince Carter"
# 6 results found.
# 0: Vince Carter
# 1: Vince Hunter
# 2: Butch Carter
# 3: Jake Carter
# 4: Ron Carter
# 5: Vince Taylor
# Pick one: 0
# Results for Vince Carter:
#
# You searched for "Omar Cook"
# ...

# %%
TOR_2006_gamelog = []

for p in TOR_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2006_gamelog.append(player_log)
TOR_2006_gamelog = pd.concat(TOR_2006_gamelog)    
TOR_2006_gamelogs = TOR_2006_gamelog.copy()
TOR_2006_gamelogs['GAME_SCORE'] = TOR_2006_gamelogs['GAME_SCORE'].astype(float)
TOR_2006_games = TOR_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2006_games_csv = TOR_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2006_games.csv', index=False)
TOR_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2006_games.csv')
TOR_2006_games_proc.head()
# Out:
# You searched for "Rafael Araújo"
# 1 result found.
# Rafael Araujo
# Results for Rafael Araujo:
#
# You searched for "Andre Barrett"
# 5 results found.
# 0: Andre Barrett
# 1: Ernie Barrett
# 2: Mike Barrett
# 3: RJ Barrett
# 4: Andre Emmett
# Pick one: 0
# Results for Andre Barrett:
#
# You searched for "Matt Bonner"
# 4 results found.
# 0: Matt Bonner
# 1: Matt Barnes
# 2: Matt Mooney
# 3: Matt Geiger
# Pick one: 0
# Results for Matt Bonner:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Antonio Davis"
# ...

# %%
# removed luke jackson

TOR_2007_gamelog = []

for p in TOR_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2007_gamelog.append(player_log)
TOR_2007_gamelog = pd.concat(TOR_2007_gamelog)    
TOR_2007_gamelogs = TOR_2007_gamelog.copy()
TOR_2007_gamelogs['GAME_SCORE'] = TOR_2007_gamelogs['GAME_SCORE'].astype(float)
TOR_2007_games = TOR_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2007_games_csv = TOR_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2007_games.csv', index=False)
TOR_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2007_games.csv')
TOR_2007_games_proc.head()
# Out:
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "T.J. Ford"
# 7 results found.
# 0: T.J. Ford
# 1: Bob Ford
# 2: Don Ford
# 3: Jake Ford
# 4: Phil Ford
# 5: T.J. Leaf
# 6: O.J. Mayo
# Pick one: 0
# Results for T.J. Ford:
#
# You searched for "Jorge Garbajosa"
# 1 result found.
# Jorge Garbajosa
# Results for Jorge Garbajosa:
#
# ...

# %%
TOR_2008_gamelog = []

for p in TOR_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2008_gamelog.append(player_log)
TOR_2008_gamelog = pd.concat(TOR_2008_gamelog)    
TOR_2008_gamelogs = TOR_2008_gamelog.copy()
TOR_2008_gamelogs['GAME_SCORE'] = TOR_2008_gamelogs['GAME_SCORE'].astype(float)
TOR_2008_games = TOR_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2008_games_csv = TOR_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2008_games.csv', index=False)
TOR_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2008_games.csv')
TOR_2008_games_proc.head()
# Out:
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Maceo Baston"
# 2 results found.
# 0: Maceo Baston
# 1: Dave Batton
# Pick one: 0
# Results for Maceo Baston:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "Primož Brezec"
# 1 result found.
# Primoz Brezec
# Results for Primoz Brezec:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Carlos Delfino"
# 1 result found.
# Carlos Delfino
# Results for Carlos Delfino:
#
# You searched for "Juan Dixon"
# 1 result found.
# ...

# %%
# removed patrick o'bruyant 
TOR_2009_gamelog = []

for p in TOR_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2009_gamelog.append(player_log)
TOR_2009_gamelog = pd.concat(TOR_2009_gamelog)    
TOR_2009_gamelogs = TOR_2009_gamelog.copy()
TOR_2009_gamelogs['GAME_SCORE'] = TOR_2009_gamelogs['GAME_SCORE'].astype(float)
TOR_2009_games = TOR_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2009_games_csv = TOR_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2009_games.csv', index=False)
TOR_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2009_games.csv')
TOR_2009_games_proc.head()
# Out:
# You searched for "Hassan Adams"
# 4 results found.
# 0: Hassan Adams
# 1: Alvan Adams
# 2: Jaylen Adams
# 3: Jordan Adams
# Pick one: 0
# Results for Hassan Adams:
#
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# ...

# %%
TOR_2010_gamelog = []

for p in TOR_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2010_gamelog.append(player_log)
TOR_2010_gamelog = pd.concat(TOR_2010_gamelog)    
TOR_2010_gamelogs = TOR_2010_gamelog.copy()
TOR_2010_gamelogs['GAME_SCORE'] = TOR_2010_gamelogs['GAME_SCORE'].astype(float)
TOR_2010_games = TOR_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2010_games_csv = TOR_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2010_games.csv', index=False)
TOR_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2010_games.csv')
TOR_2010_games_proc.head()
# Out:
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Marco Belinelli"
# 1 result found.
# Marco Belinelli
# Results for Marco Belinelli:
#
# You searched for "Chris Bosh"
# 18 results found.
# 0: Chris Bosh
# 1: Chris Babb
# 2: Chris Ford
# 3: Chris Boucher
# 4: Chris Carr
# 5: Chris Jent
# 6: Chris King
# 7: Chris Mihm
# 8: Chris Munk
# 9: Chris Paul
# 10: Chris Smith
# 11: Chris Smith
# 12: Chris Taft
# 13: Chris Welp
# 14: Chris Duhon
# 15: Chris Mills
# 16: Chris Morris
# 17: Chris Owens
# Pick one: 0
# Results for Chris Bosh:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# ...

# %%
TOR_2011_gamelog = []

for p in TOR_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2011_gamelog.append(player_log)
TOR_2011_gamelog = pd.concat(TOR_2011_gamelog)    
TOR_2011_gamelogs = TOR_2011_gamelog.copy()
TOR_2011_gamelogs['GAME_SCORE'] = TOR_2011_gamelogs['GAME_SCORE'].astype(float)
TOR_2011_games = TOR_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2011_games_csv = TOR_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2011_games.csv', index=False)
TOR_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2011_games.csv')
TOR_2011_games_proc.head()
# Out:
# You searched for "Alexis Ajinça"
# 1 result found.
# Alexis Ajinca
# Results for Alexis Ajinca:
#
# You searched for "Solomon Alabi"
# 2 results found.
# 0: Solomon Alabi
# 1: Solomon Hill
# Pick one: 0
# Results for Solomon Alabi:
#
# You searched for "David Andersen"
# 4 results found.
# 0: David Andersen
# 1: Chris Andersen
# 2: Dan Anderson
# 3: Dan Anderson
# Pick one: 0
# Results for David Andersen:
#
# You searched for "Marcus Banks"
# 6 results found.
# 0: Marcus Banks
# 1: Marcus Brown
# 2: Marcus Camby
# 3: Marcus Landry
# 4: Marcus Paige
# 5: Marcus Smart
# Pick one: 0
# Results for Marcus Banks:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# ...

# %%
TOR_2012_gamelog = []

for p in TOR_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2012_gamelog.append(player_log)
TOR_2012_gamelog = pd.concat(TOR_2012_gamelog)    
TOR_2012_gamelogs = TOR_2012_gamelog.copy()
TOR_2012_gamelogs['GAME_SCORE'] = TOR_2012_gamelogs['GAME_SCORE'].astype(float)
TOR_2012_games = TOR_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2012_games_csv = TOR_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2012_games.csv', index=False)
TOR_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2012_games.csv')
TOR_2012_games_proc.head()
# Out:
# You searched for "Solomon Alabi"
# 2 results found.
# 0: Solomon Alabi
# 1: Solomon Hill
# Pick one: 0
# Results for Solomon Alabi:
#
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Leandro Barbosa"
# 2 results found.
# 0: Leandro Barbosa
# 1: Leandro Bolmaro
# Pick one: 0
# Results for Leandro Barbosa:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "Jerryd Bayless"
# 1 result found.
# Jerryd Bayless
# Results for Jerryd Bayless:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# ...

# %%
TOR_2013_gamelog = []

for p in TOR_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2013_gamelog.append(player_log)
TOR_2013_gamelog = pd.concat(TOR_2013_gamelog)    
TOR_2013_gamelogs = TOR_2013_gamelog.copy()
TOR_2013_gamelogs['GAME_SCORE'] = TOR_2013_gamelogs['GAME_SCORE'].astype(float)
TOR_2013_games = TOR_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2013_games_csv = TOR_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2013_games.csv', index=False)
TOR_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2013_games.csv')
TOR_2013_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Andrea Bargnani"
# 1 result found.
# Andrea Bargnani
# Results for Andrea Bargnani:
#
# You searched for "José Calderón"
# 1 result found.
# Jose Calderon
# Results for Jose Calderon:
#
# You searched for "Ed Davis"
# 34 results found.
# 0: Ed Davis
# 1: Red Davis
# 2: Ben Davis
# 3: Lee Davis
# 4: Mel Davis
# 5: Bob Davis
# 6: Brad Davis
# 7: Glen Davis
# 8: Jim Davis
# 9: Ron Davis
# 10: Ed Kasid
# 11: Ed Rains
# 12: Ed Dahler
# 13: Bob Davies
# ...

# %%
TOR_2014_gamelog = []

for p in TOR_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2014_gamelog.append(player_log)
TOR_2014_gamelog = pd.concat(TOR_2014_gamelog)    
TOR_2014_gamelogs = TOR_2014_gamelog.copy()
TOR_2014_gamelogs['GAME_SCORE'] = TOR_2014_gamelogs['GAME_SCORE'].astype(float)
TOR_2014_games = TOR_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2014_games_csv = TOR_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2014_games.csv', index=False)
TOR_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2014_games.csv')
TOR_2014_games_proc.head()
# Out:
# You searched for "Quincy Acy"
# 2 results found.
# 0: Quincy Acy
# 1: Quincy Douby
# Pick one: 0
# Results for Quincy Acy:
#
# You searched for "D.J. Augustin"
# 1 result found.
# D.J. Augustin
# Results for D.J. Augustin:
#
# You searched for "Dwight Buycks"
# 1 result found.
# Dwight Buycks
# Results for Dwight Buycks:
#
# You searched for "Austin Daye"
# 4 results found.
# 0: Austin Daye
# 1: Austin Carr
# 2: Justin James
# 3: Justin Reed
# Pick one: 0
# Results for Austin Daye:
#
# You searched for "Nando De Colo"
# 1 result found.
# Nando De Colo
# Results for Nando De Colo:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Landry Fields"
# 2 results found.
# 0: Landry Fields
# 1: Kenny Fields
# Pick one: 0
# Results for Landry Fields:
#
# You searched for "Rudy Gay"
# 4 results found.
# 0: Rudy Gay
# 1: Todd Day
# 2: Ed Gray
# 3: Gary Gray
# Pick one: 0
# Results for Rudy Gay:
#
# ...

# %%
TOR_2015_gamelog = []

for p in TOR_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2015_gamelog.append(player_log)
TOR_2015_gamelog = pd.concat(TOR_2015_gamelog)    
TOR_2015_gamelogs = TOR_2015_gamelog.copy()
TOR_2015_gamelogs['GAME_SCORE'] = TOR_2015_gamelogs['GAME_SCORE'].astype(float)
TOR_2015_games = TOR_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2015_games_csv = TOR_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2015_games.csv', index=False)
TOR_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2015_games.csv')
TOR_2015_games_proc.head()
# Out:
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Landry Fields"
# 2 results found.
# 0: Landry Fields
# 1: Kenny Fields
# Pick one: 0
# Results for Landry Fields:
#
# You searched for "Tyler Hansbrough"
# 2 results found.
# 0: Tyler Hansbrough
# 1: Ben Hansbrough
# Pick one: 0
# Results for Tyler Hansbrough:
#
# You searched for "Chuck Hayes"
# 5 results found.
# 0: Chuck Hayes
# 1: Chuck Share
# 2: Chuck Lloyd
# 3: Chuck Noble
# 4: Chuck Terry
# Pick one: 0
# Results for Chuck Hayes:
#
# You searched for "Amir Johnson"
# 43 results found.
# 0: Amir Johnson
# 1: Alize Johnson
# 2: Andy Johnson
# 3: Armon Johnson
# 4: Arnie Johnson
# 5: Avery Johnson
# 6: Eric Johnson
# 7: James Johnson
# 8: Magic Johnson
# 9: Neil Johnson
# 10: Omari Johnson
# 11: B.J. Johnson
# 12: Brice Johnson
# 13: Buck Johnson
# ...

# %%
TOR_2016_gamelog = []

for p in TOR_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2016_gamelog.append(player_log)
TOR_2016_gamelog = pd.concat(TOR_2016_gamelog)    
TOR_2016_gamelogs = TOR_2016_gamelog.copy()
TOR_2016_gamelogs['GAME_SCORE'] = TOR_2016_gamelogs['GAME_SCORE'].astype(float)
TOR_2016_games = TOR_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2016_games_csv = TOR_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2016_games.csv', index=False)
TOR_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2016_games.csv')
TOR_2016_games_proc.head()
# Out:
# You searched for "Anthony Bennett"
# 3 results found.
# 0: Anthony Bennett
# 1: Tony Bennett
# 2: Anthony Bonner
# Pick one: 0
# Results for Anthony Bennett:
#
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "James Johnson"
# 32 results found.
# 0: James Johnson
# 1: Amir Johnson
# 2: Dave Johnson
# 3: Joe Johnson
# 4: James Robinson
# 5: James Cotton
# 6: Andy Johnson
# 7: Armon Johnson
# 8: Avery Johnson
# 9: Cameron Johnson
# 10: Charles Johnson
# 11: Cheese Johnson
# 12: Chris Johnson
# 13: Chris Johnson
# 14: Ed Johnson
# 15: Gus Johnson
# 16: JaJuan Johnson
# 17: John Johnson
# 18: Ken Johnson
# ...

# %%
TOR_2017_gamelog = []

for p in TOR_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2017_gamelog.append(player_log)
TOR_2017_gamelog = pd.concat(TOR_2017_gamelog)    
TOR_2017_gamelogs = TOR_2017_gamelog.copy()
TOR_2017_gamelogs['GAME_SCORE'] = TOR_2017_gamelogs['GAME_SCORE'].astype(float)
TOR_2017_games = TOR_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2017_games_csv = TOR_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2017_games.csv', index=False)
TOR_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2017_games.csv')
TOR_2017_games_proc.head()
# Out:
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Serge Ibaka"
# 1 result found.
# Serge Ibaka
# Results for Serge Ibaka:
#
# You searched for "Cory Joseph"
# 4 results found.
# 0: Cory Joseph
# 1: Garth Joseph
# 2: Kris Joseph
# 3: Yvon Joseph
# Pick one: 0
# Results for Cory Joseph:
#
# You searched for "Kyle Lowry"
# 4 results found.
# 0: Kyle Lowry
# 1: Kyle Guy
# 2: Kyle Macy
# 3: Kyle Korver
# Pick one: 0
# Results for Kyle Lowry:
#
# You searched for "Lucas Nogueira"
# 1 result found.
# Lucas Nogueira
# Results for Lucas Nogueira:
#
# You searched for "Patrick Patterson"
# 1 result found.
# Patrick Patterson
# Results for Patrick Patterson:
#
# You searched for "Jakob Poeltl"
# 1 result found.
# ...

# %%
TOR_2018_gamelog = []

for p in TOR_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2018_gamelog.append(player_log)
TOR_2018_gamelog = pd.concat(TOR_2018_gamelog)    
TOR_2018_gamelogs = TOR_2018_gamelog.copy()
TOR_2018_gamelogs['GAME_SCORE'] = TOR_2018_gamelogs['GAME_SCORE'].astype(float)
TOR_2018_games = TOR_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2018_games_csv = TOR_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2018_games.csv', index=False)
TOR_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2018_games.csv')
TOR_2018_games_proc.head()
# Out:
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Lorenzo Brown"
# 2 results found.
# 0: Lorenzo Brown
# 1: Lorenzo Romar
# Pick one: 0
# Results for Lorenzo Brown:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Nigel Hayes"
# 2 results found.
# 0: Nigel Hayes
# 1: Jim Hayes
# Pick one: 0
# Results for Nigel Hayes:
#
# You searched for "Serge Ibaka"
# 1 result found.
# Serge Ibaka
# Results for Serge Ibaka:
#
# You searched for "Kyle Lowry"
# 4 results found.
# 0: Kyle Lowry
# 1: Kyle Guy
# 2: Kyle Macy
# 3: Kyle Korver
# Pick one: 0
# Results for Kyle Lowry:
#
# You searched for "Alfonzo McKinnie"
# 1 result found.
# Alfonzo McKinnie
# Results for Alfonzo McKinnie:
#
# You searched for "C.J. Miles"
# 7 results found.
# 0: C.J. Miles
# 1: C.J. Kupec
# ...

# %%
TOR_2019_gamelog = []

for p in TOR_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2019_gamelog.append(player_log)
TOR_2019_gamelog = pd.concat(TOR_2019_gamelog)    
TOR_2019_gamelogs = TOR_2019_gamelog.copy()
TOR_2019_gamelogs['GAME_SCORE'] = TOR_2019_gamelogs['GAME_SCORE'].astype(float)
TOR_2019_games = TOR_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2019_games_csv = TOR_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2019_games.csv', index=False)
TOR_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2019_games.csv')
TOR_2019_games_proc.head()
# Out:
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Chris Boucher"
# 5 results found.
# 0: Chris Boucher
# 1: Chris Bosh
# 2: Chris Hunter
# 3: Chris Porter
# 4: Chris Herren
# Pick one: 0
# Results for Chris Boucher:
#
# You searched for "Lorenzo Brown"
# 2 results found.
# 0: Lorenzo Brown
# 1: Lorenzo Romar
# Pick one: 0
# Results for Lorenzo Brown:
#
# You searched for "Marc Gasol"
# 7 results found.
# 0: Marc Gasol
# 1: Pau Gasol
# 2: Mark Eaton
# 3: Marc Jackson
# 4: Mark Macon
# 5: Mark Davis
# 6: Mark Davis
# Pick one: 0
# Results for Marc Gasol:
#
# You searched for "Danny Green"
# 20 results found.
# 0: Danny Green
# 1: Kenny Green
# 2: Johnny Green
# 3: Danny Finn
# 4: Danny Granger
# 5: A.C. Green
# 6: Devin Green
# 7: Ken Green
# 8: Lamar Green
# 9: Sean Green
# 10: Sidney Green
# 11: Donte Greene
# 12: Lynn Greer
# 13: Danny Vranes
# 14: Danny Ainge
# 15: Danny Doyle
# 16: Danny Ferry
# 17: Dennis Grey
# ...

# %%
TOR_2020_gamelog = []

for p in TOR_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2020_gamelog.append(player_log)
TOR_2020_gamelog = pd.concat(TOR_2020_gamelog)    
TOR_2020_gamelogs = TOR_2020_gamelog.copy()
TOR_2020_gamelogs['GAME_SCORE'] = TOR_2020_gamelogs['GAME_SCORE'].astype(float)
TOR_2020_games = TOR_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2020_games_csv = TOR_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2020_games.csv', index=False)
TOR_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2020_games.csv')
TOR_2020_games_proc.head()
# Out:
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Chris Boucher"
# 5 results found.
# 0: Chris Boucher
# 1: Chris Bosh
# 2: Chris Hunter
# 3: Chris Porter
# 4: Chris Herren
# Pick one: 0
# Results for Chris Boucher:
#
# You searched for "Oshae Brissett"
# 1 result found.
# Oshae Brissett
# Results for Oshae Brissett:
#
# You searched for "Terence Davis"
# 3 results found.
# 0: Terence Davis
# 1: Terry Davis
# 2: Terence Morris
# Pick one: 0
# Results for Terence Davis:
#
# You searched for "Marc Gasol"
# 7 results found.
# 0: Marc Gasol
# 1: Pau Gasol
# 2: Mark Eaton
# 3: Marc Jackson
# 4: Mark Macon
# 5: Mark Davis
# 6: Mark Davis
# Pick one: 0
# Results for Marc Gasol:
#
# You searched for "Dewan Hernandez"
# 1 result found.
# Dewan Hernandez
# Results for Dewan Hernandez:
#
# You searched for "Rondae Hollis-Jefferson"
# 1 result found.
# Rondae Hollis-Jefferson
# Results for Rondae Hollis-Jefferson:
#
# ...

# %%
TOR_2021_gamelog = []

for p in TOR_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    TOR_2021_gamelog.append(player_log)
TOR_2021_gamelog = pd.concat(TOR_2021_gamelog)    
TOR_2021_gamelogs = TOR_2021_gamelog.copy()
TOR_2021_gamelogs['GAME_SCORE'] = TOR_2021_gamelogs['GAME_SCORE'].astype(float)
TOR_2021_games = TOR_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_2021_games_csv = TOR_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2021_games.csv', index=False)
TOR_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2021_games.csv')
TOR_2021_games_proc.head()
# Out:
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Aron Baynes"
# 8 results found.
# 0: Aron Baynes
# 1: Ron Baker
# 2: Harry Barnes
# 3: Marvin Barnes
# 4: Ron Boone
# 5: Aaron James
# 6: Tharon Mayes
# 7: Cameron Payne
# Pick one: 0
# Results for Aron Baynes:
#
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "Khem Birch"
# 1 result found.
# Khem Birch
# Results for Khem Birch:
#
# You searched for "Chris Boucher"
# 5 results found.
# 0: Chris Boucher
# 1: Chris Bosh
# 2: Chris Hunter
# 3: Chris Porter
# 4: Chris Herren
# Pick one: 0
# Results for Chris Boucher:
#
# You searched for "Terence Davis"
# 3 results found.
# 0: Terence Davis
# 1: Terry Davis
# 2: Terence Morris
# Pick one: 0
# Results for Terence Davis:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
TOR_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2000_games.csv')
TOR_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2001_games.csv')
TOR_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2002_games.csv')
TOR_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2003_games.csv')
TOR_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2004_games.csv')
TOR_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2005_games.csv')
TOR_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2006_games.csv')
TOR_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2007_games.csv')
TOR_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2008_games.csv')
TOR_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2009_games.csv')
TOR_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2010_games.csv')
TOR_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2011_games.csv')
TOR_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2012_games.csv')
TOR_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2013_games.csv')
TOR_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2014_games.csv')
TOR_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2015_games.csv')
TOR_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2016_games.csv')
TOR_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2017_games.csv')
TOR_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2018_games.csv')
TOR_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2019_games.csv')
TOR_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2020_games.csv')
TOR_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/TOR/TOR_2021_games.csv')

# %%
TOR_season_dfs = [TOR_2000_games_io, TOR_2001_games_io, TOR_2002_games_io, TOR_2003_games_io, TOR_2004_games_io, TOR_2005_games_io,
                 TOR_2006_games_io, TOR_2007_games_io, TOR_2008_games_io, TOR_2009_games_io, TOR_2010_games_io, TOR_2011_games_io,
                 TOR_2012_games_io, TOR_2013_games_io, TOR_2014_games_io, TOR_2015_games_io, TOR_2016_games_io, TOR_2017_games_io,
                 TOR_2018_games_io, TOR_2019_games_io, TOR_2020_games_io, TOR_2021_games_io]

# %%
TOR_all = pd.concat(TOR_season_dfs)
TOR_all_sorted = TOR_all.sort_values(by=['GAME_SCORE'], ascending=False)
TOR_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2021-02-02  26-343  TOR      AWAY      ORL  W (+15)   1  37:06  17   23
# 0  2018-01-01  28-147  TOR      HOME      MIL   W (+4)   1  43:27  17   29
# 0  2016-02-26  29-338  TOR      HOME      CLE   W (+2)   1  42:49  15   20
# 0  2008-11-18  24-239  TOR      AWAY      ORL  L (-13)   1  44:46  14   19
# 0  2000-11-18  23-297  TOR      HOME      MIL   W (+9)   1  44:43  14   31
# 0  2008-02-20  23-333  TOR      HOME      ORL  W (+17)   1  38:54  14   16
# 0  2004-03-21  27-055  TOR      AWAY      NOH   W (+1)   1  46:36  13   20
# 1  2017-12-21  28-136  TOR      AWAY      PHI   W (+5)   1  39:28  13   21
# 0  2010-04-04  26-011  TOR      HOME      GSW   L (-1)   1  41:18  11   19
# 0  2014-01-25  22-354  TOR      HOME      LAC   L (-8)   1  43:53  16   29
# 1  2010-01-20  25-302  TOR      AWAY      MIL   L (-6)   1  42:42  15   26
# ...
