# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_UTA = []

# UTA
while season <= 2021:
    df_UTA = get_roster('UTA', season)
    df_UTA['Season'] = season
    df_UTA['Team'] = 'UTA'
    appended_data_UTA.append(df_UTA)
    season = season + 1
appended_data_UTA = pd.concat(appended_data_UTA)

# %%
UTA_df_all = appended_data_UTA.copy()
UTA_df_all_csv = UTA_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_players_all.csv', index=False)
UTA_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_players_all.csv')
UTA_df_all_csv_io.head()
# Out:
#   NUMBER         PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY EXPERIENCE  \
# 0     23  Pete Chilcutt  PF   6-10     230  1968-09-14          US          8
# 1     10  Howard Eisley  PG    6-2     177  1972-12-04          US          5
# 2      5  Armen Gilliam  PF    6-9     230  1964-05-28          US         12
# 3     14  Jeff Hornacek  SG    6-3     190  1963-05-03          US         13
# 4     31     Adam Keefe   C    6-9     230  1970-02-22          US          7
#
#           COLLEGE  Season Team
# 0             UNC    2000  UTA
# 1  Boston College    2000  UTA
# 2            UNLV    2000  UTA
# 3      Iowa State    2000  UTA
# 4        Stanford    2000  UTA

# %%
UTA_df_2000 = UTA_df_all[UTA_df_all['Season'] == 2000]
UTA_df_2001 = UTA_df_all[UTA_df_all['Season'] == 2001]
UTA_df_2002 = UTA_df_all[UTA_df_all['Season'] == 2002]
UTA_df_2003 = UTA_df_all[UTA_df_all['Season'] == 2003]
UTA_df_2004 = UTA_df_all[UTA_df_all['Season'] == 2004]
UTA_df_2005 = UTA_df_all[UTA_df_all['Season'] == 2005]
UTA_df_2006 = UTA_df_all[UTA_df_all['Season'] == 2006]
UTA_df_2007 = UTA_df_all[UTA_df_all['Season'] == 2007]
UTA_df_2008 = UTA_df_all[UTA_df_all['Season'] == 2008]
UTA_df_2009 = UTA_df_all[UTA_df_all['Season'] == 2009]
UTA_df_2010 = UTA_df_all[UTA_df_all['Season'] == 2010]
UTA_df_2011 = UTA_df_all[UTA_df_all['Season'] == 2011]
UTA_df_2012 = UTA_df_all[UTA_df_all['Season'] == 2012]
UTA_df_2013 = UTA_df_all[UTA_df_all['Season'] == 2013]
UTA_df_2014 = UTA_df_all[UTA_df_all['Season'] == 2014]
UTA_df_2015 = UTA_df_all[UTA_df_all['Season'] == 2015]
UTA_df_2016 = UTA_df_all[UTA_df_all['Season'] == 2016]
UTA_df_2017 = UTA_df_all[UTA_df_all['Season'] == 2017]
UTA_df_2018 = UTA_df_all[UTA_df_all['Season'] == 2018]
UTA_df_2019 = UTA_df_all[UTA_df_all['Season'] == 2019]
UTA_df_2020 = UTA_df_all[UTA_df_all['Season'] == 2020]
UTA_df_2021 = UTA_df_all[UTA_df_all['Season'] == 2021]

# %%
# changing names
#UTA_df_2002.loc[UTA_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#UTA_df_2004.loc[UTA_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
UTA_df_2000_players = UTA_df_2000['PLAYER'].to_list()
UTA_df_2001_players = UTA_df_2001['PLAYER'].to_list()
UTA_df_2002_players = UTA_df_2002['PLAYER'].to_list()
UTA_df_2003_players = UTA_df_2003['PLAYER'].to_list()
UTA_df_2004_players = UTA_df_2004['PLAYER'].to_list()
UTA_df_2005_players = UTA_df_2005['PLAYER'].to_list()

UTA_df_2006_players = UTA_df_2006['PLAYER'].to_list()
UTA_df_2007_players = UTA_df_2007['PLAYER'].to_list()
UTA_df_2008_players = UTA_df_2008['PLAYER'].to_list()
UTA_df_2009_players = UTA_df_2009['PLAYER'].to_list()
UTA_df_2010_players = UTA_df_2010['PLAYER'].to_list()
UTA_df_2011_players = UTA_df_2011['PLAYER'].to_list()

UTA_df_2012_players = UTA_df_2012['PLAYER'].to_list()
UTA_df_2013_players = UTA_df_2013['PLAYER'].to_list()
UTA_df_2014_players = UTA_df_2014['PLAYER'].to_list()
UTA_df_2015_players = UTA_df_2015['PLAYER'].to_list()
UTA_df_2016_players = UTA_df_2016['PLAYER'].to_list()
UTA_df_2017_players = UTA_df_2017['PLAYER'].to_list()

UTA_df_2018_players = UTA_df_2018['PLAYER'].to_list()
UTA_df_2019_players = UTA_df_2019['PLAYER'].to_list()
UTA_df_2020_players = UTA_df_2020['PLAYER'].to_list()
UTA_df_2021_players = UTA_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#UTA_df_2001_players.remove("Mamadou N'Diaye")
#UTA_df_2004_players.remove("Sasha Pavlović")
#UTA_df_2004_players.remove("Mo Williams")
#UTA_df_2007_players.remove("Dee Brown")
#UTA_df_2013_players.remove("Mo Williams")
#UTA_df_2015_players.remove("Chris Johnson")
#UTA_df_2016_players.remove("Chris Johnson")
#UTA_df_2016_players.remove("J.J. O'Brien")
#UTA_df_2018_players.remove("Royce O'Neale")
#UTA_df_2019_players.remove("Royce O'Neale")
#UTA_df_2020_players.remove("Royce O'Neale")
UTA_df_2021_players.remove("Royce O'Neale")

# %%
UTA_2000_gamelog = []


for p in UTA_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2000_gamelog.append(player_log)
UTA_2000_gamelog = pd.concat(UTA_2000_gamelog)    
UTA_2000_gamelogs = UTA_2000_gamelog.copy()
UTA_2000_gamelogs['GAME_SCORE'] = UTA_2000_gamelogs['GAME_SCORE'].astype(float)
UTA_2000_games = UTA_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2000_games_csv = UTA_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2000_games.csv', index=False)
UTA_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2000_games.csv')
UTA_2000_games_proc.head()
# Out:
# You searched for "Pete Chilcutt"
# 1 result found.
# Pete Chilcutt
# Results for Pete Chilcutt:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Armen Gilliam"
# 5 results found.
# 0: Armen Gilliam
# 1: Herm Gilliam
# 2: Darren Tillis
# 3: Art Williams
# 4: Ron Williams
# Pick one: 0
# Results for Armen Gilliam:
#
# You searched for "Jeff Hornacek"
# 1 result found.
# Jeff Hornacek
# Results for Jeff Hornacek:
#
# You searched for "Adam Keefe"
# 1 result found.
# Adam Keefe
# Results for Adam Keefe:
#
# You searched for "Quincy Lewis"
# 2 results found.
# 0: Quincy Lewis
# 1: Quincy Miller
# Pick one: 0
# Results for Quincy Lewis:
#
# You searched for "Karl Malone"
# 9 results found.
# 0: Karl Malone
# 1: Karim Mane
# 2: Daryl Macon
# 3: Mark Macon
# 4: Jeff Malone
# 5: Matt Maloney
# 6: Earl Barron
# 7: Earl Jones
# 8: Earl Watson
# Pick one: 0
# Results for Karl Malone:
#
# You searched for "Greg Ostertag"
# ...

# %%
# removed Mamadou N'Diaye
UTA_2001_gamelog = []


for p in UTA_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2001_gamelog.append(player_log)
UTA_2001_gamelog = pd.concat(UTA_2001_gamelog)    
UTA_2001_gamelogs = UTA_2001_gamelog.copy()
UTA_2001_gamelogs['GAME_SCORE'] = UTA_2001_gamelogs['GAME_SCORE'].astype(float)
UTA_2001_games = UTA_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2001_games_csv = UTA_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2001_games.csv', index=False)
UTA_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2001_games.csv')
UTA_2001_games_proc.head()
# Out:
# You searched for "David Benoit"
# 3 results found.
# 0: David Benoit
# 1: David Noel
# 2: David West
# Pick one: 0
# Results for David Benoit:
#
# You searched for "John Crotty"
# 8 results found.
# 0: John Crotty
# 1: John Brown
# 2: John Chaney
# 3: John Coker
# 4: John Roche
# 5: John Morton
# 6: John Stroud
# 7: Johan Petro
# Pick one: 0
# Results for John Crotty:
#
# You searched for "Quincy Lewis"
# 2 results found.
# 0: Quincy Lewis
# 1: Quincy Miller
# Pick one: 0
# Results for Quincy Lewis:
#
# You searched for "Karl Malone"
# 9 results found.
# 0: Karl Malone
# 1: Karim Mane
# 2: Daryl Macon
# 3: Mark Macon
# 4: Jeff Malone
# 5: Matt Maloney
# 6: Earl Barron
# 7: Earl Jones
# 8: Earl Watson
# Pick one: 0
# Results for Karl Malone:
#
# You searched for "Danny Manning"
# 3 results found.
# 0: Danny Manning
# 1: Danny Ainge
# 2: Guy Manning
# Pick one: 0
# Results for Danny Manning:
#
# You searched for "Donyell Marshall"
# 3 results found.
# 0: Donyell Marshall
# ...

# %%
# removed Mamadou N'Diaye
UTA_2002_gamelog = []


for p in UTA_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2002_gamelog.append(player_log)
UTA_2002_gamelog = pd.concat(UTA_2002_gamelog)    
UTA_2002_gamelogs = UTA_2002_gamelog.copy()
UTA_2002_gamelogs['GAME_SCORE'] = UTA_2002_gamelogs['GAME_SCORE'].astype(float)
UTA_2002_games = UTA_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2002_games_csv = UTA_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2002_games.csv', index=False)
UTA_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2002_games.csv')
UTA_2002_games_proc.head()
# Out:
# You searched for "John Amaechi"
# 6 results found.
# 0: John Amaechi
# 1: John Janisch
# 2: John Lambert
# 3: John Mandic
# 4: John Wallace
# 5: John Shumate
# Pick one: 0
# Results for John Amaechi:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "John Crotty"
# 8 results found.
# 0: John Crotty
# 1: John Brown
# 2: John Chaney
# 3: John Coker
# 4: John Roche
# 5: John Morton
# 6: John Stroud
# 7: Johan Petro
# Pick one: 0
# Results for John Crotty:
#
# You searched for "Andrei Kirilenko"
# 1 result found.
# Andrei Kirilenko
# Results for Andrei Kirilenko:
#
# You searched for "Rusty LaRue"
# 1 result found.
# Rusty LaRue
# Results for Rusty LaRue:
#
# You searched for "Quincy Lewis"
# 2 results found.
# 0: Quincy Lewis
# ...

# %%
# removed Mamadou N'Diaye
    
UTA_2003_gamelog = []



for p in UTA_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2003_gamelog.append(player_log)
UTA_2003_gamelog = pd.concat(UTA_2003_gamelog)    
UTA_2003_gamelogs = UTA_2003_gamelog.copy()
UTA_2003_gamelogs['GAME_SCORE'] = UTA_2003_gamelogs['GAME_SCORE'].astype(float)
UTA_2003_games = UTA_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2003_games_csv = UTA_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2003_games.csv', index=False)
UTA_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2003_games.csv')
UTA_2003_games_proc.head()
# Out:
# You searched for "John Amaechi"
# 6 results found.
# 0: John Amaechi
# 1: John Janisch
# 2: John Lambert
# 3: John Mandic
# 4: John Wallace
# 5: John Shumate
# Pick one: 0
# Results for John Amaechi:
#
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Calbert Cheaney"
# 1 result found.
# Calbert Cheaney
# Results for Calbert Cheaney:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Matt Harpring"
# 1 result found.
# Matt Harpring
# Results for Matt Harpring:
#
# You searched for "Mark Jackson"
# 25 results found.
# 0: Mark Jackson
# 1: Marc Jackson
# 2: Aaron Jackson
# 3: Al Jackson
# 4: Frank Jackson
# ...

# %%
UTA_2004_gamelog = []



for p in UTA_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2004_gamelog.append(player_log)
UTA_2004_gamelog = pd.concat(UTA_2004_gamelog)    
UTA_2004_gamelogs = UTA_2004_gamelog.copy()
UTA_2004_gamelogs['GAME_SCORE'] = UTA_2004_gamelogs['GAME_SCORE'].astype(float)
UTA_2004_games = UTA_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2004_games_csv = UTA_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2004_games.csv', index=False)
UTA_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2004_games.csv')
UTA_2004_games_proc.head()
# Out:
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Curtis Borchardt"
# 1 result found.
# Curtis Borchardt
# Results for Curtis Borchardt:
#
# You searched for "Keon Clark"
# 5 results found.
# 0: Keon Clark
# 1: Ian Clark
# 2: Kenny Carr
# 3: Earl Clark
# 4: Gary Clark
# Pick one: 0
# Results for Keon Clark:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Paul Grant"
# 20 results found.
# ...

# %%
UTA_2005_gamelog = []



for p in UTA_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2005_gamelog.append(player_log)
UTA_2005_gamelog = pd.concat(UTA_2005_gamelog)    
UTA_2005_gamelogs = UTA_2005_gamelog.copy()
UTA_2005_gamelogs['GAME_SCORE'] = UTA_2005_gamelogs['GAME_SCORE'].astype(float)
UTA_2005_games = UTA_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2005_games_csv = UTA_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2005_games.csv', index=False)
UTA_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2005_games.csv')
UTA_2005_games_proc.head()
# Out:
# You searched for "Carlos Arroyo"
# 2 results found.
# 0: Carlos Arroyo
# 1: Carlos Terry
# Pick one: 0
# Results for Carlos Arroyo:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Curtis Borchardt"
# 1 result found.
# Curtis Borchardt
# Results for Curtis Borchardt:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Howard Eisley"
# 1 result found.
# Howard Eisley
# Results for Howard Eisley:
#
# You searched for "Gordan Giriček"
# ...

# %%
UTA_2006_gamelog = []

for p in UTA_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2006_gamelog.append(player_log)
UTA_2006_gamelog = pd.concat(UTA_2006_gamelog)    
UTA_2006_gamelogs = UTA_2006_gamelog.copy()
UTA_2006_gamelogs['GAME_SCORE'] = UTA_2006_gamelogs['GAME_SCORE'].astype(float)
UTA_2006_games = UTA_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2006_games_csv = UTA_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2006_games.csv', index=False)
UTA_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2006_games.csv')
UTA_2006_games_proc.head()
# Out:
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Devin Brown"
# 15 results found.
# 0: Devin Brown
# 1: Dee Brown
# 2: Dee Brown
# 3: Leon Brown
# 4: Lewis Brown
# 5: Devin Green
# 6: Devin Booker
# 7: Kevin Brooks
# 8: Damone Brown
# 9: Derrick Brown
# 10: John Brown
# 11: Myron Brown
# 12: Stan Brown
# 13: Devin Gray
# 14: Jim Browne
# Pick one: 0
# Results for Devin Brown:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Matt Harpring"
# 1 result found.
# ...

# %%
# removed dee brown

UTA_2007_gamelog = []

for p in UTA_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2007_gamelog.append(player_log)
UTA_2007_gamelog = pd.concat(UTA_2007_gamelog)    
UTA_2007_gamelogs = UTA_2007_gamelog.copy()
UTA_2007_gamelogs['GAME_SCORE'] = UTA_2007_gamelogs['GAME_SCORE'].astype(float)
UTA_2007_games = UTA_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2007_games_csv = UTA_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2007_games.csv', index=False)
UTA_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2007_games.csv')
UTA_2007_games_proc.head()
# Out:
# You searched for "Lou Amundson"
# 2 results found.
# 0: Lou Amundson
# 1: Lou Hudson
# Pick one: 0
# Results for Lou Amundson:
#
# You searched for "Rafael Araújo"
# 1 result found.
# Rafael Araujo
# Results for Rafael Araujo:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Derek Fisher"
# 2 results found.
# 0: Derek Fisher
# 1: Derek Harper
# Pick one: 0
# ...

# %%
UTA_2008_gamelog = []

for p in UTA_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2008_gamelog.append(player_log)
UTA_2008_gamelog = pd.concat(UTA_2008_gamelog)    
UTA_2008_gamelogs = UTA_2008_gamelog.copy()
UTA_2008_gamelogs['GAME_SCORE'] = UTA_2008_gamelogs['GAME_SCORE'].astype(float)
UTA_2008_games = UTA_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2008_games_csv = UTA_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2008_games.csv', index=False)
UTA_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2008_games.csv')
UTA_2008_games_proc.head()
# Out:
# You searched for "Morris Almond"
# 1 result found.
# Morris Almond
# Results for Morris Almond:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Kyrylo Fesenko"
# 1 result found.
# Kyrylo Fesenko
# Results for Kyrylo Fesenko:
#
# You searched for "Gordan Giriček"
# 1 result found.
# Gordan Giricek
# Results for Gordan Giricek:
#
# You searched for "Matt Harpring"
# ...

# %%
# removed patrick o'bruyant 
UTA_2009_gamelog = []

for p in UTA_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2009_gamelog.append(player_log)
UTA_2009_gamelog = pd.concat(UTA_2009_gamelog)    
UTA_2009_gamelogs = UTA_2009_gamelog.copy()
UTA_2009_gamelogs['GAME_SCORE'] = UTA_2009_gamelogs['GAME_SCORE'].astype(float)
UTA_2009_games = UTA_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2009_games_csv = UTA_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2009_games.csv', index=False)
UTA_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2009_games.csv')
UTA_2009_games_proc.head()
# Out:
# You searched for "Morris Almond"
# 1 result found.
# Morris Almond
# Results for Morris Almond:
#
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Jarron Collins"
# 10 results found.
# 0: Jarron Collins
# 1: Jason Collins
# 2: Sherron Collins
# 3: Jason Collier
# 4: Art Collins
# 5: Don Collins
# 6: James Collins
# 7: John Collins
# 8: Mardy Collins
# 9: Darren Collison
# Pick one: 0
# Results for Jarron Collins:
#
# You searched for "Kyrylo Fesenko"
# 1 result found.
# Kyrylo Fesenko
# Results for Kyrylo Fesenko:
#
# You searched for "Matt Harpring"
# 1 result found.
# Matt Harpring
# Results for Matt Harpring:
#
# You searched for "Andrei Kirilenko"
# ...

# %%
UTA_2010_gamelog = []

for p in UTA_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2010_gamelog.append(player_log)
UTA_2010_gamelog = pd.concat(UTA_2010_gamelog)    
UTA_2010_gamelogs = UTA_2010_gamelog.copy()
UTA_2010_gamelogs['GAME_SCORE'] = UTA_2010_gamelogs['GAME_SCORE'].astype(float)
UTA_2010_games = UTA_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2010_games_csv = UTA_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2010_games.csv', index=False)
UTA_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2010_games.csv')
UTA_2010_games_proc.head()
# Out:
# You searched for "Carlos Boozer"
# 5 results found.
# 0: Carlos Boozer
# 1: Carlos Rogers
# 2: Charles Cooke
# 3: Carlos Arroyo
# 4: Carlos Terry
# Pick one: 0
# Results for Carlos Boozer:
#
# You searched for "Ronnie Brewer"
# 4 results found.
# 0: Ronnie Brewer
# 1: Ron Brewer
# 2: Ronnie Lester
# 3: Ronnie Price
# Pick one: 0
# Results for Ronnie Brewer:
#
# You searched for "Kyrylo Fesenko"
# 1 result found.
# Kyrylo Fesenko
# Results for Kyrylo Fesenko:
#
# You searched for "Sundiata Gaines"
# 1 result found.
# Sundiata Gaines
# Results for Sundiata Gaines:
#
# You searched for "Othyus Jeffers"
# 1 result found.
# Othyus Jeffers
# Results for Othyus Jeffers:
#
# You searched for "Andrei Kirilenko"
# 1 result found.
# Andrei Kirilenko
# Results for Andrei Kirilenko:
#
# You searched for "Kyle Korver"
# 3 results found.
# 0: Kyle Korver
# 1: Kyle Weaver
# 2: Kyle Lowry
# Pick one: 0
# Results for Kyle Korver:
#
# You searched for "Kosta Koufos"
# 1 result found.
# Kosta Koufos
# ...

# %%
UTA_2011_gamelog = []

for p in UTA_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2011_gamelog.append(player_log)
UTA_2011_gamelog = pd.concat(UTA_2011_gamelog)    
UTA_2011_gamelogs = UTA_2011_gamelog.copy()
UTA_2011_gamelogs['GAME_SCORE'] = UTA_2011_gamelogs['GAME_SCORE'].astype(float)
UTA_2011_games = UTA_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2011_games_csv = UTA_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2011_games.csv', index=False)
UTA_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2011_games.csv')
UTA_2011_games_proc.head()
# Out:
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Marcus Cousin"
# 3 results found.
# 0: Marcus Cousin
# 1: DeMarcus Cousins
# 2: Marcus Morris
# Pick one: 0
# Results for Marcus Cousin:
#
# You searched for "Francisco Elson"
# 1 result found.
# Francisco Elson
# Results for Francisco Elson:
#
# You searched for "Jeremy Evans"
# 5 results found.
# 0: Jeremy Evans
# 1: Tyreke Evans
# 2: Jeremy Lamb
# 3: Jeremy Lin
# 4: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Evans:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Kyrylo Fesenko"
# 1 result found.
# Kyrylo Fesenko
# Results for Kyrylo Fesenko:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# ...

# %%
UTA_2012_gamelog = []

for p in UTA_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2012_gamelog.append(player_log)
UTA_2012_gamelog = pd.concat(UTA_2012_gamelog)    
UTA_2012_gamelogs = UTA_2012_gamelog.copy()
UTA_2012_gamelogs['GAME_SCORE'] = UTA_2012_gamelogs['GAME_SCORE'].astype(float)
UTA_2012_games = UTA_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2012_games_csv = UTA_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2012_games.csv', index=False)
UTA_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2012_games.csv')
UTA_2012_games_proc.head()
# Out:
# You searched for "Blake Ahearn"
# 1 result found.
# Blake Ahearn
# Results for Blake Ahearn:
#
# You searched for "Raja Bell"
# 2 results found.
# 0: Raja Bell
# 1: Troy Bell
# Pick one: 0
# Results for Raja Bell:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Jeremy Evans"
# 5 results found.
# 0: Jeremy Evans
# 1: Tyreke Evans
# 2: Jeremy Lamb
# 3: Jeremy Lin
# 4: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Evans:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Devin Harris"
# 8 results found.
# 0: Devin Harris
# 1: Jalen Harris
# 2: Bernie Harris
# 3: Chris Harris
# 4: Elias Harris
# 5: Steve Harris
# ...

# %%
UTA_2013_gamelog = []

for p in UTA_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2013_gamelog.append(player_log)
UTA_2013_gamelog = pd.concat(UTA_2013_gamelog)    
UTA_2013_gamelogs = UTA_2013_gamelog.copy()
UTA_2013_gamelogs['GAME_SCORE'] = UTA_2013_gamelogs['GAME_SCORE'].astype(float)
UTA_2013_games = UTA_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2013_games_csv = UTA_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2013_games.csv', index=False)
UTA_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2013_games.csv')
UTA_2013_games_proc.head()
# Out:
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "DeMarre Carroll"
# 1 result found.
# DeMarre Carroll
# Results for DeMarre Carroll:
#
# You searched for "Jeremy Evans"
# 5 results found.
# 0: Jeremy Evans
# 1: Tyreke Evans
# 2: Jeremy Lamb
# 3: Jeremy Lin
# 4: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Evans:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Randy Foye"
# 10 results found.
# 0: Randy Foye
# 1: Randy Allen
# 2: Randy Brown
# 3: Danny Doyle
# 4: Randy Stoll
# 5: Randy White
# 6: Randy Woods
# 7: Ray Owes
# 8: Brandon Roy
# 9: Ray Felix
# Pick one: 0
# Results for Randy Foye:
#
# You searched for "Gordon Hayward"
# 1 result found.
# Gordon Hayward
# Results for Gordon Hayward:
#
# ...

# %%
UTA_2014_gamelog = []

for p in UTA_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2014_gamelog.append(player_log)
UTA_2014_gamelog = pd.concat(UTA_2014_gamelog)    
UTA_2014_gamelogs = UTA_2014_gamelog.copy()
UTA_2014_gamelogs['GAME_SCORE'] = UTA_2014_gamelogs['GAME_SCORE'].astype(float)
UTA_2014_games = UTA_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2014_games_csv = UTA_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2014_games.csv', index=False)
UTA_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2014_games.csv')
UTA_2014_games_proc.head()
# Out:
# You searched for "Andris Biedriņš"
# 1 result found.
# Andris Biedrins
# Results for Andris Biedrins:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Ian Clark"
# 4 results found.
# 0: Ian Clark
# 1: Earl Clark
# 2: Gary Clark
# 3: Keon Clark
# Pick one: 0
# Results for Ian Clark:
#
# You searched for "Jeremy Evans"
# 5 results found.
# 0: Jeremy Evans
# 1: Tyreke Evans
# 2: Jeremy Lamb
# 3: Jeremy Lin
# 4: Jeremy Tyler
# Pick one: 0
# Results for Jeremy Evans:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Diante Garrett"
# 3 results found.
# ...

# %%
UTA_2015_gamelog = []

for p in UTA_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2015_gamelog.append(player_log)
UTA_2015_gamelog = pd.concat(UTA_2015_gamelog)    
UTA_2015_gamelogs = UTA_2015_gamelog.copy()
UTA_2015_gamelogs['GAME_SCORE'] = UTA_2015_gamelogs['GAME_SCORE'].astype(float)
UTA_2015_games = UTA_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2015_games_csv = UTA_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2015_games.csv', index=False)
UTA_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2015_games.csv')
UTA_2015_games_proc.head()
# Out:
# You searched for "Jerrelle Benimon"
# 1 result found.
# Jerrelle Benimon
# Results for Jerrelle Benimon:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Patrick Christopher"
# 1 result found.
# Patrick Christopher
# Results for Patrick Christopher:
#
# You searched for "Ian Clark"
# 4 results found.
# 0: Ian Clark
# 1: Earl Clark
# 2: Gary Clark
# 3: Keon Clark
# Pick one: 0
# Results for Ian Clark:
#
# You searched for "Jack Cooley"
# 15 results found.
# 0: Jack Cooley
# 1: Jack Foley
# 2: Jack Haley
# 3: Jack Kiley
# 4: Jack Smiley
# 5: Jack Toomay
# ...

# %%
UTA_2016_gamelog = []

for p in UTA_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2016_gamelog.append(player_log)
UTA_2016_gamelog = pd.concat(UTA_2016_gamelog)    
UTA_2016_gamelogs = UTA_2016_gamelog.copy()
UTA_2016_gamelogs['GAME_SCORE'] = UTA_2016_gamelogs['GAME_SCORE'].astype(float)
UTA_2016_games = UTA_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2016_games_csv = UTA_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2016_games.csv', index=False)
UTA_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2016_games.csv')
UTA_2016_games_proc.head()
# Out:
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Rudy Gobert"
# 2 results found.
# 0: Rudy Gobert
# 1: Ray Tolbert
# Pick one: 0
# Results for Rudy Gobert:
#
# You searched for "Erick Green"
# 11 results found.
# 0: Erick Green
# 1: Rickey Green
# 2: Eric Gordon
# 3: A.C. Green
# 4: Devin Green
# 5: Gerald Green
# 6: Mike Green
# 7: Si Green
# 8: Orien Greene
# 9: Ricky Grace
# ...

# %%
UTA_2017_gamelog = []

for p in UTA_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2017_gamelog.append(player_log)
UTA_2017_gamelog = pd.concat(UTA_2017_gamelog)    
UTA_2017_gamelogs = UTA_2017_gamelog.copy()
UTA_2017_gamelogs['GAME_SCORE'] = UTA_2017_gamelogs['GAME_SCORE'].astype(float)
UTA_2017_games = UTA_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2017_games_csv = UTA_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2017_games.csv', index=False)
UTA_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2017_games.csv')
UTA_2017_games_proc.head()
# Out:
# You searched for "Joel Bolomboy"
# 1 result found.
# Joel Bolomboy
# Results for Joel Bolomboy:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Boris Diaw"
# 1 result found.
# Boris Diaw
# Results for Boris Diaw:
#
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Rudy Gobert"
# 2 results found.
# 0: Rudy Gobert
# 1: Ray Tolbert
# Pick one: 0
# Results for Rudy Gobert:
#
# You searched for "Gordon Hayward"
# 1 result found.
# Gordon Hayward
# Results for Gordon Hayward:
#
# You searched for "George Hill"
# 11 results found.
# 0: George Hill
# 1: George Karl
# 2: George King
# 3: George King
# 4: Gary Hill
# 5: George Lee
# ...

# %%
UTA_2018_gamelog = []

for p in UTA_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2018_gamelog.append(player_log)
UTA_2018_gamelog = pd.concat(UTA_2018_gamelog)    
UTA_2018_gamelogs = UTA_2018_gamelog.copy()
UTA_2018_gamelogs['GAME_SCORE'] = UTA_2018_gamelogs['GAME_SCORE'].astype(float)
UTA_2018_games = UTA_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2018_games_csv = UTA_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2018_games.csv', index=False)
UTA_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2018_games.csv')
UTA_2018_games_proc.head()
# Out:
# You searched for "Tony Bradley"
# 10 results found.
# 0: Tony Bradley
# 1: Toby Bailey
# 2: Joe Bradley
# 3: Tony Allen
# 4: Alex Bradley
# 5: Alonzo Bradley
# 6: Avery Bradley
# 7: Bill Bradley
# 8: Bill Bradley
# 9: Jim Bradley
# Pick one: 0
# Results for Tony Bradley:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# Results for Derrick Favors:
#
# You searched for "Rudy Gobert"
# 2 results found.
# 0: Rudy Gobert
# 1: Ray Tolbert
# Pick one: 0
# Results for Rudy Gobert:
#
# ...

# %%
UTA_2019_gamelog = []

for p in UTA_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2019_gamelog.append(player_log)
UTA_2019_gamelog = pd.concat(UTA_2019_gamelog)    
UTA_2019_gamelogs = UTA_2019_gamelog.copy()
UTA_2019_gamelogs['GAME_SCORE'] = UTA_2019_gamelogs['GAME_SCORE'].astype(float)
UTA_2019_games = UTA_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2019_games_csv = UTA_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2019_games.csv', index=False)
UTA_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2019_games.csv')
UTA_2019_games_proc.head()
# Out:
# You searched for "Grayson Allen"
# 2 results found.
# 0: Grayson Allen
# 1: Ray Allen
# Pick one: 0
# Results for Grayson Allen:
#
# You searched for "Tony Bradley"
# 10 results found.
# 0: Tony Bradley
# 1: Toby Bailey
# 2: Joe Bradley
# 3: Tony Allen
# 4: Alex Bradley
# 5: Alonzo Bradley
# 6: Avery Bradley
# 7: Bill Bradley
# 8: Bill Bradley
# 9: Jim Bradley
# Pick one: 0
# Results for Tony Bradley:
#
# You searched for "Alec Burks"
# 3 results found.
# 0: Alec Burks
# 1: Trey Burke
# 2: Alex Kirk
# Pick one: 0
# Results for Alec Burks:
#
# You searched for "Tyler Cavanaugh"
# 1 result found.
# Tyler Cavanaugh
# Results for Tyler Cavanaugh:
#
# You searched for "Jae Crowder"
# 4 results found.
# 0: Jae Crowder
# 1: Joe Cooper
# 2: Corey Crowder
# 3: Joe Strawder
# Pick one: 0
# Results for Jae Crowder:
#
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# ...

# %%
UTA_2020_gamelog = []

for p in UTA_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2020_gamelog.append(player_log)
UTA_2020_gamelog = pd.concat(UTA_2020_gamelog)    
UTA_2020_gamelogs = UTA_2020_gamelog.copy()
UTA_2020_gamelogs['GAME_SCORE'] = UTA_2020_gamelogs['GAME_SCORE'].astype(float)
UTA_2020_games = UTA_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2020_games_csv = UTA_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2020_games.csv', index=False)
UTA_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2020_games.csv')
UTA_2020_games_proc.head()
# Out:
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Tony Bradley"
# 10 results found.
# 0: Tony Bradley
# 1: Toby Bailey
# 2: Joe Bradley
# 3: Tony Allen
# 4: Alex Bradley
# 5: Alonzo Bradley
# 6: Avery Bradley
# 7: Bill Bradley
# 8: Bill Bradley
# 9: Jim Bradley
# Pick one: 0
# Results for Tony Bradley:
#
# You searched for "Jarrell Brantley"
# 1 result found.
# Jarrell Brantley
# Results for Jarrell Brantley:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# ...

# %%
UTA_2021_gamelog = []

for p in UTA_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    UTA_2021_gamelog.append(player_log)
UTA_2021_gamelog = pd.concat(UTA_2021_gamelog)    
UTA_2021_gamelogs = UTA_2021_gamelog.copy()
UTA_2021_gamelogs['GAME_SCORE'] = UTA_2021_gamelogs['GAME_SCORE'].astype(float)
UTA_2021_games = UTA_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_2021_games_csv = UTA_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2021_games.csv', index=False)
UTA_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2021_games.csv')
UTA_2021_games_proc.head()
# Out:
# You searched for "Udoka Azubuike"
# 1 result found.
# Udoka Azubuike
# Results for Udoka Azubuike:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Jarrell Brantley"
# 1 result found.
# Jarrell Brantley
# Results for Jarrell Brantley:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Mike Conley"
# 17 results found.
# 0: Mike Conley
# 1: Gene Conley
# 2: Mike Tobey
# 3: Mike Butler
# 4: Ken Corley
# 5: Mike Dunleavy
# 6: Mike Dunleavy
# 7: Mike Gale
# 8: Mike Maloy
# 9: Mike Miller
# 10: Mike Niles
# 11: Mike Glenn
# 12: Mike Lynn
# 13: Mike Flynn
# 14: Mike Gibson
# 15: Mike Lewis
# 16: Mike Jackson
# Pick one: 0
# Results for Mike Conley:
#
# You searched for "Derrick Favors"
# 4 results found.
# 0: Derrick Favors
# 1: Derrick Byars
# 2: Derrick Rose
# 3: Derrick Walton
# Pick one: 0
# ...

# %% [markdown]
# ## combine all seasons

# %%
UTA_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2000_games.csv')
UTA_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2001_games.csv')
UTA_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2002_games.csv')
UTA_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2003_games.csv')
UTA_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2004_games.csv')
UTA_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2005_games.csv')
UTA_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2006_games.csv')
UTA_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2007_games.csv')
UTA_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2008_games.csv')
UTA_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2009_games.csv')
UTA_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2010_games.csv')
UTA_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2011_games.csv')
UTA_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2012_games.csv')
UTA_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2013_games.csv')
UTA_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2014_games.csv')
UTA_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2015_games.csv')
UTA_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2016_games.csv')
UTA_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2017_games.csv')
UTA_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2018_games.csv')
UTA_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2019_games.csv')
UTA_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2020_games.csv')
UTA_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/UTA/UTA_2021_games.csv')

# %%
UTA_season_dfs = [UTA_2000_games_io, UTA_2001_games_io, UTA_2002_games_io, UTA_2003_games_io, UTA_2004_games_io, UTA_2005_games_io,
                 UTA_2006_games_io, UTA_2007_games_io, UTA_2008_games_io, UTA_2009_games_io, UTA_2010_games_io, UTA_2011_games_io,
                 UTA_2012_games_io, UTA_2013_games_io, UTA_2014_games_io, UTA_2015_games_io, UTA_2016_games_io, UTA_2017_games_io,
                 UTA_2018_games_io, UTA_2019_games_io, UTA_2020_games_io, UTA_2021_games_io]

# %%
UTA_all = pd.concat(UTA_season_dfs)
UTA_all_sorted = UTA_all.sort_values(by=['GAME_SCORE'], ascending=False)
UTA_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2000-12-20  37-149  UTA      AWAY      PHI   W (+2)   1  43:11  13   18
# 0  2009-01-12  29-231  UTA      HOME      IND   W (+7)   1  40:13  13   19
# 0  2017-03-22  24-269  UTA      HOME      NYK   W (+7)   1  38:05  13   15
# 0  2003-03-12  39-231  UTA      AWAY      ORL   W (+3)   1  42:08  12   19
# 0  2018-02-02  21-148  UTA      AWAY      PHO  W (+32)   1  33:05  14   19
# 0  2021-05-07  32-019  UTA      HOME      DEN   W (+7)   1  39:09  16   23
# 0  2008-03-15  26-116  UTA      AWAY      NJN   L (-2)   1  38:27  15   19
# 0  2010-02-09  28-081  UTA      AWAY      LAC  W (+10)   1  38:26  13   17
# 0  2010-11-09  25-272  UTA      AWAY      MIA   W (+2)   1  43:27  19   28
# 1  2010-04-06  25-284  UTA      HOME      OKC   W (+1)   1  42:23  14   23
# 2  2009-12-14  25-171  UTA      HOME      MIN   L (-2)   1  41:05  11   20
# ...
