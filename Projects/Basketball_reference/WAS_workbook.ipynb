# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import scipy.stats as stats
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats,get_team_misc

# %%
# Constants
SEASON_2000_START = '1999-11-02'
SEASON_2000_END = '2000-04-19'

SEASON_2001_START = '2000-11-01'
SEASON_2001_END = '2001-04-18'

SEASON_2002_START = '2001-10-30'
SEASON_2002_END = '2002-04-17'

SEASON_2003_START = '2002-10-30'
SEASON_2003_END = '2003-04-16'

SEASON_2004_START = '2003-10-29'
SEASON_2004_END = '2004-04-12'

SEASON_2005_START = '2004-11-03'
SEASON_2005_END = '2005-04-20'

SEASON_2006_START = '2005-11-02'
SEASON_2006_END = '2006-04-19'

SEASON_2007_START = '2006-11-01'
SEASON_2007_END = '2007-04-18'

SEASON_2008_START = '2007-11-02'
SEASON_2008_END = '2008-04-16'

SEASON_2009_START = '2008-10-28'
SEASON_2009_END = '2009-04-15'

SEASON_2010_START = '2009-10-27'
SEASON_2010_END = '2010-04-14'

SEASON_2011_START = '2010-10-26'
SEASON_2011_END = '2011-04-13'

SEASON_2012_START = '2011-11-25'
SEASON_2012_END = '2012-04-26'

SEASON_2013_START = '2012-10-30'
SEASON_2013_END = '2013-04-17'

SEASON_2014_START = '2013-10-30'
SEASON_2014_END = '2014-04-16'

SEASON_2015_START = '2014-10-29'
SEASON_2015_END = '2015-04-15'

SEASON_2016_START = '2015-10-28' 
SEASON_2016_END = '2016-04-13'

SEASON_2017_START = '2016-10-25'
SEASON_2017_END = '2017-04-14'

SEASON_2018_START = '2017-10-17'
SEASON_2018_END = '2018-04-14'

SEASON_2019_START = '2018-10-18'
SEASON_2019_END = '2019-04-12'

SEASON_2020_START = '2019-10-22'
SEASON_2020_END = '2020-08-15'

SEASON_2021_START = '2020-12-22'
SEASON_2021_END = '2021-05-16'

# %%
season = 2000
appended_data_WAS = []

# WAS
while season <= 2021:
    df_WAS = get_roster('WAS', season)
    df_WAS['Season'] = season
    df_WAS['Team'] = 'WAS'
    appended_data_WAS.append(df_WAS)
    season = season + 1
appended_data_WAS = pd.concat(appended_data_WAS)

# %%
WAS_df_all = appended_data_WAS.copy()
WAS_df_all_csv = WAS_df_all.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_players_all.csv', index=False)
WAS_df_all_csv_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_players_all.csv')
WAS_df_all_csv_io.head()
# Out:
#    NUMBER            PLAYER POS HEIGHT  WEIGHT  BIRTH_DATE NATIONALITY  \
# 0       8      Isaac Austin   C   6-10     255  1969-08-18          US
# 1      52      Calvin Booth   C   6-11     230  1976-05-07          US
# 2      32  Richard Hamilton  SG    6-6     185  1978-02-14          US
# 3       5      Juwan Howard  PF    6-9     240  1973-02-07          US
# 4      10     Reggie Jordan  PG    6-4     195  1968-01-26          US
#
#   EXPERIENCE           COLLEGE  Season Team
# 0          6     Arizona State    2000  WAS
# 1          R        Penn State    2000  WAS
# 2          R             UConn    2000  WAS
# 3          5          Michigan    2000  WAS
# 4          5  New Mexico State    2000  WAS

# %%
WAS_df_2000 = WAS_df_all[WAS_df_all['Season'] == 2000]
WAS_df_2001 = WAS_df_all[WAS_df_all['Season'] == 2001]
WAS_df_2002 = WAS_df_all[WAS_df_all['Season'] == 2002]
WAS_df_2003 = WAS_df_all[WAS_df_all['Season'] == 2003]
WAS_df_2004 = WAS_df_all[WAS_df_all['Season'] == 2004]
WAS_df_2005 = WAS_df_all[WAS_df_all['Season'] == 2005]
WAS_df_2006 = WAS_df_all[WAS_df_all['Season'] == 2006]
WAS_df_2007 = WAS_df_all[WAS_df_all['Season'] == 2007]
WAS_df_2008 = WAS_df_all[WAS_df_all['Season'] == 2008]
WAS_df_2009 = WAS_df_all[WAS_df_all['Season'] == 2009]
WAS_df_2010 = WAS_df_all[WAS_df_all['Season'] == 2010]
WAS_df_2011 = WAS_df_all[WAS_df_all['Season'] == 2011]
WAS_df_2012 = WAS_df_all[WAS_df_all['Season'] == 2012]
WAS_df_2013 = WAS_df_all[WAS_df_all['Season'] == 2013]
WAS_df_2014 = WAS_df_all[WAS_df_all['Season'] == 2014]
WAS_df_2015 = WAS_df_all[WAS_df_all['Season'] == 2015]
WAS_df_2016 = WAS_df_all[WAS_df_all['Season'] == 2016]
WAS_df_2017 = WAS_df_all[WAS_df_all['Season'] == 2017]
WAS_df_2018 = WAS_df_all[WAS_df_all['Season'] == 2018]
WAS_df_2019 = WAS_df_all[WAS_df_all['Season'] == 2019]
WAS_df_2020 = WAS_df_all[WAS_df_all['Season'] == 2020]
WAS_df_2021 = WAS_df_all[WAS_df_all['Season'] == 2021]

# %%
# changing names
#WAS_df_2002.loc[WAS_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'
#WAS_df_2004.loc[WAS_df_2003.PLAYER == 'Nenê Hilário', 'PLAYER'] = 'Nene Hilario'

# %%
WAS_df_2000_players = WAS_df_2000['PLAYER'].to_list()
WAS_df_2001_players = WAS_df_2001['PLAYER'].to_list()
WAS_df_2002_players = WAS_df_2002['PLAYER'].to_list()
WAS_df_2003_players = WAS_df_2003['PLAYER'].to_list()
WAS_df_2004_players = WAS_df_2004['PLAYER'].to_list()
WAS_df_2005_players = WAS_df_2005['PLAYER'].to_list()

WAS_df_2006_players = WAS_df_2006['PLAYER'].to_list()
WAS_df_2007_players = WAS_df_2007['PLAYER'].to_list()
WAS_df_2008_players = WAS_df_2008['PLAYER'].to_list()
WAS_df_2009_players = WAS_df_2009['PLAYER'].to_list()
WAS_df_2010_players = WAS_df_2010['PLAYER'].to_list()
WAS_df_2011_players = WAS_df_2011['PLAYER'].to_list()

WAS_df_2012_players = WAS_df_2012['PLAYER'].to_list()
WAS_df_2013_players = WAS_df_2013['PLAYER'].to_list()
WAS_df_2014_players = WAS_df_2014['PLAYER'].to_list()
WAS_df_2015_players = WAS_df_2015['PLAYER'].to_list()
WAS_df_2016_players = WAS_df_2016['PLAYER'].to_list()
WAS_df_2017_players = WAS_df_2017['PLAYER'].to_list()

WAS_df_2018_players = WAS_df_2018['PLAYER'].to_list()
WAS_df_2019_players = WAS_df_2019['PLAYER'].to_list()
WAS_df_2020_players = WAS_df_2020['PLAYER'].to_list()
WAS_df_2021_players = WAS_df_2021['PLAYER'].to_list()

# %% [markdown]
# ## players to drop

# %%
#WAS_df_2000_players.remove("Michael Smith")
#WAS_df_2001_players.remove("Michael Smith")
#WAS_df_2005_players.remove("Peter John Ramos")
#WAS_df_2009_players.remove("Dee Brown")
#WAS_df_2011_players.remove("Hamady N'Diaye")
#WAS_df_2012_players.remove("Nenê Hilário")
#WAS_df_2012_players.remove("Hamady N'Diaye")
#WAS_df_2013_players.remove("Nenê Hilário")
#WAS_df_2014_players.remove("Nenê Hilário")
#WAS_df_2015_players.remove("Nenê Hilário")
#WAS_df_2016_players.remove("Nenê Hilário")
#WAS_df_2014_players.remove("Glen Rice")
#WAS_df_2015_players.remove("Glen Rice")
#WAS_df_2016_players.remove("Kelly Oubre")
#WAS_df_2017_players.remove("Sheldon Mac")
#WAS_df_2017_players.remove("Kelly Oubre")
#WAS_df_2018_players.remove("Kelly Oubre")
#WAS_df_2019_players.remove("Kelly Oubre")
#WAS_df_2019_players.remove("Troy Brown")
#WAS_df_2019_players.remove("Gary Payton")
#WAS_df_2020_players.remove("Gary Payton")
#WAS_df_2020_players.remove("Troy Brown")
#WAS_df_2021_players.remove("Troy Brown")
#WAS_df_2021_players.remove("Anthony Gill")
WAS_df_2012_players.remove("Hamady N'Diaye")

# %%
WAS_2000_gamelog = []


for p in WAS_df_2000_players:
    player_log = get_game_logs(str(p), SEASON_2000_START, SEASON_2000_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2000_gamelog.append(player_log)
WAS_2000_gamelog = pd.concat(WAS_2000_gamelog)    
WAS_2000_gamelogs = WAS_2000_gamelog.copy()
WAS_2000_gamelogs['GAME_SCORE'] = WAS_2000_gamelogs['GAME_SCORE'].astype(float)
WAS_2000_games = WAS_2000_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2000_games_csv = WAS_2000_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2000_games.csv', index=False)
WAS_2000_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2000_games.csv')
WAS_2000_games_proc.head()
# Out:
# You searched for "Isaac Austin"
# 1 result found.
# Isaac Austin
# Results for Isaac Austin:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Juwan Howard"
# 4 results found.
# 0: Juwan Howard
# 1: Brian Howard
# 2: Josh Howard
# 3: Juwan Morgan
# Pick one: 0
# Results for Juwan Howard:
#
# You searched for "Reggie Jordan"
# 6 results found.
# 0: Reggie Jordan
# 1: Eddie Jordan
# 2: Reggie Harding
# 3: Reggie Johnson
# 4: Jerome Jordan
# 5: Reggie Evans
# Pick one: 0
# Results for Reggie Jordan:
#
# You searched for "Gerard King"
# 4 results found.
# 0: Gerard King
# 1: Bernard King
# 2: George King
# 3: George King
# Pick one: 0
# Results for Gerard King:
#
# You searched for "Tracy Murray"
# 4 results found.
# ...

# %%
WAS_2001_gamelog = []


for p in WAS_df_2001_players:
    player_log = get_game_logs(str(p), SEASON_2001_START, SEASON_2001_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2001_gamelog.append(player_log)
WAS_2001_gamelog = pd.concat(WAS_2001_gamelog)    
WAS_2001_gamelogs = WAS_2001_gamelog.copy()
WAS_2001_gamelogs['GAME_SCORE'] = WAS_2001_gamelogs['GAME_SCORE'].astype(float)
WAS_2001_games = WAS_2001_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2001_games_csv = WAS_2001_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2001_games.csv', index=False)
WAS_2001_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2001_games.csv')
WAS_2001_games_proc.head()
# Out:
# You searched for "Courtney Alexander"
# 2 results found.
# 0: Courtney Alexander
# 1: Cory Alexander
# Pick one: 0
# Results for Courtney Alexander:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Hubert Davis"
# 5 results found.
# 0: Hubert Davis
# 1: Aubrey Davis
# 2: Ben Davis
# 3: Harry Davis
# 4: Tyler Davis
# Pick one: 0
# Results for Hubert Davis:
#
# You searched for "Obinna Ekezie"
# 1 result found.
# Obinna Ekezie
# Results for Obinna Ekezie:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Juwan Howard"
# 4 results found.
# 0: Juwan Howard
# 1: Brian Howard
# 2: Josh Howard
# 3: Juwan Morgan
# Pick one: 0
# Results for Juwan Howard:
#
# You searched for "Popeye Jones"
# 6 results found.
# 0: Popeye Jones
# 1: Bobby Jones
# ...

# %%
WAS_2002_gamelog = []


for p in WAS_df_2002_players:
    player_log = get_game_logs(str(p), SEASON_2002_START, SEASON_2002_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2002_gamelog.append(player_log)
WAS_2002_gamelog = pd.concat(WAS_2002_gamelog)    
WAS_2002_gamelogs = WAS_2002_gamelog.copy()
WAS_2002_gamelogs['GAME_SCORE'] = WAS_2002_gamelogs['GAME_SCORE'].astype(float)
WAS_2002_games = WAS_2002_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2002_games_csv = WAS_2002_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2002_games.csv', index=False)
WAS_2002_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2002_games.csv')
WAS_2002_games_proc.head()
# Out:
# You searched for "Courtney Alexander"
# 2 results found.
# 0: Courtney Alexander
# 1: Cory Alexander
# Pick one: 0
# Results for Courtney Alexander:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Hubert Davis"
# 5 results found.
# 0: Hubert Davis
# 1: Aubrey Davis
# 2: Ben Davis
# 3: Harry Davis
# 4: Tyler Davis
# Pick one: 0
# Results for Hubert Davis:
#
# You searched for "Richard Hamilton"
# 2 results found.
# 0: Richard Hamilton
# 1: Richard Morton
# Pick one: 0
# Results for Richard Hamilton:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Popeye Jones"
# 6 results found.
# 0: Popeye Jones
# 1: Bobby Jones
# 2: Bobby Jones
# 3: Ozell Jones
# 4: Perry Jones
# 5: Steve Jones
# Pick one: 0
# ...

# %%
    
WAS_2003_gamelog = []



for p in WAS_df_2003_players:
    player_log = get_game_logs(str(p), SEASON_2003_START, SEASON_2003_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2003_gamelog.append(player_log)
WAS_2003_gamelog = pd.concat(WAS_2003_gamelog)    
WAS_2003_gamelogs = WAS_2003_gamelog.copy()
WAS_2003_gamelogs['GAME_SCORE'] = WAS_2003_gamelogs['GAME_SCORE'].astype(float)
WAS_2003_games = WAS_2003_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2003_games_csv = WAS_2003_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2003_games.csv', index=False)
WAS_2003_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2003_games.csv')
WAS_2003_games_proc.head()
# Out:
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Brian Cardinal"
# 2 results found.
# 0: Brian Cardinal
# 1: Brian Martin
# Pick one: 0
# Results for Brian Cardinal:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "Anthony Goldwire"
# 2 results found.
# 0: Anthony Goldwire
# 1: Anthony Bowie
# Pick one: 0
# Results for Anthony Goldwire:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Larry Hughes"
# 6 results found.
# 0: Larry Hughes
# 1: Larry Bunce
# 2: Larry Fogle
# 3: Larry Jones
# 4: Larry Sykes
# 5: Larry Wright
# Pick one: 0
# Results for Larry Hughes:
#
# You searched for "Jared Jeffries"
# 1 result found.
# Jared Jeffries
# ...

# %%
WAS_2004_gamelog = []



for p in WAS_df_2004_players:
    player_log = get_game_logs(str(p), SEASON_2004_START, SEASON_2004_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2004_gamelog.append(player_log)
WAS_2004_gamelog = pd.concat(WAS_2004_gamelog)    
WAS_2004_gamelogs = WAS_2004_gamelog.copy()
WAS_2004_gamelogs['GAME_SCORE'] = WAS_2004_gamelogs['GAME_SCORE'].astype(float)
WAS_2004_games = WAS_2004_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2004_games_csv = WAS_2004_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2004_games.csv', index=False)
WAS_2004_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2004_games.csv')
WAS_2004_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Lonny Baxter"
# 3 results found.
# 0: Lonny Baxter
# 1: Sonny Parker
# 2: Kenny Battle
# Pick one: 0
# Results for Lonny Baxter:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Torraye Braggs"
# 1 result found.
# Torraye Braggs
# Results for Torraye Braggs:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Mitchell Butler"
# 1 result found.
# Mitchell Butler
# Results for Mitchell Butler:
#
# ...

# %%
WAS_2005_gamelog = []



for p in WAS_df_2005_players:
    player_log = get_game_logs(str(p), SEASON_2005_START, SEASON_2005_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2005_gamelog.append(player_log)
WAS_2005_gamelog = pd.concat(WAS_2005_gamelog)    
WAS_2005_gamelogs = WAS_2005_gamelog.copy()
WAS_2005_gamelogs['GAME_SCORE'] = WAS_2005_gamelogs['GAME_SCORE'].astype(float)
WAS_2005_games = WAS_2005_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2005_games_csv = WAS_2005_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2005_games.csv', index=False)
WAS_2005_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2005_games.csv')
WAS_2005_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Steve Blake"
# 11 results found.
# 0: Steve Blake
# 1: Steve Bracey
# 2: Steve Bardo
# 3: Steve Burtt
# 4: Steve Hamer
# 5: Steve Hawes
# 6: Steve Hayes
# 7: Steve Nash
# 8: Steve Novak
# 9: Steve Kerr
# 10: Steven Hill
# Pick one: 0
# Results for Steve Blake:
#
# You searched for "Damone Brown"
# 14 results found.
# 0: Damone Brown
# 1: Raymond Brown
# 2: Andre Brown
# 3: Dee Brown
# 4: Dee Brown
# 5: Devin Brown
# 6: Harold Brown
# 7: Kwame Brown
# 8: Leon Brown
# 9: Mike Brown
# 10: Moses Brown
# 11: Myron Brown
# 12: Tony Brown
# 13: Damon Jones
# Pick one: 0
# Results for Damone Brown:
#
# You searched for "Kwame Brown"
# 9 results found.
# 0: Kwame Brown
# 1: Andre Brown
# 2: Bruce Brown
# 3: Damone Brown
# 4: Dee Brown
# 5: Dee Brown
# 6: Mike Brown
# 7: Stan Brown
# 8: Jim Browne
# Pick one: 0
# Results for Kwame Brown:
#
# You searched for "Juan Dixon"
# ...

# %%
WAS_2006_gamelog = []

for p in WAS_df_2006_players:
    player_log = get_game_logs(str(p), SEASON_2006_START, SEASON_2006_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2006_gamelog.append(player_log)
WAS_2006_gamelog = pd.concat(WAS_2006_gamelog)    
WAS_2006_gamelogs = WAS_2006_gamelog.copy()
WAS_2006_gamelogs['GAME_SCORE'] = WAS_2006_gamelogs['GAME_SCORE'].astype(float)
WAS_2006_games = WAS_2006_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2006_games_csv = WAS_2006_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2006_games.csv', index=False)
WAS_2006_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2006_games.csv')
WAS_2006_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Chucky Atkins"
# 1 result found.
# Chucky Atkins
# Results for Chucky Atkins:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Jarvis Hayes"
# 4 results found.
# 0: Jarvis Hayes
# 1: Elvin Hayes
# 2: Jaxson Hayes
# 3: Jim Hayes
# Pick one: 0
# Results for Jarvis Hayes:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# ...

# %%
WAS_2007_gamelog = []

for p in WAS_df_2007_players:
    player_log = get_game_logs(str(p), SEASON_2007_START, SEASON_2007_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2007_gamelog.append(player_log)
WAS_2007_gamelog = pd.concat(WAS_2007_gamelog)    
WAS_2007_gamelogs = WAS_2007_gamelog.copy()
WAS_2007_gamelogs['GAME_SCORE'] = WAS_2007_gamelogs['GAME_SCORE'].astype(float)
WAS_2007_games = WAS_2007_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2007_games_csv = WAS_2007_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2007_games.csv', index=False)
WAS_2007_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2007_games.csv')
WAS_2007_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Calvin Booth"
# 3 results found.
# 0: Calvin Booth
# 1: Calvin Natt
# 2: Alvin Scott
# Pick one: 0
# Results for Calvin Booth:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Mike Hall"
# 21 results found.
# 0: Mike Hall
# 1: Mike Gale
# 2: Mike Barr
# 3: Mike Maloy
# 4: Josh Hall
# 5: Mike Bratz
# 6: Mike Davis
# 7: Mike Davis
# 8: Mike Evans
# 9: Mike Harper
# 10: Mike Harris
# 11: Mike James
# 12: Mike James
# 13: Mike Lynn
# 14: Mike Miller
# 15: Mike Niles
# 16: Mike Pratt
# ...

# %%
WAS_2008_gamelog = []

for p in WAS_df_2008_players:
    player_log = get_game_logs(str(p), SEASON_2008_START, SEASON_2008_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2008_gamelog.append(player_log)
WAS_2008_gamelog = pd.concat(WAS_2008_gamelog)    
WAS_2008_gamelogs = WAS_2008_gamelog.copy()
WAS_2008_gamelogs['GAME_SCORE'] = WAS_2008_gamelogs['GAME_SCORE'].astype(float)
WAS_2008_games = WAS_2008_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2008_games_csv = WAS_2008_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2008_games.csv', index=False)
WAS_2008_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2008_games.csv')
WAS_2008_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Antawn Jamison"
# 1 result found.
# Antawn Jamison
# Results for Antawn Jamison:
#
# You searched for "Roger Mason"
# 3 results found.
# 0: Roger Mason
# 1: Roger Brown
# 2: Roger Brown
# Pick one: 0
# Results for Roger Mason:
#
# You searched for "Dominic McGuire"
# 1 result found.
# Dominic McGuire
# Results for Dominic McGuire:
#
# ...

# %%
WAS_2009_gamelog = []

for p in WAS_df_2009_players:
    player_log = get_game_logs(str(p), SEASON_2009_START, SEASON_2009_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2009_gamelog.append(player_log)
WAS_2009_gamelog = pd.concat(WAS_2009_gamelog)    
WAS_2009_gamelogs = WAS_2009_gamelog.copy()
WAS_2009_gamelogs['GAME_SCORE'] = WAS_2009_gamelogs['GAME_SCORE'].astype(float)
WAS_2009_games = WAS_2009_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2009_games_csv = WAS_2009_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2009_games.csv', index=False)
WAS_2009_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2009_games.csv')
WAS_2009_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Javaris Crittenton"
# 1 result found.
# Javaris Crittenton
# Results for Javaris Crittenton:
#
# You searched for "Antonio Daniels"
# 2 results found.
# 0: Antonio Daniels
# 1: Antonio Davis
# Pick one: 0
# Results for Antonio Daniels:
#
# You searched for "Juan Dixon"
# 1 result found.
# Juan Dixon
# Results for Juan Dixon:
#
# You searched for "Brendan Haywood"
# 1 result found.
# Brendan Haywood
# Results for Brendan Haywood:
#
# You searched for "Mike James"
# 33 results found.
# 0: Mike James
# 1: Mike James
# 2: Mike Davis
# 3: Mike Davis
# 4: Mike Farmer
# 5: Mike Gale
# 6: Gene James
# ...

# %%
WAS_2010_gamelog = []

for p in WAS_df_2010_players:
    player_log = get_game_logs(str(p), SEASON_2010_START, SEASON_2010_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2010_gamelog.append(player_log)
WAS_2010_gamelog = pd.concat(WAS_2010_gamelog)    
WAS_2010_gamelogs = WAS_2010_gamelog.copy()
WAS_2010_gamelogs['GAME_SCORE'] = WAS_2010_gamelogs['GAME_SCORE'].astype(float)
WAS_2010_games = WAS_2010_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2010_games_csv = WAS_2010_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2010_games.csv', index=False)
WAS_2010_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2010_games.csv')
WAS_2010_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Earl Boykins"
# 1 result found.
# Earl Boykins
# Results for Earl Boykins:
#
# You searched for "Caron Butler"
# 4 results found.
# 0: Caron Butler
# 1: Al Butler
# 2: Greg Butler
# 3: Carl Fuller
# Pick one: 0
# Results for Caron Butler:
#
# You searched for "Paul Davis"
# 29 results found.
# 0: Paul Davis
# 1: Bill Davis
# 2: Dale Davis
# 3: Mark Davis
# 4: Mark Davis
# 5: Mel Davis
# 6: Walt Davis
# 7: Paul Dawkins
# 8: Baron Davis
# 9: Ben Davis
# 10: Bob Davis
# 11: Brad Davis
# 12: Ed Davis
# 13: Emanual Davis
# 14: Glen Davis
# 15: Harry Davis
# 16: Jim Davis
# 17: Josh Davis
# 18: Lee Davis
# 19: Mike Davis
# 20: Mike Davis
# 21: Ralph Davis
# 22: Red Davis
# 23: Ron Davis
# 24: Paul Silas
# 25: Paul Eboua
# 26: Paul Cloyd
# 27: Pau Gasol
# 28: Paul Grant
# ...

# %%
# removed Hamady N'Diaye
WAS_2011_gamelog = []

for p in WAS_df_2011_players:
    player_log = get_game_logs(str(p), SEASON_2011_START, SEASON_2011_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2011_gamelog.append(player_log)
WAS_2011_gamelog = pd.concat(WAS_2011_gamelog)    
WAS_2011_gamelogs = WAS_2011_gamelog.copy()
WAS_2011_gamelogs['GAME_SCORE'] = WAS_2011_gamelogs['GAME_SCORE'].astype(float)
WAS_2011_games = WAS_2011_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2011_games_csv = WAS_2011_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2011_games.csv', index=False)
WAS_2011_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2011_games.csv')
WAS_2011_games_proc.head()
# Out:
# You searched for "Gilbert Arenas"
# 1 result found.
# Gilbert Arenas
# Results for Gilbert Arenas:
#
# You searched for "Hilton Armstrong"
# 1 result found.
# Hilton Armstrong
# Results for Hilton Armstrong:
#
# You searched for "Mike Bibby"
# 17 results found.
# 0: Mike Bibby
# 1: Mike Tobey
# 2: Mike Barr
# 3: Mike Bloom
# 4: Mike Bratz
# 5: Mike Brown
# 6: Mike Gibson
# 7: Mike Maloy
# 8: Mike Niles
# 9: Mike Wilks
# 10: Mike Dabich
# 11: Mike Davis
# 12: Mike Davis
# 13: Mike Lewis
# 14: Mike Lynn
# 15: Mike Price
# 16: Mike Smith
# Pick one: 0
# Results for Mike Bibby:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Jordan Crawford"
# 4 results found.
# 0: Jordan Crawford
# 1: Jordan Ford
# 2: Jamal Crawford
# 3: Joe Crawford
# Pick one: 0
# ...

# %%
WAS_2012_gamelog = []

for p in WAS_df_2012_players:
    player_log = get_game_logs(str(p), SEASON_2012_START, SEASON_2012_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2012_gamelog.append(player_log)
WAS_2012_gamelog = pd.concat(WAS_2012_gamelog)    
WAS_2012_gamelogs = WAS_2012_gamelog.copy()
WAS_2012_gamelogs['GAME_SCORE'] = WAS_2012_gamelogs['GAME_SCORE'].astype(float)
WAS_2012_games = WAS_2012_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2012_games_csv = WAS_2012_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2012_games.csv', index=False)
WAS_2012_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2012_games.csv')
WAS_2012_games_proc.head()
# Out:
# You searched for "Morris Almond"
# 1 result found.
# Morris Almond
# Results for Morris Almond:
#
# You searched for "Andray Blatche"
# 1 result found.
# Andray Blatche
# Results for Andray Blatche:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Brian Cook"
# 9 results found.
# 0: Brian Cook
# 1: Quinn Cook
# 2: Brian Bowen
# 3: Bert Cook
# 4: Bobby Cook
# 5: Darwin Cook
# 6: Omar Cook
# 7: Brian Rowsom
# 8: Brian Shaw
# Pick one: 0
# Results for Brian Cook:
#
# You searched for "Jordan Crawford"
# 4 results found.
# 0: Jordan Crawford
# 1: Jordan Ford
# 2: Jamal Crawford
# 3: Joe Crawford
# Pick one: 0
# Results for Jordan Crawford:
#
# You searched for "Maurice Evans"
# 6 results found.
# 0: Maurice Evans
# 1: Mike Evans
# 2: Maurice King
# 3: Maurice Lucas
# 4: Maurice Ager
# 5: Maurice Baker
# Pick one: 0
# Results for Maurice Evans:
#
# ...

# %%
WAS_2013_gamelog = []

for p in WAS_df_2013_players:
    player_log = get_game_logs(str(p), SEASON_2013_START, SEASON_2013_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2013_gamelog.append(player_log)
WAS_2013_gamelog = pd.concat(WAS_2013_gamelog)    
WAS_2013_gamelogs = WAS_2013_gamelog.copy()
WAS_2013_gamelogs['GAME_SCORE'] = WAS_2013_gamelogs['GAME_SCORE'].astype(float)
WAS_2013_games = WAS_2013_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2013_games_csv = WAS_2013_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2013_games.csv', index=False)
WAS_2013_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2013_games.csv')
WAS_2013_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Earl Barron"
# 10 results found.
# 0: Earl Barron
# 1: Earl Watson
# 2: Dana Barros
# 3: Will Barton
# 4: Carl Braun
# 5: Earl Cureton
# 6: Earl Monroe
# 7: Earl Shannon
# 8: Earl Gardner
# 9: Earl Jones
# Pick one: 0
# Results for Earl Barron:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Jason Collins"
# 11 results found.
# 0: Jason Collins
# 1: Jason Collier
# 2: Jarron Collins
# 3: Don Collins
# 4: James Collins
# 5: John Collins
# 6: Art Collins
# 7: Jimmy Collins
# 8: Mardy Collins
# 9: Zach Collins
# 10: Jason Williams
# Pick one: 0
# Results for Jason Collins:
#
# You searched for "Jordan Crawford"
# 4 results found.
# 0: Jordan Crawford
# ...

# %%
WAS_2014_gamelog = []

for p in WAS_df_2014_players:
    player_log = get_game_logs(str(p), SEASON_2014_START, SEASON_2014_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2014_gamelog.append(player_log)
WAS_2014_gamelog = pd.concat(WAS_2014_gamelog)    
WAS_2014_gamelogs = WAS_2014_gamelog.copy()
WAS_2014_gamelogs['GAME_SCORE'] = WAS_2014_gamelogs['GAME_SCORE'].astype(float)
WAS_2014_games = WAS_2014_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2014_games_csv = WAS_2014_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2014_games.csv', index=False)
WAS_2014_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2014_games.csv')
WAS_2014_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Trevor Booker"
# 3 results found.
# 0: Trevor Booker
# 1: Devin Booker
# 2: Trevor Winter
# Pick one: 0
# Results for Trevor Booker:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Al Harrington"
# 5 results found.
# 0: Al Harrington
# 1: Adam Harrington
# 2: Bob Carrington
# 3: Al Hairston
# 4: Matt Harpring
# Pick one: 0
# Results for Al Harrington:
#
# You searched for "Eric Maynor"
# 5 results found.
# 0: Eric Maynor
# 1: Eric Dawson
# 2: Eric Money
# 3: Eric Snow
# 4: Eric Mobley
# Pick one: 0
# Results for Eric Maynor:
#
# You searched for "Andre Miller"
# ...

# %%
WAS_2015_gamelog = []

for p in WAS_df_2015_players:
    player_log = get_game_logs(str(p), SEASON_2015_START, SEASON_2015_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2015_gamelog.append(player_log)
WAS_2015_gamelog = pd.concat(WAS_2015_gamelog)    
WAS_2015_gamelogs = WAS_2015_gamelog.copy()
WAS_2015_gamelogs['GAME_SCORE'] = WAS_2015_gamelogs['GAME_SCORE'].astype(float)
WAS_2015_games = WAS_2015_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2015_games_csv = WAS_2015_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2015_games.csv', index=False)
WAS_2015_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2015_games.csv')
WAS_2015_games_proc.head()
# Out:
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Rasual Butler"
# 2 results found.
# 0: Rasual Butler
# 1: Al Butler
# Pick one: 0
# Results for Rasual Butler:
#
# You searched for "Will Bynum"
# 3 results found.
# 0: Will Bynum
# 1: Will Barton
# 2: Bill Ebben
# Pick one: 0
# Results for Will Bynum:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# Results for Drew Gooden:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Kris Humphries"
# 2 results found.
# 0: Kris Humphries
# 1: Jay Humphries
# Pick one: 0
# Results for Kris Humphries:
#
# You searched for "Andre Miller"
# 7 results found.
# 0: Andre Miller
# 1: Eddie Miller
# 2: Harry Miller
# ...

# %%
WAS_2016_gamelog = []

for p in WAS_df_2016_players:
    player_log = get_game_logs(str(p), SEASON_2016_START, SEASON_2016_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2016_gamelog.append(player_log)
WAS_2016_gamelog = pd.concat(WAS_2016_gamelog)    
WAS_2016_gamelogs = WAS_2016_gamelog.copy()
WAS_2016_gamelogs['GAME_SCORE'] = WAS_2016_gamelogs['GAME_SCORE'].astype(float)
WAS_2016_games = WAS_2016_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2016_games_csv = WAS_2016_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2016_games.csv', index=False)
WAS_2016_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2016_games.csv')
WAS_2016_games_proc.head()
# Out:
# You searched for "Alan Anderson"
# 15 results found.
# 0: Alan Anderson
# 1: Dan Anderson
# 2: Dan Anderson
# 3: Ryan Anderson
# 4: Alan Henderson
# 5: Ron Anderson
# 6: Cliff Anderson
# 7: Eric Anderson
# 8: Greg Anderson
# 9: J.J. Anderson
# 10: James Anderson
# 11: Kenny Anderson
# 12: Kim Anderson
# 13: Kyle Anderson
# 14: Nick Anderson
# Pick one: 0
# Results for Alan Anderson:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "DeJuan Blair"
# 2 results found.
# 0: DeJuan Blair
# 1: DeJuan Wheat
# Pick one: 0
# Results for DeJuan Blair:
#
# You searched for "Jared Dudley"
# 3 results found.
# 0: Jared Dudley
# 1: Charles Dudley
# 2: Chris Dudley
# Pick one: 0
# Results for Jared Dudley:
#
# You searched for "Jarell Eddie"
# 1 result found.
# Jarell Eddie
# Results for Jarell Eddie:
#
# You searched for "Drew Gooden"
# 3 results found.
# 0: Drew Gooden
# 1: Drew Gordon
# 2: Greg Oden
# Pick one: 0
# ...

# %%
WAS_2017_gamelog = []

for p in WAS_df_2017_players:
    player_log = get_game_logs(str(p), SEASON_2017_START, SEASON_2017_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2017_gamelog.append(player_log)
WAS_2017_gamelog = pd.concat(WAS_2017_gamelog)    
WAS_2017_gamelogs = WAS_2017_gamelog.copy()
WAS_2017_gamelogs['GAME_SCORE'] = WAS_2017_gamelogs['GAME_SCORE'].astype(float)
WAS_2017_games = WAS_2017_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2017_games_csv = WAS_2017_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2017_games.csv', index=False)
WAS_2017_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2017_games.csv')
WAS_2017_games_proc.head()
# Out:
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Bojan Bogdanović"
# 2 results found.
# 0: Bojan Bogdanovic
# 1: Bogdan Bogdanovic
# Pick one: 0
# Results for Bojan Bogdanovic:
#
# You searched for "Trey Burke"
# 5 results found.
# 0: Trey Burke
# 1: Pat Burke
# 2: Alec Burks
# 3: Corey Beck
# 4: Troy Bell
# Pick one: 0
# Results for Trey Burke:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Danuel House"
# 2 results found.
# 0: Danuel House
# 1: Daniel Theis
# Pick one: 0
# Results for Danuel House:
#
# You searched for "Brandon Jennings"
# 1 result found.
# Brandon Jennings
# Results for Brandon Jennings:
#
# You searched for "Ian Mahinmi"
# 2 results found.
# 0: Ian Mahinmi
# 1: Brian Martin
# Pick one: 0
# Results for Ian Mahinmi:
#
# You searched for "Chris McCullough"
# 1 result found.
# Chris McCullough
# Results for Chris McCullough:
#
# ...

# %%
WAS_2018_gamelog = []

for p in WAS_df_2018_players:
    player_log = get_game_logs(str(p), SEASON_2018_START, SEASON_2018_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2018_gamelog.append(player_log)
WAS_2018_gamelog = pd.concat(WAS_2018_gamelog)    
WAS_2018_gamelogs = WAS_2018_gamelog.copy()
WAS_2018_gamelogs['GAME_SCORE'] = WAS_2018_gamelogs['GAME_SCORE'].astype(float)
WAS_2018_games = WAS_2018_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2018_games_csv = WAS_2018_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2018_games.csv', index=False)
WAS_2018_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2018_games.csv')
WAS_2018_games_proc.head()
# Out:
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Tim Frazier"
# 4 results found.
# 0: Tim Frazier
# 1: Will Frazier
# 2: Jim Farmer
# 3: Walt Frazier
# Pick one: 0
# Results for Tim Frazier:
#
# You searched for "Marcin Gortat"
# 1 result found.
# Marcin Gortat
# Results for Marcin Gortat:
#
# You searched for "Ty Lawson"
# 3 results found.
# 0: Ty Lawson
# 1: Tony Dawson
# 2: Mo Layton
# Pick one: 0
# Results for Ty Lawson:
#
# You searched for "Ian Mahinmi"
# 2 results found.
# 0: Ian Mahinmi
# 1: Brian Martin
# Pick one: 0
# Results for Ian Mahinmi:
#
# You searched for "Chris McCullough"
# 1 result found.
# Chris McCullough
# Results for Chris McCullough:
#
# You searched for "Jodie Meeks"
# 1 result found.
# Jodie Meeks
# Results for Jodie Meeks:
#
# You searched for "Markieff Morris"
# 1 result found.
# Markieff Morris
# Results for Markieff Morris:
#
# You searched for "Otto Porter"
# 2 results found.
# ...

# %%
WAS_2019_gamelog = []

for p in WAS_df_2019_players:
    player_log = get_game_logs(str(p), SEASON_2019_START, SEASON_2019_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2019_gamelog.append(player_log)
WAS_2019_gamelog = pd.concat(WAS_2019_gamelog)    
WAS_2019_gamelogs = WAS_2019_gamelog.copy()
WAS_2019_gamelogs['GAME_SCORE'] = WAS_2019_gamelogs['GAME_SCORE'].astype(float)
WAS_2019_games = WAS_2019_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2019_games_csv = WAS_2019_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2019_games.csv', index=False)
WAS_2019_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2019_games.csv')
WAS_2019_games_proc.head()
# Out:
# You searched for "Trevor Ariza"
# 1 result found.
# Trevor Ariza
# Results for Trevor Ariza:
#
# You searched for "Ron Baker"
# 45 results found.
# 0: Ron Baker
# 1: Vin Baker
# 2: Norm Baker
# 3: Tom Barker
# 4: Ron Brewer
# 5: Ron Carter
# 6: Ron Harper
# 7: Thon Maker
# 8: Von Wafer
# 9: John Barber
# 10: John Barr
# 11: Moe Barr
# 12: Jon Barry
# 13: Aron Baynes
# 14: Moe Becker
# 15: Ron Behagen
# 16: Ron Boone
# 17: Don Boven
# 18: Don Buse
# 19: John Coker
# 20: Ron Davis
# 21: Ron Lee
# 22: Jon Leuer
# 23: Ron Mercer
# 24: Bob Naber
# 25: Tony Parker
# 26: Ron Reed
# 27: Tom Riker
# 28: Ron Riley
# 29: Ron Watts
# 30: Jon Teske
# 31: Don Bielke
# 32: Ron Bonham
# 33: Don Grate
# 34: Ron Horn
# 35: Red Kerr
# 36: Ron King
# 37: Rob Kurz
# 38: Ron Moore
# 39: Ron Rowan
# 40: Ron Sobie
# 41: Ron Widby
# 42: Byron Beck
# 43: Tom Black
# 44: Zan Tabak
# Pick one: 0
# Results for Ron Baker:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# ...

# %%
WAS_2020_gamelog = []

for p in WAS_df_2020_players:
    player_log = get_game_logs(str(p), SEASON_2020_START, SEASON_2020_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2020_gamelog.append(player_log)
WAS_2020_gamelog = pd.concat(WAS_2020_gamelog)    
WAS_2020_gamelogs = WAS_2020_gamelog.copy()
WAS_2020_gamelogs['GAME_SCORE'] = WAS_2020_gamelogs['GAME_SCORE'].astype(float)
WAS_2020_games = WAS_2020_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2020_games_csv = WAS_2020_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2020_games.csv', index=False)
WAS_2020_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2020_games.csv')
WAS_2020_games_proc.head()
# Out:
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Dāvis Bertāns"
# 3 results found.
# 0: Davis Bertans
# 1: Dairis Bertans
# 2: David Burns
# Pick one: 0
# Results for Davis Bertans:
#
# You searched for "Isaac Bonga"
# 2 results found.
# 0: Isaac Bonga
# 1: Isaac Okoro
# Pick one: 0
# Results for Isaac Bonga:
#
# You searched for "Thomas Bryant"
# 2 results found.
# 0: Thomas Bryant
# 1: Thomas Jordan
# Pick one: 0
# Results for Thomas Bryant:
#
# You searched for "Chris Chiozza"
# 2 results found.
# 0: Chris Chiozza
# 1: Chris Childs
# Pick one: 0
# Results for Chris Chiozza:
#
# You searched for "Jerian Grant"
# 3 results found.
# 0: Jerian Grant
# 1: Brian Grant
# 2: Jerami Grant
# Pick one: 0
# Results for Jerian Grant:
#
# You searched for "Rui Hachimura"
# 1 result found.
# Rui Hachimura
# Results for Rui Hachimura:
#
# You searched for "Ian Mahinmi"
# 2 results found.
# 0: Ian Mahinmi
# 1: Brian Martin
# ...

# %%
WAS_2021_gamelog = []

for p in WAS_df_2021_players:
    player_log = get_game_logs(str(p), SEASON_2021_START, SEASON_2021_END, playoffs = False)
    player_log['Player'] = p
    
    WAS_2021_gamelog.append(player_log)
WAS_2021_gamelog = pd.concat(WAS_2021_gamelog)    
WAS_2021_gamelogs = WAS_2021_gamelog.copy()
WAS_2021_gamelogs['GAME_SCORE'] = WAS_2021_gamelogs['GAME_SCORE'].astype(float)
WAS_2021_games = WAS_2021_gamelogs.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_2021_games_csv = WAS_2021_games.to_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2021_games.csv', index=False)
WAS_2021_games_proc = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2021_games.csv')
WAS_2021_games_proc.head()
# Out:
# You searched for "Deni Avdija"
# 1 result found.
# Deni Avdija
# Results for Deni Avdija:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Jordan Bell"
# 10 results found.
# 0: Jordan Bell
# 1: Jordan Hill
# 2: Jordan Bone
# 3: Jordan Ford
# 4: Jordan Loyd
# 5: Jordan Poole
# 6: Jordan Sibert
# 7: Jordan Bowden
# 8: Ryan Kelly
# 9: Jordan McRae
# Pick one: 0
# Results for Jordan Bell:
#
# You searched for "Dāvis Bertāns"
# 3 results found.
# 0: Davis Bertans
# 1: Dairis Bertans
# 2: David Burns
# Pick one: 0
# Results for Davis Bertans:
#
# You searched for "Isaac Bonga"
# 2 results found.
# 0: Isaac Bonga
# 1: Isaac Okoro
# Pick one: 0
# Results for Isaac Bonga:
#
# You searched for "Thomas Bryant"
# 2 results found.
# 0: Thomas Bryant
# 1: Thomas Jordan
# Pick one: 0
# Results for Thomas Bryant:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# ...

# %% [markdown]
# ## combine all seasons

# %%
WAS_2000_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2000_games.csv')
WAS_2001_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2001_games.csv')
WAS_2002_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2002_games.csv')
WAS_2003_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2003_games.csv')
WAS_2004_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2004_games.csv')
WAS_2005_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2005_games.csv')
WAS_2006_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2006_games.csv')
WAS_2007_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2007_games.csv')
WAS_2008_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2008_games.csv')
WAS_2009_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2009_games.csv')
WAS_2010_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2010_games.csv')
WAS_2011_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2011_games.csv')
WAS_2012_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2012_games.csv')
WAS_2013_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2013_games.csv')
WAS_2014_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2014_games.csv')
WAS_2015_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2015_games.csv')
WAS_2016_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2016_games.csv')
WAS_2017_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2017_games.csv')
WAS_2018_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2018_games.csv')
WAS_2019_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2019_games.csv')
WAS_2020_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2020_games.csv')
WAS_2021_games_io = pd.read_csv('/Users/brendan/Desktop/Python/NBA_API/WAS/WAS_2021_games.csv')

# %%
WAS_season_dfs = [WAS_2000_games_io, WAS_2001_games_io, WAS_2002_games_io, WAS_2003_games_io, WAS_2004_games_io, WAS_2005_games_io,
                 WAS_2006_games_io, WAS_2007_games_io, WAS_2008_games_io, WAS_2009_games_io, WAS_2010_games_io, WAS_2011_games_io,
                 WAS_2012_games_io, WAS_2013_games_io, WAS_2014_games_io, WAS_2015_games_io, WAS_2016_games_io, WAS_2017_games_io,
                 WAS_2018_games_io, WAS_2019_games_io, WAS_2020_games_io, WAS_2021_games_io]

# %%
WAS_all = pd.concat(WAS_season_dfs)
WAS_all_sorted = WAS_all.sort_values(by=['GAME_SCORE'], ascending=False)
WAS_all_sorted.head(25)
# Out:
#          DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT  GS     MP  FG  FGA  \
# 0  2006-12-17  24-345  WAS      AWAY      LAL   W (+6)   1  49:00  17   32
# 0  2021-01-06  27-192  WAS      AWAY      PHI   L (-5)   1  38:15  20   35
# 0  2006-02-25  24-050  WAS      HOME      NYK  W (+21)   1  30:16  13   16
# 0  2019-10-30  26-124  WAS      HOME      HOU   L (-1)   1  40:30  14   20
# 0  2013-03-25  22-200  WAS      HOME      MEM  W (+13)   1  44:33  13   22
# 0  2016-12-06  26-091  WAS      HOME      ORL   L (-8)   1  42:18  18   31
# 1  2006-11-18  24-316  WAS      HOME      CLE  W (+12)   1  39:18  14   22
# 1  2016-11-09  23-159  WAS      HOME      BOS  W (+25)   1  38:16  14   19
# 0  2019-02-22  25-239  WAS      AWAY      CHO  L (-13)   1  41:58  16   25
# 1  2021-05-08  27-314  WAS      AWAY      IND   W (+1)   1  39:27  19   31
# 2  2007-01-15  25-009  WAS      HOME      UTA   W (+3)   1  41:19  14   29
# ...
