# %%
import pandas as pd
import numpy as np

# %%
df_t0 = pd.DataFrame(np.random.randint(5,1000, size=(100,5)),columns=(['Price','Market Cap', 'Price Target','Date', '% YTD']))

min_date = pd.to_datetime('2021-10-30')
max_date = pd.to_datetime('2022-01-1')

d = (max_date - min_date).days + 1

# %%
df_t0['Price'] = np.random.randint(25,1000, size=len(df_t0))
df_t0['Market Cap'] = np.random.randint(500,50000, size=len(df_t0))
df_t0['% YTD'] = np.random.randint(-10,70, size=len(df_t0))
df_t0['Date'] = min_date + pd.to_timedelta(pd.np.random.randint(d,size=len(df_t0)), unit='d')
# Out:
# <ipython-input-140-88b9bda54361>:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df_t0['Date'] = min_date + pd.to_timedelta(pd.np.random.randint(d,size=len(df_t0)), unit='d')

# %%
df_t0 = df_t0.reset_index().head()

# %%
df_t1 = pd.DataFrame(np.random.randint(5,1000, size=(100,5)),columns=(['Price','Market Cap', 'Price Target','Date', '% YTD']))

min_date = pd.to_datetime('2021-01-02')
max_date = pd.to_datetime('2022-01-13')

d = (max_date - min_date).days + 1

df_t1['Price'] = np.random.randint(25,1000, size=len(df_t1))
df_t1['Market Cap'] = np.random.randint(500,50000, size=len(df_t1))
df_t1['% YTD'] = np.random.randint(-10,70, size=len(df_t1))
df_t1['Date'] = min_date + pd.to_timedelta(pd.np.random.randint(d,size=len(df_t1)), unit='d')
# Out:
# <ipython-input-142-a473188663aa>:11: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df_t1['Date'] = min_date + pd.to_timedelta(pd.np.random.randint(d,size=len(df_t1)), unit='d')

# %%
df_t1 = df_t1.reset_index().head()

# %%
comparison_vals = df_t0.values == df_t1.values
row,cols = np.where(comparison_vals ==False )
for item in zip(row,cols):
    df_t1.iloc[item[0], item[1]] = '{} {}'.format(df_t0.iloc[item[0],item[1]], df_t1.iloc[item[0],item[1]])

# %%
df_t0.head()
# Out:
#    index  Price  Market Cap  Price Target       Date  % YTD
# 0      0    234       10062           729 2021-12-30     -8
# 1      1    800        6143           488 2021-11-11     55
# 2      2    939        6057           440 2021-11-27     -8
# 3      3    212       17010           987 2021-11-23     -9
# 4      4    551        5459           690 2021-12-21     10

# %%
df_t1.head()
# Out:
#    index    Price   Market Cap Price Target  \
# 0      0  234 452  10062 43848      729 757
# 1      1  800 603   6143 48845      488 377
# 2      2  939 245   6057 23358      440 534
# 3      3  212 443  17010 24823      987 138
# 4      4  551 872    5459 3256      690 538
#
#                                       Date  % YTD
# 0  2021-12-30 00:00:00 2021-07-21 00:00:00  -8 -7
# 1  2021-11-11 00:00:00 2021-01-23 00:00:00   55 6
# 2  2021-11-27 00:00:00 2021-06-03 00:00:00  -8 33
# 3  2021-11-23 00:00:00 2021-01-04 00:00:00  -9 26
# 4  2021-12-21 00:00:00 2021-04-29 00:00:00   10 2

# %%
dfs = pd.concat([df_t0, df_t1])
dfs
# Out:
#    index    Price   Market Cap Price Target  \
# 0      0      234        10062          729
# 1      1      800         6143          488
# 2      2      939         6057          440
# 3      3      212        17010          987
# 4      4      551         5459          690
# 0      0  234 452  10062 43848      729 757
# 1      1  800 603   6143 48845      488 377
# 2      2  939 245   6057 23358      440 534
# 3      3  212 443  17010 24823      987 138
# 4      4  551 872    5459 3256      690 538
#
#                                       Date  % YTD
# 0                      2021-12-30 00:00:00     -8
# 1                      2021-11-11 00:00:00     55
# 2                      2021-11-27 00:00:00     -8
# 3                      2021-11-23 00:00:00     -9
# 4                      2021-12-21 00:00:00     10
# 0  2021-12-30 00:00:00 2021-07-21 00:00:00  -8 -7
# 1  2021-11-11 00:00:00 2021-01-23 00:00:00   55 6
# 2  2021-11-27 00:00:00 2021-06-03 00:00:00  -8 33
# 3  2021-11-23 00:00:00 2021-01-04 00:00:00  -9 26
# 4  2021-12-21 00:00:00 2021-04-29 00:00:00   10 2

# %%
df_t0.compare(df_t1).head()
# Out:
#   Price          Market Cap              Price Target                Date  \
#    self    other       self        other         self    other       self
# 0   234  234 452      10062  10062 43848          729  729 757 2021-12-30
# 1   800  800 603       6143   6143 48845          488  488 377 2021-11-11
# 2   939  939 245       6057   6057 23358          440  440 534 2021-11-27
# 3   212  212 443      17010  17010 24823          987  987 138 2021-11-23
# 4   551  551 872       5459    5459 3256          690  690 538 2021-12-21
#
#                                            % YTD
#                                      other  self  other
# 0  2021-12-30 00:00:00 2021-07-21 00:00:00    -8  -8 -7
# 1  2021-11-11 00:00:00 2021-01-23 00:00:00    55   55 6
# 2  2021-11-27 00:00:00 2021-06-03 00:00:00    -8  -8 33
# 3  2021-11-23 00:00:00 2021-01-04 00:00:00    -9  -9 26
# 4  2021-12-21 00:00:00 2021-04-29 00:00:00    10   10 2

# %%
df_t0.compare(df_t1, align_axis='index').head()
# Out:
#            Price   Market Cap Price Target  \
# 0 self       234        10062          729
#   other  234 452  10062 43848      729 757
# 1 self       800         6143          488
#   other  800 603   6143 48845      488 377
# 2 self       939         6057          440
#
#                                             Date  % YTD
# 0 self                       2021-12-30 00:00:00     -8
#   other  2021-12-30 00:00:00 2021-07-21 00:00:00  -8 -7
# 1 self                       2021-11-11 00:00:00     55
#   other  2021-11-11 00:00:00 2021-01-23 00:00:00   55 6
# 2 self                       2021-11-27 00:00:00     -8

# %%
dictionary = {1:df_t0,2:df_t1}
df_combined=pd.concat(dictionary)
df_combined.drop_duplicates(keep=False).head()
# Out:
#      index Price Market Cap Price Target                 Date % YTD
# 1 0      0   234      10062          729  2021-12-30 00:00:00    -8
#   1      1   800       6143          488  2021-11-11 00:00:00    55
#   2      2   939       6057          440  2021-11-27 00:00:00    -8
#   3      3   212      17010          987  2021-11-23 00:00:00    -9
#   4      4   551       5459          690  2021-12-21 00:00:00    10

# %%
df_t0.compare(df_t1, align_axis=0).head()
# Out:
#            Price   Market Cap Price Target  \
# 0 self       234        10062          729
#   other  234 452  10062 43848      729 757
# 1 self       800         6143          488
#   other  800 603   6143 48845      488 377
# 2 self       939         6057          440
#
#                                             Date  % YTD
# 0 self                       2021-12-30 00:00:00     -8
#   other  2021-12-30 00:00:00 2021-07-21 00:00:00  -8 -7
# 1 self                       2021-11-11 00:00:00     55
#   other  2021-11-11 00:00:00 2021-01-23 00:00:00   55 6
# 2 self                       2021-11-27 00:00:00     -8

# %%
df_all = pd.concat([df_t0.set_index('index'),df_t1.set_index('index')],axis='columns', keys=['First','Second'])
df_all.head()
# Out:
#       First                                            Second               \
#       Price Market Cap Price Target       Date % YTD    Price   Market Cap
# index
# 0       234      10062          729 2021-12-30    -8  234 452  10062 43848
# 1       800       6143          488 2021-11-11    55  800 603   6143 48845
# 2       939       6057          440 2021-11-27    -8  939 245   6057 23358
# 3       212      17010          987 2021-11-23    -9  212 443  17010 24823
# 4       551       5459          690 2021-12-21    10  551 872    5459 3256
#
#
#       Price Target                                     Date  % YTD
# index
# 0          729 757  2021-12-30 00:00:00 2021-07-21 00:00:00  -8 -7
# 1          488 377  2021-11-11 00:00:00 2021-01-23 00:00:00   55 6
# 2          440 534  2021-11-27 00:00:00 2021-06-03 00:00:00  -8 33
# 3          987 138  2021-11-23 00:00:00 2021-01-04 00:00:00  -9 26
# 4          690 538  2021-12-21 00:00:00 2021-04-29 00:00:00   10 2

# %%
df_final = df_all.swaplevel(axis='columns')[df.columns[1:]]
df_final
# Out:
#       Market Cap              Price Target                Date  \
#            First       Second        First   Second      First
# index
# 0          10062  10062 43848          729  729 757 2021-12-30
# 1           6143   6143 48845          488  488 377 2021-11-11
# 2           6057   6057 23358          440  440 534 2021-11-27
# 3          17010  17010 24823          987  987 138 2021-11-23
# 4           5459    5459 3256          690  690 538 2021-12-21
#
#                                                % YTD
#                                         Second First Second
# index
# 0      2021-12-30 00:00:00 2021-07-21 00:00:00    -8  -8 -7
# 1      2021-11-11 00:00:00 2021-01-23 00:00:00    55   55 6
# 2      2021-11-27 00:00:00 2021-06-03 00:00:00    -8  -8 33
# 3      2021-11-23 00:00:00 2021-01-04 00:00:00    -9  -9 26
# 4      2021-12-21 00:00:00 2021-04-29 00:00:00    10   10 2

# %%
def highlight_diff(data, color='coral'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('First', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

df_final.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# #T_cbaf5_row0_col1, #T_cbaf5_row0_col3, #T_cbaf5_row0_col5, #T_cbaf5_row0_col7, #T_cbaf5_row1_col1, #T_cbaf5_row1_col3, #T_cbaf5_row1_col5, #T_cbaf5_row1_col7, #T_cbaf5_row2_col1, #T_cbaf5_row2_col3, #T_cbaf5_row2_col5, #T_cbaf5_row2_col7, #T_cbaf5_row3_col1, #T_cbaf5_row3_col3, #T_cbaf5_row3_col5, #T_cbaf5_row3_col7, #T_cbaf5_row4_col1, #T_cbaf5_row4_col3, #T_cbaf5_row4_col5, #T_cbaf5_row4_col7 {
#   background-color: coral;
# }
# </style>
# <table id="T_cbaf5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Market Cap</th>
#       <th class="col_heading level0 col2" colspan="2">Price Target</th>
#       <th class="col_heading level0 col4" colspan="2">Date</th>
#       <th class="col_heading level0 col6" colspan="2">% YTD</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >First</th>
#       <th class="col_heading level1 col1" >Second</th>
#       <th class="col_heading level1 col2" >First</th>
#       <th class="col_heading level1 col3" >Second</th>
#       <th class="col_heading level1 col4" >First</th>
#       <th class="col_heading level1 col5" >Second</th>
#       <th class="col_heading level1 col6" >First</th>
#       <th class="col_heading level1 col7" >Second</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbaf5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbaf5_row0_col0" class="data row0 col0" >10062</td>
#       <td id="T_cbaf5_row0_col1" class="data row0 col1" >10062 43848</td>
#       <td id="T_cbaf5_row0_col2" class="data row0 col2" >729</td>
#       <td id="T_cbaf5_row0_col3" class="data row0 col3" >729 757</td>
#       <td id="T_cbaf5_row0_col4" class="data row0 col4" >2021-12-30 00:00:00</td>
#       <td id="T_cbaf5_row0_col5" class="data row0 col5" >2021-12-30 00:00:00 2021-07-21 00:00:00</td>
#       <td id="T_cbaf5_row0_col6" class="data row0 col6" >-8</td>
#       <td id="T_cbaf5_row0_col7" class="data row0 col7" >-8 -7</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbaf5_row1_col0" class="data row1 col0" >6143</td>
#       <td id="T_cbaf5_row1_col1" class="data row1 col1" >6143 48845</td>
#       <td id="T_cbaf5_row1_col2" class="data row1 col2" >488</td>
#       <td id="T_cbaf5_row1_col3" class="data row1 col3" >488 377</td>
#       <td id="T_cbaf5_row1_col4" class="data row1 col4" >2021-11-11 00:00:00</td>
#       <td id="T_cbaf5_row1_col5" class="data row1 col5" >2021-11-11 00:00:00 2021-01-23 00:00:00</td>
#       <td id="T_cbaf5_row1_col6" class="data row1 col6" >55</td>
#       <td id="T_cbaf5_row1_col7" class="data row1 col7" >55 6</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbaf5_row2_col0" class="data row2 col0" >6057</td>
#       <td id="T_cbaf5_row2_col1" class="data row2 col1" >6057 23358</td>
#       <td id="T_cbaf5_row2_col2" class="data row2 col2" >440</td>
#       <td id="T_cbaf5_row2_col3" class="data row2 col3" >440 534</td>
#       <td id="T_cbaf5_row2_col4" class="data row2 col4" >2021-11-27 00:00:00</td>
#       <td id="T_cbaf5_row2_col5" class="data row2 col5" >2021-11-27 00:00:00 2021-06-03 00:00:00</td>
#       <td id="T_cbaf5_row2_col6" class="data row2 col6" >-8</td>
#       <td id="T_cbaf5_row2_col7" class="data row2 col7" >-8 33</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbaf5_row3_col0" class="data row3 col0" >17010</td>
#       <td id="T_cbaf5_row3_col1" class="data row3 col1" >17010 24823</td>
#       <td id="T_cbaf5_row3_col2" class="data row3 col2" >987</td>
#       <td id="T_cbaf5_row3_col3" class="data row3 col3" >987 138</td>
#       <td id="T_cbaf5_row3_col4" class="data row3 col4" >2021-11-23 00:00:00</td>
#       <td id="T_cbaf5_row3_col5" class="data row3 col5" >2021-11-23 00:00:00 2021-01-04 00:00:00</td>
#       <td id="T_cbaf5_row3_col6" class="data row3 col6" >-9</td>
#       <td id="T_cbaf5_row3_col7" class="data row3 col7" >-9 26</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbaf5_row4_col0" class="data row4 col0" >5459</td>
#       <td id="T_cbaf5_row4_col1" class="data row4 col1" >5459 3256</td>
#       <td id="T_cbaf5_row4_col2" class="data row4 col2" >690</td>
#       <td id="T_cbaf5_row4_col3" class="data row4 col3" >690 538</td>
#       <td id="T_cbaf5_row4_col4" class="data row4 col4" >2021-12-21 00:00:00</td>
#       <td id="T_cbaf5_row4_col5" class="data row4 col5" >2021-12-21 00:00:00 2021-04-29 00:00:00</td>
#       <td id="T_cbaf5_row4_col6" class="data row4 col6" >10</td>
#       <td id="T_cbaf5_row4_col7" class="data row4 col7" >10 2</td>
#     </tr>
#   </tbody>
# </table>
