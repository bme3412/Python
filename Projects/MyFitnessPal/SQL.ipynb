# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import mysql.connector
import matplotlib.pyplot as plt

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Boston1429$$"
)

print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x7fddd82cdc70>

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM MyFitnessPal.food_12_01")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
df_12_01 = pd.DataFrame(myresult, columns=['Date', 'Meal', 'Food', 'Calories', 'Carbs','Fat','Protein','Sodium','Sugar'])
df_12_01
# Out:
# (datetime.date(2021, 12, 1), 'Breakfast', 'Oat Milk, Dark Chocolate, 1 cup', 140, 31, 2, 3, 135, 12)
# (datetime.date(2021, 12, 1), 'Breakfast', 'Oat Milk, Dark Chocolate, 1 cup', 140, 31, 2, 3, 135, 12)
# (datetime.date(2021, 12, 1), 'Breakfast', 'banana', 105, 27, 0, 1, 1, 14)
# (datetime.date(2021, 12, 1), 'Breakfast', 'Noosa - vanilla bean, 8 oz', 280, 32, 12, 12, 130, 32)
# (datetime.date(2021, 12, 1), 'Breakfast', 'Blueberries - 0.5 cup', 42, 11, 0, 1, 1, 7)
# (datetime.date(2021, 12, 1), 'Lunch', 'Josephs - Avocado Hummus, 2 tbsp', 60, 3, 5, 1, 105, 0)
# (datetime.date(2021, 12, 1), 'Lunch', 'Baby Carrots, 10 carrots', 36, 8, 0, 1, 4, 5)
# (datetime.date(2021, 12, 1), 'Lunch', 'Blueberries, 1 cup', 84, 21, 0, 1, 1, 15)
# (datetime.date(2021, 12, 1), 'Lunch', 'Oat Milk, Dark Chocolate, 1 cup', 140, 31, 2, 3, 135, 12)
# (datetime.date(2021, 12, 1), 'Dinner', 'Cucumber, 0.25 cucumber', 11, 3, 0, 0, 2, 1)
# (datetime.date(2021, 12, 1), 'Dinner', 'Green bell pepper, 0.5 medium', 12, 3, 0, 1, 2, 1)
# (datetime.date(2021, 12, 1), 'Dinner', 'tomato, 0.5 medium', 13, 3, 0, 1, 10, 2)
# (datetime.date(2021, 12, 1), 'Dinner', 'Green leaf lettuce, 1 cup', 5, 1, 0, 0, 10, 0)
# (datetime.date(2021, 12, 1), 'Dinner', 'Weaver chicken breast nuggets, 4', 190, 12, 11, 10, 630, 0)
# (datetime.date(2021, 12, 1), 'Dinner', 'Kens steakhouse caesar, 2 tbsp', 170, 1, 18, 1, 250, 1)
# (datetime.date(2021, 12, 1), 'Dinner', 'avocado', 240, 13, 22, 3, 11, 1)
# (datetime.date(2021, 12, 1), 'Snacks', 'roasted cashews - 10', 51, 3, 1, 2, 3, 1)
#           Date       Meal                              Food  Calories  Carbs  \
# 0   2021-12-01  Breakfast   Oat Milk, Dark Chocolate, 1 cup       140     31
# 1   2021-12-01  Breakfast   Oat Milk, Dark Chocolate, 1 cup       140     31
# 2   2021-12-01  Breakfast                            banana       105     27
# 3   2021-12-01  Breakfast        Noosa - vanilla bean, 8 oz       280     32
# 4   2021-12-01  Breakfast             Blueberries - 0.5 cup        42     11
# 5   2021-12-01      Lunch  Josephs - Avocado Hummus, 2 tbsp        60      3
# 6   2021-12-01      Lunch          Baby Carrots, 10 carrots        36      8
# 7   2021-12-01      Lunch                Blueberries, 1 cup        84     21
# 8   2021-12-01      Lunch   Oat Milk, Dark Chocolate, 1 cup       140     31
# 9   2021-12-01     Dinner           Cucumber, 0.25 cucumber        11      3
# 10  2021-12-01     Dinner     Green bell pepper, 0.5 medium        12      3
# 11  2021-12-01     Dinner                tomato, 0.5 medium        13      3
# 12  2021-12-01     Dinner         Green leaf lettuce, 1 cup         5      1
# 13  2021-12-01     Dinner  Weaver chicken breast nuggets, 4       190     12
# 14  2021-12-01     Dinner    Kens steakhouse caesar, 2 tbsp       170      1
# 15  2021-12-01     Dinner                           avocado       240     13
# 16  2021-12-01     Snacks              roasted cashews - 10        51      3
#
#     Fat  Protein  Sodium  Sugar
# 0     2        3     135     12
# 1     2        3     135     12
# 2     0        1       1     14
# 3    12       12     130     32
# 4     0        1       1      7
# 5     5        1     105      0
# 6     0        1       4      5
# 7     0        1       1     15
# 8     2        3     135     12
# 9     0        0       2      1
# 10    0        1       2      1
# 11    0        1      10      2
# 12    0        0      10      0
# 13   11       10     630      0
# 14   18        1     250      1
# 15   22        3      11      1
# 16    1        2       3      1

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM MyFitnessPal.food_12_02")

myresult_12_02 = mycursor.fetchall()


df_12_02 = pd.DataFrame(myresult_12_02, columns=['Date', 'Meal', 'Food', 'Calories', 'Carbs','Fat','Protein','Sodium','Sugar'])
df_12_02
# Out:
#          Date       Meal                          Food  Calories  Carbs  Fat  \
# 0  2021-12-02  Breakfast    Noosa - vanilla bean, 8 oz       280     32   12
# 1  2021-12-02  Breakfast         Raspberries - 0.5 cup        32      7    0
# 2  2021-12-02      Lunch  Yogurt Fruit Granole Parfait       260     53    2
# 3  2021-12-02     Dinner      Cheese Lovers Tortelloni       810    108   30
# 4  2021-12-02     Snacks   Roasted Cashews - 10 pieces       101      6    2
# 5  2021-12-02     Snacks   Roasted Cashews - 10 pieces       101      6    2
#
#    Protein  Sodium  Sugar
# 0       12     130     32
# 1        1       1      3
# 2        7     150     46
# 3       33    1560      3
# 4        3       5      1
# 5        3       5      1

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM MyFitnessPal.food_12_03")

myresult_12_03 = mycursor.fetchall()


df_12_03 = pd.DataFrame(myresult_12_03, columns=['Date', 'Meal', 'Food', 'Calories', 'Carbs','Fat','Protein','Sodium','Sugar'])
df_12_03
# Out:
#          Date       Meal                                Food  Calories  Carbs  \
# 0  2021-12-03  Breakfast               Raspberries - 0.5 cup        32      7
# 1  2021-12-03  Breakfast                              banana       105     27
# 2  2021-12-03      Lunch             Sicilian pizza, 1 slice       319     43
# 3  2021-12-03      Lunch             Sicilian pizza, 1 slice       319     43
# 4  2021-12-03      Lunch             Sicilian pizza, 1 slice       319     43
# 5  2021-12-03      Lunch                            Arancini       380     43
# 6  2021-12-03     Dinner  Trader Joes - Chicken Drumellas, 8       380     24
# 7  2021-12-03      Snack                  Blueberries, 1 cup        84     21
# 8  2021-12-03      Snack                         Iced Coffee         5      0
# 9  2021-12-03      Snack                         Iced Coffee         5      0
#
#    Fat  Protein  Sodium  Sugar
# 0    0        1       1      3
# 1    0        1       1     14
# 2   11       12     668      0
# 3   11       12     668      0
# 4   11       12     668      0
# 5   17       12     458      6
# 6   18       30     480      0
# 7    0        1       1     15
# 8    0        1       9      0
# 9    0        1       9      0

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM MyFitnessPal.food_12_04")

myresult_12_04 = mycursor.fetchall()


df_12_04 = pd.DataFrame(myresult_12_04, columns=['Date', 'Meal', 'Food', 'Calories', 'Carbs','Fat','Protein','Sodium','Sugar'])
df_12_04
# Out:
#          Date       Meal                             Food  Calories  Carbs  \
# 0  2021-12-04  Breakfast                           banana       105     27
# 1  2021-12-04      Lunch        Anerican cheese, 2 slices       208      2
# 2  2021-12-04      Lunch        Anerican cheese, 2 slices       208      2
# 3  2021-12-04      Lunch          Oat Nut bread, 2 slices       220     36
# 4  2021-12-04      Lunch          Oat Nut bread, 2 slices       220     36
# 5  2021-12-04     Dinner  Trader Joes - chicken chow mein       400     78
# 6  2021-12-04     Snacks                           banana       105     27
# 7  2021-12-04     Snacks         protein powder, 0.25 cup        33      6
#
#    Fat  Protein  Sodium  Sugar
# 0    0        1       1     14
# 1    9       10     936      2
# 2    9       10     936      2
# 3    4        8     260      6
# 4    4        8     260      6
# 5    3       18    1920     12
# 6    0        1       1     14
# 7    1       22       0      2

# %% [markdown]
# ## Append all dataframes for week 1

# %%
df_week1 = pd.concat([df_12_01, df_12_02, df_12_03, df_12_04])
df_week1
# Out:
#           Date       Meal                                Food  Calories  \
# 0   2021-12-01  Breakfast     Oat Milk, Dark Chocolate, 1 cup       140
# 1   2021-12-01  Breakfast     Oat Milk, Dark Chocolate, 1 cup       140
# 2   2021-12-01  Breakfast                              banana       105
# 3   2021-12-01  Breakfast          Noosa - vanilla bean, 8 oz       280
# 4   2021-12-01  Breakfast               Blueberries - 0.5 cup        42
# 5   2021-12-01      Lunch    Josephs - Avocado Hummus, 2 tbsp        60
# 6   2021-12-01      Lunch            Baby Carrots, 10 carrots        36
# 7   2021-12-01      Lunch                  Blueberries, 1 cup        84
# 8   2021-12-01      Lunch     Oat Milk, Dark Chocolate, 1 cup       140
# 9   2021-12-01     Dinner             Cucumber, 0.25 cucumber        11
# 10  2021-12-01     Dinner       Green bell pepper, 0.5 medium        12
# 11  2021-12-01     Dinner                  tomato, 0.5 medium        13
# 12  2021-12-01     Dinner           Green leaf lettuce, 1 cup         5
# 13  2021-12-01     Dinner    Weaver chicken breast nuggets, 4       190
# 14  2021-12-01     Dinner      Kens steakhouse caesar, 2 tbsp       170
# 15  2021-12-01     Dinner                             avocado       240
# 16  2021-12-01     Snacks                roasted cashews - 10        51
# 0   2021-12-02  Breakfast          Noosa - vanilla bean, 8 oz       280
# 1   2021-12-02  Breakfast               Raspberries - 0.5 cup        32
# 2   2021-12-02      Lunch        Yogurt Fruit Granole Parfait       260
# 3   2021-12-02     Dinner            Cheese Lovers Tortelloni       810
# 4   2021-12-02     Snacks         Roasted Cashews - 10 pieces       101
# 5   2021-12-02     Snacks         Roasted Cashews - 10 pieces       101
# 0   2021-12-03  Breakfast               Raspberries - 0.5 cup        32
# 1   2021-12-03  Breakfast                              banana       105
# 2   2021-12-03      Lunch             Sicilian pizza, 1 slice       319
# 3   2021-12-03      Lunch             Sicilian pizza, 1 slice       319
# 4   2021-12-03      Lunch             Sicilian pizza, 1 slice       319
# 5   2021-12-03      Lunch                            Arancini       380
# 6   2021-12-03     Dinner  Trader Joes - Chicken Drumellas, 8       380
# 7   2021-12-03      Snack                  Blueberries, 1 cup        84
# 8   2021-12-03      Snack                         Iced Coffee         5
# 9   2021-12-03      Snack                         Iced Coffee         5
# 0   2021-12-04  Breakfast                              banana       105
# 1   2021-12-04      Lunch           Anerican cheese, 2 slices       208
# 2   2021-12-04      Lunch           Anerican cheese, 2 slices       208
# 3   2021-12-04      Lunch             Oat Nut bread, 2 slices       220
# 4   2021-12-04      Lunch             Oat Nut bread, 2 slices       220
# 5   2021-12-04     Dinner     Trader Joes - chicken chow mein       400
# 6   2021-12-04     Snacks                              banana       105
# 7   2021-12-04     Snacks            protein powder, 0.25 cup        33
#
#     Carbs  Fat  Protein  Sodium  Sugar
# 0      31    2        3     135     12
# 1      31    2        3     135     12
# 2      27    0        1       1     14
# 3      32   12       12     130     32
# 4      11    0        1       1      7
# 5       3    5        1     105      0
# 6       8    0        1       4      5
# 7      21    0        1       1     15
# 8      31    2        3     135     12
# 9       3    0        0       2      1
# 10      3    0        1       2      1
# 11      3    0        1      10      2
# 12      1    0        0      10      0
# 13     12   11       10     630      0
# 14      1   18        1     250      1
# 15     13   22        3      11      1
# 16      3    1        2       3      1
# 0      32   12       12     130     32
# 1       7    0        1       1      3
# 2      53    2        7     150     46
# 3     108   30       33    1560      3
# 4       6    2        3       5      1
# 5       6    2        3       5      1
# 0       7    0        1       1      3
# 1      27    0        1       1     14
# 2      43   11       12     668      0
# 3      43   11       12     668      0
# 4      43   11       12     668      0
# 5      43   17       12     458      6
# 6      24   18       30     480      0
# 7      21    0        1       1     15
# 8       0    0        1       9      0
# 9       0    0        1       9      0
# 0      27    0        1       1     14
# 1       2    9       10     936      2
# 2       2    9       10     936      2
# 3      36    4        8     260      6
# 4      36    4        8     260      6
# 5      78    3       18    1920     12
# 6      27    0        1       1     14
# 7       6    1       22       0      2

# %% [markdown]
# ## Week 2

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM MyFitnessPal.food_12_05")

myresult_12_05 = mycursor.fetchall()
df_12_05 = pd.DataFrame(myresult_12_05, columns=['Date', 'Meal', 'Food', 'Calories', 'Carbs','Fat','Protein','Sodium','Sugar'])
df_12_05
# Out:
#           Date       Meal                                   Food  Calories  \
# 0   2021-12-05  Breakfast                                 banana       105
# 1   2021-12-05      Lunch                     Blueberries, 1 cup        84
# 2   2021-12-05      Lunch                  Raspberries - 0.5 cup        32
# 3   2021-12-05      Lunch                       baby carrots, 15        54
# 4   2021-12-05      Lunch       Josephs - avocado hummus, 2 tbsp        60
# 5   2021-12-05     Dinner               Cheese Lovers Tortelloni       810
# 6   2021-12-05     Snacks            Roasted Cashews - 10 pieces       101
# 7   2021-12-05     Snacks  Aurora cranberry health mix, 0.25 cup       145
# 8   2021-12-05     Snacks                   Dired Kiwi, 4 pieces       110
# 9   2021-12-05     Snacks        Oat Milk, Dark Chocolate, 1 cup       140
# 10  2021-12-05     Snacks        Oat Milk, Dark Chocolate, 1 cup       140
#
#     Carbs  Fat  Protein  Sodium  Sugar
# 0      27    0        1       1     14
# 1      21    0        1       1     15
# 2       7    0        1       1      3
# 3      12    0        1       6      7
# 4       3    5        1     105      0
# 5     108   30       33    1560      3
# 6       6    2        3       5      1
# 7      21    7        3       3     13
# 8      25    0        1       0     15
# 9      31    2        3     135     12
# 10     31    2        3     135     12

# %%
df_week1.head()
# Out:
#          Date       Meal                             Food  Calories  Carbs  \
# 0  2021-12-01  Breakfast  Oat Milk, Dark Chocolate, 1 cup       140     31
# 1  2021-12-01  Breakfast  Oat Milk, Dark Chocolate, 1 cup       140     31
# 2  2021-12-01  Breakfast                           banana       105     27
# 3  2021-12-01  Breakfast       Noosa - vanilla bean, 8 oz       280     32
# 4  2021-12-01  Breakfast            Blueberries - 0.5 cup        42     11
#
#    Fat  Protein  Sodium  Sugar
# 0    2        3     135     12
# 1    2        3     135     12
# 2    0        1       1     14
# 3   12       12     130     32
# 4    0        1       1      7
