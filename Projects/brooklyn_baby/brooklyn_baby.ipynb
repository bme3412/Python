# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('Traffic_Volume_Counts_2014-2019_.csv')
file.head()
# Out:
#    ID  Segment ID            Roadway Name             From                To  \
# 0   2       70376                3 Avenue  East 154 Street   East 155 Street
# 1   2       70376                3 Avenue  East 155 Street   East 154 Street
# 2  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 3  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 4  62      147673                Broadway  West 242 Street        240 Street
#
#   Direction        Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 0        NB  09/13/2014          204.0        177.0        133.0  ...
# 1        SB  09/13/2014          140.0         51.0        128.0  ...
# 2        EB  09/13/2014           94.0         73.0         65.0  ...
# 3        WB  09/13/2014           88.0         82.0         75.0  ...
# 4        SB  09/13/2014          255.0        209.0        149.0  ...
#
#    2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  \
# ...

# %%
file.shape
# Out:
# (27289, 31)

# %%
file['Roadway Name'].value_counts()
# Out:
# Broadway                  387
# 3 Avenue                  198
# Southern Boulevard        184
# 3 AVENUE                  181
# Kings Highway             153
#                          ...
# BAY COURT                   9
# Woolley Avenue              9
# 5th AVENUE                  6
# East 170  Main Road         1
# East 170  Service Road      1
# Name: Roadway Name, Length: 889, dtype: int64

# %%
file[file['From'].str.startswith('Ocean')][['From','To']].head()
# Out:
#                From              To
# 1356  Ocean Terrace  Renwick Avenue
# 1582  Ocean Terrace  Renwick Avenue
# 1768  Ocean Terrace  Renwick Avenue
# 1907  Ocean Terrace  Renwick Avenue
# 2047  Ocean Terrace  Renwick Avenue

# %%
file_2 = pd.read_csv('nyc_speed_limits.csv')
file_2.head()
# Out:
#         lat1       lon1       lat2       lon2            street  speed signed  \
# 0  40.813067 -73.922943  40.813324 -73.922877  alexander avenue     25     no
# 1  40.827542 -73.916381  40.827817 -73.917223      bonner place     25     no
# 2  40.868860 -73.907224  40.868857 -73.907301     bailey avenue     25     no
# 3  40.808913 -73.894871  40.811690 -73.895601      barry street     25     no
# 4  40.811690 -73.895601  40.812074 -73.895782      barry street     25     no
#
#   region  distance
# 0  Bronx  0.018025
# 1  Bronx  0.048041
# 2  Bronx  0.004040
# 3  Bronx  0.195364
# 4  Bronx  0.028166

# %%
plt.figure(figsize=(15,15))
plt.scatter(x=file_2['lat1'], y=file_2['lon1'], ec='black')
plt.show()

# %%
file_2[file_2['street']=='church avenue']
# Out:
#            lat1       lon1       lat2       lon2         street  speed signed  \
# 4068  40.640997 -73.983868  40.641229 -73.983294  church avenue     25    yes
# 4069  40.652279 -73.920747  40.652604 -73.920210  church avenue     25    yes
# 4070  40.652604 -73.920210  40.652797 -73.919963  church avenue     25    yes
#
#         region  distance
# 4068  Brooklyn  0.034121
# 4069  Brooklyn  0.036053
# 4070  Brooklyn  0.018557

# %%
file_3 = pd.read_csv('nyc_centerline.csv')
file_3.head()
# Out:
#        id           street post_type  st_width  bike_lane bike_traf_dir  \
# 0    6110           28 AVE       AVE        35        NaN           NaN
# 1  145494  SCHERMERHORN ST        ST        50        2.0            TW
# 2   61140    ARLINGTON AVE       AVE        42        NaN           NaN
# 3   12438      QUEENS BLVD      BLVD        40        NaN           NaN
# 4   15432    ARTHUR KIL RD        RD        36        NaN           NaN
#
#   traf_dir  rw_type  start_contour  end_contour snow_pri         region  \
# 0       TW        1             13           13        H         Queens
# 1       TW        1             13           13        C       Brooklyn
# 2       TW        1             13           13        C          Bronx
# 3       TF        1             13           13        C         Queens
# 4       TW        1             13           13        C  Staten Island
#
#      length                                             points
# ...

# %%
file_3['street'] = file_3['street'].astype('string')
file_3['street'] = file_3['street'].str.lower()

# %%
file_3.head()
# Out:
#        id           street post_type  st_width  bike_lane bike_traf_dir  \
# 0    6110           28 ave       AVE        35        NaN           NaN
# 1  145494  schermerhorn st        ST        50        2.0            TW
# 2   61140    arlington ave       AVE        42        NaN           NaN
# 3   12438      queens blvd      BLVD        40        NaN           NaN
# 4   15432    arthur kil rd        RD        36        NaN           NaN
#
#   traf_dir  rw_type  start_contour  end_contour snow_pri         region  \
# 0       TW        1             13           13        H         Queens
# 1       TW        1             13           13        C       Brooklyn
# 2       TW        1             13           13        C          Bronx
# 3       TF        1             13           13        C         Queens
# 4       TW        1             13           13        C  Staten Island
#
#      length                                             points
# ...

# %%
file_3['street'].str.contains('church', na=False).value_counts()
# Out:
# False    107523
# True        130
# Name: street, dtype: Int64

# %%
file_3[file_3['street'].str.contains('church')]
# Out:
#            id      street post_type  st_width  bike_lane bike_traf_dir  \
# 1775    38509  church ave       AVE        44        NaN           NaN
# 2115    38497  church ave       AVE        44        NaN           NaN
# 2317    38445  church ave       AVE        68        NaN           NaN
# 2641    38493  church ave       AVE        44        NaN           NaN
# 3411    38510  church ave       AVE        44        NaN           NaN
# ...       ...         ...       ...       ...        ...           ...
# 103417    151   church st        ST        60        2.0            FT
# 103789    159   church st        ST        60        NaN           NaN
# 104733  38440  church ave       AVE        44        NaN           NaN
# 105407  92623   church st        ST        25        NaN           NaN
# 106146  38513  church ave       AVE        42        NaN           NaN
#
#        traf_dir  rw_type  start_contour  end_contour snow_pri     region  \
# ...
