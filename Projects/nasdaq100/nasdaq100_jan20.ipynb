# %%
import pandas as pd
import glob
import os
import seedir as sd

# %%
sd.seedir(style='lines', itemlimit=20, depthlimit=3, exclude_folders='.git')
# Out:
# nasdaq100/
# ├─2015/
# │ ├─20150514/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150513/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150721/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150717/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150728/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150710/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150522/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20150911/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ └─PCAR.csv.gz
# │ ├─20150320/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150112/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150318/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150916/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ └─PCAR.csv.gz
# │ ├─20150929/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ └─PCAR.csv.gz
# │ ├─20150115/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150327/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20151201/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20151208/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150123/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20150311/
# │ │ ├─GMCR.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─BRCM.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─EQIX.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ └─20151005/
# │   ├─GMCR.csv.gz
# │   ├─FISV.csv.gz
# │   ├─REGN.csv.gz
# │   ├─JD.csv.gz
# │   ├─MDLZ.csv.gz
# │   ├─WFM.csv.gz
# │   ├─ADP.csv.gz
# │   ├─NVDA.csv.gz
# │   ├─SBAC.csv.gz
# │   ├─BRCM.csv.gz
# │   ├─CHTR.csv.gz
# │   ├─BIIB.csv.gz
# │   ├─AMAT.csv.gz
# │   ├─PAYX.csv.gz
# │   ├─SYMC.csv.gz
# │   ├─ADBE.csv.gz
# │   ├─SWKS.csv.gz
# │   ├─HSIC.csv.gz
# │   ├─ROST.csv.gz
# │   └─PCAR.csv.gz
# ├─.DS_Store
# ├─nasdaq100_jan20.ipynb
# ├─2017/
# │ ├─20171207/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170321/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170113/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20170928/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170310/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20171004/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170921/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20171003/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170317/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20170919/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170125/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20170926/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170328/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170718/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170727/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170515/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170512/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170720/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ ├─20170524/
# │ │ ├─CTRP.csv.gz
# │ │ ├─CTAS.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ ├─ESRX.csv.gz
# │ │ └─QCOM.csv.gz
# │ └─20170711/
# │   ├─CTRP.csv.gz
# │   ├─CTAS.csv.gz
# │   ├─FISV.csv.gz
# │   ├─REGN.csv.gz
# │   ├─JD.csv.gz
# │   ├─MDLZ.csv.gz
# │   ├─ADP.csv.gz
# │   ├─NVDA.csv.gz
# │   ├─CHTR.csv.gz
# │   ├─BIIB.csv.gz
# │   ├─AMAT.csv.gz
# │   ├─PAYX.csv.gz
# │   ├─SYMC.csv.gz
# │   ├─ADBE.csv.gz
# │   ├─SWKS.csv.gz
# │   ├─HSIC.csv.gz
# │   ├─ROST.csv.gz
# │   ├─PCAR.csv.gz
# │   ├─ESRX.csv.gz
# │   └─QCOM.csv.gz
# ├─2016/
# │ ├─20160711/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160523/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160524/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160729/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160512/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160720/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160727/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160718/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160926/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160328/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160317/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160125/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160919/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20161003/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20161209/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160921/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20161004/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160122/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ ├─20160310/
# │ │ ├─CTRP.csv.gz
# │ │ ├─FISV.csv.gz
# │ │ ├─REGN.csv.gz
# │ │ ├─JD.csv.gz
# │ │ ├─MDLZ.csv.gz
# │ │ ├─WFM.csv.gz
# │ │ ├─ADP.csv.gz
# │ │ ├─NVDA.csv.gz
# │ │ ├─SBAC.csv.gz
# │ │ ├─CHTR.csv.gz
# │ │ ├─BIIB.csv.gz
# │ │ ├─AMAT.csv.gz
# │ │ ├─PAYX.csv.gz
# │ │ ├─SYMC.csv.gz
# │ │ ├─ADBE.csv.gz
# │ │ ├─SWKS.csv.gz
# │ │ ├─HSIC.csv.gz
# │ │ ├─ROST.csv.gz
# │ │ ├─PCAR.csv.gz
# │ │ └─ESRX.csv.gz
# │ └─20160114/
# │   ├─CTRP.csv.gz
# │   ├─FISV.csv.gz
# │   ├─REGN.csv.gz
# │   ├─JD.csv.gz
# │   ├─MDLZ.csv.gz
# │   ├─WFM.csv.gz
# │   ├─ADP.csv.gz
# │   ├─NVDA.csv.gz
# │   ├─SBAC.csv.gz
# │   ├─CHTR.csv.gz
# │   ├─BIIB.csv.gz
# │   ├─AMAT.csv.gz
# │   ├─PAYX.csv.gz
# │   ├─SYMC.csv.gz
# │   ├─ADBE.csv.gz
# │   ├─SWKS.csv.gz
# │   ├─HSIC.csv.gz
# │   ├─ROST.csv.gz
# │   ├─PCAR.csv.gz
# │   └─ESRX.csv.gz
# └─.ipynb_checkpoints/
#   └─nasdaq100_jan20-checkpoint.ipynb

# %%
files = glob.glob('/Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/**/*.csv.gz', recursive=True)

# %%
for path, dirs, files in os.walk('/Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/'):
  print(path)
  for f in files:
    print(f)
# Out:
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/
# .DS_Store
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150514
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150513
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150721
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150717
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150728
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150710
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150522
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150911
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150320
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150112
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150318
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150916
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150929
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150115
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150327
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151201
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151208
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150123
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150311
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151005
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151230
# CTRP.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# BMRN.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# ENDP.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# EXPE.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# ULTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# MXIM.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# TMUS.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# NCLH.csv.gz
# YHOO.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151002
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150316
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150918
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150716
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150729
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150720
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150512
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150515
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150727
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150317
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151231
# CTRP.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# BMRN.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# ENDP.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# EXPE.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# ULTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# MXIM.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# TMUS.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# NCLH.csv.gz
# YHOO.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151209
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150921
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150310
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150122
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# ...
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150901
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151229
# CTRP.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# BMRN.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# ENDP.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# EXPE.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# ULTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# MXIM.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# TMUS.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# NCLH.csv.gz
# YHOO.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151211
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151023
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150105
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151015
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151218
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# PYPL.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150930
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150908
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150306
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# HSIC.csv.gz
# EQIX.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# ALTR.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# CTRX.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# DTV.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# CMCSA.csv.gz
# SIAL.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# KRFT.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz
# /Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20151012
# GMCR.csv.gz
# FISV.csv.gz
# REGN.csv.gz
# JD.csv.gz
# MDLZ.csv.gz
# WFM.csv.gz
# ADP.csv.gz
# NVDA.csv.gz
# SBAC.csv.gz
# BRCM.csv.gz
# CHTR.csv.gz
# BIIB.csv.gz
# AMAT.csv.gz
# PAYX.csv.gz
# SYMC.csv.gz
# ADBE.csv.gz
# SWKS.csv.gz
# HSIC.csv.gz
# ROST.csv.gz
# PCAR.csv.gz
# ESRX.csv.gz
# QCOM.csv.gz
# SRCL.csv.gz
# DISCK.csv.gz
# CELG.csv.gz
# EXPD.csv.gz
# ILMN.csv.gz
# MYL.csv.gz
# KHC.csv.gz
# CTSH.csv.gz
# NFLX.csv.gz
# EA.csv.gz
# CHRW.csv.gz
# BMRN.csv.gz
# VIP.csv.gz
# GILD.csv.gz
# LILAK.csv.gz
# WDC.csv.gz
# LRCX.csv.gz
# CHKP.csv.gz
# CSCO.csv.gz
# MU.csv.gz
# TXN.csv.gz
# TSLA.csv.gz
# BIDU.csv.gz
# MNST.csv.gz
# GOOGL.csv.gz
# TRIP.csv.gz
# FOX.csv.gz
# DISCA.csv.gz
# VIAB.csv.gz
# WYNN.csv.gz
# AMGN.csv.gz
# SBUX.csv.gz
# FAST.csv.gz
# AAL.csv.gz
# NXPI.csv.gz
# LILA.csv.gz
# ADI.csv.gz
# PCLN.csv.gz
# AMZN.csv.gz
# AAPL.csv.gz
# LLTC.csv.gz
# CERN.csv.gz
# INCY.csv.gz
# CMCSA.csv.gz
# LMCK.csv.gz
# DLTR.csv.gz
# VRTX.csv.gz
# LBTYA.csv.gz
# ORLY.csv.gz
# FOXA.csv.gz
# FB.csv.gz
# COST.csv.gz
# MAR.csv.gz
# NTAP.csv.gz
# ISRG.csv.gz
# WBA.csv.gz
# ALXN.csv.gz
# LVNTA.csv.gz
# GOOG.csv.gz
# INTU.csv.gz
# KLAC.csv.gz
# GRMN.csv.gz
# BBBY.csv.gz
# STX.csv.gz
# ATVI.csv.gz
# DISH.csv.gz
# TSCO.csv.gz
# AKAM.csv.gz
# QVCA.csv.gz
# ADSK.csv.gz
# SPLS.csv.gz
# MSFT.csv.gz
# CA.csv.gz
# VOD.csv.gz
# EBAY.csv.gz
# MAT.csv.gz
# CTXS.csv.gz
# LBTYK.csv.gz
# SIRI.csv.gz
# AVGO.csv.gz
# LMCA.csv.gz
# INTC.csv.gz
# XLNX.csv.gz
# YHOO.csv.gz
# CMCSK.csv.gz
# SNDK.csv.gz
# VRSK.csv.gz

# %%
AAPL = pd.read_csv('/Users/brendan/Desktop/Python/Hustle Projects/nasdaq100/2015/20150106/AAPL.csv.gz')
AAPL
# Out:
#          Date Ticker TimeBarStart   OpenBarTime  OpenBidPrice  OpenBidSize  \
# 0    20150106   AAPL        04:00  04:00:00.000           NaN          NaN
# 1    20150106   AAPL        04:01  04:01:00.000        106.00       5000.0
# 2    20150106   AAPL        04:02  04:02:00.000        106.00       5000.0
# 3    20150106   AAPL        04:03  04:03:00.000        106.01        100.0
# 4    20150106   AAPL        04:04  04:04:00.000        106.00       1500.0
# ..        ...    ...          ...           ...           ...          ...
# 956  20150106   AAPL        19:56  19:56:00.000        106.47        300.0
# 957  20150106   AAPL        19:57  19:57:00.000        106.49        300.0
# 958  20150106   AAPL        19:58  19:58:00.000        106.49        300.0
# 959  20150106   AAPL        19:59  19:59:00.000        106.55        200.0
# 960  20150106   AAPL        20:00  20:00:00.000        106.58        200.0
#
#      OpenAskPrice  OpenAskSize FirstTradeTime  FirstTradePrice  ...  \
# 0             NaN          NaN   04:00:00.015           106.50  ...
# 1          106.98        200.0            NaN              NaN  ...
# 2          106.39        200.0            NaN              NaN  ...
# 3          106.31        200.0   04:03:14.196           106.00  ...
# 4          106.31        200.0   04:04:27.903           106.00  ...
# ..            ...          ...            ...              ...  ...
# 956        106.54        400.0            NaN              NaN  ...
# 957        106.54        400.0   19:57:32.776           106.54  ...
# 958        106.54        400.0   19:58:11.531           106.54  ...
# 959        106.57        800.0   19:59:19.246           106.57  ...
# 960        106.61       1300.0            NaN              NaN  ...
#
#      FinraVolumeWeightPrice UptickVolume  DowntickVolume  RepeatUptickVolume  \
# 0                       NaN            0               0                   0
# 1                       NaN            0               0                   0
# 2                       NaN            0               0                   0
# 3                       NaN            0              10                   0
# 4                       NaN            0               0                   0
# ..                      ...          ...             ...                 ...
# 956                     NaN            0               0                   0
# 957                  106.54          100               0                   0
# 958                     NaN          164               0                1532
# 959                     NaN          700             300                   0
# 960                     NaN            0               0                   0
#
#     RepeatDowntickVolume  UnknownTickVolume  TradeToMidVolWeight  \
# 0                      0                 15              0.00000
# 1                      0                  0                  NaN
# 2                      0                  0                  NaN
# 3                   3490                  0            -15.50000
# 4                     10                  0            -15.50000
# ..                   ...                ...                  ...
# 956                    0                  0                  NaN
# 957                    0                  0                  NaN
# 958                    0                  0              2.84080
# 959                   50                  0              0.52381
# 960                    0                  0                  NaN
#
#     TradeToMidVolWeightRelative  TimeWeightBid  TimeWeightAsk
# 0                       0.00000         106.00         106.98
# 1                           NaN         106.00         106.39
# 2                           NaN         106.01         106.31
# 3                      -0.50000         106.00         106.31
# 4                      -0.50000         106.00         106.31
# ..                          ...            ...            ...
# 956                         NaN         106.49         106.54
# 957                         NaN         106.49         106.54
# 958                     0.33498         106.55         106.57
# 959                     0.26190         106.58         106.61
# 960                         NaN         106.05         106.74
#
# [961 rows x 61 columns]
