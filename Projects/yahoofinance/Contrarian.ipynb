# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.min_rows', 20)

# %%
price_df = pd.read_csv('/Users/brendan/Desktop/Python/May 2022/yf_SP500/SP500_master_df_05_26_2022.csv')

# %%
price_df = price_df.drop('Unnamed: 0', 1)
# Out:
# <ipython-input-3-4482bb1f4bcd>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   price_df = price_df.drop('Unnamed: 0', 1)

# %%
price_df.head() # price
# Out:
#                   Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0  05/26/2022 19:59:23   CSCO  1.811042e+11     194965143552         42.94
# 1  05/26/2022 19:59:23    TER  1.668672e+10      16183294976        102.37
# 2  05/26/2022 19:59:23      V           NaN     454458212352        199.03
# 3  05/26/2022 19:59:23   QRVO  1.197132e+10      13396545536        108.61
# 4  05/26/2022 19:59:23    FOX  1.842428e+10      23107883008         30.94
#
#    fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0             64.29            41.02           0.183                3.782
# 1            168.91            97.63          -0.156                4.402
# 2            252.67           186.67           0.234               16.871
# 3            201.46            98.23           0.121                2.943
# 4             40.91            28.96             NaN                1.700
#
#    enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0              12.193        3.68        2.690                      3.513243
# 1              12.537        6.45        5.309                      4.538572
# 2              23.895         NaN          NaN                           NaN
# 3               8.146       13.15        9.656                      2.629738
# 4               7.728        2.35        2.958                      1.355623
#
#    forwardPE  dividendYield
# 0  11.668478         0.0307
# 1  15.871319         0.0041
# 2        NaN         0.0075
# 3   8.259315            NaN
# 4  13.165958         0.0156

# %%
master_frame = pd.read_csv('/Users/brendan/Desktop/Python/May 2022/yf_SP500/SP500_master_df_05_26_2022.csv')

# %%
price_df.head()
# Out:
#                   Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0  05/26/2022 19:59:23   CSCO  1.811042e+11     194965143552         42.94
# 1  05/26/2022 19:59:23    TER  1.668672e+10      16183294976        102.37
# 2  05/26/2022 19:59:23      V           NaN     454458212352        199.03
# 3  05/26/2022 19:59:23   QRVO  1.197132e+10      13396545536        108.61
# 4  05/26/2022 19:59:23    FOX  1.842428e+10      23107883008         30.94
#
#    fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0             64.29            41.02           0.183                3.782
# 1            168.91            97.63          -0.156                4.402
# 2            252.67           186.67           0.234               16.871
# 3            201.46            98.23           0.121                2.943
# 4             40.91            28.96             NaN                1.700
#
#    enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0              12.193        3.68        2.690                      3.513243
# 1              12.537        6.45        5.309                      4.538572
# 2              23.895         NaN          NaN                           NaN
# 3               8.146       13.15        9.656                      2.629738
# 4               7.728        2.35        2.958                      1.355623
#
#    forwardPE  dividendYield
# 0  11.668478         0.0307
# 1  15.871319         0.0041
# 2        NaN         0.0075
# 3   8.259315            NaN
# 4  13.165958         0.0156

# %%
symbol_list = price_df['symbol'].to_list()

# %%
symbol_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
df = price_df.set_index('symbol')
def is_contrarian(symbol):
    price = df.loc[f'{symbol}', 'currentPrice']
    price_high = df.loc[f'{symbol}', 'fiftyTwoWeekHigh']
    price_low = df.loc[f'{symbol}', 'fiftyTwoWeekLow']
    price_band = (price_high - price_low)
    if price < (price_low + (.3*(price_band))):
        return f'{symbol}'
    else:
        return 'OK'

# %%
is_contrarian('LRCX')
# Out:
# 'LRCX'

# %%
contrarian_tickers = map(is_contrarian, symbol_list)
ticks = [i for i in symbol_list if is_contrarian(i) != 'OK' ]

# %%
ticks
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'SWKS',
#  'MCHP',
#  'CHTR',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'JNPR',
#  'ADSK',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'AMAT',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'TWTR',
#  'DIS',
#  'NFLX',
#  'AKAM',
#  'GOOGL',
#  'FOXA',
#  'FFIV',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'TEL',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
data = price_df[price_df['symbol'].isin(ticks)]
data
# Out:
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   05/26/2022 19:59:23   CSCO  1.811042e+11     194965143552         42.94
# 1   05/26/2022 19:59:23    TER  1.668672e+10      16183294976        102.37
# 2   05/26/2022 19:59:23      V           NaN     454458212352        199.03
# 3   05/26/2022 19:59:23   QRVO  1.197132e+10      13396545536        108.61
# 4   05/26/2022 19:59:23    FOX  1.842428e+10      23107883008         30.94
# ..                  ...    ...           ...              ...           ...
# 94  05/26/2022 19:59:23   CTSH  3.763474e+10      41370865664         70.83
# 95  05/26/2022 19:59:23     MU  7.717972e+10      73692512256         68.90
# 96  05/26/2022 19:59:23    CDW  2.174283e+10      29284814848        160.20
# 97  05/26/2022 19:59:23    CRM  1.572552e+11     178013601792        159.65
# 98  05/26/2022 19:59:23   LRCX  6.675562e+10      65261465600        474.12
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0              64.29            41.02           0.183                3.782
# 1             168.91            97.63          -0.156                4.402
# 2             252.67           186.67           0.234               16.871
# 3             201.46            98.23           0.121                2.943
# 4              40.91            28.96             NaN                1.700
# ..               ...              ...             ...                  ...
# 94             93.47            66.19           0.853                2.235
# 95             98.45            65.67           2.774                2.364
# 96            208.71           155.39          -0.050                1.407
# 97            311.75           154.55             NaN                6.720
# 98            731.85           442.53          -0.015                3.899
#
#     enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0               12.193        3.68        2.690                      3.513243
# 1               12.537        6.45        5.309                      4.538572
# 2               23.895         NaN          NaN                           NaN
# 3                8.146       13.15        9.656                      2.629738
# 4                7.728        2.35        2.958                      1.355623
# ..                 ...         ...          ...                           ...
# 94              12.357        4.52        3.545                      2.033541
# 95               4.318       11.51        6.461                      2.476169
# 96              17.594        9.11        7.116                      1.044284
# 97              58.098        4.71        1.818                      5.935952
# 98              11.775       36.65       29.588                      3.988586
#
#     forwardPE  dividendYield
# 0   11.668478         0.0307
# 1   15.871319         0.0041
# 2         NaN         0.0075
# 3    8.259315            NaN
# 4   13.165958         0.0156
# ..        ...            ...
# 94  15.670355         0.0147
# 95   5.986099         0.0056
# 96  17.585072         0.0118
# 97  33.895966            NaN
# 98  12.936425         0.0122
#
# [76 rows x 15 columns]

# %%
len(data)
# Out:
# 76

# %% [markdown]
# ## Price targets

# %%
px_target_cols = ['symbol', 'sector', 'industry','currentPrice', 'targetLowPrice', 'targetMedianPrice','numberOfAnalystOpinions',
            'targetMeanPrice', 'targetHighPrice', 'recommendationMean']

# %%
appended_data = []
for ticker in ticks:
    data = yf.Ticker(ticker)
    df = pd.DataFrame([data.info])
    px_target = df[px_target_cols]
    appended_data.append(px_target)

contrarian_df = pd.DataFrame(np.row_stack(appended_data))
contrarian_df.columns =  ['Ticker', 'Sector', 'Industry','Price', 'Low Price', 'Median Price','# of Ratings',
            'Mean Price', 'High Price', 'Avg Rating']
contrarian_df = contrarian_df[['Ticker', 'Sector', 'Industry','Price', 'Low Price', 'Median Price', 'Mean Price', 'High Price',
                 '# of Ratings', 'Avg Rating']]
contrarian_df
# Out:
#    Ticker                  Sector                             Industry  \
# 0    CSCO              Technology              Communication Equipment
# 1     TER              Technology  Semiconductor Equipment & Materials
# 2       V      Financial Services                      Credit Services
# 3    QRVO              Technology                       Semiconductors
# 4     FOX  Communication Services                        Entertainment
# 5    SWKS              Technology                       Semiconductors
# 6    MCHP              Technology                       Semiconductors
# 7    CHTR  Communication Services                        Entertainment
# 8    DISH  Communication Services                        Entertainment
# 9     APH              Technology                Electronic Components
# 10    MSI              Technology              Communication Equipment
# 11    GPN             Industrials          Specialty Business Services
# 12    WBD  Communication Services                        Entertainment
# 13    DXC              Technology      Information Technology Services
# 14   ADBE              Technology              Software—Infrastructure
# 15    NOW              Technology                 Software—Application
# 16    NWS  Communication Services                        Entertainment
# 17   ZBRA              Technology              Communication Equipment
# 18     BR              Technology      Information Technology Services
# 19    STX              Technology                    Computer Hardware
# 20    IPG  Communication Services                 Advertising Agencies
# 21   CDAY              Technology                 Software—Application
# 22   ORCL              Technology              Software—Infrastructure
# 23   INTU              Technology                 Software—Application
# 24   PAYC              Technology                 Software—Application
# 25   IPGP              Technology  Semiconductor Equipment & Materials
# 26   INTC              Technology                       Semiconductors
# 27    GLW              Technology                Electronic Components
# 28    TXN              Technology                       Semiconductors
# 29   JNPR              Technology              Communication Equipment
# 30   ADSK              Technology                 Software—Application
# 31   LUMN  Communication Services                     Telecom Services
# 32   PYPL      Financial Services                      Credit Services
# 33   MSFT              Technology              Software—Infrastructure
# 34   ANSS              Technology                 Software—Application
# 35     IT              Technology      Information Technology Services
# 36    ACN              Technology      Information Technology Services
# 37   VRSN              Technology              Software—Infrastructure
# 38   AMAT              Technology  Semiconductor Equipment & Materials
# 39    AMD              Technology                       Semiconductors
# 40   KLAC              Technology  Semiconductor Equipment & Materials
# 41   NXPI              Technology                       Semiconductors
# 42   SEDG              Technology                                Solar
# 43   MTCH  Communication Services       Internet Content & Information
# 44   NVDA              Technology                       Semiconductors
# 45    TYL              Technology                 Software—Application
# 46    HPE              Technology              Communication Equipment
# 47  CMCSA  Communication Services                     Telecom Services
# 48    PTC              Technology                 Software—Application
# 49    FIS              Technology      Information Technology Services
# 50     FB  Communication Services       Internet Content & Information
# 51   NLOK              Technology              Software—Infrastructure
# 52   TWTR  Communication Services       Internet Content & Information
# 53    DIS  Communication Services                        Entertainment
# 54   NFLX  Communication Services                        Entertainment
# 55   AKAM              Technology              Software—Infrastructure
# 56  GOOGL  Communication Services       Internet Content & Information
# 57   FOXA  Communication Services                        Entertainment
# 58   FFIV              Technology              Software—Infrastructure
# 59   GOOG  Communication Services       Internet Content & Information
# 60   EPAM              Technology      Information Technology Services
# 61    LYV  Communication Services                        Entertainment
# 62    TEL              Technology                Electronic Components
# 63    ADP             Industrials       Staffing & Employment Services
# 64   TRMB              Technology   Scientific & Technical Instruments
# 65   QCOM              Technology                       Semiconductors
# 66   NWSA  Communication Services                        Entertainment
# 67   TTWO  Communication Services       Electronic Gaming & Multimedia
# 68   AAPL              Technology                 Consumer Electronics
# 69   NTAP              Technology                    Computer Hardware
# 70   KEYS              Technology   Scientific & Technical Instruments
# 71   CTSH              Technology      Information Technology Services
# 72     MU              Technology                       Semiconductors
# 73    CDW              Technology      Information Technology Services
# 74    CRM              Technology                 Software—Application
# 75   LRCX              Technology  Semiconductor Equipment & Materials
#
#       Price Low Price Median Price Mean Price High Price # of Ratings  \
# 0     42.94        45         62.5      62.74         73           24
# 1    102.37        90        136.5      135.1        163           20
# 2    208.55       225          270     267.95        310           38
# 3    108.48       120          135     145.82        235           22
# 4     31.81      51.5         51.5       51.5       51.5            1
# 5       103       120          150        151        226           25
# 6     66.67        67           85      85.78        125           23
# 7    479.03       393          630     623.22        805           27
# 8     20.78        24           44      40.87         61           15
# 9     68.43        79           87      85.77         94           13
# 10   210.28       220          276      272.4        300           10
# 11    122.1       142          180     180.64        240           34
# 12    17.74        18         37.5      34.65         52           20
# 13    34.16        30         37.5      38.08         48           12
# 14    408.6       455          560     560.18        650           27
# 15   454.87       390          614     630.74        850           32
# 16     17.4      None         None       None       None         None
# 17   325.37       400        527.5      514.4        600           10
# 18   138.98       161        175.5     178.17        199            6
# 19    80.12      None         None       None       None         None
# 20    30.67        32           40      40.22         46            9
# 21     56.6      None         None       None       None         None
# 22    68.63        70           89      92.17        126           24
# 23   367.78       510          625     618.33        720           20
# 24   276.79       334          385     385.71        450           17
# 25   100.01        82        153.5     150.25        183            8
# 26    43.48        37           50       51.9         74           40
# 27    35.22        37           44      43.91         51           11
# 28   174.13       150        187.5     191.54        297           28
# 29    28.87        26         36.5      36.38         46           16
# 30   191.41       210          280     284.25        440           19
# 31     12.3         8         10.5       10.4       12.5           10
# 32    80.54        82          115     124.23        255           45
# 33   252.56    298.18          360     362.95     425.96           46
# 34   252.15       245          320     325.36        420           14
# 35   250.04       315          334     330.29        342            7
# 36   276.65      None         None       None       None         None
# 37   165.56       210          227        240        283            3
# 38   106.46       130          170     166.45        205           31
# 39    98.75        97          140     137.91        200           38
# 40   353.28       352          423     427.38        545           21
# 41   192.63       160        207.5     213.31        320           26
# 42   266.44        67        354.5     342.67        490           24
# 43    77.88        81        124.9     122.38        168           21
# 44   178.51       130          260     265.91        400           43
# 45   351.39       400          520     499.26        600           17
# 46    15.09        14           18       17.6         21           17
# 47    44.13        40           56      55.59         70           32
# 48   112.16       120          150     143.82        160           11
# 49    104.2       105          132     133.66        176           32
# 50   191.63       185          300     299.23        553           54
# 51     24.9      22.4         27.5      27.33       31.6            6
# 52    39.52        33           54      51.31       77.8           30
# 53   105.61      None         None       None       None         None
# 54    191.4       217          300     331.45        735           38
# 55   100.87        90          120     125.53        168           15
# 56  2155.85      2658         3270    3275.59    4533.34           45
# 57    34.54        32           45      44.25         55           22
# 58   156.28       155          215     215.47        303           15
# 59  2186.26      2950         3150    3168.89       3600            9
# 60   320.39       380          411     473.62        771           13
# 61    89.28        85          137     129.54        150           13
# 62   122.68      None         None       None       None         None
# 63   218.28       199          235     233.38        257           16
# 64    67.14        67           94      89.75        100            8
# 65   134.84       150          200     202.05      471.6           32
# 66    17.23        23           31      30.02       34.1            6
# 67   123.28       134          181     176.14        231           24
# 68   143.78       157          190     188.92        214           43
# 69    70.49        74           91      96.05        124           19
# 70   141.26       151          178     185.08        222           12
# 71    72.74        75           93      91.65        103           23
# 72     68.9        83        111.5     111.82        165           32
# 73    160.2     204.5          220     222.06        250            8
# 74   159.65       219        297.5     289.83        385           46
# 75   474.12       520          625     648.27        840           23
#
#    Avg Rating
# 0         2.5
# 1         2.2
# 2         1.8
# 3         2.5
# 4        None
# 5         2.5
# 6         2.2
# 7         2.5
# 8         2.2
# 9         2.2
# 10        1.9
# 11        1.8
# 12        2.4
# 13        2.6
# 14        1.9
# 15        1.8
# 16       None
# 17          2
# 18        2.7
# 19       None
# 20        2.4
# 21       None
# 22        2.7
# 23        1.8
# 24          2
# 25        2.4
# 26        2.9
# 27        2.1
# 28        2.6
# 29        2.6
# 30          2
# 31        3.4
# 32        2.1
# 33        1.7
# 34        2.7
# 35        2.1
# 36       None
# 37        2.5
# 38        2.1
# 39        2.2
# 40          2
# 41        2.2
# 42        2.1
# 43        1.9
# 44          2
# 45        2.1
# 46        2.5
# 47        2.2
# 48        1.9
# 49        1.9
# 50          2
# 51        2.2
# 52          3
# 53          2
# 54        2.7
# 55        2.2
# 56        1.7
# 57        2.3
# 58        2.5
# 59        1.5
# 60        1.7
# 61        2.2
# 62       None
# 63          3
# 64        2.1
# 65          2
# 66        1.9
# 67        1.9
# 68        1.9
# 69        2.5
# 70          2
# 71        2.4
# 72        1.9
# 73        1.9
# 74        1.8
# 75        2.1
