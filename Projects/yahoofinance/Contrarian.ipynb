# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
from datetime import datetime

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.min_rows', 20)

# %%
today_date = datetime.now()
date = today_date.strftime('%m_%d_%Y')

price_df = pd.read_csv(f'/Users/brendan/Desktop/Python/May 2022/yf_SP500/output/SP500_master_df_{date}.csv')

# %%
date
# Out:
# '06_02_2022'

# %%
price_df = price_df.drop('Unnamed: 0', 1)
# Out:
# <ipython-input-8-4482bb1f4bcd>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   price_df = price_df.drop('Unnamed: 0', 1)

# %%
price_df.head() # price
# Out:
#                   Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0  06/02/2022 17:36:11   CSCO  1.931244e+11     194965143552         45.79
# 1  06/02/2022 17:36:11    TER  1.802498e+10      16183294976        110.58
# 2  06/02/2022 17:36:11      V           NaN     454458212352        215.05
# 3  06/02/2022 17:36:11   QRVO  1.249488e+10      13396545536        113.36
# 4  06/02/2022 17:36:11    FOX  1.897212e+10      23107883008         31.86
#
#    fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0             64.29            41.02           0.183                3.782
# 1            168.91            97.63          -0.156                4.402
# 2            252.67           186.67           0.234               16.871
# 3            201.46            98.23           0.121                2.943
# 4             40.91            28.96             NaN                1.700
#
#    enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0              12.193        3.68        2.690                      3.746423
# 1              12.537        6.45        5.309                      4.902563
# 2              23.895         NaN          NaN                           NaN
# 3               8.146       13.15        9.656                      2.744748
# 4               7.728        2.35        2.958                      1.395933
#
#    forwardPE  dividendYield
# 0  12.442935         0.0307
# 1  17.144186         0.0041
# 2        NaN         0.0075
# 3   8.620533            NaN
# 4  13.557447         0.0156

# %%
master_frame = pd.read_csv(f'/Users/brendan/Desktop/Python/May 2022/yf_SP500/output/SP500_master_df_{date}.csv')

# %%
price_df.head()
# Out:
#                   Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0  06/02/2022 17:36:11   CSCO  1.931244e+11     194965143552         45.79
# 1  06/02/2022 17:36:11    TER  1.802498e+10      16183294976        110.58
# 2  06/02/2022 17:36:11      V           NaN     454458212352        215.05
# 3  06/02/2022 17:36:11   QRVO  1.249488e+10      13396545536        113.36
# 4  06/02/2022 17:36:11    FOX  1.897212e+10      23107883008         31.86
#
#    fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0             64.29            41.02           0.183                3.782
# 1            168.91            97.63          -0.156                4.402
# 2            252.67           186.67           0.234               16.871
# 3            201.46            98.23           0.121                2.943
# 4             40.91            28.96             NaN                1.700
#
#    enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0              12.193        3.68        2.690                      3.746423
# 1              12.537        6.45        5.309                      4.902563
# 2              23.895         NaN          NaN                           NaN
# 3               8.146       13.15        9.656                      2.744748
# 4               7.728        2.35        2.958                      1.395933
#
#    forwardPE  dividendYield
# 0  12.442935         0.0307
# 1  17.144186         0.0041
# 2        NaN         0.0075
# 3   8.620533            NaN
# 4  13.557447         0.0156

# %%
symbol_list = price_df['symbol'].to_list()

# %%
symbol_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
df = price_df.set_index('symbol')
def is_contrarian(symbol):
    price = df.loc[f'{symbol}', 'currentPrice']
    price_high = df.loc[f'{symbol}', 'fiftyTwoWeekHigh']
    price_low = df.loc[f'{symbol}', 'fiftyTwoWeekLow']
    price_band = (price_high - price_low)
    if price < (price_low + (.3*(price_band))):
        return f'{symbol}'
    else:
        return 'OK'

# %%
is_contrarian('LRCX')
# Out:
# 'LRCX'

# %%
contrarian_tickers = map(is_contrarian, symbol_list)
ticks = [i for i in symbol_list if is_contrarian(i) != 'OK' ]

# %%
ticks
# Out:
# ['CSCO',
#  'TER',
#  'QRVO',
#  'FOX',
#  'SWKS',
#  'CHTR',
#  'DISH',
#  'APH',
#  'GPN',
#  'WBD',
#  'PARA',
#  'ADBE',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'ADSK',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'AMAT',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'CMCSA',
#  'FB',
#  'NLOK',
#  'TWTR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'FOXA',
#  'FFIV',
#  'TEL',
#  'TRMB',
#  'NWSA',
#  'TTWO',
#  'NTAP',
#  'KEYS',
#  'MU',
#  'CRM',
#  'LRCX']

# %%
data = price_df[price_df['symbol'].isin(ticks)]
data.head()
# Out:
#                   Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0  06/02/2022 17:36:11   CSCO  1.931244e+11     194965143552         45.79
# 1  06/02/2022 17:36:11    TER  1.802498e+10      16183294976        110.58
# 3  06/02/2022 17:36:11   QRVO  1.249488e+10      13396545536        113.36
# 4  06/02/2022 17:36:11    FOX  1.897212e+10      23107883008         31.86
# 6  06/02/2022 17:36:11   SWKS  1.833149e+10      19951753216        110.84
#
#    fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0             64.29            41.02           0.183                3.782
# 1            168.91            97.63          -0.156                4.402
# 3            201.46            98.23           0.121                2.943
# 4             40.91            28.96             NaN                1.700
# 6            197.62            97.59          -0.213                3.905
#
#    enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0              12.193        3.68        2.690                      3.746423
# 1              12.537        6.45        5.309                      4.902563
# 3               8.146       13.15        9.656                      2.744748
# 4               7.728        2.35        2.958                      1.395933
# 6               9.960       12.87        8.970                      3.587728
#
#    forwardPE  dividendYield
# 0  12.442935         0.0307
# 1  17.144186         0.0041
# 3   8.620533            NaN
# 4  13.557447         0.0156
# 6   8.612276         0.0216

# %%
len(data)
# Out:
# 51

# %%
today_date = datetime.now()
date_file =today_date.strftime('%m_%d_%Y')
data.to_csv(f'SP500_contrarian_df_{date_file}.csv')

# %%
cont_df = pd.read_csv(f'SP500_contrarian_df_{date_file}.csv')
cont_df
# Out:
#     Unnamed: 0                 Date symbol     marketCap  enterpriseValue  \
# 0            0  06/02/2022 17:36:11   CSCO  1.931244e+11     194965143552
# 1            1  06/02/2022 17:36:11    TER  1.802498e+10      16183294976
# 2            3  06/02/2022 17:36:11   QRVO  1.249488e+10      13396545536
# 3            4  06/02/2022 17:36:11    FOX  1.897212e+10      23107883008
# 4            6  06/02/2022 17:36:11   SWKS  1.833149e+10      19951753216
# 5           10  06/02/2022 17:36:11   CHTR  8.932636e+10     168875589632
# 6           12  06/02/2022 17:36:11   DISH  1.182401e+10      33020866560
# 7           13  06/02/2022 17:36:11    APH  4.304606e+10      46405705728
# 8           15  06/02/2022 17:36:11    GPN  3.816937e+10      49546457088
# 9           16  06/02/2022 17:36:11    WBD           NaN      23732545536
# 10          18  06/02/2022 17:36:11   PARA           NaN      32926785536
# 11          20  06/02/2022 17:36:11   ADBE  2.099610e+11     187050377216
# 12          22  06/02/2022 17:36:11    NWS  1.061504e+10      13919098880
# 13          23  06/02/2022 17:36:11   ZBRA  1.854794e+10      20450457600
# 14          24  06/02/2022 17:36:11     BR  1.721041e+10      20994430976
# 15          25  06/02/2022 17:36:11    STX  1.884391e+10      22073798656
# 16          27  06/02/2022 17:36:11   CDAY  8.648568e+09       9343748096
# 17          28  06/02/2022 17:36:11   ORCL  1.953167e+11     251351728128
# 18          29  06/02/2022 17:36:11   INTU  1.208727e+11     124250726400
# 19          30  06/02/2022 17:36:11   PAYC  1.819382e+10      16730388480
# 20          31  06/02/2022 17:36:11   IPGP  5.597434e+09       3546220800
# 21          32  06/02/2022 17:36:11   INTC  1.823643e+11     176790503424
# 22          37  06/02/2022 17:36:11   ADSK  4.709402e+10      42427953152
# 23          40  06/02/2022 17:36:11   PYPL  1.037698e+11     103888453632
# 24          41  06/02/2022 17:36:11   MSFT  2.061541e+12    2048902299648
# 25          42  06/02/2022 17:36:11   ANSS  2.327474e+10      24261203968
# 26          43  06/02/2022 17:36:11     IT  2.208446e+10      26456133632
# 27          44  06/02/2022 17:36:11    ACN  1.939399e+11     188926197760
# 28          45  06/02/2022 17:36:11   VRSN  2.003070e+10      20151259136
# 29          47  06/02/2022 17:36:11   AMAT  1.042492e+11      97502601216
# 30          54  06/02/2022 17:36:11   MTCH  2.381594e+10      25804969984
# 31          55  06/02/2022 17:36:11   NVDA  4.882326e+11     455410810880
# 32          56  06/02/2022 17:36:11    TYL  1.479613e+10      17453617152
# 33          58  06/02/2022 17:36:11  CMCSA  2.001187e+11     270841151488
# 34          62  06/02/2022 17:36:11     FB  5.531808e+11     513304657920
# 35          63  06/02/2022 17:36:11   NLOK  1.434608e+10      16732807168
# 36          65  06/02/2022 17:36:11   TWTR  3.191243e+10      38548004864
# 37          67  06/02/2022 17:36:11    DIS  2.015240e+11     256654311424
# 38          68  06/02/2022 17:36:11   NFLX  9.084502e+10      95862595584
# 39          69  06/02/2022 17:36:11    OMC  1.557207e+10      19207329792
# 40          74  06/02/2022 17:36:11   FOXA  1.896349e+10      24571428864
# 41          75  06/02/2022 17:36:11   FFIV  1.030307e+10       9871137792
# 42          82  06/02/2022 17:36:11    TEL  4.296563e+10      43690319872
# 43          85  06/02/2022 17:36:11   TRMB  1.762076e+10      17879977984
# 44          88  06/02/2022 17:36:11   NWSA  1.052018e+10      13889631232
# 45          89  06/02/2022 17:36:11   TTWO  1.487947e+10      10856370176
# 46          92  06/02/2022 17:36:11   NTAP  1.620407e+10      15044795392
# 47          93  06/02/2022 17:36:11   KEYS  2.723299e+10      25562640384
# 48          95  06/02/2022 17:36:11     MU  8.442721e+10      73692512256
# 49          97  06/02/2022 17:36:11    CRM  1.855740e+11     178013601792
# 50          98  06/02/2022 17:36:11   LRCX  7.368012e+10      65261465600
#
#     currentPrice  fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  \
# 0          45.79             64.29           41.020           0.183
# 1         110.58            168.91           97.630          -0.156
# 2         113.36            201.46           98.230           0.121
# 3          31.86             40.91           28.960             NaN
# 4         110.84            197.62           97.590          -0.213
# 5         498.22            825.62          410.330           0.681
# 6          22.36             46.31           17.040          -0.308
# 7          71.98             88.45           65.840           0.283
# 8         131.55            196.88          114.800           0.187
# 9          18.00             32.40           16.510           2.267
# 10         31.43             47.46           26.110           1.326
# 11        441.28            699.54          370.270           0.019
# 12         18.02             25.69           16.570           0.018
# 13        347.07            615.00          309.000          -0.045
# 14        147.63            185.40          132.680          -0.167
# 15         84.64            117.67           76.280           0.122
# 16         57.15            130.37           48.930             NaN
# 17         73.14            106.34           66.720          -0.500
# 18        426.86            716.86          339.360           4.000
# 19        303.10            558.97          259.950           1.000
# 20        105.00            220.51           90.510           0.310
# 21         44.84             58.42           40.310           1.415
# 22        214.09            344.39          173.900          -0.901
# 23         88.32            310.16           71.831          -0.533
# 24        274.58            349.67          243.000           0.094
# 25        266.75            413.89          230.720          -0.067
# 26        268.54            369.00          228.200           0.881
# 27        306.62            417.37          268.170           0.139
# 28        180.33            257.03          159.690           0.075
# 29        117.33            167.06          101.330           0.639
# 30         84.13            182.00           67.869             NaN
# 31        195.92            346.47          155.670           1.034
# 32        361.09            557.55          327.970           0.068
# 33         43.80             61.80           39.470           0.099
# 34        198.86            384.33          169.000          -0.176
# 35         24.66             30.92           23.470           0.140
# 36         39.91             73.34           31.300           6.681
# 37        110.87            187.58           99.470          63.358
# 38        205.09            700.99          162.710          -0.059
# 39         73.26             91.61           65.760          -0.376
# 40         34.42             44.95           31.350             NaN
# 41        168.27            249.00          151.660           0.314
# 42        131.67            166.44          119.580           0.130
# 43         70.20             96.49           59.890          -0.361
# 44         17.71             26.87           16.380           0.018
# 45        129.05            195.83          101.850          -0.210
# 46         72.90             96.82           64.580           0.375
# 47        148.78            209.08          127.930           0.348
# 48         75.37             98.45           65.670           2.774
# 49        188.40            311.75          154.550             NaN
# 50        523.30            731.85          442.530          -0.015
#
#     enterpriseToRevenue  enterpriseToEbitda  forwardEps  trailingEps  \
# 0                 3.782              12.193        3.68        2.690
# 1                 4.402              12.537        6.45        5.309
# 2                 2.943               8.146       13.15        9.656
# 3                 1.700               7.728        2.35        2.958
# 4                 3.905               9.960       12.87        8.970
# 5                 3.225               8.135       31.27       21.943
# 6                 1.847               8.407        2.77        4.159
# 7                 4.053              17.165        2.67        2.380
# 8                 5.813              14.373        9.59        3.167
# 9                 1.890               6.166         NaN          NaN
# 10                1.152               7.499         NaN          NaN
# 11               11.588              28.684       16.25       10.020
# 12                1.386              10.977         NaN        0.830
# 13                3.634              17.070       19.70       15.684
# 14                3.907              18.797        7.04        4.655
# 15                1.832               8.697        9.28        6.795
# 16                9.123             841.779        0.45       -0.561
# 17                6.009              13.661        5.26        3.543
# 18               10.886              39.697       13.64        7.581
# 19               15.850              58.850        5.63        2.950
# 20                2.427               7.896        5.85        4.869
# 21                2.275               5.604        3.70        5.158
# 22                9.673              51.359        6.83        5.928
# 23                4.023              21.249        5.27        4.159
# 24               10.640              21.571       10.54        8.939
# 25               12.724              38.745        7.94        5.318
# 26                5.589              23.045        7.13        8.025
# 27                3.332              19.863       10.45        9.613
# 28               14.917              21.681        6.17        5.425
# 29                4.034              11.943        8.85        6.400
# 30                8.650              27.773        2.58        1.884
# 31               16.921              40.607        5.21        3.243
# 32                9.953              50.622        8.15        3.825
# 33                2.253               7.664        3.69        3.109
# 34                4.289               9.862       14.23       13.974
# 35                6.080              12.754        1.97        1.496
# 36                7.353              70.533        0.96       -0.228
# 37                3.516              24.304        5.06        1.094
# 38                3.153              14.854       13.09       11.091
# 39                1.346               8.254        6.41        6.420
# 40                1.808               8.218        3.56        2.958
# 41                3.718              18.315       13.18        5.340
# 42                2.821              11.941        7.91        6.788
# 43                4.886              23.125        2.96        2.197
# 44                1.383              10.954        1.03        0.830
# 45                3.180              12.955        6.70        4.836
# 46                2.429              11.038        5.51        4.113
# 47                5.101              17.989        7.48        4.780
# 48                2.364               4.318       11.51        6.461
# 49                6.720              58.098        4.71        1.818
# 50                3.899              11.775       36.65       29.588
#
#     priceToSalesTrailing12Months   forwardPE  dividendYield
# 0                       3.746423   12.442935         0.0307
# 1                       4.902563   17.144186         0.0041
# 2                       2.744748    8.620533            NaN
# 3                       1.395933   13.557447         0.0156
# 4                       3.587728    8.612276         0.0216
# 5                       1.706004   15.932843            NaN
# 6                       0.661257    8.072203            NaN
# 7                       3.759120   26.958801         0.0114
# 8                       4.477995   13.717414         0.0082
# 9                            NaN         NaN            NaN
# 10                           NaN         NaN         0.0339
# 11                     13.007126   27.155693            NaN
# 12                      1.056644         NaN         0.0111
# 13                      3.296240   17.617765            NaN
# 14                      3.202592   20.970171         0.0184
# 15                      1.564329    9.120689         0.0347
# 16                      8.444218  127.000010            NaN
# 17                      4.669632   13.904943         0.0180
# 18                     10.589861   31.294720         0.0073
# 19                     17.236767   53.836590            NaN
# 20                      3.831602   17.948719            NaN
# 21                      2.346910   12.118918         0.0335
# 22                     10.736370   31.345533            NaN
# 23                      4.018815   16.759014            NaN
# 24                     10.706134   26.051231         0.0095
# 25                     12.206720   33.595720            NaN
# 26                      4.665112   37.663395            NaN
# 27                      3.420763   29.341627         0.0135
# 28                     14.827930   29.226904            NaN
# 29                      4.312810   13.257627         0.0088
# 30                      7.983147   32.608530            NaN
# 31                     18.140470   37.604607         0.0009
# 32                      8.437610   44.305523            NaN
# 33                      1.665020   11.869918         0.0260
# 34                      4.622706   13.974702            NaN
# 35                      5.212965   12.517766         0.0209
# 36                      6.087316   41.572918            NaN
# 37                      2.761056   21.911068            NaN
# 38                      2.988094   15.667685            NaN
# 39                      1.091031   11.429018         0.0364
# 40                      1.395298    9.668539         0.0143
# 41                      3.880869   12.767072            NaN
# 42                      2.774124   16.646017         0.0179
# 43                      4.815600   23.716215            NaN
# 44                      1.047201   17.194174         0.0112
# 45                      4.358078   19.261194            NaN
# 46                      2.616513   13.230490         0.0281
# 47                      5.434642   19.890373            NaN
# 48                      2.708692    6.548219         0.0056
# 49                      7.004907   40.000000            NaN
# 50                      4.402318   14.278307         0.0122

# %%
data_merge = cont_df[['symbol', 'marketCap', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow']]

# %% [markdown]
# ## Price targets

# %%
px_target_cols = ['symbol', 'sector', 'industry','currentPrice', 'targetLowPrice', 'targetMedianPrice','numberOfAnalystOpinions',
            'targetMeanPrice', 'targetHighPrice', 'recommendationMean']

# %%
appended_data = []
for ticker in ticks:
    data = yf.Ticker(ticker)
    df = pd.DataFrame([data.info])
    px_target = df[px_target_cols]
    appended_data.append(px_target)

contrarian_df = pd.DataFrame(np.row_stack(appended_data))
contrarian_df.columns =  ['Ticker', 'Sector', 'Industry','Price', 'Low Price', 'Median Price','# of Ratings',
            'Mean Price', 'High Price', 'Avg Rating']
contrarian_df = contrarian_df[['Ticker', 'Sector', 'Industry','Price', 'Low Price', 'Median Price', 'Mean Price', 'High Price',
                 '# of Ratings', 'Avg Rating']]
contrarian_df
# Out:
#    Ticker                  Sector                             Industry  \
# 0    CSCO              Technology              Communication Equipment
# 1     TER              Technology  Semiconductor Equipment & Materials
# 2    QRVO              Technology                       Semiconductors
# 3     FOX  Communication Services                         Broadcasting
# 4    SWKS              Technology                       Semiconductors
# 5    CHTR  Communication Services                        Entertainment
# 6    DISH  Communication Services                        Entertainment
# 7     APH              Technology                Electronic Components
# 8     GPN             Industrials          Specialty Business Services
# 9     WBD  Communication Services                        Entertainment
# 10   PARA  Communication Services                        Entertainment
# 11   ADBE              Technology              Software—Infrastructure
# 12    NWS  Communication Services                         Broadcasting
# 13   ZBRA              Technology              Communication Equipment
# 14     BR              Technology      Information Technology Services
# 15    STX              Technology                    Computer Hardware
# 16   CDAY              Technology                 Software—Application
# 17   ORCL              Technology              Software—Infrastructure
# 18   INTU              Technology                 Software—Application
# 19   PAYC              Technology                 Software—Application
# 20   IPGP              Technology  Semiconductor Equipment & Materials
# 21   INTC              Technology                       Semiconductors
# 22   ADSK              Technology                 Software—Application
# 23   PYPL      Financial Services                      Credit Services
# 24   MSFT              Technology              Software—Infrastructure
# 25   ANSS              Technology                 Software—Application
# 26     IT              Technology      Information Technology Services
# 27    ACN              Technology      Information Technology Services
# 28   VRSN              Technology              Software—Infrastructure
# 29   AMAT              Technology  Semiconductor Equipment & Materials
# 30   MTCH  Communication Services       Internet Content & Information
# 31   NVDA              Technology                       Semiconductors
# 32    TYL              Technology                 Software—Application
# 33  CMCSA  Communication Services                        Entertainment
# 34     FB  Communication Services       Internet Content & Information
# 35   NLOK              Technology              Software—Infrastructure
# 36   TWTR  Communication Services       Internet Content & Information
# 37    DIS  Communication Services                        Entertainment
# 38   NFLX  Communication Services                        Entertainment
# 39    OMC  Communication Services                 Advertising Agencies
# 40   FOXA  Communication Services                         Broadcasting
# 41   FFIV              Technology              Software—Infrastructure
# 42    TEL              Technology                Electronic Components
# 43   TRMB              Technology   Scientific & Technical Instruments
# 44   NWSA  Communication Services                         Broadcasting
# 45   TTWO  Communication Services       Electronic Gaming & Multimedia
# 46   NTAP              Technology                    Computer Hardware
# 47   KEYS              Technology   Scientific & Technical Instruments
# 48     MU              Technology                       Semiconductors
# 49    CRM              Technology                 Software—Application
# 50   LRCX              Technology  Semiconductor Equipment & Materials
#
#      Price Low Price Median Price Mean Price High Price # of Ratings  \
# 0    45.79        45         62.5      62.74         73           24
# 1   110.58        90        136.5      135.1        163           20
# 2   113.36       120          135     149.86        235           22
# 3    31.86      51.5         51.5       51.5       51.5            1
# 4   110.84       120          150        151        226           25
# 5   498.22       393          630     623.22        805           27
# 6    22.36        24           44      40.87         61           15
# 7    71.98        79           87      85.77         94           13
# 8   131.55       142          180     180.64        240           34
# 9       18        18         37.5      34.65         52           20
# 10   31.43        24           35      36.56         60           25
# 11  441.28       455          570      563.7        650           27
# 12   18.02      None         None       None       None         None
# 13  347.07       400        527.5      514.4        600           10
# 14  147.63       161        175.5     178.17        199            6
# 15   84.64      None         None       None       None         None
# 16   57.15      None         None       None       None         None
# 17   73.14        70           89      92.17        126           24
# 18  426.86       510          625     618.33        720           20
# 19   303.1       334          385     385.71        450           17
# 20     105        95        153.5     151.88        183            8
# 21   44.84        37         50.5      52.36         74           40
# 22  214.09       210          280     284.25        440           19
# 23   88.32        82          115     124.23        255           45
# 24  274.58    298.18          360     362.95     425.96           46
# 25  266.75       245          320     325.36        420           14
# 26  268.54       315          334     330.29        342            7
# 27  306.62      None         None       None       None         None
# 28  180.33       210          227        240        283            3
# 29  117.33       130          170     166.45        205           31
# 30   84.13        81          125        125        170           21
# 31  195.92       160          350     326.46        400           44
# 32  361.09       408          520     509.85        600           17
# 33    43.8        40           58      56.03         70           32
# 34  198.86       185          300     301.33        553           54
# 35   24.66      22.4         27.5      27.33       31.6            6
# 36   39.91        33           54      51.88       77.8           30
# 37  110.87      None         None       None       None         None
# 38  205.09       217          300     338.95        735           38
# 39   73.26        77           90      92.56        107            9
# 40   34.42        32           46      44.96         55           23
# 41  168.27       155          215     215.47        303           15
# 42  131.67      None         None       None       None         None
# 43    70.2        70           94      90.75        100            8
# 44   17.71        28           30      30.87       34.1            7
# 45  129.05    155.26          200     200.81        231           25
# 46    72.9        74           96      97.95        124           19
# 47  148.78       176          195     198.69        230           13
# 48   75.37        83        111.5     111.82        165           32
# 49   188.4       219        297.5     289.83        385           46
# 50   523.3       520          625     648.27        840           23
#
#    Avg Rating
# 0         2.5
# 1         2.2
# 2         2.5
# 3        None
# 4         2.5
# 5         2.5
# 6         2.2
# 7         2.2
# 8         1.8
# 9         2.4
# 10        2.7
# 11        1.9
# 12       None
# 13          2
# 14        2.7
# 15       None
# 16       None
# 17        2.7
# 18        1.8
# 19          2
# 20        2.3
# 21        2.9
# 22          2
# 23        2.1
# 24        1.7
# 25        2.7
# 26        2.1
# 27       None
# 28        2.5
# 29        2.1
# 30        1.9
# 31          2
# 32        2.1
# 33        2.2
# 34          2
# 35        2.2
# 36          3
# 37          2
# 38        2.7
# 39        2.5
# 40        2.3
# 41        2.5
# 42       None
# 43        2.1
# 44        1.9
# 45        1.9
# 46        2.5
# 47          2
# 48        1.9
# 49        1.8
# 50        2.1

# %%
data_merge.columns = ['Ticker', 'Market Cap', 'FiftyTwoWeekHigh', 'FiftyTwoWeekLow']
data_merge
# Out:
#    Ticker    Market Cap  FiftyTwoWeekHigh  FiftyTwoWeekLow
# 0    CSCO  1.931244e+11             64.29           41.020
# 1     TER  1.802498e+10            168.91           97.630
# 2    QRVO  1.249488e+10            201.46           98.230
# 3     FOX  1.897212e+10             40.91           28.960
# 4    SWKS  1.833149e+10            197.62           97.590
# 5    CHTR  8.932636e+10            825.62          410.330
# 6    DISH  1.182401e+10             46.31           17.040
# 7     APH  4.304606e+10             88.45           65.840
# 8     GPN  3.816937e+10            196.88          114.800
# 9     WBD           NaN             32.40           16.510
# 10   PARA           NaN             47.46           26.110
# 11   ADBE  2.099610e+11            699.54          370.270
# 12    NWS  1.061504e+10             25.69           16.570
# 13   ZBRA  1.854794e+10            615.00          309.000
# 14     BR  1.721041e+10            185.40          132.680
# 15    STX  1.884391e+10            117.67           76.280
# 16   CDAY  8.648568e+09            130.37           48.930
# 17   ORCL  1.953167e+11            106.34           66.720
# 18   INTU  1.208727e+11            716.86          339.360
# 19   PAYC  1.819382e+10            558.97          259.950
# 20   IPGP  5.597434e+09            220.51           90.510
# 21   INTC  1.823643e+11             58.42           40.310
# 22   ADSK  4.709402e+10            344.39          173.900
# 23   PYPL  1.037698e+11            310.16           71.831
# 24   MSFT  2.061541e+12            349.67          243.000
# 25   ANSS  2.327474e+10            413.89          230.720
# 26     IT  2.208446e+10            369.00          228.200
# 27    ACN  1.939399e+11            417.37          268.170
# 28   VRSN  2.003070e+10            257.03          159.690
# 29   AMAT  1.042492e+11            167.06          101.330
# 30   MTCH  2.381594e+10            182.00           67.869
# 31   NVDA  4.882326e+11            346.47          155.670
# 32    TYL  1.479613e+10            557.55          327.970
# 33  CMCSA  2.001187e+11             61.80           39.470
# 34     FB  5.531808e+11            384.33          169.000
# 35   NLOK  1.434608e+10             30.92           23.470
# 36   TWTR  3.191243e+10             73.34           31.300
# 37    DIS  2.015240e+11            187.58           99.470
# 38   NFLX  9.084502e+10            700.99          162.710
# 39    OMC  1.557207e+10             91.61           65.760
# 40   FOXA  1.896349e+10             44.95           31.350
# 41   FFIV  1.030307e+10            249.00          151.660
# 42    TEL  4.296563e+10            166.44          119.580
# 43   TRMB  1.762076e+10             96.49           59.890
# 44   NWSA  1.052018e+10             26.87           16.380
# 45   TTWO  1.487947e+10            195.83          101.850
# 46   NTAP  1.620407e+10             96.82           64.580
# 47   KEYS  2.723299e+10            209.08          127.930
# 48     MU  8.442721e+10             98.45           65.670
# 49    CRM  1.855740e+11            311.75          154.550
# 50   LRCX  7.368012e+10            731.85          442.530

# %%
merged_cont_df = contrarian_df.merge(data_merge, how = 'inner', on = ['Ticker'])
merged_cont_df = merged_cont_df[['Ticker', 'Market Cap', 'Sector', 'Industry', 'Price', 'FiftyTwoWeekHigh', 'FiftyTwoWeekLow',
                  'Low Price', 'Median Price', 'Mean Price', 'High Price', '# of Ratings', 'Avg Rating']]

# %%
merged_cont_df['Contrarian %'] = (merged_cont_df['Price'] - merged_cont_df['FiftyTwoWeekLow'])/(merged_cont_df['FiftyTwoWeekHigh'] - merged_cont_df['FiftyTwoWeekLow'])*100

# %%
merged_cont_df = merged_cont_df[['Ticker', 'Market Cap', 'Sector', 'Industry', 'Price', 'Contrarian %','FiftyTwoWeekHigh', 'FiftyTwoWeekLow',
                  'Low Price', 'Median Price', 'Mean Price', 'High Price', '# of Ratings', 'Avg Rating']]

# %%
merged_cont_df['Market Cap $(m)'] = merged_cont_df['Market Cap']/1000000
column_price = ['Price', 'FiftyTwoWeekHigh', 'FiftyTwoWeekLow', 'Low Price', 'Median Price', 'Mean Price', 'High Price']
column_per = ['Contrarian %']
column_dollar = ['Market Cap $(m)']

merged_cont_df = merged_cont_df.drop('Market Cap',1)
merged_cont_df[['Low Price', 'Median Price', 'Mean Price', 'High Price']].apply(pd.to_numeric)
#merged_cont_df.apply(pd.to_numeric, errors='ignore').info()
# Out:
# <ipython-input-30-4be42e965c6f>:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged_cont_df = merged_cont_df.drop('Market Cap',1)
#     Low Price  Median Price  Mean Price  High Price
# 0       45.00          62.5       62.74       73.00
# 1       90.00         136.5      135.10      163.00
# 2      120.00         135.0      149.86      235.00
# 3       51.50          51.5       51.50       51.50
# 4      120.00         150.0      151.00      226.00
# 5      393.00         630.0      623.22      805.00
# 6       24.00          44.0       40.87       61.00
# 7       79.00          87.0       85.77       94.00
# 8      142.00         180.0      180.64      240.00
# 9       18.00          37.5       34.65       52.00
# 10      24.00          35.0       36.56       60.00
# 11     455.00         570.0      563.70      650.00
# 12        NaN           NaN         NaN         NaN
# 13     400.00         527.5      514.40      600.00
# 14     161.00         175.5      178.17      199.00
# 15        NaN           NaN         NaN         NaN
# 16        NaN           NaN         NaN         NaN
# 17      70.00          89.0       92.17      126.00
# 18     510.00         625.0      618.33      720.00
# 19     334.00         385.0      385.71      450.00
# 20      95.00         153.5      151.88      183.00
# 21      37.00          50.5       52.36       74.00
# 22     210.00         280.0      284.25      440.00
# 23      82.00         115.0      124.23      255.00
# 24     298.18         360.0      362.95      425.96
# 25     245.00         320.0      325.36      420.00
# 26     315.00         334.0      330.29      342.00
# 27        NaN           NaN         NaN         NaN
# 28     210.00         227.0      240.00      283.00
# 29     130.00         170.0      166.45      205.00
# 30      81.00         125.0      125.00      170.00
# 31     160.00         350.0      326.46      400.00
# 32     408.00         520.0      509.85      600.00
# 33      40.00          58.0       56.03       70.00
# 34     185.00         300.0      301.33      553.00
# 35      22.40          27.5       27.33       31.60
# 36      33.00          54.0       51.88       77.80
# 37        NaN           NaN         NaN         NaN
# 38     217.00         300.0      338.95      735.00
# 39      77.00          90.0       92.56      107.00
# 40      32.00          46.0       44.96       55.00
# 41     155.00         215.0      215.47      303.00
# 42        NaN           NaN         NaN         NaN
# 43      70.00          94.0       90.75      100.00
# 44      28.00          30.0       30.87       34.10
# 45     155.26         200.0      200.81      231.00
# 46      74.00          96.0       97.95      124.00
# 47     176.00         195.0      198.69      230.00
# 48      83.00         111.5      111.82      165.00
# 49     219.00         297.5      289.83      385.00
# 50     520.00         625.0      648.27      840.00

# %%
merged_cont_df.style.format.apply({'Price': "${:.2f}",'FiftyTwoWeekHigh':"${:.2f}",'FiftyTwoWeekLow':"${:.2f}",
                        'Low Price': "${:.2f}", 'Median Price': "${:.2f}",'Mean Price': "${:.2f}",
                        'High Price': "${:.2f}"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 merged_cont_df.style.format.apply({'Price': "${:.2f}",'FiftyTwoWeekHigh':"${:.2f}",'FiftyTwoWeekLow':"${:.2f}",
#       2                         'Low Price': "${:.2f}", 'Median Price': "${:.2f}",'Mean Price': "${:.2f}",
#       3                         'High Price': "${:.2f}"})
#
# AttributeError: 'function' object has no attribute 'apply'

# %%
merged_cont_df.style.format({'Price': "${:.2f}",'FiftyTwoWeekHigh':"${:.2f}",'FiftyTwoWeekLow':"${:.2f}",
                        'Low Price': "${:.2f}", 'Mean Price': "${:.2f}",'Median Price': "${:.2f}",
                        'High Price': "${:.2f}"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:272, in Styler._repr_html_(self)
#     267 """
#     268 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     269 default if an object is returned at the end of a cell.
#     270 """
#     271 if get_option("styler.render.repr") == "html":
# --> 272     return self.to_html()
#     273 return None
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:1178, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1176 encoding = encoding or get_option("styler.render.encoding")
#    1177 # Build HTML string..
# -> 1178 html = obj._render_html(
#    1179     sparse_index=sparse_index,
#    1180     sparse_columns=sparse_columns,
#    1181     max_rows=max_rows,
#    1182     max_cols=max_columns,
#    1183     exclude_styles=exclude_styles,
#    1184     encoding=encoding,
#    1185     doctype_html=doctype_html,
#    1186     **kwargs,
#    1187 )
#    1189 return save_to_buffer(
#    1190     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1191 )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style_render.py:164, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     162 self._compute()
#     163 # TODO: namespace all the pandas keys
# --> 164 d = self._translate(sparse_index, sparse_columns, max_rows, max_cols)
#     165 d.update(kwargs)
#     166 return self.template_html.render(
#     167     **d,
#     168     html_table_tpl=self.template_html_table,
#     169     html_style_tpl=self.template_html_style,
#     170 )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style_render.py:279, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank)
#     273 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     274     list
#     275 )
#     276 self.cellstyle_map_index: DefaultDict[
#     277     tuple[CSSPair, ...], list[str]
#     278 ] = defaultdict(list)
# --> 279 body = self._translate_body(idx_lengths, max_rows, max_cols)
#     280 d.update({"body": body})
#     282 ctx_maps = {
#     283     "cellstyle": "cellstyle_map",
#     284     "cellstyle_index": "cellstyle_map_index",
#     285     "cellstyle_columns": "cellstyle_map_columns",
#     286 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style_render.py:566, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     564         body.append(trimmed_row)
#     565         break
# --> 566     body_row = self._generate_body_row(
#     567         (r, row_tup, rlabels), max_cols, idx_lengths
#     568     )
#     569     body.append(body_row)
#     570 return body
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style_render.py:733, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     721 if (r, c) in self.cell_context:
#     722     cls = " " + self.cell_context[r, c]
#     724 data_element = _element(
#     725     "td",
#     726     (
#     727         f"{self.css['data']} {self.css['row']}{r} "
#     728         f"{self.css['col']}{c}{cls}"
#     729     ),
#     730     value,
#     731     data_element_visible,
#     732     attributes="",
# --> 733     display_value=self._display_funcs[(r, c)](value),
#     734 )
#     736 if self.cell_ids:
#     737     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style_render.py:1517, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1515 # Get initial func from input string, input callable, or from default factory
#    1516 if isinstance(formatter, str):
# -> 1517     func_0 = lambda x: formatter.format(x)
#    1518 elif callable(formatter):
#    1519     func_0 = formatter
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
merged_cont_df.head(2)
# Out:
#   Ticker      Sector                             Industry   Price  \
# 0   CSCO  Technology              Communication Equipment   45.79
# 1    TER  Technology  Semiconductor Equipment & Materials  110.58
#
#   Contrarian %  FiftyTwoWeekHigh  FiftyTwoWeekLow Low Price Median Price  \
# 0    20.498496             64.29            41.02        45         62.5
# 1    18.167789            168.91            97.63        90        136.5
#
#   Mean Price High Price # of Ratings Avg Rating  Market Cap $(m)
# 0      62.74         73           24        2.5    193124.368384
# 1      135.1        163           20        2.2     18024.982528

# %%
date_file =today_date.strftime('%m_%d_%Y')
#raw_df.to_csv(f'SP500_master_df_{date_file}.csv')
date_file
# Out:
# '06_02_2022'

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
merged_cont_df.to_sql(f'contrarian_{date_file}', con=engine, if_exists='append', index=False)
# Out:
# 51
