# %%
import pandas as pd
import yfinance as yf

# %%
df_char = pd.read_excel('russell_2000.xlsx', sheet_name='Characteristics')
df_perf = pd.read_excel('russell_2000.xlsx', sheet_name='Performance')

# %%
xl = pd.ExcelFile('russell_2000.xlsx')
xl.sheet_names
# Out:
# ['Characteristics', 'Performance', 'Notes']

# %%
df_char.head(2)
# Out:
#   Ticker                        Name      Sector  Price  Dividend Yield  \
# 0   AMKR       AMKOR Technology Inc.  Technology  19.19        0.009353
# 1   AMLX  Amylyx Pharmaceuticals Inc         NaN   8.70        0.000000
#
#    1-Year Dividend Growth  5-Year Dividend Growth (Annualized)  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
#
#    Dividends Per Share (TTM)  Market Cap ($M)  Trailing P/E Ratio  \
# 0                   0.179491      4697.311965            6.769934
# 1                   0.000000       509.239066            0.000000
#
#    Payout Ratio      Beta  52-Week High  52-Week Low
# 0      0.063649  1.797544         29.37        18.05
# 1           NaN       NaN         33.41         6.51

# %%
df_perf.head(2)
# Out:
#   Ticker                        Name  One Month Price Return  \
# 0   AMKR       AMKOR Technology Inc.               -0.003117
# 1   AMLX  Amylyx Pharmaceuticals Inc               -0.127382
#
#    Three Month Price Return  Six Month Price Return  \
# 0                 -0.153932               -0.169609
# 1                 -0.709807               -0.518539
#
#    Year-To-Date Price Return  One Year Price Return  Two Year Price Return  \
# 0                  -0.224239              -0.025854               0.979595
# 1                  -0.518539              -0.518539              -0.518539
#
#    Five Year Price Return
# 0                0.746387
# 1               -0.518539

# %%
len(df_char)
# Out:
# 1899

# %%
df_char
# Out:
#      Ticker                               Name              Sector  Price  \
# 0      AMKR              AMKOR Technology Inc.          Technology  19.19
# 1      AMLX         Amylyx Pharmaceuticals Inc                 NaN   8.70
# 2       AMN       AMN Healthcare Services Inc.          Healthcare  88.49
# 3      AMNB  American National Bankshares Inc.  Financial Services  34.56
# 4      AMOT     Allied Motion Technologies Inc          Technology  22.61
# ...     ...                                ...                 ...    ...
# 1894    ZUO                          Zuora Inc          Technology  10.43
# 1895   ZVIA                          Zevia PBC                 NaN   1.99
# 1896    ZWS          Zurn Water Solutions Corp                 NaN  26.71
# 1897     ZY                       Zymergen Inc                 NaN   1.27
# 1898   ZYXI                          Zynex Inc          Healthcare   7.25
#
#       Dividend Yield  1-Year Dividend Growth  \
# ...

# %%
df_char['Sector'].value_counts()
# Out:
# Healthcare                344
# Financial Services        268
# Industrials               211
# Consumer Cyclical         181
# Technology                170
# Real Estate               108
# Energy                     76
# Consumer Defensive         59
# Basic Materials            56
# Communication Services     53
# Utilities                  26
# Name: Sector, dtype: int64

# %%
tech_df = df_char[df_char['Sector']=='Technology']
tech_df
# Out:
#      Ticker                             Name      Sector  Price  \
# 0      AMKR            AMKOR Technology Inc.  Technology  19.19
# 4      AMOT   Allied Motion Technologies Inc  Technology  22.61
# 13    AMSWA           American Software Inc.  Technology  16.95
# 30     AOSL  Alpha & Omega Semiconductor Ltd  Technology  40.08
# 39     APPF                     Appfolio Inc  Technology  97.34
# ...     ...                              ...         ...    ...
# 1827   VUZI                Vuzix Corporation  Technology   5.07
# 1846     WK                      Workiva Inc  Technology  68.16
# 1880   XPER               Xperi Holding Corp  Technology  16.64
# 1886   YEXT                         Yext Inc  Technology   4.85
# 1894    ZUO                        Zuora Inc  Technology  10.43
#
#       Dividend Yield  1-Year Dividend Growth  \
# 0           0.009353                     NaN
# 4           0.003311                     0.0
# 13          0.025746                     0.0
# ...

# %%
len(tech_df)
# Out:
# 170

# %%
mcap = tech_df.sort_values(by=['Market Cap ($M)'], ascending=False)
mcap
# Out:
#      Ticker                                    Name      Sector   Price  \
# 1553   SMTC                           Semtech Corp.  Technology   60.58
# 988    LSCC             Lattice Semiconductor Corp.  Technology   49.92
# 828    IIVI                              Ii-Vi Inc.  Technology   59.08
# 1469   SAIL     SailPoint Technologies Holdings Inc  Technology   62.33
# 1626   SYNA                           Synaptics Inc  Technology  138.62
# ...     ...                                     ...         ...     ...
# 1367   QMCO                            Quantum Corp  Technology    1.73
# 730     HBB        Hamilton Beach Brands Holding Co  Technology    9.45
# 1789    VHC                    Virnetx Holding Corp  Technology    1.22
# 1054   MIME                            Mimecast Ltd  Technology   79.92
# 525    EPAY  Bottomline Technologies (Delaware) Inc  Technology   56.99
#
#       Dividend Yield  1-Year Dividend Growth  \
# 1553        0.000000                     NaN
# ...

# %%
df_tickers = df_char[['Ticker','Name']]

# %%
#df_tickers.to_csv('Russell_2000.csv')

# %%
valuation_cols = ['symbol', 'marketCap','enterpriseValue','currentPrice', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow','earningsGrowth','enterpriseToRevenue', 'enterpriseToEbitda',
                  'forwardEps','trailingEps',  'priceToSalesTrailing12Months', 
                  'forwardPE', 'dividendYield']

# %%
ticker_list = df_tickers['Ticker'].to_list()

# %%
type(ticker_list)
# Out:
# list

# %%
def ticker_convert(tick):
    ticker = yf.Ticker(tick)
    ticker_df = pd.DataFrame([ticker.info])
    ticker_df.to_csv(f'{tick}.csv')
    df_ticker = pd.read_csv(f'{tick}.csv')
    ticker_val = df_ticker[valuation_cols]
    return ticker_val

# %%
tickers_df = map(ticker_convert,ticker_list)
master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    master_df.append(df)
master_df = pd.concat(master_df)
master_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-a1cb6bbe72b7> in <module>
#       1 tickers_df = map(ticker_convert,ticker_list)
#       2 master_df = []
# ----> 3 for i in tickers_df:
#       4     df = pd.DataFrame(i)
#       5     master_df.append(df)
#
# <ipython-input-48-74b7647089fe> in ticker_convert(tick)
#       1 def ticker_convert(tick):
#       2     ticker = yf.Ticker(tick)
# ----> 3     ticker_df = pd.DataFrame([ticker.info])
#       4     ticker_df.to_csv(f'{tick}.csv')
#       5     df_ticker = pd.read_csv(f'{tick}.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/yfinance/ticker.py in info(self)
#     141     @property
#     142     def info(self):
# --> 143         return self.get_info()
#     144
#     145     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
# ...

# %%
master_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-2872bfc9051c> in <module>
# ----> 1 master_df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
ticker_convert('AMKR')
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   AMKR  4685069824       5002227712         19.14              29.5
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            18.05           0.408                0.781                3.55
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        2.84        2.819                      0.731015   6.739437
#
#    dividendYield
# 0         0.0105

# %%
import glob
import os

# %%
csv_list = glob.glob('/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/*.csv')

# %%
csv_list
# Out:
# ['/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BVH.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BXC.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BBIO.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/AMSC.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BTAI.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BV.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/AMKR.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/ASLE.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/ATGE.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/AXSM.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BOOT.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/AMSWA.csv',
#  '/Users/brendan/Desktop/Python/May 2022/yf_SP500/R2000_tickers/BW.csv',
# ...

# %%
def file_list(files):
    for i in files:
        file_list = os.path.basename(f'{i}')
    return file_list

# %%
file_paths = file_list(csv_list)
file_paths
# Out:
# 'ARGO.csv'

# %%
files_list = map(file_list,ticker_list)
master_df = []
for i in file_list:
    df = pd.read_csv(i)
    master_df.append(df)
master_df = pd.concat(master_df)
master_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-d9b085dc7bf0> in <module>
#       1 files_list = map(file_list,ticker_list)
#       2 master_df = []
# ----> 3 for i in file_list:
#       4     df = pd.read_csv(i)
#       5     master_df.append(df)
#
# TypeError: 'function' object is not iterable

# %%
all_files = map(file_list,csv_list)

for i in all_files:
    print(i)
# Out:
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v
# v

# %%
tickers_csv = map(file_list, csv_list)
files_df = []
for i in tickers_csv:
    df = pd.read_csv(i)
    files_df.append(df)
files_df = pd.concat(files_df)
files_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-90-fc1a49adbddc> in <module>
#       2 files_df = []
#       3 for i in tickers_csv:
# ----> 4     df = pd.read_csv(i)
#       5     files_df.append(df)
#       6 files_df = pd.concat(files_df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
tickers_df = map(ticker_convert,ticker_list)
master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    master_df.append(df)
master_df = pd.concat(master_df)
master_df

# %%
files_df = []
for i in all_files:
    df = pd.read_csv(f'{i}')
    files_df.append(df)
files_df = pd.concat(files_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-a5ad2e280dce> in <module>
#       2 files_df = []
#       3 for i in all_files:
# ----> 4     df = pd.read_csv(f'{i}')
#       5     files_df.append(df)
#       6 files_df = pd.concat(files_df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
