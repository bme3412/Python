# %%
import requests
url = "https://rest.yahoofinanceapi.com/v6/finance/quote"
querystring = {'symbols':'AAPL,BTC-USD,MSFT'}
headers = {'x-api-key':'n2dqkAuQWt9w2a9LzNpWI5qfNlPtbiNoXpH6HjIf'}

response = requests.request("GET", url, headers=headers,
                           params=querystring)

# %%
import yfinance as yf
GetAAPLInfo = yf.Ticker("AAPL")

# %%
# display Company Sector
print("Company Sector: ", GetAAPLInfo.info['sector'])
# Out:
# Company Sector:  Technology

# %%
# dispaly P/E ratio
print("Price Earnings Ratio: ", GetAAPLInfo.info['trailingPE'])
# Out:
# Price Earnings Ratio:  28.594362

# %%
# get all value pairs that are available:
for key, value in GetAAPLInfo.info.items():
    print(key, ":", value)
# Out:
# zip : 95014
# sector : Technology
# fullTimeEmployees : 147000
# ...

# %%
# get historical market prices
print(GetAAPLInfo.history(period="3mo"))
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-06-18  130.514458  131.313248  130.045159  130.264832  108953300
# 2021-06-21  130.105073  132.211917  129.016708  132.102081   79663300
# 2021-06-22  131.932333  133.879413  131.423086  133.779556   74783600
# 2021-06-23  133.569887  134.119068  133.030687  133.499985   60214200
# 2021-06-24  134.248856  134.438574  132.731126  133.210419   68711000
# ...                ...         ...         ...         ...        ...
# 2021-09-13  150.630005  151.419998  148.750000  149.550003  102404300
# 2021-09-14  150.350006  151.070007  146.910004  148.119995  109296300
# 2021-09-15  148.559998  149.440002  146.369995  149.029999   83281300
# 2021-09-16  148.440002  148.970001  147.220001  148.789993   68034100
# 2021-09-17  148.820007  148.820007  145.759995  146.059998  129728700
#
#             Dividends  Stock Splits
# Date
# 2021-06-18        0.0             0
# 2021-06-21        0.0             0
# ...

# %%
# get historical market data for the provided start and end datesa
import datetime as dt

# create startDate
startDate = datetime.datetime(2019, 5, 31)
# create endDate
endDate = datetime.datetime(2021, 1, 30)

print(GetAAPLInfo.history(start = startDate, end=endDate))
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2019-05-31   43.181805   43.613062   42.877969   42.897572  108174400
# 2019-06-03   43.027439   43.595909   41.721424   42.463867  161584400
# 2019-06-04   42.988224   44.063910   42.762796   44.017353  123872000
# 2019-06-05   45.154295   45.328268   44.384898   44.727940  119093600
# 2019-06-06   44.860258   45.445882   44.632378   45.384624   90105200
# ...                ...         ...         ...         ...        ...
# 2021-01-25  142.400940  144.411483  135.901464  142.251633  157611700
# 2021-01-26  142.928469  143.625193  140.708887  142.490524   98390600
# 2021-01-27  142.759249  143.625191  139.753383  141.395660  140843800
# 2021-01-28  138.867542  141.325993  136.060723  136.448898  142621100
# 2021-01-29  135.194777  136.100525  129.601064  131.342880  177523800
#
#             Dividends  Stock Splits
# Date
# 2019-05-31        0.0           0.0
# 2019-06-03        0.0           0.0
# ...

# %%
from pandas_datareader import data as pdr
yf.pdr_override()

# download dataframe
data = pdr.get_data_yahoo("AAPL",start='2018-01-01', end='2018-12-31')
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-02  42.540001  43.075001  42.314999  43.064999  41.248272  102223600
# 2018-01-03  43.132500  43.637501  42.990002  43.057499  41.241089  118071600
# 2018-01-04  43.134998  43.367500  43.020000  43.257500  41.432659   89738400
# 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.904385   94640000
# 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.748737   82271200

# %%
msft = yf.Ticker("MSFT")
msft_info = msft.info

# %%
msft_dividends = msft.dividends.to_frame()
msft_dividends
# Out:
#             Dividends
# Date
# 2003-02-19       0.08
# 2003-10-15       0.16
# 2004-08-23       0.08
# 2004-11-15       3.08
# 2005-02-15       0.08
# ...               ...
# 2020-08-19       0.51
# 2020-11-18       0.56
# 2021-02-17       0.56
# 2021-05-19       0.56
# 2021-08-18       0.56
#
# [71 rows x 1 columns]

# %%
msft_financials = msft.financials
msft_financials.head()
# Out:
#                                  2021-06-30     2020-06-30     2019-06-30  \
# Research Development          20716000000.0  19269000000.0  16876000000.0
# Effect Of Accounting Charges           None           None           None
# Income Before Tax             71102000000.0  53036000000.0  43688000000.0
# Minority Interest                      None           None           None
# Net Income                    61271000000.0  44281000000.0  39240000000.0
#
#                                  2018-06-30
# Research Development          14726000000.0
# Effect Of Accounting Charges           None
# Income Before Tax             36474000000.0
# Minority Interest                      None
# Net Income                    16571000000.0

# %%
msft_qrtly_financials = msft.quarterly_financials
msft_qrtly_financials.head(25)
# Out:
#                                            2021-06-30     2021-03-31  \
# Research Development                     5687000000.0   5204000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       19405000000.0  17236000000.0
# Minority Interest                                None           None
# Net Income                              16458000000.0  15457000000.0
# Selling General Administrative           7379000000.0   6409000000.0
# Gross Profit                            32161000000.0  28661000000.0
# Ebit                                    19095000000.0  17048000000.0
# Operating Income                        19095000000.0  17048000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -549000000.0   -628000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
msft_qrtly_financials.columns
# Out:
# DatetimeIndex(['2021-06-30', '2021-03-31', '2020-12-31', '2020-09-30'], dtype='datetime64[ns]', name='', freq=None)

# %%
msft_qrtly_financials.index
# Out:
# Index(['Research Development', 'Effect Of Accounting Charges',
#        'Income Before Tax', 'Minority Interest', 'Net Income',
#        'Selling General Administrative', 'Gross Profit', 'Ebit',
#        'Operating Income', 'Other Operating Expenses', 'Interest Expense',
#        'Extraordinary Items', 'Non Recurring', 'Other Items',
#        'Income Tax Expense', 'Total Revenue', 'Total Operating Expenses',
#        'Cost Of Revenue', 'Total Other Income Expense Net',
#        'Discontinued Operations', 'Net Income From Continuing Ops',
#        'Net Income Applicable To Common Shares'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
revenue = msft.quarterly_financials.loc['Total Revenue'].to_frame()
revenue
# Out:
#             Total Revenue
#
# 2021-06-30  46152000000.0
# 2021-03-31  41706000000.0
# 2020-12-31  43076000000.0
# 2020-09-30  37154000000.0

# %%
nasdaq_sym = pdr.get_nasdaq_symbols()
nasdaq_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZY               True                       Zymergen Inc. - Common Stock
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
nasdaq_sym.loc['AAPL']
# Out:
# Nasdaq Traded                            True
# Security Name       Apple Inc. - Common Stock
# Listing Exchange                            Q
# Market Category                             Q
# ETF                                     False
# Round Lot Size                          100.0
# Test Issue                              False
# Financial Status                            N
# CQS Symbol                                NaN
# NASDAQ Symbol                            AAPL
# NextShares                              False
# Name: AAPL, dtype: object

# %%
ticker='AAPL'
start = dt.datetime(2019, 1, 1)
data2 = pdr.get_data_stooq(ticker, start)
data2
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2021-09-17  148.820  148.820  145.760  146.060  129868824
# 2021-09-16  148.440  148.970  147.221  148.790   68034149
# 2021-09-15  148.560  149.440  146.370  149.030   83281315
# 2021-09-14  150.350  151.070  146.910  148.120  109296295
# 2021-09-13  150.630  151.420  148.750  149.550  102404329
# ...             ...      ...      ...      ...        ...
# 2019-01-08   36.352   36.901   36.098   36.636  168794736
# 2019-01-07   36.140   36.172   35.461   35.951  225377881
# 2019-01-04   35.128   36.106   34.951   36.034  241133189
# 2019-01-03   34.995   35.415   34.512   34.559  375695298
# 2019-01-02   37.649   38.606   37.484   38.382  152396455
#
# [684 rows x 5 columns]
