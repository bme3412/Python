# %%
import pandas as pd
import yfinance as yf

# %%
GOOG = yf.Ticker('GOOG')
GOOG_df = pd.DataFrame([GOOG.info])
GOOG_df.to_csv('GOOG.csv')

ATVI = yf.Ticker('ATVI')
ATVI_df = pd.DataFrame([ATVI.info])
ATVI_df.to_csv('ATVI.csv')

GOOGL = yf.Ticker('GOOGL')
GOOGL_df = pd.DataFrame([GOOGL.info])
GOOGL_df.to_csv('GOOGL.csv')

T = yf.Ticker('T')
T_df = pd.DataFrame([T.info])
T_df.to_csv('T.csv')

CHTR = yf.Ticker('CHTR')
CHTR_df = pd.DataFrame([CHTR.info])
CHTR_df.to_csv('CHTR.csv')

CMCSA = yf.Ticker('CMCSA')
CMCSA_df = pd.DataFrame([CMCSA.info])
CMCSA_df.to_csv('CMCSA.csv')

DISH = yf.Ticker('DISH')
DISH_df = pd.DataFrame([DISH.info])
DISH_df.to_csv('DISH.csv')

DIS = yf.Ticker('DIS')
DIS_df = pd.DataFrame([DIS.info])
DIS_df.to_csv('DIS.csv')

EA = yf.Ticker('EA')
EA_df = pd.DataFrame([EA.info])
EA_df.to_csv('EA.csv')

FOX = yf.Ticker('FOX')
FOX_df = pd.DataFrame([FOX.info])
FOX_df.to_csv('FOX.csv')

FOXA = yf.Ticker('FOXA')
FOXA_df = pd.DataFrame([FOXA.info])
FOXA_df.to_csv('FOXA.csv')
#
IPG = yf.Ticker('IPG')
IPG_df = pd.DataFrame([IPG.info])
IPG_df.to_csv('IPG.csv')

LYV = yf.Ticker('LYV')
LYV_df = pd.DataFrame([LYV.info])
LYV_df.to_csv('LYV.csv')

LUMN = yf.Ticker('LUMN')
LUMN_df = pd.DataFrame([LUMN.info])
LUMN_df.to_csv('LUMN.csv')

MTCH = yf.Ticker('MTCH')
MTCH_df = pd.DataFrame([MTCH.info])
MTCH_df.to_csv('MTCH.csv')

FB = yf.Ticker('FB')
FB_df = pd.DataFrame([FB.info])
FB_df.to_csv('FB.csv')

NFLX = yf.Ticker('NFLX')
NFLX_df = pd.DataFrame([NFLX.info])
NFLX_df.to_csv('NFLX.csv')

NWSA = yf.Ticker('NWSA')
NWSA_df = pd.DataFrame([NWSA.info])
NWSA_df.to_csv('NWSA.csv')

NWS = yf.Ticker('NWS')
NWS_df = pd.DataFrame([NWS.info])
NWS_df.to_csv('NWS.csv')

OMC = yf.Ticker('OMC')
OMC_df = pd.DataFrame([OMC.info])
OMC_df.to_csv('OMC.csv')

PARA = yf.Ticker('PARA')
PARA_df = pd.DataFrame([PARA.info])
PARA_df.to_csv('PARA.csv')

TMUS = yf.Ticker('TMUS')
TMUS_df = pd.DataFrame([TMUS.info])
TMUS_df.to_csv('TMUS.csv')

#
TTWO = yf.Ticker('TTWO')
TTWO_df = pd.DataFrame([TTWO.info])
TTWO_df.to_csv('TTWO.csv')

TWTR = yf.Ticker('TWTR')
TWTR_df = pd.DataFrame([TWTR.info])
TWTR_df.to_csv('TWTR.csv')

VZ = yf.Ticker('VZ')
VZ_df = pd.DataFrame([VZ.info])
VZ_df.to_csv('VZ.csv')

WBD = yf.Ticker('WBD')
WBD_df = pd.DataFrame([WBD.info])
WBD_df.to_csv('WBD.csv')

# %%
df_ATVI = pd.read_csv('ATVI.csv')
df_GOOG = pd.read_csv('GOOG.csv')
df_GOOGL = pd.read_csv('GOOGL.csv')
df_CHTR = pd.read_csv('CHTR.csv')
df_DISH = pd.read_csv('DISH.csv')
df_DIS = pd.read_csv('DIS.csv')
df_EA = pd.read_csv('EA.csv')
df_CMCSA = pd.read_csv('CMCSA.csv')
df_FOX = pd.read_csv('FOX.csv')
df_FOXA = pd.read_csv('FOXA.csv')
df_T = pd.read_csv('T.csv')

df_IPG = pd.read_csv('IPG.csv')
df_LYV = pd.read_csv('LYV.csv')
df_LUMN = pd.read_csv('LUMN.csv')
df_MTCH = pd.read_csv('MTCH.csv')
df_FB = pd.read_csv('FB.csv')
df_NFLX = pd.read_csv('NFLX.csv')

df_NWSA = pd.read_csv('NWSA.csv')
df_NWS = pd.read_csv('NWS.csv')
df_OMC = pd.read_csv('OMC.csv')
df_PARA = pd.read_csv('PARA.csv')
df_TMUS = pd.read_csv('TMUS.csv')
df_TTWO = pd.read_csv('TTWO.csv')
df_TWTR = pd.read_csv('TWTR.csv')
df_VZ = pd.read_csv('VZ.csv')
df_WBD = pd.read_csv('WBD.csv')

# %%
valuation_cols = ['symbol', 'marketCap','enterpriseValue','currentPrice', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow','earningsGrowth','enterpriseToRevenue', 'enterpriseToEbitda',
                  'forwardEps','trailingEps',  'priceToSalesTrailing12Months', 
                  'forwardPE', 'dividendYield']

# %%
ATVI_val = df_ATVI[valuation_cols]
GOOG_val = df_GOOG[valuation_cols]
GOOGL_val = df_GOOGL[valuation_cols]
CHTR_val = df_CHTR[valuation_cols]
T_val = df_T[valuation_cols]
DISH_val = df_DISH[valuation_cols]
DIS_val = df_DIS[valuation_cols]
EA_val = df_EA[valuation_cols]
CMCSA_val = df_CMCSA[valuation_cols]
FOX_val = df_FOX[valuation_cols]
FOXA_val = df_FOXA[valuation_cols]
df_IPG  = df_IPG[valuation_cols]
df_LYV = df_LYV[valuation_cols]
df_LUMN = df_LUMN[valuation_cols]
df_MTCH = df_MTCH[valuation_cols]
df_FB = df_FB[valuation_cols]
df_NFLX = df_NFLX[valuation_cols]
df_NWSA = df_NWSA[valuation_cols]
df_NWS = df_NWS[valuation_cols]
df_OMC = df_OMC[valuation_cols]
df_PARA = df_PARA[valuation_cols]
df_TMUS = df_TMUS[valuation_cols]
df_TTWO = df_TTWO[valuation_cols]
df_TWTR = df_TWTR[valuation_cols]
df_VZ = df_VZ[valuation_cols]
df_WBD = df_WBD[valuation_cols]

# %%
type(ATVI_val)
# Out:
# pandas.core.frame.DataFrame

# %%
df_comm_serve_val_list = [ATVI_val, GOOG_val, GOOGL_val, CHTR_val, T_val, DIS_val, DISH_val, EA_val, CMCSA_val, FOX_val, FOXA_val,
                         df_IPG, df_LUMN, df_LYV, df_MTCH, df_FB, df_NFLX, df_NWS, df_NWSA, df_OMC, df_PARA, df_TMUS, df_TTWO,
                         df_TWTR, df_VZ, df_WBD]




df_comm_serve_val = pd.concat(df_comm_serve_val_list)

# %%
df_comm_serve_val
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ATVI  6.036121e+10      52990627840         77.20         99.460000
# 0   GOOG  1.467791e+12    1334283993088       2233.33       3042.000000
# 0  GOOGL  1.470895e+12    1328950149120       2229.76       3030.930000
# 0   CHTR  9.070449e+10     177359159296        473.67        825.620000
# 0      T  1.486924e+11     362527588352         20.77         22.779455
# 0    DIS  1.926944e+11     238684372992        105.79        187.580000
# 0   DISH  1.094970e+10      31659296768         20.66         46.310000
# 0     EA  3.761907e+10      35559559168        133.77        148.930000
# 0  CMCSA  1.921028e+11     280924127232         42.88         61.800000
# 0    FOX  1.840711e+10      20478826496         31.62         40.910000
# 0   FOXA  1.840424e+10      24571428864         33.46         44.950000
# 0    IPG  1.229019e+10      14508081152         31.22         39.980000
# ...

# %%
df_comm_serve_val.isna().sum()
# Out:
# symbol                           0
# marketCap                        2
# enterpriseValue                  0
# currentPrice                     0
# fiftyTwoWeekHigh                 0
# fiftyTwoWeekLow                  0
# earningsGrowth                   4
# enterpriseToRevenue              0
# enterpriseToEbitda               0
# forwardEps                       3
# trailingEps                      2
# priceToSalesTrailing12Months     2
# forwardPE                        3
# dividendYield                   13
# dtype: int64
