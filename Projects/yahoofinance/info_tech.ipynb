# %%
import pandas as pd
import yfinance as yf

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = df[0]
df_tech = df[df['GICS Sector']=='Information Technology']

# %%
len(df_tech)
df_tech.head(2)
# Out:
#   Symbol   Security SEC filings             GICS Sector  \
# 5    ACN  Accenture     reports  Information Technology
# 8   ADBE      Adobe     reports  Information Technology
#
#                 GICS Sub-Industry Headquarters Location Date first added  \
# 5  IT Consulting & Other Services       Dublin, Ireland       2011-07-06
# 8            Application Software  San Jose, California       1997-05-05
#
#        CIK Founded
# 5  1467373    1989
# 8   796343    1982

# %%
valuation_cols = ['symbol', 'marketCap','enterpriseValue','currentPrice', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow','earningsGrowth','enterpriseToRevenue', 'enterpriseToEbitda',
                  'forwardEps','trailingEps',  'priceToSalesTrailing12Months', 
                  'forwardPE', 'dividendYield']

# %%
df_tech['Symbol'].to_list()
# Out:
# ['ACN',
#  'ADBE',
#  'ADP',
#  'AKAM',
#  'AMD',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AAPL',
#  'AMAT',
#  'ANET',
#  'ADSK',
#  'AVGO',
#  'BR',
#  'CDNS',
#  'CDW',
#  'CDAY',
#  'CSCO',
#  'CTXS',
#  'CTSH',
#  'GLW',
#  'DXC',
#  'ENPH',
#  'EPAM',
#  'FFIV',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FTNT',
#  'IT',
#  'GPN',
#  'HPE',
#  'HPQ',
#  'INTC',
#  'IBM',
#  'INTU',
#  'IPGP',
#  'JKHY',
#  'JNPR',
#  'KEYS',
#  'KLAC',
#  'LRCX',
#  'MA',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MPWR',
#  'MSI',
#  'NTAP',
#  'NLOK',
#  'NVDA',
#  'NXPI',
#  'ORCL',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PTC',
#  'QRVO',
#  'QCOM',
#  'CRM',
#  'STX',
#  'NOW',
#  'SWKS',
#  'SEDG',
#  'SNPS',
#  'TEL',
#  'TER',
#  'TXN',
#  'TRMB',
#  'TYL',
#  'VRSN',
#  'V',
#  'WDC',
#  'ZBRA']

# %%
ACN = yf.Ticker('ACN')
ACN_df = pd.DataFrame([ACN.info])
ACN_df.to_csv('ACN.csv')
df_ACN = pd.read_csv('ACN.csv')
ACN_val = df_ACN[valuation_cols]
ACN_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    ACN  179643482112     173908262912        283.39            417.37
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           268.17           0.139                3.067              18.284
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       11.53        9.923                      3.168599  24.578493
#
#    dividendYield
# 0          0.014

# %%
ADBE = yf.Ticker('ADBE')
ADBE_df = pd.DataFrame([ADBE.info])
ADBE_df.to_csv('ADBE.csv')
df_ADBE = pd.read_csv('ADBE.csv')
ADBE_val = df_ADBE[valuation_cols]
ADBE_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ADBE  192194101248     188534030336        406.76            699.54
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           370.27           0.019                11.68              28.912
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        16.1       10.068                     11.906462  25.264597
#
#    dividendYield
# 0            NaN

# %%
ADP = yf.Ticker('ADP')
ADP_df = pd.DataFrame([ADP.info])
ADP_df.to_csv('ADP.csv')
df_ADP = pd.read_csv('ADP.csv')
ADP_val = df_ADP[valuation_cols]
ADP_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    ADP  88963407872      88935464960        212.96            248.96
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           192.18           0.163                5.521              21.072
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.73        6.774                       5.52307  27.549807
#
#    dividendYield
# 0         0.0199

# %%
AKAM = yf.Ticker('AKAM')
AKAM_df = pd.DataFrame([AKAM.info])
AKAM_df.to_csv('AKAM.csv')
df_AKAM = pd.read_csv('AKAM.csv')
AKAM_val = df_AKAM[valuation_cols]
AKAM_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   AKAM  15850956800      18368784384         98.88            123.25
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            93.74          -0.223                5.215              15.221
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        6.16        3.723                      4.500349  16.051949
#
#    dividendYield
# 0            NaN

# %%
AMD = yf.Ticker('AMD')
AMD_df = pd.DataFrame([AMD.info])
AMD_df.to_csv('AMD.csv')
df_AMD = pd.read_csv('AMD.csv')
AMD_val = df_AMD[valuation_cols]
AMD_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    AMD  154061881344     147142492160         95.07            164.46
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0             76.8           0.244                7.795              30.289
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0           5        2.665                      8.161786     19.014
#
#    dividendYield
# 0            NaN

# %%
APH = yf.Ticker('APH')
APH_df = pd.DataFrame([APH.info])
APH_df.to_csv('APH.csv')
df_APH = pd.read_csv('APH.csv')
APH_val = df_APH[valuation_cols]
APH_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    APH  41441378304      44572487680          69.4             88.45
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            65.84           0.283                3.892              16.487
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        3.05        2.694                      3.618987  22.754099
#
#    dividendYield
# 0         0.0117

# %%
ADI = yf.Ticker('ADI')
ADI_df = pd.DataFrame([ADI.info])
ADI_df.to_csv('ADI.csv')
df_ADI = pd.read_csv('ADI.csv')
ADI_val = df_ADI[valuation_cols]
ADI_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    ADI  84541538304      88952774656        161.55            191.95
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           143.81           0.307                9.119              20.828
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       10.06        3.419                       8.66668  16.058647
#
#    dividendYield
# 0         0.0187

# %%
ANSS = yf.Ticker('ANSS')
ANSS_df = pd.DataFrame([ANSS.info])
ANSS_df.to_csv('ANSS.csv')
df_ANSS = pd.read_csv('ANSS.csv')
ANSS_val = df_ANSS[valuation_cols]
ANSS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ANSS  22132889600      22166970368        254.43            413.89
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           230.72          -0.012                11.26              33.633
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.76        5.151                     11.243154   29.04452
#
#    dividendYield
# 0            NaN

# %%
AAPL = yf.Ticker('AAPL')
AAPL_df = pd.DataFrame([AAPL.info])
AAPL_df.to_csv('AAPL.csv')
df_AAPL = pd.read_csv('AAPL.csv')
AAPL_val = df_AAPL[valuation_cols]
AAPL_val.head()
# Out:
#   symbol      marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   AAPL  2316264013824    2295388962816        143.11            182.94
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           123.13           0.086                5.946              17.571
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        6.56        6.137                       6.00042   21.81555
#
#    dividendYield
# 0         0.0067

# %%
ANET = yf.Ticker('ANET')
ANET_df = pd.DataFrame([ANET.info])
ANET_df.to_csv('ANET.csv')
df_ANET = pd.read_csv('ANET.csv')
ANET_val = df_ANET[valuation_cols]
ANET_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ANET  31436791808      28273729536         102.3            148.57
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            82.94           0.491                8.954              26.999
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        4.26         2.91                      9.956099  24.014084
#
#    dividendYield
# 0            NaN

# %%
AMAT = yf.Ticker('AMAT')
AMAT_df = pd.DataFrame([AMAT.info])
AMAT_df.to_csv('AMAT.csv')
df_AMAT = pd.read_csv('AMAT.csv')
AMAT_val = df_AMAT[valuation_cols]
AMAT_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   AMAT  97111613440      95004876800        109.93            167.06
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           101.33           0.217                3.825              11.374
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0         8.8        7.488                      3.910272  12.492045
#
#    dividendYield
# 0         0.0092

# %%
ADSK = yf.Ticker('ADSK')
ADSK_df = pd.DataFrame([ADSK.info])
ADSK_df.to_csv('ADSK.csv')
df_ADSK = pd.read_csv('ADSK.csv')
ADSK_val = df_ADSK[valuation_cols]
ADSK_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ADSK  39918379008      42890817536        183.51            344.39
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           173.93          -0.901                9.778               51.92
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.04         2.24                      9.100487  22.824627
#
#    dividendYield
# 0            NaN

# %%
AVGO = yf.Ticker('AVGO')
AVGO_df = pd.DataFrame([AVGO.info])
AVGO_df.to_csv('AVGO.csv')
df_AVGO = pd.read_csv('AVGO.csv')
AVGO_val = df_AVGO[valuation_cols]
AVGO_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   AVGO  224269025280     255658999808        543.19            677.76
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           455.53           0.833                 8.97                16.3
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       36.05           15                      7.868813  15.067684
#
#    dividendYield
# 0         0.0279

# %%
BR = yf.Ticker('BR')
BR_df = pd.DataFrame([BR.info])
BR_df.to_csv('BR.csv')
df_BR = pd.read_csv('BR.csv')
BR_val = df_BR[valuation_cols]
BR_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0     BR  16202009600      20994430976        138.98             185.4
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           132.68          -0.167                3.907              18.797
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.04        4.655                      3.014945  19.741476
#
#    dividendYield
# 0         0.0184

# %%
CDNS = yf.Ticker('CDNS')
CDNS_df = pd.DataFrame([CDNS.info])
CDNS_df.to_csv('CDNS.csv')
df_CDNS = pd.read_csv('CDNS.csv')
CDNS_val = df_CDNS[valuation_cols]
CDNS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   CDNS  40628871168      40811286528         146.6             192.7
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           122.04           0.269                12.94               39.46
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        3.56         2.48                      12.88177   41.17978
#
#    dividendYield
# 0            NaN

# %%
CDW = yf.Ticker('CDW')
CDW_df = pd.DataFrame([CDW.info])
CDW_df.to_csv('CDW.csv')
df_CDW = pd.read_csv('CDW.csv')
CDW_val = df_CDW[valuation_cols]
CDW_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    CDW  21787455488      28612837376        161.25            208.71
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           155.39           0.123                1.305              16.311
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       10.53        7.243                      0.993391  15.313391
#
#    dividendYield
# 0         0.0125

# %%
CDAY = yf.Ticker('CDAY')
CDAY_df = pd.DataFrame([CDAY.info])
CDAY_df.to_csv('CDAY.csv')
df_CDAY = pd.read_csv('CDAY.csv')
CDAY_val = df_CDAY[valuation_cols]
CDAY_val.head()
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   CDAY  8565335040       9343748096          56.6            130.37
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            48.93             NaN                9.123             841.779
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        0.45       -0.561                      8.362951  125.77778
#
#    dividendYield
# 0            NaN

# %%
CSCO = yf.Ticker('CSCO')
CSCO_df = pd.DataFrame([CSCO.info])
CSCO_df.to_csv('CSCO.csv')
df_CSCO = pd.read_csv('CSCO.csv')
CSCO_val = df_CSCO[valuation_cols]
CSCO_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   CSCO  181104164864     194965143552         42.94             64.29
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            41.02           0.183                3.782              12.193
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        3.68         2.69                      3.513243  11.668478
#
#    dividendYield
# 0         0.0307

# %%
CTXS = yf.Ticker('CTXS')
CTXS_df = pd.DataFrame([CTXS.info])
CTXS_df.to_csv('CTXS.csv')
df_CTXS = pd.read_csv('CTXS.csv')
CTXS_val = df_CTXS[valuation_cols]
CTXS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   CTXS  12381251584      15305981952         99.78            121.87
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            78.07          -0.338                4.685              25.593
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.77        2.199                      3.848492  18.908571
#
#    dividendYield
# 0         0.0149

# %%
CTSH = yf.Ticker('CTSH')
CTSH_df = pd.DataFrame([CTSH.info])
CTSH_df.to_csv('CTSH.csv')
df_CTSH = pd.read_csv('CTSH.csv')
CTSH_val = df_CTSH[valuation_cols]
CTSH_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   CTSH  37441138688      36202741760         71.84             93.47
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            66.19           0.126                1.912              10.614
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.04         4.17                      1.977664  14.253967
#
#    dividendYield
# 0         0.0152

# %%
GLW = yf.Ticker('GLW')
GLW_df = pd.DataFrame([GLW.info])
GLW_df.to_csv('GLW.csv')
df_GLW = pd.read_csv('GLW.csv')
GLW_val = df_GLW[valuation_cols]
GLW_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    GLW  28273408000      34304129024         33.13              44.3
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           32.235           0.019                 2.37               8.866
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        2.32        1.004                      1.953663  14.280173
#
#    dividendYield
# 0         0.0304

# %%
DXC = yf.Ticker('DXC')
DXC_df = pd.DataFrame([DXC.info])
DXC_df.to_csv('DXC.csv')
df_DXC = pd.read_csv('DXC.csv')
DXC_val = df_DXC[valuation_cols]
DXC_val.head()
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    DXC  7466274816      10545514496          29.6             44.18
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            27.28          -0.911                0.634               5.487
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0         4.3         1.52                       0.44864   6.883721
#
#    dividendYield
# 0            NaN

# %%
ENPH = yf.Ticker('ENPH')
ENPH_df = pd.DataFrame([ENPH.info])
ENPH_df.to_csv('ENPH.csv')
df_ENPH = pd.read_csv('ENPH.csv')
ENPH_val = df_ENPH[valuation_cols]
ENPH_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ENPH  22698944512      22035568640        168.25            282.46
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            113.4           0.703               14.482              84.994
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        2.98        1.152                     14.917941  56.459732
#
#    dividendYield
# 0            NaN

# %%
EPAM = yf.Ticker('EPAM')
EPAM_df = pd.DataFrame([EPAM.info])
EPAM_df.to_csv('EPAM.csv')
df_EPAM = pd.read_csv('EPAM.csv')
EPAM_val = df_EPAM[valuation_cols]
EPAM_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   EPAM  18172393472      13873497088        320.39             725.4
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           168.59           0.644                3.692              22.084
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       11.17        7.211                       4.83547   28.68308
#
#    dividendYield
# 0            NaN

# %%
FISV = yf.Ticker('FISV')
FISV_df = pd.DataFrame([FISV.info])
FISV_df.to_csv('FISV.csv')
df_FISV = pd.read_csv('FISV.csv')
FISV_val = df_FISV[valuation_cols]
FISV_val.head()

# %%
FFIV = yf.Ticker('FFIV')
FFIV_df = pd.DataFrame([FFIV.info])
FFIV_df.to_csv('FFIV.csv')
df_FFIV = pd.read_csv('FFIV.csv')
FFIV_val = df_FFIV[valuation_cols]
FFIV_val.head()
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   FFIV  9568930816       9871137792        156.28               249
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           151.66           0.314                3.718              18.315
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       13.18         5.34                       3.60434  11.857359
#
#    dividendYield
# 0            NaN

# %%
FIS = yf.Ticker('FIS')
FIS_df = pd.DataFrame([FIS.info])
FIS_df.to_csv('FIS.csv')
df_FIS = pd.read_csv('FIS.csv')
FIS_val = df_FIS[valuation_cols]
FIS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    FIS  60698841088      79492915200         99.68             152.2
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0               85           1.969                5.728              20.181
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.39         0.36                      4.374061  13.488499
#
#    dividendYield
# 0         0.0195

# %%
FLT = yf.Ticker('FLT')
FLT_df = pd.DataFrame([FLT.info])
FLT_df.to_csv('FLT.csv')
df_FLT = pd.read_csv('FLT.csv')
FLT_val = df_FLT[valuation_cols]
FLT_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    FLT  18763372544      24022804480        231.08            282.02
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           200.78           0.122                8.477              16.263
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       15.29        9.686                      6.621426  15.113146
#
#    dividendYield
# 0            NaN

# %%
FTNT = yf.Ticker('FTNT')
FTNT_df = pd.DataFrame([FTNT.info])
FTNT_df.to_csv('FTNT.csv')
df_FTNT = pd.read_csv('FTNT.csv')
FTNT_val = df_FTNT[valuation_cols]
FTNT_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   FTNT  46643277824      44997472256        285.28            371.77
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           211.53           0.348               13.463              61.623
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        4.61        3.322                      13.95586  61.882862
#
#    dividendYield
# 0            NaN

# %%
IT = yf.Ticker('IT')
IT_df = pd.DataFrame([IT.info])
IT_df.to_csv('IT.csv')
df_IT = pd.read_csv('IT.csv')
IT_val = df_IT[valuation_cols]
IT_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0     IT  20563038208      26456133632        250.04               369
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            228.2           0.881                5.589              23.045
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.13        8.025                      4.343727   35.06872
#
#    dividendYield
# 0            NaN

# %%
GPN = yf.Ticker('GPN')
GPN_df = pd.DataFrame([GPN.info])
GPN_df.to_csv('GPN.csv')
df_GPN = pd.read_csv('GPN.csv')
GPN_val = df_GPN[valuation_cols]
GPN_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    GPN  35427438592      49546457088         122.1            197.75
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            114.8           0.187                5.813              14.373
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        9.59        3.167                      4.156315  12.732012
#
#    dividendYield
# 0         0.0082

# %%
HPE = yf.Ticker('HPE')
HPE_df = pd.DataFrame([HPE.info])
HPE_df.to_csv('HPE.csv')
df_HPE = pd.read_csv('HPE.csv')
HPE_val = df_HPE[valuation_cols]
HPE_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    HPE  18315110400      31279091712         14.16             17.76
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            12.99           1.294                1.121               6.467
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        2.18         2.58                      0.656173   6.495412
#
#    dividendYield
# 0         0.0301

# %%
HPQ = yf.Ticker('HPQ')
HPQ_df = pd.DataFrame([HPQ.info])
HPQ_df.to_csv('HPQ.csv')
df_HPQ = pd.read_csv('HPQ.csv')
HPQ_val = df_HPQ[valuation_cols]
HPQ_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    HPQ  37516251136      43780136960         34.65             41.47
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            26.11           0.193                0.675               6.649
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        4.38         5.33                      0.578339   7.910959
#
#    dividendYield
# 0         0.0272

# %%
INTC = yf.Ticker('INTC')
INTC_df = pd.DataFrame([INTC.info])
INTC_df.to_csv('INTC.csv')
df_INTC = pd.read_csv('INTC.csv')
INTC_val = df_INTC[valuation_cols]
INTC_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   INTC  169390555136     176790503424         41.65             58.42
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            40.31           1.415                2.275               5.604
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0         3.7        5.158                      2.179946  11.256757
#
#    dividendYield
# 0         0.0335

# %%
IBM = yf.Ticker('IBM')
IBM_df = pd.DataFrame([IBM.info])
IBM_df.to_csv('IBM.csv')
df_IBM = pd.read_csv('IBM.csv')
IBM_val = df_IBM[valuation_cols]
IBM_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    IBM  115159187456     166039339008        128.48         146.11855
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           114.56          -0.239                2.845                13.7
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        10.3        5.283                      1.973222  12.473785
#
#    dividendYield
# 0         0.0494

# %%
INTU = yf.Ticker('INTU')
INTU_df = pd.DataFrame([INTU.info])
INTU_df.to_csv('INTU.csv')
df_INTU = pd.read_csv('INTU.csv')
INTU_val = df_INTU[valuation_cols]
INTU_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   INTU  104143159296     124250726400        367.78            716.86
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           339.36               4               10.886              39.697
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       13.64        7.581                       9.12416  26.963343
#
#    dividendYield
# 0         0.0073

# %%
IPGP = yf.Ticker('IPGP')
IPGP_df = pd.DataFrame([IPGP.info])
IPGP_df.to_csv('IPGP.csv')
df_IPGP = pd.read_csv('IPGP.csv')
IPGP_val = df_IPGP[valuation_cols]
IPGP_val.head()
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   IPGP  5335687680       3546220800        100.09            220.51
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            90.51            0.31                2.427               7.896
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.85        4.869                      3.652429  17.109402
#
#    dividendYield
# 0            NaN

# %%
JKHY = yf.Ticker('JKHY')
JKHY_df = pd.DataFrame([JKHY.info])
JKHY_df.to_csv('JKHY.csv')
df_JKHY = pd.read_csv('JKHY.csv')
JKHY_val = df_JKHY[valuation_cols]
JKHY_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   JKHY  13262223360      14073831424        179.12            205.37
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            147.5           0.383                7.542              28.146
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.15        4.302                       7.10724  34.780582
#
#    dividendYield
# 0         0.0112

# %%
JNPR = yf.Ticker('JNPR')
JNPR_df = pd.DataFrame([JNPR.info])
JNPR_df.to_csv('JNPR.csv')
df_JNPR = pd.read_csv('JNPR.csv')
JNPR_val = df_JNPR[valuation_cols]
JNPR_val.head()
# Out:
#   symbol   marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   JNPR  9387975680      10685168640         28.87             38.14
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            26.12             NaN                2.213              15.423
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        1.96         0.45                      1.944002  14.729592
#
#    dividendYield
# 0         0.0276

# %%
KLAC = yf.Ticker('KLAC')
KLAC_df = pd.DataFrame([KLAC.info])
KLAC_df.to_csv('KLAC.csv')
df_KLAC = pd.read_csv('KLAC.csv')
KLAC_val = df_KLAC[valuation_cols]
KLAC_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   KLAC  50866151424      48858214400        335.48            457.12
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           287.44            0.32                5.648               13.05
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       21.24       17.618                      5.880062  15.794727
#
#    dividendYield
# 0         0.0125

# %%
KEYS = yf.Ticker('KEYS')
KEYS_df = pd.DataFrame([KEYS.info])
KEYS_df.to_csv('KEYS.csv')
df_KEYS = pd.read_csv('KEYS.csv')
KEYS_val = df_KEYS[valuation_cols]
KEYS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   KEYS  25223188480      25562640384         137.8            209.08
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           127.93           0.348                5.101              17.989
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.48         4.78                      5.033564   18.42246
#
#    dividendYield
# 0            NaN

# %%
LRCX = yf.Ticker('LRCX')
LRCX_df = pd.DataFrame([LRCX.info])
LRCX_df.to_csv('LRCX.csv')
df_LRCX = pd.read_csv('LRCX.csv')
LRCX_val = df_LRCX[valuation_cols]
LRCX_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   LRCX  66755624960      65261465600        474.12            731.85
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           442.53          -0.015                3.899              11.775
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       36.65       29.588                      3.988586  12.936425
#
#    dividendYield
# 0         0.0122

# %%
MCHP = yf.Ticker('MCHP')
MCHP_df = pd.DataFrame([MCHP.info])
MCHP_df.to_csv('MCHP.csv')
df_MCHP = pd.read_csv('MCHP.csv')
MCHP_val = df_MCHP[valuation_cols]
MCHP_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   MCHP  36993245184      43838595072         66.67                90
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            63.34           8.023                6.803              15.892
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        4.91        1.143                      5.740905  13.578411
#
#    dividendYield
# 0         0.0165

# %%
MU = yf.Ticker('MU')
MU_df = pd.DataFrame([MU.info])
MU_df.to_csv('MU.csv')
df_MU = pd.read_csv('MU.csv')
MU_val = df_MU[valuation_cols]
MU_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0     MU  77179715584      73692512256          68.9             98.45
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            65.67           2.774                2.364               4.318
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       11.51        6.461                      2.476169   5.986099
#
#    dividendYield
# 0         0.0056

# %%
MA = yf.Ticker('MA')
MA_df = pd.DataFrame([MA.info])
MA_df.to_csv('MA.csv')
df_MA = pd.read_csv('MA.csv')
MA_val = df_MA[valuation_cols]
MA_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0     MA  330315988992     360853635072        336.18            399.92
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           305.61           0.464               18.137              30.555
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       10.53         8.13                      16.60213  31.925926
#
#    dividendYield
# 0         0.0059

# %%
MSFT = yf.Ticker('MSFT')
MSFT_df = pd.DataFrame([MSFT.info])
MSFT_df.to_csv('MSFT.csv')
df_MSFT = pd.read_csv('MSFT.csv')
MSFT_val = df_MSFT[valuation_cols]
MSFT_val.head()
# Out:
#   symbol      marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   MSFT  1896215347200    2048902299648        252.56            349.67
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0              243           0.094                10.64              21.571
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       10.54        8.939                      9.847553   23.96205
#
#    dividendYield
# 0         0.0095

# %%
MPWR = yf.Ticker('MPWR')
MPWR_df = pd.DataFrame([MPWR.info])
MPWR_df.to_csv('MPWR.csv')
df_MPWR = pd.read_csv('MPWR.csv')
MPWR_val = df_MPWR[valuation_cols]
MPWR_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   MPWR  19272404992      17523415040        418.12               580
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           326.39           0.647               14.509              58.934
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.53         4.46                     15.956646  49.017586
#
#    dividendYield
# 0         0.0069

# %%
MSI = yf.Ticker('MSI')
MSI_df = pd.DataFrame([MSI.info])
MSI_df.to_csv('MSI.csv')
df_MSI = pd.read_csv('MSI.csv')
MSI_val = df_MSI[valuation_cols]
MSI_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    MSI  35515658240      40217600000        210.28            273.65
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           199.24          -0.032                4.922              15.947
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        9.88        7.245                       4.34655    21.2834
#
#    dividendYield
# 0         0.0147

# %%
NTAP = yf.Ticker('NTAP')
NTAP_df = pd.DataFrame([NTAP.info])
NTAP_df.to_csv('NTAP.csv')
df_NTAP = pd.read_csv('NTAP.csv')
NTAP_val = df_NTAP[valuation_cols]
NTAP_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   NTAP  14812605440      15044795392         66.64             96.82
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            64.58           0.375                2.429              11.038
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.51        4.113                       2.39183  12.094374
#
#    dividendYield
# 0         0.0281

# %%
NLOK = yf.Ticker('NLOK')
NLOK_df = pd.DataFrame([NLOK.info])
NLOK_df.to_csv('NLOK.csv')
df_NLOK = pd.read_csv('NLOK.csv')
NLOK_val = df_NLOK[valuation_cols]
NLOK_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   NLOK  14142464000      16732807168         24.31             30.92
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            23.47            0.14                 6.08              12.754
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        1.97        1.496                      5.138977  12.340101
#
#    dividendYield
# 0         0.0209

# %%
NVDA = yf.Ticker('NVDA')
NVDA_df = pd.DataFrame([NVDA.info])
NVDA_df.to_csv('NVDA.csv')
df_NVDA = pd.read_csv('NVDA.csv')
NVDA_val = df_NVDA[valuation_cols]
NVDA_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   NVDA  416014499840     455410810880        166.94            346.47
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           151.76           1.034               16.921              40.607
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.21        3.243                     15.457178  32.042225
#
#    dividendYield
# 0         0.0009

# %%
NXPI = yf.Ticker('NXPI')
NXPI_df = pd.DataFrame([NXPI.info])
NXPI_df.to_csv('NXPI.csv')
df_NXPI = pd.read_csv('NXPI.csv')
NXPI_val = df_NXPI[valuation_cols]
NXPI_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   NXPI  47897190400      53111771136        180.11            239.91
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           164.75           1.074                4.801              13.875
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       12.02        5.585                      4.329494  14.984193
#
#    dividendYield
# 0         0.0195

# %%
ORCL = yf.Ticker('ORCL')
ORCL_df = pd.DataFrame([ORCL.info])
ORCL_df.to_csv('ORCL.csv')
df_ORCL = pd.read_csv('ORCL.csv')
ORCL_val = df_ORCL[valuation_cols]
ORCL_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ORCL  183272964096     251351728128         68.63            106.34
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            66.72            -0.5                6.009              13.661
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.26        3.543                      4.381691  13.047527
#
#    dividendYield
# 0          0.018

# %%
PAYX = yf.Ticker('PAYX')
PAYX_df = pd.DataFrame([PAYX.info])
PAYX_df.to_csv('PAYX.csv')
df_PAYX = pd.read_csv('PAYX.csv')
PAYX_val = df_PAYX[valuation_cols]
PAYX_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   PAYX  42327617536      45283831808        117.33            141.92
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            99.88           0.227               10.071              22.757
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        3.87         3.52                      9.413249  30.317831
#
#    dividendYield
# 0         0.0264

# %%
PAYC = yf.Ticker('PAYC')
PAYC_df = pd.DataFrame([PAYC.info])
PAYC_df.to_csv('PAYC.csv')
df_PAYC = pd.read_csv('PAYC.csv')
PAYC_val = df_PAYC[valuation_cols]
PAYC_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   PAYC  16614541312      16730388480        276.79            558.97
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           259.95               1                15.85               58.85
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.63         2.95                     15.740562   49.16341
#
#    dividendYield
# 0            NaN

# %%
PYPL = yf.Ticker('PYPL')
PYPL_df = pd.DataFrame([PYPL.info])
PYPL_df.to_csv('PYPL.csv')
df_PYPL = pd.read_csv('PYPL.csv')
PYPL_val = df_PYPL[valuation_cols]
PYPL_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   PYPL  94628864000     103888453632         80.54            310.16
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           71.831          -0.533                4.023              21.249
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.27        4.159                      3.664803  15.282733
#
#    dividendYield
# 0            NaN

# %%
PTC = yf.Ticker('PTC')
PTC_df = pd.DataFrame([PTC.info])
PTC_df.to_csv('PTC.csv')
df_PTC = pd.read_csv('PTC.csv')
PTC_val = df_PTC[valuation_cols]
PTC_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    PTC  13369041920      14526318592        113.42            153.73
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            96.55          -0.174                 7.73              28.633
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        5.06         4.03                      7.113951   22.41502
#
#    dividendYield
# 0            NaN

# %%
QRVO = yf.Ticker('QRVO')
QRVO_df = pd.DataFrame([QRVO.info])
QRVO_df.to_csv('QRVO.csv')
df_QRVO = pd.read_csv('QRVO.csv')
QRVO_val = df_QRVO[valuation_cols]
QRVO_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   QRVO  11971319808      13396545536        108.61            201.46
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            98.23           0.121                2.943               8.146
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       13.15        9.656                      2.629738   8.259315
#
#    dividendYield
# 0            NaN

# %%
QCOM = yf.Ticker('QCOM')
QCOM_df = pd.DataFrame([QCOM.info])
QCOM_df.to_csv('QCOM.csv')
df_QCOM = pd.read_csv('QCOM.csv')
QCOM_val = df_QCOM[valuation_cols]
QCOM_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   QCOM  147392004096     160586792960         131.6            193.58
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           122.17            0.68                 4.09              11.087
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       11.64         7.87                      3.753871  11.305842
#
#    dividendYield
# 0         0.0222

# %%
CRM = yf.Ticker('CRM')
CRM_df = pd.DataFrame([CRM.info])
CRM_df.to_csv('CRM.csv')
df_CRM = pd.read_csv('CRM.csv')
CRM_val = df_CRM[valuation_cols]
CRM_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    CRM  157255237632     178013601792        159.65            311.75
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           154.55             NaN                 6.72              58.098
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        4.71        1.818                      5.935952  33.895966
#
#    dividendYield
# 0            NaN

# %%
STX = yf.Ticker('STX')
STX_df = pd.DataFrame([STX.info])
STX_df.to_csv('STX.csv')
df_STX = pd.read_csv('STX.csv')
STX_val = df_STX[valuation_cols]
STX_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    STX  17837596672      22073798656         80.12            117.67
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            76.28           0.122                1.832               8.697
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        9.28        6.795                       1.48079   8.633621
#
#    dividendYield
# 0         0.0347

# %%
NOW = yf.Ticker('NOW')
NOW_df = pd.DataFrame([NOW.info])
NOW_df.to_csv('NOW.csv')
df_NOW = pd.read_csv('NOW.csv')
NOW_val = df_NOW[valuation_cols]
NOW_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    NOW  86172966912      94031495168        433.03             707.6
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           406.47          -0.098               15.026             131.697
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.22        1.091                     13.770049  59.976456
#
#    dividendYield
# 0            NaN

# %%
SWKS = yf.Ticker('SWKS')
SWKS_df = pd.DataFrame([SWKS.info])
SWKS_df.to_csv('SWKS.csv')
df_SWKS = pd.read_csv('SWKS.csv')
SWKS_val = df_SWKS[valuation_cols]
SWKS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   SWKS  17034861568      19951753216           103            197.62
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            97.59          -0.213                3.905                9.96
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0       12.87         8.97                      3.333959   8.003108
#
#    dividendYield
# 0         0.0216

# %%
SEDG = yf.Ticker('SEDG')
SEDG_df = pd.DataFrame([SEDG.info])
SEDG_df.to_csv('SEDG.csv')
df_SEDG = pd.read_csv('SEDG.csv')
SEDG_val = df_SEDG[valuation_cols]
SEDG_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   SEDG  13487533056      13244208128        256.81            389.71
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           200.86           1.249                6.744              53.399
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        6.92        2.666                      6.867852   37.11127
#
#    dividendYield
# 0            NaN

# %%
SNPS = yf.Ticker('SNPS')
SNPS_df = pd.DataFrame([SNPS.info])
SNPS_df.to_csv('SNPS.csv')
df_SNPS = pd.read_csv('SNPS.csv')
SNPS_val = df_SNPS[valuation_cols]
SNPS_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   SNPS  47062503424      43219197952        306.72             377.6
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0              244           0.932                9.595              37.855
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        9.02         4.81                     10.448751  34.004433
#
#    dividendYield
# 0            NaN

# %%
TEL = yf.Ticker('TEL')
TEL_df = pd.DataFrame([TEL.info])
TEL_df.to_csv('TEL.csv')
df_TEL = pd.read_csv('TEL.csv')
TEL_val = df_TEL[valuation_cols]
TEL_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    TEL  40032079872      43690319872        122.68            166.44
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           119.58            0.13                2.821              11.941
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        7.91        6.788                      2.584716  15.509482
#
#    dividendYield
# 0         0.0179

# %%
TER = yf.Ticker('TER')
TER_df = pd.DataFrame([TER.info])
TER_df.to_csv('TER.csv')
df_TER = pd.read_csv('TER.csv')
TER_val = df_TER[valuation_cols]
TER_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    TER  16686720000      16183294976        102.37            168.91
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            97.63          -0.156                4.402              12.537
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        6.45        5.309                      4.538572  15.871319
#
#    dividendYield
# 0         0.0041

# %%
TXN = yf.Ticker('TXN')
TXN_df = pd.DataFrame([TXN.info])
TXN_df.to_csv('TXN.csv')
df_TXN = pd.read_csv('TXN.csv')
TXN_val = df_TXN[valuation_cols]
TXN_val.head()
# Out:
#   symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    TXN  156823945216     154910294016        169.81            202.26
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            160.5           0.257                 8.17              14.562
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.23        7.788                      8.271306   20.63305
#
#    dividendYield
# 0         0.0271

# %%
TRMB = yf.Ticker('TRMB')
TRMB_df = pd.DataFrame([TRMB.info])
TRMB_df.to_csv('TRMB.csv')
df_TRMB = pd.read_csv('TRMB.csv')
TRMB_val = df_TRMB[valuation_cols]
TRMB_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   TRMB  16373253120      17879977984         65.23             96.49
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            59.89          -0.361                4.886              23.125
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        2.96        2.197                      4.474667  22.037163
#
#    dividendYield
# 0            NaN

# %%
TYL = yf.Ticker('TYL')
TYL_df = pd.DataFrame([TYL.info])
TYL_df.to_csv('TYL.csv')
df_TYL = pd.read_csv('TYL.csv')
TYL_val = df_TYL[valuation_cols]
TYL_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    TYL  14002831360      17453617152        341.73            557.55
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           327.97           0.068                9.953              50.622
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.15        3.825                      7.985223  41.930065
#
#    dividendYield
# 0            NaN

# %%
VRSN = yf.Ticker('VRSN')
VRSN_df = pd.DataFrame([VRSN.info])
VRSN_df.to_csv('VRSN.csv')
df_VRSN = pd.read_csv('VRSN.csv')
VRSN_val = df_VRSN[valuation_cols]
VRSN_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   VRSN  18390073344      20151259136        165.56            257.03
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           159.69           0.075               14.917              21.681
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        6.17        5.425                     13.613442  26.833063
#
#    dividendYield
# 0            NaN

# %%
V = yf.Ticker('V')
V_df = pd.DataFrame([V.info])
V_df.to_csv('V.csv')
df_V = pd.read_csv('V.csv')
V_val = df_V[valuation_cols]
V_val.head()
# Out:
#   symbol  marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0      V        NaN     454458212352        199.03            252.67
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0           186.67           0.234               16.871              23.895
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0         NaN          NaN                           NaN        NaN
#
#    dividendYield
# 0         0.0075

# %%
WDC = yf.Ticker('WDC')
WDC_df = pd.DataFrame([WDC.info])
WDC_df.to_csv('WDC.csv')
df_WDC = pd.read_csv('WDC.csv')
WDC_val = df_WDC[valuation_cols]
WDC_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    WDC  17703303168      21267910656         56.81             78.19
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0            43.85          -0.873                1.109               5.883
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        8.98         4.78                      0.922768   6.326281
#
#    dividendYield
# 0            NaN

# %%
ZBRA = yf.Ticker('ZBRA')
ZBRA_df = pd.DataFrame([ZBRA.info])
ZBRA_df.to_csv('ZBRA.csv')
df_ZBRA = pd.read_csv('ZBRA.csv')
ZBRA_val = df_ZBRA[valuation_cols]
ZBRA_val.head()
# Out:
#   symbol    marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0   ZBRA  17388261376      20450457600        325.37               615
#
#    fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# 0              309          -0.045                3.634               17.07
#
#    forwardEps  trailingEps  priceToSalesTrailing12Months  forwardPE  \
# 0        19.7       15.684                      3.090148  16.516243
#
#    dividendYield
# 0            NaN

# %%
df_tech_val_list = [ZBRA_val, WDC_val,V_val, VRSN_val, TEL_val, TYL_val, TXN_val, TRMB_val, TER_val,
                   SNPS_val, SEDG_val,SWKS_val,NOW_val,STX_val, CRM_val,QRVO_val, PAYC_val, PTC_val, PYPL_val,
                   PAYX_val, QCOM_val,ORCL_val,NXPI_val,NVDA_val,NLOK_val,NTAP_val, MSFT_val, MSI_val,MPWR_val,
                   MA_val, MU_val,MCHP_val, LRCX_val,KEYS_val, KLAC_val, JNPR_val, JKHY_val, IPGP_val,INTU_val, IBM_val,
                   INTC_val,HPQ_val, HPE_val,GPN_val, IT_val, FTNT_val,FLT_val, FFIV_val, EPAM_val,ENPH_val, DXC_val,
                   GLW_val, CTSH_val, CTXS_val,CSCO_val, CDW_val, CDAY_val, CDNS_val, BR_val, AAPL_val, ACN_val, ADBE_val, 
                   ADI_val, ADP_val, ADSK_val, AKAM_val, AMAT_val, AMD_val, ANET_val, ANSS_val, APH_val, AVGO_val]




df_tech_val = pd.concat(df_tech_val_list)

# %%
df_tech_val
# Out:
#    symbol     marketCap  enterpriseValue  currentPrice  fiftyTwoWeekHigh  \
# 0    ZBRA  1.738826e+10      20450457600        325.37            615.00
# 0     WDC  1.770330e+10      21267910656         56.81             78.19
# 0       V           NaN     454458212352        199.03            252.67
# 0    VRSN  1.839007e+10      20151259136        165.56            257.03
# 0     TEL  4.003208e+10      43690319872        122.68            166.44
# ..    ...           ...              ...           ...               ...
# 0     AMD  1.540619e+11     147142492160         95.07            164.46
# 0    ANET  3.143679e+10      28273729536        102.30            148.57
# 0    ANSS  2.213289e+10      22166970368        254.43            413.89
# 0     APH  4.144138e+10      44572487680         69.40             88.45
# 0    AVGO  2.242690e+11     255658999808        543.19            677.76
#
#     fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  enterpriseToEbitda  \
# ...
