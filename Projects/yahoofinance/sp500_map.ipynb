# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files =glob.glob('*csv')

# %%
from ticker_convert import ticker_convert

# %%
files
SP500_tickers_list = []
for i in files:
    x = i.replace(".csv", "")
    SP500_tickers_list.append(x)
SP500_tickers_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
tickers_df = map(ticker_convert,SP500_tickers_list)
SP500_master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    SP500_master_df.append(df)
SP500_master_df = pd.concat(SP500_master_df)

# %%
today_date = datetime.now()
date = today_date.strftime('%m/%d/%Y %H:%M:%S')
SP500_master_df['Date'] = date
SP500_master_df.to_csv('SP500_master_df.csv')

# %%
SP500_master_df.columns
# Out:
# Index(['symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
#        'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
#        'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
#        'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
#        'dividendYield', 'Date'],
#       dtype='object')

# %%
raw_df = pd.read_csv('SP500_master_df.csv')
raw_df.columns
raw_df = raw_df.drop('Unnamed: 0', 1)
raw_df = raw_df[['Date','symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
       'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
       'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
       'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
       'dividendYield']]
raw_df
# Out:
# <ipython-input-8-a98c53e3806d>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   raw_df = raw_df.drop('Unnamed: 0', 1)
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   05/26/2022 10:55:12   CSCO  187373846528     171998003200        45.105
# 1   05/26/2022 10:55:12    TER   16444838912      14984250368       102.650
# 2   05/26/2022 10:55:12      V  436400685056     435106119680       206.220
# 3   05/26/2022 10:55:12   QRVO   11360793600      12218433536       107.150
# 4   05/26/2022 10:55:12    FOX   18175985664      20384178176        31.210
# ..                  ...    ...           ...              ...           ...
# 94  05/26/2022 10:55:12   CTSH   37634744320      41370865664        70.830
# 95  05/26/2022 10:55:12     MU   77407559680      73335177216        69.320
# 96  05/26/2022 10:55:12    CDW   22158348288      28756060160       163.995
# 97  05/26/2022 10:55:12    CRM  159608160256     159193694208       160.580
# 98  05/26/2022 10:55:12   LRCX   69684871168      68288229376       502.360
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0              64.29            41.02           0.076                3.335
# 1             168.91            97.63          -0.156                4.076
# 2             252.67           186.67           0.234               16.153
# 3             201.46            98.23          -0.247                2.630
# 4              40.91            28.96          -0.479                1.474
# ..               ...              ...             ...                  ...
# 94             93.47            66.19           0.853                2.235
# 95             98.45            65.67           2.774                2.353
# 96            208.71           155.39           0.123                1.311
# 97            311.75           154.55             NaN                6.009
# 98            731.85           442.53          -0.015                4.080
#
#     enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0               10.708        3.55        2.850                      3.632614
# 1               11.372        6.61        5.384                      4.472784
# 2               22.877        8.37        6.358                     16.200790
# 3                7.356       12.73        9.260                      2.445435
# 4                7.024        2.35        1.999                      1.314148
# ..                 ...         ...          ...                           ...
# 94              12.357        4.52        3.545                      2.033541
# 95               4.297       12.53        7.945                      2.483479
# 96              16.393       10.53        7.243                      1.010302
# 97              51.956        5.76        1.480                      6.024768
# 98              12.321       38.06       32.000                      4.163606
#
#     forwardPE  dividendYield
# 0   12.705634         0.0345
# 1   15.529501         0.0044
# 2   24.637993         0.0074
# 3    8.417126            NaN
# 4   13.280851         0.0160
# ..        ...            ...
# 94  15.670355         0.0147
# 95   5.532322         0.0059
# 96  15.574074         0.0124
# 97  27.879341            NaN
# 98  13.199159         0.0123
#
# [99 rows x 15 columns]

# %%
date_file =today_date.strftime('%m_%d_%Y')
raw_df.to_csv(f'SP500_master_df_{date_file}.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
raw_df.to_sql(f'SP500_{date_file}', con=engine, if_exists='append', index=False)
