# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files =glob.glob('*csv')

# %%
from ticker_convert import ticker_convert

# %%
files
SP500_tickers_list = []
for i in files:
    x = i.replace(".csv", "")
    SP500_tickers_list.append(x)
SP500_tickers_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
# ...

# %%
tickers_df = map(ticker_convert,SP500_tickers_list)
SP500_master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    SP500_master_df.append(df)
SP500_master_df = pd.concat(SP500_master_df)

# %%
today_date = datetime.now()
date = today_date.strftime('%m/%d/%Y %H:%M:%S')
SP500_master_df['Date'] = date
SP500_master_df.to_csv('output/SP500_master_df.csv')

# %%
SP500_master_df.columns
# Out:
# Index(['symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
#        'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
#        'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
#        'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
#        'dividendYield', 'Date'],
#       dtype='object')

# %%
raw_df = pd.read_csv('output/SP500_master_df.csv')
raw_df.columns
raw_df = raw_df.drop('Unnamed: 0', 1)
raw_df = raw_df[['Date','symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
       'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
       'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
       'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
       'dividendYield']]
raw_df
# Out:
# <ipython-input-24-5dbd28508f64>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   raw_df = raw_df.drop('Unnamed: 0', 1)
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   06/02/2022 17:36:11   CSCO  1.931244e+11     194965143552         45.79
# 1   06/02/2022 17:36:11    TER  1.802498e+10      16183294976        110.58
# 2   06/02/2022 17:36:11      V           NaN     454458212352        215.05
# 3   06/02/2022 17:36:11   QRVO  1.249488e+10      13396545536        113.36
# 4   06/02/2022 17:36:11    FOX  1.897212e+10      23107883008         31.86
# ..                  ...    ...           ...              ...           ...
# 94  06/02/2022 17:36:11   CTSH  3.982917e+10      41370865664         74.96
# 95  06/02/2022 17:36:11     MU  8.442721e+10      73692512256         75.37
# 96  06/02/2022 17:36:11    CDW  2.390489e+10      29284814848        176.13
# ...

# %%
date_file =today_date.strftime('%m_%d_%Y')
raw_df.to_csv(f'output/SP500_master_df_{date_file}.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
raw_df.to_sql(f'output/SP500_{date_file}', con=engine, if_exists='append', index=False)
# Out:
# 99
