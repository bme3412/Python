# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files =glob.glob('*csv')

# %%
from ticker_convert import ticker_convert

# %%
files
SP500_tickers_list = []
for i in files:
    x = i.replace(".csv", "")
    SP500_tickers_list.append(x)
SP500_tickers_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CSCO',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
tickers_df = map(ticker_convert,SP500_tickers_list)
SP500_master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    SP500_master_df.append(df)
SP500_master_df = pd.concat(SP500_master_df)

# %%
today_date = datetime.now()
date = today_date.strftime('%m/%d/%Y %H:%M:%S')
SP500_master_df['Date'] = date
SP500_master_df.to_csv('SP500_master_df.csv')

# %%
SP500_master_df.columns
# Out:
# Index(['symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
#        'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
#        'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
#        'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
#        'dividendYield', 'Date'],
#       dtype='object')

# %%
raw_df = pd.read_csv('SP500_master_df.csv')
raw_df.columns
raw_df = raw_df.drop('Unnamed: 0', 1)
raw_df = raw_df[['Date','symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
       'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
       'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
       'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
       'dividendYield']]
raw_df
# Out:
# <ipython-input-97-a98c53e3806d>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   raw_df = raw_df.drop('Unnamed: 0', 1)
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   05/24/2022 13:40:36   CSCO  1.783385e+11     167596883968        42.930
# 1   05/24/2022 13:40:36    TER  1.587932e+10      15493695488        99.120
# 2   05/24/2022 13:40:36      V  4.257668e+11     425086353408       201.195
# 3   05/24/2022 13:40:36   QRVO  1.106223e+10      12666929152       102.020
# 4   05/24/2022 13:40:36    FOX  1.842428e+10      23107883008        30.940
# ..                  ...    ...           ...              ...           ...
# 95  05/24/2022 13:40:36     MU  7.717972e+10      73692512256        68.900
# 96  05/24/2022 13:40:36   CSCO  1.811042e+11     194965143552        42.940
# 97  05/24/2022 13:40:36    CDW  2.174283e+10      29284814848       160.200
# 98  05/24/2022 13:40:36    CRM  1.572552e+11     178013601792       159.650
# 99  05/24/2022 13:40:36   LRCX  6.675562e+10      65261465600       474.120
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0              64.29            41.02           0.076                3.249
# 1             168.91            97.63          -0.156                4.214
# 2             252.67           186.67           0.234               15.781
# 3             201.46            98.23          -0.247                2.727
# 4              40.91            28.96             NaN                1.700
# ..               ...              ...             ...                  ...
# 95             98.45            65.67           2.774                2.364
# 96             64.29            41.02           0.183                3.782
# 97            208.71           155.39          -0.050                1.407
# 98            311.75           154.55             NaN                6.720
# 99            731.85           442.53          -0.015                3.899
#
#     enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0               10.434        3.56        2.850                      3.457446
# 1               11.759        6.61        5.384                      4.318971
# 2               22.351        8.38        6.358                     15.806024
# 3                7.626       12.73        9.260                      2.381170
# 4                7.728        2.35        2.958                      1.355623
# ..                 ...         ...          ...                           ...
# 95               4.318       11.51        6.461                      2.476169
# 96              12.193        3.68        2.690                      3.513243
# 97              17.594        9.11        7.116                      1.044284
# 98              58.098        4.71        1.818                      5.935952
# 99              11.775       36.65       29.588                      3.988586
#
#     forwardPE  dividendYield
# 0   12.058989         0.0354
# 1   14.995461         0.0043
# 2   24.008951         0.0075
# 3    8.014140            NaN
# 4   13.165958         0.0156
# ..        ...            ...
# 95   5.986099         0.0056
# 96  11.668478         0.0307
# 97  17.585072         0.0118
# 98  33.895966            NaN
# 99  12.936425         0.0122
#
# [100 rows x 15 columns]

# %%
raw_df.to_csv('SP500_master_df_5_24_22.csv')
