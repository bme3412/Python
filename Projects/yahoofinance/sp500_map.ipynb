# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files =glob.glob('*csv')

# %%
from ticker_convert import ticker_convert

# %%
files
SP500_tickers_list = []
for i in files:
    x = i.replace(".csv", "")
    SP500_tickers_list.append(x)
SP500_tickers_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
tickers_df = map(ticker_convert,SP500_tickers_list)
SP500_master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    SP500_master_df.append(df)
SP500_master_df = pd.concat(SP500_master_df)

# %%
today_date = datetime.now()
date = today_date.strftime('%m/%d/%Y %H:%M:%S')
SP500_master_df['Date'] = date
SP500_master_df.to_csv('SP500_master_df.csv')

# %%
SP500_master_df.columns
# Out:
# Index(['symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
#        'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
#        'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
#        'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
#        'dividendYield', 'Date'],
#       dtype='object')

# %%
raw_df = pd.read_csv('SP500_master_df.csv')
raw_df.columns
raw_df = raw_df.drop('Unnamed: 0', 1)
raw_df = raw_df[['Date','symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
       'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
       'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
       'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
       'dividendYield']]
raw_df
# Out:
# <ipython-input-13-a98c53e3806d>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   raw_df = raw_df.drop('Unnamed: 0', 1)
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   05/25/2022 12:10:28   CSCO  1.823473e+11     171043045376       43.8950
# 1   05/25/2022 12:10:28    TER  1.586170e+10      15577000960       99.0100
# 2   05/25/2022 12:10:28      V  4.307517e+11     432585572352      203.5506
# 3   05/25/2022 12:10:28   QRVO  1.102893e+10      11983052800      104.0200
# 4   05/25/2022 12:10:28    FOX  1.791648e+10      20857415680       30.7800
# ..                  ...    ...           ...              ...           ...
# 94  05/25/2022 12:10:28   CTSH  3.763474e+10      41370865664       70.8300
# 95  05/25/2022 12:10:28     MU  7.717972e+10      73692512256       68.9000
# 96  05/25/2022 12:10:28    CDW  2.174283e+10      29284814848      160.2000
# 97  05/25/2022 12:10:28    CRM  1.572552e+11     178013601792      159.6500
# 98  05/25/2022 12:10:28   LRCX  6.675562e+10      65261465600      474.1200
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0              64.29            41.02           0.076                3.316
# 1             168.91            97.63          -0.156                4.237
# 2             252.67           186.67           0.234               16.059
# 3             201.46            98.23          -0.247                2.579
# 4              40.91            28.96          -0.479                1.508
# ..               ...              ...             ...                  ...
# 94             93.47            66.19           0.853                2.235
# 95             98.45            65.67           2.774                2.364
# 96            208.71           155.39          -0.050                1.407
# 97            311.75           154.55             NaN                6.720
# 98            731.85           442.53          -0.015                3.899
#
#     enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0               10.649        3.55        2.850                      3.535164
# 1               11.822        6.61        5.384                      4.314178
# 2               22.745        8.37        6.358                     15.991081
# 3                7.214       12.73        9.260                      2.374001
# 4                7.187        2.35        1.999                      1.295386
# ..                 ...         ...          ...                           ...
# 94              12.357        4.52        3.545                      2.033541
# 95               4.318       11.51        6.461                      2.476169
# 96              17.594        9.11        7.116                      1.044284
# 97              58.098        4.71        1.818                      5.935952
# 98              11.775       36.65       29.588                      3.988586
#
#     forwardPE  dividendYield
# 0   12.364789         0.0347
# 1   14.978820         0.0043
# 2   24.319069         0.0072
# 3    8.171249            NaN
# 4   13.097873         0.0152
# ..        ...            ...
# 94  15.670355         0.0147
# 95   5.986099         0.0056
# 96  17.585072         0.0118
# 97  33.895966            NaN
# 98  12.936425         0.0122
#
# [99 rows x 15 columns]

# %%
date_file =today_date.strftime('%m_%d_%Y')
raw_df.to_csv(f'SP500_master_df_{date_file}.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
raw_df.to_sql(f'SP500_{date_file}', con=engine, if_exists='append', index=False)
