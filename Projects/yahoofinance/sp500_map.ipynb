# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files =glob.glob('*csv')

# %%
from ticker_convert import ticker_convert

# %%
files
SP500_tickers_list = []
for i in files:
    x = i.replace(".csv", "")
    SP500_tickers_list.append(x)
SP500_tickers_list
# Out:
# ['CSCO',
#  'TER',
#  'V',
#  'QRVO',
#  'FOX',
#  'FLT',
#  'SWKS',
#  'ENPH',
#  'MCHP',
#  'CDNS',
#  'CHTR',
#  'T',
#  'DISH',
#  'APH',
#  'MSI',
#  'GPN',
#  'WBD',
#  'DXC',
#  'PARA',
#  'ADI',
#  'ADBE',
#  'NOW',
#  'NWS',
#  'ZBRA',
#  'BR',
#  'STX',
#  'IPG',
#  'CDAY',
#  'ORCL',
#  'INTU',
#  'PAYC',
#  'IPGP',
#  'INTC',
#  'GLW',
#  'TXN',
#  'FTNT',
#  'JNPR',
#  'ADSK',
#  'WDC',
#  'LUMN',
#  'PYPL',
#  'MSFT',
#  'ANSS',
#  'IT',
#  'ACN',
#  'VRSN',
#  'HPQ',
#  'AMAT',
#  'ATVI',
#  'EA',
#  'AMD',
#  'KLAC',
#  'NXPI',
#  'SEDG',
#  'MTCH',
#  'NVDA',
#  'TYL',
#  'HPE',
#  'CMCSA',
#  'CTXS',
#  'PTC',
#  'FIS',
#  'FB',
#  'NLOK',
#  'IBM',
#  'TWTR',
#  'MPWR',
#  'DIS',
#  'NFLX',
#  'OMC',
#  'AKAM',
#  'GOOGL',
#  'ANET',
#  'PAYX',
#  'FOXA',
#  'FFIV',
#  'SNPS',
#  'GOOG',
#  'EPAM',
#  'LYV',
#  'AVGO',
#  'VZ',
#  'TEL',
#  'JKHY',
#  'ADP',
#  'TRMB',
#  'QCOM',
#  'MA',
#  'NWSA',
#  'TTWO',
#  'AAPL',
#  'TMUS',
#  'NTAP',
#  'KEYS',
#  'CTSH',
#  'MU',
#  'CDW',
#  'CRM',
#  'LRCX']

# %%
tickers_df = map(ticker_convert,SP500_tickers_list)
SP500_master_df = []
for i in tickers_df:
    df = pd.DataFrame(i)
    SP500_master_df.append(df)
SP500_master_df = pd.concat(SP500_master_df)

# %%
today_date = datetime.now()
date = today_date.strftime('%m/%d/%Y %H:%M:%S')
SP500_master_df['Date'] = date
SP500_master_df.to_csv('SP500_master_df.csv')

# %%
SP500_master_df.columns
# Out:
# Index(['symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
#        'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
#        'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
#        'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
#        'dividendYield', 'Date'],
#       dtype='object')

# %%
raw_df = pd.read_csv('SP500_master_df.csv')
raw_df.columns
raw_df = raw_df.drop('Unnamed: 0', 1)
raw_df = raw_df[['Date','symbol', 'marketCap', 'enterpriseValue', 'currentPrice',
       'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'earningsGrowth',
       'enterpriseToRevenue', 'enterpriseToEbitda', 'forwardEps',
       'trailingEps', 'priceToSalesTrailing12Months', 'forwardPE',
       'dividendYield']]
raw_df
# Out:
# <ipython-input-8-a98c53e3806d>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   raw_df = raw_df.drop('Unnamed: 0', 1)
#                    Date symbol     marketCap  enterpriseValue  currentPrice  \
# 0   05/31/2022 11:51:16   CSCO  1.892863e+11     194965143552       44.8800
# 1   05/31/2022 11:51:16    TER  1.768919e+10      16183294976      108.5200
# 2   05/31/2022 11:51:16      V           NaN     454458212352      212.3101
# 3   05/31/2022 11:51:16   QRVO  1.229648e+10      13396545536      111.5600
# 4   05/31/2022 11:51:16    FOX  1.941278e+10      23107883008       32.6000
# ..                  ...    ...           ...              ...           ...
# 94  05/31/2022 11:51:16   CTSH  3.948380e+10      41370865664       74.3100
# 95  05/31/2022 11:51:16     MU  8.237730e+10      73692512256       73.5400
# 96  05/31/2022 11:51:16    CDW  2.312449e+10      29284814848      170.3800
# 97  05/31/2022 11:51:16    CRM  1.606338e+11     178013601792      163.0600
# 98  05/31/2022 11:51:16   LRCX  7.347877e+10      65261465600      521.8700
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  earningsGrowth  enterpriseToRevenue  \
# 0              64.29            41.02           0.183                3.782
# 1             168.91            97.63          -0.156                4.402
# 2             252.67           186.67           0.234               16.871
# 3             201.46            98.23           0.121                2.943
# 4              40.91            28.96             NaN                1.700
# ..               ...              ...             ...                  ...
# 94             93.47            66.19           0.853                2.235
# 95             98.45            65.67           2.774                2.364
# 96            208.71           155.39          -0.050                1.407
# 97            311.75           154.55             NaN                6.720
# 98            731.85           442.53          -0.015                3.899
#
#     enterpriseToEbitda  forwardEps  trailingEps  priceToSalesTrailing12Months  \
# 0               12.193        3.68        2.690                      3.671969
# 1               12.537        6.45        5.309                      4.811233
# 2               23.895         NaN          NaN                           NaN
# 3                8.146       13.15        9.656                      2.701165
# 4                7.728        2.35        2.958                      1.428355
# ..                 ...         ...          ...                           ...
# 94              12.357        4.52        3.545                      2.133452
# 95               4.318       11.51        6.461                      2.642924
# 96              17.594        9.11        7.116                      1.110643
# 97              58.098        4.71        1.818                      6.063483
# 98              11.775       36.65       29.588                      4.390288
#
#     forwardPE  dividendYield
# 0   12.195652         0.0307
# 1   16.824806         0.0041
# 2         NaN         0.0075
# 3    8.483650            NaN
# 4   13.872340         0.0156
# ..        ...            ...
# 94  16.440266         0.0147
# 95   6.389227         0.0056
# 96  18.702526         0.0118
# 97  34.624203            NaN
# 98  14.239290         0.0122
#
# [99 rows x 15 columns]

# %%
date_file =today_date.strftime('%m_%d_%Y')
raw_df.to_csv(f'SP500_master_df_{date_file}.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
raw_df.to_sql(f'SP500_{date_file}', con=engine, if_exists='append', index=False)
# Out:
# 99
