# %%
from PIL import Image
from pytesseract import pytesseract
import pandas as pd

# %%
img = Image.open('/Users/brendan/Desktop/nbanumbers.png')
df = pytesseract.image_to_data(Image.open('/Users/brendan/Desktop/nbanumbers.png'),lang='eng', output_type='data.frame')

# %%
df = df[df['text'].notnull()]

df_ = df['text']

# %%
df_.to_frame()
df_.to_excel('nba_excel.xlsx')

# %%
file = pd.read_excel('/Users/brendan/Desktop/Python/nba_excel_scrubbed.xlsx', sheet_name='data')
file
# Out:
#     text                Player  Score     Year
# 0    1.0  Kareem Abdul-Jabbar*  25.37  1971-72
# 1    2.0     Wilt Chamberlain*  24.98  1963-64
# 2    3.0         George Mikan*  23.43  1950-51
# 3    4.0     Wilt Chamberlain*  23.11  1961-62
# 4    5.0  Kareem Abdul-Jabbar*  22.31  1970-71
# 5    6.0     Wilt Chamberlain*  21.87  1966-67
# 6    7.0  Kareem Abdul-Jabbar*  21.86  1972-73
# 7    8.0     Wilt Chamberlain*  21.42  1965-66
# 8    9.0       Michael Jordan*  21.23  1987-88
# 9   10.0         George Mikan*  21.13  1949-50
# 10  11.0     Wilt Chamberlain*  20.94  1962-63
# 11  12.0         George Mikan*  20.86  1948-49
# 12  13.0      Oscar Robertson*  20.65  1963-64
# 13  14.0       Michael Jordan*  20.43  1995-96
# 14  15.0     Wilt Chamberlain*  20.38  1967-68
# 15  16.0       Michael Jordan*  20.30  1990-91
# 16  17.0          LeBron James  20.25  2008-09
# 17  18.0       David Robinson*  19.98  1993-94
# 18  19.0       Michael Jordan*  19.80  1988-89
# ...

# %%
img = Image.open('/Users/brendan/Desktop/fantasybb.png')
df = pytesseract.image_to_data(Image.open('/Users/brendan/Desktop/fantasybb.png'),lang='eng', output_type='data.frame')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 img = Image.open('/Users/brendan/Desktop/fantasybb.png')
#       2 df = pytesseract.image_to_data(Image.open('/Users/brendan/Desktop/fantasybb.png'),lang='eng', output_type='data.frame')
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/PIL/Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/brendan/Desktop/fantasybb.png'

# %%
df.to_excel('fantasybbprep.xlsx')

# %%
img2 = Image.open('/Users/brendan/Desktop/excel_numbers.png')
df = pytesseract.image_to_data(Image.open('/Users/brendan/Desktop/excel_numbers.png'),lang='eng', output_type='data.frame')

# %%
df
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 0       1         1          0        0         0         0     0    0    154
# 1       2         1          1        0         0         0    79   16     59
# 2       3         1          1        1         0         0    79   16     56
# 3       4         1          1        1         1         0    79   16     52
# 4       5         1          1        1         1         1    79   16     52
# 5       4         1          1        1         2         0    90   48     45
# 6       5         1          1        1         2         1    90   48     45
# 7       4         1          1        1         3         0    88   80     47
# 8       5         1          1        1         3         1    88   80     47
# 9       3         1          1        2         0         0    81  112     57
# 10      4         1          1        2         1         0    81  112     57
# ...
