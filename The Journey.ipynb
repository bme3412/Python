# %%
# import all libraries
import glob
import os
import time
import pandas as pd
import datetime as dt
import pathlib
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns
from pathlib import Path
import qgrid
import numpy as np
import warnings
import warnings
import mpl_axes_aligner
warnings.filterwarnings('ignore')

# %%
dir_name = '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science'

# %%
# get list of all filies only in the given diretory
list_of_files = filter(os.path.isfile, glob.glob(dir_name + '/**/*'))

# %%
# sort list of files based on last modification time
list_of_files = sorted(list_of_files, key=os.path.getmtime)

# %%
# iterate over sorted list of files and print file path
# along with last modidicaiton date time
for file_path in list_of_files:
    time_stamp_str = time.strftime('%m/%d/%Y :: %H:%M:%S',
                                  time.gmtime(os.path.getmtime(file_path)))
    print(time_stamp_str, ' -->', file_path)
# Out:
# 11/18/2020 :: 01:55:44  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/widgets.py
# 11/18/2020 :: 23:28:45  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/widgets_interactive.py
# 11/19/2020 :: 00:13:59  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/labels.py
# 11/22/2020 :: 20:16:56  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/exercise_8.py
# 11/22/2020 :: 20:39:04  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/labels_radio_buttons.py
# 11/27/2020 :: 23:57:27  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/filtering_glyphs.py
# 12/05/2020 :: 19:49:52  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/bitcoin_streaming_webscrapping.py
# 12/05/2020 :: 20:26:15  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/random_graphing.py
# 12/07/2020 :: 03:30:00  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/insty/11788939_10101414218421757_535490599_n.mp4
# 07/04/2021 :: 01:45:52  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/bokeh_static.py
# 07/04/2021 :: 01:53:14  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh/bokeh_static.ipynb
# 07/17/2021 :: 19:49:51  --> /Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Python/Untitled.ipynb

# %%
time_stamp_str
# Out:
# '07/17/2021 :: 19:49:51'

# %% [markdown]
# ## try 2

# %%
dir_name
# Out:
# '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science'

# %%
filelist = []

# %%
for root, dirs, files in os.walk(dir_name):
    for file in files:
        # append the file name to the list
        filelist.append(os.path.join(root,file))
    
# print all the file names
#for name in filelist:
    #print(name)

# %%
#type(name)

# %%
type(filelist)
# Out:
# list

# %%
df = pd.DataFrame(filelist, columns=['FileName'])
df.to_csv('files.csv',index=False)

# %% [markdown]
# # sept 4

# %%
fname = pathlib.Path(dir_name)

# %%
assert fname.exists(), f'No such file: {fname}'

# %%
print(fname.stat())
# Out:
# os.stat_result(st_mode=16877, st_ino=287493, st_dev=16777230, st_nlink=15, st_uid=501, st_gid=20, st_size=480, st_atime=1631747261, st_mtime=1631747261, st_ctime=1631747261)

# %%
mtime = datetime.datetime.fromtimestamp(fname.stat().st_mtime)
print(mtime)
# Out:
# 2021-09-15 19:07:41

# %%
root = dir_name
for item in os.listdir(root):
    if not item.startswith('.') and os.path.isfile(os.path.join(root, item)):
        print(item)
# Out:
# python_graph.png
# files.csv
# jupyter_graph.png

# %%
filesglob = glob.glob('/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/[!.DS_Store]*')
filesglob
# Out:
# ['/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Bokeh',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Udemy',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Tableau',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Python',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/insty',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/13F',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/python_graph.png',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/files.csv',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/Udemy-BT',
#  '/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science/jupyter_graph.png']

# %%
p = Path('/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science'
).glob('')
p
# Out:
# <generator object Path.glob at 0x7fb9929515f0>

# %%
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
       
                
    return allFiles

dirName = dir_name;
# Get the list of all files in directory tree at given path
listOfFiles = getListOfFiles(dirName)
#listOfFiles

# %%
d_ext_desc = {'csv':'CSV file',
              'css' : 'CSS Styling',
              'db':'Thumbnail',
              'doc':'Microsoft Word Document',
              'docx':'Microsoft Word Document',
              'GIF':'GIF Image file',
              'html':'HTML file',
              'ico':'Icon Image file',
              'ipynb': 'Jupyter Notebook',
              '.ipynb':'Jupyter',
              'ipynb.icloud': 'Jupyter',
              'html': 'HTML',
              'jpg':'JPG Image file',
              'JPEG':'JPEG Image file',
              'js': 'Javascript',
              'json':'JSON file',
              'lnk':'Shortcut file',
              'msg':'Microsoft Outlook Message file',
              'pdf':'PDF file',
              'pkl':'Pickle (python) file',
              'png':'PNG Image file',
              'ppt':'Microsoft Powerpoint file',
              'pptx':'Microsoft Powerpoint file',
              'pst':'Microsoft Outlook Data file',
              'py':'Python file',
              'pyc':'Python file (compiled)',
              'rtf':'Rich Text Format',
              'svg':'SVG Image file',
              'txt':'Text document',
              'url':'Hyperlink',
              'vsd':'Microsoft Visio file',
              'xls':'Microsoft Excel file',
              'xlsb':'Microsoft Excel file',
              'xlsm':'Microsoft Excel (Macro-enabled) file',
              'xlsx':'Microsoft Excel file',
              'yml':'Requirements file (python)',
              'zip':'ZIP file'}

def ext_desc(ext):
    try:
        desc = d_ext_desc[ext]
    except KeyError:
        desc = ''
    else:
        pass
    return desc


def generate_index(path=None, max=0):
    # stops generating index whenever there are more than 500 records, to test if the script works
    # use 'max=0' to generate the full index
    
    path = dir_name

    df = pd.DataFrame(columns=['File','File Type','Folder Location','Date','Path'])
    for root, _ , files in os.walk(path):
        files = [f for f in files if not f.startswith('~') and f!='Thumbs.db']
        paths = [os.path.join(root, f) for f in files]
        exts = [os.path.splitext(f)[1][1:].lower() for f in files]
        filetypes = [ext_desc(ext) for ext in exts]
        file_links = ['=HYPERLINK("{}","link")'.format(p) if len(p) < 256 else '' for p in paths]
        folders = [os.path.dirname(p) for p in paths]
        time_stamp_str = [time.strftime('%m/%d/%Y :: %H:%M:%S',
                                  time.gmtime(os.path.getmtime(p))) for p in paths]
        df1 = pd.DataFrame({'File': files,
                            'File Type': filetypes,
                            'Folder Location': folders,
                            'Date': time_stamp_str,
                            'Path': paths})
        df = df.append(df1)
        if max and (df.shape[0]>max):
            break
    df = df.reset_index(drop=True)
    return df

# %%
raw_df = generate_index(dir_name)
raw_df['File']=raw_df['File'].str.replace('.ipynb.icloud', '.ipynb')
raw_df.loc[raw_df['File'].str.contains('ipynb'), 'File Type'] = 'Jupyter Notebook'
raw_df.head()
# Out:
#                         File       File Type  \
# 0                  .DS_Store
# 1           python_graph.png  PNG Image file
# 2                  files.csv        CSV file
# 3          jupyter_graph.png  PNG Image file
# 4  .simple_bokeh.html.icloud
#
#                                      Folder Location                    Date  \
# 0  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 01:08:47
# 1  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:37
# 2  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:33
# 3  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:36
# 4  /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 01:55:53
#
#                                                 Path
# 0  /Users/brendan/Library/Mobile Documents/com~ap...
# 1  /Users/brendan/Library/Mobile Documents/com~ap...
# 2  /Users/brendan/Library/Mobile Documents/com~ap...
# 3  /Users/brendan/Library/Mobile Documents/com~ap...
# 4  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
raw_df.shape
# Out:
# (15479, 5)

# %%
raw_df['File']=raw_df['File'].str.replace('.ipynb.icloud', '.ipynb')
raw_df.loc[raw_df['File'].str.contains('ipynb'), 'File Type'] = 'Jupyter Notebook'
raw_df.head(7)
# Out:
#                         File       File Type  \
# 0                  .DS_Store
# 1           python_graph.png  PNG Image file
# 2                  files.csv        CSV file
# 3          jupyter_graph.png  PNG Image file
# 4  .simple_bokeh.html.icloud
# 5                  labels.py     Python file
# 6              exercise_8.py     Python file
#
#                                      Folder Location                    Date  \
# 0  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 01:08:47
# 1  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:37
# 2  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:33
# 3  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:36
# 4  /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 01:55:53
# 5  /Users/brendan/Library/Mobile Documents/com~ap...  11/19/2020 :: 00:13:59
# 6  /Users/brendan/Library/Mobile Documents/com~ap...  11/22/2020 :: 20:16:56
#
#                                                 Path
# 0  /Users/brendan/Library/Mobile Documents/com~ap...
# 1  /Users/brendan/Library/Mobile Documents/com~ap...
# 2  /Users/brendan/Library/Mobile Documents/com~ap...
# 3  /Users/brendan/Library/Mobile Documents/com~ap...
# 4  /Users/brendan/Library/Mobile Documents/com~ap...
# 5  /Users/brendan/Library/Mobile Documents/com~ap...
# 6  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
raw_df.value_counts('Date')
# Out:
# Date
# 10/26/1985 :: 08:15:00    5449
# 08/26/2018 :: 00:52:52    1576
# 09/21/2019 :: 02:56:04     536
# 08/10/2018 :: 02:01:48     411
# 09/21/2019 :: 02:56:02     390
#                           ...
# 07/26/2020 :: 21:29:34       1
# 07/26/2020 :: 21:25:25       1
# 07/26/2020 :: 21:24:21       1
# 07/25/2018 :: 20:35:43       1
# 12/31/2020 :: 22:09:58       1
# Length: 2212, dtype: int64

# %%
raw_df.value_counts('File Type')
# Out:
# File Type
#                           6624
# Javascript                5261
# Python file               1085
# JSON file                  635
# Jupyter Notebook           548
# JPG Image file             502
# SVG Image file             298
# PNG Image file             290
# Text document              152
# PDF file                    40
# Python file (compiled)      14
# HTML                        10
# Thumbnail                    7
# CSS Styling                  6
# Icon Image file              4
# CSV file                     3
# dtype: int64

# %%
raw_df.shape
# Out:
# (15479, 5)

# %%
qgrid_widget_10_26_85  = qgrid.show_grid(raw_df, show_toolbar = True)
df_10_26_1985_filtered = qgrid_widget_10_26_85.get_changed_df()
df_10_26_1985_filtered.head()
# Out:
#                         File       File Type  \
# 0                  .DS_Store
# 1           python_graph.png  PNG Image file
# 2                  files.csv        CSV file
# 3          jupyter_graph.png  PNG Image file
# 4  .simple_bokeh.html.icloud
#
#                                      Folder Location                    Date  \
# 0  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 01:08:47
# 1  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:37
# 2  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:33
# 3  /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:36
# 4  /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 01:55:53
#
#                                                 Path
# 0  /Users/brendan/Library/Mobile Documents/com~ap...
# 1  /Users/brendan/Library/Mobile Documents/com~ap...
# 2  /Users/brendan/Library/Mobile Documents/com~ap...
# 3  /Users/brendan/Library/Mobile Documents/com~ap...
# 4  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
# filter for all files with the data that matches '10/26/1985 :: 08:15:00'
df_10_26_1985_filtered_vs = raw_df.loc[(raw_df['File Type'] == 'Python file') & 
                                       (raw_df['Date'] == '10/26/1985 :: 08:15:00')]
df_10_26_1985_filtered_jupyter = raw_df.loc[(raw_df['File Type'] == 'Jupyter Notebook') 
                                             & (raw_df['Date'] == '10/26/1985 :: 08:15:00')]
df_10_26_1985_filtered.head(50)
# Out:
#                                          File         File Type  \
# 0                                   .DS_Store
# 1                            python_graph.png    PNG Image file
# 2                                   files.csv          CSV file
# 3                           jupyter_graph.png    PNG Image file
# 4                   .simple_bokeh.html.icloud
# 5                                   labels.py       Python file
# 6                               exercise_8.py       Python file
# 7                                   .DS_Store
# 8                      widgets_interactive.py       Python file
# 9                         filtering_glyphs.py       Python file
# 10                                 widgets.py       Python file
# 11                            .Untitled.ipynb  Jupyter Notebook
# 12                         bokeh_static.ipynb  Jupyter Notebook
# 13          bitcoin_streaming_webscrapping.py       Python file
# 14                            bokeh_static.py       Python file
# 15                    labels_radio_buttons.py       Python file
# 16                         random_graphing.py       Python file
# 17     .random_graphing.cpython-37.pyc.icloud
# 18              bokeh_static-checkpoint.ipynb  Jupyter Notebook
# 19                 .Untitled-checkpoint.ipynb  Jupyter Notebook
# 20                              settings.json         JSON file
# 21                                  .DS_Store
# 22               .05 Matplotlib Lecture.ipynb  Jupyter Notebook
# 23                   .08 Plotly Lecture.ipynb  Jupyter Notebook
# 24                      .14 KNN Lecture.ipynb  Jupyter Notebook
# 25      .01 Python Crash Course Lecture.ipynb  Jupyter Notebook
# 26                    .02 Numpy Lecture.ipynb  Jupyter Notebook
# 27      .13 Logistic Regression Lecture.ipynb  Jupyter Notebook
# 28     .07 Pandas Visualization lecture.ipynb  Jupyter Notebook
# 29        .11 Linear Regression lecture.ipynb  Jupyter Notebook
# 30           .15 Decision Trees lecture.ipynb  Jupyter Notebook
# 31  .16 Support Vector Machines lecture.ipynb  Jupyter Notebook
# 32                  .06 Seaborn Lecture.ipynb  Jupyter Notebook
# 33                   .03 Pandas Lecture.ipynb  Jupyter Notebook
# 34                Bias Variance Trade-Off.pdf          PDF file
# 35           Intro to Logistic Regression.pdf          PDF file
# 36           Principal Component Analysis.pdf          PDF file
# 37   Intro to Natural Language Processing.pdf          PDF file
# 38              Intro to Machine Learning.pdf          PDF file
# 39           Intro to K Nearest Neighbors.pdf          PDF file
# 40                  Intro to Tree Methods.pdf          PDF file
# 41    Python - Intro to Linear Regression.pdf          PDF file
# 42            Intro to K Means Clustering.pdf          PDF file
# 43                   Intro to Neural Nets.pdf          PDF file
# 44                 .10  Finance Project.ipynb  Jupyter Notebook
# 45  .16 Support Vector Machines Project.ipynb  Jupyter Notebook
# 46        .11 Linear Regression Project.ipynb  Jupyter Notebook
# 47      .01-Python Crash Course Project.ipynb  Jupyter Notebook
# 48      .13 Logistic Regression Project.ipynb  Jupyter Notebook
# 49                    .02 Numpy Project.ipynb  Jupyter Notebook
#
#                                       Folder Location                    Date  \
# 0   /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 01:08:47
# 1   /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:37
# 2   /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:33
# 3   /Users/brendan/Library/Mobile Documents/com~ap...  09/15/2021 :: 23:07:36
# 4   /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 01:55:53
# 5   /Users/brendan/Library/Mobile Documents/com~ap...  11/19/2020 :: 00:13:59
# 6   /Users/brendan/Library/Mobile Documents/com~ap...  11/22/2020 :: 20:16:56
# 7   /Users/brendan/Library/Mobile Documents/com~ap...  09/04/2021 :: 15:11:01
# 8   /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 23:28:45
# 9   /Users/brendan/Library/Mobile Documents/com~ap...  11/27/2020 :: 23:57:27
# 10  /Users/brendan/Library/Mobile Documents/com~ap...  11/18/2020 :: 01:55:44
# 11  /Users/brendan/Library/Mobile Documents/com~ap...  12/05/2020 :: 20:01:10
# 12  /Users/brendan/Library/Mobile Documents/com~ap...  07/04/2021 :: 01:53:14
# 13  /Users/brendan/Library/Mobile Documents/com~ap...  12/05/2020 :: 19:49:52
# 14  /Users/brendan/Library/Mobile Documents/com~ap...  07/04/2021 :: 01:45:52
# 15  /Users/brendan/Library/Mobile Documents/com~ap...  11/22/2020 :: 20:39:04
# 16  /Users/brendan/Library/Mobile Documents/com~ap...  12/05/2020 :: 20:26:15
# 17  /Users/brendan/Library/Mobile Documents/com~ap...  12/05/2020 :: 20:12:25
# 18  /Users/brendan/Library/Mobile Documents/com~ap...  07/04/2021 :: 01:53:14
# 19  /Users/brendan/Library/Mobile Documents/com~ap...  12/05/2020 :: 19:53:08
# 20  /Users/brendan/Library/Mobile Documents/com~ap...  11/22/2020 :: 20:53:32
# 21  /Users/brendan/Library/Mobile Documents/com~ap...  09/06/2021 :: 00:46:16
# 22  /Users/brendan/Library/Mobile Documents/com~ap...  12/27/2020 :: 14:23:29
# 23  /Users/brendan/Library/Mobile Documents/com~ap...  12/27/2020 :: 22:04:05
# 24  /Users/brendan/Library/Mobile Documents/com~ap...  12/29/2020 :: 20:21:42
# 25  /Users/brendan/Library/Mobile Documents/com~ap...  12/26/2020 :: 02:04:50
# 26  /Users/brendan/Library/Mobile Documents/com~ap...  12/26/2020 :: 03:02:42
# 27  /Users/brendan/Library/Mobile Documents/com~ap...  12/29/2020 :: 17:52:06
# 28  /Users/brendan/Library/Mobile Documents/com~ap...  01/01/2021 :: 04:38:43
# 29  /Users/brendan/Library/Mobile Documents/com~ap...  12/28/2020 :: 21:42:48
# 30  /Users/brendan/Library/Mobile Documents/com~ap...  12/30/2020 :: 01:28:02
# 31  /Users/brendan/Library/Mobile Documents/com~ap...  12/30/2020 :: 15:54:15
# 32  /Users/brendan/Library/Mobile Documents/com~ap...  12/29/2020 :: 18:14:15
# 33  /Users/brendan/Library/Mobile Documents/com~ap...  12/27/2020 :: 15:27:59
# 34  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:37:49
# 35  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:56:21
# 36  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:35:32
# 37  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:34:12
# 38  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:30:30
# 39  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:37:12
# 40  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:33:31
# 41  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:32:38
# 42  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:36:36
# 43  /Users/brendan/Library/Mobile Documents/com~ap...  12/21/2016 :: 05:36:09
# 44  /Users/brendan/Library/Mobile Documents/com~ap...  12/30/2020 :: 14:24:25
# 45  /Users/brendan/Library/Mobile Documents/com~ap...  12/30/2020 :: 16:04:45
# 46  /Users/brendan/Library/Mobile Documents/com~ap...  12/28/2020 :: 21:57:56
# 47  /Users/brendan/Library/Mobile Documents/com~ap...  08/30/2018 :: 18:54:18
# 48  /Users/brendan/Library/Mobile Documents/com~ap...  12/29/2020 :: 18:30:40
# 49  /Users/brendan/Library/Mobile Documents/com~ap...  08/30/2018 :: 18:54:18
#
#                                                  Path
# 0   /Users/brendan/Library/Mobile Documents/com~ap...
# 1   /Users/brendan/Library/Mobile Documents/com~ap...
# 2   /Users/brendan/Library/Mobile Documents/com~ap...
# 3   /Users/brendan/Library/Mobile Documents/com~ap...
# 4   /Users/brendan/Library/Mobile Documents/com~ap...
# 5   /Users/brendan/Library/Mobile Documents/com~ap...
# 6   /Users/brendan/Library/Mobile Documents/com~ap...
# 7   /Users/brendan/Library/Mobile Documents/com~ap...
# 8   /Users/brendan/Library/Mobile Documents/com~ap...
# 9   /Users/brendan/Library/Mobile Documents/com~ap...
# 10  /Users/brendan/Library/Mobile Documents/com~ap...
# 11  /Users/brendan/Library/Mobile Documents/com~ap...
# 12  /Users/brendan/Library/Mobile Documents/com~ap...
# 13  /Users/brendan/Library/Mobile Documents/com~ap...
# 14  /Users/brendan/Library/Mobile Documents/com~ap...
# 15  /Users/brendan/Library/Mobile Documents/com~ap...
# 16  /Users/brendan/Library/Mobile Documents/com~ap...
# 17  /Users/brendan/Library/Mobile Documents/com~ap...
# 18  /Users/brendan/Library/Mobile Documents/com~ap...
# 19  /Users/brendan/Library/Mobile Documents/com~ap...
# 20  /Users/brendan/Library/Mobile Documents/com~ap...
# 21  /Users/brendan/Library/Mobile Documents/com~ap...
# 22  /Users/brendan/Library/Mobile Documents/com~ap...
# 23  /Users/brendan/Library/Mobile Documents/com~ap...
# 24  /Users/brendan/Library/Mobile Documents/com~ap...
# 25  /Users/brendan/Library/Mobile Documents/com~ap...
# 26  /Users/brendan/Library/Mobile Documents/com~ap...
# 27  /Users/brendan/Library/Mobile Documents/com~ap...
# 28  /Users/brendan/Library/Mobile Documents/com~ap...
# 29  /Users/brendan/Library/Mobile Documents/com~ap...
# 30  /Users/brendan/Library/Mobile Documents/com~ap...
# 31  /Users/brendan/Library/Mobile Documents/com~ap...
# 32  /Users/brendan/Library/Mobile Documents/com~ap...
# 33  /Users/brendan/Library/Mobile Documents/com~ap...
# 34  /Users/brendan/Library/Mobile Documents/com~ap...
# 35  /Users/brendan/Library/Mobile Documents/com~ap...
# 36  /Users/brendan/Library/Mobile Documents/com~ap...
# 37  /Users/brendan/Library/Mobile Documents/com~ap...
# 38  /Users/brendan/Library/Mobile Documents/com~ap...
# 39  /Users/brendan/Library/Mobile Documents/com~ap...
# 40  /Users/brendan/Library/Mobile Documents/com~ap...
# 41  /Users/brendan/Library/Mobile Documents/com~ap...
# 42  /Users/brendan/Library/Mobile Documents/com~ap...
# 43  /Users/brendan/Library/Mobile Documents/com~ap...
# 44  /Users/brendan/Library/Mobile Documents/com~ap...
# 45  /Users/brendan/Library/Mobile Documents/com~ap...
# 46  /Users/brendan/Library/Mobile Documents/com~ap...
# 47  /Users/brendan/Library/Mobile Documents/com~ap...
# 48  /Users/brendan/Library/Mobile Documents/com~ap...
# 49  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
df_10_26_1985_filtered_jupyter = raw_df.loc[(raw_df['File Type'] == 'Jupyter Notebook') & (raw_df['Date'] == '10/26/1985 :: 08:15:00')]
df_10_26_1985_filtered_jupyter
# Out:
# Empty DataFrame
# Columns: [File, File Type, Folder Location, Date, Path]
# Index: []

# %%
df_10_26_1985_filtered_vs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 8309 to 14291
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             147 non-null    object
#  1   File Type        147 non-null    object
#  2   Folder Location  147 non-null    object
#  3   Date             147 non-null    object
#  4   Path             147 non-null    object
# dtypes: object(5)
# memory usage: 6.9+ KB

# %%
# filter for all files with the data that matches '08/26/2018 :: 00:52:52'
df_8_26_2018_filtered_vs = raw_df.loc[(raw_df['File Type'] == 'Python file') & 
                                       (raw_df['Date'] == '08/26/2018 :: 00:52:52')]
df_8_26_2018_filtered_jupyter = raw_df.loc[(raw_df['File Type'] == 'Jupyter Notebook') 
                                             & (raw_df['Date'] == '08/26/2018 :: 00:52:52')]
df_8_26_2018_filtered_vs.head()
# Out:
# Empty DataFrame
# Columns: [File, File Type, Folder Location, Date, Path]
# Index: []

# %%
df_8_26_2018_filtered_jupyter.head()
# Out:
# Empty DataFrame
# Columns: [File, File Type, Folder Location, Date, Path]
# Index: []

# %%
'08/10/2018 :: 02:01:48'
# Out:
# '08/10/2018 :: 02:01:48'

# %%
# filter for all files with the data that matches '08/10/2018 :: 02:01:48'
df_8_10_2018_filtered_vs = raw_df.loc[(raw_df['File Type'] == 'Python file') & 
                                       (raw_df['Date'] == '08/10/2018 :: 02:01:48')]
df_8_10_2018_filtered_jupyter = raw_df.loc[(raw_df['File Type'] == 'Jupyter Notebook') 
                                             & (raw_df['Date'] == '08/10/2018 :: 02:01:48')]

df_8_10_2018_filtered_vs.head()
# Out:
#                     File    File Type  \
# 5893   formatted_name.py  Python file
# 5894           person.py  Python file
# 5895  printing_models.py  Python file
# 5896            pizza.py  Python file
# 5897             pets.py  Python file
#
#                                         Folder Location  \
# 5893  /Users/brendan/Library/Mobile Documents/com~ap...
# 5894  /Users/brendan/Library/Mobile Documents/com~ap...
# 5895  /Users/brendan/Library/Mobile Documents/com~ap...
# 5896  /Users/brendan/Library/Mobile Documents/com~ap...
# 5897  /Users/brendan/Library/Mobile Documents/com~ap...
#
#                         Date  \
# 5893  08/10/2018 :: 02:01:48
# 5894  08/10/2018 :: 02:01:48
# 5895  08/10/2018 :: 02:01:48
# 5896  08/10/2018 :: 02:01:48
# 5897  08/10/2018 :: 02:01:48
#
#                                                    Path
# 5893  /Users/brendan/Library/Mobile Documents/com~ap...
# 5894  /Users/brendan/Library/Mobile Documents/com~ap...
# 5895  /Users/brendan/Library/Mobile Documents/com~ap...
# 5896  /Users/brendan/Library/Mobile Documents/com~ap...
# 5897  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
df_8_10_2018_filtered_vs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 5893 to 6300
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             215 non-null    object
#  1   File Type        215 non-null    object
#  2   Folder Location  215 non-null    object
#  3   Date             215 non-null    object
#  4   Path             215 non-null    object
# dtypes: object(5)
# memory usage: 10.1+ KB

# %%
'09/21/2019 :: 02:56:04'
# Out:
# '09/21/2019 :: 02:56:04'

# %%
# filter for all files with the data that matches '09/21/2019 :: 02:56:02'
df_9_21_2019_filtered_vs = raw_df.loc[(raw_df['File Type'] == 'Python file') & 
                                       (raw_df['Date'] == '09/21/2019 :: 02:56:02')]
df_9_21_2019_filtered_jupyter = raw_df.loc[(raw_df['File Type'] == 'Jupyter Notebook') 
                                             & (raw_df['Date'] == '09/21/2019 :: 02:56:02')]

df_9_21_2019_filtered_vs.head()
df_9_21_2019_filtered_jupyter.head()
# Out:
# Empty DataFrame
# Columns: [File, File Type, Folder Location, Date, Path]
# Index: []

# %%
df_9_21_2019_filtered_vs.info()
df_9_21_2019_filtered_jupyter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 4969 to 6718
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             2 non-null      object
#  1   File Type        2 non-null      object
#  2   Folder Location  2 non-null      object
#  3   Date             2 non-null      object
#  4   Path             2 non-null      object
# dtypes: object(5)
# memory usage: 96.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             0 non-null      object
#  1   File Type        0 non-null      object
#  2   Folder Location  0 non-null      object
#  3   Date             0 non-null      object
#  4   Path             0 non-null      object
# dtypes: object(5)
# memory usage: 0.0+ bytes

# %%
raw_df_filtered = raw_df.loc[(raw_df['Date']!='10/26/1985 :: 08:15:00')]
raw_df_filtered2 = raw_df_filtered.loc[(raw_df_filtered['Date']!='09/21/2019 :: 02:56:04')]
raw_df_filtered3 = raw_df_filtered2.loc[(raw_df_filtered2['Date']!='08/26/2018 :: 00:52:52')]
raw_df_filtered_vs = raw_df_filtered3[(raw_df_filtered3['File Type'] == 'Python file')]
raw_df_filtered_vs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 938 entries, 5 to 8878
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             938 non-null    object
#  1   File Type        938 non-null    object
#  2   Folder Location  938 non-null    object
#  3   Date             938 non-null    object
#  4   Path             938 non-null    object
# dtypes: object(5)
# memory usage: 44.0+ KB

# %%
raw_df_filtered_jupyter = raw_df_filtered3[(raw_df_filtered3['File Type'] == 'Jupyter Notebook')]
raw_df_filtered_jupyter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548 entries, 11 to 7448
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File             548 non-null    object
#  1   File Type        548 non-null    object
#  2   Folder Location  548 non-null    object
#  3   Date             548 non-null    object
#  4   Path             548 non-null    object
# dtypes: object(5)
# memory usage: 25.7+ KB

# %%
raw_df_filtered_jupyter.value_counts('File Type'), raw_df_filtered_vs.value_counts('File Type')
# Out:
# (File Type
#  Jupyter Notebook    548
#  dtype: int64,
#  File Type
#  Python file    938
#  dtype: int64)

# %%
raw_df_filtered3.value_counts('File Type')
# Out:
# File Type
#                           4165
# Python file                938
# Javascript                 794
# Jupyter Notebook           548
# JSON file                  529
# JPG Image file             473
# PNG Image file             290
# Text document               61
# PDF file                    40
# SVG Image file              36
# Python file (compiled)      14
# HTML                        10
# Thumbnail                    7
# CSS Styling                  6
# Icon Image file              4
# CSV file                     3
# dtype: int64

# %%
raw_df_filtered3.value_counts('Date')
# Out:
# Date
# 08/10/2018 :: 02:01:48    411
# 09/21/2019 :: 02:56:02    390
# 08/26/2018 :: 00:56:42    220
# 08/21/2018 :: 18:21:08    162
# 11/14/2020 :: 21:38:22    150
#                          ...
# 07/26/2020 :: 21:29:34      1
# 07/26/2020 :: 21:25:25      1
# 07/26/2020 :: 21:24:21      1
# 07/25/2018 :: 20:35:43      1
# 12/31/2020 :: 22:09:58      1
# Length: 2209, dtype: int64

# %%
qgrid_widget = qgrid.show_grid(raw_df_filtered3, show_toolbar = True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
type(raw_df_filtered3['Date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## File type = .py

# %%
# the 'Date' variable in each dataframe needs to be converted to datetime
raw_df_filtered_vs_ = raw_df_filtered_vs.copy()
raw_df_filtered_jupyter_ = raw_df_filtered_jupyter.copy()

raw_df_filtered_vs_['Date'] = pd.to_datetime(raw_df_filtered_vs_['Date'], format = '%m/%d/%Y :: %H:%M:%S')
raw_df_filtered_jupyter_ ['Date']= pd.to_datetime(raw_df_filtered_jupyter_['Date'], format = '%m/%d/%Y :: %H:%M:%S')

raw_df_filtered_jupyter_.value_counts('File Type'), raw_df_filtered_vs_.value_counts('File Type')
# Out:
# (File Type
#  Jupyter Notebook    548
#  dtype: int64,
#  File Type
#  Python file    938
#  dtype: int64)

# %%
df_python = pd.concat([raw_df_filtered_vs_, raw_df_filtered_jupyter_])
df_python_ = df_python.copy()
df_python_['Date'] = pd.to_datetime(df_python["Date"], format = '%m/%d/%Y :: %H:%M:%S')
df_python_.sort_values(by=['Date'])
# Out:
#                            File         File Type  \
# 6370            errorExample.py       Python file
# 6358              allMyCats2.py       Python file
# 6399              allMyCats1.py       Python file
# 6350          characterCount.py       Python file
# 6401      buggyAddingProgram.py       Python file
# ...                         ...               ...
# 430                     data.py       Python file
# 426                       ui.py       Python file
# 429                     main.py       Python file
# 6641  Untitled-checkpoint.ipynb  Jupyter Notebook
# 4922             Untitled.ipynb  Jupyter Notebook
#
#                                         Folder Location                Date  \
# 6370  /Users/brendan/Library/Mobile Documents/com~ap... 2015-03-30 13:51:24
# 6358  /Users/brendan/Library/Mobile Documents/com~ap... 2015-03-30 13:51:24
# 6399  /Users/brendan/Library/Mobile Documents/com~ap... 2015-03-30 13:51:24
# 6350  /Users/brendan/Library/Mobile Documents/com~ap... 2015-03-30 13:51:24
# 6401  /Users/brendan/Library/Mobile Documents/com~ap... 2015-03-30 13:51:24
# ...                                                 ...                 ...
# 430   /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:10:12
# 426   /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:17:25
# 429   /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:18:22
# 6641  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:47:48
# 4922  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:49:51
#
#                                                    Path
# 6370  /Users/brendan/Library/Mobile Documents/com~ap...
# 6358  /Users/brendan/Library/Mobile Documents/com~ap...
# 6399  /Users/brendan/Library/Mobile Documents/com~ap...
# 6350  /Users/brendan/Library/Mobile Documents/com~ap...
# 6401  /Users/brendan/Library/Mobile Documents/com~ap...
# ...                                                 ...
# 430   /Users/brendan/Library/Mobile Documents/com~ap...
# 426   /Users/brendan/Library/Mobile Documents/com~ap...
# 429   /Users/brendan/Library/Mobile Documents/com~ap...
# 6641  /Users/brendan/Library/Mobile Documents/com~ap...
# 4922  /Users/brendan/Library/Mobile Documents/com~ap...
#
# [1486 rows x 5 columns]

# %%
df_python_.value_counts('Date')
# Out:
# Date
# 2018-08-10 02:01:48    215
# 2018-08-21 18:21:08     90
# 2018-08-21 18:19:06     82
# 2018-08-30 18:54:18     69
# 2018-08-21 19:05:30     26
#                       ...
# 2019-12-27 21:12:30      1
# 2019-12-27 21:07:19      1
# 2019-12-27 18:13:33      1
# 2019-12-27 18:02:35      1
# 2021-07-17 19:49:51      1
# Length: 618, dtype: int64

# %%
df_python_widget = qgrid.show_grid(df_python_, show_toolbar = True)
df_python_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df_python_vs = df_python_[df_python_['Date']>'2019-08-31 00:00:00']

# %% [markdown]
# # File type = .ipynb

# %%
df_python_jupyter = raw_df_filtered3[raw_df_filtered3['File Type'] == 'Jupyter Notebook']
df_python_jupyter
# Out:
#                                   File         File Type  \
# 11                     .Untitled.ipynb  Jupyter Notebook
# 12                  bokeh_static.ipynb  Jupyter Notebook
# 18       bokeh_static-checkpoint.ipynb  Jupyter Notebook
# 19          .Untitled-checkpoint.ipynb  Jupyter Notebook
# 22        .05 Matplotlib Lecture.ipynb  Jupyter Notebook
# ...                                ...               ...
# 7436             .Matrix_capital.ipynb  Jupyter Notebook
# 7445          .Coatue-checkpoint.ipynb  Jupyter Notebook
# 7446    .Tiger Global-checkpoint.ipynb  Jupyter Notebook
# 7447  .Matrix_capital-checkpoint.ipynb  Jupyter Notebook
# 7448      .whale_rock-checkpoint.ipynb  Jupyter Notebook
#
#                                         Folder Location  \
# 11    /Users/brendan/Library/Mobile Documents/com~ap...
# 12    /Users/brendan/Library/Mobile Documents/com~ap...
# 18    /Users/brendan/Library/Mobile Documents/com~ap...
# 19    /Users/brendan/Library/Mobile Documents/com~ap...
# 22    /Users/brendan/Library/Mobile Documents/com~ap...
# ...                                                 ...
# 7436  /Users/brendan/Library/Mobile Documents/com~ap...
# 7445  /Users/brendan/Library/Mobile Documents/com~ap...
# 7446  /Users/brendan/Library/Mobile Documents/com~ap...
# 7447  /Users/brendan/Library/Mobile Documents/com~ap...
# 7448  /Users/brendan/Library/Mobile Documents/com~ap...
#
#                         Date  \
# 11    12/05/2020 :: 20:01:10
# 12    07/04/2021 :: 01:53:14
# 18    07/04/2021 :: 01:53:14
# 19    12/05/2020 :: 19:53:08
# 22    12/27/2020 :: 14:23:29
# ...                      ...
# 7436  08/08/2020 :: 04:22:56
# 7445  08/08/2020 :: 23:02:20
# 7446  08/16/2020 :: 01:25:32
# 7447  08/06/2020 :: 00:57:09
# 7448  08/06/2020 :: 01:24:15
#
#                                                    Path
# 11    /Users/brendan/Library/Mobile Documents/com~ap...
# 12    /Users/brendan/Library/Mobile Documents/com~ap...
# 18    /Users/brendan/Library/Mobile Documents/com~ap...
# 19    /Users/brendan/Library/Mobile Documents/com~ap...
# 22    /Users/brendan/Library/Mobile Documents/com~ap...
# ...                                                 ...
# 7436  /Users/brendan/Library/Mobile Documents/com~ap...
# 7445  /Users/brendan/Library/Mobile Documents/com~ap...
# 7446  /Users/brendan/Library/Mobile Documents/com~ap...
# 7447  /Users/brendan/Library/Mobile Documents/com~ap...
# 7448  /Users/brendan/Library/Mobile Documents/com~ap...
#
# [548 rows x 5 columns]

# %%
df_python_jupyter_ = df_python_jupyter.copy()
df_python_jupyter_['Date'] = pd.to_datetime(df_python_jupyter_["Date"], format = '%m/%d/%Y :: %H:%M:%S')
df_python_jupyter_.sort_values(by=['Date'])
# Out:
#                                                    File         File Type  \
# 100   .01-NLP (Natural Language Processing) with Pyt...  Jupyter Notebook
# 106               .01-Matplotlib Concepts Lecture.ipynb  Jupyter Notebook
# 105              .04-Advanced Matplotlib Concepts.ipynb  Jupyter Notebook
# 104          .03-Matplotlib Exercises - Solutions.ipynb  Jupyter Notebook
# 101                   .03-NLP Project - Solutions.ipynb  Jupyter Notebook
# ...                                                 ...               ...
# 5528                                    goodreads.ipynb  Jupyter Notebook
# 424                            ISS_sky-checkpoint.ipynb  Jupyter Notebook
# 421                                       ISS_sky.ipynb  Jupyter Notebook
# 6641                          Untitled-checkpoint.ipynb  Jupyter Notebook
# 4922                                     Untitled.ipynb  Jupyter Notebook
#
#                                         Folder Location                Date  \
# 100   /Users/brendan/Library/Mobile Documents/com~ap... 2018-08-30 18:54:18
# 106   /Users/brendan/Library/Mobile Documents/com~ap... 2018-08-30 18:54:18
# 105   /Users/brendan/Library/Mobile Documents/com~ap... 2018-08-30 18:54:18
# 104   /Users/brendan/Library/Mobile Documents/com~ap... 2018-08-30 18:54:18
# 101   /Users/brendan/Library/Mobile Documents/com~ap... 2018-08-30 18:54:18
# ...                                                 ...                 ...
# 5528  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-15 07:05:08
# 424   /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-15 11:44:57
# 421   /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-15 11:44:57
# 6641  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:47:48
# 4922  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-17 19:49:51
#
#                                                    Path
# 100   /Users/brendan/Library/Mobile Documents/com~ap...
# 106   /Users/brendan/Library/Mobile Documents/com~ap...
# 105   /Users/brendan/Library/Mobile Documents/com~ap...
# 104   /Users/brendan/Library/Mobile Documents/com~ap...
# 101   /Users/brendan/Library/Mobile Documents/com~ap...
# ...                                                 ...
# 5528  /Users/brendan/Library/Mobile Documents/com~ap...
# 424   /Users/brendan/Library/Mobile Documents/com~ap...
# 421   /Users/brendan/Library/Mobile Documents/com~ap...
# 6641  /Users/brendan/Library/Mobile Documents/com~ap...
# 4922  /Users/brendan/Library/Mobile Documents/com~ap...
#
# [548 rows x 5 columns]

# %% [markdown]
# ## File type = ipynb.cloud

# %%
df_python_jupyter_ = df_python_jupyter_[df_python_jupyter_['Date']>'2019-08-31 00:00:00']

# %%
plt.figure(figsize=(15,10))
plt.style.use('fivethirtyeight')
plt.title("Python Files over time")
plt.xlabel("Date")
plt.ylabel('# of Python files on VS Code or Jupyter')
plt.legend(['Visual Studio', 'Jupyter'], loc='upper right')
s = df_python_vs['Date'].value_counts().sort_index()
j = df_python_jupyter_['Date'].value_counts().sort_index()
plt.plot(s, label='Visual Studio Code')
plt.plot(j, label='Jupyter Notebook')
plt.legend()

# %%
df_python_jupyter_['File Type'].value_counts(), df_python_vs['File Type'].value_counts()
# Out:
# (Jupyter Notebook    469
#  Name: File Type, dtype: int64,
#  Jupyter Notebook    469
#  Python file         264
#  Name: File Type, dtype: int64)

# %%
df_python_jupyter_['Date'].value_counts()
# Out:
# 2019-12-31 02:54:21    4
# 2019-12-30 23:40:50    2
# 2020-12-30 01:28:02    2
# 2020-03-07 22:31:56    2
# 2020-12-05 16:17:47    2
#                       ..
# 2020-12-28 22:40:24    1
# 2020-10-24 17:13:34    1
# 2021-07-15 07:04:49    1
# 2019-09-08 16:55:10    1
# 2021-07-17 19:47:48    1
# Name: Date, Length: 301, dtype: int64

# %%
df_python_vs['Date'].value_counts()
# Out:
# 2020-07-28 22:10:22    4
# 2019-12-31 02:54:21    4
# 2020-07-28 21:59:55    4
# 2019-12-27 17:11:21    4
# 2019-12-27 16:52:45    4
#                       ..
# 2020-10-10 14:38:25    1
# 2019-12-26 17:36:20    1
# 2019-10-17 16:34:16    1
# 2020-10-17 17:01:55    1
# 2019-09-23 20:20:32    1
# Name: Date, Length: 527, dtype: int64

# %%
raw_df['File Type'].value_counts()
# Out:
#                           6624
# Javascript                5261
# Python file               1085
# JSON file                  635
# Jupyter Notebook           548
# JPG Image file             502
# SVG Image file             298
# PNG Image file             290
# Text document              152
# PDF file                    40
# Python file (compiled)      14
# HTML                        10
# Thumbnail                    7
# CSS Styling                  6
# Icon Image file              4
# CSV file                     3
# Name: File Type, dtype: int64

# %%
raw_df['Date'].value_counts()
# Out:
# 10/26/1985 :: 08:15:00    5449
# 08/26/2018 :: 00:52:52    1576
# 09/21/2019 :: 02:56:04     536
# 08/10/2018 :: 02:01:48     411
# 09/21/2019 :: 02:56:02     390
#                           ...
# 08/25/2015 :: 04:42:00       1
# 04/28/2002 :: 11:43:03       1
# 12/29/2019 :: 22:10:14       1
# 10/04/2018 :: 18:45:35       1
# 11/07/2019 :: 03:23:04       1
# Name: Date, Length: 2212, dtype: int64

# %% [markdown]
# ## Sorting by dates

# %% [markdown]
# ### For Python-Jupyter first

# %%
raw_df_filtered_vs_.head()
raw_df_filtered_jupyter_.head()
# Out:
#                              File         File Type  \
# 11                .Untitled.ipynb  Jupyter Notebook
# 12             bokeh_static.ipynb  Jupyter Notebook
# 18  bokeh_static-checkpoint.ipynb  Jupyter Notebook
# 19     .Untitled-checkpoint.ipynb  Jupyter Notebook
# 22   .05 Matplotlib Lecture.ipynb  Jupyter Notebook
#
#                                       Folder Location                Date  \
# 11  /Users/brendan/Library/Mobile Documents/com~ap... 2020-12-05 20:01:10
# 12  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-04 01:53:14
# 18  /Users/brendan/Library/Mobile Documents/com~ap... 2021-07-04 01:53:14
# 19  /Users/brendan/Library/Mobile Documents/com~ap... 2020-12-05 19:53:08
# 22  /Users/brendan/Library/Mobile Documents/com~ap... 2020-12-27 14:23:29
#
#                                                  Path
# 11  /Users/brendan/Library/Mobile Documents/com~ap...
# 12  /Users/brendan/Library/Mobile Documents/com~ap...
# 18  /Users/brendan/Library/Mobile Documents/com~ap...
# 19  /Users/brendan/Library/Mobile Documents/com~ap...
# 22  /Users/brendan/Library/Mobile Documents/com~ap...

# %%
df_python_jupyter_dates = raw_df_filtered_jupyter_[['File', 'File Type', 'Date']]
df_python_vs_dates = raw_df_filtered_vs_[['File', 'File Type', 'Date']]
df_python_jupyter_dates
# Out:
#                                   File         File Type                Date
# 11                     .Untitled.ipynb  Jupyter Notebook 2020-12-05 20:01:10
# 12                  bokeh_static.ipynb  Jupyter Notebook 2021-07-04 01:53:14
# 18       bokeh_static-checkpoint.ipynb  Jupyter Notebook 2021-07-04 01:53:14
# 19          .Untitled-checkpoint.ipynb  Jupyter Notebook 2020-12-05 19:53:08
# 22        .05 Matplotlib Lecture.ipynb  Jupyter Notebook 2020-12-27 14:23:29
# ...                                ...               ...                 ...
# 7436             .Matrix_capital.ipynb  Jupyter Notebook 2020-08-08 04:22:56
# 7445          .Coatue-checkpoint.ipynb  Jupyter Notebook 2020-08-08 23:02:20
# 7446    .Tiger Global-checkpoint.ipynb  Jupyter Notebook 2020-08-16 01:25:32
# 7447  .Matrix_capital-checkpoint.ipynb  Jupyter Notebook 2020-08-06 00:57:09
# 7448      .whale_rock-checkpoint.ipynb  Jupyter Notebook 2020-08-06 01:24:15
#
# [548 rows x 3 columns]

# %%
df_python_jupyter_dates_sorted = df_python_jupyter_dates.sort_values(by=['Date'])
df_python_vs_dates_sorted = df_python_vs_dates.sort_values(by=['Date'])

df_python_vs_dates_sorted
df_python_jupyter_dates_sorted
# Out:
#                                                    File         File Type  \
# 100   .01-NLP (Natural Language Processing) with Pyt...  Jupyter Notebook
# 106               .01-Matplotlib Concepts Lecture.ipynb  Jupyter Notebook
# 105              .04-Advanced Matplotlib Concepts.ipynb  Jupyter Notebook
# 104          .03-Matplotlib Exercises - Solutions.ipynb  Jupyter Notebook
# 101                   .03-NLP Project - Solutions.ipynb  Jupyter Notebook
# ...                                                 ...               ...
# 5528                                    goodreads.ipynb  Jupyter Notebook
# 424                            ISS_sky-checkpoint.ipynb  Jupyter Notebook
# 421                                       ISS_sky.ipynb  Jupyter Notebook
# 6641                          Untitled-checkpoint.ipynb  Jupyter Notebook
# 4922                                     Untitled.ipynb  Jupyter Notebook
#
#                     Date
# 100  2018-08-30 18:54:18
# 106  2018-08-30 18:54:18
# 105  2018-08-30 18:54:18
# 104  2018-08-30 18:54:18
# 101  2018-08-30 18:54:18
# ...                  ...
# 5528 2021-07-15 07:05:08
# 424  2021-07-15 11:44:57
# 421  2021-07-15 11:44:57
# 6641 2021-07-17 19:47:48
# 4922 2021-07-17 19:49:51
#
# [548 rows x 3 columns]

# %%
df_python_jupyter_dates_sorted.set_index('Date')
df_python_vs_dates_sorted.set_index('Date')
# Out:
#                                       File    File Type
# Date
# 2015-03-30 13:51:24      characterCount.py  Python file
# 2015-03-30 13:51:24           birthdays.py  Python file
# 2015-03-30 13:51:24        errorExample.py  Python file
# 2015-03-30 13:51:24  buggyAddingProgram.py  Python file
# 2015-03-30 13:51:24            coinFlip.py  Python file
# ...                                    ...          ...
# 2021-07-10 13:35:28          quotes_app.py  Python file
# 2021-07-11 17:38:28                main.py  Python file
# 2021-07-17 19:10:12                data.py  Python file
# 2021-07-17 19:17:25                  ui.py  Python file
# 2021-07-17 19:18:22                main.py  Python file
#
# [938 rows x 2 columns]

# %%
df_python_vs_dates_sorted
df_python_jupyter_dates_sorted
# Out:
#                                                    File         File Type  \
# 100   .01-NLP (Natural Language Processing) with Pyt...  Jupyter Notebook
# 106               .01-Matplotlib Concepts Lecture.ipynb  Jupyter Notebook
# 105              .04-Advanced Matplotlib Concepts.ipynb  Jupyter Notebook
# 104          .03-Matplotlib Exercises - Solutions.ipynb  Jupyter Notebook
# 101                   .03-NLP Project - Solutions.ipynb  Jupyter Notebook
# ...                                                 ...               ...
# 5528                                    goodreads.ipynb  Jupyter Notebook
# 424                            ISS_sky-checkpoint.ipynb  Jupyter Notebook
# 421                                       ISS_sky.ipynb  Jupyter Notebook
# 6641                          Untitled-checkpoint.ipynb  Jupyter Notebook
# 4922                                     Untitled.ipynb  Jupyter Notebook
#
#                     Date
# 100  2018-08-30 18:54:18
# 106  2018-08-30 18:54:18
# 105  2018-08-30 18:54:18
# 104  2018-08-30 18:54:18
# 101  2018-08-30 18:54:18
# ...                  ...
# 5528 2021-07-15 07:05:08
# 424  2021-07-15 11:44:57
# 421  2021-07-15 11:44:57
# 6641 2021-07-17 19:47:48
# 4922 2021-07-17 19:49:51
#
# [548 rows x 3 columns]

# %%
# First, reformat the Date variable so it reads month/day/Year
df_python_jupyter_dates_sorted['Date'] = pd.to_datetime(df_python_jupyter_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_vs_dates_sorted['Date'] = pd.to_datetime(df_python_vs_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))

# %%
# Then call value_counts and convert this to a new DataFrame

df_python_vs_dates_sorted['Date'] = pd.to_datetime(df_python_vs_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_vs_dates_sorted_toframe = df_python_vs_dates_sorted['Date'].value_counts().to_frame()

df_python_jupyter_dates_sorted['Date'] = pd.to_datetime(df_python_jupyter_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_jupyter_dates_sorted_toframe = df_python_jupyter_dates_sorted['Date'].value_counts().to_frame()

# %%
# Then I reset the index and rename the labels
df_jupyter_raw = df_python_jupyter_dates_sorted_toframe.reset_index()
df_vs_raw = df_python_vs_dates_sorted_toframe.reset_index()

# %%
# And rename the column labels
df_jupyter = df_jupyter_raw.rename(columns={'index':'Date', 'Date':'Files'})
df_jupyter_output = df_jupyter.sort_values(by='Date')

df_vs = df_vs_raw.rename(columns={'index':'Date', 'Date':'Files'})
df_vs_output = df_vs.sort_values(by='Date')
df_vs_output_ = df_vs_output[df_vs_output['Date'] > '2018-08-27']

# %%
# DataFrame to be used for visualization
df_jupyter_output.head()
# Out:
#           Date  Files
# 0   2018-08-30     69
# 7   2018-11-14     10
# 105 2019-09-01      1
# 46  2019-09-02      3
# 27  2019-09-07      5

# %%
df_vs_output_.head()
# Out:
#          Date  Files
# 15 2018-09-27     10
# 7  2018-10-04     14
# 10 2018-10-05     12
# 34 2019-09-21      2
# 33 2019-10-17      2

# %%
df_python_jupyter_dates_sorted['Date'] = pd.to_datetime(df_python_jupyter_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_jupyter_dates_sorted.head(10)

df_jupyter_dates_frame = df_python_jupyter_dates_sorted['Date'].value_counts().to_frame()
df_jupyter_raw = df_jupyter_dates_frame.reset_index()
df_jupyter_raw

df_jupyter = df_jupyter_raw.rename(columns={'index':'Date', 'Date':'Files'})
df_jupyter_output = df_jupyter.sort_values(by='Date')
df_jupyter_output.head()
# Out:
#           Date  Files
# 0   2018-08-30     69
# 7   2018-11-14     10
# 105 2019-09-01      1
# 46  2019-09-02      3
# 27  2019-09-07      5

# %%
df_jupyter_output.shape, df_vs_output.shape
# Out:
# ((119, 2), (55, 2))

# %%
df_jupyter_output.head()
df_vs_output_.head()
# Out:
#          Date  Files
# 15 2018-09-27     10
# 7  2018-10-04     14
# 10 2018-10-05     12
# 34 2019-09-21      2
# 33 2019-10-17      2

# %%
# Graph Jupyter files
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
ax.bar(df_jupyter_output['Date'], df_jupyter_output['Files'], width=7, ec='black')
ax.xaxis_date()

plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded (Jupyter Notebook) during the Pandemic')
plt.savefig('jupyter_graph.png')
plt.show()

# %%
#

# %%
# Combine the two plots
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
ax.bar(df_vs_output_['Date'], df_vs_output_['Files'], width=7, ec='black', color='red')
ax.bar(df_jupyter_output['Date'], df_jupyter_output['Files'], width=7, ec='black', color='blue')
ax.xaxis_date()


plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded (Visual Studio Code & Jupyter Notebook) during the Pandemic')
plt.savefig('python_graph.png')
plt.show()

# %% [markdown]
# ## Bring in COVID dataset

# %%
cov_df_raw_usa_new_cases = cov_df_raw_usa[['date', 'new_cases']]
cov_df_raw_usa_new_cases['date']
# Out:
# 110899    2020-01-22
# 110900    2020-01-23
# 110901    2020-01-24
# 110902    2020-01-25
# 110903    2020-01-26
#              ...
# 111497    2021-09-11
# 111498    2021-09-12
# 111499    2021-09-13
# 111500    2021-09-14
# 111501    2021-09-15
# Name: date, Length: 603, dtype: object

# %%
cov_df_raw_usa_new_cases['date'] = pd.to_datetime(cov_df_raw_usa_new_cases['date'], format='%Y-%m-%d')

x = cov_df_raw_usa_new_cases['date']
y = cov_df_raw_usa_new_cases['new_cases']

plt.bar(x,y, color='blue')


plt.xlabel('Date')
plt.ylabel('# of new cases')
plt.title('Covid new case data')
#plt.savefig('covid_graph.png')
plt.show()

# %%
# Combine the two plots and COVID dataset
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(25,15))
ax = plt.subplot(111)
ax.bar(df_vs_output_['Date'], df_vs_output_['Files'], width=7, ec='black', color='red')
ax.bar(df_jupyter_output['Date'], df_jupyter_output['Files'], width=7, ec='black', color='blue')
ax.xaxis_date()

plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded (Visual Studio Code & Jupyter Notebook) during the Pandemic')
plt.savefig('python_graph.png')

# twin objecty
ax2 = ax.twinx()
ax2.plot(cov_df_raw_usa_new_cases['date'],cov_df_raw_usa_new_cases['new_cases'])
ax2.xaxis_date()


plt.show()

# %%
# Combine the two plots and COVID dataset

fig = plt.figure(figsize=(18,12))
ax = plt.subplot(111)

df_vs_output__ = df_vs_output_[df_vs_output_['Date'] > '2020-03-12']
df_jupyter_output_ = df_jupyter_output[df_jupyter_output['Date'] > '2020-03-12']


ax.bar(df_vs_output__['Date'], df_vs_output__['Files'], width=7, ec='black', color='red')
ax.bar(df_jupyter_output_['Date'], df_jupyter_output_['Files'], width=7, ec='black', color='blue')
ax.xaxis_date()
ax.axhline(0)

plt.xlabel('Date', fontsize=18)
plt.ylabel('# of Files uploaded', fontsize=18)
plt.title('How did the COVID case count in the United States impact the # of Python files I created?', fontsize=18)
plt.savefig('python_covid.png')

# twin objecty
ax2 = ax.twinx()
ax2.plot(cov_df_raw_usa_new_cases['date'],cov_df_raw_usa_new_cases['new_cases'])
ax2.xaxis_date()



plt.tight_layout()
mpl_axes_aligner.align.yaxes(ax, 0, ax2, 0, 0.1)
plt.savefig('python_covid.png')

plt.show()

# %% [markdown]
# ## Count the files

# %%
# Visual Studio Code - count # of files pre and post 3/12
df_vs_output_.head()
df_vs_output_pre = df_vs_output_.copy()
df_vs_output_pre = df_vs_output_pre[df_vs_output_pre['Date'] <='2020-03-12'] # files pre-COVID
df_vs_output_pre.shape

# %%
df_vs_output_post = df_vs_output_.copy()
df_vs_output_post = df_vs_output_post[df_vs_output_post['Date'] > '2020-03-12']
df_vs_output_post.shape

# %%
# Jupyter Notebook - count # of files pre and post 3/12
df_jupyter.head()
df_jupyter_output_pre = df_jupyter_output.copy()
df_jupyter_output_pre = df_jupyter_output_pre[df_jupyter_output_pre['Date'] <='2020-03-12'] # files pre-COVID
df_jupyter_output_pre.shape

# %%
# Jupyter Notebook - count # of files pre and post 3/12
df_jupyter.head()
df_jupyter_output_post = df_jupyter_output.copy()
df_jupyter_output_post = df_jupyter_output_post[df_jupyter_output_post['Date'] >'2020-03-12'] # files pre-COVID
df_jupyter_output_post.shape

# %%
# 4 dataframes, 1 each for pre and post '3/12/2020' for VS Code and Jupyter Notebook
df_jupyter_output_pre_files = df_jupyter_output_pre['Files'].sum()
df_jupyter_output_post_files = df_jupyter_output_post['Files'].sum()

df_vs_output_pre_files = df_vs_output_pre['Files'].sum()
df_vs_output_post_files = df_vs_output_post['Files'].sum()

print('Jupyter Files, pre 3/12/20210: ', df_jupyter_output_pre_files)
print('Jupyter Files, post 3/12/2020: ', df_jupyter_output_post_files)
print('VS Code Files, pre 3/12/20210: ', df_vs_output_pre_files)
print('VS Code Files, post 3/12/2020: ', df_vs_output_post_files)

# %%
raw_df_filtered_vs_.head()
raw_df_filtered_jupyter.head()

# %%
filenames_vs = raw_df_filtered_vs_['Path'].astype(str).to_list()
filenames_jupyter = raw_df_filtered_jupyter['Path'].astype(str).to_list()

# %%
len(filenames_vs), len(filenames_jupyter)

# %%
# of lines for VS code
line_count = 0
for file in filenames_vs:
    file_open = open(file)
    for line in file:
        line_count += 1
    file_open.close()
print(line_count)

# %%
# of lines for jupyter
line_count = 0
for file in filenames_jupyter:
    file_open = open(file)
    for line in file:
        line_count += 1
    file_open.close()
print(line_count)

# %%
# of words for VS

number_of_words = 0
for file in filenames_vs:
    file_open = open(file)
    for line in file:
        words = line.split()
        number_of_words += len(words)
    file_open.close()
print(number_of_words)

# %%
# of words for Jupyter

number_of_words = 0
for file in filenames_jupyter:
    file_open = open(file)
    for line in file:
        words = line.split()
        number_of_words += len(words)
    file_open.close()
print(number_of_words)

# %% [markdown]
# ## Analysis by days of the week

# %%
raw_df_filtered_vs_.shape
raw_df_filtered_jupyter.shape

# %%
raw_df_filtered_vs_.head()

# %%
raw_df_filtered_vs_2= raw_df_filtered_vs_[raw_df_filtered_vs_['Date'] >'2018-08-11 00:00:00']
raw_df_filtered_vs_2

# %%
raw_df_filtered_vs_2['Date'].value_counts()

# %%
# Jupyter
raw_df_jupyter_date = raw_df_filtered_jupyter[['File', 'Date']]
raw_df_jupyter_date['Date'] = pd.to_datetime(raw_df_jupyter_date["Date"], format = '%m/%d/%Y :: %H:%M:%S')

raw_df_jupyter_date['Day'] = raw_df_jupyter_date['Date'].dt.day_name()
raw_df_jupyter_date.style.set_caption("Jupyter Notebook")

raw_df_jupyter_date.groupby(['Day']).count()

# %%
raw_df_filtered_vs

# %%
# VS
raw_df_filtered_vs_3 = raw_df_filtered_vs_2.loc[(raw_df_filtered_vs['Date'] >= '08/22/2019 :: 0:0:0')]
raw_df_filtered_vs_3.shape
raw_df_filtered_vs_3['Date'].value_counts()

# %%
# VS
raw_df_vs_date = raw_df_filtered_vs_3[['File', 'Date']]
raw_df_vs_date['Date'] = pd.to_datetime(raw_df_vs_date["Date"], format = '%m/%d/%Y :: %H:%M:%S')

raw_df_vs_date['Day'] = raw_df_vs_date['Date'].dt.day_name()
raw_df_vs_date.style.set_caption("VS Code")

raw_df_vs_date.groupby(['Day']).count()

# %% [markdown]
# ## Pull in Covid data

# %%
covid_df_raw = pd.read_csv('owid-covid-data.csv')
covid_df_raw.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 62 columns]

# %%
# explore the dataset

# %%
covid_df_raw['continent'].value_counts()
# Out:
# Africa           29731
# Europe           27481
# Asia             27296
# North America    14989
# South America     6896
# Oceania           5275
# Name: continent, dtype: int64

# %%
covid_df_raw[covid_df_raw['location'] == 'United States']['location'].value_counts()
# Out:
# United States    603
# Name: location, dtype: int64

# %%
cov_df_raw_usa = covid_df_raw[covid_df_raw['location'] == 'United States']
cov_df_raw_usa_ = cov_df_raw_usa[cov_df_raw_usa['date'] > '2020-03-01']
cov_df_raw_usa_
# Out:
#        iso_code      continent       location        date  total_cases  \
# 110939      USA  North America  United States  2020-03-02         55.0
# 110940      USA  North America  United States  2020-03-03         74.0
# 110941      USA  North America  United States  2020-03-04        107.0
# 110942      USA  North America  United States  2020-03-05        184.0
# 110943      USA  North America  United States  2020-03-06        237.0
# ...         ...            ...            ...         ...          ...
# 111497      USA  North America  United States  2021-09-11   41021592.0
# 111498      USA  North America  United States  2021-09-12   41057176.0
# 111499      USA  North America  United States  2021-09-13   41317328.0
# 111500      USA  North America  United States  2021-09-14   41461662.0
# 111501      USA  North America  United States  2021-09-15   41627946.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 110939       23.0               5.571           6.0         5.0
# 110940       19.0               8.286           7.0         1.0
# 110941       33.0              13.000          11.0         4.0
# 110942       77.0              23.857          12.0         1.0
# 110943       53.0              31.429          14.0         2.0
# ...           ...                 ...           ...         ...
# 111497    63965.0          146195.571      659691.0       699.0
# 111498    35584.0          145551.857      659970.0       279.0
# 111499   260152.0          172001.571      662106.0      2136.0
# 111500   144334.0          153146.714      663929.0      1823.0
# 111501   166284.0          150968.286      666607.0      2678.0
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 110939                0.857  ...              1.2                151.089
# 110940                1.000  ...              1.2                151.089
# 110941                1.571  ...              1.2                151.089
# 110942                1.714  ...              1.2                151.089
# 110943                2.000  ...              1.2                151.089
# ...                     ...  ...              ...                    ...
# 111497             1626.286  ...              1.2                151.089
# 111498             1614.000  ...              1.2                151.089
# 111499             1843.286  ...              1.2                151.089
# 111500             1805.000  ...              1.2                151.089
# 111501             1880.429  ...              1.2                151.089
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 110939                10.79            19.1          24.6
# 110940                10.79            19.1          24.6
# 110941                10.79            19.1          24.6
# 110942                10.79            19.1          24.6
# 110943                10.79            19.1          24.6
# ...                     ...             ...           ...
# 111497                10.79            19.1          24.6
# 111498                10.79            19.1          24.6
# 111499                10.79            19.1          24.6
# 111500                10.79            19.1          24.6
# 111501                10.79            19.1          24.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 110939                     NaN                        2.77            78.86
# 110940                     NaN                        2.77            78.86
# 110941                     NaN                        2.77            78.86
# 110942                     NaN                        2.77            78.86
# 110943                     NaN                        2.77            78.86
# ...                        ...                         ...              ...
# 111497                     NaN                        2.77            78.86
# 111498                     NaN                        2.77            78.86
# 111499                     NaN                        2.77            78.86
# 111500                     NaN                        2.77            78.86
# 111501                     NaN                        2.77            78.86
#
#         human_development_index  excess_mortality
# 110939                    0.926               NaN
# 110940                    0.926               NaN
# 110941                    0.926               NaN
# 110942                    0.926               NaN
# 110943                    0.926               NaN
# ...                         ...               ...
# 111497                    0.926               NaN
# 111498                    0.926               NaN
# 111499                    0.926               NaN
# 111500                    0.926               NaN
# 111501                    0.926               NaN
#
# [563 rows x 62 columns]

# %%
os.getcwd()
os.chdir('/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science')
df_python_jupyter_dates_sorted
# Out:
#                                                    File         File Type  \
# 100   .01-NLP (Natural Language Processing) with Pyt...  Jupyter Notebook
# 106               .01-Matplotlib Concepts Lecture.ipynb  Jupyter Notebook
# 105              .04-Advanced Matplotlib Concepts.ipynb  Jupyter Notebook
# 104          .03-Matplotlib Exercises - Solutions.ipynb  Jupyter Notebook
# 101                   .03-NLP Project - Solutions.ipynb  Jupyter Notebook
# ...                                                 ...               ...
# 5528                                    goodreads.ipynb  Jupyter Notebook
# 424                            ISS_sky-checkpoint.ipynb  Jupyter Notebook
# 421                                       ISS_sky.ipynb  Jupyter Notebook
# 6641                          Untitled-checkpoint.ipynb  Jupyter Notebook
# 4922                                     Untitled.ipynb  Jupyter Notebook
#
#            Date
# 100  2018-08-30
# 106  2018-08-30
# 105  2018-08-30
# 104  2018-08-30
# 101  2018-08-30
# ...         ...
# 5528 2021-07-15
# 424  2021-07-15
# 421  2021-07-15
# 6641 2021-07-17
# 4922 2021-07-17
#
# [548 rows x 3 columns]

# %%
# store the filenames as

# %%
os.chdir('/Users/brendan/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Data Science')
os.getcwd()
filenames = df_python_jupyter_dates_sorted['Path'].astype(str).to_list()
line_count = 0
for file in filenames:
    file_open = open(file)
    for line in file:
        line_count += 1
    file_open.close()

# %%
# Graph VS files
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
ax.bar(df_vs_output_['Date'], df_vs_output_['Files'], width=7, ec='black', color='red')
ax.xaxis_date()

plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded (Visual Studio Code) during the Pandemic')
plt.savefig('vs_graph.png')
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
ax.bar(df_jupyter_output['Date'], df_jupyter_output['Files'], width=7, ec='black')
ax.xaxis_date()
plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded to Jupyter Notebook during the Pandemic')
plt.show()

# %%
    # split the date by date and time
# then count frequyency by day

# %% [markdown]
# ### For Python - VS Code next

# %%
df_python_vs_dates = df_python_vs[['File', 'File Type', 'Date']]
df_python_vs_dates

# %%
df_python_vs_dates_sorted = df_python_vs_dates.sort_values(by=['Date'])
df_python_vs_dates_sorted['Date'] = pd.to_datetime(df_python_vs_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_vs_dates_sorted.head(10)

# %%
df_python_vs_dates_sorted['Date'] = pd.to_datetime(df_python_vs_dates_sorted['Date'].dt.strftime('%m/%d/%Y'))
df_python_vs_dates_sorted.head(10)

df_vs_dates_frame = df_python_vs_dates_sorted['Date'].value_counts().to_frame()
#df_jupyter_dates_frame_sorted = df_jupyter_dates_frame.sort_values(by='Date')

#df_vs = df_vs_dates_frame.rename(columns={'index':'Date', 'Date':'Files'})
#df_vs_output = df_vs.sort_values(by='Date')
df_vs_raw = df_vs_dates_frame.reset_index()
df_vs_raw

df_vs = df_vs_raw.rename(columns={'index':'Date', 'Date':'Files'})
df_vs_output = df_vs.sort_values(by='Date')
df_vs_output.head()

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
ax.bar(df_vs_output['Date'], df_vs_output['Files'], width=7, ec='black', color='red')
ax.xaxis_date()
plt.xlabel('Date')
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded to Visual Studio during the Pandemic')
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.subplot(111)
ax.bar(df_jupyter_output['Date'], df_jupyter_output['Files'], width=7, ec='black')
ax.bar(df_vs_output['Date'], df_vs_output['Files'], width=7, ec='black', color='red')
ax.xaxis_date()

ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.xlabel('Date')
plt.xticks(rotation=45, fontsize=8)
plt.ylabel('# of Files uploaded')
plt.title('# of Python Files Uploaded (Daily) during the Pandemic')
plt.legend(['Jupyter', 'Visual Code'])
plt.savefig('python_files.jpg')
plt.show()
