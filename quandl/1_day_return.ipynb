# %%
from datetime import date
import quandl
quandl.ApiConfig.api_key = 'Hu3ZHysZhH1VrPCHA6ym'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.min_rows', 20)

# %%
df_SP500 = pd.read_csv('/Users/brendan/Desktop/Python/Quandl/constituents.csv')

# %%
df_SP500.columns = ['ticker','Company','Sector']

# %%
tickers_SP500 = list(df_SP500['ticker'])

# %%
df_SP500['Sector'].value_counts()
# Out:
# Industrials               74
# Information Technology    74
# Financials                65
# Health Care               64
# Consumer Discretionary    63
# Consumer Staples          32
# Real Estate               29
# Utilities                 28
# Materials                 28
# Communication Services    27
# Energy                    21
# Name: Sector, dtype: int64

# %%
df_SP500_industrials = df_SP500[df_SP500['Sector']=='Industrials']
df_SP500_tech = df_SP500[df_SP500['Sector']=='Information Technology']
df_SP500_healthcare = df_SP500[df_SP500['Sector']=='Health Care']
df_SP500_consumer = df_SP500[df_SP500['Sector']=='Consumer Discretionary']
df_SP500_comm = df_SP500[df_SP500['Sector']=='Communication Services']

# %%
# ticker list
tickers_industrials = list(df_SP500_industrials['ticker'])
tickers_tech = list(df_SP500_tech['ticker'])
tickers_healthcare = list(df_SP500_healthcare['ticker'])
tickers_consumer = list(df_SP500_consumer['ticker'])
tickers_comm = list(df_SP500_comm['ticker'])

# %% [markdown]
# ## Tech

# %%
prices_06_03_2022 = pd.read_csv('/Users/brendan/Desktop/Python/Quandl/quandl_prices_06_03_2022.csv')

# %%
len(prices_06_03_2022)
# Out:
# 10000

# %%
prices_06_03_2022_df = prices_06_03_2022[prices_06_03_2022['date']=='2022-06-03']
len(prices_06_03_2022_df)
# Out:
# 10

# %%
data = quandl.get_table("SHARADAR/SP500", paginate=True)

# %%
data.head()
# Out:
#            date   action ticker                                       name  \
# None
# 0    2022-06-03  current    ZTS                                 ZOETIS INC
# 1    2022-06-03  current   ZION  ZIONS BANCORPORATION NATIONAL ASSOCIATION
# 2    2022-06-03  current   ZBRA                    ZEBRA TECHNOLOGIES CORP
# 3    2022-06-03  current    ZBH                 ZIMMER BIOMET HOLDINGS INC
# 4    2022-06-03  current    YUM                             YUM BRANDS INC
#
#      contraticker contraname  note
# None
# 0             N/A        N/A  None
# 1             N/A        N/A  None
# 2             N/A        N/A  None
# 3             N/A        N/A  None
# 4             N/A        N/A  None

# %%
data2 = pd.read_csv('/Users/brendan/Desktop/Python/June 2022/SHARADAR_DAILY_3_06_03_2022.csv')

# %%
data2[data2['date']=='2022-06-02'].head()
# Out:
#         ticker        date lastupdated       ev  evebit  evebitda  marketcap  \
# 7394501   ARIZ  2022-06-02  2022-06-02     87.6     NaN       NaN       87.9
# 7394502   ARKO  2022-06-02  2022-06-02   2924.2    19.1      11.7     1108.8
# 7394503   ARKR  2022-06-02  2022-06-02    131.0     6.4       5.3       66.3
# 7394504    ARL  2022-06-02  2022-06-02    651.0    28.3      17.4      353.6
# 7498250      A  2022-06-02  2022-06-02  40282.2    26.7      21.9    38563.2
#
#            pb     pe   ps
# 7394501 -38.0    NaN  NaN
# 7394502   4.6   15.7  0.1
# 7394503   1.2    5.2  0.4
# 7394504   1.4 -103.8  9.3
# 7498250   7.5   30.5  5.9

# %%
data3 = pd.read_csv('/Users/brendan/Desktop/Python/June 2022/SHARADAR_SEP_06_03_2022.csv')

# %%
data3[data3['date']=='2022-06-02'].head()
# Out:
#          ticker        date  open   high   low  close   volume  closeadj  \
# 8568340   AAC.U  2022-06-02  9.81  9.840  9.81   9.84    422.0      9.84
# 8568341  AAC.WS  2022-06-02  0.24  0.240  0.24   0.24   5428.0      0.24
# 8568342    AACG  2022-06-02  0.97  1.035  0.97   1.03  15743.0      1.03
# 8568343    AACI  2022-06-02  9.88  9.890  9.88   9.89  14278.0      9.89
# 8568344   AACIU  2022-06-02  9.93  9.930  9.93   9.93    500.0      9.93
#
#          closeunadj lastupdated
# 8568340        9.84  2022-06-02
# 8568341        0.24  2022-06-02
# 8568342        1.03  2022-06-02
# 8568343        9.89  2022-06-02
# 8568344        9.93  2022-06-02

# %%
SP500_metrics = data2[data2['ticker'].isin(tickers_SP500)]
SP500_metrics_06_02_2022 = SP500_metrics[SP500_metrics['date']=='2022-06-02']

SP500_prices = data3[data3['ticker'].isin(tickers_SP500)]
SP500_prices_06_02_2022 = SP500_prices[SP500_prices['date']=='2022-06-02']

# %%
len(SP500_prices_06_02_2022), len(SP500_metrics_06_02_2022)
# Out:
# (496, 491)

# %%
SP500_metrics_06_02_2022.head()
# Out:
#         ticker        date lastupdated         ev  evebit  evebitda  \
# 7498250      A  2022-06-02  2022-06-02    40282.2    26.7      21.9
# 7498257    AAL  2022-06-02  2022-06-02    55874.5   -47.8      47.9
# 7498263    AAP  2022-06-02  2022-06-02    14966.7    19.1      14.2
# 7498264   AAPL  2022-06-02  2022-06-02  2539244.2    20.9      19.1
# 7498272   ABBV  2022-06-02  2022-06-02   326699.4    20.0      13.2
#
#          marketcap    pb    pe   ps
# 7498250    38563.2   7.5  30.5  5.9
# 7498257    11340.5  -1.3  -4.8  0.3
# 7498263    11587.7   4.0  20.3  1.0
# 7498264  2447361.2  36.3  24.0  6.3
# 7498272   259323.4  15.9  20.8  4.6

# %%
SP500_prices_06_02_2022.head()
# Out:
#         ticker        date    open    high      low   close    volume  \
# 8568536    AIZ  2022-06-02  178.35  179.95  176.705  179.93  420613.0
# 8568570   ALLE  2022-06-02  112.62  114.37  112.010  114.11  574690.0
# 8568815    AVB  2022-06-02  207.60  209.28  204.290  208.97  609325.0
# 8569043     BR  2022-06-02  145.16  147.65  143.900  147.63  302687.0
# 8569374    EXR  2022-06-02  178.35  179.97  174.870  179.83  584510.0
#
#          closeadj  closeunadj lastupdated
# 8568536    179.93      179.93  2022-06-02
# 8568570    114.11      114.11  2022-06-02
# 8568815    208.97      208.97  2022-06-02
# 8569043    147.63      147.63  2022-06-02
# 8569374    179.83      179.83  2022-06-02

# %%
SP500_06_02_2022 = pd.merge(SP500_metrics_06_02_2022, SP500_prices_06_02_2022,on='ticker')

# %%
SP500_06_02_2022 = SP500_06_02_2022.drop(['lastupdated_x','lastupdated_y', 'date_y'],axis=1)
SP500_06_02_2022.head()
# Out:
#   ticker      date_x         ev  evebit  evebitda  marketcap    pb    pe   ps  \
# 0      A  2022-06-02    40282.2    26.7      21.9    38563.2   7.5  30.5  5.9
# 1    AAL  2022-06-02    55874.5   -47.8      47.9    11340.5  -1.3  -4.8  0.3
# 2    AAP  2022-06-02    14966.7    19.1      14.2    11587.7   4.0  20.3  1.0
# 3   AAPL  2022-06-02  2539244.2    20.9      19.1  2447361.2  36.3  24.0  6.3
# 4   ABBV  2022-06-02   326699.4    20.0      13.2   259323.4  15.9  20.8  4.6
#
#      open    high      low   close      volume  closeadj  closeunadj
# 0  122.96  129.19  122.300  129.10   1444412.0    129.10      129.10
# 1   17.27   17.51   17.175   17.46  23195134.0     17.46       17.46
# 2  188.45  191.25  185.895  191.09    729004.0    191.09      191.09
# 3  147.83  151.27  146.860  151.21  72095989.0    151.21      151.21
# 4  146.65  147.07  142.900  146.75   5998940.0    146.75      146.75

# %% [markdown]
# ## 1 day

# %%
SP500_metrics = data2[data2['ticker'].isin(tickers_SP500)]
SP500_metrics_06_01_2022 = SP500_metrics[SP500_metrics['date']=='2022-06-01']

SP500_prices = data3[data3['ticker'].isin(tickers_SP500)]
SP500_prices_06_01_2022 = SP500_prices[SP500_prices['date']=='2022-06-01']

SP500_06_01_2022 = pd.merge(SP500_metrics_06_01_2022, SP500_prices_06_01_2022,on='ticker')
SP500_06_01_2022 = SP500_06_01_2022.drop(['lastupdated_x','lastupdated_y', 'date_y'],axis=1)
SP500_06_01_2022.head()
# Out:
#   ticker      date_x         ev  evebit  evebitda  marketcap    pb    pe   ps  \
# 0      A  2022-06-01    38487.0    25.5      20.9    36768.0   7.2  29.1  5.6
# 1    AAL  2022-06-01    55764.1   -47.7      47.8    11230.1  -1.3  -4.7  0.3
# 2    AAP  2022-06-01    14758.7    18.9      14.0    11379.7   3.9  20.0  1.0
# 3   AAPL  2022-06-01  2498781.3    20.5      18.8  2406898.3  35.7  23.6  6.2
# 4   ABBV  2022-06-01   325409.4    19.9      13.2   258033.4  15.8  20.7  4.5
#
#      open    high     low   close      volume  closeadj  closeunadj
# 0  127.86  128.98  122.43  123.09   1757618.0    123.09      123.09
# 1   18.07   18.10   16.98   17.29  32525103.0     17.29       17.29
# 2  191.62  192.04  187.29  187.66    728568.0    187.66      187.66
# 3  149.90  151.74  147.68  148.71  74046038.0    148.71      148.71
# 4  147.79  147.89  144.32  146.02   5597906.0    146.02      146.02

# %% [markdown]
# ## 1 day return

# %%
SP500_prices_06_01_2022 = SP500_06_01_2022[['ticker', 'date_x', 'closeadj']]
SP500_prices_06_02_2022 = SP500_06_02_2022[['ticker', 'date_x', 'closeadj']]
SP500_1day_06_02_2022 = pd.concat([SP500_prices_06_01_2022, SP500_prices_06_02_2022])
SP500_1day_06_02_2022['1_day_%'] = SP500_1day_06_02_2022.groupby(['ticker'])['closeadj'].pct_change()*100
SP500_1day_06_02_2022= SP500_1day_06_02_2022.dropna()

# %%
SP500_1day_06_02_2022_merged = SP500_1day_06_02_2022.merge(df_SP500,how='inner',on=['ticker'])
SP500_1day_06_02_2022_merged.head()
# Out:
#   ticker      date_x  closeadj   1_day_%                  Company  \
# 0      A  2022-06-02    129.10  4.882606     Agilent Technologies
# 1    AAL  2022-06-02     17.46  0.983227  American Airlines Group
# 2    AAP  2022-06-02    191.09  1.827774       Advance Auto Parts
# 3   AAPL  2022-06-02    151.21  1.681124                    Apple
# 4   ABBV  2022-06-02    146.75  0.499932                   AbbVie
#
#                    Sector
# 0             Health Care
# 1             Industrials
# 2  Consumer Discretionary
# 3  Information Technology
# 4             Health Care

# %% [markdown]
# ## Market cap wgt return

# %%
SP500_06_01_2022_mcap = SP500_06_01_2022.merge(df_SP500,how='inner',on=['ticker'])
SP500_06_01_2022_mcap= SP500_06_01_2022_mcap[['date_x', 'ticker','Company','Sector','marketcap','ev','evebit','pb','pe','ps',
                       'open','high','low','close','volume','closeadj','closeunadj']]
SP500_06_01_2022_mcap.to_csv('SP500_06_01_2022.csv')

# %%
SP500_06_02_2022_mcap = SP500_06_02_2022.merge(df_SP500,how='inner',on=['ticker'])
SP500_06_02_2022_mcap= SP500_06_02_2022_mcap[['date_x', 'ticker','Company','Sector','marketcap','ev','evebit','pb','pe','ps',
                       'open','high','low','close','volume','closeadj','closeunadj']]
SP500_06_02_2022_mcap.to_csv('SP500_06_02_2022.csv')

# %%
SP500_06_02_mcap_chg = pd.concat([SP500_06_01_2022_mcap, SP500_06_02_2022_mcap])
SP500_06_02_mcap_chg['1_day_%'] = SP500_06_02_mcap_chg.groupby(['ticker'])['marketcap'].pct_change()*100
SP500_06_02_mcap_chg.dropna().head()
# Out:
#        date_x ticker                  Company                  Sector  \
# 0  2022-06-02      A     Agilent Technologies             Health Care
# 1  2022-06-02    AAL  American Airlines Group             Industrials
# 2  2022-06-02    AAP       Advance Auto Parts  Consumer Discretionary
# 3  2022-06-02   AAPL                    Apple  Information Technology
# 4  2022-06-02   ABBV                   AbbVie             Health Care
#
#    marketcap         ev  evebit    pb    pe   ps    open    high      low  \
# 0    38563.2    40282.2    26.7   7.5  30.5  5.9  122.96  129.19  122.300
# 1    11340.5    55874.5   -47.8  -1.3  -4.8  0.3   17.27   17.51   17.175
# 2    11587.7    14966.7    19.1   4.0  20.3  1.0  188.45  191.25  185.895
# 3  2447361.2  2539244.2    20.9  36.3  24.0  6.3  147.83  151.27  146.860
# 4   259323.4   326699.4    20.0  15.9  20.8  4.6  146.65  147.07  142.900
#
#     close      volume  closeadj  closeunadj   1_day_%
# ...

# %%
SP500_06_01_2022_sector = SP500_06_01_2022_mcap.groupby(["Sector"])['marketcap'].agg('sum').to_frame()
SP500_06_02_2022_sector = SP500_06_02_2022_mcap.groupby(["Sector"])['marketcap'].agg('sum').to_frame()
SP500_06_02_2022_sector
# Out:
#                         marketcap
# Sector
# Communication Services  3471221.1
# Consumer Discretionary  4294806.3
# Consumer Staples        2612460.9
# Energy                  1724594.8
# Financials              4104405.0
# Health Care             5075548.0
# Industrials             2915400.4
# Information Technology  9914500.4
# Materials                977606.6
# Real Estate              980604.8
# Utilities               1027416.6

# %%
SP500_06_02_2022_sector_chg = pd.concat([SP500_06_01_2022_sector, SP500_06_02_2022_sector])
SP500_06_02_2022_sector_chg['1_day_%'] = SP500_06_02_2022_sector_chg.groupby(['Sector'])['marketcap'].pct_change()*100

SP500_06_02_2022_sector_chg.dropna()
# Out:
#                         marketcap   1_day_%
# Sector
# Communication Services  3471221.1  2.673062
# Consumer Discretionary  4294806.3  3.078665
# Consumer Staples        2612460.9  1.351933
# Energy                  1724594.8 -0.306780
# Financials              4104405.0  1.377236
# Health Care             5075548.0  0.770236
# Industrials             2915400.4  1.906074
# Information Technology  9914500.4  2.409643
# Materials                977606.6  2.706836
# Real Estate              980604.8  1.463148
# Utilities               1027416.6  0.611868

# %%
SP500_06_02_mcap_chg_sector = pd.merge(SP500_06_02_mcap_chg,SP500_06_02_2022_sector_chg,how='inner',on=['Sector']).dropna()
len(SP500_06_02_mcap_chg_sector)
# Out:
# 491

# %%
SP500_06_02_mcap_chg_sector['Active'] = SP500_06_02_mcap_chg_sector['1_day_%_x'] - SP500_06_02_mcap_chg_sector['1_day_%_y']
SP500_06_02_mcap_chg_sector.head()
# Out:
#          date_x ticker               Company       Sector  marketcap_x  \
# 129  2022-06-02      A  Agilent Technologies  Health Care      38563.2
# 131  2022-06-02   ABBV                AbbVie  Health Care     259323.4
# 133  2022-06-02    ABC     AmerisourceBergen  Health Care      31044.7
# 135  2022-06-02   ABMD               Abiomed  Health Care      12285.4
# 137  2022-06-02    ABT   Abbott Laboratories  Health Care     205753.2
#
#            ev  evebit    pb    pe    ps    open    high     low   close  \
# 129   40282.2    26.7   7.5  30.5   5.9  122.96  129.19  122.30  129.10
# 131  326699.4    20.0  15.9  20.8   4.6  146.65  147.07  142.90  146.75
# 133   34540.3    13.0  56.4  18.0   0.1  149.92  150.32  145.61  148.21
# 135   12152.6    63.8   8.2  90.0  11.9  256.50  270.10  253.68  269.63
# 137  215168.2    22.5   5.8  26.6   4.6  115.29  117.61  113.23  117.51
#
#         volume  closeadj  closeunadj  1_day_%_x  marketcap_y  1_day_%_y  \
# ...

# %%
SP500_06_02_mcap_chg_sector.sort_values(by=['Active'],ascending=False).head()
# Out:
#          date_x ticker           Company                  Sector  marketcap_x  \
# 179  2022-06-02   DXCM            DexCom             Health Care      30598.6
# 453  2022-06-02   GNRC  Generac Holdings             Industrials      17167.1
# 139  2022-06-02   ALGN  Align Technology             Health Care      22449.3
# 983  2022-06-02   ENPH    Enphase Energy  Information Technology      26861.2
# 251  2022-06-02   XRAY   Dentsply Sirona             Health Care       9093.8
#
#           ev  evebit    pb     pe    ps    open    high     low   close  \
# 179  31962.7   117.3  14.0  144.5  11.9  285.00  312.97  281.01  311.83
# 453  18404.8    27.1   7.4   33.3   4.2  249.79  271.60  249.16  268.95
# 139  21628.2    23.1   6.1   31.8   5.6  266.76  287.05  264.54  284.87
# 983  27893.5   126.5  81.2  162.2  17.7  183.12  200.68  182.27  198.93
# 251  10994.8    17.9   1.8   21.6   2.1   39.70   41.91   39.51   41.80
#
# ...

# %%
#SP500_06_02_mcap_chg_sector['1_day_%_y'].value_counts()

# %%
SP500_06_02_2022_tableau = SP500_06_02_mcap_chg_sector[['date_x','ticker','Company','Sector',
                                                       'marketcap_x','1_day_%_x','1_day_%_y','Active']]
SP500_06_02_2022_tableau.to_excel('SP500_06_2022_tableau.xlsx',encoding='utf8')

# %%
SP500_mcap_wgts = SP500_06_02_2022_sector_chg.dropna()
SP500_mcap_wgts['% index'] = round(SP500_mcap_wgts['marketcap']/sum(SP500_mcap_wgts['marketcap'])*100,2)
SP500_mcap_wgts
# Out:
# <ipython-input-43-cfdfef04a213>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SP500_mcap_wgts['% index'] = round(SP500_mcap_wgts['marketcap']/sum(SP500_mcap_wgts['marketcap'])*100,2)
#                         marketcap   1_day_%  % index
# Sector
# Communication Services  3471221.1  2.673062     9.36
# Consumer Discretionary  4294806.3  3.078665    11.58
# Consumer Staples        2612460.9  1.351933     7.04
# Energy                  1724594.8 -0.306780     4.65
# Financials              4104405.0  1.377236    11.06
# Health Care             5075548.0  0.770236    13.68
# Industrials             2915400.4  1.906074     7.86
# Information Technology  9914500.4  2.409643    26.72
# Materials                977606.6  2.706836     2.64
# ...

# %%
SP500_06_02_mcap_chg_sector.columns = ['Date','Ticker','Company','Sector','MarketCap','EV',
                                      'EvEbit','PB','PE','PS','open','high','low','close','volume',
                                      'closeadj','closeunadj','1D','SectorMarketCap','1D_Sector',
                                      '1D_Active']
SP500_06_02_mcap_chg_sector
# Out:
#             Date Ticker                    Company                  Sector  \
# 129   2022-06-02      A       Agilent Technologies             Health Care
# 131   2022-06-02   ABBV                     AbbVie             Health Care
# 133   2022-06-02    ABC          AmerisourceBergen             Health Care
# 135   2022-06-02   ABMD                    Abiomed             Health Care
# 137   2022-06-02    ABT        Abbott Laboratories             Health Care
# 139   2022-06-02   ALGN           Align Technology             Health Care
# 141   2022-06-02   AMGN                      Amgen             Health Care
# 143   2022-06-02   ANTM                     Anthem             Health Care
# 145   2022-06-02    BAX       Baxter International             Health Care
# 147   2022-06-02    BDX           Becton Dickinson             Health Care
# ...          ...    ...                        ...                     ...
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@localhost/{db}'.format(user='root',
                                                                        pw='Boston1429$$',
                                                                        db='SP500'))
SP500_06_02_mcap_chg_sector.to_sql(f'SP500_daily_06_02_2022', con=engine, if_exists='append', index=False)
# Out:
# 491
