# %%
import pandas as pd

# %%
crm_excel = pd.read_excel('/Users/brendan/Desktop/Python/Quandl/CRM_GS.xlsx', sheet_name='Python')

# %%
crm_excel.head()
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 Unnamed: 5  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)   FY03 (A)         NaN
# 1               12937               14634      47656         NaN
# 2            0.911634            0.940126   0.934596         NaN
# 3            0.147406            0.131174          0         NaN
# 4                 NaN                 NaN   1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  ...  \
# ...

# %%
#crm = crm_excel.iloc[:6,:4]
crm_excel
crm.columns = ['Value', '2002-04-30', '2002-07-31', '2002-10-31']
crm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [81], in <cell line: 3>()
#       1 #crm = crm_excel.iloc[:6,:4]
#       2 crm = crm_excel
# ----> 3 crm.columns = ['Value', '2002-04-30', '2002-07-31', '2002-10-31']
#       4 crm
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
# ...

# %%
crm_excel.T
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
# 2002-07-31 00:00:00  2Q03 (A)                          11275         0.948834
# 2002-10-31 00:00:00  3Q03 (A)                          12937         0.911634
# 2003-01-31 00:00:00  4Q03 (A)                          14634         0.940126
# ...                       ...                            ...              ...
# 2032-04-30 00:00:00  1Q33 (E)                 23138116.06768          0.95537
# 2032-07-31 00:00:00  2Q33 (E)                24218615.094188         0.957371
# 2032-10-31 00:00:00  3Q33 (E)                25905161.391913          0.95484
# 2033-01-31 00:00:00  4Q33 (E)                27728553.375761         0.956514
# Unnamed: 185         FY33 (E)               100990445.929542         0.956027
#
# ...
