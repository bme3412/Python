# %%
import pandas as pd

# %%
crm_excel = pd.read_excel('/Users/brendan/Desktop/Python/Quandl/CRM_GS.xlsx', sheet_name='Python')
pd.set_option('display.max_columns', len(crm_excel.columns))
pd.set_option('display.max_rows',200)
pd.set_option('display.min_rows',20)

# %%
crm_excel.head()
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 Unnamed: 5  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)   FY03 (A)         NaN
# 1               12937               14634      47656         NaN
# 2            0.911634            0.940126   0.934596         NaN
# 3            0.147406            0.131174          0         NaN
# 4                 NaN                 NaN   1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  \
# 0            1Q04 (A)            2Q04 (A)            3Q04 (A)
# ...

# %%
#crm = crm_excel.iloc[:6,:4]
crm = crm_excel.T
crm_excel.iloc[0]
# Out:
# Unnamed: 0                  NaN
# 2002-04-30 00:00:00    1Q03 (A)
# 2002-07-31 00:00:00    2Q03 (A)
# 2002-10-31 00:00:00    3Q03 (A)
# 2003-01-31 00:00:00    4Q03 (A)
# Unnamed: 5             FY03 (A)
# Unnamed: 6                  NaN
# 2003-04-30 00:00:00    1Q04 (A)
# 2003-07-31 00:00:00    2Q04 (A)
# 2003-10-31 00:00:00    3Q04 (A)
# 2004-01-31 00:00:00    4Q04 (A)
# Unnamed: 11            FY04 (A)
# Unnamed: 12                 NaN
# 2004-04-30 00:00:00    1Q05 (A)
# 2004-07-31 00:00:00    2Q05 (A)
# 2004-10-31 00:00:00    3Q05 (A)
# 2005-01-31 00:00:00    4Q05 (A)
# Unnamed: 17            FY05 (A)
# Unnamed: 18                 NaN
# 2005-04-30 00:00:00    1Q06 (A)
# 2005-07-31 00:00:00    2Q06 (A)
# 2005-10-31 00:00:00    3Q06 (A)
# 2006-01-31 00:00:00    4Q06 (A)
# Unnamed: 23            FY06 (A)
# Unnamed: 24                 NaN
# 2006-04-30 00:00:00    1Q07 (A)
# 2006-07-31 00:00:00    2Q07 (A)
# 2006-10-31 00:00:00    3Q07 (A)
# 2007-01-31 00:00:00    4Q07 (A)
# ...

# %%
crm.head()
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
# 2002-07-31 00:00:00  2Q03 (A)                          11275         0.948834
# 2002-10-31 00:00:00  3Q03 (A)                          12937         0.911634
# 2003-01-31 00:00:00  4Q03 (A)                          14634         0.940126
#
#                                        3                          4    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
# 2002-07-31 00:00:00               0.279796                        NaN
# 2002-10-31 00:00:00               0.147406                        NaN
# 2003-01-31 00:00:00               0.131174                        NaN
#
#                                                5                6    \
# ...

# %%
crm_excel.T.head(2)
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
#
#                                        3                          4    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
#
#                                                5                6    \
# Unnamed: 0           Professional Services Revenue    % of revenues
# 2002-04-30 00:00:00                            541         0.942145
#
#                                        7                          8    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
#
#                                     9                       10   \
# ...

# %%
crm.head()
crm_ = crm.iloc[:,:129]
crm_
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
# 2002-07-31 00:00:00  2Q03 (A)                          11275         0.948834
# 2002-10-31 00:00:00  3Q03 (A)                          12937         0.911634
# 2003-01-31 00:00:00  4Q03 (A)                          14634         0.940126
# Unnamed: 5           FY03 (A)                          47656         0.934596
# Unnamed: 6                NaN                            NaN              NaN
# 2003-04-30 00:00:00  1Q04 (A)                          16922         0.894728
# 2003-07-31 00:00:00  2Q04 (A)                          19592         0.906072
# 2003-10-31 00:00:00  3Q04 (A)                          22480         0.883856
# 2004-01-31 00:00:00  4Q04 (A)                          26802         0.891824
# ...

# %%
crm_.columns = [
    'Quarter',
    'Subscription/ Support Revenue',
    'Subscription/ Support Revenue % of total revenue',
    'Subscription/ Support Revenue % q/q',
    'Subscription/ Support Revenue % y/y',
    'Professional Services Revenue',
    'Professional Services Revenue % of total revenue',
    'Professional Services Revenue % q/q',
    'Professional Services Revenue % y/y',
    'Revenue adjustment',
    
    'Total Revenue, Adjusted',
    'Total Revenue, % q/q',
    'Total Revenue, % y/y',
    'Total Revenue, (GAAP)',
    'Total Revenue, % q/q',
    'Total Revenue, % y/y',
    ' ',
    'Cost of Revenue',
    'Cost o System Engineering',
    'Cost of System Engineering, % of subscription/suport revenue',
    'Cost of System Engineering, % q/q',
    'Cost of System Engineering, %y/y',
    ' ',
    'Cost of support',
    'Cost of support, % of subscription/support revs',
    'Cost of support, % of subscription/support revs % q/q',
    'Cost of support, % of subscription/support revs % y/y',
    'Cost of subscription/support',
    'Cost of subscription/support, % q/q',
    'Cost of subscription/support, % y/y',
    
    'Subscription/Support GM',
    ' ',
    'Cost of Prof. Services',
    'Cost of Prof. Services % q/q',
    'Cost of Prof. Services % y/y',
    'Prof. Services GM',
    ' ',
    'Total Cost of Revenue',
    'Total Cost of Revenue % q/q',
    'Total Cost of Revenue % y/y',
    
    'Total Gross Profit',
    'Total Gross Profit, % q/q',
    'Total Gross Profit % y/y',
    'Overall Gross Margin %',
    ' ',
    'Operating Expenses',
    'Research & Development',
    'Research & Development % of Revenue',
    'Research & Development % q/q',
    'Research & Development % y/y',
    
    'Sales & Marketing',
    'Sales & Marketing % of Revenue',
    'Sales & Marketing % q/q',
    'Sales & Marketing % y/y',
    
    'G&A',
    'G&A % of Revenue',
    'G&A % q/q',
    'G&A % y/y',
    
    'Other Charges',
    'Other Charges % of Revenue',
    'Other Charges % q/q',
    'Other Charges % y/y',
    
    'Total Op Ex',
    'Total Op Ex % of Revenue',
    'Total Op Ex % q/q',
    'Total Op Ex % y/y',
    
    'Operating Income (Loss)',
    'Operating Income (Loss) % q/q',
    'Operating Income (Loss) % y/y',
    'Operating Margin %',
    'Expansion/Compression',
    
    'Interest income',
    'Interest expense',
    'Other income/expense',
    'Other Inc. (Expense), net',
    
    'Pre-tax Income',
    'Pre-tax Income % q/q',
    'Pre-tax Income % y/y',
    'Pre-tax Margin %',
    'Income Tax (Benefit)',
    'Tax Rate %',
    
    'Net Income before Minority Int',
    'Net Income before Minority Int % q/q',
    'Net Income before Minority Int % y/y',
    
    'Minority Interest',
    
    'Non-GAAP net income',
    'Option Expense',
    'Net Income (with Comp)',
    'Net Income (with Comp) % q/q',
    'Net Income (with Comp) % y/y',
    'Net Margin %',
    
    'Shares Outstanding',
    'Shares Outstanding - Diluted',
    
    'Proforma EPS (w ESO)',
    'Proforma EPS (w ESO) % q/q',
    'Proforma EPS (w ESO) % y/y',
    
    'Non-GAAP EPS',
    'Non-GAAP EPS % q/q',
    'Non-GAAP EPS % y/y',
    ' ',
    'GAAP Charges',
    'GAAP Net Income',
    'GAAP EPS',
    'GAAP EPS % q/q',
    'GAAP EPS % y/y',
    ' ',
    'Depreciation',
    'EBITA',
    'EBITDA',
    ' ',
    ' ',
    'Cash Flow',
    'Cash Flow % y/y',
    ' ',
    'Cash from Operations',
    'Cap Ex',
    'FCF',
    'FCF % y/y',
    ' ',
    'Cash Flow/sh',
    'Cash Flow/sh % y/y',
    ' ',
    'FCF/sh',
    'FCF/sh % y/y',
    ' ',
    'NOPAT',
    'NOPAT/sh',
    'NOPAT/sh % y/y',
    ' ',

]

# %%
crm.head()
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
# 2002-07-31 00:00:00  2Q03 (A)                          11275         0.948834
# 2002-10-31 00:00:00  3Q03 (A)                          12937         0.911634
# 2003-01-31 00:00:00  4Q03 (A)                          14634         0.940126
#
#                                        3                          4    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
# 2002-07-31 00:00:00               0.279796                        NaN
# 2002-10-31 00:00:00               0.147406                        NaN
# 2003-01-31 00:00:00               0.131174                        NaN
#
#                                                5                6    \
# ...

# %%
crm_.iloc[1:].head()
# Out:
#                       Quarter Subscription/ Support Revenue  \
# 2002-04-30 00:00:00  1Q03 (A)                          8810
# 2002-07-31 00:00:00  2Q03 (A)                         11275
# 2002-10-31 00:00:00  3Q03 (A)                         12937
# 2003-01-31 00:00:00  4Q03 (A)                         14634
# Unnamed: 5           FY03 (A)                         47656
#
#                     Subscription/ Support Revenue % of total revenue  \
# 2002-04-30 00:00:00                                         0.942145
# 2002-07-31 00:00:00                                         0.948834
# 2002-10-31 00:00:00                                         0.911634
# 2003-01-31 00:00:00                                         0.940126
# Unnamed: 5                                                  0.934596
#
#                     Subscription/ Support Revenue % q/q  \
# 2002-04-30 00:00:00                                 NaN
# 2002-07-31 00:00:00                            0.279796
# ...
