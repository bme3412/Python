# %%
import pandas as pd

# %%
crm_excel = pd.read_excel('/Users/brendan/Desktop/Python/Quandl/CRM_GS.xlsx', sheet_name='Python')
pd.set_option('display.max_columns', len(crm_excel.columns))
pd.set_option('display.max_rows',200)
pd.set_option('display.min_rows',20)

# %%
crm_excel.head()
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 2003-01-31 00:00:00.1  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)              FY03 (A)         NaN
# 1               12937               14634                 47656         NaN
# 2            0.911634            0.940126              0.934596         NaN
# 3            0.147406            0.131174                     0         NaN
# 4                 NaN                 NaN              1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  \
# ...

# %%
crm_excel.shape
# Out:
# (193, 186)

# %%
crm_ = crm_excel.copy()
crm.iloc[0][2] = 'Subscription/ Support Revenue, % of revenues'
crm.iloc[0][3] = 'Subscription/ Support Revenue, % q/q'
crm.iloc[0][4] = 'Subscription/ Support Revenue, % y/y'
crm.iloc[0][6] = 'Professional Services Revenue, % of revenues'
crm.iloc[0][7] = 'Professional Services Revenue, % q/q'
crm.iloc[0][8] = 'Professional Services Revenue, % y/y'

crm.iloc[0][11] = 'Adjusted Total Revenue, % q/q'
crm.iloc[0][12] = 'Adjusted Total Revenue, % y/y'

crm.iloc[0][14] = 'GAAP Total Revenue, % q/q'
crm.iloc[0][15] = 'GAAP Total Revenue, % y/y'

crm.iloc[0][19] = 'Cost of System Engineering, % of subscription/support revs'
crm.iloc[0][20] = 'Cost of System Engineering, % q/q'
crm.iloc[0][21] = 'Cost of System Engineering, % y/y'

crm.iloc[0][24] = 'Cost of Support, % of subscription/support revs'
crm.iloc[0][25] = 'Cost of Support, % q/q'
crm.iloc[0][26] = 'Cost of Support, % y/y'

crm.iloc[0][28] = 'Cost of Subscription/Support, % q/q'
crm.iloc[0][29] = 'Cost of Subscription/Support, % y/y'

crm.iloc[0][33] = 'Cost of Prof. Services, % q/q'
crm.iloc[0][34] = 'Cost of Prof. Services, % y/y'

crm.iloc[0][38] = 'Total Cost of Revenue, % q/q'
crm.iloc[0][39] = 'Total Cost of Revenue, % y/y'

crm.iloc[0][41] = 'Total Gross Profit, % q/q'
crm.iloc[0][42] = 'Total Gross Profit, % y/y'

crm.iloc[0][47] = 'Research & Development, % revenue'
crm.iloc[0][48] = 'Research & Development, % q/q'
crm.iloc[0][49] = 'Research & Development, % y/y'

crm.iloc[0][51] = 'Sales & Marketing, % revenue'
crm.iloc[0][52] = 'Sales & Marketing, % q/q'
crm.iloc[0][53] = 'Sales & Marketing, % y/y'

crm.iloc[0][55] = 'G&A, % revenue'
crm.iloc[0][56] = 'G&A, % q/q'
crm.iloc[0][57] = 'G&A, % y/y'

crm.iloc[0][59] = 'Other Charges, % revenue'
crm.iloc[0][60] = 'Other Charges, % q/q'
crm.iloc[0][61] = 'Other Charges, % y/y'

crm.iloc[0][63] = 'Total Op Ex, % revenue'
crm.iloc[0][64] = 'Total Op Ex, % q/q'
crm.iloc[0][65] = 'Total Op Ex, % y/y'

crm.iloc[0][67] = 'Total Op Ex, % q/q'
crm.iloc[0][68] = 'Total Op Ex, % y/y'

crm.iloc[0][76] = 'Pre-tax Income, % q/q'
crm.iloc[0][77] = 'Pre-tax Income, % y/y'

crm.iloc[0][82] = 'Net Income before Minority Int, % q/q'
crm.iloc[0][83] = 'Net Income before Minority Int, % y/y'

crm.iloc[0][88] = 'Net Income (with Comp), % q/q'
crm.iloc[0][89] = 'Net Income (with Comp), % y/y'

crm.iloc[0][94] = 'Proforma EPS (w ESO), % q/q'
crm.iloc[0][95] = 'Proforma EPS (w ESO), % y/y'

crm.iloc[0][97] = 'Non-GAAP EPS, % q/q'
crm.iloc[0][98] = 'Non-GAAP EPS, % y/y'

crm.iloc[0][103] = 'GAAP EPS, % q/q'
crm.iloc[0][104] = 'GAAP EPS, % y/y'

crm.iloc[0][112] = 'Cash Flow, % y/y'

crm.iloc[0][117] = 'Free Cash Flow, % y/y'

crm.iloc[0][120] = 'Cash Flow/sh, % y/y'

crm.iloc[0][123] = 'Free Cash Flow/sh, % y/y'

crm.iloc[0][126] = 'NOPAT/sh, % y/y'
# Out:
# <ipython-input-93-5cd4eb1973aa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crm.iloc[0][2] = 'Subscription/ Support Revenue, % of revenues'
# <ipython-input-93-5cd4eb1973aa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crm.iloc[0][3] = 'Subscription/ Support Revenue, % q/q'
# <ipython-input-93-5cd4eb1973aa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
crm_.head()
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 2003-01-31 00:00:00.1  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)              FY03 (A)         NaN
# 1               12937               14634                 47656         NaN
# 2            0.911634            0.940126              0.934596         NaN
# 3            0.147406            0.131174                     0         NaN
# 4                 NaN                 NaN              1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  \
# ...

# %%
crm_cond = crm_.iloc[:,:127]
crm_cond.head()
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 2003-01-31 00:00:00.1  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)              FY03 (A)         NaN
# 1               12937               14634                 47656         NaN
# 2            0.911634            0.940126              0.934596         NaN
# 3            0.147406            0.131174                     0         NaN
# 4                 NaN                 NaN              1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  \
# ...

# %%
crm_cond.columns = [
    'Quarter',
    'Subscription/ Support Revenue',
    'Subscription/ Support Revenue, % of revenues',
    'Subscription/ Support Revenue, % q/q',
    'Subscription/ Support Revenue, % y/y',
    'Professional Services Revenue',
    'Professional Services Revenue, % of revenues',
    'Professional Services Revenue, % q/q',
    'Professional Services Revenue, % y/y',
    'Revenue adjustment',
    'Adjusted Total Revenue',
    'Adjusted Total Revenue, % q/q',
    'Adjusted Total Revenue, % y/y',
    'GAAP Total Revenue',
    'GAAP Total Revenue, % q/q',
    'GAAP Total Revenue, % y/y',
    '',
    'Cost of Revenue',
    'Cost of System Engineering',
    'Cost of System Engineering, % of subscription/support revs',
    'System Engineering, % q/q',
    'Cost of System Engineering, % y/y',
    '',
    'Cost of Support',
    'Cost of Support, % of subscription/support revs',
    'Cost of Support, % q/q',
    'Cost of Support, % y/y',
    'Cost of Subscription/Support',
    'Cost of Subscription/Support, % q/q',
    'Cost of Subscription/Support, % y/y',
    'Subscription/Support GM %',
    '',
    'Cost of Prof. Services',
    'Cost of Prof. Services, % q/q',
    'Cost of Prof. Services, % y/y',
    'Prof. Services GM %',
    '',
    'Total Cost of Revenue',
    'Total Cost of Revenue, % q/q',
    'Total Cost of Revenue, % y/y',
    'Total Gross Profit',
    'Total Gross Profit, % q/q',
    'Total Gross Profit, % y/y',
    'Overall Gross Margin %',
    '',
    'Operating Expenses',
    'Research & Development',
    'Research & Development, % revenue',
    'Research & Development, % q/q',
    'Research & Development, % y/y',
    'Sales & Marketing',
    'Sales & Marketing, % revenue',
    'Sales & Marketing, % q/q',
    'Sales & Marketing, % y/y',
    'G&A',
    'G&A, % revenue',
    'G&A, % q/q',
    'G&A, % y/y',
    'Other Charges',
    'Other Charges, % revenue',
    'Other Charges, % q/q',
    'Other Charges, % y/y',
    'Total Operating Exp.',
    'Total Op Ex, % revenue',
    'Total Op Ex, % q/q',
    'Total Op Ex, % y/y',
    'Operating Income (Loss)',
    'Ttoal Operating Income % q/q',
    'Total Operating Income % y/y',
    'Operating Margin %',
    'Expansion/compression',
    'Interest income',
    'Interest expense',
    'Other income/expense',
    'Other Inc. (Expense), net',
    'Pre-tax Income',
    'Pre-tax Income, % q/q',
    'Pre-tax Income, % y/y',
    'Pre-tax Margin %',
    'Income Tax (Benefit)',
    'Tax Rate %',
    'Net Income before Minority Int',
    'Net Income before Minority Int, % q/q',
    'Net Income before Minority Int, % y/y',
    'Minority Interest',
    'Non-GAAP net income',
    'Option Expense',
    'Net Income (with Comp)',
    'Net Income (with Comp), % q/q',
    'Net Income (with Comp), % y/y',
    'Net Margin %',
    'Shares Outstanding',
    'Shares Outstanding - diluted',
    'Proforma EPS (w ESO)',
    'Proforma EPS (w ESO) % q/q',
    'Proforma EPS (w ESO) % y/y',
    'Non-GAAP EPS',
    'Non-GAAP EPS % q/q',
    'Non-GAAP EPS % y/y',
    '',
    'GAAP Charges',
    'GAAP Net Income',
    'GAAP EPS',
    'GAAP EPS, % q/q',
    'GAAP EPS, % y/y',
    '',
    'Depreciation',
    'EBITA',
    'EBITDA',
    '',
    '',
    'Cash Flow',
    'Cash Flow, % y/y',
    '',
    'Cash From Operations',
    'Cap Ex',
    'Free Cash Flow',
    'Free Cash Flow, % y/y',
    '',
    'Cash Flow/Share',
    'Cash Flow/sh, % y/y',
    '',
    'Free Cash Flow/Share',
    'Free Cash Flow/sh, % y/y',
    '',
    'NOPAT',
    'NOPAT/sh, % y/y'
    
]

# %%
crm_cond.head()
# Out:
#                          Quarter Subscription/ Support Revenue  \
# 0                            NaN                      1Q03 (A)
# 1  Subscription/ Support Revenue                          8810
# 2                  % of revenues                      0.942145
# 3            sequential growth %                           NaN
# 4        year over year growth %                           NaN
#
#   Subscription/ Support Revenue, % of revenues  \
# 0                                     2Q03 (A)
# 1                                        11275
# 2                                     0.948834
# 3                                     0.279796
# 4                                          NaN
#
#   Subscription/ Support Revenue, % q/q Subscription/ Support Revenue, % y/y  \
# 0                             3Q03 (A)                             4Q03 (A)
# 1                                12937                                14634
# ...

# %%
crm_cond.T
# Out:
#                             0                              1    \
# Unnamed: 0                  NaN  Subscription/ Support Revenue
# 2002-04-30 00:00:00    1Q03 (A)                           8810
# 2002-07-31 00:00:00    2Q03 (A)                          11275
# 2002-10-31 00:00:00    3Q03 (A)                          12937
# 2003-01-31 00:00:00    4Q03 (A)                          14634
# 2003-01-31 00:00:00.1  FY03 (A)                          47656
# Unnamed: 6                  NaN                            NaN
# 2003-04-30 00:00:00    1Q04 (A)                          16922
# 2003-07-31 00:00:00    2Q04 (A)                          19592
# 2003-10-31 00:00:00    3Q04 (A)                          22480
# 2004-01-31 00:00:00    4Q04 (A)                          26802
# 2004-01-31 00:00:00.1  FY04 (A)                          85796
# Unnamed: 12                 NaN                            NaN
# 2004-04-30 00:00:00    1Q05 (A)                          31116
# ...

# %%
crm_excel.T.head(2)
# Out:
#                           0                              1                2    \
# Unnamed: 0                NaN  Subscription/ Support Revenue    % of revenues
# 2002-04-30 00:00:00  1Q03 (A)                           8810         0.942145
#
#                                        3                          4    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
#
#                                                5                6    \
# Unnamed: 0           Professional Services Revenue    % of revenues
# 2002-04-30 00:00:00                            541         0.942145
#
#                                        7                          8    \
# Unnamed: 0             sequential growth %    year over year growth %
# 2002-04-30 00:00:00                    NaN                        NaN
#
#                                     9                       10   \
# ...

# %%
crm.head()
crm_ = crm.iloc[:,:129]

# %%
crm_.columns = [
    'Quarter',
    'Subscription/ Support Revenue',
    'Subscription/ Support Revenue % of total revenue',
    'Subscription/ Support Revenue % q/q',
    'Subscription/ Support Revenue % y/y',
    'Professional Services Revenue',
    'Professional Services Revenue % of total revenue',
    'Professional Services Revenue % q/q',
    'Professional Services Revenue % y/y',
    'Revenue adjustment',
    
    'Total Revenue, Adjusted',
    'Total Revenue, % q/q',
    'Total Revenue, % y/y',
    'Total Revenue, (GAAP)',
    'Total Revenue, % q/q',
    'Total Revenue, % y/y',
    ' ',
    'Cost of Revenue',
    'Cost o System Engineering',
    'Cost of System Engineering, % of subscription/suport revenue',
    'Cost of System Engineering, % q/q',
    'Cost of System Engineering, % y/y',
    ' ',
    'Cost of support',
    'Cost of support, % of subscription/support revs',
    'Cost of support, % q/q',
    'Cost of support, % y/y',
    'Cost of subscription/support',
    'Cost of subscription/support, % q/q',
    'Cost of subscription/support, % y/y',
    
    'Subscription/Support GM',
    ' ',
    'Cost of Prof. Services',
    'Cost of Prof. Services % q/q',
    'Cost of Prof. Services % y/y',
    'Prof. Services GM',
    ' ',
    'Total Cost of Revenue',
    'Total Cost of Revenue % q/q',
    'Total Cost of Revenue % y/y',
    
    'Total Gross Profit',
    'Total Gross Profit, % q/q',
    'Total Gross Profit % y/y',
    'Overall Gross Margin %',
    ' ',
    'Operating Expenses',
    'Research & Development',
    'Research & Development % of Revenue',
    'Research & Development % q/q',
    'Research & Development % y/y',
    
    'Sales & Marketing',
    'Sales & Marketing % of Revenue',
    'Sales & Marketing % q/q',
    'Sales & Marketing % y/y',
    
    'G&A',
    'G&A % of Revenue',
    'G&A % q/q',
    'G&A % y/y',
    
    'Other Charges',
    'Other Charges % of Revenue',
    'Other Charges % q/q',
    'Other Charges % y/y',
    
    'Total Op Ex',
    'Total Op Ex % of Revenue',
    'Total Op Ex % q/q',
    'Total Op Ex % y/y',
    
    'Operating Income (Loss)',
    'Operating Income (Loss) % q/q',
    'Operating Income (Loss) % y/y',
    'Operating Margin %',
    'Expansion/Compression',
    
    'Interest income',
    'Interest expense',
    'Other income/expense',
    'Other Inc. (Expense), net',
    
    'Pre-tax Income',
    'Pre-tax Income % q/q',
    'Pre-tax Income % y/y',
    'Pre-tax Margin %',
    'Income Tax (Benefit)',
    'Tax Rate %',
    
    'Net Income before Minority Int',
    'Net Income before Minority Int % q/q',
    'Net Income before Minority Int % y/y',
    
    'Minority Interest',
    
    'Non-GAAP net income',
    'Option Expense',
    'Net Income (with Comp)',
    'Net Income (with Comp) % q/q',
    'Net Income (with Comp) % y/y',
    'Net Margin %',
    
    'Shares Outstanding',
    'Shares Outstanding - Diluted',
    
    'Proforma EPS (w ESO)',
    'Proforma EPS (w ESO) % q/q',
    'Proforma EPS (w ESO) % y/y',
    
    'Non-GAAP EPS',
    'Non-GAAP EPS % q/q',
    'Non-GAAP EPS % y/y',
    ' ',
    'GAAP Charges',
    'GAAP Net Income',
    'GAAP EPS',
    'GAAP EPS % q/q',
    'GAAP EPS % y/y',
    ' ',
    'Depreciation',
    'EBITA',
    'EBITDA',
    ' ',
    ' ',
    'Cash Flow',
    'Cash Flow % y/y',
    ' ',
    'Cash from Operations',
    'Cap Ex',
    'FCF',
    'FCF % y/y',
    ' ',
    'Cash Flow/sh',
    'Cash Flow/sh % y/y',
    ' ',
    'FCF/sh',
    'FCF/sh % y/y',
    ' ',
    'NOPAT',
    'NOPAT/sh',
    'NOPAT/sh % y/y',
    ' ',

]

# %%
crm.head(5)
# Out:
#                       Unnamed: 0 2002-04-30 00:00:00 2002-07-31 00:00:00  \
# 0                            NaN            1Q03 (A)            2Q03 (A)
# 1  Subscription/ Support Revenue                8810               11275
# 2                  % of revenues            0.942145            0.948834
# 3            sequential growth %                 NaN            0.279796
# 4        year over year growth %                 NaN                 NaN
#
#   2002-10-31 00:00:00 2003-01-31 00:00:00 2003-01-31 00:00:00.1  Unnamed: 6  \
# 0            3Q03 (A)            4Q03 (A)              FY03 (A)         NaN
# 1               12937               14634                 47656         NaN
# 2            0.911634            0.940126              0.934596         NaN
# 3            0.147406            0.131174                     0         NaN
# 4                 NaN                 NaN              1.215219         NaN
#
#   2003-04-30 00:00:00 2003-07-31 00:00:00 2003-10-31 00:00:00  \
# ...

# %%
import datetime as dt

# %%
crm_
# Out:
#                                   Quarter Subscription/ Support Revenue  \
# 0                                     NaN                      1Q03 (A)
# 1           Subscription/ Support Revenue                          8810
# 2                           % of revenues                      0.942145
# 3                     sequential growth %                           NaN
# 4                 year over year growth %                           NaN
# 5           Professional Services Revenue                           541
# 6                           % of revenues                      0.942145
# 7                     sequential growth %                           NaN
# 8                 year over year growth %                           NaN
# 9                      Revenue adjustment                             0
# 10                 Adjusted Total Revenue                          9351
# 11                    sequential growth %                           NaN
# ...

# %%
crm_ = crm_.dropna(how='all')
crm_.index = pd.to_datetime(crm_.index, format='%m-%d-%Y')
crm_.index = pd.to_datetime(crm_.index,format = '%Y-%m-%d').strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 crm_ = crm_.dropna(how='all')
# ----> 2 crm_.index = pd.to_datetime(crm_.index, format='%m-%d-%Y')
# ...

# %%
crm_.head()

# %%
crm_qrtly = crm_[crm_['Quarter'].str.contains('FY')==False]

# %%
crm_qrtly.head()

# %%
crm_qrtly.to_excel('CRM_qrt_df.xlsx')

# %%
crm_year = crm_[crm_['Quarter'].str.contains('FY')==True]
crm_year.head()

# %%
crm_year['Subscription/ Support Revenue % of total revenue'] = crm_year['Subscription/ Support Revenue % of total revenue'] *100
crm_year['Subscription/ Support Revenue % q/q'] = crm_year['Subscription/ Support Revenue % q/q'] *100
crm_year['Subscription/ Support Revenue % y/y'] = crm_year['Subscription/ Support Revenue % y/y'] * 100

crm_year['Professional Services Revenue % of total revenue'] = crm_year['Professional Services Revenue % of total revenue'] * 100
crm_year['Professional Services Revenue % q/q'] = crm_year['Professional Services Revenue % q/q'] * 100
crm_year['Professional Services Revenue % y/y'] = crm_year['Professional Services Revenue % y/y'] * 100

crm_year['Total Revenue, % q/q'] = crm_year['Total Revenue, % q/q'] * 100
crm_year['Total Revenue, % y/y'] = crm_year['Total Revenue, % y/y'] * 100

crm_year['Cost of System Engineering, % of subscription/suport revenue'] = crm_year['Cost of System Engineering, % of subscription/suport revenue'] * 100
crm_year['Cost of System Engineering, % q/q'] = crm_year['Cost of System Engineering, % q/q'] * 100
crm_year['Cost of System Engineering, % y/y'] = crm_year['Cost of System Engineering, % y/y'] * 100

crm_year['Cost of support, % of subscription/support revs'] = crm_year['Cost of support, % of subscription/support revs']*100
crm_year['Cost of support, % q/q'] = crm_year['Cost of support, % q/q']*100
crm_year['Cost of support, % y/y'] = crm_year['Cost of support, % y/y']*100

crm_year['Subscription/Support GM'] = crm_year['Subscription/Support GM'] * 100

crm_year['Cost of Prof. Services % q/q'] = crm_year['Cost of Prof. Services % q/q'] * 100
crm_year['Cost of Prof. Services % y/y'] = crm_year['Cost of Prof. Services % y/y'] * 100

crm_year['Prof. Services GM'] = crm_year['Prof. Services GM'] * 100

crm_year['Total Cost of Revenue % q/q'] = crm_year['Total Cost of Revenue % q/q'] * 100
crm_year['Total Cost of Revenue % y/y'] = crm_year['Total Cost of Revenue % y/y'] * 100

crm_year['Total Gross Profit, % q/q'] = crm_year['Total Gross Profit, % q/q'] * 100
crm_year['Total Gross Profit % y/y'] = crm_year['Total Gross Profit % y/y'] * 100
crm_year['Overall Gross Margin %'] = crm_year['Overall Gross Margin %'] * 100

crm_year['Research & Development % of Revenue'] = crm_year['Research & Development % of Revenue'] * 100
crm_year['Research & Development % q/q'] = crm_year['Research & Development % q/q'] * 100
crm_year['Research & Development % y/y'] = crm_year['Research & Development % y/y'] * 100

crm_year['Sales & Marketing % of Revenue'] = crm_year['Sales & Marketing % of Revenue'] * 100
crm_year['Sales & Marketing % q/q'] = crm_year['Sales & Marketing % q/q']*100
crm_year['Sales & Marketing % y/y'] = crm_year['Sales & Marketing % y/y']*100

crm_year['G&A % of Revenue'] = crm_year['G&A % of Revenue'] * 100
crm_year['G&A % q/q'] = crm_year['G&A % q/q'] * 100
crm_year['G&A % y/y'] = crm_year['G&A % y/y'] * 100

crm_year['Total Op Ex % of Revenue'] = crm_year['Total Op Ex % of Revenue'] * 100
crm_year['Total Op Ex % q/q'] = crm_year['Total Op Ex % q/q'] * 100
crm_year['Total Op Ex % y/y'] = crm_year['Total Op Ex % y/y'] * 100

crm_year['Operating Income (Loss) % q/q'] = crm_year['Operating Income (Loss) % q/q'] * 100
crm_year['Operating Income (Loss) % y/y'] = crm_year['Operating Income (Loss) % y/y'] * 100
crm_year['Operating Margin %'] = crm_year['Operating Margin %'] * 100

crm_year['Pre-tax Income % q/q'] = crm_year['Pre-tax Income % q/q'] * 100
crm_year['Pre-tax Income % y/y'] = crm_year['Pre-tax Income % y/y'] * 100
crm_year['Pre-tax Margin %'] = crm_year['Pre-tax Margin %'] * 100

crm_year['Tax Rate %'] = crm_year['Tax Rate %'] * 100

crm_year['Net Income (with Comp) % q/q'] = crm_year['Net Income (with Comp) % q/q']*100
crm_year['Net Income (with Comp) % y/y'] = crm_year['Net Income (with Comp) % y/y']*100
crm_year['Net Margin %'] = crm_year['Net Margin %'] * 100

crm_year['Non-GAAP EPS % q/q'] = crm_year['Non-GAAP EPS % q/q'] * 100
crm_year['Non-GAAP EPS % y/y'] = crm_year['Non-GAAP EPS % y/y'] * 100
crm_year['GAAP EPS % q/q'] = crm_year['GAAP EPS % q/q']*100
crm_year['GAAP EPS % y/y'] = crm_year['GAAP EPS % y/y']*100

crm_year['Cash Flow % y/y'] = crm_year['Cash Flow % y/y'] * 100
crm_year['Cash Flow/sh % y/y'] = crm_year['Cash Flow/sh % y/y'] * 100

crm_year['FCF % y/y'] = crm_year['FCF % y/y'] * 100
crm_year['FCF/sh % y/y'] = crm_year['FCF/sh % y/y']*100

crm_year['NOPAT/sh % y/y'] = crm_year['NOPAT/sh % y/y']*100

# %%
crm_year.head(10)
