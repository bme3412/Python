# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.min_rows', 20)

# %%
avgo_raw = pd.read_excel('AVGO.xlsx', sheet_name='Python')
avgo_raw.head()
# Out:
#       Unnamed: 0 2008-04-30 00:00:00 2008-07-31 00:00:00 2008-10-31 00:00:00  \
# 0            NaN                1Q08                2Q08                3Q08
# 1        Revenue                 411                 439                 447
# 2  Revenue % q/q                   0            0.068127            0.018223
# 3  Revenue % y/y                   0                   0                   0
# 4           COGS                 237                 251                 263
#
#   2009-01-31 00:00:00 2009-04-30 00:00:00 2009-07-31 00:00:00  \
# 0                4Q08                1Q09                2Q09
# 1                 368                 325                 363
# 2           -0.176734           -0.116848            0.116923
# 3                   0           -0.209246           -0.173121
# 4                 204                 210                 205
#
#   2009-10-31 00:00:00 2010-01-31 00:00:00 2010-04-30 00:00:00  \
# 0                3Q09                4Q09                1Q10
# ...

# %%
avgo_raw = avgo_raw.rename(columns={'Unnamed: 0':'Metric'})
avgo_raw.columns = avgo_raw.iloc[0]
avgo_raw.head()
# Out:
# 0            NaN  1Q08      2Q08      3Q08      4Q08      1Q09      2Q09  \
# 0            NaN  1Q08      2Q08      3Q08      4Q08      1Q09      2Q09
# 1        Revenue   411       439       447       368       325       363
# 2  Revenue % q/q     0  0.068127  0.018223 -0.176734 -0.116848  0.116923
# 3  Revenue % y/y     0         0         0         0 -0.209246 -0.173121
# 4           COGS   237       251       263       204       210       205
#
# 0      3Q09      4Q09      1Q10      2Q10      3Q10      4Q10      1Q11  \
# 0      3Q09      4Q09      1Q10      2Q10      3Q10      4Q10      1Q11
# 1       428       456       515       550       572       550       560
# 2  0.179063  0.065421  0.129386  0.067961      0.04 -0.038462  0.018182
# 3 -0.042506   0.23913  0.584615  0.515152  0.336449   0.20614  0.087379
# 4       236       247       268       271       282       265       271
#
# 0      2Q11      3Q11      4Q11      1Q12      2Q12      3Q12      4Q12  \
# ...
