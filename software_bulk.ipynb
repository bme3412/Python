# %%
import pandas as pd
import requests
api = 'c4ad87b03bec1878bc0be6156d4472b0'
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 100)

# %%
# Request financial data from API
company = 'AAPL'


income_statement_q = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{company}?period=quarter&limit=400&apikey={api}').json()
balance_sheet = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company}?period=quarter&limit=400&apikey={api}').json()
cash_flow = requests.get(f'https://financialmodelingprep.com/api/v3/cash-flow-statement/{company}?period=quarter&limit=400&apikey={api}').json()
Ratios = requests.get(f'https://financialmodelingprep.com/api/v3/ratios/{company}?period=quarter&limit=400&apikey={api}').json()
key_Metrics = requests.get(f'https://financialmodelingprep.com/api/v3/key-metrics/{company}?period=quarter&limit=400&apikey={api}').json()
profile = requests.get(f'https://financialmodelingprep.com/api/v3/profile/{company}?period=quarter&limit=400&apikey={api}').json()
#shares_float = requests.get(f'https://financialmodelingprep.com/api/v4/shares_float?symbol={company}?period=quarter&apikey={api}').json()

# %%
income_statement_q
# Out:
# [{'date': '2022-06-25',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-07-29',
#   'acceptedDate': '2022-07-28 18:06:56',
#   'calendarYear': '2022',
#   'period': 'Q3',
#   'revenue': 82959000000,
#   'costOfRevenue': 47074000000,
#   'grossProfit': 35885000000,
#   'grossProfitRatio': 0.4325630733253776,
#   'researchAndDevelopmentExpenses': 6797000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 6012000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 12809000000,
#   'costAndExpenses': 59883000000,
#   'interestIncome': 722000000,
#   'interestExpense': 719000000,
#   'depreciationAndAmortization': 2805000000,
#   'ebitda': 26590000000,
#   'ebitdaratio': 0.3205197748285298,
#   'operatingIncome': 23076000000,
#   'operatingIncomeRatio': 0.2781615014645789,
#   'totalOtherIncomeExpensesNet': -10000000,
#   'incomeBeforeTax': 23066000000,
#   'incomeBeforeTaxRatio': 0.27804095999228534,
#   'incomeTaxExpense': 3624000000,
#   'netIncome': 19442000000,
#   'netIncomeRatio': 0.2343567304331055,
#   'eps': 1.2,
#   'epsdiluted': 1.2,
#   'weightedAverageShsOut': 16162945000,
#   'weightedAverageShsOutDil': 16262203000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/0000320193-22-000070-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625.htm'},
#  {'date': '2022-03-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-04-29',
#   'acceptedDate': '2022-04-28 18:03:58',
#   'calendarYear': '2022',
#   'period': 'Q2',
#   'revenue': 97278000000,
#   'costOfRevenue': 54719000000,
#   'grossProfit': 42559000000,
#   'grossProfitRatio': 0.437498715022924,
#   'researchAndDevelopmentExpenses': 6387000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 6193000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 12580000000,
#   'costAndExpenses': 67299000000,
#   'interestIncome': 0.0,
#   'interestExpense': 691000000,
#   'depreciationAndAmortization': 2737000000,
#   'ebitda': 33567000000,
#   'ebitdaratio': 0.34506260408314315,
#   'operatingIncome': 29979000000,
#   'operatingIncomeRatio': 0.30817862209338187,
#   'totalOtherIncomeExpensesNet': 160000000,
#   'incomeBeforeTax': 30139000000,
#   'incomeBeforeTaxRatio': 0.30982339275067333,
#   'incomeTaxExpense': 5129000000,
#   'netIncome': 25010000000,
#   'netIncomeRatio': 0.25709821336787353,
#   'eps': 1.53,
#   'epsdiluted': 1.51,
#   'weightedAverageShsOut': 16391724000,
#   'weightedAverageShsOutDil': 16519291000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/0000320193-22-000059-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326.htm'},
#  {'date': '2021-12-25',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-01-28',
#   'acceptedDate': '2022-01-27 18:00:58',
#   'calendarYear': '2022',
#   'period': 'Q1',
#   'revenue': 123945000000,
#   'costOfRevenue': 69702000000,
#   'grossProfit': 54243000000,
#   'grossProfitRatio': 0.43763766186615033,
#   'researchAndDevelopmentExpenses': 6306000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 6449000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 12755000000,
#   'costAndExpenses': 82457000000,
#   'interestIncome': 650000000,
#   'interestExpense': 694000000,
#   'depreciationAndAmortization': 2697000000,
#   'ebitda': 44632000000,
#   'ebitdaratio': 0.3600952035176893,
#   'operatingIncome': 41488000000,
#   'operatingIncomeRatio': 0.3347291137197951,
#   'totalOtherIncomeExpensesNet': -247000000,
#   'incomeBeforeTax': 41241000000,
#   'incomeBeforeTaxRatio': 0.33273629432409535,
#   'incomeTaxExpense': 6611000000,
#   'netIncome': 34630000000,
#   'netIncomeRatio': 0.2793981201339304,
#   'eps': 2.11,
#   'epsdiluted': 2.1,
#   'weightedAverageShsOut': 16391724000,
#   'weightedAverageShsOutDil': 16519291000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/0000320193-22-000007-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225.htm'},
#  {'date': '2021-09-25',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2021-10-29',
#   'acceptedDate': '2021-10-28 18:04:28',
#   'calendarYear': '2021',
#   'period': 'Q4',
#   'revenue': 83360000000,
#   'costOfRevenue': 48186000000,
#   'grossProfit': 35174000000,
#   'grossProfitRatio': 0.4219529750479846,
#   'researchAndDevelopmentExpenses': 5772000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 5616000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 11388000000,
#   'costAndExpenses': 59574000000,
#   'interestIncome': 659000000,
#   'interestExpense': 672000000,
#   'depreciationAndAmortization': 2989000000,
#   'ebitda': 26909000000,
#   'ebitdaratio': 0.32280470249520155,
#   'operatingIncome': 23786000000,
#   'operatingIncomeRatio': 0.28534069097888676,
#   'totalOtherIncomeExpensesNet': -538000000,
#   'incomeBeforeTax': 23248000000,
#   'incomeBeforeTaxRatio': 0.27888675623800385,
#   'incomeTaxExpense': 2697000000,
#   'netIncome': 20551000000,
#   'netIncomeRatio': 0.2465331094049904,
#   'eps': 1.25,
#   'epsdiluted': 1.24,
#   'weightedAverageShsOut': 16487121000,
#   'weightedAverageShsOutDil': 16635097000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925.htm'},
#  {'date': '2021-06-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2021-07-28',
#   'acceptedDate': '2021-07-27 18:03:42',
#   'calendarYear': '2021',
#   'period': 'Q3',
#   'revenue': 81434000000,
#   'costOfRevenue': 46179000000,
#   'grossProfit': 35255000000,
#   'grossProfitRatio': 0.4329272785323084,
#   'researchAndDevelopmentExpenses': 5717000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 5412000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 11129000000,
#   'costAndExpenses': 57308000000,
#   'interestIncome': 719000000,
#   'interestExpense': 665000000,
#   'depreciationAndAmortization': 2832000000,
#   'ebitda': 27866000000,
#   'ebitdaratio': 0.34219122233956334,
#   'operatingIncome': 24126000000,
#   'operatingIncomeRatio': 0.296264459562345,
#   'totalOtherIncomeExpensesNet': 243000000,
#   'incomeBeforeTax': 24369000000,
#   'incomeBeforeTaxRatio': 0.2992484711545546,
#   'incomeTaxExpense': 2625000000,
#   'netIncome': 21744000000,
#   'netIncomeRatio': 0.2670137780288332,
#   'eps': 1.31,
#   'epsdiluted': 1.3,
#   'weightedAverageShsOut': 16629371000,
#   'weightedAverageShsOutDil': 16781735000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000065/0000320193-21-000065-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000065/aapl-20210626.htm'},
#  {'date': '2021-03-27',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2021-04-29',
#   'acceptedDate': '2021-04-28 18:02:54',
#   'calendarYear': '2021',
#   'period': 'Q2',
#   'revenue': 89584000000,
#   'costOfRevenue': 51505000000,
#   'grossProfit': 38079000000,
#   'grossProfitRatio': 0.4250647437042329,
#   'researchAndDevelopmentExpenses': 5262000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 5314000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 10576000000,
#   'costAndExpenses': 62081000000,
#   'interestIncome': 718000000,
#   'interestExpense': 670000000,
#   'depreciationAndAmortization': 2797000000,
#   'ebitda': 31478000000,
#   'ebitdaratio': 0.3513797106626183,
#   'operatingIncome': 27503000000,
#   'operatingIncomeRatio': 0.30700794784783,
#   'totalOtherIncomeExpensesNet': 508000000,
#   'incomeBeforeTax': 28011000000,
#   'incomeBeforeTaxRatio': 0.3126786033220218,
#   'incomeTaxExpense': 4381000000,
#   'netIncome': 23630000000,
#   'netIncomeRatio': 0.2637747812109305,
#   'eps': 1.41,
#   'epsdiluted': 1.4,
#   'weightedAverageShsOut': 16753476000,
#   'weightedAverageShsOutDil': 16929157000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000056/0000320193-21-000056-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000056/aapl-20210327.htm'},
#  {'date': '2020-12-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2021-01-28',
#   'acceptedDate': '2021-01-27 18:03:06',
#   'calendarYear': '2021',
#   'period': 'Q1',
#   'revenue': 111439000000,
#   'costOfRevenue': 67111000000,
#   'grossProfit': 44328000000,
#   'grossProfitRatio': 0.39777815665969724,
#   'researchAndDevelopmentExpenses': 5163000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 5631000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 10794000000,
#   'costAndExpenses': 77905000000,
#   'interestIncome': 747000000,
#   'interestExpense': 638000000,
#   'depreciationAndAmortization': 2666000000,
#   'ebitda': 36883000000,
#   'ebitdaratio': 0.3309703066251492,
#   'operatingIncome': 33534000000,
#   'operatingIncomeRatio': 0.30091799100853384,
#   'totalOtherIncomeExpensesNet': 45000000,
#   'incomeBeforeTax': 33579000000,
#   'incomeBeforeTaxRatio': 0.30132179937005893,
#   'incomeTaxExpense': 4824000000,
#   'netIncome': 28755000000,
#   'netIncomeRatio': 0.25803354301456405,
#   'eps': 1.7,
#   'epsdiluted': 1.68,
#   'weightedAverageShsOut': 16935119000,
#   'weightedAverageShsOutDil': 17113688000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/0000320193-21-000010-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/aapl-20201226.htm'},
#  {'date': '2020-09-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2020-10-30',
#   'acceptedDate': '2020-10-29 18:06:25',
#   'calendarYear': '2020',
#   'period': 'Q4',
#   'revenue': 64698000000,
#   'costOfRevenue': 40009000000,
#   'grossProfit': 24689000000,
#   'grossProfitRatio': 0.3816037590033695,
#   'researchAndDevelopmentExpenses': 4978000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4936000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 9914000000,
#   'costAndExpenses': 49923000000,
#   'interestIncome': 768000000,
#   'interestExpense': 634000000,
#   'depreciationAndAmortization': 2702000000,
#   'ebitda': 18237000000,
#   'ebitdaratio': 0.2818788834276175,
#   'operatingIncome': 14775000000,
#   'operatingIncomeRatio': 0.2283687285542057,
#   'totalOtherIncomeExpensesNet': 126000000,
#   'incomeBeforeTax': 14901000000,
#   'incomeBeforeTaxRatio': 0.23031623852360197,
#   'incomeTaxExpense': 2228000000,
#   'netIncome': 12673000000,
#   'netIncomeRatio': 0.19587931620761073,
#   'eps': 0.74,
#   'epsdiluted': 0.73,
#   'weightedAverageShsOut': 17057622000,
#   'weightedAverageShsOutDil': 17256521000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm'},
#  {'date': '2020-06-27',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2020-07-31',
#   'acceptedDate': '2020-07-30 19:29:09',
#   'calendarYear': '2020',
#   'period': 'Q3',
#   'revenue': 59685000000,
#   'costOfRevenue': 37005000000,
#   'grossProfit': 22680000000,
#   'grossProfitRatio': 0.3799949736114602,
#   'researchAndDevelopmentExpenses': 4758000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4831000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 9589000000,
#   'costAndExpenses': 46594000000,
#   'interestIncome': 901000000,
#   'interestExpense': 697000000,
#   'depreciationAndAmortization': 2752000000,
#   'ebitda': 16586000000,
#   'ebitdaratio': 0.27789226773896286,
#   'operatingIncome': 13091000000,
#   'operatingIncomeRatio': 0.21933484124989527,
#   'totalOtherIncomeExpensesNet': 46000000,
#   'incomeBeforeTax': 13137000000,
#   'incomeBeforeTaxRatio': 0.22010555415933653,
#   'incomeTaxExpense': 1884000000,
#   'netIncome': 11253000000,
#   'netIncomeRatio': 0.18853983412917819,
#   'eps': 0.6525,
#   'epsdiluted': 0.645,
#   'weightedAverageShsOut': 17250292000,
#   'weightedAverageShsOutDil': 17419152000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000062/0000320193-20-000062-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000062/aapl-20200627.htm'},
#  {'date': '2020-03-28',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2020-05-01',
#   'acceptedDate': '2020-04-30 18:03:10',
#   'calendarYear': '2020',
#   'period': 'Q2',
#   'revenue': 58313000000,
#   'costOfRevenue': 35943000000,
#   'grossProfit': 22370000000,
#   'grossProfitRatio': 0.3836194330595236,
#   'researchAndDevelopmentExpenses': 4565000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4952000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 9517000000,
#   'costAndExpenses': 45460000000,
#   'interestIncome': 1049000000,
#   'interestExpense': 757000000,
#   'depreciationAndAmortization': 2786000000,
#   'ebitda': 16678000000,
#   'ebitdaratio': 0.2860082657383431,
#   'operatingIncome': 12853000000,
#   'operatingIncomeRatio': 0.22041397287054346,
#   'totalOtherIncomeExpensesNet': 282000000,
#   'incomeBeforeTax': 13135000000,
#   'incomeBeforeTaxRatio': 0.2252499442662871,
#   'incomeTaxExpense': 1886000000,
#   'netIncome': 11249000000,
#   'netIncomeRatio': 0.1929072419529093,
#   'eps': 0.645,
#   'epsdiluted': 0.6375,
#   'weightedAverageShsOut': 17440404000,
#   'weightedAverageShsOutDil': 17618764000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000052/0000320193-20-000052-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000052/a10-qq220203282020.htm'},
#  {'date': '2019-12-28',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2020-01-29',
#   'acceptedDate': '2020-01-28 18:02:44',
#   'calendarYear': '2020',
#   'period': 'Q1',
#   'revenue': 91819000000,
#   'costOfRevenue': 56602000000,
#   'grossProfit': 35217000000,
#   'grossProfitRatio': 0.38354806739345887,
#   'researchAndDevelopmentExpenses': 4451000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 5197000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 9648000000,
#   'costAndExpenses': 66250000000,
#   'interestIncome': 1045000000,
#   'interestExpense': 785000000,
#   'depreciationAndAmortization': 2816000000,
#   'ebitda': 29519000000,
#   'ebitdaratio': 0.3214911946329191,
#   'operatingIncome': 25569000000,
#   'operatingIncomeRatio': 0.2784717759940753,
#   'totalOtherIncomeExpensesNet': 349000000,
#   'incomeBeforeTax': 25918000000,
#   'incomeBeforeTaxRatio': 0.2822727322231782,
#   'incomeTaxExpense': 3682000000,
#   'netIncome': 22236000000,
#   'netIncomeRatio': 0.2421720994565395,
#   'eps': 1.26,
#   'epsdiluted': 1.2475,
#   'weightedAverageShsOut': 17660160000,
#   'weightedAverageShsOutDil': 17818416000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000010/0000320193-20-000010-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000010/a10-qq1202012282019.htm'},
#  {'date': '2019-09-28',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2019-10-31',
#   'acceptedDate': '2019-10-30 18:12:36',
#   'calendarYear': '2019',
#   'period': 'Q4',
#   'revenue': 64040000000,
#   'costOfRevenue': 39727000000,
#   'grossProfit': 24313000000,
#   'grossProfitRatio': 0.3796533416614616,
#   'researchAndDevelopmentExpenses': 4110000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4578000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 8688000000,
#   'costAndExpenses': 48415000000,
#   'interestIncome': 1106000000,
#   'interestExpense': 810000000,
#   'depreciationAndAmortization': 3179000000,
#   'ebitda': 20116000000,
#   'ebitdaratio': 0.3141161773891318,
#   'operatingIncome': 15625000000,
#   'operatingIncomeRatio': 0.2439881324172392,
#   'totalOtherIncomeExpensesNet': 502000000,
#   'incomeBeforeTax': 16127000000,
#   'incomeBeforeTaxRatio': 0.2518269831355403,
#   'incomeTaxExpense': 2441000000,
#   'netIncome': 13686000000,
#   'netIncomeRatio': 0.2137101811367895,
#   'eps': 0.7625,
#   'epsdiluted': 0.7575,
#   'weightedAverageShsOut': 17963248000,
#   'weightedAverageShsOutDil': 18081492000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019.htm'},
#  {'date': '2019-06-29',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2019-07-31',
#   'acceptedDate': '2019-07-31 16:31:53',
#   'calendarYear': '2019',
#   'period': 'Q3',
#   'revenue': 53809000000,
#   'costOfRevenue': 33582000000,
#   'grossProfit': 20227000000,
#   'grossProfitRatio': 0.37590365923916075,
#   'researchAndDevelopmentExpenses': 4257000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4426000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 8683000000,
#   'costAndExpenses': 42265000000,
#   'interestIncome': 1190000000,
#   'interestExpense': 866000000,
#   'depreciationAndAmortization': 2933000000,
#   'ebitda': 15710000000,
#   'ebitdaratio': 0.291958594287201,
#   'operatingIncome': 11544000000,
#   'operatingIncomeRatio': 0.2145366016837332,
#   'totalOtherIncomeExpensesNet': 367000000,
#   'incomeBeforeTax': 11911000000,
#   'incomeBeforeTaxRatio': 0.22135702205950678,
#   'incomeTaxExpense': 1867000000,
#   'netIncome': 10044000000,
#   'netIncomeRatio': 0.18666022412607555,
#   'eps': 0.55,
#   'epsdiluted': 0.545,
#   'weightedAverageShsOut': 18282532000,
#   'weightedAverageShsOutDil': 18405520000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000076/a10-qq320196292019.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000076/a10-qq320196292019.htm'},
#  {'date': '2019-03-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2019-05-01',
#   'acceptedDate': '2019-05-01 16:32:00',
#   'calendarYear': '2019',
#   'period': 'Q2',
#   'revenue': 58015000000,
#   'costOfRevenue': 36194000000,
#   'grossProfit': 21821000000,
#   'grossProfitRatio': 0.37612686374213566,
#   'researchAndDevelopmentExpenses': 3948000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4458000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 8406000000,
#   'costAndExpenses': 44600000000,
#   'interestIncome': 1358000000,
#   'interestExpense': 1010000000,
#   'depreciationAndAmortization': 3040000000,
#   'ebitda': 17843000000,
#   'ebitdaratio': 0.30755839007153324,
#   'operatingIncome': 13415000000,
#   'operatingIncomeRatio': 0.2312333017323106,
#   'totalOtherIncomeExpensesNet': 378000000,
#   'incomeBeforeTax': 13793000000,
#   'incomeBeforeTaxRatio': 0.23774885805395157,
#   'incomeTaxExpense': 2232000000,
#   'netIncome': 11561000000,
#   'netIncomeRatio': 0.19927604929759546,
#   'eps': 0.6175,
#   'epsdiluted': 0.615,
#   'weightedAverageShsOut': 18696284000,
#   'weightedAverageShsOutDil': 18802584000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000066/0000320193-19-000066-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000066/a10-qq220193302019.htm'},
#  {'date': '2018-12-29',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2019-01-30',
#   'acceptedDate': '2019-01-30 16:31:37',
#   'calendarYear': '2019',
#   'period': 'Q1',
#   'revenue': 84310000000,
#   'costOfRevenue': 52279000000,
#   'grossProfit': 32031000000,
#   'grossProfitRatio': 0.3799193452733958,
#   'researchAndDevelopmentExpenses': 3902000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4783000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 8685000000,
#   'costAndExpenses': 60964000000,
#   'interestIncome': 1307000000,
#   'interestExpense': 890000000,
#   'depreciationAndAmortization': 3395000000,
#   'ebitda': 28191000000,
#   'ebitdaratio': 0.3343731467204365,
#   'operatingIncome': 23346000000,
#   'operatingIncomeRatio': 0.27690665401494485,
#   'totalOtherIncomeExpensesNet': 560000000,
#   'incomeBeforeTax': 23906000000,
#   'incomeBeforeTaxRatio': 0.28354880797058474,
#   'incomeTaxExpense': 3941000000,
#   'netIncome': 19965000000,
#   'netIncomeRatio': 0.23680464950776894,
#   'eps': 1.055,
#   'epsdiluted': 1.045,
#   'weightedAverageShsOut': 18943280000,
#   'weightedAverageShsOutDil': 19093008000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000010/0000320193-19-000010-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000010/a10-qq1201912292018.htm'},
#  {'date': '2018-09-29',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2018-11-05',
#   'acceptedDate': '2018-11-05 08:01:40',
#   'calendarYear': '2018',
#   'period': 'Q4',
#   'revenue': 62900000000,
#   'costOfRevenue': 38816000000,
#   'grossProfit': 24084000000,
#   'grossProfitRatio': 0.38289348171701115,
#   'researchAndDevelopmentExpenses': 3750000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4216000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 7966000000,
#   'costAndExpenses': 46782000000,
#   'interestIncome': 1311000000,
#   'interestExpense': 868000000,
#   'depreciationAndAmortization': 2754000000,
#   'ebitda': 20043000000,
#   'ebitdaratio': 0.31864864864864867,
#   'operatingIncome': 16118000000,
#   'operatingIncomeRatio': 0.256248012718601,
#   'totalOtherIncomeExpensesNet': 303000000,
#   'incomeBeforeTax': 16421000000,
#   'incomeBeforeTaxRatio': 0.2610651828298887,
#   'incomeTaxExpense': 2296000000,
#   'netIncome': 14125000000,
#   'netIncomeRatio': 0.22456279809220986,
#   'eps': 0.735,
#   'epsdiluted': 0.7275,
#   'weightedAverageShsOut': 19206356000,
#   'weightedAverageShsOutDil': 19390188000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm'},
#  {'date': '2018-06-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2018-08-01',
#   'acceptedDate': '2018-08-01 16:31:48',
#   'calendarYear': '2018',
#   'period': 'Q3',
#   'revenue': 53265000000,
#   'costOfRevenue': 32844000000,
#   'grossProfit': 20421000000,
#   'grossProfitRatio': 0.38338496198254013,
#   'researchAndDevelopmentExpenses': 3701000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4108000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 7809000000,
#   'costAndExpenses': 40653000000,
#   'interestIncome': 1418000000,
#   'interestExpense': 846000000,
#   'depreciationAndAmortization': 2665000000,
#   'ebitda': 16795000000,
#   'ebitdaratio': 0.3153102412465972,
#   'operatingIncome': 12612000000,
#   'operatingIncomeRatio': 0.23677837228949591,
#   'totalOtherIncomeExpensesNet': 672000000,
#   'incomeBeforeTax': 13284000000,
#   'incomeBeforeTaxRatio': 0.2493945367502112,
#   'incomeTaxExpense': 1765000000,
#   'netIncome': 11519000000,
#   'netIncomeRatio': 0.21625833098657654,
#   'eps': 0.59,
#   'epsdiluted': 0.585,
#   'weightedAverageShsOut': 19528668000,
#   'weightedAverageShsOutDil': 19706436000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000100/0000320193-18-000100-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000100/a10-qq320186302018.htm'},
#  {'date': '2018-03-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2018-05-02',
#   'acceptedDate': '2018-05-02 16:32:12',
#   'calendarYear': '2018',
#   'period': 'Q2',
#   'revenue': 61137000000,
#   'costOfRevenue': 37715000000,
#   'grossProfit': 23422000000,
#   'grossProfitRatio': 0.38310679294044525,
#   'researchAndDevelopmentExpenses': 3378000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4150000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 7528000000,
#   'costAndExpenses': 45243000000,
#   'interestIncome': 1505000000,
#   'interestExpense': 792000000,
#   'depreciationAndAmortization': 2739000000,
#   'ebitda': 19699000000,
#   'ebitdaratio': 0.3222107725272748,
#   'operatingIncome': 15894000000,
#   'operatingIncomeRatio': 0.2599735021345503,
#   'totalOtherIncomeExpensesNet': 274000000,
#   'incomeBeforeTax': 16168000000,
#   'incomeBeforeTaxRatio': 0.26445523987110914,
#   'incomeTaxExpense': 2346000000,
#   'netIncome': 13822000000,
#   'netIncomeRatio': 0.22608240509020724,
#   'eps': 0.6875,
#   'epsdiluted': 0.6825,
#   'weightedAverageShsOut': 20099508000,
#   'weightedAverageShsOutDil': 20273972000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000070/0000320193-18-000070-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000070/a10-qq220183312018.htm'},
#  {'date': '2017-12-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2018-02-02',
#   'acceptedDate': '2018-02-02 08:01:26',
#   'calendarYear': '2018',
#   'period': 'Q1',
#   'revenue': 88293000000,
#   'costOfRevenue': 54381000000,
#   'grossProfit': 33912000000,
#   'grossProfitRatio': 0.384084808535218,
#   'researchAndDevelopmentExpenses': 3407000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 4231000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 7638000000,
#   'costAndExpenses': 62019000000,
#   'interestIncome': 1452000000,
#   'interestExpense': 734000000,
#   'depreciationAndAmortization': 2745000000,
#   'ebitda': 30509000000,
#   'ebitdaratio': 0.34554268175280034,
#   'operatingIncome': 26274000000,
#   'operatingIncomeRatio': 0.29757738439060855,
#   'totalOtherIncomeExpensesNet': 756000000,
#   'incomeBeforeTax': 27030000000,
#   'incomeBeforeTaxRatio': 0.3061397845808841,
#   'incomeTaxExpense': 6965000000,
#   'netIncome': 20065000000,
#   'netIncomeRatio': 0.22725470875380835,
#   'eps': 0.98,
#   'epsdiluted': 0.9725,
#   'weightedAverageShsOut': 20451508000,
#   'weightedAverageShsOutDil': 20631148000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000007/0000320193-18-000007-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000007/a10-qq1201812302017.htm'},
#  {'date': '2017-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2017-11-03',
#   'acceptedDate': '2017-11-03 08:01:37',
#   'calendarYear': '2017',
#   'period': 'Q4',
#   'revenue': 52579000000,
#   'costOfRevenue': 32648000000,
#   'grossProfit': 19931000000,
#   'grossProfitRatio': 0.3790676886209323,
#   'researchAndDevelopmentExpenses': 2997000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3814000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6811000000,
#   'costAndExpenses': 39459000000,
#   'interestIncome': 1368000000,
#   'interestExpense': 666000000,
#   'depreciationAndAmortization': 2484000000,
#   'ebitda': 17067000000,
#   'ebitdaratio': 0.3245972726754027,
#   'operatingIncome': 13120000000,
#   'operatingIncomeRatio': 0.24952927975047073,
#   'totalOtherIncomeExpensesNet': 797000000,
#   'incomeBeforeTax': 13917000000,
#   'incomeBeforeTaxRatio': 0.2646874227353126,
#   'incomeTaxExpense': 3203000000,
#   'netIncome': 10714000000,
#   'netIncomeRatio': 0.20376956579623043,
#   'eps': 0.52,
#   'epsdiluted': 0.5175,
#   'weightedAverageShsOut': 20597712000,
#   'weightedAverageShsOutDil': 20734340000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/0000320193-17-000070-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/a10-k20179302017.htm'},
#  {'date': '2017-07-01',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2017-08-02',
#   'acceptedDate': '2017-08-02 16:31:28',
#   'calendarYear': '2017',
#   'period': 'Q3',
#   'revenue': 45408000000,
#   'costOfRevenue': 27920000000,
#   'grossProfit': 17488000000,
#   'grossProfitRatio': 0.38513037350246654,
#   'researchAndDevelopmentExpenses': 2937000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3783000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6720000000,
#   'costAndExpenses': 34640000000,
#   'interestIncome': 1327000000,
#   'interestExpense': 602000000,
#   'depreciationAndAmortization': 2354000000,
#   'ebitda': 14264000000,
#   'ebitdaratio': 0.3141296687808316,
#   'operatingIncome': 10768000000,
#   'operatingIncomeRatio': 0.23713883016208598,
#   'totalOtherIncomeExpensesNet': 540000000,
#   'incomeBeforeTax': 11308000000,
#   'incomeBeforeTaxRatio': 0.24903100775193798,
#   'incomeTaxExpense': 2591000000,
#   'netIncome': 8717000000,
#   'netIncomeRatio': 0.19197057787174066,
#   'eps': 0.42,
#   'epsdiluted': 0.4175,
#   'weightedAverageShsOut': 20780352000,
#   'weightedAverageShsOutDil': 20933996000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000009/0000320193-17-000009-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000009/a10-qq32017712017.htm'},
#  {'date': '2017-04-01',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2017-05-03',
#   'acceptedDate': '2017-05-03 16:32:23',
#   'calendarYear': '2017',
#   'period': 'Q2',
#   'revenue': 52896000000,
#   'costOfRevenue': 32305000000,
#   'grossProfit': 20591000000,
#   'grossProfitRatio': 0.38927329098608593,
#   'researchAndDevelopmentExpenses': 2776000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3718000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6494000000,
#   'costAndExpenses': 38799000000,
#   'interestIncome': 1282000000,
#   'interestExpense': 530000000,
#   'depreciationAndAmortization': 2332000000,
#   'ebitda': 17546000000,
#   'ebitdaratio': 0.3317075015124017,
#   'operatingIncome': 14097000000,
#   'operatingIncomeRatio': 0.2665040834845735,
#   'totalOtherIncomeExpensesNet': 587000000,
#   'incomeBeforeTax': 14684000000,
#   'incomeBeforeTaxRatio': 0.2776013309134906,
#   'incomeTaxExpense': 3655000000,
#   'netIncome': 11029000000,
#   'netIncomeRatio': 0.20850347852389595,
#   'eps': 0.5275,
#   'epsdiluted': 0.525,
#   'weightedAverageShsOut': 20903164000,
#   'weightedAverageShsOutDil': 21046752000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828017004790/0001628280-17-004790-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828017004790/a10-qq22017412017.htm'},
#  {'date': '2016-12-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2017-02-01',
#   'acceptedDate': '2017-02-01 16:33:29',
#   'calendarYear': '2017',
#   'period': 'Q1',
#   'revenue': 78351000000,
#   'costOfRevenue': 48175000000,
#   'grossProfit': 30176000000,
#   'grossProfitRatio': 0.38513867085295656,
#   'researchAndDevelopmentExpenses': 2871000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3946000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6817000000,
#   'costAndExpenses': 54992000000,
#   'interestIncome': 1224000000,
#   'interestExpense': 525000000,
#   'depreciationAndAmortization': 2987000000,
#   'ebitda': 27692000000,
#   'ebitdaratio': 0.3534351827034754,
#   'operatingIncome': 23359000000,
#   'operatingIncomeRatio': 0.2981327615473957,
#   'totalOtherIncomeExpensesNet': 821000000,
#   'incomeBeforeTax': 24180000000,
#   'incomeBeforeTaxRatio': 0.3086112493777999,
#   'incomeTaxExpense': 6289000000,
#   'netIncome': 17891000000,
#   'netIncomeRatio': 0.22834424576584855,
#   'eps': 0.845,
#   'epsdiluted': 0.84,
#   'weightedAverageShsOut': 21194644000,
#   'weightedAverageShsOutDil': 21311980000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828017000717/0001628280-17-000717-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828017000717/a10-qq1201712312016.htm'},
#  {'date': '2016-09-24',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2016-10-26',
#   'acceptedDate': '2016-10-26 16:42:16',
#   'calendarYear': '2016',
#   'period': 'Q4',
#   'revenue': 46852000000,
#   'costOfRevenue': 29039000000,
#   'grossProfit': 17813000000,
#   'grossProfitRatio': 0.380197216767694,
#   'researchAndDevelopmentExpenses': 2570000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3482000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6052000000,
#   'costAndExpenses': 35091000000,
#   'interestIncome': 1036000000,
#   'interestExpense': 450000000,
#   'depreciationAndAmortization': 2548000000,
#   'ebitda': 15186000000,
#   'ebitdaratio': 0.3241270383334756,
#   'operatingIncome': 11761000000,
#   'operatingIncomeRatio': 0.2510245026893196,
#   'totalOtherIncomeExpensesNet': 427000000,
#   'incomeBeforeTax': 12188000000,
#   'incomeBeforeTaxRatio': 0.26013830786305814,
#   'incomeTaxExpense': 3174000000,
#   'netIncome': 9014000000,
#   'netIncomeRatio': 0.19239306753180227,
#   'eps': 0.42,
#   'epsdiluted': 0.4175,
#   'weightedAverageShsOut': 21467648000,
#   'weightedAverageShsOutDil': 21573332000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/0001628280-16-020309-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/a201610-k9242016.htm'},
#  {'date': '2016-06-25',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2016-07-27',
#   'acceptedDate': '2016-07-27 16:32:36',
#   'calendarYear': '2016',
#   'period': 'Q3',
#   'revenue': 42358000000,
#   'costOfRevenue': 26252000000,
#   'grossProfit': 16106000000,
#   'grossProfitRatio': 0.38023513858066954,
#   'researchAndDevelopmentExpenses': 2560000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3441000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6001000000,
#   'costAndExpenses': 32253000000,
#   'interestIncome': 1036000000,
#   'interestExpense': 409000000,
#   'depreciationAndAmortization': 2526000000,
#   'ebitda': 13404000000,
#   'ebitdaratio': 0.3164455356721281,
#   'operatingIncome': 10105000000,
#   'operatingIncomeRatio': 0.23856178289815383,
#   'totalOtherIncomeExpensesNet': 364000000,
#   'incomeBeforeTax': 10469000000,
#   'incomeBeforeTaxRatio': 0.24715520090655838,
#   'incomeTaxExpense': 2673000000,
#   'netIncome': 7796000000,
#   'netIncomeRatio': 0.18405023844374144,
#   'eps': 0.3575,
#   'epsdiluted': 0.355,
#   'weightedAverageShsOut': 21772232000,
#   'weightedAverageShsOutDil': 21891124000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016017809/a10-qq320166252016.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016017809/a10-qq320166252016.htm'},
#  {'date': '2016-03-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2016-04-27',
#   'acceptedDate': '2016-04-27 16:32:53',
#   'calendarYear': '2016',
#   'period': 'Q2',
#   'revenue': 50557000000,
#   'costOfRevenue': 30636000000,
#   'grossProfit': 19921000000,
#   'grossProfitRatio': 0.39403050022746605,
#   'researchAndDevelopmentExpenses': 2511000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3423000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 5934000000,
#   'costAndExpenses': 36570000000,
#   'interestIncome': 986000000,
#   'interestExpense': 321000000,
#   'depreciationAndAmortization': 2477000000,
#   'ebitda': 16940000000,
#   'ebitdaratio': 0.3350673497240738,
#   'operatingIncome': 13987000000,
#   'operatingIncomeRatio': 0.27665802955080404,
#   'totalOtherIncomeExpensesNet': 155000000,
#   'incomeBeforeTax': 14142000000,
#   'incomeBeforeTaxRatio': 0.2797238760211247,
#   'incomeTaxExpense': 3626000000,
#   'netIncome': 10516000000,
#   'netIncomeRatio': 0.2080028482702692,
#   'eps': 0.4775,
#   'epsdiluted': 0.475,
#   'weightedAverageShsOut': 22057524000,
#   'weightedAverageShsOutDil': 22163544000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312516559625/0001193125-16-559625-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312516559625/d165350d10q.htm'},
#  {'date': '2015-12-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2016-01-27',
#   'acceptedDate': '2016-01-27 16:32:03',
#   'calendarYear': '2016',
#   'period': 'Q1',
#   'revenue': 75872000000,
#   'costOfRevenue': 45449000000,
#   'grossProfit': 30423000000,
#   'grossProfitRatio': 0.4009779628848587,
#   'researchAndDevelopmentExpenses': 2404000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3848000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 6252000000,
#   'costAndExpenses': 51701000000,
#   'interestIncome': 941000000,
#   'interestExpense': 276000000,
#   'depreciationAndAmortization': 2954000000,
#   'ebitda': 27803000000,
#   'ebitdaratio': 0.36644611978068325,
#   'operatingIncome': 24171000000,
#   'operatingIncomeRatio': 0.31857602277520036,
#   'totalOtherIncomeExpensesNet': 402000000,
#   'incomeBeforeTax': 24573000000,
#   'incomeBeforeTaxRatio': 0.3238744200759173,
#   'incomeTaxExpense': 6212000000,
#   'netIncome': 18361000000,
#   'netIncomeRatio': 0.24199968367777308,
#   'eps': 0.825,
#   'epsdiluted': 0.82,
#   'weightedAverageShsOut': 22235720000,
#   'weightedAverageShsOutDil': 22376508000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312516439878/0001193125-16-439878-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312516439878/d66145d10q.htm'},
#  {'date': '2015-09-26',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2015-10-28',
#   'acceptedDate': '2015-10-28 16:31:09',
#   'calendarYear': '2015',
#   'period': 'Q4',
#   'revenue': 51501000000,
#   'costOfRevenue': 30953000000,
#   'grossProfit': 20548000000,
#   'grossProfitRatio': 0.39898254402827127,
#   'researchAndDevelopmentExpenses': 2220000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3705000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 5925000000,
#   'costAndExpenses': 36878000000,
#   'interestIncome': 826000000,
#   'interestExpense': 238000000,
#   'depreciationAndAmortization': 3119000000,
#   'ebitda': 18419000000,
#   'ebitdaratio': 0.3576435409021184,
#   'operatingIncome': 14623000000,
#   'operatingIncomeRatio': 0.28393623424787867,
#   'totalOtherIncomeExpensesNet': 439000000,
#   'incomeBeforeTax': 15062000000,
#   'incomeBeforeTaxRatio': 0.29246034057591114,
#   'incomeTaxExpense': 3938000000,
#   'netIncome': 11124000000,
#   'netIncomeRatio': 0.21599580590668144,
#   'eps': 0.4925,
#   'epsdiluted': 0.49,
#   'weightedAverageShsOut': 22587664000,
#   'weightedAverageShsOutDil': 22730076000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/0001193125-15-356351-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/d17062d10k.htm'},
#  {'date': '2015-06-27',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2015-07-22',
#   'acceptedDate': '2015-07-22 17:01:17',
#   'calendarYear': '2015',
#   'period': 'Q3',
#   'revenue': 49605000000,
#   'costOfRevenue': 29924000000,
#   'grossProfit': 19681000000,
#   'grossProfitRatio': 0.3967543594395726,
#   'researchAndDevelopmentExpenses': 2034000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3564000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 5598000000,
#   'costAndExpenses': 35522000000,
#   'interestIncome': 766000000,
#   'interestExpense': 201000000,
#   'depreciationAndAmortization': 3084000000,
#   'ebitda': 17758000000,
#   'ebitdaratio': 0.3579881060376978,
#   'operatingIncome': 14083000000,
#   'operatingIncomeRatio': 0.2839028323757686,
#   'totalOtherIncomeExpensesNet': 390000000,
#   'incomeBeforeTax': 14473000000,
#   'incomeBeforeTaxRatio': 0.29176494305009576,
#   'incomeTaxExpense': 3796000000,
#   'netIncome': 10677000000,
#   'netIncomeRatio': 0.21524039915331117,
#   'eps': 0.465,
#   'epsdiluted': 0.4625,
#   'weightedAverageShsOut': 22919544000,
#   'weightedAverageShsOutDil': 23092396000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515259935/0001193125-15-259935-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515259935/d927922d10q.htm'},
#  {'date': '2015-03-28',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2015-04-28',
#   'acceptedDate': '2015-04-28 17:01:16',
#   'calendarYear': '2015',
#   'period': 'Q2',
#   'revenue': 58010000000,
#   'costOfRevenue': 34354000000,
#   'grossProfit': 23656000000,
#   'grossProfitRatio': 0.4077917600413722,
#   'researchAndDevelopmentExpenses': 1918000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3460000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 5378000000,
#   'costAndExpenses': 39732000000,
#   'interestIncome': 675000000,
#   'interestExpense': 163000000,
#   'depreciationAndAmortization': 2479000000,
#   'ebitda': 21206000000,
#   'ebitdaratio': 0.36555766247198757,
#   'operatingIncome': 18278000000,
#   'operatingIncomeRatio': 0.3150836062747802,
#   'totalOtherIncomeExpensesNet': 286000000,
#   'incomeBeforeTax': 18564000000,
#   'incomeBeforeTaxRatio': 0.32001379072573694,
#   'incomeTaxExpense': 4995000000,
#   'netIncome': 13569000000,
#   'netIncomeRatio': 0.2339079469057059,
#   'eps': 0.585,
#   'epsdiluted': 0.5825,
#   'weightedAverageShsOut': 23175196000,
#   'weightedAverageShsOutDil': 23339432000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515153166/0001193125-15-153166-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515153166/d892246d10q.htm'},
#  {'date': '2014-12-27',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2015-01-28',
#   'acceptedDate': '2015-01-28 16:39:32',
#   'calendarYear': '2015',
#   'period': 'Q1',
#   'revenue': 74599000000,
#   'costOfRevenue': 44858000000,
#   'grossProfit': 29741000000,
#   'grossProfitRatio': 0.3986782664646979,
#   'researchAndDevelopmentExpenses': 1895000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3600000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 5495000000,
#   'costAndExpenses': 50353000000,
#   'interestIncome': 654000000,
#   'interestExpense': 131000000,
#   'depreciationAndAmortization': 2575000000,
#   'ebitda': 27122000000,
#   'ebitdaratio': 0.3635705572460757,
#   'operatingIncome': 24246000000,
#   'operatingIncomeRatio': 0.3250177616321935,
#   'totalOtherIncomeExpensesNet': 170000000,
#   'incomeBeforeTax': 24416000000,
#   'incomeBeforeTaxRatio': 0.3272966125551281,
#   'incomeTaxExpense': 6392000000,
#   'netIncome': 18024000000,
#   'netIncomeRatio': 0.24161181785278624,
#   'eps': 0.77,
#   'epsdiluted': 0.765,
#   'weightedAverageShsOut': 23372328000,
#   'weightedAverageShsOutDil': 23527212000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm'},
#  {'date': '2014-09-27',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2014-10-27',
#   'acceptedDate': '2014-10-27 17:11:55',
#   'calendarYear': '2014',
#   'period': 'Q4',
#   'revenue': 42123000000,
#   'costOfRevenue': 26114000000,
#   'grossProfit': 16009000000,
#   'grossProfitRatio': 0.38005365239892697,
#   'researchAndDevelopmentExpenses': 1686000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 3158000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 4844000000,
#   'costAndExpenses': 30958000000,
#   'interestIncome': 519000000,
#   'interestExpense': 115000000,
#   'depreciationAndAmortization': 1969000000,
#   'ebitda': 13556000000,
#   'ebitdaratio': 0.3218194335636113,
#   'operatingIncome': 11165000000,
#   'operatingIncomeRatio': 0.26505709469885813,
#   'totalOtherIncomeExpensesNet': 307000000,
#   'incomeBeforeTax': 11472000000,
#   'incomeBeforeTaxRatio': 0.2723452745530945,
#   'incomeTaxExpense': 3005000000,
#   'netIncome': 8467000000,
#   'netIncomeRatio': 0.20100657597986848,
#   'eps': 0.3575,
#   'epsdiluted': 0.355,
#   'weightedAverageShsOut': 23735380000,
#   'weightedAverageShsOutDil': 23888328000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/0001193125-14-383437-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm'},
#  {'date': '2014-06-28',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2014-07-23',
#   'acceptedDate': '2014-07-23 16:32:48',
#   'calendarYear': '2014',
#   'period': 'Q3',
#   'revenue': 37432000000,
#   'costOfRevenue': 22697000000,
#   'grossProfit': 14735000000,
#   'grossProfitRatio': 0.3936471468262449,
#   'researchAndDevelopmentExpenses': 1603000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 2850000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 4453000000,
#   'costAndExpenses': 27150000000,
#   'interestIncome': 439000000,
#   'interestExpense': 100000000,
#   'depreciationAndAmortization': 1946000000,
#   'ebitda': 12530000000,
#   'ebitdaratio': 0.334740329130156,
#   'operatingIncome': 10282000000,
#   'operatingIncomeRatio': 0.2746847617012182,
#   'totalOtherIncomeExpensesNet': 202000000,
#   'incomeBeforeTax': 10484000000,
#   'incomeBeforeTaxRatio': 0.2800812139346014,
#   'incomeTaxExpense': 2736000000,
#   'netIncome': 7748000000,
#   'netIncomeRatio': 0.2069886727933319,
#   'eps': 0.3225,
#   'epsdiluted': 0.32,
#   'weightedAverageShsOut': 24050540000,
#   'weightedAverageShsOutDil': 24206844000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514277160/0001193125-14-277160-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514277160/d740164d10q.htm'},
#  {'date': '2014-03-29',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2014-04-24',
#   'acceptedDate': '2014-04-24 17:02:12',
#   'calendarYear': '2014',
#   'period': 'Q2',
#   'revenue': 45646000000,
#   'costOfRevenue': 27699000000,
#   'grossProfit': 17947000000,
#   'grossProfitRatio': 0.3931779345397187,
#   'researchAndDevelopmentExpenses': 1422000000,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 2932000000,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 4354000000,
#   'costAndExpenses': 32053000000,
# ...
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 1246900000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 1246900000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.003929,
#   'epsdiluted': 0.003929,
#   'weightedAverageShsOut': 14307664000,
#   'weightedAverageShsOutDil': 14307664000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1988-12-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1988-12-31',
#   'acceptedDate': '1988-12-31',
#   'calendarYear': '1989',
#   'period': 'Q1',
#   'revenue': 1405100000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 1405100000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 1405100000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.009821,
#   'epsdiluted': 0.009821,
#   'weightedAverageShsOut': 14285264000,
#   'weightedAverageShsOutDil': 14285264000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1988-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1988-09-30',
#   'acceptedDate': '1988-09-30',
#   'calendarYear': '1988',
#   'period': 'Q4',
#   'revenue': 1168700000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': -2282400000,
#   'ebitdaratio': -1.952939163172756,
#   'operatingIncome': -2282400000,
#   'operatingIncomeRatio': -1.952939163172756,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.0,
#   'epsdiluted': 0.0,
#   'weightedAverageShsOut': 14285264000,
#   'weightedAverageShsOutDil': 14285264000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1988-06-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1988-06-30',
#   'acceptedDate': '1988-06-30',
#   'calendarYear': '1988',
#   'period': 'Q3',
#   'revenue': 993100000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 993100000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 993100000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.006429,
#   'epsdiluted': 0.006429,
#   'weightedAverageShsOut': 14622720000,
#   'weightedAverageShsOutDil': 14622720000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1988-03-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1988-03-31',
#   'acceptedDate': '1988-03-31',
#   'calendarYear': '1988',
#   'period': 'Q2',
#   'revenue': 867200000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 867200000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 867200000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.005536,
#   'epsdiluted': 0.005536,
#   'weightedAverageShsOut': 13946352000,
#   'weightedAverageShsOutDil': 13946352000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1987-12-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1987-12-31',
#   'acceptedDate': '1987-12-31',
#   'calendarYear': '1988',
#   'period': 'Q1',
#   'revenue': 1042400000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 1042400000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 1042400000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.008214,
#   'epsdiluted': 0.008214,
#   'weightedAverageShsOut': 14063280000,
#   'weightedAverageShsOutDil': 14063280000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1987-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1987-09-30',
#   'acceptedDate': '1987-09-30',
#   'calendarYear': '1987',
#   'period': 'Q4',
#   'revenue': 786500000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': -1503100000,
#   'ebitdaratio': -1.9111252383979658,
#   'operatingIncome': -1503100000,
#   'operatingIncomeRatio': -1.9111252383979658,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.0,
#   'epsdiluted': 0.0,
#   'weightedAverageShsOut': 14063280000,
#   'weightedAverageShsOutDil': 14063280000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1987-06-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1987-06-30',
#   'acceptedDate': '1987-06-30',
#   'calendarYear': '1987',
#   'period': 'Q3',
#   'revenue': 637100000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 637100000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 637100000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.003571,
#   'epsdiluted': 0.003571,
#   'weightedAverageShsOut': 14028672000,
#   'weightedAverageShsOutDil': 14028672000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1987-03-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1987-03-31',
#   'acceptedDate': '1987-03-31',
#   'calendarYear': '1987',
#   'period': 'Q2',
#   'revenue': 575300000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 575300000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 575300000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.002321,
#   'epsdiluted': 0.002321,
#   'weightedAverageShsOut': 14028672000,
#   'weightedAverageShsOutDil': 14028672000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1986-12-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1986-12-31',
#   'acceptedDate': '1986-12-31',
#   'calendarYear': '1987',
#   'period': 'Q1',
#   'revenue': 662300000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 662300000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 662300000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.004107,
#   'epsdiluted': 0.004107,
#   'weightedAverageShsOut': 14260064000,
#   'weightedAverageShsOutDil': 14260064000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1986-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1986-09-30',
#   'acceptedDate': '1986-09-30',
#   'calendarYear': '1986',
#   'period': 'Q4',
#   'revenue': 510800000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': -1117600000,
#   'ebitdaratio': -2.1879404855129208,
#   'operatingIncome': -1117600000,
#   'operatingIncomeRatio': -2.1879404855129208,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.0,
#   'epsdiluted': 0.0,
#   'weightedAverageShsOut': 14260064000,
#   'weightedAverageShsOutDil': 14260064000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1986-06-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1986-06-30',
#   'acceptedDate': '1986-06-30',
#   'calendarYear': '1986',
#   'period': 'Q3',
#   'revenue': 448300000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 448300000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 448300000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.002321,
#   'epsdiluted': 0.002321,
#   'weightedAverageShsOut': 14260064000,
#   'weightedAverageShsOutDil': 14260064000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1986-03-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1986-03-31',
#   'acceptedDate': '1986-03-31',
#   'calendarYear': '1986',
#   'period': 'Q2',
#   'revenue': 408900000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 408900000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 408900000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.002321,
#   'epsdiluted': 0.002321,
#   'weightedAverageShsOut': 14033600000,
#   'weightedAverageShsOutDil': 14033600000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1985-12-31',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1985-12-31',
#   'acceptedDate': '1985-12-31',
#   'calendarYear': '1986',
#   'period': 'Q1',
#   'revenue': 533900000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 533900000,
#   'ebitdaratio': 1.0,
#   'operatingIncome': 533900000,
#   'operatingIncomeRatio': 1.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.004107,
#   'epsdiluted': 0.004107,
#   'weightedAverageShsOut': 13837824000,
#   'weightedAverageShsOutDil': 13837824000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1985-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '1985-09-30',
#   'acceptedDate': '1985-09-30',
#   'calendarYear': '1985',
#   'period': 'Q4',
#   'revenue': 409700000,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 0.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 0.0,
#   'costAndExpenses': 0.0,
#   'interestIncome': 0.0,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': -1361300000,
#   'ebitdaratio': -3.3226751281425435,
#   'operatingIncome': -1361300000,
#   'operatingIncomeRatio': -3.3226751281425435,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 0.0,
#   'incomeBeforeTaxRatio': 0.0,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 0.0,
#   'netIncomeRatio': 0.0,
#   'eps': 0.0,
#   'epsdiluted': 0.0,
#   'weightedAverageShsOut': 13837824000,
#   'weightedAverageShsOutDil': 13837824000,
#   'link': '',
#   'finalLink': ''}]

# %%
income_statement_q_df = pd.DataFrame(income_statement_q)
income_statement_q_df.head()
dates = income_statement_q_df['date']

# %%
def quarterly_data(ticker):
    income_statement_q = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{ticker}?period=quarter&limit=400&apikey={api}').json()
    balance_sheet = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{ticker}?period=quarter&limit=400&apikey={api}').json()
    cash_flow = requests.get(f'https://financialmodelingprep.com/api/v3/cash-flow-statement/{ticker}?period=quarter&limit=400&apikey={api}').json()
    Ratios = requests.get(f'https://financialmodelingprep.com/api/v3/ratios/{ticker}?period=quarter&limit=400&apikey={api}').json()
    key_Metrics = requests.get(f'https://financialmodelingprep.com/api/v3/key-metrics/{ticker}?period=quarter&limit=400&apikey={api}').json()
    profile = requests.get(f'https://financialmodelingprep.com/api/v3/profile/{ticker}?period=quarter&limit=400&apikey={api}').json()
    
    millions = 1000000
    
    financials = {}
    length = min([len(income_statement_q), len(balance_sheet), len(cash_flow), len(Ratios), len(key_Metrics)])
    for item in range(length): # 10 years
        financials[dates[item]]={}
        financials[dates[item]]['Calendar_Year'] = income_statement_q[item]['calendarYear']
        financials[dates[item]]['Quarter'] = income_statement_q[item]['period']
        financials[dates[item]]['Mkt Cap'] = key_Metrics[item]['marketCap'] /millions
        financials[dates[item]]['Debt to Equity'] = key_Metrics[item]['debtToEquity']
        financials[dates[item]]['Debt to Assets'] = key_Metrics[item]['debtToAssets']
        financials[dates[item]]['Revenue per Share'] = key_Metrics[item]['revenuePerShare']
        financials[dates[item]]['NI per Share'] = key_Metrics[item]['netIncomePerShare']
        financials[dates[item]]['outstandingShares'] = income_statement_q[item]['weightedAverageShsOutDil'] / millions
        
    # income statement
        financials[dates[item]]['Revenue'] = income_statement_q[item]['revenue'] / millions
        financials[dates[item]]['Gross Profit'] = income_statement_q[item]['grossProfit'] / millions
        financials[dates[item]]['R&D Expenses'] = income_statement_q[item]['researchAndDevelopmentExpenses']/ millions
        financials[dates[item]]['G&A Expenses'] = income_statement_q[item]['generalAndAdministrativeExpenses']/ millions
        financials[dates[item]]['Sales and Marketing Expenses'] = income_statement_q[item]['sellingAndMarketingExpenses']/ millions
        financials[dates[item]]['SG&A Expenses'] = income_statement_q[item]['sellingGeneralAndAdministrativeExpenses']/ millions
        financials[dates[item]]['Op Expenses'] = income_statement_q[item]['operatingExpenses'] / millions
        financials[dates[item]]['Cost and Expenses'] = income_statement_q[item]['costAndExpenses'] / millions
        financials[dates[item]]['Op Income'] = income_statement_q[item]['operatingIncome'] / millions
        financials[dates[item]]['Interest Income'] = income_statement_q[item]['interestIncome'] / millions
        financials[dates[item]]['Interest Expense'] = income_statement_q[item]['interestExpense'] / millions
        financials[dates[item]]['Net Income'] = income_statement_q[item]['netIncome'] / millions
        financials[dates[item]]['EPS'] = income_statement_q[item]['epsdiluted'] / millions
        
    
    # balance sheet
        financials[dates[item]]['Cash'] = balance_sheet[item]['cashAndCashEquivalents'] / millions
        financials[dates[item]]['Receivables'] = balance_sheet[item]['netReceivables'] / millions
        financials[dates[item]]['Inventory'] = balance_sheet[item]['inventory'] / millions
        financials[dates[item]]['Cur Assets'] = balance_sheet[item]['totalCurrentAssets'] / millions
        financials[dates[item]]['Tax Assets'] = balance_sheet[item]['taxAssets'] / millions
        financials[dates[item]]['LT Assets'] = balance_sheet[item]['totalNonCurrentAssets'] / millions
        financials[dates[item]]['Int Assets'] = balance_sheet[item]['intangibleAssets'] / millions
        financials[dates[item]]['Total Assets'] = balance_sheet[item]['totalAssets'] / millions
        financials[dates[item]]['Payables'] = balance_sheet[item]['accountPayables'] / millions
        financials[dates[item]]['Deferred Revenue Current'] = balance_sheet[item]['deferredRevenue'] / millions
        financials[dates[item]]['Deferred Revenue LongTerm'] = balance_sheet[item]['deferredRevenueNonCurrent'] / millions
        financials[dates[item]]['Cur Liab'] = balance_sheet[item]['totalCurrentLiabilities'] / millions
        financials[dates[item]]['LT Debt'] = balance_sheet[item]['longTermDebt'] / millions
        financials[dates[item]]['LT Liab'] = balance_sheet[item]['totalNonCurrentLiabilities'] / millions
        financials[dates[item]]['Total Liab'] = balance_sheet[item]['totalLiabilities'] / millions
        financials[dates[item]]['SH Equity'] = balance_sheet[item]['totalStockholdersEquity'] / millions
    
    # cash flow
        financials[dates[item]]['cash_flow Operations'] = cash_flow[item]['netCashProvidedByOperatingActivities'] / millions
        financials[dates[item]]['cash_flow Investing'] = cash_flow[item]['netCashUsedForInvestingActivites'] / millions
        financials[dates[item]]['cash_flow Financing'] = cash_flow[item]['netCashUsedProvidedByFinancingActivities'] / millions
        financials[dates[item]]['CAPEX'] = cash_flow[item]['capitalExpenditure'] / millions
        financials[dates[item]]['FCF'] = cash_flow[item]['freeCashFlow'] / millions
        financials[dates[item]]['Dividends Paid'] = cash_flow[item]['dividendsPaid'] / millions
    
    # income statement ratios
        financials[dates[item]]['Gross Profit Margin'] = Ratios[item]['grossProfitMargin']
        financials[dates[item]]['Op Margin'] = Ratios[item]['operatingProfitMargin']
        financials[dates[item]]['Int Coverage'] = Ratios[item]['interestCoverage']
        financials[dates[item]]['Net Profit Margin'] = Ratios[item]['netProfitMargin']
        financials[dates[item]]['Dividend Yield'] = Ratios[item]['dividendYield']
    
    # balance sheet ratios
        financials[dates[item]]['Current Ratio'] = Ratios[item]['currentRatio']
        financials[dates[item]]['Operating Cycle'] = Ratios[item]['operatingCycle']
        financials[dates[item]]['Days of AP Outstanding'] = Ratios[item]['daysOfPayablesOutstanding']
        financials[dates[item]]['Cash Conversion Cycle'] = Ratios[item]['cashConversionCycle']

    # return ratios
        financials[dates[item]]['ROA'] = Ratios[item]['returnOnAssets']
        financials[dates[item]]['ROE'] = Ratios[item]['returnOnEquity']
        financials[dates[item]]['ROCE'] = Ratios[item]['returnOnCapitalEmployed']
        financials[dates[item]]['Dividend Yield'] = Ratios[item]['dividendYield']
    
    # Valuation/Price ratios
        financials[dates[item]]['PE'] = Ratios[item]['priceEarningsRatio']
        financials[dates[item]]['PS'] = Ratios[item]['priceToSalesRatio']
        financials[dates[item]]['PB'] = Ratios[item]['priceToBookRatio']
        financials[dates[item]]['Price To FCF'] = Ratios[item]['priceToFreeCashFlowsRatio']
        financials[dates[item]]['PEG'] = Ratios[item]['priceEarningsToGrowthRatio']
        financials[dates[item]]['EPS'] = income_statement_q[item]['eps']
 
        
    df = pd.DataFrame(financials)
    df = df.T
    df['Ticker'] = ticker
    df.to_csv(f'{ticker}.csv')
    
    
    return df

# %%
tickers_df = pd.read_excel('/Users/brendan/Desktop/meritech_table.xlsx', sheet_name='Tickers',header=None)

# %%
tickers = tickers_df[1]
tickers
# Out:
# 0     ADBE
# 1     ALKT
# 2      AYX
# 3     AMPL
# 4     APPF
#       ...
# 80     ZEN
# 81      ZM
# 82      ZI
# 83      ZS
# 84     ZUO
# Name: 1, Length: 85, dtype: object

# %%
result = [quarterly_data(ticker) for ticker in tickers]

# %%
import glob, os

path = '/Users/brendan/Desktop/Python/Wellington'
csv_files = [f for f in os.listdir(path) if f.endswith('csv')]
csv_files
# Out:
# ['BRZE.csv',
#  'HUBS.csv',
#  'GTLB.csv',
#  'MDB.csv',
#  'QTWO.csv',
#  'AMPL.csv',
#  'ZS.csv',
#  'SMAR.csv',
#  'SQSP.csv',
#  'FSLY.csv',
#  'FRSH.csv',
#  'INST.csv',
#  'ADBE.csv',
#  'LSPD.csv',
#  'NOW.csv',
#  'RPD.csv',
#  'BOX.csv',
#  'HCP.csv',
#  'WDAY.csv',
#  'CYBR.csv',
#  'ZEN.csv',
#  'DBX.csv',
#  'MNTV.csv',
#  'AI.csv',
#  'S.csv',
#  'NCNO.csv',
#  'BILL.csv',
#  'COUP.csv',
#  'PAYC.csv',
#  'IOT.csv',
#  'DOCU.csv',
#  'WKME.csv',
#  'RNG.csv',
#  'BLND.csv',
#  'SPT.csv',
#  'PD.csv',
#  'QLYS.csv',
#  'OKTA.csv',
#  'ESTC.csv',
#  'AVLR.csv',
#  'OLO.csv',
#  'DOCS.csv',
#  'DOMO.csv',
#  'ALKT.csv',
#  'MNDY.csv',
#  'BASE.csv',
#  'TWLO.csv',
#  'JAMF.csv',
#  'NET.csv',
#  'FROG.csv',
#  'PING.csv',
#  'WIX.csv',
#  'PCOR.csv',
#  'VEEV.csv',
#  'AYX.csv',
#  'PCTY.csv',
#  'TOST.csv',
#  'CVT.csv',
#  'ZUO.csv',
#  'SUMO.csv',
#  'FIVN.csv',
#  'KNBE.csv',
#  'BIGC.csv',
#  'SNOW.csv',
#  'PATH.csv',
#  'CXM.csv',
#  'CRWD.csv',
#  'SHOP.csv',
#  'DOCN.csv',
#  'NEWR.csv',
#  'ZM.csv',
#  'FORG.csv',
#  'OM.csv',
#  'TENB.csv',
#  'TEAM.csv',
#  'PLTR.csv',
#  'APPF.csv',
#  'DDOG.csv',
#  'ZI.csv',
#  'LAW.csv',
#  'CFLT.csv',
#  'ASAN.csv',
#  'BL.csv',
#  'CWAN.csv',
#  'CRM.csv']

# %%
csv_to_df = [pd.DataFrame(pd.read_csv(file)) for file in csv_files]

# %%
raw_data_df = []
for file in csv_files:
    file = pd.read_csv(file)
    df = pd.DataFrame(file)
    #df['ticker'] = file
    raw_data_df.append(df)
master_df = pd.concat(raw_data_df)

# %%
len(master_df)
# Out:
# 1521

# %%
master_df
# Out:
#     Unnamed: 0  Calendar_Year Quarter   Mkt Cap  Debt to Equity  \
# 0   2022-06-25           2023      Q2  4,166.88            0.09
# 1   2022-03-26           2023      Q1  3,747.72            0.10
# 2   2021-12-25           2022      Q4  3,919.77            0.00
# 3   2021-09-25           2022      Q3  8,428.99            0.00
# 0   2022-06-25           2022      Q2 14,375.58            0.82
# ..         ...            ...     ...       ...             ...
# 68  2005-06-25           2006      Q2  2,568.33            0.01
# 69  2005-03-26           2006      Q1  1,518.34            0.01
# 70  2004-12-25           2005      Q4  1,441.53            0.00
# 71  2004-09-25           2005      Q3  2,220.71            0.02
# 72  2004-06-26           2005      Q2    839.46            0.01
#
#     Debt to Assets  Revenue per Share  NI per Share  outstandingShares  \
# 0             0.33               0.92         -0.35              94.10
# 1             0.32               0.83         -0.42              93.25
# 2             0.24               0.90         -0.55              78.36
# 3             0.68               0.71         -0.10              90.26
# 0             0.62               8.82         -1.18              47.81
# ..             ...                ...           ...                ...
# 68            0.48               0.17          0.01             471.90
# 69            0.48               0.15          0.01             465.47
# 70            0.48               0.13          0.01             465.47
# 71            0.44               0.11          0.01             464.70
# 72            0.41               0.16          0.00             431.00
#
#     Revenue  Gross Profit  R&D Expenses  G&A Expenses  \
# 0     86.13         58.78         23.34         20.54
# 1     77.50         51.59         21.62         23.57
# 2     70.43         45.66         22.90         19.62
# 3     63.97         44.79         12.74         12.94
# 0    421.75        342.82        118.91         51.90
# ..      ...           ...           ...           ...
# 68    71.94         55.71          5.47          0.00
# 69    64.18         52.21          4.30          0.00
# 70    54.59         44.59          3.16          0.00
# 71    46.36         37.46          2.46          0.00
# 72    40.58         32.40          2.07          0.00
#
#     Sales and Marketing Expenses  SG&A Expenses  Op Expenses  \
# 0                          50.01          70.55        93.89
# 1                          46.04          69.62        91.24
# 2                          45.73          65.34        88.25
# 3                          29.57          42.50        55.24
# 0                         224.26         276.16       395.07
# ..                           ...            ...          ...
# 68                          0.00          46.04        51.51
# 69                          0.00          43.92        47.94
# 70                          0.00          38.21        41.37
# 71                          0.00          33.22        35.68
# 72                          0.00          29.16        31.23
#
#     Cost and Expenses  Op Income  Interest Income  Interest Expense  \
# 0              121.24     -35.11             0.00              0.00
# 1              117.14     -39.65             0.00              0.00
# 2              113.02     -42.59             0.09              0.06
# 3               74.42     -10.45             0.00              0.00
# 0              474.00     -52.25             2.05              0.95
# ..                ...        ...              ...               ...
# 68              67.75       4.19             0.00              0.00
# 69              59.91       4.27             0.00              0.00
# 70              51.37       3.22             0.00              0.00
# 71              44.59       1.77             0.00              0.00
# 72              39.42       1.17             0.00              0.00
#
#     Net Income   EPS   Cash  Receivables  Inventory  Cur Assets  Tax Assets  \
# 0       -32.89 -0.35  80.88        52.93       0.00      580.90        0.00
# 1       -39.27 -0.42  90.61        42.66       0.00      598.76        0.00
# 2       -42.94 -0.55 478.94        64.50       0.00      608.18        0.00
# 3        -9.06 -0.10  41.98        36.03       0.00      130.60        0.00
# 0       -56.36 -1.18 305.66       165.95       0.00    1,531.78        0.00
# ..         ...   ...    ...          ...        ...         ...         ...
# 68        5.04  0.01  25.14        50.18       0.00      199.82        0.00
# 69        4.38  0.01  40.60        42.38       0.00      180.60        0.00
# 70        3.59  0.01  35.73        48.87       0.00      178.72        0.00
# 71        2.15  0.01  22.76        37.53       0.00      162.92        0.00
# 72        1.17  0.01  61.09        29.94       0.00      156.97        0.00
#
#     LT Assets  Int Assets  Total Assets  Payables  Deferred Revenue Current  \
# 0      121.19        0.00        702.09      2.89                    135.79
# 1      117.53        0.00        716.30      2.68                    139.44
# 2       58.08        0.00        666.26      2.08                    126.26
# 3       53.49        0.00        184.09      1.20                     98.43
# 0      742.18       69.00      2,273.96     11.82                    469.58
# ..        ...         ...           ...       ...                       ...
# 68     123.85        0.00        323.68      3.94                    117.31
# 69     114.03        0.00        294.63      3.63                    104.64
# 70     101.78        0.00        280.50      2.52                     95.90
# 71      83.78        0.00        246.70      3.84                     74.24
# 72      69.55        0.00        226.51      1.95                     61.56
#
#     Deferred Revenue LongTerm  Cur Liab  LT Debt  LT Liab  Total Liab  \
# 0                        0.00    184.31    44.39    44.89      229.20
# 1                        0.00    180.98    47.39    47.77      228.75
# 2                        0.00    159.97     0.00     1.48      161.44
# 3                        0.00    122.44     0.00     2.26      124.70
# 0                        4.51    662.16   717.47   740.33    1,402.49
# ..                        ...       ...      ...      ...         ...
# 68                       0.00    154.81     1.66     1.66      156.47
# 69                       0.00    138.22     1.81     1.82      140.03
# 70                       0.00    131.67     0.72     2.32      133.99
# 71                       0.00    105.81     2.50     2.50      108.32
# 72                       0.00     89.68     1.00     2.69       92.37
#
#     SH Equity  cash_flow Operations  cash_flow Investing  cash_flow Financing  \
# 0      470.55                -16.32                 4.00                 2.78
# 1      484.67                 17.92              -407.80                 2.63
# 2      501.58                -24.53                -1.75               463.31
# 3     -118.49                 -2.45                 0.90                 2.02
# 0      871.47                 40.92              -120.98               -14.89
# ..        ...                   ...                  ...                  ...
# 68     165.40                 14.07               -34.91                 5.09
# 69     153.00                 17.91               -15.77                 2.73
# 70     145.13                 21.13               -11.23                 3.46
# 71     137.35                 13.15               -51.77                 0.11
# 72     133.19                 14.94               -73.08               113.74
#
#     CAPEX    FCF  Dividends Paid  Gross Profit Margin  Op Margin  \
# 0   -8.36 -24.68            0.00                 0.68      -0.41
# 1   -2.27  15.65            0.00                 0.67      -0.51
# 2   -1.42 -25.95            0.00                 0.65      -0.60
# 3   -1.02  -3.48            0.00                 0.70      -0.16
# 0  -28.54  12.38            0.00                 0.81      -0.12
# ..    ...    ...             ...                  ...        ...
# 68  -3.37  10.70            0.00                 0.77       0.06
# 69  -9.16   8.75            0.00                 0.81       0.07
# 70  -2.27  18.86            0.00                 0.82       0.06
# 71  -1.28  11.87            0.00                 0.81       0.04
# 72  -0.48  14.45            0.00                 0.80       0.03
#
#     Int Coverage  Net Profit Margin  Dividend Yield  Current Ratio  \
# 0            NaN              -0.38             NaN           3.15
# 1            NaN              -0.51             NaN           3.31
# 2        -760.50              -0.61             NaN           3.80
# 3            NaN              -0.14             NaN           1.07
# 0         -55.06              -0.13             NaN           2.31
# ..           ...                ...             ...            ...
# 68           NaN               0.07             NaN           1.29
# 69           NaN               0.07             NaN           1.31
# 70           NaN               0.07             NaN           1.36
# 71           NaN               0.05             NaN           1.54
# 72           NaN               0.03             NaN           1.75
#
#     Operating Cycle  Days of AP Outstanding  Cash Conversion Cycle   ROA  \
# 0             55.31                    9.51                  45.80 -0.05
# 1             49.55                    9.31                  40.24 -0.05
# 2             82.42                    7.57                  74.86 -0.06
# 3             50.69                    5.65                  45.04 -0.05
# 0             35.41                   13.48                  21.93 -0.02
# ..              ...                     ...                    ...   ...
# 68            62.78                   21.84                  40.94  0.02
# 69            59.44                   27.34                  32.09  0.01
# 70            80.57                   22.72                  57.85  0.01
# 71            72.87                   38.85                  34.02  0.01
# 72            66.41                   21.42                  44.99  0.01
#
#      ROE  ROCE      PE     PS     PB  Price To FCF       PEG Ticker
# 0  -0.07 -0.07  -31.68  48.38   8.86       -168.82     -1.90   BRZE
# 1  -0.08 -0.07  -23.86  48.36   7.73        239.39     -1.01   BRZE
# 2  -0.09 -0.08  -22.82  55.65   7.81       -151.03      0.05   BRZE
# 3   0.08 -0.17 -232.64 131.77 -71.14     -2,422.82   -225.13   BRZE
# 0  -0.06 -0.03  -63.77  34.09  16.50      1,161.29      0.13   HUBS
# ..   ...   ...     ...    ...    ...           ...       ...    ...
# 68  0.03  0.02  127.40  35.70  15.53        240.03      5.10    CRM
# 69  0.03  0.03   86.66  23.66   9.92        173.46      4.91    CRM
# 70  0.02  0.02  100.50  26.40   9.93         76.42      1.44    CRM
# 71  0.02  0.01  257.86  47.90  16.17        187.10 15,079.36    CRM
# 72  0.01  0.01  179.37  20.69   6.30         58.09      1.79    CRM
#
# [1521 rows x 62 columns]

# %%
twlo_df_ = master_df[master_df['Ticker']=='TWLO']
twlo_df = twlo_df_.copy()
twlo_df['R&D % of Rev'] = twlo_df['R&D Expenses']/twlo_df['Revenue']*100
twlo_df['G&A % of Rev'] = twlo_df['G&A Expenses']/twlo_df['Revenue']*100
twlo_df['Sales and Marketing % of Rev'] = twlo_df['Sales and Marketing Expenses']/twlo_df['Revenue']*100
twlo_df['SG&A % of Rev'] = twlo_df['SG&A Expenses']/twlo_df['Revenue']*100
twlo_df['OpEx % of Rev'] = twlo_df['Op Expenses']/twlo_df['Revenue']*100
twlo_df['OpEx & Costs % of Rev'] = twlo_df['Cost and Expenses']/twlo_df['Revenue']*100

# %%
twlo_df
# Out:
#     Unnamed: 0  Calendar_Year Quarter   Mkt Cap  Debt to Equity  \
# 0   2022-06-25           2022      Q2 15,282.57            0.11
# 1   2022-03-26           2022      Q1 29,813.92            0.11
# 2   2021-12-25           2021      Q4 47,120.66            0.11
# 3   2021-09-25           2021      Q3 56,545.64            0.11
# 4   2021-06-26           2021      Q2 68,350.18            0.11
# 5   2021-03-27           2021      Q1 56,961.60            0.14
# 6   2020-12-26           2020      Q4 53,612.53            0.07
# 7   2020-09-26           2020      Q3 36,446.04            0.08
# 8   2020-06-27           2020      Q2 31,073.94            0.11
# 9   2020-03-28           2020      Q1 12,459.84            0.11
# 10  2019-12-28           2019      Q4 13,535.96            0.11
# 11  2019-09-28           2019      Q3 14,998.63            0.11
# 12  2019-06-29           2019      Q2 17,697.45            0.10
# 13  2019-03-30           2019      Q1 14,885.11            0.13
# 14  2018-12-29           2018      Q4  8,878.02            0.99
# 15  2018-09-29           2018      Q3  8,209.14            0.99
# 16  2018-06-30           2018      Q2  5,397.43            0.98
# 17  2018-03-31           2018      Q1  3,469.79            0.00
# 18  2017-12-30           2017      Q4  2,340.50            0.00
# 19  2017-09-30           2017      Q3  2,750.88            0.00
# 20  2017-07-01           2017      Q2  2,645.32            0.00
# 21  2017-04-01           2017      Q1  2,558.25            0.00
# 22  2016-12-31           2016      Q4  2,556.48            0.00
# 23  2016-09-24           2016      Q3  5,399.03            0.00
# 24  2016-06-25           2016      Q2    885.56            0.00
#
#     Debt to Assets  Revenue per Share  NI per Share  outstandingShares  \
# 0             0.16               5.17         -1.77             182.35
# 1             0.15               4.84         -1.23             180.90
# 2             0.15               4.71         -1.63             178.93
# 3             0.15               4.18         -1.26             177.23
# 4             0.15               3.86         -1.31             173.41
# 5             0.16               3.53         -1.24             167.16
# 6             0.11               3.46         -1.13             158.38
# 7             0.14               3.04         -0.79             147.50
# 8             0.18               2.83         -0.71             141.62
# 9             0.18               2.62         -0.68             139.23
# 10            0.17               2.40         -0.66             137.73
# 11            0.16               2.16         -0.64             136.40
# 12            0.16               2.13         -0.72             129.31
# 13            0.19               2.00         -0.31             116.59
# 14            0.57               2.05         -0.47              99.42
# 15            0.57               1.72         -0.28              98.02
# 16            0.56               1.53         -0.25              96.35
# 17            0.25               1.36         -0.25              94.67
# 18            0.20               1.24         -0.20              93.25
# 19            0.20               1.09         -0.25              92.16
# 20            0.18               1.05         -0.08              90.87
# 21            0.21               0.99         -0.16              88.61
# 22            0.20               0.92         -0.14              88.61
# 23            0.22               0.85         -0.13              83.89
# 24            0.21               2.66         -0.45              24.26
#
#     Revenue  Gross Profit  R&D Expenses  G&A Expenses  \
# 0    943.35        445.29        279.64        142.63
# 1    875.36        425.07        240.61        114.36
# 2    842.74        396.55        223.25        125.50
# 3    740.18        364.62        209.89        122.52
# 4    668.93        331.25        181.28        114.18
# 5    589.99        298.30        174.80        110.25
# 6    548.09        282.12        158.86        128.57
# 7    447.97        230.87        136.65         65.62
# 8    400.85        209.13        120.70         61.25
# 9    364.87        193.53        114.34         55.17
# 10   331.22        174.69        110.24         51.86
# 11   295.07        158.16        104.48         47.69
# 12   275.04        150.01         98.78         54.54
# 13   233.14        126.05         77.86         64.18
# 14   204.30        108.01         51.63         34.21
# 15   168.90         91.86         42.34         28.61
# 16   147.75         79.81         39.81         24.21
# 17   129.12         69.53         37.58         23.39
# 18   115.24         60.21         32.83         18.81
# 19   100.54         52.29         31.67         18.87
# 20    95.87         53.54         29.71          4.74
# 21    87.37         50.09         26.52         17.20
# 22    81.95         47.75         24.59         14.30
# 23    71.53         40.25         21.11         14.54
# 24    64.51         36.31         17.37         11.63
#
#     Sales and Marketing Expenses  SG&A Expenses  Op Expenses  \
# 0                         334.96         477.58       757.23
# 1                         287.91         402.27       642.88
# 2                         331.42         456.92       680.17
# 3                         264.55         387.07       596.96
# 4                         238.06         352.24       533.52
# 5                         210.59         320.84       495.64
# 6                         179.99         308.56       467.41
# 7                         140.88         206.49       343.14
# 8                         129.82         191.07       311.77
# 9                         116.72         171.89       286.23
# 10                        106.39         158.25       268.49
# 11                        100.66         148.35       252.83
# 12                         90.42         144.96       243.75
# 13                         71.61         135.78       213.64
# 14                         59.03          93.25       144.88
# 15                         45.95          74.56       116.90
# 16                         37.75          61.96       101.77
# 17                         32.82          56.22        93.79
# 18                         27.62          46.43        79.26
# 19                         25.78          44.65        76.32
# 20                         26.15          30.89        60.61
# 21                         21.12          38.32        64.84
# 22                         17.82          32.12        56.71
# 23                         15.87          30.42        51.52
# 24                         18.16          29.79        47.16
#
#     Cost and Expenses  Op Income  Interest Income  Interest Expense  \
# 0            1,255.29    -311.94             0.00              0.00
# 1            1,093.17    -217.81             0.00              0.00
# 2            1,126.37    -283.63             0.00              0.00
# 3              972.52    -232.34             0.00              0.00
# 4              871.21    -202.27             0.00              0.00
# 5              787.33    -197.34             0.00              0.00
# 6              733.38    -185.29             0.00              0.00
# 7              560.24    -112.27             0.00              0.00
# 8              503.49    -102.64             0.00              0.00
# 9              457.56     -92.70             0.00              0.00
# 10             425.02     -93.80             0.00              0.00
# 11             389.73     -94.67             0.00              0.00
# 12             368.77     -93.73             0.00              0.00
# 13             320.73     -87.59             0.00              0.00
# 14             241.17     -43.99             0.00              0.00
# 15             193.93     -25.03             0.00              0.00
# 16             169.71     -21.96             0.00              0.00
# 17             153.37     -24.26             0.00              0.00
# 18             134.28     -20.22             0.00              0.00
# 19             124.57     -24.03             0.00              0.00
# 20             102.94      -7.07             0.00              0.00
# 21             102.13     -14.76             0.00              0.00
# 22              90.91     -12.82             0.00              0.00
# 23              82.81     -11.28             0.00              0.00
# 24              75.36     -10.85             0.00              0.00
#
#     Net Income   EPS     Cash  Receivables  Inventory  Cur Assets  Tax Assets  \
# 0      -322.77 -1.77   798.62       471.92       0.00    5,104.39        0.00
# 1      -221.63 -1.23 1,617.02       406.74       0.00    5,831.19        0.00
# 2      -291.40 -1.63 1,479.45       388.21       0.00    5,932.23        0.00
# 3      -224.11 -1.26 1,497.50       345.79       0.00    5,905.81        0.00
# 4      -227.85 -1.31 1,799.60       301.55       0.00    6,373.69        0.00
# 5      -206.54 -1.24 2,331.77       257.85       0.00    6,093.98        0.00
# 6      -179.35 -1.13   933.88       251.17       0.00    3,372.34        0.00
# 7      -116.91 -0.79 1,127.10       203.84       0.00    3,569.02        0.00
# 8       -99.92 -0.71   475.70       194.56       0.00    2,160.68        0.00
# 9       -94.79 -0.68   345.52       172.87       0.00    2,077.66        0.00
# 10      -90.25 -0.66   253.66       154.07       0.00    2,061.33        0.00
# 11      -87.73 -0.64   330.60       131.19       0.00    2,068.42        0.00
# 12      -92.58 -0.72   535.91       126.78       0.00    2,059.51        0.00
# 13      -36.50 -0.31   377.73       105.15       0.00    1,063.13        0.00
# 14      -47.16 -0.47   487.21        97.71       0.00      872.95        0.00
# 15      -27.06 -0.28   469.13        80.16       0.00      850.75        0.00
# 16      -24.01 -0.25   493.51        67.57       0.00      884.03        0.00
# 17      -23.73 -0.25   117.74        57.31       0.00      382.11        0.00
# 18      -18.92 -0.20   115.29        43.11       0.00      353.26        0.00
# 19      -23.45 -0.25    91.91        37.26       0.00      347.62        0.00
# 20       -7.11 -0.08    92.18        37.32       0.00      345.64        0.00
# 21      -14.23 -0.16   118.44        29.96       0.00      341.71        0.00
# 22      -12.61 -0.14   305.67        26.20       0.00      353.38        0.00
# 23      -11.25 -0.13   252.22        29.35       0.00      299.84        0.00
# 24      -10.99 -0.45   261.39        22.98       0.00      301.17        0.00
#
#     LT Assets  Int Assets  Total Assets  Payables  Deferred Revenue Current  \
# 0    7,764.84      953.52     12,869.23    102.04                    137.73
# 1    7,059.61    1,006.69     12,890.80     93.39                    139.67
# 2    7,066.37    1,050.01     12,998.60     93.33                    140.39
# 3    7,071.04    1,102.60     12,976.85     76.29                    121.34
# 4    6,159.90      913.31     12,533.58    106.00                     98.72
# 5    6,148.21      951.88     12,242.18     66.51                     93.52
# 6    6,115.10      966.57      9,487.43     60.04                     87.03
# 7    3,154.68      404.42      6,723.70     39.88                     33.92
# 8    3,129.89      424.74      5,290.57     27.53                     29.11
# 9    3,088.61      445.15      5,166.27     18.45                     26.71
# 10   3,089.18      460.85      5,150.52     39.10                     26.36
# 11   3,041.74      465.25      5,110.17     25.95                     26.02
# 12   3,049.59      485.41      5,109.10     29.36                     24.90
# 13   3,056.95      503.95      4,120.07     22.42                     23.35
# 14     155.76       27.56      1,028.71     18.50                     19.56
# 15     153.05       29.78      1,003.80     12.84                     18.69
# 16     101.82       17.11        985.85     23.77                     16.90
# 17     100.69       18.98        482.80     17.92                     14.79
# 18      96.52       20.06        449.78     11.12                     13.80
# 19      95.93       21.27        443.55      7.12                     13.60
# 20      92.30       22.32        437.95      4.27                     12.58
# 21      88.05       22.76        429.77      6.23                     11.11
# 22      59.31       10.27        412.69      4.17                     10.22
# 23      40.72        2.56        340.57      6.22                      9.49
# 24      35.38        2.60        336.55      8.72                      8.71
#
#     Deferred Revenue LongTerm  Cur Liab  LT Debt  LT Liab  Total Liab  \
# 0                        0.00    795.32 1,194.62 1,231.91    2,027.23
# 1                        0.00    719.82 1,209.65 1,253.55    1,973.37
# 2                        0.00    703.55 1,222.29 1,263.58    1,967.13
# 3                        0.00    617.07 1,228.83 1,278.03    1,895.10
# 4                        0.00    583.28 1,209.02 1,256.19    1,839.47
# 5                        0.00    499.92 1,452.44 1,495.06    1,994.98
# 6                        0.00    448.31   549.83   586.46    1,034.77
# 7                        0.00    326.35   432.70   635.09      961.43
# 8                        0.00    296.37   470.55   672.61      968.98
# 9                        0.00    277.04   464.37   632.70      909.74
# 10                       0.00    247.22   458.19   623.88      871.11
# 11                       0.00    216.23   452.18   609.45      825.68
# 12                       0.00    201.78   448.41   610.46      812.25
# 13                       0.00    182.34   443.11   610.22      792.56
# 14                       0.00    137.81   434.50   452.67      590.48
# 15                       0.00    125.43   428.78   444.02      569.44
# 16                       0.00    122.83   423.10   433.34      556.18
# 17                       0.00    109.30     0.00    10.95      120.25
# 18                       0.00     78.53     0.00    11.41       89.94
# 19                       0.00     76.00     0.00    12.55       88.55
# 20                       0.00     67.40     0.00    12.44       79.84
# 21                       0.00     79.60     0.00    12.31       91.91
# 22                       0.00     73.70     0.00     9.54       83.25
# 23                       0.00     66.25     0.00    10.04       76.29
# 24                       0.00     59.57     0.00     9.75       69.32
#
#     SH Equity  cash_flow Operations  cash_flow Investing  cash_flow Financing  \
# 0   10,842.00                -62.57              -786.60                30.30
# 1   10,917.43                -17.57               150.97                 4.11
# 2   11,031.47                -38.24               -38.26                57.02
# 3   11,081.75                -46.17              -270.25                14.44
# 4   10,694.11                 21.72              -815.47               265.41
# 5   10,247.20                  4.50            -1,366.02             2,759.45
# 6    8,452.67                 14.90              -224.91                16.75
# 7    5,762.27                  3.84              -765.71             1,413.27
# 8    4,321.59                 -1.62                73.12                58.69
# 9    4,256.52                 15.54                71.64                 4.60
# 10   4,279.41                 12.02              -103.08                14.12
# 11   4,284.49                 15.84              -220.85                -1.09
# 12   4,296.86                 -4.71              -831.66               994.31
# 13   3,327.51                 -9.11              -130.20                12.81
# 14     438.24                 -4.85                 8.98                11.83
# 15     434.35                 -6.39               -10.29                 7.69
# 16     429.67                  2.29              -117.18               489.99
# 17     362.54                 16.94               -20.94                 6.31
# 18     359.85                  3.79                12.16                 7.43
# 19     355.00                 -3.00                -1.50                 4.18
# 20     358.11                 -6.49               -32.27                12.47
# 21     337.86                  2.44              -202.02                12.34
# 22     329.45                  5.67               -20.61                68.38
# 23     264.27                 -0.69                -6.73                -1.74
# 24     267.23                 -0.91                -4.23               163.20
#
#     CAPEX    FCF  Dividends Paid  Gross Profit Margin  Op Margin  \
# 0  -15.91 -78.48            0.00                 0.47      -0.33
# 1  -17.23 -34.80            0.00                 0.49      -0.25
# 2  -20.52 -58.76            0.00                 0.47      -0.34
# 3  -35.52 -81.69            0.00                 0.49      -0.31
# 4  -18.56   3.16            0.00                 0.50      -0.30
# 5  -15.42 -10.91            0.00                 0.51      -0.33
# 6  -13.77   1.13            0.00                 0.51      -0.34
# 7  -14.92 -11.08            0.00                 0.52      -0.25
# 8  -15.50 -17.13            0.00                 0.52      -0.26
# 9  -14.95   0.59            0.00                 0.53      -0.25
# 10 -31.49 -19.46            0.00                 0.53      -0.28
# 11 -17.40  -1.56            0.00                 0.54      -0.32
# 12 -10.40 -15.10            0.00                 0.55      -0.34
# 13  -8.00 -17.12            0.00                 0.54      -0.38
# 14  -5.95 -10.80            0.00                 0.53      -0.22
# 15  -6.43 -12.82            0.00                 0.54      -0.15
# 16  -6.43  -4.14            0.00                 0.54      -0.15
# 17  -5.85  11.09            0.00                 0.54      -0.19
# 18  -5.72  -1.92            0.00                 0.52      -0.18
# 19  -6.17  -9.18            0.00                 0.52      -0.24
# 20  -6.30 -12.79            0.00                 0.56      -0.07
# 21  -8.63  -6.19            0.00                 0.57      -0.17
# 22 -12.11  -6.44            0.00                 0.58      -0.16
# 23  -6.73  -7.42            0.00                 0.56      -0.16
# 24  -4.23  -5.13            0.00                 0.56      -0.17
#
#     Int Coverage  Net Profit Margin  Dividend Yield  Current Ratio  \
# 0            NaN              -0.34             NaN           6.42
# 1            NaN              -0.25             NaN           8.10
# 2            NaN              -0.35             NaN           8.43
# 3            NaN              -0.30             NaN           9.57
# 4            NaN              -0.34             NaN          10.93
# 5            NaN              -0.35             NaN          12.19
# 6            NaN              -0.33             NaN           7.52
# 7            NaN              -0.26             NaN          10.94
# 8            NaN              -0.25             NaN           7.29
# 9            NaN              -0.26             NaN           7.50
# 10           NaN              -0.27             NaN           8.34
# 11           NaN              -0.30             NaN           9.57
# 12           NaN              -0.34             NaN          10.21
# 13           NaN              -0.16             NaN           5.83
# 14           NaN              -0.23             NaN           6.33
# 15           NaN              -0.16             NaN           6.78
# 16           NaN              -0.16             NaN           7.20
# 17           NaN              -0.18             NaN           3.50
# 18           NaN              -0.16             NaN           4.50
# 19           NaN              -0.23             NaN           4.57
# 20           NaN              -0.07             NaN           5.13
# 21           NaN              -0.16             NaN           4.29
# 22           NaN              -0.15             NaN           4.79
# 23           NaN              -0.16             NaN           4.53
# 24           NaN              -0.17             NaN           5.06
#
#     Operating Cycle  Days of AP Outstanding  Cash Conversion Cycle   ROA  \
# 0             45.02                   18.44                  26.58 -0.03
# 1             41.82                   18.67                  23.15 -0.02
# 2             41.46                   18.83                  22.63 -0.02
# 3             42.05                   18.28                  23.76 -0.02
# 4             40.57                   28.25                  12.32 -0.02
# 5             39.33                   20.52                  18.81 -0.02
# 6             41.24                   20.32                  20.93 -0.02
# 7             40.95                   16.53                  24.42 -0.02
# 8             43.68                   12.92                  30.76 -0.02
# 9             42.64                    9.69                  32.95 -0.02
# 10            41.86                   22.48                  19.38 -0.02
# 11            40.02                   17.06                  22.96 -0.02
# 12            41.49                   21.14                  20.35 -0.02
# 13            40.59                   18.84                  21.75 -0.01
# 14            43.04                   17.29                  25.76 -0.05
# 15            42.71                   15.00                  27.71 -0.03
# 16            41.16                   31.48                   9.68 -0.02
# 17            39.95                   27.07                  12.87 -0.05
# 18            33.67                   18.18                  15.49 -0.04
# 19            33.35                   13.27                  20.08 -0.05
# 20            35.04                    9.07                  25.96 -0.02
# 21            30.86                   15.05                  15.82 -0.03
# 22            28.78                   10.98                  17.79 -0.03
# 23            36.93                   17.88                  19.04 -0.03
# 24            32.06                   27.83                   4.23 -0.03
#
#      ROE  ROCE      PE     PS    PB  Price To FCF    PEG Ticker  R&D % of Rev  \
# 0  -0.03 -0.03  -11.84  16.20  1.41       -194.74   0.27   TWLO         29.64
# 1  -0.02 -0.02  -33.63  34.06  2.73       -856.60  -1.37   TWLO         27.49
# 2  -0.03 -0.02  -40.43  55.91  4.27       -801.88   1.38   TWLO         26.49
# 3  -0.02 -0.02  -63.08  76.39  5.10       -692.17 -16.53   TWLO         28.36
# 4  -0.02 -0.02  -74.99 102.18  6.39     21,643.50  13.28   TWLO         27.10
# 5  -0.02 -0.02  -68.95  96.55  5.56     -5,218.65   7.08   TWLO         29.63
# 6  -0.02 -0.02  -74.73  97.82  6.34     47,277.37   1.74   TWLO         28.98
# 7  -0.02 -0.02  -77.93  81.36  6.32     -3,290.54   6.92   TWLO         30.50
# 8  -0.02 -0.02  -77.74  77.52  7.19     -1,814.32  17.62   TWLO         30.11
# 9  -0.02 -0.02  -32.86  34.15  2.93     21,118.36  10.84   TWLO         31.34
# 10 -0.02 -0.02  -37.50  40.87  3.16       -695.47  12.00   TWLO         33.28
# 11 -0.02 -0.02  -42.74  50.83  3.50     -9,626.85  -3.85   TWLO         35.41
# 12 -0.02 -0.02  -47.79  64.35  4.12     -1,171.71   0.36   TWLO         35.92
# 13 -0.01 -0.02 -101.94  63.85  4.47       -869.61  -2.99   TWLO         33.39
# 14 -0.11 -0.05  -47.07  43.46 20.26       -821.96   0.69   TWLO         25.27
# 15 -0.06 -0.03  -75.85  48.61 18.90       -640.19   6.32   TWLO         25.07
# 16 -0.06 -0.03  -56.21  36.53 12.56     -1,304.67  97.74   TWLO         26.94
# 17 -0.07 -0.06  -36.56  26.87  9.57        312.90   1.46   TWLO         29.10
# 18 -0.05 -0.05  -30.93  20.31  6.50     -1,216.48  -1.55   TWLO         28.49
# 19 -0.07 -0.07  -29.32  27.36  7.75       -299.69   0.14   TWLO         31.50
# 20 -0.02 -0.02  -93.03  27.59  7.39       -206.88  -1.86   TWLO         30.99
# 21 -0.04 -0.04  -44.95  29.28  7.57       -413.42   3.61   TWLO         30.36
# 22 -0.04 -0.04  -50.69  31.19  7.76       -397.03   5.37   TWLO         30.00
# 23 -0.04 -0.04 -119.94  75.48 20.43       -727.24  -1.69   TWLO         29.51
# 24 -0.04 -0.04  -20.14  13.73  3.31       -172.46   0.05   TWLO         26.92
#
#     G&A % of Rev  Sales and Marketing % of Rev  SG&A % of Rev  OpEx % of Rev  \
# 0          15.12                         35.51          50.63          80.27
# 1          13.06                         32.89          45.95          73.44
# 2          14.89                         39.33          54.22          80.71
# 3          16.55                         35.74          52.29          80.65
# 4          17.07                         35.59          52.66          79.76
# 5          18.69                         35.69          54.38          84.01
# 6          23.46                         32.84          56.30          85.28
# 7          14.65                         31.45          46.10          76.60
# 8          15.28                         32.39          47.67          77.78
# 9          15.12                         31.99          47.11          78.45
# 10         15.66                         32.12          47.78          81.06
# 11         16.16                         34.11          50.28          85.69
# 12         19.83                         32.88          52.71          88.62
# 13         27.53                         30.71          58.24          91.64
# 14         16.75                         28.90          45.64          70.91
# 15         16.94                         27.21          44.14          69.21
# 16         16.39                         25.55          41.94          68.88
# 17         18.12                         25.42          43.54          72.64
# 18         16.32                         23.97          40.29          68.78
# 19         18.77                         25.64          44.40          75.91
# 20          4.94                         27.28          32.22          63.22
# 21         19.69                         24.17          43.86          74.21
# 22         17.45                         21.74          39.19          69.20
# 23         20.33                         22.19          42.52          72.03
# 24         18.04                         28.14          46.18          73.10
#
#     OpEx & Costs % of Rev
# 0                  133.07
# 1                  124.88
# 2                  133.66
# 3                  131.39
# 4                  130.24
# 5                  133.45
# 6                  133.81
# 7                  125.06
# 8                  125.61
# 9                  125.41
# 10                 128.32
# 11                 132.08
# 12                 134.08
# 13                 137.57
# 14                 118.04
# 15                 114.82
# 16                 114.86
# 17                 118.79
# 18                 116.53
# 19                 123.90
# 20                 107.37
# 21                 116.89
# 22                 110.93
# 23                 115.76
# 24                 116.82

# %%
'https://towardsdatascience.com/stacked-bar-charts-with-pythons-matplotlib-f4020e4eb4a7'
# Out:
# 'https://towardsdatascience.com/stacked-bar-charts-with-pythons-matplotlib-f4020e4eb4a7'

# %%
from bokeh.plotting import figure, show

quarters = ['Q1', 'Q2', 'Q3', 'Q4']
years = ["2017", "2018", "2019", "2020", "2021"]
colors = ["#c9d9d3", "#718dbf", "#e84d60"]

data = {'quarters' : quarters,
        '2017'   : [2, 1, 4, 3, 2, 4],
        '2018'   : [5, 3, 4, 2, 4, 6],
        '2019'   : [3, 2, 4, 4, 5, 3],
        '2020'   : [],
        '2021'   : []}

p = figure(x_range=fruits, height=250, title="Fruit Counts by Year",
           toolbar_location=None, tools="hover", tooltips="$name @fruits: @$name")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=data,
             legend_label=years)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)

# %%
data
# Out:
# {'fruits': ['Apples',
#   'Pears',
#   'Nectarines',
#   'Plums',
#   'Grapes',
#   'Strawberries'],
#  '2015': [2, 1, 4, 3, 2, 4],
#  '2016': [5, 3, 4, 2, 4, 6],
#  '2017': [3, 2, 4, 4, 5, 3]}
