# %%
from selenium import webdriver
import pandas as pd
import glob 
import os
import requests
from bs4 import BeautifulSoup as bs
import requests
import urllib.parse
from sqlalchemy import create_engine

# %%
#driver = webdriver.Chrome('/Users/brendan/Desktop/Python/Selenium/chromedriver4')

# %%
#driver.get('https://bme3412.github.io/')

# %%
#driver.find_element_by_xpath('/html/body/div/figure[1]/figcaption').text

# %%
#driver.get('https://web.archive.org/web/20220000000000*/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682')
#input_ = driver.find_element_by_xpath('/html/body/div[4]/div[4]/div[3]/div/div[2]/ul/div/div/li[1]/a')
#input_.click()
#input_.send_keys("0.5")

# %%
import requests
import urllib.parse

site = 'https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682'
year = 2022

safe_site = urllib.parse.quote_plus(site)

url = f'https://web.archive.org/__wb/calendarcaptures/2?url={safe_site}&date={year}&groupby=day'

resp = requests.get(url).json()

complete = []
for item in resp['items']:
    if len(str(item[0])) == 4:
        day = str(item[0])[-2:]
        month = str(item[0])[:2]
    else:
        day = str(item[0])[-2:]
        month = str(item[0])[:1].zfill(2)

    day_url = f'https://web.archive.org/__wb/calendarcaptures/2?url={safe_site}&date={year}{month}{day}'

    time_data = requests.get(day_url).json()
    print(f'Finished {day_url}')

    for t in time_data['items']:
        time_str = str(t[0]).zfill(6)

        final_url = f'https://web.archive.org/web/{year}{month}{day}{time_str}/{site}'

        complete.append(final_url)
# Out:
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220101
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220102
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220103
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220104
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220105
# Finished https://web.archive.org/__wb/calendarcaptures/2?url=https%3A%2F%2Fwww.ebay.com%2Fb%2FApple-Cell-Phones-Smartphones%2F9355%2Fbn_319682&date=20220106
# ...

# %%
complete
# Out:
# ['https://web.archive.org/web/20220101154045/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220101180055/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220101210614/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220102163445/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220102190319/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220102220335/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220103044117/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220103174121/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
# ...

# %%
type(complete)
complete = complete[:2]
complete
# Out:
# ['https://web.archive.org/web/20220101154045/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682',
#  'https://web.archive.org/web/20220101180055/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682']

# %%
for i in complete:
    page_ = requests.get(i)
    soup_ = bs(page_.content, "lxml")
    print(soup_)
complete[0]
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9" lang="en"><![endif]--><!--[if gt IE 9]><!--><html lang="en"><!--<![endif]--><head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>
# <script type="text/javascript">window.addEventListener('DOMContentLoaded',function(){var v=archive_analytics.values;v.service='wb';v.server_name='wwwb-app226.us.archive.org';v.server_ms=351;archive_analytics.send_pageview({});});</script>
# <script charset="utf-8" src="/_static/js/bundle-playback.js?v=KTqwAcYd" type="text/javascript"></script>
# <script charset="utf-8" src="/_static/js/wombat.js?v=UHAOicsW" type="text/javascript"></script>
# <script type="text/javascript">
#   __wm.init("https://web.archive.org/web");
#   __wm.wombat("https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682","20220101154045","https://web.archive.org/","web","/_static/",
# 	      "1641051645");
# </script>
# ...

# %%
complete[0]
# Out:
# 'https://web.archive.org/web/20220101154045/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682'

# %%
html = complete[0]
page = requests.get(html)
soup = bs(page.content, "lxml")

# %%
company = [] # fill in manual
category = []
category_id = []
bn_id = []
link = []
count = []

data = soup.find_all('div', attrs ={'class','dialog__cell'})[0]
for li in data:
    listings = data.find_all('li')
    #print(listings)
    for l in listings:
        category.append(l.string)
        links = l.find_all('a')
        for a in links:
            link.append(a['href'])
            bn_id_str = str(link)
            bn_id_ = bn_id_str.rsplit('/', 1)[-1]
            bn_id.extend([bn_id_])
            category_id_str = str(a['href'])
            #print(category_id_str)
            category_id_ = category_id_str.rsplit('/',maxsplit=2)[-2]
            #cat_ids = [val[-1] for val in category_id_str.rsplit(maxsplit=5)]
            category_id.append(category_id_)

 
        

category = category[:198]
            
len(category), len(bn_id), len(link), len(bn_id)
# Out:
# (198, 198, 198, 198)

# %%
df = pd.DataFrame({'Category':category,'Category_id': category_id,'bn_id':bn_id,'Link':link})
df['bn_id'] = df['bn_id'].str.replace("']","")
df_AAPL = df[df["bn_id"].str.contains("i.html")==False]
df_AAPL.head(5)
# Out:
# <ipython-input-15-d00e1c08ad02>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['bn_id'] = df['bn_id'].str.replace("']","")
#                     Category Category_id        bn_id  \
# 0  Cell Phones & Accessories       15032   bn_1865441
# 1  Cell Phones & Smartphones      178893    bn_152365
# 2              Smart Watches      182064  bn_16565905
# 3    Smart Watch Accessories        9394    bn_320095
# 4     Cell Phone Accessories      136699    bn_317614
#
#                                                 Link
# 0  https://web.archive.org/web/20220101154045/htt...
# 1  https://web.archive.org/web/20220101154045/htt...
# 2  https://web.archive.org/web/20220101154045/htt...
# 3  https://web.archive.org/web/20220101154045/htt...
# 4  https://web.archive.org/web/20220101154045/htt...

# %%
df = pd.DataFrame({'Category':category,'Category_id': category_id,'bn_id':bn_id,'Link':link})
df['bn_id'] = df['bn_id'].str.replace("']","")
df_AAPL = df[df["bn_id"].str.contains("i.html")==False]
df_AAPL.head(5)
# Out:
# <ipython-input-16-d00e1c08ad02>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['bn_id'] = df['bn_id'].str.replace("']","")
#                     Category Category_id        bn_id  \
# 0  Cell Phones & Accessories       15032   bn_1865441
# 1  Cell Phones & Smartphones      178893    bn_152365
# 2              Smart Watches      182064  bn_16565905
# 3    Smart Watch Accessories        9394    bn_320095
# 4     Cell Phone Accessories      136699    bn_317614
#
#                                                 Link
# 0  https://web.archive.org/web/20220101154045/htt...
# 1  https://web.archive.org/web/20220101154045/htt...
# 2  https://web.archive.org/web/20220101154045/htt...
# 3  https://web.archive.org/web/20220101154045/htt...
# 4  https://web.archive.org/web/20220101154045/htt...

# %%
product_title = []
prices = []

def get_prices(category):
    #category_id = df_AAPL_.loc[df_AAPL_.Category == category, 'Category_id'].iloc[0] 
    #bn_id = df_AAPL_.loc[df_AAPL_.Category == category, 'bn_id'].iloc[0]
    url = 'https://web.archive.org/web/20211215183409/https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682?rt=nc&LH_BIN=1'
    buy_it_now = '?rt=nc&LH_BIN=1'
    url_sold = url+buy_it_now 
    page = requests.get(url)
    soup = bs(page.content, "lxml")
    items = soup.find_all('li', class_='s-item s-item--large s-item--bgcolored')
    #print(items)
    for item in items:
        title_all = soup.find_all('h3', class_='s-item__title')
        for title in title_all:
            product_title.append(title.text)
        price_all = soup.find_all('span', class_="s-item__price")
        for price in price_all:
            prices.append(price.text)
    return product_title, prices

# %%
x = get_prices('Apple Cell Phones & Smartphones')
df_phones = pd.DataFrame({'Product_Title':product_title,'Prices':prices, 'Date':'20211215'})
df_phones
# Out:
#                                           Product_Title              Prices  \
# 0     Apple iphone 7/7 plus 32GB/128GB Black Gold Un...  $110.00 to $276.00
# 1     Apple iPhone 11 - 128GB - All Colors - Fully U...  $449.99 to $458.99
# 2     Apple iPhone X 64GB/256GB Gray Silver Unlocked...  $254.00 to $366.00
# 3     Apple iPhone SE 2020 - 64GB - Factory Unlocked...             $249.99
# 4     Apple iPhone 11 64GB Factory Unlocked 4G LTE S...             $399.99
# ...                                                 ...                 ...
# 2299  Apple iPhone XR 64GB 128GB 256GB Factory Unloc...             $314.99
# 2300  Apple iPhone X 64GB 256GB Factory Unlocked Sma...  $399.50 to $469.90
# 2301  Apple Watch Series5 GPS+Cellular 40mm Space Gr...             $228.99
# 2302  Apple iPhone 11 Pro Max 64GB Factory Unlocked ...             $619.99
# 2303  NEW Never activated  Apple iPhone 8 256gb Unlo...             $299.99
#
#           Date
# 0     20211215
# 1     20211215
# ...

# %%
def calendar_scrape(year):
    site = 'https://www.ebay.com/b/Apple-Cell-Phones-Smartphones/9355/bn_319682'
    year = year

    safe_site = urllib.parse.quote_plus(site)

    url = f'https://web.archive.org/__wb/calendarcaptures/2?url={safe_site}&date={year}&groupby=day'

    resp = requests.get(url).json()

    complete = []
    complete_df = pd.DataFrame()
    for item in resp['items']:
        if len(str(item[0])) == 4:
            day = str(item[0])[-2:]
            month = str(item[0])[:2]
        else:
            day = str(item[0])[-2:]
            month = str(item[0])[:1].zfill(2)

        day_url = f'https://web.archive.org/__wb/calendarcaptures/2?url={safe_site}&date={year}{month}{day}'

        time_data = requests.get(day_url).json()
        #print(f'Finished {day_url}')

        for t in time_data['items']:
            time_str = str(t[0]).zfill(6)

            final_url = f'https://web.archive.org/web/{year}{month}{day}{time_str}/{site}'

            complete.append(final_url)
            complete_df = complete_df.append(complete, ignore_index=True)
    complete_df = complete_df.rename(columns={0:'Link'})
    
    return complete_df

# %%
scrape_2020 = calendar_scrape(2020)
scrape_2020.head()
# Out:
# <ipython-input-43-2bb32a373f1b>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_df = complete_df.append(complete, ignore_index=True)
#                                                       Link
# 0        https://web.archive.org/web/20200101003040/htt...
# 1        https://web.archive.org/web/20200101003040/htt...
# 2        https://web.archive.org/web/20200101095842/htt...
# 3        https://web.archive.org/web/20200101003040/htt...
# 4        https://web.archive.org/web/20200101095842/htt...
# ...                                                    ...
# 1046176  https://web.archive.org/web/20201231064757/htt...
# 1046177  https://web.archive.org/web/20201231112909/htt...
# 1046178  https://web.archive.org/web/20201231165205/htt...
# 1046179  https://web.archive.org/web/20201231190632/htt...
# 1046180  https://web.archive.org/web/20201231232141/htt...
#
# [1046181 rows x 1 columns]

# %%
scrape_2020.head()
scrape_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046181 entries, 0 to 1046180
# Data columns (total 1 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Link    1046181 non-null  object
# dtypes: object(1)
# memory usage: 8.0+ MB

# %%
scrape_2020_short = scrape_2020[:55]
scrape_2020_short
# Out:
#                                                  Link        Fulldate  Year  \
# 0   https://web.archive.org/web/20200101003040/htt...  20200101111455  2020
# 1   https://web.archive.org/web/20200101003040/htt...  20200101111455  2020
# 2   https://web.archive.org/web/20200101095842/htt...  20200101111455  2020
# 3   https://web.archive.org/web/20200101003040/htt...  20200101111455  2020
# 4   https://web.archive.org/web/20200101095842/htt...  20200101111455  2020
# 5   https://web.archive.org/web/20200101100230/htt...  20200101111455  2020
# 6   https://web.archive.org/web/20200101003040/htt...  20200101111455  2020
# 7   https://web.archive.org/web/20200101095842/htt...  20200101111455  2020
# 8   https://web.archive.org/web/20200101100230/htt...  20200101111455  2020
# 9   https://web.archive.org/web/20200101111455/htt...  20200101111455  2020
# 10  https://web.archive.org/web/20200101003040/htt...  20200101111455  2020
# ...

# %%
df_compressed = []
def df_edit(df, year):
    for i in df['Link']:
        #print(i)
        string = i
        string_ = string.split('/')
    #string = string.copy(string)
    df['Fulldate'] = string_[4]
    df['Year'] = string_[4][:4]
    df['Month'] = string_[4][4:6]
    df['Day'] = string_[4][6:8]
    df['Category'] = string_[9]
    df['Category_id'] = string_[10]
    df['bn_id'] = string_[11]
    #df_final = df.drop_duplicates(subset=['Year','Month','Day'],keep="last")
    #df_final.to_csv(f'{year}.csv')
    return df

# %%
df_20202 = df_edit(scrape_2020_short,2020)
df_20202
# Out:
# <ipython-input-186-636f73a148ec>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fulldate'] = string_[4]
# <ipython-input-186-636f73a148ec>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = string_[4][:4]
# <ipython-input-186-636f73a148ec>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_compressed
# Out:
# [                                                 Link        Fulldate  Year  \
#  0   https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
#  1   https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
#  2   https://web.archive.org/web/20200101095842/htt...  20200102171620  2020
#  3   https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
#  4   https://web.archive.org/web/20200101095842/htt...  20200102171620  2020
#  5   https://web.archive.org/web/20200101100230/htt...  20200102171620  2020
#  6   https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
#  7   https://web.archive.org/web/20200101095842/htt...  20200102171620  2020
#  8   https://web.archive.org/web/20200101100230/htt...  20200102171620  2020
#  9   https://web.archive.org/web/20200101111455/htt...  20200102171620  2020
#  10  https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
# ...

# %%
df_2020_short = df_edit(scrape_2020_short,2020)
df_2020_short
# Out:
# <ipython-input-173-c9ca03ef84e5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fulldate'] = string_[4]
# <ipython-input-173-c9ca03ef84e5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = string_[4][:4]
# <ipython-input-173-c9ca03ef84e5>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2020 = df_edit(scrape_2020, 2020)
df_2020.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [148], in <cell line: 1>()
# ----> 1 df_2020 = df_edit(scrape_2020, 2020)
#       2 df_2020.head(2)
#
# Input In [134], in df_edit(df, year)
#       7 df['Fulldate'] = string_[4]
#       8 df['Year'] = string_[4][:4]
# ----> 9 df['Month'] = string_[4][4:6]
#      10 df['Day'] = string_[4][6:8]
#      11 df['Category'] = string_[9]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3845, in DataFrame._set_item(self, key, value)
#    3842         if isinstance(existing_piece, DataFrame):
# ...

# %%
import pymysql
def df_to_SQL(df):
    engine =create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}".format(user='root',pw="Boston1429$$",
                                                                              db='NBA_since_2000'))
    df.to_sql('EBAY', con=engine, if_exists='append',chunksize=1000,index=False)

# %%
df_to_SQL(df_2020)

# %%
def drop_dupes(df):
    for i in df['Fulldate']:
        df_ = df.drop_duplicates(subset=['Year','Month','Day'],keep='first')
    return df_

# %%
drop_dupes(df_2020_short)
# Out:
#                                                 Link        Fulldate  Year  \
# 0  https://web.archive.org/web/20200101003040/htt...  20200102171620  2020
#
#   Month Day                       Category Category_id      bn_id
# 0    01  02  Apple-Cell-Phones-Smartphones        9355  bn_319682

# %%
year = string1_edit[4][:4]
day = string1_edit[4][6:8]
month = string1_edit[4][4:6]
category = string1_edit[9]
catgory_id = string1_edit[10]
bn_id = string1_edit[11]

# %%
string1 = scrape_2020['Link'].iloc[0]

string1_edit = string1.split('/')
string1_edit
# Out:
# ['https:',
#  '',
#  'web.archive.org',
#  'web',
#  '20200101003040',
#  'https:',
#  '',
#  'www.ebay.com',
#  'b',
#  'Apple-Cell-Phones-Smartphones',
#  '9355',
#  'bn_319682']

# %%
fulldate = string1_edit[4]
year = string1_edit[4][:4]
day = string1_edit[4][6:8]
month = string1_edit[4][4:6]
category = string1_edit[9]
catgory_id = string1_edit[10]
bn_id = string1_edit[11]

# %%
day = string1_edit[4][6:8]
month = string1_edit[4][4:6]
day, month
# Out:
# ('01', '01')

# %%
scrape_2020_1 = scrape_2020[1]
scrape_2020_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 scrape_2020_1 = scrape_2020[1]
#       2 scrape_2020_1
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
# ...

# %%
page_ = requests.get(scrape_2020_1)
soup_ = bs(page_.content, "lxml")
soup_.prettify()

# %%
product_title = []
prices = []


def get_prices(category, url):
    #category_id = df_AAPL_.loc[df_AAPL_.Category == category, 'Category_id'].iloc[0] 
    #bn_id = df_AAPL_.loc[df_AAPL_.Category == category, 'bn_id'].iloc[0]
    url = scrape_2020_1
    buy_it_now = '?rt=nc&LH_BIN=1'
    url_sold = url+buy_it_now 
    page = requests.get(url_sold)
    soup = bs(page.content, "lxml")
    items = soup.find_all('div', class_='s-item__info clearfix')
    #print(items)
    for item in items:
        title_all = soup.find_all('h3', class_='s-item__title')
        for title in title_all:
            product_title.append(title.text)
        price_all = soup.find_all('span', class_="s-item__price")
        for price in price_all:
            prices.append(price.text)
    return product_title, prices

# %%
scrape_2020_1 = get_prices('Apple-Cell-Phones-Smartphones', scrape_2020_1)
scrape_2020_1

# %%
len(product_title)

# %%
scrape_2020_10 = scrape_2020[1000]
scrape_2020_10

scrape_2020_50 = scrape_2020[500]
scrape_2020_50

# %%
product_title_ = []
prices_ = []


def get_prices(category, url):
    #category_id = df_AAPL_.loc[df_AAPL_.Category == category, 'Category_id'].iloc[0] 
    #bn_id = df_AAPL_.loc[df_AAPL_.Category == category, 'bn_id'].iloc[0]
    url = url
    buy_it_now = '?rt=nc&LH_BIN=1'
    url_sold = url+buy_it_now 
    page = requests.get(url_sold)
    soup = bs(page.content, "lxml")
    items = soup.find_all('div', class_='s-item__info clearfix')
    #print(items)
    for item in items:
        title_all = soup.find_all('h3', class_='s-item__title')
        for title in title_all:
            product_title_.append(title.text)
        price_all = soup.find_all('span', class_="s-item__price")
        for price in price_all:
            prices_.append(price.text)
    return product_title_, prices_

# %%
scrape_2020_100 = get_prices('Apple-Cell-Phones-Smartphones',scrape_2020_10)

# %%
len(product_title_)

# %%
product_title_2 = []
prices_2 = []


def get_prices_multi_2(category, url):
    #category_id = df_AAPL_.loc[df_AAPL_.Category == category, 'Category_id'].iloc[0] 
    #bn_id = df_AAPL_.loc[df_AAPL_.Category == category, 'bn_id'].iloc[0]
    url = url
    buy_it_now = '?rt=nc&LH_BIN=1'
    url_sold = url+buy_it_now 
    page = requests.get(url_sold)
    soup = bs(page.content, "lxml")

    while True:
        items = soup.find_all('div', class_='s-item__info clearfix')
        #print(items)
        for item in items:
            title_all = soup.find_all('h3', class_='s-item__title')
            for title in title_all:
                product_title_2.append(title.text)
            price_all = soup.find_all('span', class_="s-item__price")
            for price in price_all:
                prices_2.append(price.text)
        return product_title_2, prices_2
            #break
        
        next_page_full = soup.find('a', {'class':'ebayui-pagination__control'}).get('href')
        #next_page_full =url_sold+next_page
        next_page_full
        
        url = next_page_full
        page = requests.get(url)
        soup = bs(page.text, 'lxml')
        return url

# %%
scrape_2020_100_multi = get_prices_multi_2('Apple-Cell-Phones-Smartphones',scrape_2020_11)

# %%
len(product_title_2)

# %%
scrape_2020_11

# %%
scrape_2020_10

# %%
scrape_2020_50_multi = get_prices_multi_2('Apple-Cell-Phones-Smartphones',scrape_2020_50)

# %%
len(product_title_2)
